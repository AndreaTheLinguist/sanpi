# %% [markdown]
#  # Calculating Trigger ~ `UNIT` frequencies and AMs directly from final parquets
#  initiated: _January 16, 2025_
#  > The previously authored notebook `calc_trigger_AM.*` relies on `UCS` command line tools,
#  > which this attempt will not, thereby simplifying the pipeline and file outputs.
#
#  Loading imports

# %%
from am_notebooks import *
from source.utils.LexicalCategories import SPECIAL_ADV
from association_measures import frequencies as amfq, measures as amms

L1 = 'trigger_lemma'
L2 = 'adv_form_lower'
pd.set_option('display.max_colwidth', 15)
pd.set_option('display.max_columns', 6)
pd.set_option('display.width', 120)
HIT_DATA_DIR = Path('/share/compling/data/sanpi/2_hit_tables')
NEG_SUPER_PARQ = HIT_DATA_DIR.joinpath('RBdirect/ALL-RBdirect_final.parq')
POS_SUPER_PARQ = HIT_DATA_DIR.joinpath(
    'not-RBdirect/ALL_not-RBdirect_final.parq')
NEG_MIRROR_PARQ = HIT_DATA_DIR.joinpath('NEGmirror/ALL-NEGmirror_final.parq')
POS_MIRROR_PARQ = HIT_DATA_DIR.joinpath('POSmirror/ALL-POSmirror_final.parq')
print(timestamp_today())


def rename_trigger_dep_info(df):
    if df.filter(['neg_head', 'mir_head', 'neg_deprel', 'mir_deprel']).empty:
        return df
    return df.assign(
        trigger_head=df.filter(
            ['neg_head', 'mir_head']).iloc[:, 0],
        trigger_deprel=df.filter(
            ['neg_deprel', 'mir_deprel']).iloc[:, 0],
    )


def fix_word_null(df):
    """Fix null values in adjective and adverb columns.

    This function replaces null values in 'adj_form_lower' and 'adv_form_lower'
    columns of a DataFrame with the string 'null'. 
    That is, these are cases where the string "null" 
    was improperly interpreted as '<NA>' rather than the literal word, "null".

    Args:
        df: Pandas DataFrame containing 'adj_form_lower' and 'adv_form_lower' columns.

    Returns:
        Pandas DataFrame with null values in specified columns replaced with 'null'.
    """

    return df.assign(adj_form_lower=df.adj_form_lower.fillna('null'),
                     adv_form_lower=df.adv_form_lower.fillna('null'),
                     trigger_lower=df.trigger_lower.fillna('null'))


def load_trigger_info(parq_paths):
    sources = []
    trig_node = 'neg'
    polarity = 'neg'
    for path in parq_paths:
        if 'POS' in path.stem:
            trig_node = 'mir'
            polarity = 'pos'
        _df = pd.read_parquet(
            path, engine='pyarrow',
            columns=(pd.Series(
                [L1, L2] +
                ['trigger_lemma', 'trigger_lower', 'bigram_lower',
                 f'{trig_node}_head', f'{trig_node}_deprel',
                 'adv_form_lower', 'adj_form_lower', 'bigram_id']
            ).drop_duplicates().to_list()))
        _df = rename_trigger_dep_info(_df)
        _df = _df.assign(polarity=polarity).convert_dtypes()
        sources.append(_df)
    trigger_df = pd.concat(sources) if len(sources) > 1 else sources[0]
    trigger_df = trigger_df.loc[:, ~
                                trigger_df.columns.str.startswith(('neg_', 'mir_'))]
    trigger_df = fix_word_null(trigger_df)
    if any(trigger_df.trigger_lemma.str.startswith('ain')):
        aint_triggered = trigger_df.trigger_lemma.isin(["ain't", "aint"])
        trigger_df.loc[aint_triggered, :] = trigger_df.loc[aint_triggered, :].assign(
            trigger_lemma='not')
    trigger_df.info()
    return trigger_df
# Out:
# 2025-03-10

# %%
# %%

df_super_neg = load_trigger_info([NEG_SUPER_PARQ])
print(df_super_neg.describe().T.iloc[:, 1:].convert_dtypes())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3188297 entries, apw_eng_19971117_0849_61:4-6-7 to pcc_eng_val_3.10643_x51716_28:5-7-8
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   trigger_lemma   string
#  1   adv_form_lower  string
#  2   trigger_lower   string
#  3   bigram_lower    string
#  4   adj_form_lower  string
#  5   bigram_id       string
#  6   trigger_head    string
#  7   trigger_deprel  string
#  8   polarity        string
# dtypes: string(9)
# memory usage: 243.2+ MB
#                  unique             top     freq
# trigger_lemma        15             not  2871807
# adv_form_lower     5579              as   533878
# trigger_lower        54             not  2005270
# bigram_lower     187832         as_good    44635
# adj_form_lower    28060            good   131430
# bigram_id       3188297  apw_eng_199...        1
# trigger_head          2             ADJ  3101239
# trigger_deprel       33          advmod  2701472
# polarity              1             neg  3188297

# %%
# %%

def display_trigger_totals(_df, dataset='superset',
                           polar='negative',
                           cross='lower',
                           cmap='YlGnBu'):
    x = f'trigger_{cross}'
    cross_count_label = f"{x} total".replace('_', ' ')
    total_name = 'lemma total'
    _df[total_name] = _df.trigger_lemma.map(_df.trigger_lemma.value_counts())
    indexers = ['polarity', 'rigger_lemma', total_name] if _df.polarity.nunique() > 1 else [
        'trigger_lemma', total_name]
    for_sty = _df.groupby(indexers).value_counts(
        [x,]).to_frame(cross_count_label)
    if cross == 'head':
        if _df[x].nunique() > 2:
            _df[x] = _df[x].map(
                {'ADJ': 'BIGRAM', 'MIR': 'TRIGGER', 'NEG': 'TRIGGER'})
        cross_name = 'dependency head'
        for_sty = for_sty.unstack().fillna(0).droplevel(
            0, axis=1).reset_index(level=total_name).sort_index(axis=1)
        # head_totals = _df.value_counts(x).to_frame(cross_count_label).T
        print(_df.value_counts(x)
              .to_frame(cross_count_label).T
              .style.background_gradient(cmap, axis=1)
              .to_latex(siunitx=True, convert_css=True).replace('_', ' '))
        for_sty = (
            for_sty  # .assign(Total=q.sum(axis=1))
            .sort_values(total_name, ascending=False)
            .convert_dtypes())
    else:
        cross_name = 'lowercase form'
        for_sty = (
            for_sty.reset_index(level=total_name)
            .sort_values([total_name, cross_count_label], ascending=False)
            # .reset_index(level=x)
            # .filter([total_name, x, cross_count_label])
            .filter([total_name, cross_count_label])
        )
    for_sty['lemma % N'] = (for_sty[total_name] / for_sty[total_name].sum()) * 100
    _sty = (for_sty.sort_index(axis=1).style
            .background_gradient(
                axis=0, cmap=cmap))
    # nb_display(_sty)
    tex_table = save_latex_table(
        sty=_sty, 
        longtable=cross=='lower',
        caption=(
            f'{dataset} {polar} Trigger Lemma Frequencies by {cross_name}'.title()),
        label=f'trig-lemma-{cross}-{dataset[:3]}-{polar[:3]}',
        verbose=True,
        latex_subdir='ch2/triggers',
        latex_stem=f'trigger_lemma-{cross}_counts_{dataset[:3]}-{polar[:3]}')


display_trigger_totals(df_super_neg)
# Out:
# Caption: Superset Negative Trigger Lemma Frequencies By Lowercase Form
# <style type="text/css">
# #T_0184c th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_0184c th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_0184c th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_0184c caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_0184c_row0_col0, #T_0184c_row0_col1, #T_0184c_row0_col2, #T_0184c_row1_col0, #T_0184c_row1_col1, #T_0184c_row2_col0, #T_0184c_row2_col1, #T_0184c_row3_col0, #T_0184c_row3_col1, #T_0184c_row4_col0, #T_0184c_row4_col1, #T_0184c_row5_col0, #T_0184c_row5_col1, #T_0184c_row6_col0, #T_0184c_row6_col1, #T_0184c_row7_col0, #T_0184c_row7_col1, #T_0184c_row8_col0, #T_0184c_row8_col1, #T_0184c_row9_col0, #T_0184c_row9_col1, #T_0184c_row10_col0, #T_0184c_row10_col1, #T_0184c_row11_col0, #T_0184c_row11_col1, #T_0184c_row12_col0, #T_0184c_row12_col1, #T_0184c_row13_col0, #T_0184c_row13_col1, #T_0184c_row14_col0, #T_0184c_row14_col1, #T_0184c_row15_col0, #T_0184c_row15_col1, #T_0184c_row16_col0, #T_0184c_row16_col1, #T_0184c_row17_col0, #T_0184c_row17_col1, #T_0184c_row18_col0, #T_0184c_row18_col1, #T_0184c_row19_col0, #T_0184c_row19_col1, #T_0184c_row20_col0, #T_0184c_row20_col1, #T_0184c_row21_col0, #T_0184c_row21_col1, #T_0184c_row22_col0, #T_0184c_row22_col1, #T_0184c_row23_col0, #T_0184c_row23_col1, #T_0184c_row24_col0, #T_0184c_row24_col1, #T_0184c_row25_col0, #T_0184c_row25_col1, #T_0184c_row26_col0, #T_0184c_row26_col1, #T_0184c_row27_col0, #T_0184c_row27_col1, #T_0184c_row28_col0, #T_0184c_row28_col1, #T_0184c_row29_col0, #T_0184c_row29_col1 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row1_col2 {
#   background-color: #63c3bf;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row2_col2, #T_0184c_row3_col2, #T_0184c_row4_col2, #T_0184c_row5_col2, #T_0184c_row6_col2, #T_0184c_row7_col2, #T_0184c_row8_col2, #T_0184c_row9_col2, #T_0184c_row10_col2, #T_0184c_row11_col2, #T_0184c_row12_col2, #T_0184c_row13_col2, #T_0184c_row14_col2, #T_0184c_row15_col2, #T_0184c_row16_col2, #T_0184c_row17_col2, #T_0184c_row18_col2, #T_0184c_row19_col2, #T_0184c_row20_col2, #T_0184c_row21_col2, #T_0184c_row22_col2, #T_0184c_row23_col2, #T_0184c_row24_col2, #T_0184c_row25_col2, #T_0184c_row26_col2, #T_0184c_row27_col2, #T_0184c_row28_col2, #T_0184c_row29_col2, #T_0184c_row32_col2, #T_0184c_row33_col2, #T_0184c_row35_col2, #T_0184c_row36_col2, #T_0184c_row39_col2, #T_0184c_row41_col2, #T_0184c_row42_col0, #T_0184c_row42_col1, #T_0184c_row42_col2, #T_0184c_row43_col0, #T_0184c_row43_col1, #T_0184c_row43_col2, #T_0184c_row44_col0, #T_0184c_row44_col1, #T_0184c_row44_col2, #T_0184c_row45_col0, #T_0184c_row45_col1, #T_0184c_row45_col2, #T_0184c_row46_col0, #T_0184c_row46_col1, #T_0184c_row46_col2, #T_0184c_row47_col0, #T_0184c_row47_col1, #T_0184c_row47_col2, #T_0184c_row48_col0, #T_0184c_row48_col1, #T_0184c_row48_col2, #T_0184c_row49_col0, #T_0184c_row49_col1, #T_0184c_row49_col2, #T_0184c_row50_col0, #T_0184c_row50_col1, #T_0184c_row50_col2, #T_0184c_row51_col0, #T_0184c_row51_col1, #T_0184c_row51_col2, #T_0184c_row52_col1, #T_0184c_row52_col2, #T_0184c_row53_col1, #T_0184c_row53_col2, #T_0184c_row54_col1, #T_0184c_row54_col2 {
#   background-color: #ffffd9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row30_col0, #T_0184c_row30_col1 {
#   background-color: #fafdce;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row30_col2 {
#   background-color: #f7fcc7;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row31_col0, #T_0184c_row31_col1, #T_0184c_row32_col0, #T_0184c_row32_col1, #T_0184c_row33_col0, #T_0184c_row33_col1 {
#   background-color: #fafdcf;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row31_col2 {
#   background-color: #f8fcca;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row34_col0, #T_0184c_row34_col1, #T_0184c_row35_col0, #T_0184c_row35_col1, #T_0184c_row36_col0, #T_0184c_row36_col1, #T_0184c_row37_col2 {
#   background-color: #feffd6;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row34_col2 {
#   background-color: #fdfed4;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row37_col0, #T_0184c_row37_col1, #T_0184c_row38_col0, #T_0184c_row38_col1, #T_0184c_row38_col2, #T_0184c_row39_col0, #T_0184c_row39_col1, #T_0184c_row40_col0, #T_0184c_row40_col1, #T_0184c_row40_col2, #T_0184c_row41_col0, #T_0184c_row41_col1 {
#   background-color: #feffd8;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_0184c_row52_col0, #T_0184c_row53_col0, #T_0184c_row54_col0 {
#   background-color: #ffffd9;
#   color: #000000;
#   background-color: Gray!30;
#   color: Black!70;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_0184c">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0184c_level0_col0" class="col_heading level0 col0" >lemma \% N</th>
#       <th id="T_0184c_level0_col1" class="col_heading level0 col1" >lemma total</th>
#       <th id="T_0184c_level0_col2" class="col_heading level0 col2" >trigger lower total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Trigger Lemma</th>
#       <th class="index_name level1" >Trigger Lower</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0184c_level0_row0" class="row_heading level0 row0" rowspan="30">not</th>
#       <th id="T_0184c_level1_row0" class="row_heading level1 row0" >not</th>
#       <td id="T_0184c_row0_col0" class="data row0 col0" >3.31</td>
#       <td id="T_0184c_row0_col1" class="data row0 col1" >2,871,807</td>
#       <td id="T_0184c_row0_col2" class="data row0 col2" >2,005,270</td>
#     </tr>
#     <tr>
#       <th id="T_0184c_level1_row1" class="row_heading level1 row1" >n't</th>
#       <td id="T_0184c_row1_col0" class="data row1 col0" >3.31</td>
#       <td id="T_0184c_row1_col1" class="data row1 col1" >2,871,807</td>
#       <td id="T_0184c_row1_col2" class="data row1 col2" >863,289</td>
#     </tr>
#     <tr>
#       <th id="T_0184c_level1_row2" class="row_heading level1 row2" >ain't</th>
#       <td id="T_0184c_row2_col0" class="data row2 col0" >3.31</td>
#       <td id="T_0184c_row2_col1" class="data row2 col1" >2,871,807</td>
#       <td id="T_0184c_row2_col2" class="data row2 col2" >2,052</td>
#     </tr>
#     <tr>
#       <th id="T_0184c_level1_row3" class="row_heading level1 row3" >nit</th>
#       <td id="T_0184c_row3_col0" class="data row3 col0" >3.31</td>
#       <td id="T_0184c_row3_col1" class="data row3 col1" >2,871,807</td>
#       <td id="T_0184c_row3_col2" class="data row3 col2" >608</td>
#     </tr>
#     <tr>
#       <th id="T_0184c_level1_row4" class="row_heading level1 row4" >aint</th>
#       <td id="T_0184c_row4_col0" class="data row4 col0" >3.31</td>
#       <td id="T_0184c_row4_col1" class="data row4 col1" >2,871,807</td>
#       <td id="T_0184c_row4_col2" class="data row4 col2" >270</td>
#     </tr>
#     <tr>
#       <th id="T_0184c_level1_row5" class="row_heading level1 row5" >nt</th>
#       <td id="T_0184c_row5_col0" class="data row5 col0" >3.31</td>
#       <td id="T_0184c_row5_col1" class="data row5 col1" >2,871,807</td>
#       <td id="T_0184c_row5_col2" class="data row5 co
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/triggers/trigger_lemma-lower_counts_sup-neg.2025-03-10.tex

# %%
# %%

display_trigger_totals(df_super_neg, cross='head', cmap='YlOrRd')
# Out:
# \begin{tabular}{lSS}
# {trigger head} & {ADJ} & {NEG} \\
# trigger head total & {\cellcolor[HTML]{800026}} \color[HTML]{F1F1F1} 3101239 & {\cellcolor[HTML]{FFFFCC}} \color[HTML]{000000} 87058 \\
# \end{tabular}
#
# Caption: Superset Negative Trigger Lemma Frequencies By Dependency Head
# <style type="text/css">
# #T_820ae th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_820ae th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_820ae th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_820ae caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_820ae_row0_col0, #T_820ae_row0_col2, #T_820ae_row0_col3, #T_820ae_row2_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row0_col1 {
#   background-color: #ffeda1;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row1_col0, #T_820ae_row1_col2, #T_820ae_row1_col3 {
#   background-color: #fffac0;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row1_col1, #T_820ae_row6_col1, #T_820ae_row7_col0, #T_820ae_row7_col1, #T_820ae_row7_col2, #T_820ae_row7_col3, #T_820ae_row8_col0, #T_820ae_row8_col2, #T_820ae_row8_col3, #T_820ae_row9_col0, #T_820ae_row9_col1, #T_820ae_row9_col2, #T_820ae_row9_col3, #T_820ae_row10_col0, #T_820ae_row10_col1, #T_820ae_row10_col2, #T_820ae_row10_col3, #T_820ae_row11_col0, #T_820ae_row11_col1, #T_820ae_row11_col2, #T_820ae_row11_col3, #T_820ae_row12_col0, #T_820ae_row12_col2, #T_820ae_row12_col3, #T_820ae_row13_col0, #T_820ae_row13_col1, #T_820ae_row13_col2, #T_820ae_row13_col3, #T_820ae_row14_col0, #T_820ae_row14_col1, #T_820ae_row14_col2, #T_820ae_row14_col3 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row2_col0, #T_820ae_row3_col2, #T_820ae_row3_col3, #T_820ae_row8_col1 {
#   background-color: #fffec9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row2_col2, #T_820ae_row2_col3 {
#   background-color: #fffac1;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row3_col0, #T_820ae_row4_col0, #T_820ae_row4_col2, #T_820ae_row4_col3, #T_820ae_row5_col0, #T_820ae_row5_col2, #T_820ae_row5_col3, #T_820ae_row6_col0, #T_820ae_row6_col2, #T_820ae_row6_col3 {
#   background-color: #fffecb;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row3_col1 {
#   background-color: #ffe998;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row4_col1, #T_820ae_row12_col1 {
#   background-color: #ffffcc;
#   color: #000000;
#   background-color: Gray!30;
#   color: Black!70;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_820ae_row5_col1 {
#   background-color: #fffcc5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_820ae">
#   <thead>
#     <tr>
#       <th class="index_name level0" >trigger_head</th>
#       <th id="T_820ae_level0_col0" class="col_heading level0 col0" >ADJ</th>
#       <th id="T_820ae_level0_col1" class="col_heading level0 col1" >NEG</th>
#       <th id="T_820ae_level0_col2" class="col_heading level0 col2" >lemma \% N</th>
#       <th id="T_820ae_level0_col3" class="col_heading level0 col3" >lemma total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Trigger Lemma</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_820ae_level0_row0" class="row_heading level0 row0" >not</th>
#       <td id="T_820ae_row0_col0" class="data row0 col0" >2,863,597</td>
#       <td id="T_820ae_row0_col1" class="data row0 col1" >8,210</td>
#       <td id="T_820ae_row0_col2" class="data row0 col2" >90.07</td>
#       <td id="T_820ae_row0_col3" class="data row0 col3" >2,871,807</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row1" class="row_heading level0 row1" >never</th>
#       <td id="T_820ae_row1_col0" class="data row1 col0" >111,026</td>
#       <td id="T_820ae_row1_col1" class="data row1 col1" >63</td>
#       <td id="T_820ae_row1_col2" class="data row1 col2" >3.48</td>
#       <td id="T_820ae_row1_col3" class="data row1 col3" >111,089</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row2" class="row_heading level0 row2" >nothing</th>
#       <td id="T_820ae_row2_col0" class="data row2 col0" >34,067</td>
#       <td id="T_820ae_row2_col1" class="data row2 col1" >66,446</td>
#       <td id="T_820ae_row2_col2" class="data row2 col2" >3.15</td>
#       <td id="T_820ae_row2_col3" class="data row2 col3" >100,513</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row3" class="row_heading level0 row3" >none</th>
#       <td id="T_820ae_row3_col0" class="data row3 col0" >21,502</td>
#       <td id="T_820ae_row3_col1" class="data row3 col1" >9,951</td>
#       <td id="T_820ae_row3_col2" class="data row3 col2" >0.99</td>
#       <td id="T_820ae_row3_col3" class="data row3 col3" >31,453</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row4" class="row_heading level0 row4" >nor</th>
#       <td id="T_820ae_row4_col0" class="data row4 col0" >15,925</td>
#       <td id="T_820ae_row4_col1" class="data row4 col1" >0</td>
#       <td id="T_820ae_row4_col2" class="data row4 col2" >0.50</td>
#       <td id="T_820ae_row4_col3" class="data row4 col3" >15,925</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row5" class="row_heading level0 row5" >without</th>
#       <td id="T_820ae_row5_col0" class="data row5 col0" >13,339</td>
#       <td id="T_820ae_row5_col1" class="data row5 col1" >1,486</td>
#       <td id="T_820ae_row5_col2" class="data row5 col2" >0.46</td>
#       <td id="T_820ae_row5_col3" class="data row5 col3" >14,825</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row6" class="row_heading level0 row6" >no</th>
#       <td id="T_820ae_row6_col0" class="data row6 col0" >12,343</td>
#       <td id="T_820ae_row6_col1" class="data row6 col1" >95</td>
#       <td id="T_820ae_row6_col2" class="data row6 col2" >0.39</td>
#       <td id="T_820ae_row6_col3" class="data row6 col3" >12,438</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row7" class="row_heading level0 row7" >neither</th>
#       <td id="T_820ae_row7_col0" class="data row7 col0" >6,436</td>
#       <td id="T_820ae_row7_col1" class="data row7 col1" >92</td>
#       <td id="T_820ae_row7_col2" class="data row7 col2" >0.20</td>
#       <td id="T_820ae_row7_col3" class="data row7 col3" >6,528</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row8" class="row_heading level0 row8" >nobody</th>
#       <td id="T_820ae_row8_col0" class="data row8 col0" >5,827</td>
#       <td id="T_820ae_row8_col1" class="data row8 col1" >538</td>
#       <td id="T_820ae_row8_col2" class="data row8 col2" >0.20</td>
#       <td id="T_820ae_row8_col3" class="data row8 col3" >6,365</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row9" class="row_heading level0 row9" >hardly</th>
#       <td id="T_820ae_row9_col0" class="data row9 col0" >5,517</td>
#       <td id="T_820ae_row9_col1" class="data row9 col1" >8</td>
#       <td id="T_820ae_row9_col2" class="data row9 col2" >0.17</td>
#       <td id="T_820ae_row9_col3" class="data row9 col3" >5,525</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row10" class="row_heading level0 row10" >rarely</th>
#       <td id="T_820ae_row10_col0" class="data row10 col0" >4,464</td>
#       <td id="T_820ae_row10_col1" class="data row10 col1" >10</td>
#       <td id="T_820ae_row10_col2" class="data row10 col2" >0.14</td>
#       <td id="T_820ae_row10_col3" class="data row10 col3" >4,474</td>
#     </tr>
#     <tr>
#       <th id="T_820ae_level0_row11" class="row_heading level0 row11" >few</th>
#       <td id="T_820ae_row11_col0" clas
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/triggers/trigger_lemma-head_counts_sup-neg.2025-03-10.tex

# %%
#%%

N_dict = {'super':  71961373,
          'mirror':  1680633}
def describe_triggers(_df):
    lemma_counts = _df.value_counts('trigger_lemma')
    form_counts = _df.value_counts('trigger_lower')
    trig_stats = lemma_counts.describe().to_frame('lemma').join(
        form_counts.describe().to_frame('lowercase form')
    ).convert_dtypes()
    trig_stats.columns.name = 'Trigger'
    trig_stats = trig_stats.rename(index={'count': 'unique'})
    trig_stats.loc['CV%'] = [(v.std()/v.mean()) * 100
                             for v in (lemma_counts, form_counts)]
    return trig_stats  # .iloc[1:, :]


# nb_display(describe_triggers(df_super_neg))
save_latex_table(
    describe_triggers(df_super_neg), default_SI=7.0,
    caption='Descriptive Statistics for Negative Superset Trigger Frequencies', 
    latex_subdir= 'ch2/freq/neg-super/', position='ht', verbose=True,
    latex_stem='neg-super-trigger-freq-descrip')
# Out:
# Caption: Descriptive Statistics for Negative Superset Trigger Frequencies
# <style type="text/css">
# #T_226a3 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_226a3 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_226a3 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_226a3 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_226a3_row0_col0, #T_226a3_row0_col1, #T_226a3_row1_col0, #T_226a3_row1_col1, #T_226a3_row2_col0, #T_226a3_row2_col1, #T_226a3_row3_col0, #T_226a3_row3_col1, #T_226a3_row4_col0, #T_226a3_row4_col1, #T_226a3_row5_col0, #T_226a3_row5_col1, #T_226a3_row6_col0, #T_226a3_row6_col1, #T_226a3_row7_col0, #T_226a3_row7_col1, #T_226a3_row8_col0, #T_226a3_row8_col1 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_226a3">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Trigger</th>
#       <th id="T_226a3_level0_col0" class="col_heading level0 col0" >lemma</th>
#       <th id="T_226a3_level0_col1" class="col_heading level0 col1" >lowercase form</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_226a3_level0_row0" class="row_heading level0 row0" >unique</th>
#       <td id="T_226a3_row0_col0" class="data row0 col0" >15.00</td>
#       <td id="T_226a3_row0_col1" class="data row0 col1" >54.00</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_226a3_row1_col0" class="data row1 col0" >212,553.13</td>
#       <td id="T_226a3_row1_col1" class="data row1 col1" >59,042.54</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_226a3_row2_col0" class="data row2 col0" >736,488.25</td>
#       <td id="T_226a3_row2_col1" class="data row2 col1" >294,680.56</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_226a3_row3_col0" class="data row3 col0" >796.00</td>
#       <td id="T_226a3_row3_col1" class="data row3 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row4" class="row_heading level0 row4" >25\%</th>
#       <td id="T_226a3_row4_col0" class="data row4 col0" >4,381.50</td>
#       <td id="T_226a3_row4_col1" class="data row4 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row5" class="row_heading level0 row5" >50\%</th>
#       <td id="T_226a3_row5_col0" class="data row5 col0" >6,528.00</td>
#       <td id="T_226a3_row5_col1" class="data row5 col1" >13.00</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row6" class="row_heading level0 row6" >75\%</th>
#       <td id="T_226a3_row6_col0" class="data row6 col0" >23,689.00</td>
#       <td id="T_226a3_row6_col1" class="data row6 col1" >1,846.75</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_226a3_row7_col0" class="data row7 col0" >2,871,807.00</td>
#       <td id="T_226a3_row7_col1" class="data row7 col1" >2,005,270.00</td>
#     </tr>
#     <tr>
#       <th id="T_226a3_level0_row8" class="row_heading level0 row8" >CV\%</th>
#       <td id="T_226a3_row8_col0" class="data row8 col0" >346.50</td>
#       <td id="T_226a3_row8_col1" class="data row8 col1" >499.10</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/freq/neg-super/neg-super-trigger-freq-descrip.2025-03-10.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch2/freq/neg-super/neg-super-trigger-freq-descrip.2025-03-10.tex')

# %%
# %%

df_mirror_neg = load_trigger_info([NEG_MIRROR_PARQ])
df_mirror_neg.describe().T.iloc[:, 1:].convert_dtypes()

# save_latex_table(
#     sty=(df_mirror_neg.groupby(['polarity', 'trigger_lemma']).value_counts(
#         ['trigger_lower']).to_frame()
#         .style
#         .background_gradient(axis=0, cmap='purple_rain')
#         .format(precision=0, thousands=',', escape='latex')),
#     caption=(r'Negative Mirror Subset Trigger Lemma Composition: attested forms'),
#     label='negmir-trig-lemma-vs-form',
#     longtable=True,
#     latex_subdir='triggers',
#     latex_stem='mirror-neg-trigger_lemma-form_counts')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 293456 entries, apw_eng_19941117_0297_31:3-4-5 to pcc_eng_val_3.09952_x50620_12:13-15-16
# Data columns (total 9 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   trigger_lemma   293456 non-null  string
#  1   adv_form_lower  293456 non-null  string
#  2   trigger_lower   293456 non-null  string
#  3   bigram_lower    293456 non-null  string
#  4   adj_form_lower  293456 non-null  string
#  5   bigram_id       293456 non-null  string
#  6   trigger_head    293456 non-null  string
#  7   trigger_deprel  293456 non-null  string
#  8   polarity        293456 non-null  string
# dtypes: string(9)
# memory usage: 22.4+ MB
#                 unique             top    freq
# trigger_lemma       12           never  111102
# adv_form_lower    2013            more   79045
# trigger_lower       20           never  111102
# bigram_lower     41019  more_important   12347
# adj_form_lower    8070       important   14913
# bigram_id       293456  apw_eng_199...       1
# trigger_head         2             ADJ  216433
# trigger_deprel      18          advmod  120867
# polarity             1             neg  293456

# %%
# %%

save_latex_table(
    describe_triggers(df_mirror_neg), default_SI=6.0,
    caption='Descriptive Statistics for Negative Mirror Subset Trigger Frequencies', 
    latex_subdir= 'ch2/freq/neg-mirror/', position='ht', verbose=True,
    latex_stem='neg-mirror-trigger-freq-descrip')

display_trigger_totals(df_mirror_neg, dataset='mirror')
display_trigger_totals(df_mirror_neg, dataset='mirror', cross='head', cmap='YlOrRd')
# Out:
# Caption: Descriptive Statistics for Negative Mirror Subset Trigger Frequencies
# <style type="text/css">
# #T_1d88f th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_1d88f th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1d88f th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1d88f caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_1d88f_row0_col0, #T_1d88f_row0_col1, #T_1d88f_row1_col0, #T_1d88f_row1_col1, #T_1d88f_row2_col0, #T_1d88f_row2_col1, #T_1d88f_row3_col0, #T_1d88f_row3_col1, #T_1d88f_row4_col0, #T_1d88f_row4_col1, #T_1d88f_row5_col0, #T_1d88f_row5_col1, #T_1d88f_row6_col0, #T_1d88f_row6_col1, #T_1d88f_row7_col0, #T_1d88f_row7_col1, #T_1d88f_row8_col0, #T_1d88f_row8_col1 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_1d88f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Trigger</th>
#       <th id="T_1d88f_level0_col0" class="col_heading level0 col0" >lemma</th>
#       <th id="T_1d88f_level0_col1" class="col_heading level0 col1" >lowercase form</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1d88f_level0_row0" class="row_heading level0 row0" >unique</th>
#       <td id="T_1d88f_row0_col0" class="data row0 col0" >12.00</td>
#       <td id="T_1d88f_row0_col1" class="data row0 col1" >20.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_1d88f_row1_col0" class="data row1 col0" >24,454.67</td>
#       <td id="T_1d88f_row1_col1" class="data row1 col1" >14,672.80</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_1d88f_row2_col0" class="data row2 col0" >38,879.07</td>
#       <td id="T_1d88f_row2_col1" class="data row2 col1" >32,027.43</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_1d88f_row3_col0" class="data row3 col0" >797.00</td>
#       <td id="T_1d88f_row3_col1" class="data row3 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row4" class="row_heading level0 row4" >25\%</th>
#       <td id="T_1d88f_row4_col0" class="data row4 col0" >3,671.25</td>
#       <td id="T_1d88f_row4_col1" class="data row4 col1" >4.75</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row5" class="row_heading level0 row5" >50\%</th>
#       <td id="T_1d88f_row5_col0" class="data row5 col0" >6,426.00</td>
#       <td id="T_1d88f_row5_col1" class="data row5 col1" >1,143.50</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row6" class="row_heading level0 row6" >75\%</th>
#       <td id="T_1d88f_row6_col0" class="data row6 col0" >19,770.00</td>
#       <td id="T_1d88f_row6_col1" class="data row6 col1" >7,161.75</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_1d88f_row7_col0" class="data row7 col0" >111,102.00</td>
#       <td id="T_1d88f_row7_col1" class="data row7 col1" >111,102.00</td>
#     </tr>
#     <tr>
#       <th id="T_1d88f_level0_row8" class="row_heading level0 row8" >CV\%</th>
#       <td id="T_1d88f_row8_col0" class="data row8 col0" >158.98</td>
#       <td id="T_1d88f_row8_col1" class="data row8 col1" >218.28</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/freq/neg-mirror/neg-mirror-trigger-freq-descrip.2025-03-10.tex
#
# Caption: Mirror Negative Trigger Lemma Frequencies By Lowercase Form
# <style type="text/css">
# #T_d6fdd th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_d6fdd th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_d6fdd th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_d6fdd caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_d6fdd_row0_col0, #T_d6fdd_row0_col1, #T_d6fdd_row0_col2 {
#   background-color: #081d58;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row1_col0, #T_d6fdd_row1_col1, #T_d6fdd_row1_col2, #T_d6fdd_row2_col0, #T_d6fdd_row2_col1, #T_d6fdd_row3_col0, #T_d6fdd_row3_col1 {
#   background-color: #1f2f87;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row2_col2, #T_d6fdd_row3_col2, #T_d6fdd_row5_col2, #T_d6fdd_row6_col2, #T_d6fdd_row9_col2, #T_d6fdd_row12_col2, #T_d6fdd_row13_col2, #T_d6fdd_row14_col2, #T_d6fdd_row18_col0, #T_d6fdd_row18_col1, #T_d6fdd_row19_col0, #T_d6fdd_row19_col1 {
#   background-color: #ffffd9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row4_col0, #T_d6fdd_row4_col1, #T_d6fdd_row5_col0, #T_d6fdd_row5_col1, #T_d6fdd_row6_col0, #T_d6fdd_row6_col1 {
#   background-color: #b9e4b5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row4_col2 {
#   background-color: #b7e3b6;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row7_col0, #T_d6fdd_row7_col1 {
#   background-color: #e9f7b1;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row7_col2 {
#   background-color: #e8f6b1;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row8_col0, #T_d6fdd_row8_col1, #T_d6fdd_row9_col0, #T_d6fdd_row9_col1 {
#   background-color: #f4fbc1;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row8_col2 {
#   background-color: #f3fabf;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row10_col0, #T_d6fdd_row10_col1 {
#   background-color: #f8fcc9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row10_col2, #T_d6fdd_row11_col2 {
#   background-color: #f7fcc7;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row11_col0, #T_d6fdd_row11_col1, #T_d6fdd_row12_col0, #T_d6fdd_row12_col1, #T_d6fdd_row13_col0, #T_d6fdd_row13_col1, #T_d6fdd_row14_col0, #T_d6fdd_row14_col1, #T_d6fdd_row15_col2 {
#   background-color: #f8fcca;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row15_col0, #T_d6fdd_row15_col1, #T_d6fdd_row16_col2 {
#   background-color: #f9fdcc;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row16_col0, #T_d6fdd_row16_col1 {
#   background-color: #fafdcf;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row17_col0, #T_d6fdd_row17_col1, #T_d6fdd_row19_col2 {
#   background-color: #feffd8;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_d6fdd_row17_col2, #T_d6fdd_row18_col2 {
#   background-color: #feffd6;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_d6fdd">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d6fdd_level0_col0" class="col_heading level0 col0" >lemma \% N</th>
#       <th id="T_d6fdd_level0_col1" class="col_heading level0 col1" >lemma total</th>
#       <th id="T_d6fdd_level0_col2" class="col_heading level0 col2" >trigger lower total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Trigger Lemma</th>
#       <th class="index_name level1" >Trigger Lower</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d6fdd_level0_row0" class="row_heading level0 row0" >never</th>
#       <th id="T_d6fdd_level1_row0" class="row_heading level1 row0" >never</th>
#       <td id="T_d6fdd_row0_col0" class="data row0 col0" >19.01</td>
#       <td id="T_d6fdd_row0_col1" class="data row0 col1" >111,102</td>
#       <td id="T_d6fdd_row0_col2" class="data row0 col2" >111,102</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level0_row1" class="row_heading level0 row1" rowspan="3">nothing</th>
#       <th id="T_d6fdd_level1_row1" class="row_heading level1 row1" >nothing</th>
#       <td id="T_d6fdd_row1_col0" class="data row1 col0" >17.12</td>
#       <td id="T_d6fdd_row1_col1" class="data row1 col1" >100,044</td>
#       <td id="T_d6fdd_row1_col2" class="data row1 col2" >100,012</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level1_row2" class="row_heading level1 row2" >nothings</th>
#       <td id="T_d6fdd_row2_col0" class="data row2 col0" >17.12</td>
#       <td id="T_d6fdd_row2_col1" class="data row2 col1" >100,044</td>
#       <td id="T_d6fdd_row2_col2" class="data row2 col2" >31</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level1_row3" class="row_heading level1 row3" >nothingis</th>
#       <td id="T_d6fdd_row3_col0" class="data row3 col0" >17.12</td>
#       <td id="T_d6fdd_row3_col1" class="data row3 col1" >100,044</td>
#       <td id="T_d6fdd_row3_col2" class="data row3 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level0_row4" class="row_heading level0 row4" rowspan="3">none</th>
#       <th id="T_d6fdd_level1_row4" class="row_heading level1 row4" >none</th>
#       <td id="T_d6fdd_row4_col0" class="data row4 col0" >5.35</td>
#       <td id="T_d6fdd_row4_col1" class="data row4 col1" >31,248</td>
#       <td id="T_d6fdd_row4_col2" class="data row4 col2" >31,215</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level1_row5" class="row_heading level1 row5" >nones</th>
#       <td id="T_d6fdd_row5_col0" class="data row5 col0" >5.35</td>
#       <td id="T_d6fdd_row5_col1" class="data row5 col1" >31,248</td>
#       <td id="T_d6fdd_row5_col2" class="data row5 col2" >32</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level1_row6" class="row_heading level1 row6" >non-exalts</th>
#       <td id="T_d6fdd_row6_col0" class="data row6 col0" >5.35</td>
#       <td id="T_d6fdd_row6_col1" class="data row6 col1" >31,248</td>
#       <td id="T_d6fdd_row6_col2" class="data row6 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level0_row7" class="row_heading level0 row7" >nor</th>
#       <th id="T_d6fdd_level1_row7" class="row_heading level1 row7" >nor</th>
#       <td id="T_d6fdd_row7_col0" class="data row7 col0" >2.73</td>
#       <td id="T_d6fdd_row7_col1" class="data row7 col1" >15,944</td>
#       <td id="T_d6fdd_row7_col2" class="data row7 col2" >15,944</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level0_row8" class="row_heading level0 row8" rowspan="2">no</th>
#       <th id="T_d6fdd_level1_row8" class="row_heading level1 row8" >no</th>
#       <td id="T_d6fdd_row8_col0" class="data row8 col0" >1.57</td>
#       <td id="T_d6fdd_row8_col1" class="data row8 col1" >9,175</td>
#       <td id="T_d6fdd_row8_col2" class="data row8 col2" >9,174</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level1_row9" class="row_heading level1 row9" >nys</th>
#       <td id="T_d6fdd_row9_col0" class="data row9 col0" >1.57</td>
#       <td id="T_d6fdd_row9_col1" class="data row9 col1" >9,175</td>
#       <td id="T_d6fdd_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_d6fdd_level0_row10" class="row_heading level0 row10" >neither</th>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/triggers/trigger_lemma-lower_counts_mir-neg.2025-03-10.tex
#
# \begin{tabular}{lSS}
# {trigger head} & {ADJ} & {NEG} \\
# trigger head total & {\cellcolor[HTML]{800026}} \color[HTML]{F1F1F1} 216433 & {\cellcolor[HTML]{FFFFCC}} \color[HTML]{000000} 77023 \\
# \end{tabular}
#
# Caption: Mirror Negative Trigger Lemma Frequencies By Dependency Head
# <style type="text/css">
# #T_9140d th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_9140d th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_9140d th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_9140d caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_9140d_row0_col0, #T_9140d_row0_col2, #T_9140d_row0_col3, #T_9140d_row1_col1 {
#   background-color: #800026;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row0_col1, #T_9140d_row4_col1, #T_9140d_row5_col1, #T_9140d_row7_col1, #T_9140d_row8_col1, #T_9140d_row10_col0, #T_9140d_row10_col1, #T_9140d_row10_col2, #T_9140d_row10_col3, #T_9140d_row11_col0, #T_9140d_row11_col1, #T_9140d_row11_col2, #T_9140d_row11_col3 {
#   background-color: #ffffcc;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row1_col0 {
#   background-color: #feca66;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row1_col2, #T_9140d_row1_col3 {
#   background-color: #b00026;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row2_col0 {
#   background-color: #ffe48c;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row2_col1 {
#   background-color: #ffe998;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row2_col2, #T_9140d_row2_col3 {
#   background-color: #fed16e;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row3_col0, #T_9140d_row3_col2, #T_9140d_row3_col3 {
#   background-color: #ffeb9c;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row3_col1, #T_9140d_row9_col1 {
#   background-color: #ffffcc;
#   color: #000000;
#   background-color: Gray!30;
#   color: Black!70;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row4_col0, #T_9140d_row4_col2, #T_9140d_row4_col3 {
#   background-color: #fff4b2;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row5_col0, #T_9140d_row5_col2, #T_9140d_row5_col3 {
#   background-color: #fff8ba;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row6_col0 {
#   background-color: #fff9bd;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row6_col1 {
#   background-color: #fffec9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row6_col2, #T_9140d_row6_col3 {
#   background-color: #fff8bb;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row7_col0, #T_9140d_row7_col2, #T_9140d_row7_col3 {
#   background-color: #fff9be;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row8_col0, #T_9140d_row8_col2, #T_9140d_row8_col3 {
#   background-color: #fffac1;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_9140d_row9_col0, #T_9140d_row9_col2, #T_9140d_row9_col3 {
#   background-color: #fffecb;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_9140d">
#   <thead>
#     <tr>
#       <th class="index_name level0" >trigger_head</th>
#       <th id="T_9140d_level0_col0" class="col_heading level0 col0" >ADJ</th>
#       <th id="T_9140d_level0_col1" class="col_heading level0 col1" >NEG</th>
#       <th id="T_9140d_level0_col2" class="col_heading level0 col2" >lemma \% N</th>
#       <th id="T_9140d_level0_col3" class="col_heading level0 col3" >lemma total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Trigger Lemma</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9140d_level0_row0" class="row_heading level0 row0" >never</th>
#       <td id="T_9140d_row0_col0" class="data row0 col0" >111,039</td>
#       <td id="T_9140d_row0_col1" class="data row0 col1" >63</td>
#       <td id="T_9140d_row0_col2" class="data row0 col2" >37.86</td>
#       <td id="T_9140d_row0_col3" class="data row0 col3" >111,102</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row1" class="row_heading level0 row1" >nothing</th>
#       <td id="T_9140d_row1_col0" class="data row1 col0" >33,760</td>
#       <td id="T_9140d_row1_col1" class="data row1 col1" >66,284</td>
#       <td id="T_9140d_row1_col2" class="data row1 col2" >34.09</td>
#       <td id="T_9140d_row1_col3" class="data row1 col3" >100,044</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row2" class="row_heading level0 row2" >none</th>
#       <td id="T_9140d_row2_col0" class="data row2 col0" >21,319</td>
#       <td id="T_9140d_row2_col1" class="data row2 col1" >9,929</td>
#       <td id="T_9140d_row2_col2" class="data row2 col2" >10.65</td>
#       <td id="T_9140d_row2_col3" class="data row2 col3" >31,248</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row3" class="row_heading level0 row3" >nor</th>
#       <td id="T_9140d_row3_col0" class="data row3 col0" >15,944</td>
#       <td id="T_9140d_row3_col1" class="data row3 col1" >0</td>
#       <td id="T_9140d_row3_col2" class="data row3 col2" >5.43</td>
#       <td id="T_9140d_row3_col3" class="data row3 col3" >15,944</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row4" class="row_heading level0 row4" >no</th>
#       <td id="T_9140d_row4_col0" class="data row4 col0" >9,081</td>
#       <td id="T_9140d_row4_col1" class="data row4 col1" >94</td>
#       <td id="T_9140d_row4_col2" class="data row4 col2" >3.13</td>
#       <td id="T_9140d_row4_col3" class="data row4 col3" >9,175</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row5" class="row_heading level0 row5" >neither</th>
#       <td id="T_9140d_row5_col0" class="data row5 col0" >6,400</td>
#       <td id="T_9140d_row5_col1" class="data row5 col1" >91</td>
#       <td id="T_9140d_row5_col2" class="data row5 col2" >2.21</td>
#       <td id="T_9140d_row5_col3" class="data row5 col3" >6,491</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row6" class="row_heading level0 row6" >nobody</th>
#       <td id="T_9140d_row6_col0" class="data row6 col0" >5,823</td>
#       <td id="T_9140d_row6_col1" class="data row6 col1" >538</td>
#       <td id="T_9140d_row6_col2" class="data row6 col2" >2.17</td>
#       <td id="T_9140d_row6_col3" class="data row6 col3" >6,361</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row7" class="row_heading level0 row7" >hardly</th>
#       <td id="T_9140d_row7_col0" class="data row7 col0" >5,519</td>
#       <td id="T_9140d_row7_col1" class="data row7 col1" >8</td>
#       <td id="T_9140d_row7_col2" class="data row7 col2" >1.88</td>
#       <td id="T_9140d_row7_col3" class="data row7 col3" >5,527</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row8" class="row_heading level0 row8" >rarely</th>
#       <td id="T_9140d_row8_col0" class="data row8 col0" >4,470</td>
#       <td id="T_9140d_row8_col1" class="data row8 col1" >10</td>
#       <td id="T_9140d_row8_col2" class="data row8 col2" >1.53</td>
#       <td id="T_9140d_row8_col3" class="data row8 col3" >4,480</td>
#     </tr>
#     <tr>
#       <th id="T_9140d_level0_row9" class="row_heading level0 row9" >barely</th>
#       <td id="T_9140d_row9_col0" class="data row9 col0" >1,245</td>
#       <td id="T_9140d_row9_col1" class="data row9 col1" >0</td>
#       <td id="T_9140d_row9_col2" class="data row9 col2" >0.42</td>
#       <t
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/triggers/trigger_lemma-head_counts_mir-neg.2025-03-10.tex

# %%
# %%

df_mirror_pos = load_trigger_info([POS_MIRROR_PARQ])
df_mirror_pos.describe().T.iloc[:, 1:].convert_dtypes()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1396324 entries, apw_eng_19941121_0258_30:1-4-5 to pcc_eng_val_3.11049_x52389_100:30-31-32
# Data columns (total 9 columns):
#  #   Column          Non-Null Count    Dtype
# ---  ------          --------------    -----
#  0   trigger_lemma   1396324 non-null  string
#  1   adv_form_lower  1396324 non-null  string
#  2   trigger_lower   1396324 non-null  string
#  3   bigram_lower    1396324 non-null  string
#  4   adj_form_lower  1396324 non-null  string
#  5   bigram_id       1396324 non-null  string
#  6   trigger_head    1396324 non-null  string
#  7   trigger_deprel  1396324 non-null  string
#  8   polarity        1396324 non-null  string
# dtypes: string(9)
# memory usage: 106.5+ MB
#                  unique             top     freq
# trigger_lemma        16       something   309632
# adv_form_lower     5322            more   208524
# trigger_lower        35       something   309483
# bigram_lower     178916       as_simple    14992
# adj_form_lower    21484       different    34454
# bigram_id       1396324  apw_eng_199...        1
# trigger_head          2             ADJ  1076623
# trigger_deprel       20          advmod   451671
# polarity              1             pos  1396324

# %%
#%%

save_latex_table(
    describe_triggers(df_mirror_pos), default_SI=6.0,
    caption='Descriptive Statistics for Positive Mirror Subset Trigger Frequencies', 
    latex_subdir= 'ch2/freq/pos-mirror/', position='ht', verbose=True,
    latex_stem='pos-mirror-trigger-freq-descrip')

display_trigger_totals(df_mirror_pos, dataset='mirror', polar='positive', cmap='PuBu')
display_trigger_totals(df_mirror_pos, dataset='mirror', polar='positive',  cross='head', cmap='PuBuGn')

# save_latex_table(
#     sty=(df_mirror_pos.groupby(['polarity', 'trigger_lemma']).value_counts(
#         ['trigger_lower']).to_frame()
#         .style
#         .background_gradient(axis=0, cmap='purple_rain')
#         .format(precision=0, thousands=',', escape='latex')),
#     caption=(r'Negative Mirror Subset Trigger Lemma Composition: attested forms'),
#     label='posmir-trig-lemma-vs-form',
#     longtable=True,
#     latex_subdir='triggers',
#     latex_stem='mirror-pos-trigger_lemma-form_counts')
# Out:
# Caption: Descriptive Statistics for Positive Mirror Subset Trigger Frequencies
# <style type="text/css">
# #T_fd331 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_fd331 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_fd331 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_fd331 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_fd331_row0_col0, #T_fd331_row0_col1, #T_fd331_row1_col0, #T_fd331_row1_col1, #T_fd331_row2_col0, #T_fd331_row2_col1, #T_fd331_row3_col0, #T_fd331_row3_col1, #T_fd331_row4_col0, #T_fd331_row4_col1, #T_fd331_row5_col0, #T_fd331_row5_col1, #T_fd331_row6_col0, #T_fd331_row6_col1, #T_fd331_row7_col0, #T_fd331_row7_col1, #T_fd331_row8_col0, #T_fd331_row8_col1 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_fd331">
#   <thead>
#     <tr>
#       <th class="index_name level0" >Trigger</th>
#       <th id="T_fd331_level0_col0" class="col_heading level0 col0" >lemma</th>
#       <th id="T_fd331_level0_col1" class="col_heading level0 col1" >lowercase form</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_fd331_level0_row0" class="row_heading level0 row0" >unique</th>
#       <td id="T_fd331_row0_col0" class="data row0 col0" >16.00</td>
#       <td id="T_fd331_row0_col1" class="data row0 col1" >35.00</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row1" class="row_heading level0 row1" >mean</th>
#       <td id="T_fd331_row1_col0" class="data row1 col0" >87,270.25</td>
#       <td id="T_fd331_row1_col1" class="data row1 col1" >39,894.97</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row2" class="row_heading level0 row2" >std</th>
#       <td id="T_fd331_row2_col0" class="data row2 col0" >104,293.06</td>
#       <td id="T_fd331_row2_col1" class="data row2 col1" >82,105.48</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row3" class="row_heading level0 row3" >min</th>
#       <td id="T_fd331_row3_col0" class="data row3 col0" >334.00</td>
#       <td id="T_fd331_row3_col1" class="data row3 col1" >1.00</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row4" class="row_heading level0 row4" >25\%</th>
#       <td id="T_fd331_row4_col0" class="data row4 col0" >22,694.50</td>
#       <td id="T_fd331_row4_col1" class="data row4 col1" >1.50</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row5" class="row_heading level0 row5" >50\%</th>
#       <td id="T_fd331_row5_col0" class="data row5 col0" >44,761.00</td>
#       <td id="T_fd331_row5_col1" class="data row5 col1" >18.00</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row6" class="row_heading level0 row6" >75\%</th>
#       <td id="T_fd331_row6_col0" class="data row6 col0" >88,812.75</td>
#       <td id="T_fd331_row6_col1" class="data row6 col1" >39,017.00</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row7" class="row_heading level0 row7" >max</th>
#       <td id="T_fd331_row7_col0" class="data row7 col0" >309,632.00</td>
#       <td id="T_fd331_row7_col1" class="data row7 col1" >309,483.00</td>
#     </tr>
#     <tr>
#       <th id="T_fd331_level0_row8" class="row_heading level0 row8" >CV\%</th>
#       <td id="T_fd331_row8_col0" class="data row8 col0" >119.51</td>
#       <td id="T_fd331_row8_col1" class="data row8 col1" >205.80</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/freq/pos-mirror/pos-mirror-trigger-freq-descrip.2025-03-10.tex
#
# Caption: Mirror Positive Trigger Lemma Frequencies By Lowercase Form
# <style type="text/css">
# #T_42284 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_42284 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_42284 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_42284 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_42284_row0_col0, #T_42284_row0_col1, #T_42284_row0_col2, #T_42284_row1_col0, #T_42284_row1_col1, #T_42284_row2_col0, #T_42284_row2_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row1_col2, #T_42284_row2_col2, #T_42284_row4_col2, #T_42284_row6_col2, #T_42284_row7_col2, #T_42284_row9_col2, #T_42284_row10_col2, #T_42284_row12_col2, #T_42284_row13_col2, #T_42284_row18_col2, #T_42284_row20_col2, #T_42284_row21_col2, #T_42284_row23_col2, #T_42284_row25_col2, #T_42284_row26_col2, #T_42284_row28_col2, #T_42284_row29_col2, #T_42284_row31_col2, #T_42284_row33_col2, #T_42284_row34_col0, #T_42284_row34_col1, #T_42284_row34_col2 {
#   background-color: #fff7fb;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row3_col0, #T_42284_row3_col1, #T_42284_row3_col2, #T_42284_row4_col0, #T_42284_row4_col1 {
#   background-color: #023b5d;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row5_col0, #T_42284_row5_col1, #T_42284_row5_col2, #T_42284_row6_col0, #T_42284_row6_col1, #T_42284_row7_col0, #T_42284_row7_col1 {
#   background-color: #0569a5;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row8_col0, #T_42284_row8_col1, #T_42284_row9_col0, #T_42284_row9_col1, #T_42284_row10_col0, #T_42284_row10_col1 {
#   background-color: #b0c2de;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row8_col2 {
#   background-color: #afc1dd;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row11_col0, #T_42284_row11_col1, #T_42284_row11_col2, #T_42284_row12_col0, #T_42284_row12_col1, #T_42284_row13_col0, #T_42284_row13_col1, #T_42284_row14_col2 {
#   background-color: #cacee5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row14_col0, #T_42284_row14_col1 {
#   background-color: #cccfe5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row15_col0, #T_42284_row15_col1 {
#   background-color: #dad9ea;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row15_col2 {
#   background-color: #d9d8ea;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row16_col0, #T_42284_row16_col1, #T_42284_row16_col2 {
#   background-color: #e5e1ef;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row17_col0, #T_42284_row17_col1, #T_42284_row18_col0, #T_42284_row18_col1 {
#   background-color: #ece7f2;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row17_col2 {
#   background-color: #ebe6f2;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row19_col0, #T_42284_row19_col1, #T_42284_row19_col2, #T_42284_row20_col0, #T_42284_row20_col1, #T_42284_row21_col0, #T_42284_row21_col1 {
#   background-color: #ede7f2;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row22_col0, #T_42284_row22_col1, #T_42284_row22_col2, #T_42284_row23_col0, #T_42284_row23_col1 {
#   background-color: #f0eaf4;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row24_col0, #T_42284_row24_col1, #T_42284_row24_col2, #T_42284_row25_col0, #T_42284_row25_col1, #T_42284_row26_col0, #T_42284_row26_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row27_col0, #T_42284_row27_col1, #T_42284_row27_col2, #T_42284_row28_col0, #T_42284_row28_col1, #T_42284_row29_col0, #T_42284_row29_col1 {
#   background-color: #fbf4f9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row30_col0, #T_42284_row30_col1, #T_42284_row31_col0, #T_42284_row31_col1, #T_42284_row32_col2 {
#   background-color: #fef6fa;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row30_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_42284_row32_col0, #T_42284_row32_col1, #T_42284_row33_col0, #T_42284_row33_col1 {
#   background-color: #fef6fb;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_42284">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_42284_level0_col0" class="col_heading level0 col0" >lemma \% N</th>
#       <th id="T_42284_level0_col1" class="col_heading level0 col1" >lemma total</th>
#       <th id="T_42284_level0_col2" class="col_heading level0 col2" >trigger lower total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Trigger Lemma</th>
#       <th class="index_name level1" >Trigger Lower</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_42284_level0_row0" class="row_heading level0 row0" rowspan="3">something</th>
#       <th id="T_42284_level1_row0" class="row_heading level1 row0" >something</th>
#       <td id="T_42284_row0_col0" class="data row0 col0" >9.07</td>
#       <td id="T_42284_row0_col1" class="data row0 col1" >309,632</td>
#       <td id="T_42284_row0_col2" class="data row0 col2" >309,483</td>
#     </tr>
#     <tr>
#       <th id="T_42284_level1_row1" class="row_heading level1 row1" >somethings</th>
#       <td id="T_42284_row1_col0" class="data row1 col0" >9.07</td>
#       <td id="T_42284_row1_col1" class="data row1 col1" >309,632</td>
#       <td id="T_42284_row1_col2" class="data row1 col2" >131</td>
#     </tr>
#     <tr>
#       <th id="T_42284_level1_row2" class="row_heading level1 row2" >somethin</th>
#       <td id="T_42284_row2_col0" class="data row2 col0" >9.07</td>
#       <td id="T_42284_row2_col1" class="data row2 col1" >309,632</td>
#       <td id="T_42284_row2_col2" class="data row2 col2" >18</td>
#     </tr>
#     <tr>
#       <th id="T_42284_level0_row3" class="row_heading level0 row3" rowspan="2">or</th>
#       <th id="T_42284_level1_row3" class="row_heading level1 row3" >or</th>
#       <td id="T_42284_row3_col0" class="data row3 col0" >8.93</td>
#       <td id="T_42284_row3_col1" class="data row3 col1" >304,971</td>
#       <td id="T_42284_row3_col2" class="data row3 col2" >304,970</td>
#     </tr>
#     <tr>
#       <th id="T_42284_level1_row4" class="row_heading level1 row4" >ors</th>
#       <td id="T_42284_row4_col0" class="data row4 col0" >8.93</td>
#       <td id="T_42284_row4_col1" class="data row4 col1" >304,971</td>
#       <td id="T_42284_row4_col2" class="data row4 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_42284_level0_row5" class="row_heading level0 row5" rowspan="3">all</th>
#       <th id="T_42284_level1_row5" class="row_heading level1 row5" >all</th>
#       <td id="T_42284_row5_col0" class="data row5 col0" >7.15</td>
#       <td id="T_42284_row5_col1" class="data row5 col1" >243,962</td>
#       <td id="T_42284_row5_col2" class="data row5 col2" >243,951</td>
#     </tr>
#     <tr>
#       <th id="T
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/triggers/trigger_lemma-lower_counts_mir-pos.2025-03-10.tex
#
# \begin{tabular}{lSS}
# {trigger head} & {ADJ} & {MIR} \\
# trigger head total & {\cellcolor[HTML]{014636}} \color[HTML]{F1F1F1} 1076623 & {\cellcolor[HTML]{FFF7FB}} \color[HTML]{000000} 319701 \\
# \end{tabular}
#
# Caption: Mirror Positive Trigger Lemma Frequencies By Dependency Head
# <style type="text/css">
# #T_33f7f th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_33f7f th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_33f7f th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_33f7f caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_33f7f_row0_col0, #T_33f7f_row11_col1 {
#   background-color: #f5ecf5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row0_col1, #T_33f7f_row0_col2, #T_33f7f_row0_col3, #T_33f7f_row1_col0 {
#   background-color: #014636;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row1_col1, #T_33f7f_row4_col1, #T_33f7f_row5_col1, #T_33f7f_row6_col1, #T_33f7f_row7_col1, #T_33f7f_row8_col1, #T_33f7f_row12_col1, #T_33f7f_row13_col1, #T_33f7f_row14_col0, #T_33f7f_row15_col0, #T_33f7f_row15_col1, #T_33f7f_row15_col2, #T_33f7f_row15_col3 {
#   background-color: #fff7fb;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row1_col2, #T_33f7f_row1_col3 {
#   background-color: #014a39;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row2_col0 {
#   background-color: #027978;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row2_col1, #T_33f7f_row3_col1, #T_33f7f_row10_col1, #T_33f7f_row14_col1, #T_33f7f_row14_col2, #T_33f7f_row14_col3 {
#   background-color: #fef6fb;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row2_col2, #T_33f7f_row2_col3 {
#   background-color: #027b7b;
#   color: #f1f1f1;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row3_col0, #T_33f7f_row3_col2, #T_33f7f_row3_col3 {
#   background-color: #b0c2de;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row4_col0 {
#   background-color: #c9cee4;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row4_col2, #T_33f7f_row4_col3, #T_33f7f_row5_col0 {
#   background-color: #cacee5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row5_col2, #T_33f7f_row5_col3 {
#   background-color: #cccfe5;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row6_col0 {
#   background-color: #d9d7e9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row6_col2, #T_33f7f_row6_col3 {
#   background-color: #dad7ea;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row7_col0 {
#   background-color: #e4dded;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row7_col2, #T_33f7f_row7_col3 {
#   background-color: #e5deed;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row8_col0, #T_33f7f_row8_col2, #T_33f7f_row8_col3 {
#   background-color: #ece2f0;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row9_col0 {
#   background-color: #eee4f1;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row9_col1, #T_33f7f_row13_col0, #T_33f7f_row13_col2, #T_33f7f_row13_col3 {
#   background-color: #fef6fa;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row9_col2, #T_33f7f_row9_col3 {
#   background-color: #ede3f0;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row10_col0 {
#   background-color: #f0e7f2;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row10_col2, #T_33f7f_row10_col3 {
#   background-color: #f0e6f2;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row11_col0, #T_33f7f_row12_col0, #T_33f7f_row12_col2, #T_33f7f_row12_col3 {
#   background-color: #fbf3f9;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# #T_33f7f_row11_col2, #T_33f7f_row11_col3 {
#   background-color: #f2e9f3;
#   color: #000000;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_33f7f">
#   <thead>
#     <tr>
#       <th class="index_name level0" >trigger_head</th>
#       <th id="T_33f7f_level0_col0" class="col_heading level0 col0" >ADJ</th>
#       <th id="T_33f7f_level0_col1" class="col_heading level0 col1" >MIR</th>
#       <th id="T_33f7f_level0_col2" class="col_heading level0 col2" >lemma \% N</th>
#       <th id="T_33f7f_level0_col3" class="col_heading level0 col3" >lemma total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Trigger Lemma</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_33f7f_level0_row0" class="row_heading level0 row0" >something</th>
#       <td id="T_33f7f_row0_col0" class="data row0 col0" >19,715</td>
#       <td id="T_33f7f_row0_col1" class="data row0 col1" >289,917</td>
#       <td id="T_33f7f_row0_col2" class="data row0 col2" >22.17</td>
#       <td id="T_33f7f_row0_col3" class="data row0 col3" >309,632</td>
#     </tr>
#     <tr>
#       <th id="T_33f7f_level0_row1" class="row_heading level0 row1" >or</th>
#       <td id="T_33f7f_row1_col0" class="data row1 col0" >304,920</td>
#       <td id="T_33f7f_row1_col1" class="data row1 col1" >51</td>
#       <td id="T_33f7f_row1_col2" class="data row1 col2" >21.84</td>
#       <td id="T_33f7f_row1_col3" class="data row1 col3" >304,971</td>
#     </tr>
#     <tr>
#       <th id="T_33f7f_level0_row2" class="row_heading level0 row2" >all</th>
#       <td id="T_33f7f_row2_col0" class="data row2 col0" >242,683</td>
#       <td id="T_33f7f_row2_col1" class="data row2 col1" >1,279</td>
#       <td id="T_33f7f_row2_col2" class="data row2 col2" >17.47</td>
#       <td id="T_33f7f_row2_col3" class="data row2 col3" >243,962</td>
#     </tr>
#     <tr>
#       <th id="T_33f7f_level0_row3" class="row_heading level0 row3" >some</th>
#       <td id="T_33f7f_row3_col0" class="data row3 col0" >105,476</td>
#       <td id="T_33f7f_row3_col1" class="data row3 col1" >2,158</td>
#       <td id="T_33f7f_row3_col2" class="data row3 col2" >7.71</td>
#       <td id="T_33f7f_row3_col3" class="data row3 col3" >107,634</td>
#     </tr>
#     <tr>
#       <th id="T_33f7f_level0_row4" class="row_heading level0 row4" >often</th>
#       <td id="T_33f7f_row4_col0" class="data row4 col0" >82,474</td>
#       <td id="T_33f7f_row4_col1" class="data row4 col1" >65</td>
#       <td id="T_33f7f_row4_col2" class="data row4 col2" >5.91</td>
#       <td id="T_33f7f_row4_col3" class="data row4 col3" >82,539</td>
#     </tr>
#     <tr>
#       <th id="T_33f7f_level0_row5" class="row_heading level0 row5" >always</th>
#       <td id="T_33f7f_row5_col0" class="data row5 col0" >82,213</td>
#       <td id="T_33f7f_row5_col1" class="data row5 col1" >25</td>
#       <td id="T_33f7f_row5_col2" class="data row5 col2" >5.89</td>
#       <td id="T_33f7f_row5_col3" class="data row5 col3" >82,238</td>
#     </tr>
#     <tr>
#       <th id="T_33f7f_level0_row6" class="row_heading level0 row6" >sometimes</th>
#       <td id="T_33f7f_row6_col0" class="data row6 col0" >64,092</td>
#       <td id="T_33f7f_row6_col1" class="data row6 col1" >58</td>
#       <td id="T_33f7f_row6_col2" class="data row6 col2" >4.59</td>
#       <td id="T_33f7f_row6_col3" class="data row6 col3" >64,150</td>
#     </tr>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch2/triggers/trigger_lemma-head_counts_mir-pos.2025-03-10.tex
