# %%
import pandas as pd

from source.utils import FREQ_DIR, RESULT_DIR, UCS_DIR, confirm_dir
from source.utils.associate import (BINARY_ASSOC_ARGS, add_extra_am,
                                    associate_ucs, confirm_basic_ucs)
from source.utils.associate import convert_ucs_to_csv as ucs2csv
from source.utils.associate import get_associations_csv as init_am, AM_DF_DIR
from source.utils.associate import manipulate_ucs, seek_readable_ucs, adjust_assoc_columns
pd.set_option('display.float_format', '{:,.2f}'.format)

# %% [markdown]
# set parameters

# %%
UNIT = 'Adj'
PAT_DIR = 'POSmirror'
# PAT_DIR = 'NEGmirror'
# PAT_DIR = 'RBdirect'
# PAT_DIR = 'ANYmirror'
# FRQ_FLOOR = 3
# FRQ_FLOOR = 10
# FRQ_FLOOR = 20
# FRQ_FLOOR = 50
FRQ_FLOOR = 100  # BUG 100 will be used regardless, so set it to this to at least keep the naming accurate
ADVADJ_TSV = FREQ_DIR.joinpath(
    f'{PAT_DIR}/ucs_format/Adv{UNIT}_frq-thrMIN-7.35f.tsv')
FOCUS = ['f', 'unexpected_f',
         'conservative_log_ratio',
         'am_p1_given2', 'am_p2_given1',
         'am_p1_given2_simple', 'am_p2_given1_simple',
         'am_log_likelihood',
         #  'mutual_information', 'am_odds_ratio_disc', 't_score',
         'N', 'f1', 'f2', 'E11',
         'l1', 'l2']

# %%
def invert_set_dict(d: dict):
    return {v: k for k in d for v in d[k]}

# %% [markdown]
# ## 1. Run `seek_readable_ucs()` to generate consistent output path

# %%
readable = seek_readable_ucs(min_freq=FRQ_FLOOR,
                             ucs_subdir='adv_adj',
                             contained_counts_path=ADVADJ_TSV)
print(readable.relative_to(RESULT_DIR))
# Out:
#     > seeking `adv_adj/POSmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x*` frequency data and initial associations...
# ucs/adv_adj/POSmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv

# %% [markdown]
#  Snippet of starting frequency data (`ADVADJ_TSV`)

# %%
! head -5 {ADVADJ_TSV} | column -t
# Out:
# 14875  as          simple
# 10996  more        important
# 8327   completely  different
# 7819   more        likely
# 7221   too         easy

# %% [markdown]
# ## 2. Run `confirm_basic_ucs()` (if needed)

# %%
if not readable.is_file():
    basic_ucs_path = readable.parent.parent.joinpath(
        readable.name.replace('.rsort-view_am-only.txt', '.ds.gz'))
    print(
        f'Creating initial UCS table: `{basic_ucs_path.relative_to(RESULT_DIR)}')

    basic_ucs_path = confirm_basic_ucs(
        basic_ucs_path,
        freq_floor=FRQ_FLOOR,
        contained_counts_path=ADVADJ_TSV)

# %% [markdown]
# Excerpt of initial UCS table

# %%
init_readable = UCS_DIR.joinpath(
    f'adv_adj/{PAT_DIR}/readable'
).joinpath(f'{ADVADJ_TSV.name.replace(".tsv","")}_min{FRQ_FLOOR}x.init.txt')
! head -7 {init_readable}
# Out:
#              l1  l2                    f     f2      f1        N
# ---------------  ----------------  -----  -----  ------  -------
#            more  different           138  34503  207924  1472077
#            very  different          6219  34503  175105  1472077
#             too  different           103  34503  112009  1472077
#              so  different          1844  34503  104617  1472077
#              as  different           134  34503   76987  1472077

# %% [markdown]
# ## 3. Run `associate_ucs()` (if needed)

# %%
if not readable.is_file():
    associate_ucs(basic_ucs_path)

transform_ucs_log = f'/share/compling/projects/sanpi/logs/associate/ucs//ucs-{PAT_DIR}_Adv{UNIT}_frq-thrMIN-7-35f_min{FRQ_FLOOR}x*.log'
! head -15 `ls -t1 {transform_ucs_log} | head -1`
! echo '...'
! tail -2 `ls -t1 {transform_ucs_log} | head -1`
# Out:
# # Manipulating AdvAdj_frq-thrMIN-7-35f_min100x ucs table
# path to this script: /share/compling/projects/sanpi/script/transform_ucs.sh
# Sun Jun  2 18:49:09 EDT 2024
# (TMP: /share/compling/projects/sanpi/results/ucs/adv_adj/POSmirror/tmp/tmp_POSmirror-20240602-184909.AdvAdj_frq-thrMIN-7-35f_min100x)
# ## Initial Contingency Info
#
# DATA SET FILE:  /share/compling/projects/sanpi/results/ucs/adv_adj/POSmirror/AdvAdj_frq-thrMIN-7.35f_min100x.ds.gz
#
# # Frequency signatures computed by the ucs-make-tables tool for relational cooccurrences.
# # Sample size:  N = 1472077 tokens,  V = 178159 pair types.
# # A frequency threshold of f >= 100 was applied, leaving V = 1892 pair types.
#
# ##:: size = 1892
# ##:: threshold = 100
#
# ...
# Loading data set /share/compling/projects/sanpi/results/ucs/adv_adj/POSmirror/AdvAdj_frq-thrMIN-7.35f_min100x.rsort.gz ... 1892 rows
# Script finished at Sun Jun  2 18:49:22 EDT 2024

# %% [markdown]
# ## 4. Run `ucs_to_csv()` to convert `ucs/[PAT_DIR]/readable/*.txt` to format that `pandas` can parse as a dataframe

# %%
! head -5 {readable}
csv_path = ucs2csv(readable)
print(f'CSV: `{csv_path.relative_to(RESULT_DIR)}`')
# Out:
# l1,l2,f,E11,am_log_likelihood,am_odds_ratio_disc,am_p1_given2,am_p2_given1,am_p1_given2_simple,am_p2_given1_simple,f1,f2,N
# even,triple,113,4.8168418,667.103411,2.464213905,0.8868206947,0.0019378547,0.9262295082,0.0019442198,58121,122,1472077
# very,least,101,12.3709018,403.690341,2.332278545,0.8522630785,0.0005744837,0.9711538462,0.0005767968,175105,104,1472077
# early,next,144,0.0200968,2641.253161,5.418049794,0.8371902794,0.8371902794,0.8372093023,0.8372093023,172,172,1472077
# even,third,371,17.5301455,2009.332874,2.092529357,0.7963434648,0.0063316068,0.8355855856,0.0063832350,58121,444,1472077
# UCS table text converted & saved as /share/compling/projects/sanpi/results/ucs/adv_adj/POSmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv
# CSV: `ucs/adv_adj/POSmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv`

# %% [markdown]
# ##

# %%
adx_amdf = pd.read_csv(csv_path).convert_dtypes()
adx_amdf
# Out:
#          l1         l2    f      E11  am_log_likelihood  am_odds_ratio_disc  \
# 0      even     triple  113     4.82             667.10                2.46
# 1      very      least  101    12.37             403.69                2.33
# 2     early       next  144     0.02           2,641.25                5.42
# 3      even      third  371    17.53           2,009.33                2.09
# 4       now       live  407     1.86           4,083.81                3.05
# ...     ...        ...  ...      ...                ...                 ...
# 1887   more     simple  373 3,190.73          -4,470.00               -1.00
# 1888   more       easy  204 2,117.97          -3,165.21               -1.08
# 1889   more  available  105 1,614.43          -2,678.88               -1.25
# 1890   more     better  119 1,832.38          -3,043.50               -1.25
# 1891   more  different  138 4,873.39          -9,334.24               -1.62
#
#       am_p1_given2  am_p2_given1  am_p1_given2_simple  am_p2_given1_simple  \
# 0             0.89          0.00                 0.93                 0.00
# 1             0.85          0.00                 0.97                 0.00
# 2             0.84          0.84                 0.84                 0.84
# 3             0.80          0.01                 0.84                 0.01
# 4             0.79          0.08                 0.79                 0.08
# ...            ...           ...                  ...                  ...
# 1887         -0.13         -0.02                 0.02                 0.00
# 1888         -0.13         -0.01                 0.01                 0.00
# 1889         -0.13         -0.01                 0.01                 0.00
# 1890         -0.13         -0.01                 0.01                 0.00
# 1891         -0.14         -0.03                 0.00                 0.00
#
#           f1     f2        N
# 0      58121    122  1472077
# 1     175105    104  1472077
# 2        172    172  1472077
# 3      58121    444  1472077
# 4       5320    514  1472077
# ...      ...    ...      ...
# 1887  207924  22590  1472077
# 1888  207924  14995  1472077
# 1889  207924  11430  1472077
# 1890  207924  12973  1472077
# 1891  207924  34503  1472077
#
# [1892 rows x 13 columns]

# %%
adx_amdf['key'] = (adx_amdf.l1 + '~' +
                   adx_amdf.l2).astype('string')
adx_amdf = adx_amdf.set_index('key')
adx_amdf
# Out:
#                    l1         l2    f      E11  am_log_likelihood  \
# key
# even~triple      even     triple  113     4.82             667.10
# very~least       very      least  101    12.37             403.69
# early~next      early       next  144     0.02           2,641.25
# even~third       even      third  371    17.53           2,009.33
# now~live          now       live  407     1.86           4,083.81
# ...               ...        ...  ...      ...                ...
# more~simple      more     simple  373 3,190.73          -4,470.00
# more~easy        more       easy  204 2,117.97          -3,165.21
# more~available   more  available  105 1,614.43          -2,678.88
# more~better      more     better  119 1,832.38          -3,043.50
# more~different   more  different  138 4,873.39          -9,334.24
#
#                 am_odds_ratio_disc  am_p1_given2  am_p2_given1  \
# key
# even~triple                   2.46          0.89          0.00
# very~least                    2.33          0.85          0.00
# early~next                    5.42          0.84          0.84
# even~third                    2.09          0.80          0.01
# now~live                      3.05          0.79          0.08
# ...                            ...           ...           ...
# more~simple                  -1.00         -0.13         -0.02
# more~easy                    -1.08         -0.13         -0.01
# more~available               -1.25         -0.13         -0.01
# more~better                  -1.25         -0.13         -0.01
# more~different               -1.62         -0.14         -0.03
#
#                 am_p1_given2_simple  am_p2_given1_simple      f1     f2  \
# key
# even~triple                    0.93                 0.00   58121    122
# very~least                     0.97                 0.00  175105    104
# early~next                     0.84                 0.84     172    172
# even~third                     0.84                 0.01   58121    444
# now~live                       0.79                 0.08    5320    514
# ...                             ...                  ...     ...    ...
# more~simple                    0.02                 0.00  207924  22590
# more~easy                      0.01                 0.00  207924  14995
# more~available                 0.01                 0.00  207924  11430
# more~better                    0.01                 0.00  207924  12973
# more~different                 0.00                 0.00  207924  34503
#
#                       N
# key
# even~triple     1472077
# very~least      1472077
# early~next      1472077
# even~third      1472077
# now~live        1472077
# ...                 ...
# more~simple     1472077
# more~easy       1472077
# more~available  1472077
# more~better     1472077
# more~different  1472077
#
# [1892 rows x 13 columns]

# %% [markdown]
# ## 6. Save to `./results/assoc_df/`

# %%
df_csv_path = AM_DF_DIR.joinpath(
    str(csv_path.relative_to(UCS_DIR))
    .replace('/readable', '')
    .replace('.rsort-view_am-only', ''))

if not df_csv_path.is_file():
    confirm_dir(df_csv_path.parent)
    adx_amdf.to_csv(df_csv_path)

df_pkl_path = df_csv_path.with_suffix('.pkl.gz')
if not df_pkl_path.is_file():
    adx_amdf.to_pickle(df_csv_path.with_suffix('.pkl.gz'))

# %% [markdown]
# ## 7. Add additional AM via `add_extra_am()`
# Define dictionary containing relevant vocab sizes
# !!! Warning This is a `#HACK`: \
#     Rather than developing a command/code to retrieve the vocab sizes programmatically,
#     I simply copied the values given in the log output of `transform_usc.sh`
#     for each `PAT_DIR`+`UNIT` combination

# %%
VOCABS = {
    # // 'ANYmirror': {'Adj': 83422},
    # //   'NEGmirror': {'Adj': 21562},
    'POSmirror': {'Adj': 178159},
    'RBdirect':  {'Adj': 61860}
}  # ! #HACK
VOCAB = VOCABS[PAT_DIR][UNIT]

print(pd.DataFrame(VOCABS).convert_dtypes().to_markdown(intfmt=','))
VOCAB = None
ex_adx_amdf = add_extra_am(df=adx_amdf,
                           verbose=True,
                           vocab=VOCAB,
                           metrics=['t_score', 'mutual_information']
                           ).convert_dtypes()
# Out:
# |     |   POSmirror |   RBdirect |
# |:----|------------:|-----------:|
# | Adj |     178,159 |     61,860 |
#
# Preview of Extended Measures (rounded)
#
# | key          |   t_score |   mutual_information |   deltaP_min |   deltaP_max |   deltaP_max_abs |   deltaP_product |   unexpected_f |   unexpected_ratio |
# |:-------------|----------:|---------------------:|-------------:|-------------:|-----------------:|-----------------:|---------------:|-------------------:|
# | even~triple  |     10.18 |                 1.37 |         0.00 |         0.89 |             0.89 |             0.00 |         108.18 |               0.96 |
# | very~least   |      8.82 |                 0.91 |         0.00 |         0.85 |             0.85 |             0.00 |          88.63 |               0.88 |
# | early~next   |     12.00 |                 3.86 |         0.84 |         0.84 |             0.84 |             0.70 |         143.98 |               1.00 |
# | even~third   |     18.35 |                 1.33 |         0.01 |         0.80 |             0.80 |             0.01 |         353.47 |               0.95 |
# | now~live     |     20.08 |                 2.34 |         0.08 |         0.79 |             0.79 |             0.06 |         405.14 |               1.00 |
# | too~late     |     39.94 |                 1.05 |         0.02 |         0.78 |             0.78 |             0.01 |       1,751.18 |               0.91 |
# | even~fourth  |     12.62 |                 1.31 |         0.00 |         0.77 |             0.77 |             0.00 |         167.43 |               0.95 |
# | more~akin    |     25.74 |                 0.79 |         0.00 |         0.73 |             0.73 |             0.00 |         791.33 |               0.84 |
# | just~wishful |     11.24 |                 1.60 |         0.00 |         0.72 |             0.72 |             0.00 |         129.62 |               0.97 |
# | long~overdue |     14.27 |                 3.12 |         0.25 |         0.72 |             0.72 |             0.18 |         203.84 |               1.00 |

# %% [markdown]
#  Save extended AM tables to `extra/` subdirectory if not already saved

# %%
df_extra_csv = df_csv_path.parent / 'extra' / \
    df_csv_path.name.replace('.csv', '_extra.csv')
print(df_extra_csv)
if not df_extra_csv.is_file():
    confirm_dir(df_extra_csv.parent)
    ex_adx_amdf.to_csv(df_extra_csv)

df_extra_pkl = df_extra_csv.with_suffix('.pkl.gz')
if not df_extra_pkl.is_file():
    ex_adx_amdf.to_pickle(df_extra_pkl)
# Out:
# /share/compling/projects/sanpi/results/assoc_df/adv_adj/POSmirror/extra/AdvAdj_frq-thrMIN-7.35f_min100x_extra.csv

# %%
ex_adx_full = ex_adx_amdf.copy()
ex_adx_abbr = adjust_assoc_columns(
    ex_adx_amdf[[c for c in ['polarity', 'quant'] + FOCUS if c in ex_adx_amdf.columns]]).sort_values('LRC', ascending=False)
cols = ex_adx_abbr.columns

# %% [markdown]
#  Define lexical items with given lean shown in binary environment evaluation

# %%
pos_prone = {
    'Adj': [
        'unrelated',
        'unable',
        'akin',
        'larger',
        'different',
        'familiar',
        'similar',
        'likely',
        'brief',
        'unaware'
    ],
    'Adv': [
        'slightly',
        'definitely',
        'utterly',
        # LRC top
        'pretty',
        'rather',
        'plain',
        'fairly',
        'somewhat',
        'otherwise',
        'downright',
        'relatively',
        # G2 top
        # 'very',
        # 'even',
        # 'just',
        # dP1 top (and odds ratio disc)
        'plain',
        'maybe'
    ],
    'Bigr': [
        # G2 top
        'completely_different',
        'too_familiar',
        'even_better',
        # dP1 top
        'quite_different',
        'too_real',
        'well_aware',
        # LRC top
        'too_common',
        'entirely_different'
    ]}
neg_prone = {
    'Bigr': [
        # LRC top
        'quite_sure',
        'really_sure',
        'too_early',
        'too_pleased',
        'too_fancy',
        # dP1 top
        'entirely_sure',
        'ever_easy',
        'ever_perfect',
        'particularly_surprising',
        'particularly_new',
        # G2 top
        'too_late',
        'more_important',
        'so_easy',
        'as_good',
        'too_old'
    ],
    'Adv': [
        'yet',
        # LRC top
        'ever',
        'any',
        'longer',
        'necessarily',
        'that',
        # dP1 top
        'before',
        'wise',  # ? How is this used as an adverb?
        'earthly',
        'remotely',
        'exactly',
        # G2 top
        'particularly',
        'too',
        # 'inherently'
    ],
    'Adj': [
        # LRC top
        'early',
        'late',
        'fancy',
        'alone',
        'sure',
        # dP1 top
        'shabby',
        'demoralizing',
        'alone',
        'aggravating',
        'groundbreaking',
        'eventful',
        # G2 top
        'important',
        'frustrating',
        'evident',
        'certain'
    ]
}


def sort_prone_by_f2(prone_list, amdf):
    return amdf.copy().loc[amdf.l2.isin(prone_list), ['f2', 'l2']].drop_duplicates().reset_index(drop=True).set_index('l2').round(1).sort_values(['f2'], ascending=False).index.to_list()


pos_prone[UNIT] = sort_prone_by_f2(pos_prone[UNIT], ex_adx_abbr)
neg_prone[UNIT] = sort_prone_by_f2(neg_prone[UNIT], ex_adx_abbr)
pos_prone[UNIT]
# Out:
# ['different',
#  'familiar',
#  'likely',
#  'similar',
#  'larger',
#  'unable',
#  'akin',
#  'unaware',
#  'unrelated',
#  'brief']

# %% [markdown]
#  Strongest associations for each polarity by metric

# %%
def show_metric_top(amdf: pd.DataFrame,
                    metric: str,
                    k=5,
                    cols=[None]):
    if not any(cols):
        cols = amdf.columns
    return (amdf.nlargest(k, metric)
            .loc[:, [metric] + cols[cols != metric].to_list()]
            .reset_index(drop=True).set_index(['l1', 'l2'])
            )

# %% [markdown]
#  Top consevative log ratio $LRC$ values

# %%
exdf = show_metric_top(ex_adx_abbr, "LRC", k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                         LRC    f  unexp_f  dP1  dP2  dP1_simple  dP2_simple  \
# l1         l2
# early      next       14.18  144   143.98 0.84 0.84        0.84        0.84
# non        existent   11.71  108   107.95 0.71 0.22        0.71        0.22
# long       overdue    11.35  204   203.84 0.72 0.25        0.72        0.25
# lightly    golden     11.30  206   205.89 0.50 0.52        0.50        0.52
# minimally  invasive   10.94  120   119.94 0.33 0.49        0.33        0.49
# critically endangered 10.83  204   203.84 0.54 0.33        0.54        0.33
# mutually   exclusive  10.33  220   219.79 0.42 0.38        0.42        0.38
# grossly    negligent  10.30  111   110.91 0.43 0.21        0.43        0.21
#
#                             G2        N   f1   f2  exp_f
# l1         l2
# early      next       2,641.25  1472077  172  172   0.02
# non        existent   1,571.60  1472077  487  153   0.05
# long       overdue    2,781.93  1472077  808  284   0.16
# lightly    golden     2,947.29  1472077  397  412   0.11
# minimally  invasive   1,700.11  1472077  245  362   0.06
# critically endangered 2,729.85  1472077  609  381   0.16
# mutually   exclusive  2,832.80  1472077  578  526   0.21
# grossly    negligent  1,438.05  1472077  519  258   0.09

# %% [markdown]
#  Top $\Delta P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#               dP1     f  unexp_f   LRC  dP2  dP1_simple  dP2_simple       G2  \
# l1    l2
# even  triple 0.89   113   108.18  6.00 0.00        0.93        0.00   667.10
# very  least  0.85   101    88.63  4.15 0.00        0.97        0.00   403.69
# early next   0.84   144   143.98 14.18 0.84        0.84        0.84 2,641.25
# even  third  0.80   371   353.47  6.12 0.01        0.84        0.01 2,009.33
# now   live   0.79   407   405.14  9.33 0.08        0.79        0.08 4,083.81
# too   late   0.78  1922 1,751.18  5.78 0.02        0.86        0.02 8,132.92
# even  fourth 0.77   176   167.43  5.58 0.00        0.81        0.00   931.08
# more  akin   0.73   945   791.33  4.74 0.00        0.87        0.00 2,899.59
#
#                     N      f1    f2  exp_f
# l1    l2
# even  triple  1472077   58121   122   4.82
# very  least   1472077  175105   104  12.37
# early next    1472077     172   172   0.02
# even  third   1472077   58121   444  17.53
# now   live    1472077    5320   514   1.86
# too   late    1472077  112009  2245 170.82
# even  fourth  1472077   58121   217   8.57
# more  akin    1472077  207924  1088 153.67

# %% [markdown]
#  Top conditional probability $P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                    dP1_simple     f  unexp_f   LRC  dP1  dP2  dP2_simple  \
# l1    l2
# very  least              0.97   101    88.63  4.15 0.85 0.00        0.00
# even  triple             0.93   113   108.18  6.00 0.89 0.00        0.00
# more  akin               0.87   945   791.33  4.74 0.73 0.00        0.00
# too   late               0.86  1922 1,751.18  5.78 0.78 0.02        0.02
# more  galling            0.85   132   110.11  3.65 0.71 0.00        0.00
#       substantial        0.84  1529 1,272.50  4.60 0.70 0.01        0.01
# early next               0.84   144   143.98 14.18 0.84 0.84        0.84
# even  third              0.84   371   353.47  6.12 0.80 0.01        0.01
#
#                         G2        N      f1    f2  exp_f
# l1    l2
# very  least         403.69  1472077  175105   104  12.37
# even  triple        667.10  1472077   58121   122   4.82
# more  akin        2,899.59  1472077  207924  1088 153.67
# too   late        8,132.92  1472077  112009  2245 170.82
# more  galling       393.62  1472077  207924   155  21.89
#       substantial 4,496.77  1472077  207924  1816 256.50
# early next        2,641.25  1472077     172   172   0.02
# even  third       2,009.33  1472077   58121   444  17.53

# %% [markdown]
#  Top $\Delta P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                    dP2    f  unexp_f  LRC  dP1  dP1_simple  dP2_simple  \
# l1      l2
# crystal clear     1.00  137   136.50 8.04 0.03        0.03        1.00
# brand   new       0.97  511   507.07 7.01 0.05        0.05        0.97
# kind    enough    0.95  347   345.01 7.40 0.04        0.04        0.95
# at      best      0.94  137   136.84 9.63 0.08        0.08        0.94
# humanly possible  0.90  285   283.92 7.97 0.06        0.06        0.90
# closely related   0.88  681   679.12 8.65 0.19        0.19        0.88
# wide    open      0.87  218   217.42 8.45 0.06        0.06        0.87
# vitally important 0.85  260   254.07 5.31 0.01        0.01        0.87
#
#                         G2        N   f1     f2  exp_f
# l1      l2
# crystal clear     1,540.35  1472077  137   5395   0.50
# brand   new       4,898.44  1472077  525  11009   3.93
# kind    enough    3,493.58  1472077  364   8041   1.99
# at      best      1,811.78  1472077  145   1647   0.16
# humanly possible  3,052.48  1472077  315   5056   1.08
# closely related   7,766.92  1472077  774   3583   1.88
# wide    open      2,467.40  1472077  250   3419   0.58
# vitally important 1,808.26  1472077  300  29118   5.93

# %% [markdown]
#  Top conditional probability $P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                    dP2_simple    f  unexp_f  LRC  dP1  dP2  dP1_simple  \
# l1      l2
# crystal clear            1.00  137   136.50 8.04 0.03 1.00        0.03
# brand   new              0.97  511   507.07 7.01 0.05 0.97        0.05
# kind    enough           0.95  347   345.01 7.40 0.04 0.95        0.04
# at      best             0.94  137   136.84 9.63 0.08 0.94        0.08
# humanly possible         0.90  285   283.92 7.97 0.06 0.90        0.06
# closely related          0.88  681   679.12 8.65 0.19 0.88        0.19
# wide    open             0.87  218   217.42 8.45 0.06 0.87        0.06
# vitally important        0.87  260   254.07 5.31 0.01 0.85        0.01
#
#                         G2        N   f1     f2  exp_f
# l1      l2
# crystal clear     1,540.35  1472077  137   5395   0.50
# brand   new       4,898.44  1472077  525  11009   3.93
# kind    enough    3,493.58  1472077  364   8041   1.99
# at      best      1,811.78  1472077  145   1647   0.16
# humanly possible  3,052.48  1472077  315   5056   1.08
# closely related   7,766.92  1472077  774   3583   1.88
# wide    open      2,467.40  1472077  250   3419   0.58
# vitally important 1,808.26  1472077  300  29118   5.93

# %% [markdown]
#  Top log-likelihood $G^2$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'G2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                             G2      f   unexp_f  LRC  dP1  dP2  dP1_simple  \
# l1         l2
# as         simple    62,381.27  14875 13,693.58 5.04 0.62 0.19        0.66
# completely different 33,964.46   8327  7,756.53 4.17 0.23 0.32        0.24
# even       better    22,570.11   6091  5,578.80 4.32 0.43 0.10        0.47
#            worse     21,113.74   4867  4,545.14 5.03 0.56 0.08        0.60
# too        familiar  20,013.50   7027  6,061.28 3.80 0.48 0.06        0.55
# n't        right     18,353.73   3800  3,631.80 4.89 0.29 0.18        0.31
# too        easy      18,030.93   7221  6,080.04 3.39 0.41 0.06        0.48
# all        right     17,420.94   2521  2,476.91 6.05 0.20 0.48        0.20
#
#                       dP2_simple        N      f1     f2    exp_f
# l1         l2
# as         simple           0.19  1472077   76987  22590 1,181.42
# completely different        0.34  1472077   24339  34503   570.47
# even       better           0.10  1472077   58121  12973   512.20
#            worse            0.08  1472077   58121   8152   321.86
# too        familiar         0.06  1472077  112009  12692   965.72
# n't        right            0.19  1472077   19938  12419   168.20
# too        easy             0.06  1472077  112009  14995 1,140.96
# all        right            0.48  1472077    5226  12419    44.09

# %%
sig_adx_abbr = ex_adx_abbr.loc[ex_adx_abbr.LRC.abs() > 1, :]
sig_adx_abbr
# Out:
#                       f   unexp_f   LRC   dP1   dP2  dP1_simple  dP2_simple  \
# key
# early~next          144    143.98 14.18  0.84  0.84        0.84        0.84
# non~existent        108    107.95 11.71  0.71  0.22        0.71        0.22
# long~overdue        204    203.84 11.35  0.72  0.25        0.72        0.25
# lightly~golden      206    205.89 11.30  0.50  0.52        0.50        0.52
# minimally~invasive  120    119.94 10.94  0.33  0.49        0.33        0.49
# ...                 ...       ...   ...   ...   ...         ...         ...
# as~different        134 -1,670.45 -3.26 -0.05 -0.02        0.00        0.00
# more~available      105 -1,509.43 -3.51 -0.13 -0.01        0.01        0.00
# more~better         119 -1,713.38 -3.55 -0.13 -0.01        0.01        0.00
# too~different       103 -2,522.30 -4.14 -0.07 -0.02        0.00        0.00
# more~different      138 -4,735.39 -4.80 -0.14 -0.03        0.00        0.00
#
#                           G2        N      f1     f2    exp_f         l1  \
# key
# early~next          2,641.25  1472077     172    172     0.02      early
# non~existent        1,571.60  1472077     487    153     0.05        non
# long~overdue        2,781.93  1472077     808    284     0.16       long
# lightly~golden      2,947.29  1472077     397    412     0.11    lightly
# minimally~invasive  1,700.11  1472077     245    362     0.06  minimally
# ...                      ...      ...     ...    ...      ...        ...
# as~different       -2,766.86  1472077   76987  34503 1,804.45         as
# more~available     -2,678.88  1472077  207924  11430 1,614.43       more
# more~better        -3,043.50  1472077  207924  12973 1,832.38       more
# too~different      -4,634.55  1472077  112009  34503 2,625.30        too
# more~different     -9,334.24  1472077  207924  34503 4,873.39       more
#
#                            l2
# key
# early~next               next
# non~existent         existent
# long~overdue          overdue
# lightly~golden         golden
# minimally~invasive   invasive
# ...                       ...
# as~different        different
# more~available      available
# more~better            better
# too~different       different
# more~different      different
#
# [1015 rows x 14 columns]

# %% [markdown]
#  Positive Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(pos_prone['Adv'])]
# Out:
#                             f  unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# otherwise~objectionable   193   191.68  7.91  0.65  0.03        0.65
# otherwise~unable          348   342.48  6.04  0.28  0.05        0.28
# relatively~inexpensive    136   134.02  5.87  0.25  0.03        0.25
# otherwise~unavailable     165   162.38  5.85  0.28  0.02        0.28
# otherwise~inappropriate   199   195.55  5.75  0.25  0.03        0.26
# definitely~worth          260   255.40  5.52  0.05  0.18        0.06
# relatively~minor          160   156.64  5.28  0.17  0.03        0.17
# plain~weird               236   229.57  4.94  0.12  0.05        0.13
# maybe~more                403   389.76  4.70  0.05  0.15        0.05
# slightly~higher           376   361.50  4.54  0.13  0.05        0.13
# plain~stupid              300   288.16  4.41  0.08  0.06        0.09
# plain~silly               148   142.70  4.39  0.09  0.03        0.10
# definitely~wrong          364   348.78  4.31  0.02  0.24        0.02
# pretty~standard           140   133.18  4.26  0.33  0.01        0.34
# downright~bizarre         105   101.02  4.19  0.08  0.02        0.08
# downright~scary           112   107.66  4.18  0.08  0.02        0.08
# fairly~straightforward    113   108.53  4.16  0.09  0.02        0.10
# relatively~unknown        107   102.83  4.16  0.09  0.02        0.09
# slightly~smaller          135   129.26  4.14  0.12  0.02        0.12
# slightly~lower            201   191.76  4.12  0.11  0.03        0.11
# plain~crazy               131   124.96  3.96  0.07  0.02        0.07
# pretty~decent             126   118.95  3.96  0.28  0.00        0.30
# slightly~larger           226   213.49  3.86  0.09  0.03        0.09
# relatively~new            584   544.15  3.68  0.05  0.10        0.05
# relatively~cheap          106   100.21  3.64  0.06  0.02        0.07
# slightly~less             100    93.12  3.29  0.07  0.01        0.07
# pretty~straightforward    190   170.65  3.02  0.15  0.01        0.16
# pretty~cool               649   571.20  2.98  0.12  0.02        0.14
# plain~wrong               497   443.65  2.98  0.03  0.09        0.03
# downright~dangerous       156   139.45  2.76  0.03  0.03        0.03
# relatively~small          278   245.49  2.75  0.03  0.05        0.03
# pretty~awesome            267   232.81  2.72  0.11  0.01        0.13
# slightly~different       1252 1,075.65  2.70  0.03  0.14        0.04
# pretty~solid              115   100.45  2.51  0.12  0.00        0.13
# fairly~obvious            129   112.24  2.41  0.03  0.02        0.03
# pretty~amazing            348   290.00  2.35  0.08  0.01        0.10
# pretty~good              2087 1,672.45  2.29  0.07  0.07        0.08
# relatively~easy           304   249.73  2.14  0.02  0.05        0.02
# plain~bad                 154   128.76  2.11  0.02  0.03        0.02
# relatively~young          145   121.14  2.09  0.02  0.02        0.02
# fairly~new                235   192.54  2.07  0.02  0.03        0.02
# slightly~more             214   175.28  2.06  0.02  0.02        0.03
# pretty~tough              125   103.46  2.05  0.08  0.00        0.10
# fairly~easy               287   229.16  1.96  0.02  0.04        0.02
# pretty~sure               299   232.31  1.86  0.06  0.01        0.07
# slightly~better           272   205.69  1.67  0.02  0.03        0.02
# maybe~better              108    85.32  1.65  0.01  0.03        0.01
# fairly~similar            117    90.64  1.57  0.01  0.02        0.02
# pretty~great              274   198.24  1.52  0.04  0.01        0.06
# pretty~funny              281   201.51  1.49  0.04  0.01        0.06
# pretty~close              604   413.30  1.45  0.04  0.02        0.05
# relatively~simple         259   177.24  1.28  0.01  0.03        0.01
# relatively~close          141    99.70  1.24  0.01  0.02        0.01
# somewhat~likely           128    91.15  1.24  0.01  0.02        0.01
# pretty~excited            419   271.65  1.23  0.03  0.01        0.05
# pretty~tired              158   109.37  1.23  0.04  0.00        0.05
# pretty~obvious            219   146.41  1.19  0.03  0.01        0.05
# pretty~bad                327   204.13  1.09  0.03  0.01        0.04
# rather~special            207   131.48  1.02  0.01  0.02        0.02
# pretty~important          136  -350.57 -1.30 -0.01 -0.01        0.00
#
#                          dP2_simple       G2        N     f1     f2  exp_f  \
# key
# otherwise~objectionable        0.03 1,711.43  1472077   6562    297   1.32
# otherwise~unable               0.05 2,322.42  1472077   6562   1239   5.52
# relatively~inexpensive         0.03   922.45  1472077   5328    546   1.98
# otherwise~unavailable          0.03 1,096.19  1472077   6562    588   2.62
# otherwise~inappropriate        0.03 1,283.69  1472077   6562    773   3.45
# definitely~worth               0.18 1,650.30  1472077   1442   4691   4.60
# relatively~minor               0.03   955.54  1472077   5328    929   3.36
# plain~weird                    0.05 1,281.84  1472077   5053   1872   6.43
# maybe~more                     0.16 2,056.68  1472077   2573   7575  13.24
# slightly~higher                0.05 1,791.27  1472077   7524   2837  14.50
# plain~stupid                   0.06 1,404.65  1472077   5053   3450  11.84
# plain~silly                    0.03   717.70  1472077   5053   1545   5.30
# definitely~wrong               0.25 1,714.48  1472077   1442  15542  15.22
# pretty~standard                0.01   630.68  1472077  24599    408   6.82
# downright~bizarre              0.02   496.02  1472077   4730   1238   3.98
# downright~scary                0.02   524.26  1472077   4730   1350   4.34
# fairly~straightforward         0.02   525.73  1472077   5678   1158   4.47
# relatively~unknown             0.02   500.09  1472077   5328   1153   4.17
# slightly~smaller               0.02   611.91  1472077   7524   1123   5.74
# slightly~lower                 0.03   880.68  1472077   7524   1808   9.24
# plain~crazy                    0.03   568.55  1472077   5053   1759   6.04
# pretty~decent                  0.01   527.13  1472077  24599    422   7.05
# slightly~larger                0.03   906.48  1472077   7524   2448  12.51
# relatively~new                 0.11 2,133.31  1472077   5328  11009  39.85
# relatively~cheap               0.02   424.24  1472077   5328   1600   5.79
# slightly~less                  0.01   356.88  1472077   7524   1346   6.88
# pretty~straightforward         0.01   554.90  1472077  24599   1158  19.35
# pretty~cool                    0.03 1,699.05  1472077  24599   4656  77.80
# plain~wrong                    0.10 1,384.60  1472077   5053  15542  53.35
# downright~dangerous            0.03   428.99  1472077   4730   5152  16.55
# relatively~small               0.05   720.70  1472077   5328   8981  32.51
# pretty~awesome                 0.01   662.22  1472077  24599   2046  34.19
# slightly~different             0.17 2,957.25  1472077   7524  34503 176.35
# pretty~solid                   0.00   287.21  1472077  24599    871  14.55
# fairly~obvious                 0.02   307.30  1472077   5678   4344  16.76
# pretty~amazing                 0.01   695.92  1472077  24599   3471  58.00
# pretty~good                    0.08 3,639.24  1472077  24599  24808 414.55
# relatively~easy                0.06   564.39  1472077   5328  14995  54.27
# plain~bad                      0.03   305.12  1472077   5053   7353  25.24
# relatively~young               0.03   286.05  1472077   5328   6593  23.86
# fairly~new                     0.04   429.15  1472077   5678  11009  42.46
# slightly~more                  0.03   389.45  1472077   7524   7575  38.72
# pretty~tough                   0.01   241.81  1472077  24599   1289  21.54
# fairly~easy                    0.05   474.18  1472077   5678  14995  57.84
# pretty~sure                    0.01   448.88  1472077  24599   3991  66.69
# slightly~better                0.04   365.53  1472077   7524  12973  66.31
# maybe~better                   0.04   169.95  1472077   2573  12973  22.68
# fairly~similar                 0.02   170.11  1472077   5678   6835  26.36
# pretty~great                   0.01   318.56  1472077  24599   4534  75.76
# pretty~funny                   0.01   317.12  1472077  24599   4757  79.49
# pretty~close                   0.02   588.64  1472077  24599  11412 190.70
# relatively~simple              0.05   250.26  1472077   5328  22590  81.76
# relatively~close               0.03   149.62  1472077   5328  11412  41.30
# somewhat~likely                0.03   139.05  1472077   4441  12215  36.85
# pretty~excited                 0.02   344.13  1472077  24599   8818 147.35
# pretty~tired                   0.01   158.36  1472077  24599   2910  48.63
# pretty~obvious                 0.01   196.81  1472077  24599   4344  72.59
# pretty~bad                     0.01   239.45  1472077  24599   7353 122.87
# rather~special                 0.03   157.93  1472077   8259  13460  75.52
# pretty~important               0.01  -363.85  1472077  24599  29118 486.57
#
#                                  l1               l2
# key
# otherwise~objectionable   otherwise    objectionable
# otherwise~unable          otherwise           unable
# relatively~inexpensive   relatively      inexpensive
# otherwise~unavailable     otherwise      unavailable
# otherwise~inappropriate   otherwise    inappropriate
# definitely~worth         definitely            worth
# relatively~minor         relatively            minor
# plain~weird                   plain            weird
# maybe~more                    maybe             more
# slightly~higher            slightly           higher
# plain~stupid                  plain           stupid
# plain~silly                   plain            silly
# definitely~wrong         definitely            wrong
# pretty~standard              pretty         standard
# downright~bizarre         downright          bizarre
# downright~scary           downright            scary
# fairly~straightforward       fairly  straightforward
# relatively~unknown       relatively          unknown
# slightly~smaller           slightly          smaller
# slightly~lower             slightly            lower
# plain~crazy                   plain            crazy
# pretty~decent                pretty           decent
# slightly~larger            slightly           larger
# relatively~new           relatively              new
# relatively~cheap         relatively            cheap
# slightly~less              slightly             less
# pretty~straightforward       pretty  straightforward
# pretty~cool                  pretty             cool
# plain~wrong                   plain            wrong
# downright~dangerous       downright        dangerous
# relatively~small         relatively            small
# pretty~awesome               pretty          awesome
# slightly~different         slightly        different
# pretty~solid                 pretty            solid
# fairly~obvious               fairly          obvious
# pretty~amazing               pretty          amazing
# pretty~good                  pretty             good
# relatively~easy          relatively             easy
# plain~bad                     plain              bad
# relatively~young         relatively            young
# fairly~new                   fairly              new
# slightly~more              slightly             more
# pretty~tough                 pretty            tough
# fairly~easy                  fairly             easy
# pretty~sure                  pretty             sure
# slightly~better            slightly           better
# maybe~better                  maybe           better
# fairly~similar               fairly          similar
# pretty~great                 pretty            great
# pretty~funny                 pretty            funny
# pretty~close                 pretty            close
# relatively~simple        relatively           simple
# relatively~close         relatively            close
# somewhat~likely            somewhat           likely
# pretty~excited               pretty          excited
# pretty~tired                 pretty            tired
# pretty~obvious               pretty          obvious
# pretty~bad                   pretty              bad
# rather~special               rather          special
# pretty~important             pretty        important

# %% [markdown]
#  Negative Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(neg_prone['Adv'])]
# Out:
#                     f   unexp_f   LRC   dP1   dP2  dP1_simple  dP2_simple  \
# key
# too~late         1922  1,751.18  5.78  0.78  0.02        0.86        0.02
# too~much         3854  3,445.33  4.75  0.64  0.03        0.72        0.03
# too~common       4927  4,369.34  4.48  0.60  0.04        0.67        0.04
# too~familiar     7027  6,061.28  3.80  0.48  0.06        0.55        0.06
# too~embarrassed   241    212.16  3.71  0.56  0.00        0.64        0.00
# ...               ...       ...   ...   ...   ...         ...         ...
# too~excited       168   -502.95 -1.58 -0.06 -0.00        0.02        0.00
# too~simple        299 -1,419.85 -2.24 -0.06 -0.01        0.01        0.00
# too~new           112   -725.66 -2.38 -0.07 -0.01        0.01        0.00
# too~important     183 -2,032.56 -3.22 -0.07 -0.02        0.01        0.00
# too~different     103 -2,522.30 -4.14 -0.07 -0.02        0.00        0.00
#
#                        G2        N      f1     f2    exp_f   l1           l2
# key
# too~late         8,132.92  1472077  112009   2245   170.82  too         late
# too~much        13,816.86  1472077  112009   5371   408.67  too         much
# too~common      16,678.14  1472077  112009   7329   557.66  too       common
# too~familiar    20,013.50  1472077  112009  12692   965.72  too     familiar
# too~embarrassed    766.78  1472077  112009    379    28.84  too  embarrassed
# ...                   ...      ...     ...    ...      ...  ...          ...
# too~excited       -573.52  1472077  112009   8818   670.95  too      excited
# too~simple      -1,908.00  1472077  112009  22590 1,718.85  too       simple
# too~new         -1,056.31  1472077  112009  11009   837.66  too          new
# too~important   -3,342.74  1472077  112009  29118 2,215.56  too    important
# too~different   -4,634.55  1472077  112009  34503 2,625.30  too    different
#
# [85 rows x 14 columns]

# %% [markdown]
#  Positive Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(pos_prone['Adj'])]
# Out:
#                             f   unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# much~larger              1352  1,315.89  6.10  0.54  0.06        0.55
# otherwise~unable          348    342.48  6.04  0.28  0.05        0.28
# physically~unable         106    104.51  5.64  0.08  0.06        0.09
# intimately~familiar       129    126.76  5.45  0.01  0.49        0.01
# eerily~similar            106    104.15  5.31  0.02  0.26        0.02
# completely~unrelated      424    408.99  5.27  0.45  0.02        0.47
# strikingly~similar        101     99.14  5.22  0.01  0.25        0.01
# totally~unrelated         199    192.93  4.87  0.21  0.02        0.22
# substantially~similar     113    110.11  4.75  0.02  0.18        0.02
# more~akin                 945    791.33  4.74  0.73  0.00        0.87
# radically~different       509    489.71  4.56  0.01  0.60        0.01
# altogether~different      839    804.71  4.50  0.02  0.55        0.02
# vastly~different          308    295.02  4.33  0.01  0.53        0.01
# remarkably~similar        122    117.56  4.25  0.02  0.12        0.02
# entirely~different       3300  3,114.79  4.20  0.09  0.40        0.10
# completely~different     8327  7,756.53  4.17  0.23  0.32        0.24
# simply~unable             146    139.52  4.10  0.11  0.02        0.12
# slightly~larger           226    213.49  3.86  0.09  0.03        0.09
# too~familiar             7027  6,061.28  3.80  0.48  0.06        0.55
# drastically~different     170    160.51  3.79  0.00  0.40        0.00
# dramatically~different    136    128.05  3.67  0.00  0.38        0.00
# far~larger                142    133.14  3.53  0.05  0.03        0.06
# more~likely              7819  6,093.69  3.31  0.50  0.03        0.64
# completely~unaware        187    171.00  3.30  0.18  0.01        0.19
# totally~different        2267  2,036.53  3.26  0.06  0.21        0.07
# too~brief                 324    277.66  3.26  0.46  0.00        0.53
# already~familiar          400    363.12  3.17  0.03  0.09        0.03
# probably~familiar         194    176.46  3.04  0.01  0.09        0.02
# vaguely~familiar          111    101.92  3.04  0.01  0.10        0.01
# most~likely              1008    876.07  2.83  0.07  0.06        0.08
# very~similar             3420  2,606.97  2.73  0.38  0.02        0.50
# slightly~different       1252  1,075.65  2.70  0.03  0.14        0.04
# less~likely              1141    967.29  2.64  0.08  0.05        0.09
# fundamentally~different   261    217.57  2.22  0.01  0.12        0.01
# wildly~different          141    116.62  2.03  0.00  0.11        0.00
# quite~different          3156  2,351.34  1.96  0.07  0.07        0.09
# significantly~different   153    120.75  1.75  0.00  0.09        0.00
# fairly~similar            117     90.64  1.57  0.01  0.02        0.02
# quite~similar             463    303.60  1.29  0.04  0.01        0.07
# somewhat~likely           128     91.15  1.24  0.01  0.02        0.01
# even~larger               274    177.35  1.20  0.07  0.00        0.11
# as~likely                 231   -407.82 -1.09 -0.03 -0.01        0.02
# too~likely                289   -640.43 -1.38 -0.05 -0.01        0.02
# more~familiar             568 -1,224.69 -1.53 -0.10 -0.01        0.04
# very~likely               427 -1,025.99 -1.58 -0.08 -0.01        0.03
# more~similar              191   -774.41 -2.04 -0.11 -0.00        0.03
# as~different              134 -1,670.45 -3.26 -0.05 -0.02        0.00
# too~different             103 -2,522.30 -4.14 -0.07 -0.02        0.00
# more~different            138 -4,735.39 -4.80 -0.14 -0.03        0.00
#
#                          dP2_simple        G2        N      f1     f2  \
# key
# much~larger                    0.06  8,150.08  1472077   21712   2448
# otherwise~unable               0.05  2,322.42  1472077    6562   1239
# physically~unable              0.06    710.27  1472077    1772   1239
# intimately~familiar            0.50    869.52  1472077     260  12692
# eerily~similar                 0.27    681.31  1472077     399   6835
# completely~unrelated           0.02  2,247.17  1472077   24339    908
# strikingly~similar             0.25    637.40  1472077     400   6835
# totally~unrelated              0.02  1,051.86  1472077    9833    908
# substantially~similar          0.18    630.74  1472077     623   6835
# more~akin                      0.00  2,899.59  1472077  207924   1088
# radically~different            0.62  2,748.72  1472077     823  34503
# altogether~different           0.57  4,350.72  1472077    1463  34503
# vastly~different               0.56  1,565.29  1472077     554  34503
# remarkably~similar             0.13    590.35  1472077     957   6835
# entirely~different             0.42 14,550.09  1472077    7902  34503
# completely~different           0.34 33,964.46  1472077   24339  34503
# simply~unable                  0.02    649.64  1472077    7695   1239
# slightly~larger                0.03    906.48  1472077    7524   2448
# too~familiar                   0.06 20,013.50  1472077  112009  12692
# drastically~different          0.42    737.09  1472077     405  34503
# dramatically~different         0.40    574.41  1472077     339  34503
# far~larger                     0.03    532.28  1472077    5330   2448
# more~likely                    0.04 16,196.42  1472077  207924  12215
# completely~unaware             0.01    611.35  1472077   24339    968
# totally~different              0.23  6,884.65  1472077    9833  34503
# too~brief                      0.00    873.25  1472077  112009    609
# already~familiar               0.09  1,223.52  1472077    4277  12692
# probably~familiar              0.10    598.06  1472077    2034  12692
# vaguely~familiar               0.11    363.07  1472077    1053  12692
# most~likely                    0.06  2,462.59  1472077   15899  12215
# very~similar                   0.02  5,996.76  1472077  175105   6835
# slightly~different             0.17  2,957.25  1472077    7524  34503
# less~likely                    0.05  2,487.02  1472077   20935  12215
# fundamentally~different        0.14    529.67  1472077    1853  34503
# wildly~different               0.14    276.05  1472077    1040  34503
# quite~different                0.09  4,264.42  1472077   34331  34503
# significantly~different        0.11    246.53  1472077    1376  34503
# fairly~similar                 0.02    170.11  1472077    5678   6835
# quite~similar                  0.01    396.99  1472077   34331   6835
# somewhat~likely                0.03    139.05  1472077    4441  12215
# even~larger                    0.00    230.61  1472077   58121   2448
# as~likely                      0.00   -362.19  1472077   76987  12215
# too~likely                     0.00   -645.33  1472077  112009  12215
# more~familiar                  0.00 -1,284.90  1472077  207924  12692
# very~likely                    0.00 -1,107.88  1472077  175105  12215
# more~similar                   0.00 -1,031.20  1472077  207924   6835
# as~different                   0.00 -2,766.86  1472077   76987  34503
# too~different                  0.00 -4,634.55  1472077  112009  34503
# more~different                 0.00 -9,334.24  1472077  207924  34503
#
#                            exp_f             l1         l2
# key
# much~larger                36.11           much     larger
# otherwise~unable            5.52      otherwise     unable
# physically~unable           1.49     physically     unable
# intimately~familiar         2.24     intimately   familiar
# eerily~similar              1.85         eerily    similar
# completely~unrelated       15.01     completely  unrelated
# strikingly~similar          1.86     strikingly    similar
# totally~unrelated           6.07        totally  unrelated
# substantially~similar       2.89  substantially    similar
# more~akin                 153.67           more       akin
# radically~different        19.29      radically  different
# altogether~different       34.29     altogether  different
# vastly~different           12.98         vastly  different
# remarkably~similar          4.44     remarkably    similar
# entirely~different        185.21       entirely  different
# completely~different      570.47     completely  different
# simply~unable               6.48         simply     unable
# slightly~larger            12.51       slightly     larger
# too~familiar              965.72            too   familiar
# drastically~different       9.49    drastically  different
# dramatically~different      7.95   dramatically  different
# far~larger                  8.86            far     larger
# more~likely             1,725.31           more     likely
# completely~unaware         16.00     completely    unaware
# totally~different         230.47        totally  different
# too~brief                  46.34            too      brief
# already~familiar           36.88        already   familiar
# probably~familiar          17.54       probably   familiar
# vaguely~familiar            9.08        vaguely   familiar
# most~likely               131.93           most     likely
# very~similar              813.03           very    similar
# slightly~different        176.35       slightly  different
# less~likely               173.71           less     likely
# fundamentally~different    43.43  fundamentally  different
# wildly~different           24.38         wildly  different
# quite~different           804.66          quite  different
# significantly~different    32.25  significantly  different
# fairly~similar             26.36         fairly    similar
# quite~similar             159.40          quite    similar
# somewhat~likely            36.85       somewhat     likely
# even~larger                96.65           even     larger
# as~likely                 638.82             as     likely
# too~likely                929.43            too     likely
# more~familiar           1,792.69           more   familiar
# very~likely             1,452.99           very     likely
# more~similar              965.41           more    similar
# as~different            1,804.45             as  different
# too~different           2,625.30            too  different
# more~different          4,873.39           more  different

# %% [markdown]
#  Negative Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(neg_prone['Adj'])]
# Out:
#                           f   unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# too~late               1922  1,751.18  5.78  0.78  0.02        0.86
# vitally~important       260    254.07  5.31  0.01  0.85        0.01
# not~sure               2127  1,973.53  4.63  0.50  0.04        0.53
# n't~sure                882    827.95  4.12  0.21  0.04        0.22
# critically~important    202    189.95  3.70  0.01  0.31        0.01
# too~early               235    202.36  3.25  0.47  0.00        0.55
# too~evident             409    331.47  2.61  0.33  0.00        0.40
# equally~important       941    797.89  2.56  0.03  0.11        0.03
# pretty~sure             299    232.31  1.86  0.06  0.01        0.07
# more~important        10996  6,883.22  1.81  0.24  0.04        0.38
# most~important          943    628.51  1.41  0.02  0.04        0.03
# more~frustrating        416    232.80  1.13  0.18  0.00        0.32
# pretty~important        136   -350.57 -1.30 -0.01 -0.01        0.00
# not~important           307   -812.70 -1.54 -0.03 -0.01        0.01
# quite~important         132   -547.07 -1.82 -0.02 -0.02        0.00
# too~important           183 -2,032.56 -3.22 -0.07 -0.02        0.01
#
#                       dP2_simple        G2        N      f1     f2    exp_f  \
# key
# too~late                    0.02  8,132.92  1472077  112009   2245   170.82
# vitally~important           0.87  1,808.26  1472077     300  29118     5.93
# not~sure                    0.04  8,564.19  1472077   56607   3991   153.47
# n't~sure                    0.04  3,492.78  1472077   19938   3991    54.05
# critically~important        0.33    828.57  1472077     609  29118    12.05
# too~early                   0.00    650.96  1472077  112009    429    32.64
# too~evident                 0.00    831.93  1472077  112009   1019    77.53
# equally~important           0.13  2,064.61  1472077    7235  29118   143.11
# pretty~sure                 0.01    448.88  1472077   24599   3991    66.69
# more~important              0.05 10,231.89  1472077  207924  29118 4,112.78
# most~important              0.06    853.83  1472077   15899  29118   314.49
# more~frustrating            0.00    269.50  1472077  207924   1297   183.20
# pretty~important            0.01   -363.85  1472077   24599  29118   486.57
# not~important               0.01   -866.59  1472077   56607  29118 1,119.70
# quite~important             0.00   -681.25  1472077   34331  29118   679.07
# too~important               0.00 -3,342.74  1472077  112009  29118 2,215.56
#
#                               l1           l2
# key
# too~late                     too         late
# vitally~important        vitally    important
# not~sure                     not         sure
# n't~sure                     n't         sure
# critically~important  critically    important
# too~early                    too        early
# too~evident                  too      evident
# equally~important        equally    important
# pretty~sure               pretty         sure
# more~important              more    important
# most~important              most    important
# more~frustrating            more  frustrating
# pretty~important          pretty    important
# not~important                not    important
# quite~important            quite    important
# too~important                too    important
