# %%
import pandas as pd

from source.utils import FREQ_DIR, RESULT_DIR, UCS_DIR, confirm_dir
from source.utils.associate import (BINARY_ASSOC_ARGS, add_extra_am,
                                    associate_ucs, confirm_basic_ucs)
from source.utils.associate import convert_ucs_to_csv as ucs2csv
from source.utils.associate import get_associations_csv as init_am, AM_DF_DIR
from source.utils.associate import manipulate_ucs, seek_readable_ucs, adjust_assoc_columns
pd.set_option('display.float_format', '{:,.2f}'.format)

# %% [markdown]
#  set parameters

# %%
UNIT = 'Adj'
# PAT_DIR = 'POSmirror'
# PAT_DIR = 'NEGmirror'
PAT_DIR = 'RBdirect'
# PAT_DIR = 'ANYmirror'
# FRQ_FLOOR = 3
# FRQ_FLOOR = 10
# FRQ_FLOOR = 20
# FRQ_FLOOR = 50
FRQ_FLOOR = 100  # BUG 100 will be used regardless, so set it to this to at least keep the naming accurate
ADVADJ_TSV = FREQ_DIR.joinpath(
    f'{PAT_DIR}/ucs_format/Adv{UNIT}_frq-thrMIN-7.35f.tsv')
FOCUS = ['f', 'unexpected_f',
         'conservative_log_ratio',
         'am_p1_given2', 'am_p2_given1',
         'am_p1_given2_simple', 'am_p2_given1_simple',
         'am_log_likelihood',
         #  'mutual_information', 'am_odds_ratio_disc', 't_score',
         'N', 'f1', 'f2', 'E11',
         'l1', 'l2']

# %%
def invert_set_dict(d: dict):
    return {v: k for k in d for v in d[k]}

# %% [markdown]
#  1. Run `seek_readable_ucs()` to generate consistent output path

# %%
readable = seek_readable_ucs(min_freq=FRQ_FLOOR,
                             ucs_subdir='adv_adj',
                             contained_counts_path=ADVADJ_TSV)
print(readable.relative_to(RESULT_DIR))
# Out:
#     > seeking `adv_adj/RBdirect/readable/AdvAdj_frq-thrMIN-7.35f_min100x*` frequency data and initial associations...
# ucs/adv_adj/RBdirect/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv

# %% [markdown]
#  Snippet of starting frequency data (`ADVADJ_TSV`)

# %%
! head -5 {ADVADJ_TSV} | column -t
# Out:
# 44885  as     good
# 30349  very   good
# 27740  as     bad
# 26584  so     sure
# 26156  quite  sure

# %% [markdown]
#  2. Run `confirm_basic_ucs()` (if needed)

# %%
if not readable.is_file():
    basic_ucs_path = readable.parent.parent.joinpath(
        readable.name.replace('.rsort-view_am-only.txt', '.ds.gz'))
    print(
        f'Creating initial UCS table: `{basic_ucs_path.relative_to(RESULT_DIR)}')

    basic_ucs_path = confirm_basic_ucs(
        basic_ucs_path,
        freq_floor=FRQ_FLOOR,
        contained_counts_path=ADVADJ_TSV)

# %% [markdown]
#  Excerpt of initial UCS table

# %%
init_readable = UCS_DIR.joinpath(
    f'adv_adj/{PAT_DIR}/readable'
).joinpath(f'{ADVADJ_TSV.name.replace(".tsv","")}_min{FRQ_FLOOR}x.init.txt')
! head -7 {init_readable}
# Out:
#              l1  l2                    f      f2      f1        N
# ---------------  ----------------  -----  ------  ------  -------
#              as  good              44889  132448  535450  3226225
#              so  good              18002  132448  346575  3226225
#             too  good               3623  132448  311944  3226225
#            very  good              30349  132448  193561  3226225
#            that  good              10655  132448  165411  3226225

# %% [markdown]
#  3. Run `associate_ucs()` (if needed)

# %%
if not readable.is_file():
    associate_ucs(basic_ucs_path)

transform_ucs_log = f'/share/compling/projects/sanpi/logs/associate/ucs//ucs-{PAT_DIR}_Adv{UNIT}_frq-thrMIN-7-35f_min{FRQ_FLOOR}x*.log'
! head -15 `ls -t1 {transform_ucs_log} | head -1`
! echo '...'
! tail -2 `ls -t1 {transform_ucs_log} | head -1`
# Out:
# # Manipulating AdvAdj_frq-thrMIN-7-35f_min100x ucs table
# path to this script: /share/compling/projects/sanpi/script/transform_ucs.sh
# Thu May 30 14:42:52 EDT 2024
# (TMP: /share/compling/projects/sanpi/results/ucs/adv_adj/RBdirect/tmp/tmp_RBdirect-20240530-144252.AdvAdj_frq-thrMIN-7-35f_min100x)
# ## Initial Contingency Info
#
# DATA SET FILE:  /share/compling/projects/sanpi/results/ucs/adv_adj/RBdirect/AdvAdj_frq-thrMIN-7.35f_min100x.ds.gz
#
# # Frequency signatures computed by the ucs-make-tables tool for relational cooccurrences.
# # Sample size:  N = 3226225 tokens,  V = 182629 pair types.
# # A frequency threshold of f >= 100 was applied, leaving V = 3622 pair types.
#
# ##:: size = 3622
# ##:: threshold = 100
#
# ...
# Loading data set /share/compling/projects/sanpi/results/ucs/adv_adj/RBdirect/AdvAdj_frq-thrMIN-7.35f_min100x.rsort.gz ... 3622 rows
# Script finished at Thu May 30 14:43:05 EDT 2024

# %% [markdown]
#  4. Run `ucs_to_csv()` to convert `ucs/[PAT_DIR]/readable/*.txt` to format that `pandas` can parse as a dataframe

# %%
! head -5 {readable}
csv_path = ucs2csv(readable)
print(f'CSV: `{csv_path.relative_to(RESULT_DIR)}`')
# Out:
# l1,l2,f,E11,am_log_likelihood,am_odds_ratio_disc,am_p1_given2,am_p2_given1,am_p1_given2_simple,am_p2_given1_simple,f1,f2,N
# legally,binding,637,0.7166022,8527.099448,4.197714768,0.9304361497,0.1884469551,0.9312865497,0.1884615385,3380,684,3226225
# too,late,25854,2543.3362447,118329.968464,2.766802345,0.8934870036,0.0827258485,0.9828923358,0.0828802606,311944,26304,3226225
# mutually,exclusive,5509,11.4188812,73788.677919,4.772885829,0.8881280010,0.9272258791,0.8882618510,0.9274410774,5940,6202,3226225
# too,early,7193,713.0894466,32089.573205,2.576235904,0.8806450530,0.0229961748,0.9753220339,0.0230586259,311944,7375,3226225
# UCS table text converted & saved as /share/compling/projects/sanpi/results/ucs/adv_adj/RBdirect/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv
# CSV: `ucs/adv_adj/RBdirect/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv`

# %% [markdown]
# ##

# %%
adx_amdf = pd.read_csv(csv_path).convert_dtypes()
adx_amdf
# Out:
#             l1         l2      f       E11  am_log_likelihood  \
# 0      legally    binding    637      0.72           8,527.10
# 1          too       late  25854  2,543.34         118,329.97
# 2     mutually  exclusive   5509     11.42          73,788.68
# 3          too      early   7193    713.09          32,089.57
# 4          too     shabby   5399    535.18          24,062.20
# ...        ...        ...    ...       ...                ...
# 3617        as       able    202  2,364.38          -3,713.05
# 3618        as    distant    111  1,358.28          -2,157.25
# 3619        as  different    616  7,595.19         -12,178.64
# 3620        as  available    320  9,316.28         -17,646.14
# 3621        as       sure    714 21,380.66         -41,207.08
#
#       am_odds_ratio_disc  am_p1_given2  am_p2_given1  am_p1_given2_simple  \
# 0                   4.20          0.93          0.19                 0.93
# 1                   2.77          0.89          0.08                 0.98
# 2                   4.77          0.89          0.93                 0.89
# 3                   2.58          0.88          0.02                 0.98
# 4                   2.58          0.88          0.02                 0.98
# ...                  ...           ...           ...                  ...
# 3617               -1.14         -0.15         -0.00                 0.01
# 3618               -1.16         -0.15         -0.00                 0.01
# 3619               -1.17         -0.15         -0.02                 0.01
# 3620               -1.55         -0.16         -0.02                 0.01
# 3621               -1.57         -0.17         -0.05                 0.01
#
#       am_p2_given1_simple      f1      f2        N
# 0                    0.19    3380     684  3226225
# 1                    0.08  311944   26304  3226225
# 2                    0.93    5940    6202  3226225
# 3                    0.02  311944    7375  3226225
# 4                    0.02  311944    5535  3226225
# ...                   ...     ...     ...      ...
# 3617                 0.00  535450   14246  3226225
# 3618                 0.00  535450    8184  3226225
# 3619                 0.00  535450   45763  3226225
# 3620                 0.00  535450   56133  3226225
# 3621                 0.00  535450  128824  3226225
#
# [3622 rows x 13 columns]

# %%
adx_amdf['key'] = (adx_amdf.l1 + '~' +
                   adx_amdf.l2).astype('string')
adx_amdf = adx_amdf.set_index('key')
adx_amdf
# Out:
#                           l1         l2      f       E11  am_log_likelihood  \
# key
# legally~binding      legally    binding    637      0.72           8,527.10
# too~late                 too       late  25854  2,543.34         118,329.97
# mutually~exclusive  mutually  exclusive   5509     11.42          73,788.68
# too~early                too      early   7193    713.09          32,089.57
# too~shabby               too     shabby   5399    535.18          24,062.20
# ...                      ...        ...    ...       ...                ...
# as~able                   as       able    202  2,364.38          -3,713.05
# as~distant                as    distant    111  1,358.28          -2,157.25
# as~different              as  different    616  7,595.19         -12,178.64
# as~available              as  available    320  9,316.28         -17,646.14
# as~sure                   as       sure    714 21,380.66         -41,207.08
#
#                     am_odds_ratio_disc  am_p1_given2  am_p2_given1  \
# key
# legally~binding                   4.20          0.93          0.19
# too~late                          2.77          0.89          0.08
# mutually~exclusive                4.77          0.89          0.93
# too~early                         2.58          0.88          0.02
# too~shabby                        2.58          0.88          0.02
# ...                                ...           ...           ...
# as~able                          -1.14         -0.15         -0.00
# as~distant                       -1.16         -0.15         -0.00
# as~different                     -1.17         -0.15         -0.02
# as~available                     -1.55         -0.16         -0.02
# as~sure                          -1.57         -0.17         -0.05
#
#                     am_p1_given2_simple  am_p2_given1_simple      f1      f2  \
# key
# legally~binding                    0.93                 0.19    3380     684
# too~late                           0.98                 0.08  311944   26304
# mutually~exclusive                 0.89                 0.93    5940    6202
# too~early                          0.98                 0.02  311944    7375
# too~shabby                         0.98                 0.02  311944    5535
# ...                                 ...                  ...     ...     ...
# as~able                            0.01                 0.00  535450   14246
# as~distant                         0.01                 0.00  535450    8184
# as~different                       0.01                 0.00  535450   45763
# as~available                       0.01                 0.00  535450   56133
# as~sure                            0.01                 0.00  535450  128824
#
#                           N
# key
# legally~binding     3226225
# too~late            3226225
# mutually~exclusive  3226225
# too~early           3226225
# too~shabby          3226225
# ...                     ...
# as~able             3226225
# as~distant          3226225
# as~different        3226225
# as~available        3226225
# as~sure             3226225
#
# [3622 rows x 13 columns]

# %% [markdown]
#  6. Save to `./results/assoc_df/`

# %%
df_csv_path = AM_DF_DIR.joinpath(
    str(csv_path.relative_to(UCS_DIR))
    .replace('/readable', '')
    .replace('.rsort-view_am-only', ''))

if not df_csv_path.is_file():
    confirm_dir(df_csv_path.parent)
    adx_amdf.to_csv(df_csv_path)

df_pkl_path = df_csv_path.with_suffix('.pkl.gz')
if not df_pkl_path.is_file():
    adx_amdf.to_pickle(df_csv_path.with_suffix('.pkl.gz'))

# %% [markdown]
#  7. Add additional AM via `add_extra_am()`
#  Define dictionary containing relevant vocab sizes
#  !!! Warning This is a `#HACK`: \
#      Rather than developing a command/code to retrieve the vocab sizes programmatically,
#      I simply copied the values given in the log output of `transform_usc.sh`
#      for each `PAT_DIR`+`UNIT` combination

# %%
VOCABS = {
    # // 'ANYmirror': {'Adj': 83422},
    'NEGmirror': {'Adj': 40004},
    'POSmirror': {'Adj': 178159},
    'RBdirect':  {'Adj': 61860}
}  # ! #HACK
VOCAB = VOCABS[PAT_DIR][UNIT]

print(pd.DataFrame(VOCABS).convert_dtypes().to_markdown(intfmt=','))
VOCAB = None
ex_adx_amdf = add_extra_am(df=adx_amdf,
                           verbose=True,
                           vocab=VOCAB,
                           metrics=['t_score', 'mutual_information']
                           ).convert_dtypes()
# Out:
# |     |   NEGmirror |   POSmirror |   RBdirect |
# |:----|------------:|------------:|-----------:|
# | Adj |      40,004 |     178,159 |     61,860 |
#
# Preview of Extended Measures (rounded)
#
# | key                |   t_score |   mutual_information |   deltaP_min |   deltaP_max |   deltaP_max_abs |   deltaP_product |   unexpected_f |   unexpected_ratio |
# |:-------------------|----------:|---------------------:|-------------:|-------------:|-----------------:|-----------------:|---------------:|-------------------:|
# | legally~binding    |     25.21 |                 2.95 |         0.19 |         0.93 |             0.93 |             0.18 |         636.28 |               1.00 |
# | too~late           |    144.97 |                 1.01 |         0.08 |         0.89 |             0.89 |             0.07 |      23,310.66 |               0.90 |
# | mutually~exclusive |     74.07 |                 2.68 |         0.89 |         0.93 |             0.93 |             0.82 |       5,497.58 |               1.00 |
# | too~early          |     76.40 |                 1.00 |         0.02 |         0.88 |             0.88 |             0.02 |       6,479.91 |               0.90 |
# | too~shabby         |     66.19 |                 1.00 |         0.02 |         0.88 |             0.88 |             0.02 |       4,863.82 |               0.90 |
# | much~older         |     33.87 |                 1.69 |         0.02 |         0.81 |             0.81 |             0.02 |       1,170.85 |               0.98 |
# | long~lasting       |     19.27 |                 2.99 |         0.14 |         0.80 |             0.80 |             0.11 |         371.62 |               1.00 |
# | always~greener     |     19.82 |                 1.40 |         0.00 |         0.78 |             0.78 |             0.00 |         409.04 |               0.96 |
# | more~fitting       |     16.18 |                 1.19 |         0.00 |         0.77 |             0.77 |             0.00 |         279.86 |               0.94 |
# | just~wishful       |     11.94 |                 1.66 |         0.00 |         0.76 |             0.76 |             0.00 |         145.76 |               0.98 |

# %% [markdown]
#  Save extended AM tables to `extra/` subdirectory if not already saved

# %%
df_extra_csv = df_csv_path.parent / 'extra' / \
    df_csv_path.name.replace('.csv', '_extra.csv')
print(df_extra_csv)
if not df_extra_csv.is_file():
    confirm_dir(df_extra_csv.parent)
    ex_adx_amdf.to_csv(df_extra_csv)

df_extra_pkl = df_extra_csv.with_suffix('.pkl.gz')
if not df_extra_pkl.is_file():
    ex_adx_amdf.to_pickle(df_extra_pkl)
# Out:
# /share/compling/projects/sanpi/results/assoc_df/adv_adj/RBdirect/extra/AdvAdj_frq-thrMIN-7.35f_min100x_extra.csv

# %%
ex_adx_full = ex_adx_amdf.copy()
ex_adx_abbr = adjust_assoc_columns(
    ex_adx_amdf[[c for c in ['polarity', 'quant'] + FOCUS if c in ex_adx_amdf.columns]]).sort_values('LRC', ascending=False)
cols = ex_adx_abbr.columns

# %% [markdown]
#  Define lexical items with given lean shown in binary environment evaluation

# %%
pos_prone = {
    'Adj': [
        'unrelated',
        'unable',
        'akin',
        'larger',
        'different',
        'familiar',
        'similar',
        'likely',
        'brief',
        'unaware'
    ],
    'Adv': [
        'slightly',
        'definitely',
        'utterly',
        # LRC top
        'pretty',
        'rather',
        'plain',
        'fairly',
        'somewhat',
        'otherwise',
        'downright',
        'relatively',
        # G2 top
        # 'very',
        # 'even',
        # 'just',
        # dP1 top (and odds ratio disc)
        'plain',
        'maybe'
    ],
    'Bigr': [
        # G2 top
        'completely_different',
        'too_familiar',
        'even_better',
        # dP1 top
        'quite_different',
        'too_real',
        'well_aware',
        # LRC top
        'too_common',
        'entirely_different'
    ]}
neg_prone = {
    'Bigr': [
        # LRC top
        'quite_sure',
        'really_sure',
        'too_early',
        'too_pleased',
        'too_fancy',
        # dP1 top
        'entirely_sure',
        'ever_easy',
        'ever_perfect',
        'particularly_surprising',
        'particularly_new',
        # G2 top
        'too_late',
        'more_important',
        'so_easy',
        'as_good',
        'too_old'
    ],
    'Adv': [
        'yet',
        # LRC top
        'ever',
        'any',
        'longer',
        'necessarily',
        'that',
        # dP1 top
        'before',
        'wise',  # ? How is this used as an adverb?
        'earthly',
        'remotely',
        'exactly',
        # G2 top
        'particularly',
        'too',
        # 'inherently'
    ],
    'Adj': [
        # LRC top
        'early',
        'late',
        'fancy',
        'alone',
        'sure',
        # dP1 top
        'shabby',
        'demoralizing',
        'alone',
        'aggravating',
        'groundbreaking',
        'eventful',
        # G2 top
        'important',
        'frustrating',
        'evident',
        'certain'
    ]
}


def sort_prone_by_f2(prone_list, amdf):
    return amdf.copy().loc[amdf.l2.isin(prone_list), ['f2', 'l2']].drop_duplicates().reset_index(drop=True).set_index('l2').round(1).sort_values(['f2'], ascending=False).index.to_list()


pos_prone[UNIT] = sort_prone_by_f2(pos_prone[UNIT], ex_adx_abbr)
neg_prone[UNIT] = sort_prone_by_f2(neg_prone[UNIT], ex_adx_abbr)
pos_prone[UNIT]
# Out:
# ['different', 'familiar', 'likely', 'similar', 'larger', 'unrelated', 'unable']

# %% [markdown]
#  Strongest associations for each polarity by metric

# %%
def show_metric_top(amdf: pd.DataFrame,
                    metric: str,
                    k=5,
                    cols=[None]):
    if not any(cols):
        cols = amdf.columns
    return (amdf.nlargest(k, metric)
            .loc[:, [metric] + cols[cols != metric].to_list()]
            .reset_index(drop=True).set_index(['l1', 'l2'])
            )

# %% [markdown]
#  Top consevative log ratio $LRC$ values

# %%
exdf = show_metric_top(ex_adx_abbr, "LRC", k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                             LRC     f  unexp_f  dP1  dP2  dP1_simple  \
# l1            l2
# legally       binding     12.67   637   636.28 0.93 0.19        0.93
# seriously     hurt        11.85   252   251.86 0.70 0.21        0.70
# mutually      exclusive   11.82  5509 5,497.58 0.89 0.93        0.89
# long          lasting     11.48   372   371.62 0.80 0.14        0.80
# reasonably    foreseeable 11.12   114   113.94 0.55 0.12        0.55
# clearly       erroneous   11.07   176   175.87 0.65 0.11        0.65
# aesthetically pleasing    10.88   794   793.37 0.43 0.72        0.43
# independently wealthy     10.63   192   191.89 0.16 0.65        0.16
#
#                            dP2_simple        G2        N    f1    f2  exp_f
# l1            l2
# legally       binding            0.19  8,527.10  3226225  3380   684   0.72
# seriously     hurt               0.21  3,585.97  3226225  1219   361   0.14
# mutually      exclusive          0.93 73,788.68  3226225  5940  6202  11.42
# long          lasting            0.14  4,869.30  3226225  2670   465   0.38
# reasonably    foreseeable        0.12  1,583.89  3226225   935   209   0.06
# clearly       erroneous          0.11  2,354.77  3226225  1569   271   0.13
# aesthetically pleasing           0.72 10,961.34  3226225  1104  1836   0.63
# independently wealthy            0.65  2,670.87  3226225   295  1236   0.11

# %% [markdown]
#  Top $\Delta P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                     dP1      f   unexp_f   LRC  dP2  dP1_simple  dP2_simple  \
# l1       l2
# legally  binding   0.93    637    636.28 12.67 0.19        0.93        0.19
# too      late      0.89  25854 23,310.66  8.75 0.08        0.98        0.08
# mutually exclusive 0.89   5509  5,497.58 11.82 0.93        0.89        0.93
# too      early     0.88   7193  6,479.91  8.03 0.02        0.98        0.02
#          shabby    0.88   5399  4,863.82  7.96 0.02        0.98        0.02
# much     older     0.81   1195  1,170.85  7.68 0.02        0.83        0.02
# long     lasting   0.80    372    371.62 11.48 0.14        0.80        0.14
# always   greener   0.78    426    409.04  6.29 0.00        0.81        0.00
#
#                            G2        N      f1     f2    exp_f
# l1       l2
# legally  binding     8,527.10  3226225    3380    684     0.72
# too      late      118,329.97  3226225  311944  26304 2,543.34
# mutually exclusive  73,788.68  3226225    5940   6202    11.42
# too      early      32,089.57  3226225  311944   7375   713.09
#          shabby     24,062.20  3226225  311944   5535   535.18
# much     older       8,482.07  3226225   53921   1445    24.15
# long     lasting     4,869.30  3226225    2670    465     0.38
# always   greener     2,427.81  3226225  104605    523    16.96

# %% [markdown]
#  Top conditional probability $P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                     dP1_simple      f   unexp_f   LRC  dP1  dP2  dP2_simple  \
# l1       l2
# too      late             0.98  25854 23,310.66  8.75 0.89 0.08        0.08
#          shabby           0.98   5399  4,863.82  7.96 0.88 0.02        0.02
#          early            0.98   7193  6,479.91  8.03 0.88 0.02        0.02
# legally  binding          0.93    637    636.28 12.67 0.93 0.19        0.19
# mutually exclusive        0.89   5509  5,497.58 11.82 0.89 0.93        0.93
# too      fussed           0.84    136    120.43  4.23 0.75 0.00        0.00
# much     older            0.83   1195  1,170.85  7.68 0.81 0.02        0.02
# more     fitting          0.82    299    279.86  5.46 0.77 0.00        0.00
#
#                            G2        N      f1     f2    exp_f
# l1       l2
# too      late      118,329.97  3226225  311944  26304 2,543.34
#          shabby     24,062.20  3226225  311944   5535   535.18
#          early      32,089.57  3226225  311944   7375   713.09
# legally  binding     8,527.10  3226225    3380    684     0.72
# mutually exclusive  73,788.68  3226225    5940   6202    11.42
# too      fussed        501.57  3226225  311944    161    15.57
# much     older       8,482.07  3226225   53921   1445    24.15
# more     fitting     1,425.41  3226225  169217    365    19.14

# %% [markdown]
#  Top $\Delta P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                           dP2     f  unexp_f   LRC  dP1  dP1_simple  \
# l1           l2
# ornamentally significant 1.00   109   108.73  8.62 0.01        0.01
# backwards    compatible  0.97   142   141.89 10.31 0.06        0.06
# crystal      clear       0.97   117   114.33  5.40 0.00        0.00
# mutually     exclusive   0.93  5509 5,497.58 11.82 0.89        0.89
# closely      related     0.92   819   816.26  8.25 0.08        0.08
# terminally   ill         0.90   373   372.74 10.60 0.18        0.18
# mobile       friendly    0.90   435   434.12  8.93 0.07        0.07
# humanly      possible    0.88   344   341.53  7.02 0.02        0.02
#
#                           dP2_simple        G2        N    f1     f2  exp_f
# l1           l2
# ornamentally significant        1.00  1,312.36  3226225   109   7893   0.27
# backwards    compatible         0.97  2,025.02  3226225   146   2341   0.11
# crystal      clear              0.99    875.54  3226225   118  72905   2.67
# mutually     exclusive          0.93 73,788.68  3226225  5940   6202  11.42
# closely      related            0.92  9,058.12  3226225   887   9959   2.74
# terminally   ill                0.90  5,314.49  3226225   413   2017   0.26
# mobile       friendly           0.90  5,210.44  3226225   484   5834   0.88
# humanly      possible           0.89  3,216.91  3226225   386  20623   2.47

# %% [markdown]
#  Top conditional probability $P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                           dP2_simple     f  unexp_f   LRC  dP1  dP2  \
# l1           l2
# ornamentally significant        1.00   109   108.73  8.62 0.01 1.00
# crystal      clear              0.99   117   114.33  5.40 0.00 0.97
# backwards    compatible         0.97   142   141.89 10.31 0.06 0.97
# mutually     exclusive          0.93  5509 5,497.58 11.82 0.89 0.93
# closely      related            0.92   819   816.26  8.25 0.08 0.92
# terminally   ill                0.90   373   372.74 10.60 0.18 0.90
# mobile       friendly           0.90   435   434.12  8.93 0.07 0.90
# humanly      possible           0.89   344   341.53  7.02 0.02 0.88
#
#                           dP1_simple        G2        N    f1     f2  exp_f
# l1           l2
# ornamentally significant        0.01  1,312.36  3226225   109   7893   0.27
# crystal      clear              0.00    875.54  3226225   118  72905   2.67
# backwards    compatible         0.06  2,025.02  3226225   146   2341   0.11
# mutually     exclusive          0.89 73,788.68  3226225  5940   6202  11.42
# closely      related            0.08  9,058.12  3226225   887   9959   2.74
# terminally   ill                0.18  5,314.49  3226225   413   2017   0.26
# mobile       friendly           0.07  5,210.44  3226225   484   5834   0.88
# humanly      possible           0.02  3,216.91  3226225   386  20623   2.47

# %% [markdown]
#  Top log-likelihood $G^2$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'G2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                               G2      f   unexp_f   LRC  dP1  dP2  dP1_simple  \
# l1          l2
# immediately clear     123,693.61  25276 23,980.73  4.83 0.34 0.43        0.35
# too         late      118,329.97  25854 23,310.66  8.75 0.89 0.08        0.98
# immediately available 106,933.84  21297 20,299.71  5.03 0.37 0.36        0.38
# even        close      96,653.89  17701 16,984.89  5.84 0.58 0.22        0.60
# quite       sure       77,043.21  26156 22,996.80  3.30 0.19 0.30        0.20
# always      easy       73,886.15  24574 21,734.43  3.50 0.26 0.21        0.28
# mutually    exclusive  73,788.68   5509  5,497.58 11.82 0.89 0.93        0.89
# much        better     61,573.77  11225 10,824.80  5.62 0.46 0.20        0.47
#
#                        dP2_simple        N      f1      f2    exp_f
# l1          l2
# immediately clear            0.44  3226225   57319   72905 1,295.27
# too         late             0.08  3226225  311944   26304 2,543.34
# immediately available        0.37  3226225   57319   56133   997.29
# even        close            0.23  3226225   78489   29435   716.11
# quite       sure             0.33  3226225   79118  128824 3,159.20
# always      easy             0.23  3226225  104605   87578 2,839.57
# mutually    exclusive        0.93  3226225    5940    6202    11.42
# much        better           0.21  3226225   53921   23945   400.20

# %%
sig_adx_abbr = ex_adx_abbr.loc[ex_adx_abbr.LRC.abs() > 1, :]
sig_adx_abbr
# Out:
#                            f    unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# legally~binding          637     636.28 12.67  0.93  0.19        0.93
# seriously~hurt           252     251.86 11.85  0.70  0.21        0.70
# mutually~exclusive      5509   5,497.58 11.82  0.89  0.93        0.89
# long~lasting             372     371.62 11.48  0.80  0.14        0.80
# reasonably~foreseeable   114     113.94 11.12  0.55  0.12        0.55
# ...                      ...        ...   ...   ...   ...         ...
# that~sure                300  -6,304.90 -4.15 -0.05 -0.04        0.00
# more~easy                147  -4,446.51 -4.50 -0.05 -0.03        0.00
# as~available             320  -8,996.28 -4.75 -0.16 -0.02        0.01
# as~sure                  714 -20,666.66 -4.91 -0.17 -0.05        0.01
# more~sure                141  -6,615.88 -5.10 -0.05 -0.04        0.00
#
#                         dP2_simple         G2        N      f1      f2  \
# key
# legally~binding               0.19   8,527.10  3226225    3380     684
# seriously~hurt                0.21   3,585.97  3226225    1219     361
# mutually~exclusive            0.93  73,788.68  3226225    5940    6202
# long~lasting                  0.14   4,869.30  3226225    2670     465
# reasonably~foreseeable        0.12   1,583.89  3226225     935     209
# ...                            ...        ...      ...     ...     ...
# that~sure                     0.00 -11,335.14  3226225  165411  128824
# more~easy                     0.00  -8,240.87  3226225  169217   87578
# as~available                  0.00 -17,646.14  3226225  535450   56133
# as~sure                       0.00 -41,207.08  3226225  535450  128824
# more~sure                     0.00 -12,773.57  3226225  169217  128824
#
#                            exp_f          l1           l2
# key
# legally~binding             0.72     legally      binding
# seriously~hurt              0.14   seriously         hurt
# mutually~exclusive         11.42    mutually    exclusive
# long~lasting                0.38        long      lasting
# reasonably~foreseeable      0.06  reasonably  foreseeable
# ...                          ...         ...          ...
# that~sure               6,604.90        that         sure
# more~easy               4,593.51        more         easy
# as~available            9,316.28          as    available
# as~sure                21,380.66          as         sure
# more~sure               6,756.88        more         sure
#
# [1752 rows x 14 columns]

# %% [markdown]
#  Positive Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(pos_prone['Adv'])]
# Out:
#                         f  unexp_f  LRC  dP1  dP2  dP1_simple  dP2_simple  \
# key
# otherwise~eligible    103   102.23 6.52 0.06 0.07        0.06        0.07
# downright~impossible  127   125.47 5.86 0.04 0.07        0.05        0.07
# pretty~enough         544   528.40 4.91 0.02 0.23        0.03        0.23
# otherwise~available   388   361.94 3.62 0.01 0.24        0.01        0.26
# otherwise~possible    116   106.42 3.02 0.01 0.07        0.01        0.08
#
#                            G2        N    f1     f2  exp_f         l1  \
# key
# otherwise~eligible     819.04  3226225  1498   1648   0.77  otherwise
# downright~impossible   886.49  3226225  1765   2795   1.53  downright
# pretty~enough        2,952.01  3226225  2319  21707  15.60     pretty
# otherwise~available  1,471.42  3226225  1498  56133  26.06  otherwise
# otherwise~possible     374.20  3226225  1498  20623   9.58  otherwise
#
#                               l2
# key
# otherwise~eligible      eligible
# downright~impossible  impossible
# pretty~enough             enough
# otherwise~available    available
# otherwise~possible      possible

# %% [markdown]
#  Negative Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(neg_prone['Adv'])]
# Out:
#                    f   unexp_f   LRC   dP1   dP2  dP1_simple  dP2_simple  \
# key
# too~late       25854 23,310.66  8.75  0.89  0.08        0.98        0.08
# any~clearer      357    354.58  8.33  0.70  0.02        0.71        0.02
# any~happier      830    823.67  8.09  0.63  0.05        0.63        0.05
# too~early       7193  6,479.91  8.03  0.88  0.02        0.98        0.02
# too~shabby      5399  4,863.82  7.96  0.88  0.02        0.98        0.02
# ...              ...       ...   ...   ...   ...         ...         ...
# too~simple       236 -2,726.29 -3.35 -0.09 -0.01        0.01        0.00
# too~effective    140 -1,809.76 -3.38 -0.09 -0.01        0.01        0.00
# too~aware        128 -1,770.51 -3.44 -0.09 -0.01        0.01        0.00
# too~clear        473 -6,576.19 -3.73 -0.09 -0.02        0.01        0.00
# that~sure        300 -6,304.90 -4.15 -0.05 -0.04        0.00        0.00
#
#                       G2        N      f1      f2    exp_f    l1         l2
# key
# too~late      118,329.97  3226225  311944   26304 2,543.34   too       late
# any~clearer     3,213.03  3226225   15492     504     2.42   any    clearer
# any~happier     7,174.46  3226225   15492    1318     6.33   any    happier
# too~early      32,089.57  3226225  311944    7375   713.09   too      early
# too~shabby     24,062.20  3226225  311944    5535   535.18   too     shabby
# ...                  ...      ...     ...     ...      ...   ...        ...
# too~simple     -4,545.21  3226225  311944   30637 2,962.29   too     simple
# too~effective  -3,067.85  3226225  311944   20165 1,949.76   too  effective
# too~aware      -3,032.95  3226225  311944   19635 1,898.51   too      aware
# too~clear     -11,388.57  3226225  311944   72905 7,049.19   too      clear
# that~sure     -11,335.14  3226225  165411  128824 6,604.90  that       sure
#
# [347 rows x 14 columns]

# %% [markdown]
#  Positive Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(pos_prone['Adj'])]
# Out:
#                              f   unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# intimately~familiar        311    309.26  7.31  0.02  0.72        0.02
# substantially~similar      118    117.46  7.28  0.06  0.14        0.06
# much~larger                790    769.56  6.35  0.63  0.01        0.65
# radically~different        430    421.67  5.54  0.01  0.72        0.01
# drastically~different      237    232.02  5.33  0.01  0.66        0.01
# significantly~different   1604  1,561.26  5.16  0.03  0.52        0.04
# already~familiar           893    869.58  5.14  0.07  0.15        0.07
# markedly~different         147    143.51  5.05  0.00  0.58        0.00
# remotely~similar           152    148.48  4.99  0.07  0.03        0.08
# vastly~different           140    136.45  4.94  0.00  0.55        0.00
# materially~different       167    162.50  4.87  0.00  0.51        0.00
# dramatically~different     270    262.16  4.82  0.01  0.47        0.01
# substantially~different    338    325.72  4.51  0.01  0.38        0.01
# only~unable                162    152.03  4.41  0.54  0.00        0.57
# fundamentally~different    359    342.97  4.21  0.01  0.30        0.01
# much~different           10891 10,126.15  4.13  0.22  0.19        0.24
# entirely~unrelated         106    100.31  4.05  0.35  0.00        0.37
# personally~familiar        103     95.89  3.23  0.01  0.06        0.01
# previously~familiar        106     97.52  3.03  0.01  0.05        0.01
# less~likely                462    414.31  3.03  0.04  0.03        0.04
# ever~likely                185    165.55  2.79  0.02  0.03        0.02
# most~likely                517    451.45  2.75  0.04  0.02        0.05
# more~likely               2618  2,066.48  2.43  0.20  0.01        0.25
# statistically~different    321    272.74  2.39  0.01  0.08        0.01
# wildly~different           103     88.55  2.22  0.00  0.09        0.00
# very~likely               2330  1,699.14  2.00  0.16  0.01        0.22
# any~different              910    690.25  1.86  0.02  0.04        0.02
# more~different            6797  4,396.71  1.57  0.10  0.03        0.15
# that~different            6574  4,227.70  1.55  0.09  0.03        0.14
# yet~familiar               660    445.73  1.41  0.03  0.01        0.05
# super~familiar             149    108.86  1.36  0.01  0.01        0.01
# overly~familiar            288    187.25  1.15  0.01  0.01        0.02
# only~familiar              164   -301.16 -1.02 -0.02 -0.00        0.01
# just~different             265   -506.62 -1.15 -0.01 -0.01        0.01
# as~similar                 103   -228.94 -1.21 -0.11 -0.00        0.05
# entirely~different         252   -651.68 -1.45 -0.01 -0.01        0.01
# too~likely                 297   -719.70 -1.49 -0.07 -0.00        0.03
# really~different           366 -1,024.78 -1.61 -0.02 -0.01        0.01
# that~likely                111   -428.11 -1.71 -0.04 -0.00        0.01
# so~likely                  272   -857.57 -1.78 -0.08 -0.00        0.03
# more~familiar              126   -564.04 -1.93 -0.04 -0.00        0.01
# only~different             299 -1,319.06 -2.10 -0.03 -0.01        0.01
# particularly~different     117   -674.49 -2.17 -0.01 -0.01        0.00
# as~different               616 -6,979.19 -3.60 -0.15 -0.02        0.01
#
#                          dP2_simple         G2        N      f1     f2  \
# key
# intimately~familiar            0.73   2,931.16  3226225     427  13156
# substantially~similar          0.14   1,061.52  3226225     866   2000
# much~larger                    0.01   4,900.77  3226225   53921   1223
# radically~different            0.73   2,986.49  3226225     587  45763
# drastically~different          0.68   1,579.05  3226225     351  45763
# significantly~different        0.53   9,582.62  3226225    3013  45763
# already~familiar               0.16   4,962.00  3226225    5744  13156
# markedly~different             0.60     922.83  3226225     246  45763
# remotely~similar               0.03     862.94  3226225    5679   2000
# vastly~different               0.56     852.16  3226225     250  45763
# materially~different           0.53     987.70  3226225     317  45763
# dramatically~different         0.49   1,541.32  3226225     553  45763
# substantially~different        0.39   1,735.72  3226225     866  45763
# only~unable                    0.00     707.08  3226225  114071    282
# fundamentally~different        0.32   1,667.38  3226225    1130  45763
# much~different                 0.20  42,170.30  3226225   53921  45763
# entirely~unrelated             0.00     460.51  3226225   63708    288
# personally~familiar            0.06     364.96  3226225    1744  13156
# previously~familiar            0.05     345.86  3226225    2079  13156
# less~likely                    0.03   1,298.21  3226225   14632  10515
# ever~likely                    0.03     509.65  3226225    5967  10515
# most~likely                    0.03   1,262.61  3226225   20113  10515
# more~likely                    0.02   4,510.64  3226225  169217  10515
# statistically~different        0.09     695.51  3226225    3402  45763
# wildly~different               0.10     235.66  3226225    1019  45763
# very~likely                    0.01   3,016.60  3226225  193561  10515
# any~different                  0.06   1,247.98  3226225   15492  45763
# more~different                 0.04   5,941.47  3226225  169217  45763
# that~different                 0.04   5,632.96  3226225  165411  45763
# yet~familiar                   0.01     612.93  3226225   52546  13156
# super~familiar                 0.02     175.24  3226225    9844  13156
# overly~familiar                0.01     234.62  3226225   24707  13156
# only~familiar                  0.00    -268.30  3226225  114071  13156
# just~different                 0.00    -457.33  3226225   54398  45763
# as~similar                     0.00    -247.00  3226225  535450   2000
# entirely~different             0.00    -676.02  3226225   63708  45763
# too~likely                     0.00    -763.47  3226225  311944  10515
# really~different               0.00  -1,107.00  3226225   98048  45763
# that~likely                    0.00    -524.66  3226225  165411  10515
# so~likely                      0.00  -1,019.05  3226225  346575  10515
# more~familiar                  0.00    -726.69  3226225  169217  13156
# only~different                 0.00  -1,683.38  3226225  114071  45763
# particularly~different         0.00    -920.08  3226225   55799  45763
# as~different                   0.00 -12,178.64  3226225  535450  45763
#
#                            exp_f             l1         l2
# key
# intimately~familiar         1.74     intimately   familiar
# substantially~similar       0.54  substantially    similar
# much~larger                20.44           much     larger
# radically~different         8.33      radically  different
# drastically~different       4.98    drastically  different
# significantly~different    42.74  significantly  different
# already~familiar           23.42        already   familiar
# markedly~different          3.49       markedly  different
# remotely~similar            3.52       remotely    similar
# vastly~different            3.55         vastly  different
# materially~different        4.50     materially  different
# dramatically~different      7.84   dramatically  different
# substantially~different    12.28  substantially  different
# only~unable                 9.97           only     unable
# fundamentally~different    16.03  fundamentally  different
# much~different            764.85           much  different
# entirely~unrelated          5.69       entirely  unrelated
# personally~familiar         7.11     personally   familiar
# previously~familiar         8.48     previously   familiar
# less~likely                47.69           less     likely
# ever~likely                19.45           ever     likely
# most~likely                65.55           most     likely
# more~likely               551.52           more     likely
# statistically~different    48.26  statistically  different
# wildly~different           14.45         wildly  different
# very~likely               630.86           very     likely
# any~different             219.75            any  different
# more~different          2,400.29           more  different
# that~different          2,346.30           that  different
# yet~familiar              214.27            yet   familiar
# super~familiar             40.14          super   familiar
# overly~familiar           100.75         overly   familiar
# only~familiar             465.16           only   familiar
# just~different            771.62           just  different
# as~similar                331.94             as    similar
# entirely~different        903.68       entirely  different
# too~likely              1,016.70            too     likely
# really~different        1,390.78         really  different
# that~likely               539.11           that     likely
# so~likely               1,129.57             so     likely
# more~familiar             690.04           more   familiar
# only~different          1,618.06           only  different
# particularly~different    791.49   particularly  different
# as~different            7,595.19             as  different

# %% [markdown]
#  Negative Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(neg_prone['Adj'])]
# Out:
#                            f    unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# too~late               25854  23,310.66  8.75  0.89  0.08        0.98
# too~early               7193   6,479.91  8.03  0.88  0.02        0.98
# too~shabby              5399   4,863.82  7.96  0.88  0.02        0.98
# truly~alone              228     223.88  5.53  0.13  0.03        0.13
# more~frustrating        1917   1,770.35  5.03  0.63  0.01        0.69
# absolutely~certain       543     527.65  4.96  0.06  0.09        0.06
# more~aggravating         101      92.56  3.85  0.57  0.00        0.63
# quite~sure             26156  22,996.80  3.30  0.19  0.30        0.20
# completely~alone         214     195.62  3.24  0.11  0.01        0.12
# more~evident            1475   1,263.62  3.17  0.31  0.01        0.37
# more~important         15208  12,589.20  2.92  0.26  0.08        0.30
# entirely~certain        1218   1,051.55  2.87  0.13  0.02        0.14
# ever~certain             147     131.41  2.72  0.02  0.02        0.02
# yet~certain              874     736.72  2.57  0.09  0.01        0.10
# too~fancy                823     638.52  2.52  0.33  0.00        0.43
# entirely~sure          13046  10,502.12  2.43  0.08  0.17        0.10
# immediately~evident      428     356.40  2.38  0.09  0.01        0.11
# exactly~sure            8860   7,117.64  2.36  0.06  0.17        0.07
# really~alone             303     250.94  2.36  0.15  0.00        0.18
# really~sure            17898  13,982.92  2.32  0.11  0.15        0.14
# even~sure              14520  11,385.91  2.30  0.09  0.15        0.11
# less~important           926     699.56  1.84  0.01  0.05        0.02
# completely~certain       382     291.54  1.79  0.03  0.01        0.05
# quite~certain            747     540.29  1.70  0.06  0.01        0.09
# n't~important            239     178.83  1.58  0.00  0.05        0.00
# entirely~alone           138     104.17  1.54  0.06  0.00        0.08
# even~certain             672     466.94  1.53  0.06  0.01        0.08
# absolutely~sure          757     522.33  1.47  0.00  0.09        0.01
# most~important           963     651.73  1.44  0.01  0.03        0.02
# equally~important        139     103.61  1.43  0.00  0.05        0.00
# totally~sure            1762   1,095.40  1.26  0.01  0.07        0.01
# always~evident           361     230.33  1.19  0.06  0.00        0.09
# that~important          5532   2,972.10  1.11  0.06  0.02        0.11
# so~sure                26584  12,745.17  1.07  0.10  0.04        0.21
# fully~sure               240    -431.99 -1.07 -0.00 -0.03        0.00
# necessarily~important    204    -456.98 -1.25 -0.01 -0.01        0.00
# all~important            112    -344.17 -1.41 -0.01 -0.01        0.00
# as~certain               471    -927.94 -1.44 -0.11 -0.00        0.06
# always~sure             1168  -3,008.90 -1.68 -0.02 -0.03        0.01
# too~certain              188    -627.00 -1.74 -0.07 -0.00        0.02
# all~sure                 175  -1,001.98 -2.26 -0.01 -0.03        0.00
# even~important           165  -1,049.69 -2.40 -0.02 -0.01        0.00
# necessarily~sure         222  -1,483.42 -2.52 -0.01 -0.04        0.00
# too~important            683  -4,144.64 -2.69 -0.08 -0.01        0.01
# always~important         136  -1,482.87 -3.05 -0.03 -0.01        0.00
# very~sure                675  -7,053.94 -3.34 -0.06 -0.04        0.01
# immediately~sure         150  -2,138.76 -3.42 -0.02 -0.04        0.00
# that~sure                300  -6,304.90 -4.15 -0.05 -0.04        0.00
# as~sure                  714 -20,666.66 -4.91 -0.17 -0.05        0.01
# more~sure                141  -6,615.88 -5.10 -0.05 -0.04        0.00
#
#                        dP2_simple         G2        N      f1      f2  \
# key
# too~late                     0.08 118,329.97  3226225  311944   26304
# too~early                    0.02  32,089.57  3226225  311944    7375
# too~shabby                   0.02  24,062.20  3226225  311944    5535
# truly~alone                  0.03   1,419.43  3226225    7763    1713
# more~frustrating             0.01   7,935.19  3226225  169217    2796
# absolutely~certain           0.09   2,899.94  3226225    5877    8429
# more~aggravating             0.00     389.36  3226225  169217     161
# quite~sure                   0.33  77,043.21  3226225   79118  128824
# completely~alone             0.01     683.90  3226225   34625    1713
# more~evident                 0.01   3,687.80  3226225  169217    4030
# more~important               0.09  33,049.72  3226225  169217   49929
# entirely~certain             0.02   2,902.99  3226225   63708    8429
# ever~certain                 0.02     401.86  3226225    5967    8429
# yet~certain                  0.02   1,840.23  3226225   52546    8429
# too~fancy                    0.00   1,458.61  3226225  311944    1908
# entirely~sure                0.20  24,502.08  3226225   63708  128824
# immediately~evident          0.01     853.12  3226225   57319    4030
# exactly~sure                 0.20  16,290.04  3226225   43635  128824
# really~alone                 0.00     606.14  3226225   98048    1713
# really~sure                  0.18  30,319.37  3226225   98048  128824
# even~sure                    0.18  24,673.13  3226225   78489  128824
# less~important               0.06   1,253.78  3226225   14632   49929
# completely~certain           0.01     530.26  3226225   34625    8429
# quite~certain                0.01     878.95  3226225   79118    8429
# n't~important                0.06     310.78  3226225    3888   49929
# entirely~alone               0.00     186.49  3226225   63708    1713
# even~certain                 0.01     691.26  3226225   78489    8429
# absolutely~sure              0.13     780.64  3226225    5877  128824
# most~important               0.05     902.18  3226225   20113   49929
# equally~important            0.06     178.14  3226225    2287   49929
# totally~sure                 0.11   1,321.01  3226225   16694  128824
# always~evident               0.00     287.46  3226225  104605    4030
# that~important               0.03   2,829.53  3226225  165411   49929
# so~sure                      0.08  11,240.59  3226225  346575  128824
# fully~sure                   0.01    -382.73  3226225   16829  128824
# necessarily~important        0.00    -443.55  3226225   42710   49929
# all~important                0.00    -380.25  3226225   29476   49929
# as~certain                   0.00    -949.77  3226225  535450    8429
# always~sure                  0.01  -3,205.44  3226225  104605  128824
# too~certain                  0.00    -754.17  3226225  311944    8429
# all~sure                     0.01  -1,380.13  3226225   29476  128824
# even~important               0.00  -1,477.62  3226225   78489   49929
# necessarily~sure             0.01  -2,132.57  3226225   42710  128824
# too~important                0.00  -6,049.30  3226225  311944   49929
# always~important             0.00  -2,359.06  3226225  104605   49929
# very~sure                    0.00 -11,501.25  3226225  193561  128824
# immediately~sure             0.00  -3,579.51  3226225   57319  128824
# that~sure                    0.00 -11,335.14  3226225  165411  128824
# as~sure                      0.00 -41,207.08  3226225  535450  128824
# more~sure                    0.00 -12,773.57  3226225  169217  128824
#
#                           exp_f           l1           l2
# key
# too~late               2,543.34          too         late
# too~early                713.09          too        early
# too~shabby               535.18          too       shabby
# truly~alone                4.12        truly        alone
# more~frustrating         146.65         more  frustrating
# absolutely~certain        15.35   absolutely      certain
# more~aggravating           8.44         more  aggravating
# quite~sure             3,159.20        quite         sure
# completely~alone          18.38   completely        alone
# more~evident             211.38         more      evident
# more~important         2,618.80         more    important
# entirely~certain         166.45     entirely      certain
# ever~certain              15.59         ever      certain
# yet~certain              137.28          yet      certain
# too~fancy                184.48          too        fancy
# entirely~sure          2,543.88     entirely         sure
# immediately~evident       71.60  immediately      evident
# exactly~sure           1,742.36      exactly         sure
# really~alone              52.06       really        alone
# really~sure            3,915.08       really         sure
# even~sure              3,134.09         even         sure
# less~important           226.44         less    important
# completely~certain        90.46   completely      certain
# quite~certain            206.71        quite      certain
# n't~important             60.17          n't    important
# entirely~alone            33.83     entirely        alone
# even~certain             205.06         even      certain
# absolutely~sure          234.67   absolutely         sure
# most~important           311.27         most    important
# equally~important         35.39      equally    important
# totally~sure             666.60      totally         sure
# always~evident           130.67       always      evident
# that~important         2,559.90         that    important
# so~sure               13,838.83           so         sure
# fully~sure               671.99        fully         sure
# necessarily~important    660.98  necessarily    important
# all~important            456.17          all    important
# as~certain             1,398.94           as      certain
# always~sure            4,176.90       always         sure
# too~certain              815.00          too      certain
# all~sure               1,176.98          all         sure
# even~important         1,214.69         even    important
# necessarily~sure       1,705.42  necessarily         sure
# too~important          4,827.64          too    important
# always~important       1,618.87       always    important
# very~sure              7,728.94         very         sure
# immediately~sure       2,288.76  immediately         sure
# that~sure              6,604.90         that         sure
# as~sure               21,380.66           as         sure
# more~sure              6,756.88         more         sure
