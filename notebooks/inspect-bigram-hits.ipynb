# %% [markdown]
# # Inspecting pickled `bigram` hits

# %% [markdown]
# ## Imports

# %%
import pandas as pd
from pathlib import Path

# %% [markdown]
# ## Define helper functions
#
# ### Copied from `./source/analyze/utils/`
# jupyter won't import them 🤷‍♀️

# %%
def find_files(data_dir: Path, fname_glob: str, verbose: bool = False):
    path_iter = data_dir.rglob(fname_glob)
    if verbose:
        path_iter = tuple(path_iter)
        print_iter(
            [f'../{p.relative_to(data_dir)}' for p in path_iter], bullet='-',
            header=f'### {len(path_iter)} paths matching {fname_glob} found in {data_dir}')
    return path_iter


def print_iter(iter_obj,
               bullet: str = '▸',
               # //    logger: logging.Logger = None,
               # //    level: int = 20,
               header: str = ''):

    bullet_str = f'\n{bullet} '

    iter_str = bullet_str.join(f'{i}' for i in iter_obj)

    msg_str = f'\n{header}{bullet_str}{iter_str}'
    msg_str = msg_str.replace('\n\n', '\n').strip(f'{bullet} ')

    print(msg_str)


def cols_by_str(df: pd.DataFrame, start_str=None, end_str=None) -> list:
    if end_str:
        cols = df.columns[df.columns.str.endswith(end_str)]
        if start_str:
            cols = cols[cols.str.startswith(start_str)]
    elif start_str:
        cols = df.columns[df.columns.str.startswith(start_str)]
    else:
        cols = df.columns

    return cols.to_list()


def make_cats(orig_df: pd.DataFrame, columns: list = None) -> pd.DataFrame:
    df = orig_df.copy()
    if columns is None:
        cat_suff = ("code", "name", "path", "stem")
        columns = df.columns.str.endswith(cat_suff)  # type: ignore
    df.loc[:, columns] = df.loc[:, columns].astype(
        'string').fillna('_').astype('category')

    return df


def balance_sample(full_df: pd.DataFrame,
                   column_name: str = 'category',
                   sample_per_value: int = 5,
                   verbose: bool = False) -> tuple:
    '''
    create sample with no more than n rows satisfying each unique value
    of the given column. A value of -1 for `sample_per_value` will limit
    all values' results to the minimum count per value.
    '''
    info_message = ''
    subsamples = []
    for __, col_val_df in full_df.groupby(column_name):
        # take sample if 1+ and less than length of full dataframe
        if len(col_val_df) > sample_per_value > 0:
            subsample_df = col_val_df.sample(sample_per_value)
            subsamples.append(subsample_df)
        else:
            subsamples.append(col_val_df)

    # > trim all "by column" sub dfs to length of shortest if -1 given
    if sample_per_value == -1:
        trim_len = int(min(len(sdf) for sdf in subsamples))
        subsamples = [sdf.sample(trim_len)
                      for sdf in subsamples]

    b_sample = pd.concat(subsamples)

    if verbose:
        subset_info_table = (
            b_sample
            .value_counts(subset=column_name)
            .to_frame(name='count')
            .assign(percentage=b_sample
                    .value_counts(column_name, normalize=True)
                    .round(2) * 100)
            .to_markdown())
        label = (full_df.hits_df_pkl[0].stem + ' '
                 if 'hits_df_pkl' in full_df.columns
                 else '')
        info_message = (f'\n## {column_name} representation in {label}sample\n'
                        + subset_info_table)

    return b_sample, info_message


def concat_pkls(data_dir: Path = Path('/share/compling/data/sanpi/2_hit_tables'),
                fname_glob: str = '*.pkl.gz',
                pickles=None,
                convert_dtypes=False,
                verbose: bool = True) -> pd.DataFrame:
    if not pickles:
        pickles = find_files(Path(data_dir), fname_glob, verbose)

    # tested and found that it is faster to assign `corpus` intermittently
    sep_dfs = []
    for p in pickles:
        df = (pd.read_pickle(p).assign(corpus=p.stem.rsplit('_', 2)[0]))
        df = df.loc[:, cols_by_str(df, end_str=('lemma', 'id', 'text', 'window',
                      'category', 'Pol', 'sent')) + cols_by_str(df, start_str=('corpus', 'lemma'))]
        df = df.convert_dtypes()

        dup_check_cols = cols_by_str(df, end_str=('text', 'id', 'sent'))
        df = (df.loc[~df.duplicated(subset=dup_check_cols), :])
    
    c_df = pd.concat(sep_dfs)    
    dup_check_cols = cols_by_str(c_df, end_str=('text', 'id', 'sent'))
    c_df = (c_df.loc[~c_df.duplicated(subset=dup_check_cols), :])
    c_df = make_cats(c_df, (['corpus'] + cols_by_str(c_df, start_str=('nr', 'neg', 'adv'),
                                                 end_str=('lemma', 'form'))))

    return c_df

# %% [markdown]
# ### copied from `./source/analyze_deps.py`:

# %%
def _optimize_df(df: pd.DataFrame) -> pd.DataFrame:

    # print('Original Dataframe:')
    # df.info(memory_usage='deep')

    # > drop unneeded string columns
    # was:
    #   for c in udf.cols_by_str(df, start_str=('context', 'text', 'sent_text', 'token')):
    for c in cols_by_str(df, start_str=('context', 'token', 'utt')):
        df.pop(c)

    # > select only non-`object` dtype columns
    relevant_cols = df.columns[~df.dtypes.astype(
        'string').str.endswith(('object'))]
    # limit df to `relevant_cols`
    df = df[relevant_cols]

    # > create empty dataframe with `relevant_cols` as index/rows
    df_info = pd.DataFrame(index=relevant_cols)

    df_info = df_info.assign(
        mem0=df.memory_usage(deep=True),
        dtype0=df.dtypes.astype('string'),
        defined_values=df.count(),
        unique_values=df.apply(pd.unique, axis=0).apply(len))
    df_info = df_info.assign(
        ratio_unique=(df_info.unique_values/df_info.defined_values).round(2))

    cat_candidates = df_info.loc[df_info.ratio_unique < 0.8,
                                 :].loc[df_info.dtype0 != 'category'].index.to_list()
    #was: catted_df = udf.make_cats(df.copy(), cat_candidates)
    catted_df = make_cats(df.copy(), cat_candidates)

    df_info = df_info.assign(dtype1=catted_df.dtypes,
                             mem1=catted_df.memory_usage(deep=True))
    df_info = df_info.assign(mem_change=df_info.mem1-df_info.mem0)
    print(df_info.sort_values(
        ['mem_change', 'ratio_unique', 'dtype0']).to_markdown())
    mem_improved = df_info.loc[df_info.mem_change < 0, :].index.to_list()
    for c in df.columns[~df.columns.isin(mem_improved)]:
        print(c, '\t', df.loc[:, c].dtype)
    df.loc[:, mem_improved] = catted_df.loc[:, mem_improved]
    print('Category Converted dataframe:')
    df.info(memory_usage='deep')

    return df

# %% [markdown]
# ### Newly created

# %%
def show_counts(df, columns):
    return df.value_counts(columns).to_frame().rename(columns={0: 'count'})

def summarize_text_cols(tdf: pd.DataFrame):

    summary = tdf.describe().transpose()
    summary = summary.assign(top_percent=(
        ((pd.to_numeric(summary.freq) / len(tdf)))*100).round(2))
    summary = summary.rename(columns={'top': 'top_value', 'freq': 'top_freq'})

    return summary.convert_dtypes().sort_values('unique')

# %% [markdown]
# ## Load Data

# %%
# ddf = concat_pkls(
#     data_dir=Path('/share/compling/data/sanpi/2_hit_tables'),
#     # fname_glob='bigram*hits.pkl.gz',
#     fname_glob='bigram-[AP]??[TV_]*hits.pkl.gz',
#     convert_dtypes=True)

def select_pickles():
    # HACK -- `with-context/` is temporary!
    pickle_dir = Path(
        '/share/compling/data/sanpi/2_hit_tables/')
    # > make dataframe to load smallest files first (for testing)
    pkl_df = pd.DataFrame(pickle_dir.rglob(
        'bigram-*hits.pkl.gz'), columns=['path'])
    pkl_df = pkl_df.assign(size=pkl_df.path.apply(lambda f: f.stat().st_size))
    pkl_df = pkl_df.sort_values('size')
    print(pkl_df.reset_index().astype('string').to_markdown())
    pkl_paths = pkl_df.path.to_list()
    return pkl_paths
hit_pkls = select_pickles()
# Out:
# |     |   index | path                                                                                            |      size |
# |----:|--------:|:------------------------------------------------------------------------------------------------|----------:|
# |   0 |      61 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-PccTe_with-relay_hits.pkl.gz              |     47450 |
# |   1 |      43 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-PccVa_with-relay_hits.pkl.gz              |     47672 |
# |   2 |      22 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-PccVa_neg-raised_hits.pkl.gz              |     61657 |
# |   3 |       0 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-PccTe_neg-raised_hits.pkl.gz              |     61667 |
# |   4 |      70 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-PccTe_sans-relay_hits.pkl.gz              |    856805 |
# |   5 |      71 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-PccVa_sans-relay_hits.pkl.gz              |    875519 |
# |   6 |      29 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Apw_neg-raised_hits.pkl.gz                |   1398819 |
# |   7 |      48 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Apw_with-relay_hits.pkl.gz                |   1481861 |
# |   8 |      31 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Nyt1_neg-raised_hits.pkl.gz               |   1676579 |
# |   9 |      65 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Nyt1_with-relay_hits.pkl.gz               |   1858947 |
# |  10 |      42 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc12_with-relay_hits.pkl.gz              |   1894822 |
# |  11 |      37 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc01_with-relay_hits.pkl.gz              |   1895832 |
# |  12 |      35 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc11_with-relay_hits.pkl.gz              |   1898027 |
# |  13 |      60 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc23_with-relay_hits.pkl.gz              |   1902743 |
# |  14 |      51 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc04_with-relay_hits.pkl.gz              |   1908931 |
# |  15 |      67 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc29_with-relay_hits.pkl.gz              |   1910216 |
# |  16 |      64 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc20_with-relay_hits.pkl.gz              |   1916322 |
# |  17 |      62 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc27_with-relay_hits.pkl.gz              |   1917341 |
# |  18 |      63 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc28_with-relay_hits.pkl.gz              |   1924791 |
# |  19 |      49 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc05_with-relay_hits.pkl.gz              |   1929366 |
# |  20 |      54 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc16_with-relay_hits.pkl.gz              |   1933296 |
# |  21 |      55 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc14_with-relay_hits.pkl.gz              |   1934450 |
# |  22 |      38 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc02_with-relay_hits.pkl.gz              |   1939447 |
# |  23 |      69 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc18_with-relay_hits.pkl.gz              |   1942886 |
# |  24 |      40 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc09_with-relay_hits.pkl.gz              |   1943518 |
# |  25 |      56 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc19_with-relay_hits.pkl.gz              |   1946487 |
# |  26 |      52 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc17_with-relay_hits.pkl.gz              |   1947185 |
# |  27 |      45 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc24_with-relay_hits.pkl.gz              |   1949971 |
# |  28 |      36 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc10_with-relay_hits.pkl.gz              |   1953197 |
# |  29 |      57 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc25_with-relay_hits.pkl.gz              |   1953980 |
# |  30 |      68 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc13_with-relay_hits.pkl.gz              |   1955811 |
# |  31 |      46 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc08_with-relay_hits.pkl.gz              |   1964710 |
# |  32 |      39 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc00_with-relay_hits.pkl.gz              |   1966526 |
# |  33 |      50 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc06_with-relay_hits.pkl.gz              |   1967553 |
# |  34 |      47 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc07_with-relay_hits.pkl.gz              |   1972301 |
# |  35 |      53 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc15_with-relay_hits.pkl.gz              |   1976823 |
# |  36 |      58 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc21_with-relay_hits.pkl.gz              |   1978664 |
# |  37 |      44 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc26_with-relay_hits.pkl.gz              |   1980054 |
# |  38 |      41 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc03_with-relay_hits.pkl.gz              |   1993030 |
# |  39 |      59 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Pcc22_with-relay_hits.pkl.gz              |   2002756 |
# |  40 |      15 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc16_neg-raised_hits.pkl.gz              |   2112177 |
# |  41 |      33 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc13_neg-raised_hits.pkl.gz              |   2114522 |
# |  42 |      24 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc22_neg-raised_hits.pkl.gz              |   2116888 |
# |  43 |       8 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc08_neg-raised_hits.pkl.gz              |   2124996 |
# |  44 |      30 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc07_neg-raised_hits.pkl.gz              |   2128676 |
# |  45 |      10 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc06_neg-raised_hits.pkl.gz              |   2131255 |
# |  46 |      12 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc09_neg-raised_hits.pkl.gz              |   2134114 |
# |  47 |       3 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc01_neg-raised_hits.pkl.gz              |   2134410 |
# |  48 |      20 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc21_neg-raised_hits.pkl.gz              |   2137350 |
# |  49 |      28 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc29_neg-raised_hits.pkl.gz              |   2138326 |
# |  50 |      17 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc20_neg-raised_hits.pkl.gz              |   2141178 |
# |  51 |       5 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc05_neg-raised_hits.pkl.gz              |   2145438 |
# |  52 |      14 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc14_neg-raised_hits.pkl.gz              |   2146402 |
# |  53 |      27 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc27_neg-raised_hits.pkl.gz              |   2148145 |
# |  54 |      16 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc19_neg-raised_hits.pkl.gz              |   2150649 |
# |  55 |      19 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc18_neg-raised_hits.pkl.gz              |   2151408 |
# |  56 |      25 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc25_neg-raised_hits.pkl.gz              |   2151415 |
# |  57 |       6 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc00_neg-raised_hits.pkl.gz              |   2152251 |
# |  58 |       1 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc02_neg-raised_hits.pkl.gz              |   2159276 |
# |  59 |      32 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc28_neg-raised_hits.pkl.gz              |   2162492 |
# |  60 |      26 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc26_neg-raised_hits.pkl.gz              |   2162531 |
# |  61 |      23 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc24_neg-raised_hits.pkl.gz              |   2164543 |
# |  62 |       2 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc15_neg-raised_hits.pkl.gz              |   2171437 |
# |  63 |       4 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc04_neg-raised_hits.pkl.gz              |   2171934 |
# |  64 |       9 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc10_neg-raised_hits.pkl.gz              |   2178166 |
# |  65 |      13 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc12_neg-raised_hits.pkl.gz              |   2186406 |
# |  66 |       7 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc03_neg-raised_hits.pkl.gz              |   2190358 |
# |  67 |      21 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc23_neg-raised_hits.pkl.gz              |   2200075 |
# |  68 |      11 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc11_neg-raised_hits.pkl.gz              |   2205699 |
# |  69 |      18 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Pcc17_neg-raised_hits.pkl.gz              |   2214509 |
# |  70 |      34 | /share/compling/data/sanpi/2_hit_tables/raised/bigram-Nyt2_neg-raised_hits.pkl.gz               |   2389966 |
# |  71 |      66 | /share/compling/data/sanpi/2_hit_tables/scoped/bigram-Nyt2_with-relay_hits.pkl.gz               |   2500067 |
# |  72 |     101 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Apw_sans-relay_hits.pkl.gz                |  20111313 |
# |  73 |     139 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-PccVa_all-RB-JJs_hits.pkl.gz |  20682569 |
# |  74 |     138 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-PccTe_all-RB-JJs_hits.pkl.gz |  20770053 |
# |  75 |     102 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Nyt1_sans-relay_hits.pkl.gz               |  24366874 |
# |  76 |     104 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc02_sans-relay_hits.pkl.gz              |  27267466 |
# |  77 |      78 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc16_sans-relay_hits.pkl.gz              |  27283071 |
# |  78 |      84 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc23_sans-relay_hits.pkl.gz              |  27284428 |
# |  79 |      76 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc18_sans-relay_hits.pkl.gz              |  27326356 |
# |  80 |      73 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc19_sans-relay_hits.pkl.gz              |  27327729 |
# |  81 |      90 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc08_sans-relay_hits.pkl.gz              |  27336524 |
# |  82 |      91 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc00_sans-relay_hits.pkl.gz              |  27360183 |
# |  83 |      83 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc13_sans-relay_hits.pkl.gz              |  27380460 |
# |  84 |      88 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc20_sans-relay_hits.pkl.gz              |  27396970 |
# |  85 |      72 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc11_sans-relay_hits.pkl.gz              |  27409522 |
# |  86 |      74 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc06_sans-relay_hits.pkl.gz              |  27410079 |
# |  87 |      81 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc09_sans-relay_hits.pkl.gz              |  27415583 |
# |  88 |      89 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc21_sans-relay_hits.pkl.gz              |  27436900 |
# |  89 |      77 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc17_sans-relay_hits.pkl.gz              |  27440205 |
# |  90 |      96 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc28_sans-relay_hits.pkl.gz              |  27444208 |
# |  91 |      94 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc03_sans-relay_hits.pkl.gz              |  27447020 |
# |  92 |      93 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc05_sans-relay_hits.pkl.gz              |  27449519 |
# |  93 |      99 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc25_sans-relay_hits.pkl.gz              |  27453431 |
# |  94 |      87 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc01_sans-relay_hits.pkl.gz              |  27453477 |
# |  95 |     100 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc24_sans-relay_hits.pkl.gz              |  27466244 |
# |  96 |      92 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc04_sans-relay_hits.pkl.gz              |  27480163 |
# |  97 |      95 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc29_sans-relay_hits.pkl.gz              |  27496163 |
# |  98 |      86 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc12_sans-relay_hits.pkl.gz              |  27525314 |
# |  99 |      82 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc07_sans-relay_hits.pkl.gz              |  27578782 |
# | 100 |      85 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc22_sans-relay_hits.pkl.gz              |  27580618 |
# | 101 |      80 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc14_sans-relay_hits.pkl.gz              |  27612492 |
# | 102 |      97 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc27_sans-relay_hits.pkl.gz              |  27633706 |
# | 103 |      75 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc10_sans-relay_hits.pkl.gz              |  27674688 |
# | 104 |      79 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc15_sans-relay_hits.pkl.gz              |  27690362 |
# | 105 |      98 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Pcc26_sans-relay_hits.pkl.gz              |  27709638 |
# | 106 |     103 | /share/compling/data/sanpi/2_hit_tables/contig/bigram-Nyt2_sans-relay_hits.pkl.gz               |  34212736 |
# | 107 |     105 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Apw_all-RB-JJs_hits.pkl.gz   | 552814674 |
# | 108 |     106 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Nyt1_all-RB-JJs_hits.pkl.gz  | 614263683 |
# | 109 |     114 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc06_all-RB-JJs_hits.pkl.gz | 682773409 |
# | 110 |     127 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc19_all-RB-JJs_hits.pkl.gz | 683226065 |
# | 111 |     126 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc18_all-RB-JJs_hits.pkl.gz | 683396100 |
# | 112 |     116 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc08_all-RB-JJs_hits.pkl.gz | 683425676 |
# | 113 |     120 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc12_all-RB-JJs_hits.pkl.gz | 683624913 |
# | 114 |     128 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc20_all-RB-JJs_hits.pkl.gz | 683792076 |
# | 115 |     131 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc23_all-RB-JJs_hits.pkl.gz | 683833734 |
# | 116 |     108 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc00_all-RB-JJs_hits.pkl.gz | 684238162 |
# | 117 |     124 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc16_all-RB-JJs_hits.pkl.gz | 684380035 |
# | 118 |     130 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc22_all-RB-JJs_hits.pkl.gz | 684488433 |
# | 119 |     132 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc24_all-RB-JJs_hits.pkl.gz | 684535195 |
# | 120 |     113 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc05_all-RB-JJs_hits.pkl.gz | 684602901 |
# | 121 |     111 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc03_all-RB-JJs_hits.pkl.gz | 684721439 |
# | 122 |     136 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc28_all-RB-JJs_hits.pkl.gz | 685096125 |
# | 123 |     112 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc04_all-RB-JJs_hits.pkl.gz | 685307278 |
# | 124 |     109 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc01_all-RB-JJs_hits.pkl.gz | 685318675 |
# | 125 |     117 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc09_all-RB-JJs_hits.pkl.gz | 685497274 |
# | 126 |     125 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc17_all-RB-JJs_hits.pkl.gz | 685582048 |
# | 127 |     119 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc11_all-RB-JJs_hits.pkl.gz | 685594332 |
# | 128 |     133 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc25_all-RB-JJs_hits.pkl.gz | 685614099 |
# | 129 |     115 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc07_all-RB-JJs_hits.pkl.gz | 686250064 |
# | 130 |     118 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc10_all-RB-JJs_hits.pkl.gz | 686433511 |
# | 131 |     129 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc21_all-RB-JJs_hits.pkl.gz | 686450955 |
# | 132 |     122 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc14_all-RB-JJs_hits.pkl.gz | 686570699 |
# | 133 |     110 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc02_all-RB-JJs_hits.pkl.gz | 686699297 |
# | 134 |     137 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc29_all-RB-JJs_hits.pkl.gz | 687000622 |
# | 135 |     121 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc13_all-RB-JJs_hits.pkl.gz | 687125135 |
# | 136 |     123 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc15_all-RB-JJs_hits.pkl.gz | 687485651 |
# | 137 |     135 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc27_all-RB-JJs_hits.pkl.gz | 687717034 |
# | 138 |     134 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Pcc26_all-RB-JJs_hits.pkl.gz | 688332502 |
# | 139 |     107 | /share/compling/data/sanpi/2_hit_tables/advadj/with-context/bigram-Nyt2_all-RB-JJs_hits.pkl.gz  | 887298967 |

# %%
ddf = concat_pkls(pickles=hit_pkls[:75], convert_dtypes=True)
# ddf = concat_pkls(pickles=hit_pkls[:50], convert_dtypes=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb Cell 12 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> ddf = concat_pkls(pickles=hit_pkls[:75], convert_dtypes=True)
#
# /share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb Cell 12 in concat_pkls(data_dir, fname_glob, pickles, convert_dtypes, verbose)
#     <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=111'>112</a>     dup_check_cols = cols_by_str(df, end_str=('text', 'id', 'sent'))
#     <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=112'>113</a>     df = (df.loc[~df.duplicated(subset=dup_check_cols), :])
# --> <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=114'>115</a> c_df = pd.concat(sep_dfs)
#     <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=115'>116</a> dup_check_cols = cols_by_str(c_df, end_str=('text', 'id', 'sent'))
#     <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X14sdnNjb2RlLXJlbW90ZQ%3D%3D?line=116'>117</a> c_df = (c_df.loc[~c_df.duplicated(subset=dup_check_cols), :])
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/reshape/concat.py:347, in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     143 @deprecate_nonkeyword_arguments(version=None, allowed_args=["objs"])
#     144 def concat(
#     145     objs: Iterable[NDFrame] | Mapping[Hashable, NDFrame],
#    (...)
#     154     copy: bool = True,
#     155 ) -> DataFrame | Series:
#     156     """
#     157     Concatenate pandas objects along a particular axis with optional set logic
#     158     along the other axes.
#    (...)
#     345     ValueError: Indexes have overlapping values: ['a']
#     346     """
# --> 347     op = _Concatenator(
#     348         objs,
#     349         axis=axis,
#     350         ignore_index=ignore_index,
#     351         join=join,
#     352         keys=keys,
#     353         levels=levels,
#     354         names=names,
#     355         verify_integrity=verify_integrity,
#     356         copy=copy,
#     357         sort=sort,
#     358     )
#     360     return op.get_result()
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/reshape/concat.py:404, in _Concatenator.__init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     401     objs = list(objs)
#     403 if len(objs) == 0:
# --> 404     raise ValueError("No objects to concatenate")
#     406 if keys is None:
#     407     objs = list(com.not_none(*objs))
#
# ValueError: No objects to concatenate

# %% [markdown]
# ### Optimize DataFrame

# %%
odf = _optimize_df(ddf)
# Out:
# |             |     mem0 | dtype0   |   defined_values |   unique_values |   ratio_unique | dtype1   |     mem1 |   mem_change |
# |:------------|---------:|:---------|-----------------:|----------------:|---------------:|:---------|---------:|-------------:|
# | match_id    | 17574729 | string   |           263594 |            6283 |           0.02 | category |  1086069 |    -16488660 |
# | category    | 16606422 | string   |           263594 |               3 |           0    | category |   263891 |    -16342531 |
# | adj_lemma   | 16816300 | string   |           263594 |            7675 |           0.03 | category |  1295691 |    -15520609 |
# | adj_form    | 16831481 | string   |           263594 |            8110 |           0.03 | category |  1323527 |    -15507954 |
# | relay_lemma | 14558993 | string   |           179219 |           12100 |           0.07 | category |  1564856 |    -12994137 |
# | colloc      | 18357547 | string   |           263594 |           49088 |           0.19 | category |  5647041 |    -12710506 |
# | relay_form  | 14643872 | string   |           179219 |           16783 |           0.09 | category |  2133326 |    -12510546 |
# | nr_index    |   790782 | UInt16   |            78176 |             135 |           0    | category |   539348 |      -251434 |
# | relay_index |   790782 | UInt16   |           179219 |             173 |           0    | category |   541628 |      -249154 |
# | neg_index   |   790782 | UInt16   |           263594 |             191 |           0    | category |   542710 |      -248072 |
# | adv_index   |   790782 | UInt16   |           263594 |             196 |           0    | category |   543012 |      -247770 |
# | adj_index   |   790782 | UInt16   |           263594 |             196 |           0    | category |   543014 |      -247768 |
# | hit_text    | 27062610 | string   |           263594 |          200526 |           0.76 | category | 26937785 |      -124825 |
# | neg_form    |   269229 | category |           263594 |              57 |           0    | category |   269229 |            0 |
# | neg_lemma   |   265084 | category |           263594 |              15 |           0    | category |   265084 |            0 |
# | corpus      |   267009 | category |           263594 |              34 |           0    | category |   267009 |            0 |
# | nr_form     |   274798 | category |           263594 |             111 |           0    | category |   274798 |            0 |
# | nr_lemma    |   265655 | category |           263594 |              24 |           0    | category |   265655 |            0 |
# | adv_form    |   752452 | category |           263594 |            2422 |           0.01 | category |   752452 |            0 |
# | adv_lemma   |   739861 | category |           263594 |            2225 |           0.01 | category |   739861 |            0 |
# | text_window | 32433667 | string   |           263594 |          242992 |           0.92 | string   | 32433667 |            0 |
# | sent_text   | 49864904 | string   |           263594 |          244714 |           0.93 | string   | 49864904 |            0 |
# | sent_id     | 23050818 | string   |           263594 |          260065 |           0.99 | string   | 23050818 |            0 |
# | colloc_id   | 24465580 | string   |           263594 |          262175 |           0.99 | string   | 24465580 |            0 |
# | lemma_str   | 49486532 | string   |           263594 |          244472 |           0.93 | string   | 49487679 |         1147 |
# sent_text 	 string
# neg_form 	 category
# adv_form 	 category
# text_window 	 string
# sent_id 	 string
# colloc_id 	 string
# lemma_str 	 string
# neg_lemma 	 category
# adv_lemma 	 category
# corpus 	 category
# nr_form 	 category
# nr_lemma 	 category
# /tmp/ipykernel_2407718/2635148037.py:42: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[:, mem_improved] = catted_df.loc[:, mem_improved]
# Category Converted dataframe:
# <class 'pandas.core.frame.DataFrame'>
# Index: 263594 entries, pcc_eng_test_3.00526_x35290_08:1-4-8-9 to pcc_eng_29_001.9962_x0015951_068:3-4-8-9
# Data columns (total 25 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   colloc       263594 non-null  category
#  1   sent_text    263594 non-null  string
#  2   relay_form   263594 non-null  category
#  3   neg_form     263594 non-null  category
#  4   adv_form     263594 non-null  category
#  5   adj_form     263594 non-null  category
#  6   hit_text     263594 non-null  category
#  7   text_window  263594 non-null  string
#  8   sent_id      263594 non-null  string
#  9   match_id     263594 non-null  category
#  10  colloc_id    263594 non-null  string
#  11  lemma_str    263594 non-null  string
#  12  relay_lemma  263594 non-null  category
#  13  neg_lemma    263594 non-null  category
#  14  adv_lemma    263594 non-null  category
#  15  adj_lemma    263594 non-null  category
#  16  relay_index  263594 non-null  category
#  17  neg_index    263594 non-null  category
#  18  adv_index    263594 non-null  category
#  19  adj_index    263594 non-null  category
#  20  category     263594 non-null  category
#  21  corpus       263594 non-null  category
#  22  nr_form      263594 non-null  category
#  23  nr_lemma     263594 non-null  category
#  24  nr_index     263594 non-null  category
# dtypes: category(20), string(5)
# memory usage: 239.3 MB

# %%
columns = odf.columns[~odf.columns.isin(cols_by_str(
    odf, start_str=('dep_m', 'dep_n', 'dep_r', 'context')))].to_list()
columns.sort()
odf = odf.loc[:, columns]
len(odf) == len(ddf)
# Out:
# True

# %% [markdown]
# ⚠️ remove `any-direct` hits with `x_...` values filled

# %%
if 'x_form' in odf.columns: 
    x_cols = cols_by_str(odf, start_str='x')
    print(x_cols)

    odf = odf.loc[odf.x_form == '_', ~odf.columns.isin(x_cols)]

# %%
odf.loc[odf.corpus.str.contains('Pcc'), 'corpus_group'] = 'puddin'
odf.loc[odf.corpus.str.endswith(('Nyt1', 'Nyt2', 'Apw')), 'corpus_group'] = 'news'

general_counts = show_counts(odf, ['category', 'corpus_group'])

general_counts = general_counts.unstack()
general_counts = general_counts.sort_values(('count', 'puddin'), ascending=False)  # type: ignore
general_counts
# Out:
#                 count
# corpus_group     news    puddin
# category
# scoped        12405.0  166814.0
# raised        11428.0   66748.0
# contig            NaN    6199.0

# %% [markdown]
# *NOTE:* 👇 *`odf` is shorter (fewer rows) than original loaded hits because adverbs other than `'exactly'` have been dropped.*

# %%
len(odf) < len(ddf)
# Out:
# False

# %% [markdown]
# ### Add `conllu_id` and drop unused columns

# %%
odf = odf.assign(conllu_id=odf.sent_id.str.rsplit('_', 2).str.get(0).str.split(
    '.').str.get(0).astype('string').astype('category'))  # type: ignore
tdf = odf[cols_by_str(odf, end_str=('lemma', 'id', 'text', 'window',
                      'category', 'Pol')) + cols_by_str(odf, start_str=('corpus', 'lemma'))]
print(f'Total hits for all patterns: {len(tdf)}')
summary_tdf = summarize_text_cols(tdf)
summary_tdf
# Out:
# Total hits for all patterns: 263594
#                count  unique  \
# corpus_group  263594       2
# category      263594       3
# neg_lemma     263594      15
# nr_lemma      263594      24
# corpus        263594      34
# adv_lemma     263594    2225
# match_id      263594    6283
# adj_lemma     263594    7675
# conllu_id     263594    9426
# relay_lemma   263594   12099
# hit_text      263594  200526
# text_window   263594  242992
# lemma_str     263594  244472
# sent_text     263594  244714
# sent_id       263594  260065
# colloc_id     263594  262175
#
#                                                       top_value  top_freq  \
# corpus_group                                             puddin    239761
# category                                                 scoped    179219
# neg_lemma                                                    no     95292
# nr_lemma                                                      _    185418
# corpus                                             bigram-Pcc21     12361
# adv_lemma                                                   too     30360
# match_id                                                1-2-4-5     17968
# adj_lemma                                                  good     11688
# conllu_id                                         pcc_eng_val_2      1268
# relay_lemma                                                   _     84376
# hit_text                                      No job is too big      1231
# text_window                      No job is too big or too small       764
# lemma_str     never before have independent media be more en...       544
# sent_text     Never before has independent media been more e...       544
# sent_id                         pcc_eng_05_023.1527_x0358945_23         6
# colloc_id                 pcc_eng_05_023.1527_x0358945_23:13-14         6
#
#               top_percent
# corpus_group        90.96
# category            67.99
# neg_lemma           36.15
# nr_lemma            70.34
# corpus               4.69
# adv_lemma           11.52
# match_id             6.82
# adj_lemma            4.43
# conllu_id            0.48
# relay_lemma         32.01
# hit_text             0.47
# text_window          0.29
# lemma_str            0.21
# sent_text            0.21
# sent_id               0.0
# colloc_id             0.0

# %% [markdown]
# ## Identify $PosPol$ and $NegPol$ contexts

# %% [markdown]
# ### Option A
# bare collocation tokens (`advadj.all-RB-JJs` pattern match) which do not appear as matches for any other pattern match (i.e. $NegPol$ contexts).
#
# *That is, the `colloc_id` (unique `ADV` & `ADJ` nodes in unique sentence tokens) is not duplicated.*
#
# ```{python}
# tdfp_a = tdf.loc[(tdf.category=='advadj') & (~tdf.duplicated(subset='colloc_id', keep=False)), :]
# ```
#
# ### Option B
# categorize $NegPol$ set first (`tdfn`), then compute complement of that (i.e. $ALL - NegPol$)
#
# ```{python}
# tdfn = tdf.loc[tdf.neg_lemma!='_', :]
# tdfp = tdf.loc[~tdf.colloc_id.isin(tdfn.colloc_id), :]
# ```
#
# ### Options A and B are identical
#
# `all(tdfp_a.index == tdfp_b.index)` evaluates as true
#
# So, since $NegPol$ is more directly defined, and has to be separated out anyway, it's simpler to just get the "complement", (`tdfp_b` method)

# %%
tdfn = tdf.loc[tdf.neg_lemma != '_', :]
summarize_text_cols(tdfn)
# Out:
#                count  unique  \
# corpus_group  263594       2
# category      263594       3
# neg_lemma     263594      15
# nr_lemma      263594      24
# corpus        263594      34
# adv_lemma     263594    2225
# match_id      263594    6283
# adj_lemma     263594    7675
# conllu_id     263594    9426
# relay_lemma   263594   12099
# hit_text      263594  200526
# text_window   263594  242992
# lemma_str     263594  244472
# sent_text     263594  244714
# sent_id       263594  260065
# colloc_id     263594  262175
#
#                                                       top_value  top_freq  \
# corpus_group                                             puddin    239761
# category                                                 scoped    179219
# neg_lemma                                                    no     95292
# nr_lemma                                                      _    185418
# corpus                                             bigram-Pcc21     12361
# adv_lemma                                                   too     30360
# match_id                                                1-2-4-5     17968
# adj_lemma                                                  good     11688
# conllu_id                                         pcc_eng_val_2      1268
# relay_lemma                                                   _     84376
# hit_text                                      No job is too big      1231
# text_window                      No job is too big or too small       764
# lemma_str     never before have independent media be more en...       544
# sent_text     Never before has independent media been more e...       544
# sent_id                         pcc_eng_05_023.1527_x0358945_23         6
# colloc_id                 pcc_eng_05_023.1527_x0358945_23:13-14         6
#
#               top_percent
# corpus_group        90.96
# category            67.99
# neg_lemma           36.15
# nr_lemma            70.34
# corpus               4.69
# adv_lemma           11.52
# match_id             6.82
# adj_lemma            4.43
# conllu_id            0.48
# relay_lemma         32.01
# hit_text             0.47
# text_window          0.29
# lemma_str            0.21
# sent_text            0.21
# sent_id               0.0
# colloc_id             0.0

# %%
tdfn[['neg_lemma', 'adv_lemma', 'adj_lemma', 'hit_text', 
      'text_window', 
    #   'sent_text'
      ]].sample(25)
# Out:
#                                              neg_lemma    adv_lemma  \
# hit_id
# pcc_eng_17_076.7114_x1223615_32:06-07-22-23     rarely         only
# pcc_eng_08_008.1914_x0116299_12:13-15-17-18        few           as
# pcc_eng_13_021.9275_x0338306_11:40-42-47-48      never      finally
# pcc_eng_16_074.8470_x1195017_43:1-2-4-5            few           as
# pcc_eng_19_038.7455_x0609019_16:21-22-24-25        few         more
# pcc_eng_04_043.9559_x0694086_11:3-4-7-8            few   especially
# pcc_eng_13_095.0590_x1520108_47:08-09-12-13        not           as
# pcc_eng_17_093.1097_x1488440_075:01-03-18-19   without          not
# pcc_eng_17_085.4247_x1364425_88:12-13-16-17         no         very
# pcc_eng_07_108.06696_x1741620_7:03-05-11-12        not         very
# pcc_eng_13_098.5948_x1577100_11:07-08-20-21        not          too
# pcc_eng_08_105.6142_x1693870_04:3-4-5-6            not         very
# pcc_eng_01_013.6042_x0203387_49:14-15-24-25        not          too
# pcc_eng_12_064.2592_x1022753_11:04-05-22-23         no          not
# pcc_eng_18_065.7921_x1049170_21:09-10-13-14         no          too
# pcc_eng_27_097.4523_x1560151_02:11-12-14-15         no         more
# pcc_eng_06_018.2979_x0279803_05:1-2-4-5             no          too
# pcc_eng_09_068.6405_x1094309_52:04-05-09-10        not         that
# pcc_eng_29_080.0045_x1276294_138:14-15-16-17       not   especially
# pcc_eng_28_047.9681_x0759910_18:16-17-23-24         no  potentially
# pcc_eng_28_003.2560_x0036377_060:03-04-19-20       few           as
# pcc_eng_04_106.5358_x1704858_05:21-23-26-27         no           so
# pcc_eng_25_018.9869_x0290651_10:08-09-22-23         no        hella
# pcc_eng_06_060.4501_x0961897_03:04-05-15-16        not   physically
# pcc_eng_22_024.7867_x0383568_03:1-2-4-5             no         more
#
#                                                 adj_lemma  \
# hit_id
# pcc_eng_17_076.7114_x1223615_32:06-07-22-23       logical
# pcc_eng_08_008.1914_x0116299_12:13-15-17-18       fraught
# pcc_eng_13_021.9275_x0338306_11:40-42-47-48          able
# pcc_eng_16_074.8470_x1195017_43:1-2-4-5       frustrating
# pcc_eng_19_038.7455_x0609019_16:21-22-24-25      familiar
# pcc_eng_04_043.9559_x0694086_11:3-4-7-8             broad
# pcc_eng_13_095.0590_x1520108_47:08-09-12-13   progressive
# pcc_eng_17_093.1097_x1488440_075:01-03-18-19     possible
# pcc_eng_17_085.4247_x1364425_88:12-13-16-17          wise
# pcc_eng_07_108.06696_x1741620_7:03-05-11-12    functional
# pcc_eng_13_098.5948_x1577100_11:07-08-20-21      alarming
# pcc_eng_08_105.6142_x1693870_04:3-4-5-6          exciting
# pcc_eng_01_013.6042_x0203387_49:14-15-24-25        fussed
# pcc_eng_12_064.2592_x1022753_11:04-05-22-23      uncommon
# pcc_eng_18_065.7921_x1049170_21:09-10-13-14         small
# pcc_eng_27_097.4523_x1560151_02:11-12-14-15       shocked
# pcc_eng_06_018.2979_x0279803_05:1-2-4-5               big
# pcc_eng_09_068.6405_x1094309_52:04-05-09-10         great
# pcc_eng_29_080.0045_x1276294_138:14-15-16-17   interested
# pcc_eng_28_047.9681_x0759910_18:16-17-23-24    reversible
# pcc_eng_28_003.2560_x0036377_060:03-04-19-20   remarkable
# pcc_eng_04_106.5358_x1704858_05:21-23-26-27     important
# pcc_eng_25_018.9869_x0290651_10:08-09-22-23          ugly
# pcc_eng_06_060.4501_x0961897_03:04-05-15-16         ready
# pcc_eng_22_024.7867_x0383568_03:1-2-4-5       responsible
#
#                                                                                        hit_text  \
# hit_id
# pcc_eng_17_076.7114_x1223615_32:06-07-22-23   rarely offers three decades of job security pl...
# pcc_eng_08_008.1914_x0116299_12:13-15-17-18           few demographic categories are as fraught
# pcc_eng_13_021.9275_x0338306_11:40-42-47-48           never did come out , we were finally able
# pcc_eng_16_074.8470_x1195017_43:1-2-4-5                           Few things are as frustrating
# pcc_eng_19_038.7455_x0609019_16:21-22-24-25                         few songs are more familiar
# pcc_eng_04_043.9559_x0694086_11:3-4-7-8                    few films have been especially broad
# pcc_eng_13_095.0590_x1520108_47:08-09-12-13                  n't think Labour is as progressive
# pcc_eng_17_093.1097_x1488440_075:01-03-18-19  Without the interactions and development produ...
# pcc_eng_17_085.4247_x1364425_88:12-13-16-17                             no doubt , is very wise
# pcc_eng_07_108.06696_x1741620_7:03-05-11-12    not only looks good ; it is also very functional
# pcc_eng_13_098.5948_x1577100_11:07-08-20-21   n't think his comments around his job being " ...
# pcc_eng_08_105.6142_x1693870_04:3-4-5-6                                  n't seem very exciting
# pcc_eng_01_013.6042_x0203387_49:14-15-24-25   n't look super real , and my client is n't too...
# pcc_eng_12_064.2592_x1022753_11:04-05-22-23   no stranger to harsh winters , the likelihood ...
# pcc_eng_18_065.7921_x1049170_21:09-10-13-14                          no niche is just too small
# pcc_eng_27_097.4523_x1560151_02:11-12-14-15                             no one was more shocked
# pcc_eng_06_018.2979_x0279803_05:1-2-4-5                                       No job is too big
# pcc_eng_09_068.6405_x1094309_52:04-05-09-10                    n't seem to have been that great
# pcc_eng_29_080.0045_x1276294_138:14-15-16-17                     n't seem especially interested
# pcc_eng_28_047.9681_x0759910_18:16-17-23-24   No changes yet that would n't be potentially r...
# pcc_eng_28_003.2560_x0036377_060:03-04-19-20  few days , two women walking hand - ln- hand d...
# pcc_eng_04_106.5358_x1704858_05:21-23-26-27       no chemical carcinogen is nearly so important
# pcc_eng_25_018.9869_x0290651_10:08-09-22-23   no matter how much you might not care about gr...
# pcc_eng_06_060.4501_x0961897_03:04-05-15-16   n't think there would be any way possible he w...
# pcc_eng_22_024.7867_x0383568_03:1-2-4-5                              No one is more responsible
#
#                                                                                     text_window
# hit_id
# pcc_eng_17_076.7114_x1223615_32:06-07-22-23   fickle employment market rarely offers three d...
# pcc_eng_08_008.1914_x0116299_12:13-15-17-18   the DPRK , few demographic categories are as f...
# pcc_eng_13_021.9275_x0338306_11:40-42-47-48   while the sun never did come out , we were fin...
# pcc_eng_16_074.8470_x1195017_43:1-2-4-5               Few things are as frustrating as having a
# pcc_eng_19_038.7455_x0609019_16:21-22-24-25     Grace , " few songs are more familiar , and yet
# pcc_eng_04_043.9559_x0694086_11:3-4-7-8       His past few films have been especially broad ...
# pcc_eng_13_095.0590_x1520108_47:08-09-12-13   , I do n't think Labour is as progressive or i...
# pcc_eng_17_093.1097_x1488440_075:01-03-18-19  Without the interactions and development produ...
# pcc_eng_17_085.4247_x1364425_88:12-13-16-17   floor project , no doubt , is very wise , very...
# pcc_eng_07_108.06696_x1741620_7:03-05-11-12   The Coco not only looks good ; it is also very...
# pcc_eng_13_098.5948_x1577100_11:07-08-20-21   , I do n't think his comments around his job b...
# pcc_eng_08_105.6142_x1693870_04:3-4-5-6                  It did n't seem very exciting to us --
# pcc_eng_01_013.6042_x0203387_49:14-15-24-25   big firms do n't look super real , and my clie...
# pcc_eng_12_064.2592_x1022753_11:04-05-22-23   Since Connecticut is no stranger to harsh wint...
# pcc_eng_18_065.7921_x1049170_21:09-10-13-14   account is that no niche is just too small to ...
# pcc_eng_27_097.4523_x1560151_02:11-12-14-15   world , but no one was more shocked than Hilla...
# pcc_eng_06_018.2979_x0279803_05:1-2-4-5                          No job is too big or too small
# pcc_eng_09_068.6405_x1094309_52:04-05-09-10   Its reception does n't seem to have been that ...
# pcc_eng_29_080.0045_x1276294_138:14-15-16-17  stepmother who did n't seem especially interes...
# pcc_eng_28_047.9681_x0759910_18:16-17-23-24   said : " No changes yet that would n't be pote...
# pcc_eng_28_003.2560_x0036377_060:03-04-19-20  For a few days , two women walking hand - ln- ...
# pcc_eng_04_106.5358_x1704858_05:21-23-26-27   said that " no chemical carcinogen is nearly s...
# pcc_eng_25_018.9869_x0290651_10:08-09-22-23   everyone , because no matter how much you migh...
# pcc_eng_06_060.4501_x0961897_03:04-05-15-16   " I did n't think there would be any way possi...
# pcc_eng_22_024.7867_x0383568_03:1-2-4-5       No one is more responsible for marijuana prohi...

# %%
tdfp = tdf.loc[~tdf.colloc_id.isin(tdfn.colloc_id), :]
summarize_text_cols(tdfp)
# Out:
#               count  unique  top_value  top_freq  top_percent
# adj_lemma         0       0       <NA>      <NA>         <NA>
# adv_lemma         0       0       <NA>      <NA>         <NA>
# category          0       0       <NA>      <NA>         <NA>
# colloc_id         0       0       <NA>      <NA>         <NA>
# hit_text          0       0       <NA>      <NA>         <NA>
# match_id          0       0       <NA>      <NA>         <NA>
# neg_lemma         0       0       <NA>      <NA>         <NA>
# nr_lemma          0       0       <NA>      <NA>         <NA>
# relay_lemma       0       0       <NA>      <NA>         <NA>
# sent_id           0       0       <NA>      <NA>         <NA>
# sent_text         0       0       <NA>      <NA>         <NA>
# text_window       0       0       <NA>      <NA>         <NA>
# conllu_id         0       0       <NA>      <NA>         <NA>
# corpus            0       0       <NA>      <NA>         <NA>
# lemma_str         0       0       <NA>      <NA>         <NA>
# corpus_group      0       0       <NA>      <NA>         <NA>

# %% [markdown]
# ## Assign `polarity` and recombine

# %%
tdfp = tdfp.assign(polarity='positive')
tdfn = tdfn.assign(polarity='negative')
tdf_with_overlap = tdf
pol_union_df = pd.concat([tdfp, tdfn]).sort_values('colloc_id')

print(
    f'Total bare `exactly ADJ` collocations: {odf.category.value_counts()["advadj"]}')
print(
    f'Total `exactly` pattern hits (+ NegPol pattern overlap): {len(pol_union_df)}')
print(f'PosPol: {round(100*len(tdfp)/len(pol_union_df))}% : {len(tdfp)} hits')
print(
    f'NegPol: {str(round(100*len(tdfn)/len(pol_union_df))).zfill(2)}% : {len(tdfn)} hits')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'advadj'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb Cell 29 in <cell line: 6>()
#       <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=2'>3</a> tdf_with_overlap = tdf
#       <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=3'>4</a> pol_union_df = pd.concat([tdfp, tdfn]).sort_values('colloc_id')
#       <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=5'>6</a> print(
# ----> <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=6'>7</a>     f'Total bare `exactly ADJ` collocations: {odf.category.value_counts()["advadj"]}')
#       <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=7'>8</a> print(
#       <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=8'>9</a>     f'Total `exactly` pattern hits (+ NegPol pattern overlap): {len(pol_union_df)}')
#      <a href='vscode-notebook-cell://ssh-remote%2Bcompling-compute-02.compling.cornell.edu/share/compling/projects/sanpi/notebooks/inspect-bigram-hits.ipynb#X33sdnNjb2RlLXJlbW90ZQ%3D%3D?line=9'>10</a> print(f'PosPol: {round(100*len(tdfp)/len(pol_union_df))}% : {len(tdfp)} hits')
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/series.py:958, in Series.__getitem__(self, key)
#     955     return self._values[key]
#     957 elif key_is_scalar:
# --> 958     return self._get_value(key)
#     960 if is_hashable(key):
#     961     # Otherwise index.get_value will raise InvalidIndexError
#     962     try:
#     963         # For labels that don't resolve as scalars like tuples and frozensets
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/series.py:1069, in Series._get_value(self, label, takeable)
#    1066     return self._values[label]
#    1068 # Similar to Index.get_value, but we do not fall back to positional
# -> 1069 loc = self.index.get_loc(label)
#    1070 return self.index._get_values_for_loc(self, loc, label)
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/indexes/base.py:3619, in Index.get_loc(self, key, method, tolerance)
#    3614 if tolerance is not None:
#    3615     raise ValueError(
#    3616         "tolerance argument only valid if using pad, "
#    3617         "backfill or nearest lookups"
#    3618     )
# -> 3619 casted_key = self._maybe_cast_indexer(key)
#    3620 try:
#    3621     return self._engine.get_loc(casted_key)
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/indexes/category.py:471, in CategoricalIndex._maybe_cast_indexer(self, key)
#     467 def _maybe_cast_indexer(self, key) -> int:
#     468     # GH#41933: we have to do this instead of self._data._validate_scalar
#     469     #  because this will correctly get partial-indexing on Interval categories
#     470     try:
# --> 471         return self._data._unbox_scalar(key)
#     472     except KeyError:
#     473         if is_valid_na_for_dtype(key, self.categories.dtype):
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/arrays/categorical.py:1956, in Categorical._unbox_scalar(self, key)
#    1953 def _unbox_scalar(self, key) -> int:
#    1954     # searchsorted is very performance sensitive. By converting codes
#    1955     # to same dtype as self.codes, we get much faster performance.
# -> 1956     code = self.categories.get_loc(key)
#    1957     code = self._ndarray.dtype.type(code)
#    1958     return code
#
# File ~/.conda/envs/dev-sanpi/lib/python3.10/site-packages/pandas/core/indexes/base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: 'advadj'

# %% [markdown]
# ### Pickle Pos+Neg Dataframe

# %%
# pol_union_df.to_pickle(
#     '/share/compling/projects/sanpi/notebooks/bigram_out/all-exactly-hits_text+polarity.pkl.gz')

# %% [markdown]
# ## Frequency by Polarity

# %% [markdown]
# ### Simple Frequency Comparison

# %%
top_200 = show_counts(pol_union_df, ['polarity', 'adj_lemma']).head(200)
top_200
# Out:
#                       count
# polarity adj_lemma
# positive much         83407
#          important    61485
#          many         57946
#          cloudy       50578
#          good         50526
# ...                     ...
#          lucrative     2367
#          unclear       2359
#          fine          2356
#          present       2353
#          appropriate   2348
#
# [200 rows x 1 columns]

# %%
top_200_neg = show_counts(pol_union_df.loc[pol_union_df.polarity=='negative', :], ['polarity', 'adj_lemma']).head(200)
top_200_neg
# Out:
#                      count
# polarity adj_lemma
# negative clear       16551
#          available   15788
#          good         3571
#          bad          3114
#          sure         2737
# ...                    ...
#          special        69
#          sweet          68
#          promising      68
#          rich           68
#          satisfying     67
#
# [200 rows x 1 columns]

# %%
spread_top_200 = top_200.unstack(level='polarity', fill_value=0)
spread_top_200.sort_values(('count', 'negative'),
                           ascending=False).head(30)  # type: ignore
# Out:
#                  count
# polarity      negative positive
# adj_lemma
# clear            16551    12220
# available        15788     8526
# good              3571    50526
# bad               3114    12827
# sure              2737     3957
# much                 0    83407
# experienced          0     3132
# independent          0     3378
# right                0     3374
# necessary            0     3363
# advanced             0     3353
# sophisticated        0     3252
# wide                 0     3250
# nervous              0     3249
# profitable           0     3206
# fast                 0     3132
# old                  0     3477
# angry                0     3116
# dramatic             0     3109
# volatile             0     3104
# unpopular            0     3103
# friendly             0     3088
# similar              0     3082
# prestigious          0     3082
# disappointing        0     2991
# careful              0     2959
# painful              0     2957
# tight                0     3414
# impressive           0     3546
# rare                 0     3505

# %%
spread_top_200.sort_values(('count', 'positive'),
                           ascending=False).head(30)  # type: ignore
# Out:
#               count
# polarity   negative positive
# adj_lemma
# much              0    83407
# important         0    61485
# many              0    57946
# cloudy            0    50578
# good           3571    50526
# difficult         0    36910
# high              0    29277
# more              0    27604
# likely            0    25740
# popular           0    21585
# serious           0    20405
# higher            0    19894
# strong            0    19579
# happy             0    17873
# different         0    17554
# dangerous         0    16575
# powerful          0    16452
# low               0    16010
# expensive         0    14544
# lower             0    13968
# concerned         0    13841
# close             0    13384
# bad            3114    12827
# recent            0    12710
# better            0    12651
# hard              0    12621
# clear         16551    12220
# successful        0    11762
# little            0    11601
# small             0    10738

# %% [markdown]
# ### Crosstabulate adjective by context polarity

# %%
freq_dist = pd.crosstab(pol_union_df.adj_lemma,
                        pol_union_df.polarity,
                        margins=True, margins_name='TOTAL')

freq_dist = freq_dist.assign(
    ratio_neg=(freq_dist.negative/freq_dist.TOTAL).round(3),
    ratio_pos=(freq_dist.positive/freq_dist.TOTAL).round(3))

freq_dist = freq_dist.assign(
    bin_neg=freq_dist.ratio_neg.round(1),
    bin_pos=freq_dist.ratio_pos.round(1))

cols = freq_dist.columns.to_list()
cols.pop(cols.index('TOTAL'))
freq_dist = freq_dist[['TOTAL'] + cols]

freq_dist.sort_values('TOTAL', ascending=False)
# Out:
# polarity           TOTAL  negative  positive  ratio_neg  ratio_pos  bin_neg  \
# adj_lemma
# TOTAL            2572234    113814   2458420      0.044      0.956      0.0
# much               84741      1334     83407      0.016      0.984      0.0
# important          62835      1350     61485      0.021      0.979      0.0
# many               58233       287     57946      0.005      0.995      0.0
# good               54097      3571     50526      0.066      0.934      0.1
# ...                  ...       ...       ...        ...        ...      ...
# black-supported        1         0         1      0.000      1.000      0.0
# misspell               1         0         1      0.000      1.000      0.0
# missionary-like        1         0         1      0.000      1.000      0.0
# blackburn              1         0         1      0.000      1.000      0.0
# &comma                 1         0         1      0.000      1.000      0.0
#
# polarity         bin_pos
# adj_lemma
# TOTAL                1.0
# much                 1.0
# important            1.0
# many                 1.0
# good                 0.9
# ...                  ...
# black-supported      1.0
# misspell             1.0
# missionary-like      1.0
# blackburn            1.0
# &comma               1.0
#
# [35594 rows x 7 columns]

# %%
freq_thresh5 = freq_dist.loc[freq_dist.TOTAL >= 5, :]
freq_thresh5 = freq_thresh5.sort_values(
    ['bin_neg', 'TOTAL', 'ratio_neg'], ascending=False)
freq_thresh5.to_csv(
    '/share/compling/projects/sanpi/notebooks/bigram_out/freq_thresh5.csv')
freq_thresh5
# Out:
# polarity       TOTAL  negative  positive  ratio_neg  ratio_pos  bin_neg  \
# adj_lemma
# 0                 29        26         3      0.897      0.103      0.9
# batsmen           31        24         7      0.774      0.226      0.8
# curfew             6         5         1      0.833      0.167      0.8
# fussed             6         5         1      0.833      0.167      0.8
# begun              5         4         1      0.800      0.200      0.8
# ...              ...       ...       ...        ...        ...      ...
# y                  5         0         5      0.000      1.000      0.0
# yellow-carded      5         0         5      0.000      1.000      0.0
# yemeni             5         0         5      0.000      1.000      0.0
# yiddish            5         0         5      0.000      1.000      0.0
# zen-like           5         0         5      0.000      1.000      0.0
#
# polarity       bin_pos
# adj_lemma
# 0                  0.1
# batsmen            0.2
# curfew             0.2
# fussed             0.2
# begun              0.2
# ...                ...
# y                  1.0
# yellow-carded      1.0
# yemeni             1.0
# yiddish            1.0
# zen-like           1.0
#
# [9083 rows x 7 columns]

# %%
freq_dist.ratio_neg.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
freq_dist.loc[freq_dist.index!='TOTAL', ['negative', 'positive']].plot(x='negative', y ='positive', kind='scatter')
# Out:
# <AxesSubplot:xlabel='negative', ylabel='positive'>

# %%
freq_dist.loc[freq_dist.index!='TOTAL', ['negative', 'positive']].plot(x='negative', y ='positive', kind='density')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
freq_dist.ratio_pos.plot(kind='hist')
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
freq_thresh100 = freq_dist.loc[freq_dist.TOTAL >= 100, :]
freq_thresh100 = freq_thresh100.sort_values(
    ['ratio_neg','TOTAL', 'bin_neg', ], ascending=False)
freq_thresh100.to_csv(
    '/share/compling/projects/sanpi/notebooks/bigram_out/freq_thresh100.csv')
freq_thresh100
# Out:
# polarity     TOTAL  negative  positive  ratio_neg  ratio_pos  bin_neg  bin_pos
# adj_lemma
# available    24314     15788      8526      0.649      0.351      0.6      0.4
# clear        28771     16551     12220      0.575      0.425      0.6      0.4
# sure          6694      2737      3957      0.409      0.591      0.4      0.6
# ripe           200        66       134      0.330      0.670      0.3      0.7
# comparable     279        85       194      0.305      0.695      0.3      0.7
# ...            ...       ...       ...        ...        ...      ...      ...
# pashtun        102         0       102      0.000      1.000      0.0      1.0
# three-month    102         0       102      0.000      1.000      0.0      1.0
# distrustful    100         0       100      0.000      1.000      0.0      1.0
# impassable     100         0       100      0.000      1.000      0.0      1.0
# restless       100         0       100      0.000      1.000      0.0      1.0
#
# [1949 rows x 7 columns]

# %%
freq_thresh200 = freq_dist.loc[freq_dist.TOTAL >= 200, :]
freq_thresh200 = freq_thresh200.sort_values(
    ['bin_neg', 'TOTAL', 'ratio_neg'], ascending=False)
freq_thresh200.to_csv(
    '/share/compling/projects/sanpi/notebooks/bigram_out/freq_thresh200.csv')
freq_thresh200
# Out:
# polarity   TOTAL  negative  positive  ratio_neg  ratio_pos  bin_neg  bin_pos
# adj_lemma
# clear      28771     16551     12220      0.575      0.425      0.6      0.4
# available  24314     15788      8526      0.649      0.351      0.6      0.4
# sure        6694      2737      3957      0.409      0.591      0.4      0.6
# binding     1979       505      1474      0.255      0.745      0.3      0.7
# final        382       105       277      0.275      0.725      0.3      0.7
# ...          ...       ...       ...        ...        ...      ...      ...
# southwest    201         0       201      0.000      1.000      0.0      1.0
# engaging     200         5       195      0.025      0.975      0.0      1.0
# feminine     200         5       195      0.025      0.975      0.0      1.0
# moral        200         5       195      0.025      0.975      0.0      1.0
# stricter     200         0       200      0.000      1.000      0.0      1.0
#
# [1268 rows x 7 columns]

# %% [markdown]
# ## Save $PosPol$ text data
#
# Since $PosPol$ is defined as the complement of $NegPol$, accuracy relies on $NegPol$ catching all relevant cases.
#
# To ensure pattern specifications are sufficiently inclusive, all sentences with supposedly positive polarity
# should be manually inspected for any errant (uncaught) negative lemmas, as identified in the $NegPol$ pattern specifications.
#
# ```{ocaml}
# NEG [lemma="hardly"|"scarcely"|"never"|"rarely"|"barely"|"seldom"|"no"|"nothing"|"none"|"nobody"|"neither"|"without"|"few"|"nor"];
# ```
#
# - [x] create simplified output of $PosPol$/`tdfp` sentence text data, with necessary identifiers
# - [x] save as csv
# - [ ] grep `pos_sentences.csv` for each neg lemma:\
#   *There should not be any negative lemmas an `exactly JJ` collocation in its scope.*

# %%
select_cols = ['adj_lemma', 'text_window', 'sent_text',
               'sent_id', 'conllu_id', 'corpus']
pos_text_info = tdfp.loc[:, select_cols]
pos_text_info = pos_text_info.assign(
    adj_neg_ratio=pos_text_info.adj_lemma.apply(lambda a: freq_dist.loc[a, 'ratio_neg'] if a in freq_dist.index else None))  # type: ignore
pos_text_info.sort_values(['adj_neg_ratio', 'conllu_id'], ascending=False)
pos_text_info.to_csv(
    '/share/compling/projects/sanpi/notebooks/bigram_out/pos_sentences.csv')

# tdfp.adj_lemma[~tdfp.adj_lemma.isin(freq_dist.index)].value_counts()
# TODO?? why does it say there is a mismatch between the crosstab and pospol adj set?
# ^ 🤔 probably something to do with categorical dtype

# %%
freq_thresh5.describe().round(2)
# Out:
# polarity       TOTAL   negative    positive  ratio_neg  ratio_pos  bin_neg  \
# count        9083.00    9083.00     9083.00    9083.00    9083.00  9083.00
# mean          562.06      24.94      537.12       0.03       0.97     0.02
# std         27057.49    1220.49    25860.63       0.06       0.06     0.06
# min             5.00       0.00        1.00       0.00       0.10     0.00
# 25%             8.00       0.00        8.00       0.00       0.97     0.00
# 50%            19.00       0.00       18.00       0.00       1.00     0.00
# 75%            74.00       2.00       72.00       0.03       1.00     0.00
# max       2572234.00  113814.00  2458420.00       0.90       1.00     0.90
#
# polarity  bin_pos
# count     9083.00
# mean         0.98
# std          0.06
# min          0.10
# 25%          1.00
# 50%          1.00
# 75%          1.00
# max          1.00

# %%
# pol_union_thresh5 = pol_union_df.loc[pol_union_df.adj_lemma]
adj_x_cat = (pd.crosstab(index=pol_union_df.adj_lemma, columns=pol_union_df.category, 
                         margins=True, margins_name='TOTAL', normalize='index')
             .rename(columns={'advadj':'PosPol', 'contig':'contig_NegPol', 
                              'raised': 'raised_NegPol', 'scoped':'scoped_NegPol'})
             .round(3))
adj_x_cat.loc[adj_x_cat.index.isin(freq_thresh200.index), :]
# Out:
# category   PosPol  contig_NegPol  raised_NegPol  scoped_NegPol
# adj_lemma
# 5-4         1.000          0.000          0.000          0.000
# able        0.905          0.087          0.002          0.006
# absent      0.989          0.007          0.001          0.002
# absurd      0.967          0.030          0.002          0.002
# abundant    0.981          0.019          0.000          0.000
# ...           ...            ...            ...            ...
# worthy      0.949          0.045          0.003          0.003
# wrong       0.954          0.042          0.002          0.002
# young       0.987          0.010          0.001          0.001
# younger     0.920          0.080          0.000          0.000
# TOTAL       0.956          0.039          0.002          0.003
#
# [1268 rows x 4 columns]

# %%
adj_x_neg = pd.crosstab(index=pol_union_df.adj_lemma,
                        columns=pol_union_df.neg_lemma, margins=True)
adj_x_neg.nlargest(20, columns=['All'])
# Out:
# neg_lemma        _  barely  few  hardly  neither  never    no  nobody  none  \
# adj_lemma
# All        2458420      50  910     137      537   2590  6947     325   622
# much         83407       2    2       1        1     20    15       3     1
# important    61485       0   24       2        0     59   169       2    21
# many         57946       3    5       0        0     10     2       0     2
# good         50526       1   15       0       12    135    44       9    12
# cloudy       50578       0    0       0        0      0     0       0     0
# difficult    36910       0   25       0        4     18    32       2     3
# high         29277       2    1       0        4     24    14       0     0
# clear        12220       0    1       1        3     45    31       1     0
# more         27604       1    3       0        0      2     4       2     0
# likely       25740       1    8       0        3      2    40       0     6
# available     8526       0  103       0      174      4  3209      40    25
# popular      21585       0    3       1        5     41    13       0     5
# serious      20405       0    3       1        1     19    32       0     6
# strong       19579       0    2       0        3     36    19       0     7
# higher       19894       0    0       0        0      1     2       0     1
# happy        17873       0    3       1       11     56    27      12    11
# different    17554       0    0      22        5      5     6       0     0
# dangerous    16575       0    4       0        1     10    52       1     5
# powerful     16452       0    4       0        3      6    11       0     3
#
# neg_lemma  nor    not  nothing  rarely  scarcely  seldom  without      All
# adj_lemma
# All        297  99418      749     128        24      21     1059  2572234
# much         3   1277        1       0         0       0        8    84741
# important    1    946      107       1         0       2       16    62835
# many         0    262        0       1         0       0        2    58233
# good         1   3310       11       2         0       1       18    54097
# cloudy       0      2        0       0         0       0        0    50580
# difficult    1    492        9       2         0       1      137    37636
# high         1    703        0       3         0       0        5    30034
# clear        4  16453        7       0         1       0        4    28771
# more         0    139        0       0         0       0       13    27768
# likely       1    199        6       0         0       0       30    26036
# available  138  12091        1       0         0       0        3    24314
# popular      1    351        0       2         0       0        2    22009
# serious      0    616       21       0         0       0        3    21107
# strong       0   1102        1       0         0       0       12    20761
# higher       0     58        0       0         0       0       11    19967
# happy        6   1090        3       4         0       0        4    19101
# different    7   1098       13       0         8       0        9    18727
# dangerous    1    246       20       0         0       0       12    16927
# powerful     0    121        2       0         0       0        1    16603
