# %%
# %%

import pandas as pd

from source.utils import FREQ_DIR, RESULT_DIR, UCS_DIR, confirm_dir
from source.utils.associate import (BINARY_ASSOC_ARGS, add_extra_am,
                                    associate_ucs, confirm_basic_ucs)
from source.utils.associate import convert_ucs_to_csv as ucs2csv
from source.utils.associate import get_associations_csv as init_am, AM_DF_DIR
from source.utils.associate import manipulate_ucs, seek_readable_ucs, adjust_assoc_columns
pd.set_option('display.float_format', '{:,.2f}'.format)

# %% [markdown]
# # %% [markdown]
#
#  set parameters

# %%
UNIT = 'Adj'
# PAT_DIR = 'POSmirror'
# PAT_DIR = 'NEGmirror'
PAT_DIR = 'ANYmirror'
# PAT_DIR = 'RBdirect'
# PAT_DIR = 'RBXadj'
# FRQ_FLOOR = 3
# FRQ_FLOOR = 10
# FRQ_FLOOR = 20
# FRQ_FLOOR = 50
FRQ_FLOOR = 100  # BUG 100 will be used regardless, so set it to this to at least keep the naming accurate
ADVADJ_TSV = FREQ_DIR.joinpath(
    f'{PAT_DIR}/ucs_format/Adv{UNIT}_frq-thrMIN-7.35f.tsv')
FOCUS = ['f', 'unexpected_f',
         'conservative_log_ratio',
         'am_p1_given2', 'am_p2_given1',
         'am_p1_given2_simple', 'am_p2_given1_simple',
         'am_log_likelihood',
         #  'mutual_information', 'am_odds_ratio_disc', 't_score',
         'N', 'f1', 'f2', 'E11',
         'l1', 'l2']

# %%
# %%

def invert_set_dict(d: dict):
    return {v: k for k in d for v in d[k]}

# %% [markdown]
# # %% [markdown]
#
#  1. Run `seek_readable_ucs()` to generate consistent output path

# %%
readable = seek_readable_ucs(min_freq=FRQ_FLOOR,
                             ucs_subdir='adv_adj',
                             contained_counts_path=ADVADJ_TSV)
print(readable.relative_to(RESULT_DIR))
# Out:
#     > seeking `adv_adj/ANYmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x*` frequency data and initial associations...
# ucs/adv_adj/ANYmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv

# %% [markdown]
# # %% [markdown]
#
#  Snippet of starting frequency data (`ADVADJ_TSV`)

# %%
! head -5 {ADVADJ_TSV} | column -t
# Out:
# 14875  as          simple
# 10996  more        important
# 8327   completely  different
# 7819   more        likely
# 7221   too         easy

# %% [markdown]
# # %% [markdown]
#
#  2. Run `confirm_basic_ucs()` (if needed)

# %%
if not readable.is_file():
    basic_ucs_path = readable.parent.parent.joinpath(
        readable.name.replace('.rsort-view_am-only.txt', '.ds.gz'))
    print(
        f'Creating initial UCS table: `{basic_ucs_path.relative_to(RESULT_DIR)}')

    basic_ucs_path = confirm_basic_ucs(
        basic_ucs_path,
        freq_floor=FRQ_FLOOR,
        contained_counts_path=ADVADJ_TSV)

# %% [markdown]
# # %% [markdown]
#
#  Excerpt of initial UCS table

# %%
init_readable = UCS_DIR.joinpath(
    f'adv_adj/{PAT_DIR}/readable'
).joinpath(f'{ADVADJ_TSV.name.replace(".tsv","")}_min{FRQ_FLOOR}x.init.txt')
! head -7 {init_readable}
# Out:
#              l1  l2                    f     f2      f1        N
# ---------------  ----------------  -----  -----  ------  -------
#            more  important         23085  43776  285602  1761853
#            very  important          6209  43776  184009  1761853
#             too  important           252  43776  158082  1761853
#              so  important          1739  43776  129602  1761853
#              as  important          3417  43776  108116  1761853

# %% [markdown]
# # %% [markdown]
#
#  3. Run `associate_ucs()` (if needed)

# %%
if not readable.is_file():
    associate_ucs(basic_ucs_path)

transform_ucs_log = f'/share/compling/projects/sanpi/logs/associate/ucs//ucs-{PAT_DIR}_Adv{UNIT}_frq-thrMIN-7-35f_min{FRQ_FLOOR}x*.log'
! head -15 `ls -t1 {transform_ucs_log} | head -1`
! echo '...'
! tail -2 `ls -t1 {transform_ucs_log} | head -1`
# Out:
# # Manipulating AdvAdj_frq-thrMIN-7-35f_min100x ucs table
# path to this script: /share/compling/projects/sanpi/script/transform_ucs.sh
# Thu May 23 18:15:25 EDT 2024
# (TMP: /share/compling/projects/sanpi/results/ucs/adv_adj/ANYmirror/tmp/tmp_ANYmirror-20240523-181525.AdvAdj_frq-thrMIN-7-35f_min100x)
# ## Initial Contingency Info
#
# DATA SET FILE:  /share/compling/projects/sanpi/results/ucs/adv_adj/ANYmirror/AdvAdj_frq-thrMIN-7.35f_min100x.ds.gz
#
# # Frequency signatures computed by the ucs-make-tables tool for relational cooccurrences.
# # Sample size:  N = 1761853 tokens,  V = 195059 pair types.
# # A frequency threshold of f >= 100 was applied, leaving V = 2315 pair types.
#
# ##:: size = 2315
# ##:: threshold = 100
#
# ...
# Loading data set /share/compling/projects/sanpi/results/ucs/adv_adj/ANYmirror/AdvAdj_frq-thrMIN-7.35f_min100x.rsort.gz ... 2315 rows
# Script finished at Thu May 23 18:15:29 EDT 2024

# %% [markdown]
# # %% [markdown]
#
#  4. Run `ucs_to_csv()` to convert `ucs/[PAT_DIR]/readable/*.txt` to format that `pandas` can parse as a dataframe

# %%
! head -5 {readable}
csv_path = ucs2csv(readable)
print(f'CSV: `{csv_path.relative_to(RESULT_DIR)}`')
# Out:
# l1,l2,f,E11,am_log_likelihood,am_odds_ratio_disc,am_p1_given2,am_p2_given1,am_p1_given2_simple,am_p2_given1_simple,f1,f2,N
# even,triple,113,4.2193225,696.935688,2.523903988,0.8917066440,0.0018492047,0.9262295082,0.0018544959,60933,122,1761853
# too,late,12778,1180.1509808,59242.424654,2.574631803,0.8883968110,0.0805976433,0.9714893941,0.0808314672,158082,13153,1761853
# too,early,5158,481.8224562,23279.731355,2.405772510,0.8734588021,0.0324964473,0.9605214153,0.0326286358,158082,5370,1761853
# very,least,101,11.1751451,411.488355,2.127013432,0.8395356111,0.0005450835,0.9439252336,0.0005488862,184009,107,1761853
# UCS table text converted & saved as /share/compling/projects/sanpi/results/ucs/adv_adj/ANYmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv
# CSV: `ucs/adv_adj/ANYmirror/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv`

# %% [markdown]
# # %% [markdown]
#
# ##

# %%
adx_amdf = pd.read_csv(csv_path).convert_dtypes()
adx_amdf
# Out:
#          l1         l2      f      E11  am_log_likelihood  am_odds_ratio_disc  \
# 0      even     triple    113     4.22             696.94                2.52
# 1       too       late  12778 1,180.15          59,242.42                2.57
# 2       too      early   5158   481.82          23,279.73                2.41
# 3      very      least    101    11.18             411.49                2.13
# 4     early       next    144     0.02           2,675.23                5.42
# ...     ...        ...    ...      ...                ...                 ...
# 2310   more      wrong    273 3,382.45          -5,408.31               -1.17
# 2311   more      happy    179 2,327.32          -3,760.40               -1.19
# 2312   more  available    136 2,048.34          -3,428.64               -1.25
# 2313   more     better    125 2,281.76          -3,979.33               -1.34
# 2314   more      right    113 2,184.02          -3,849.38               -1.36
#
#       am_p1_given2  am_p2_given1  am_p1_given2_simple  am_p2_given1_simple  \
# 0             0.89          0.00                 0.93                 0.00
# 1             0.89          0.08                 0.97                 0.08
# 2             0.87          0.03                 0.96                 0.03
# 3             0.84          0.00                 0.94                 0.00
# 4             0.82          0.83                 0.82                 0.83
# ...            ...           ...                  ...                  ...
# 2310         -0.15         -0.01                 0.01                 0.00
# 2311         -0.15         -0.01                 0.01                 0.00
# 2312         -0.15         -0.01                 0.01                 0.00
# 2313         -0.15         -0.01                 0.01                 0.00
# 2314         -0.15         -0.01                 0.01                 0.00
#
#           f1     f2        N
# 0      60933    122  1761853
# 1     158082  13153  1761853
# 2     158082   5370  1761853
# 3     184009    107  1761853
# 4        174    175  1761853
# ...      ...    ...      ...
# 2310  285602  20866  1761853
# 2311  285602  14357  1761853
# 2312  285602  12636  1761853
# 2313  285602  14076  1761853
# 2314  285602  13473  1761853
#
# [2315 rows x 13 columns]

# %%
# %%

adx_amdf['key'] = (adx_amdf.l1 + '~' +
                   adx_amdf.l2).astype('string')
adx_amdf = adx_amdf.set_index('key')
adx_amdf
# Out:
#                    l1         l2      f      E11  am_log_likelihood  \
# key
# even~triple      even     triple    113     4.22             696.94
# too~late          too       late  12778 1,180.15          59,242.42
# too~early         too      early   5158   481.82          23,279.73
# very~least       very      least    101    11.18             411.49
# early~next      early       next    144     0.02           2,675.23
# ...               ...        ...    ...      ...                ...
# more~wrong       more      wrong    273 3,382.45          -5,408.31
# more~happy       more      happy    179 2,327.32          -3,760.40
# more~available   more  available    136 2,048.34          -3,428.64
# more~better      more     better    125 2,281.76          -3,979.33
# more~right       more      right    113 2,184.02          -3,849.38
#
#                 am_odds_ratio_disc  am_p1_given2  am_p2_given1  \
# key
# even~triple                   2.52          0.89          0.00
# too~late                      2.57          0.89          0.08
# too~early                     2.41          0.87          0.03
# very~least                    2.13          0.84          0.00
# early~next                    5.42          0.82          0.83
# ...                            ...           ...           ...
# more~wrong                   -1.17         -0.15         -0.01
# more~happy                   -1.19         -0.15         -0.01
# more~available               -1.25         -0.15         -0.01
# more~better                  -1.34         -0.15         -0.01
# more~right                   -1.36         -0.15         -0.01
#
#                 am_p1_given2_simple  am_p2_given1_simple      f1     f2  \
# key
# even~triple                    0.93                 0.00   60933    122
# too~late                       0.97                 0.08  158082  13153
# too~early                      0.96                 0.03  158082   5370
# very~least                     0.94                 0.00  184009    107
# early~next                     0.82                 0.83     174    175
# ...                             ...                  ...     ...    ...
# more~wrong                     0.01                 0.00  285602  20866
# more~happy                     0.01                 0.00  285602  14357
# more~available                 0.01                 0.00  285602  12636
# more~better                    0.01                 0.00  285602  14076
# more~right                     0.01                 0.00  285602  13473
#
#                       N
# key
# even~triple     1761853
# too~late        1761853
# too~early       1761853
# very~least      1761853
# early~next      1761853
# ...                 ...
# more~wrong      1761853
# more~happy      1761853
# more~available  1761853
# more~better     1761853
# more~right      1761853
#
# [2315 rows x 13 columns]

# %% [markdown]
# # %% [markdown]
#
#  6. Save to `./results/assoc_df/`

# %%
df_csv_path = AM_DF_DIR.joinpath(
    str(csv_path.relative_to(UCS_DIR))
    .replace('/readable', '')
    .replace('.rsort-view_am-only', ''))

if not df_csv_path.is_file():
    confirm_dir(df_csv_path.parent)
    adx_amdf.to_csv(df_csv_path)

df_pkl_path = df_csv_path.with_suffix('.pkl.gz')
if not df_pkl_path.is_file():
    adx_amdf.to_pickle(df_csv_path.with_suffix('.pkl.gz'))

# %% [markdown]
# # %% [markdown]
#
#  7. Add additional AM via `add_extra_am()`
#  Define dictionary containing relevant vocab sizes
#  !!! Warning This is a `#HACK`: \
#      Rather than developing a command/code to retrieve the vocab sizes programmatically,
#      I simply copied the values given in the log output of `transform_usc.sh`
#      for each `PAT_DIR`+`UNIT` combination

# %%
VOCABS = {
    'NEGmirror': {'Adj': 40004},
    'POSmirror': {'Adj': 178159},
    'ANYmirror': {'Adj': 195059},
    'RBdirect':  {'Adj': 61860},
    'RBXadj':  {'Adj': 1940305}
}  # ! #HACK
VOCAB = VOCABS[PAT_DIR][UNIT]

print(pd.DataFrame(VOCABS).convert_dtypes().to_markdown(intfmt=','))
VOCAB = None
ex_adx_amdf = add_extra_am(df=adx_amdf,
                           verbose=True,
                           vocab=VOCAB,
                           metrics=['t_score', 'mutual_information']
                           ).convert_dtypes()
# Out:
# |     |   NEGmirror |   POSmirror |   ANYmirror |   RBdirect |    RBXadj |
# |:----|------------:|------------:|------------:|-----------:|----------:|
# | Adj |      40,004 |     178,159 |     195,059 |     61,860 | 1,940,305 |
#
# Preview of Extended Measures (rounded)
#
# | key           |   t_score |   mutual_information |   deltaP_min |   deltaP_max |   deltaP_max_abs |   deltaP_product |   unexpected_f |   unexpected_ratio |
# |:--------------|----------:|---------------------:|-------------:|-------------:|-----------------:|-----------------:|---------------:|-------------------:|
# | even~triple   |     10.23 |                 1.43 |         0.00 |         0.89 |             0.89 |             0.00 |         108.78 |               0.96 |
# | too~late      |    102.60 |                 1.03 |         0.08 |         0.89 |             0.89 |             0.07 |      11,597.85 |               0.91 |
# | too~early     |     65.11 |                 1.03 |         0.03 |         0.87 |             0.87 |             0.03 |       4,676.18 |               0.91 |
# | very~least    |      8.94 |                 0.96 |         0.00 |         0.84 |             0.84 |             0.00 |          89.82 |               0.89 |
# | early~next    |     12.00 |                 3.92 |         0.82 |         0.83 |             0.83 |             0.68 |         143.98 |               1.00 |
# | even~third    |     18.46 |                 1.38 |         0.01 |         0.80 |             0.80 |             0.00 |         355.54 |               0.96 |
# | even~fourth   |     12.70 |                 1.37 |         0.00 |         0.77 |             0.77 |             0.00 |         168.46 |               0.96 |
# | now~live      |     20.09 |                 2.39 |         0.07 |         0.77 |             0.77 |             0.06 |         405.35 |               1.00 |
# | even~national |      9.60 |                 1.35 |         0.00 |         0.74 |             0.74 |             0.00 |          96.47 |               0.96 |
# | long~overdue  |     14.41 |                 3.08 |         0.20 |         0.72 |             0.72 |             0.14 |         207.83 |               1.00 |

# %% [markdown]
# # %% [markdown]
#
#  Save extended AM tables to `extra/` subdirectory if not already saved

# %%
df_extra_csv = df_csv_path.parent / 'extra' / \
    df_csv_path.name.replace('.csv', '_extra.csv')
print(df_extra_csv)
if not df_extra_csv.is_file():
    confirm_dir(df_extra_csv.parent)
    ex_adx_amdf.to_csv(df_extra_csv)

df_extra_pkl = df_extra_csv.with_suffix('.pkl.gz')
if not df_extra_pkl.is_file():
    ex_adx_amdf.to_pickle(df_extra_pkl)
# Out:
# /share/compling/projects/sanpi/results/assoc_df/adv_adj/ANYmirror/extra/AdvAdj_frq-thrMIN-7.35f_min100x_extra.csv

# %%
# %%

ex_adx_full = ex_adx_amdf.copy()
ex_adx_abbr = adjust_assoc_columns(
    ex_adx_amdf[[c for c in ['polarity', 'quant'] + FOCUS if c in ex_adx_amdf.columns]]).sort_values('LRC', ascending=False)
cols = ex_adx_abbr.columns

# %% [markdown]
# # %% [markdown]
#
#  Define lexical items with given lean shown in binary environment evaluation

# %%
pos_prone = {
    'Adj': [
        'unrelated',
        'unable',
        'akin',
        'larger',
        'different',
        'familiar',
        'similar',
        'likely',
        'brief',
        'unaware'
    ],
    'Adv': [
        'slightly',
        'definitely',
        'utterly',
        # LRC top
        'pretty',
        'rather',
        'plain',
        'fairly',
        'somewhat',
        'otherwise',
        'downright',
        'relatively',
        # G2 top
        # 'very',
        # 'even',
        # 'just',
        # dP1 top (and odds ratio disc)
        'plain',
        'maybe'
    ],
    'Bigr': [
        # G2 top
        'completely_different',
        'too_familiar',
        'even_better',
        # dP1 top
        'quite_different',
        'too_real',
        'well_aware',
        # LRC top
        'too_common',
        'entirely_different'
    ]}
neg_prone = {
    'Bigr': [
        # LRC top
        'quite_sure',
        'really_sure',
        'too_early',
        'too_pleased',
        'too_fancy',
        # dP1 top
        'entirely_sure',
        'ever_easy',
        'ever_perfect',
        'particularly_surprising',
        'particularly_new',
        # G2 top
        'too_late',
        'more_important',
        'so_easy',
        'as_good',
        'too_old'
    ],
    'Adv': [
        'yet',
        # LRC top
        'ever',
        'any',
        'longer',
        'necessarily',
        'that',
        # dP1 top
        'before',
        'wise',  # ? How is this used as an adverb?
        'earthly',
        'remotely',
        'exactly',
        # G2 top
        'particularly',
        'too',
        # 'inherently'
    ],
    'Adj': [
        # LRC top
        'early',
        'late',
        'fancy',
        'alone',
        'sure',
        # dP1 top
        'shabby',
        'demoralizing',
        'alone',
        'aggravating',
        'groundbreaking',
        'eventful',
        # G2 top
        'important',
        'frustrating',
        'evident',
        'certain'
    ]
}


def sort_prone_by_f2(prone_list, amdf):
    return amdf.copy().loc[amdf.l2.isin(prone_list), ['f2', 'l2']].drop_duplicates().reset_index(drop=True).set_index('l2').round(1).sort_values(['f2'], ascending=False).index.to_list()


pos_prone[UNIT] = sort_prone_by_f2(pos_prone[UNIT], ex_adx_abbr)
neg_prone[UNIT] = sort_prone_by_f2(neg_prone[UNIT], ex_adx_abbr)
pos_prone[UNIT]
# Out:
# ['different',
#  'likely',
#  'familiar',
#  'similar',
#  'larger',
#  'unable',
#  'akin',
#  'unaware',
#  'unrelated',
#  'brief']

# %% [markdown]
# # %% [markdown]
#
#  Strongest associations for each polarity by metric

# %%
def show_metric_top(amdf: pd.DataFrame,
                    metric: str,
                    k=5,
                    cols=[None]):
    if not any(cols):
        cols = amdf.columns
    return (amdf.nlargest(k, metric)
            .loc[:, [metric] + cols[cols != metric].to_list()]
            .reset_index(drop=True).set_index(['l1', 'l2'])
            )

# %% [markdown]
# # %% [markdown]
#
#  Top consevative log ratio $LRC$ values

# %%
exdf = show_metric_top(ex_adx_abbr, "LRC", k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                         LRC    f  unexp_f  dP1  dP2  dP1_simple  dP2_simple  \
# l1         l2
# early      next       14.32  144   143.98 0.82 0.83        0.82        0.83
# non        existent   11.78  108   107.95 0.67 0.22        0.68        0.22
# lightly    golden     11.47  206   205.90 0.48 0.52        0.48        0.52
# long       overdue    11.25  208   207.83 0.72 0.20        0.72        0.20
# minimally  invasive   11.03  122   121.94 0.31 0.48        0.31        0.48
# mutually   exclusive  10.98  441   440.63 0.56 0.54        0.56        0.54
# critically endangered 10.85  206   205.85 0.50 0.32        0.50        0.32
# grossly    negligent  10.42  112   111.92 0.42 0.20        0.42        0.20
#
#                             G2        N    f1   f2  exp_f
# l1         l2
# early      next       2,675.23  1761853   174  175   0.02
# non        existent   1,589.53  1761853   496  160   0.05
# lightly    golden     2,999.46  1761853   399  426   0.10
# long       overdue    2,793.45  1761853  1043  289   0.17
# minimally  invasive   1,743.16  1761853   254  392   0.06
# mutually   exclusive  5,968.69  1761853   823  794   0.37
# critically endangered 2,768.70  1761853   645  408   0.15
# grossly    negligent  1,470.63  1761853   550  266   0.08

# %% [markdown]
# # %% [markdown]
#
#  Top $\Delta P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#               dP1      f   unexp_f   LRC  dP2  dP1_simple  dP2_simple  \
# l1    l2
# even  triple 0.89    113    108.78  6.19 0.00        0.93        0.00
# too   late   0.89  12778 11,597.85  8.09 0.08        0.97        0.08
#       early  0.87   5158  4,676.18  7.49 0.03        0.96        0.03
# very  least  0.84    101     89.82  4.42 0.00        0.94        0.00
# early next   0.82    144    143.98 14.32 0.83        0.82        0.83
# even  third  0.80    371    355.54  6.27 0.01        0.83        0.01
#       fourth 0.77    176    168.46  5.75 0.00        0.81        0.00
# now   live   0.77    407    405.35  9.38 0.07        0.77        0.07
#
#                     G2        N      f1     f2    exp_f
# l1    l2
# even  triple    696.94  1761853   60933    122     4.22
# too   late   59,242.42  1761853  158082  13153 1,180.15
#       early  23,279.73  1761853  158082   5370   481.82
# very  least     411.49  1761853  184009    107    11.18
# early next    2,675.23  1761853     174    175     0.02
# even  third   2,096.25  1761853   60933    447    15.46
#       fourth    974.02  1761853   60933    218     7.54
# now   live    4,156.73  1761853    5479    530     1.65

# %% [markdown]
# # %% [markdown]
#
#  Top conditional probability $P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                dP1_simple      f   unexp_f   LRC  dP1  dP2  dP2_simple  \
# l1    l2
# too   late           0.97  12778 11,597.85  8.09 0.89 0.08        0.08
#       early          0.96   5158  4,676.18  7.49 0.87 0.03        0.03
# very  least          0.94    101     89.82  4.42 0.84 0.00        0.00
# even  triple         0.93    113    108.78  6.19 0.89 0.00        0.00
# more  akin           0.86    946    768.33  4.45 0.70 0.00        0.00
#       galling        0.85    147    119.12  3.51 0.69 0.00        0.00
# even  third          0.83    371    355.54  6.27 0.80 0.01        0.01
# early next           0.82    144    143.98 14.32 0.82 0.83        0.83
#
#                      G2        N      f1     f2    exp_f
# l1    l2
# too   late    59,242.42  1761853  158082  13153 1,180.15
#       early   23,279.73  1761853  158082   5370   481.82
# very  least      411.49  1761853  184009    107    11.18
# even  triple     696.94  1761853   60933    122     4.22
# more  akin     2,622.96  1761853  285602   1096   177.67
#       galling    401.23  1761853  285602    172    27.88
# even  third    2,096.25  1761853   60933    447    15.46
# early next     2,675.23  1761853     174    175     0.02

# %% [markdown]
# # %% [markdown]
#
#  Top $\Delta P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                      dP2    f  unexp_f  LRC  dP1  dP1_simple  dP2_simple  \
# l1         l2
# crystal    clear    1.00  146   145.35 7.77 0.02        0.02        1.00
# brand      new      0.96  523   518.96 7.00 0.04        0.04        0.97
# kind       enough   0.95  354   352.10 7.49 0.04        0.04        0.95
# at         best     0.94  139   138.86 9.84 0.08        0.08        0.95
# humanly    possible 0.88  296   294.94 8.05 0.05        0.05        0.88
# closely    related  0.87  703   701.24 8.79 0.18        0.18        0.87
# wide       open     0.85  232   231.41 8.52 0.06        0.06        0.85
# terminally ill      0.84  255   254.56 9.13 0.10        0.10        0.84
#
#                           G2        N   f1     f2  exp_f
# l1         l2
# crystal    clear    1,584.13  1761853  146   7833   0.65
# brand      new      4,986.68  1761853  541  13145   4.04
# kind       enough   3,609.50  1761853  371   9034   1.90
# at         best     1,877.47  1761853  147   1714   0.14
# humanly    possible 3,181.85  1761853  336   5543   1.06
# closely    related  8,139.68  1761853  804   3857   1.76
# wide       open     2,632.68  1761853  273   3796   0.59
# terminally ill      3,101.85  1761853  302   2540   0.44

# %% [markdown]
# # %% [markdown]
#
#  Top conditional probability $P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                    dP2_simple    f  unexp_f  LRC  dP1  dP2  dP1_simple  \
# l1      l2
# crystal clear            1.00  146   145.35 7.77 0.02 1.00        0.02
# brand   new              0.97  523   518.96 7.00 0.04 0.96        0.04
# kind    enough           0.95  354   352.10 7.49 0.04 0.95        0.04
# at      best             0.95  139   138.86 9.84 0.08 0.94        0.08
# humanly possible         0.88  296   294.94 8.05 0.05 0.88        0.05
# closely related          0.87  703   701.24 8.79 0.18 0.87        0.18
# vitally important        0.86  270   262.22 4.98 0.01 0.84        0.01
# wide    open             0.85  232   231.41 8.52 0.06 0.85        0.06
#
#                         G2        N   f1     f2  exp_f
# l1      l2
# crystal clear     1,584.13  1761853  146   7833   0.65
# brand   new       4,986.68  1761853  541  13145   4.04
# kind    enough    3,609.50  1761853  371   9034   1.90
# at      best      1,877.47  1761853  147   1714   0.14
# humanly possible  3,181.85  1761853  336   5543   1.06
# closely related   8,139.68  1761853  804   3857   1.76
# vitally important 1,748.59  1761853  313  43776   7.78
# wide    open      2,632.68  1761853  273   3796   0.59

# %% [markdown]
# # %% [markdown]
#
#  Top log-likelihood $G^2$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'G2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                             G2      f   unexp_f  LRC  dP1  dP2  dP1_simple  \
# l1         l2
# too        late      59,242.42  12778 11,597.85 8.09 0.89 0.08        0.97
# as         simple    58,922.50  15954 14,396.44 4.61 0.58 0.14        0.63
# completely different 34,381.84   8352  7,804.10 4.22 0.22 0.30        0.23
# more       important 31,883.65  23085 15,988.77 2.47 0.37 0.07        0.53
# too        early     23,279.73   5158  4,676.18 7.49 0.87 0.03        0.96
# even       better    22,919.59   6103  5,616.19 4.31 0.40 0.10        0.43
#            worse     22,551.80   4970  4,676.38 5.16 0.55 0.08        0.59
# n't        right     18,933.61   3808  3,653.63 4.97 0.27 0.18        0.28
#
#                       dP2_simple        N      f1     f2    exp_f
# l1         l2
# too        late             0.08  1761853  158082  13153 1,180.15
# as         simple           0.15  1761853  108116  25382 1,557.56
# completely different        0.31  1761853   26819  35994   547.90
# more       important        0.08  1761853  285602  43776 7,096.23
# too        early            0.03  1761853  158082   5370   481.82
# even       better           0.10  1761853   60933  14076   486.81
#            worse            0.08  1761853   60933   8490   293.62
# n't        right            0.19  1761853   20187  13473   154.37

# %%
# %%

sig_adx_abbr = ex_adx_abbr.loc[ex_adx_abbr.LRC.abs() > 1, :]
sig_adx_abbr
# Out:
#                       f   unexp_f   LRC   dP1   dP2  dP1_simple  dP2_simple  \
# key
# early~next          144    143.98 14.32  0.82  0.83        0.82        0.83
# non~existent        108    107.95 11.78  0.67  0.22        0.68        0.22
# lightly~golden      206    205.90 11.47  0.48  0.52        0.48        0.52
# long~overdue        208    207.83 11.25  0.72  0.20        0.72        0.20
# minimally~invasive  122    121.94 11.03  0.31  0.48        0.31        0.48
# ...                 ...       ...   ...   ...   ...         ...         ...
# more~available      136 -1,912.34 -3.59 -0.15 -0.01        0.01        0.00
# too~important       252 -3,675.80 -3.68 -0.09 -0.03        0.01        0.00
# more~better         125 -2,156.76 -3.84 -0.15 -0.01        0.01        0.00
# more~right          113 -2,071.02 -3.90 -0.15 -0.01        0.01        0.00
# too~different       154 -3,075.56 -3.99 -0.09 -0.02        0.00        0.00
#
#                           G2        N      f1     f2    exp_f         l1  \
# key
# early~next          2,675.23  1761853     174    175     0.02      early
# non~existent        1,589.53  1761853     496    160     0.05        non
# lightly~golden      2,999.46  1761853     399    426     0.10    lightly
# long~overdue        2,793.45  1761853    1043    289     0.17       long
# minimally~invasive  1,743.16  1761853     254    392     0.06  minimally
# ...                      ...      ...     ...    ...      ...        ...
# more~available     -3,428.64  1761853  285602  12636 2,048.34       more
# too~important      -6,392.11  1761853  158082  43776 3,927.80        too
# more~better        -3,979.33  1761853  285602  14076 2,281.76       more
# more~right         -3,849.38  1761853  285602  13473 2,184.02       more
# too~different      -5,560.60  1761853  158082  35994 3,229.56        too
#
#                            l2
# key
# early~next               next
# non~existent         existent
# lightly~golden         golden
# long~overdue          overdue
# minimally~invasive   invasive
# ...                       ...
# more~available      available
# too~important       important
# more~better            better
# more~right              right
# too~different       different
#
# [1163 rows x 14 columns]

# %% [markdown]
# # %% [markdown]
#
#  Positive Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(pos_prone['Adv'])]
# Out:
#                             f  unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# otherwise~objectionable   193   191.56  7.41  0.50  0.03        0.50
# otherwise~unable          348   343.32  6.28  0.28  0.05        0.28
# otherwise~unavailable     165   162.77  6.08  0.27  0.02        0.28
# relatively~inexpensive    137   135.25  6.04  0.24  0.03        0.24
# otherwise~inappropriate   199   195.84  5.84  0.23  0.03        0.24
# definitely~worth          267   262.69  5.66  0.05  0.18        0.05
# relatively~minor          160   157.13  5.50  0.17  0.03        0.17
# plain~weird               237   231.14  5.07  0.11  0.05        0.12
# maybe~more                404   391.85  4.82  0.05  0.15        0.05
# slightly~higher           377   364.46  4.75  0.13  0.05        0.13
# plain~silly               148   143.36  4.57  0.09  0.03        0.09
# plain~stupid              301   290.44  4.57  0.08  0.06        0.08
# pretty~standard           143   136.94  4.45  0.32  0.01        0.33
# relatively~unknown        110   106.41  4.42  0.09  0.02        0.09
# slightly~smaller          135   130.06  4.35  0.11  0.02        0.12
# slightly~lower            202   194.04  4.34  0.11  0.03        0.11
# downright~bizarre         105   101.35  4.30  0.08  0.02        0.08
# pretty~decent             128   121.82  4.16  0.28  0.00        0.29
# definitely~wrong          364   346.61  4.11  0.02  0.24        0.02
# slightly~larger           226   215.28  4.08  0.09  0.03        0.09
# fairly~straightforward    114   109.12  4.02  0.07  0.02        0.08
# downright~scary           112   107.15  3.99  0.06  0.02        0.06
# plain~crazy               131   124.13  3.75  0.05  0.02        0.05
# relatively~cheap          106   100.43  3.68  0.05  0.02        0.06
# relatively~new            587   546.96  3.67  0.04  0.10        0.04
# slightly~less             101    94.81  3.46  0.07  0.01        0.07
# pretty~cool               654   582.56  3.10  0.11  0.02        0.13
# slightly~different       1255 1,099.10  2.88  0.03  0.14        0.03
# relatively~small          279   249.00  2.87  0.03  0.05        0.03
# pretty~awesome            268   236.87  2.85  0.11  0.01        0.12
# pretty~straightforward    191   169.83  2.84  0.11  0.01        0.13
# plain~wrong               498   437.97  2.80  0.02  0.09        0.02
# downright~dangerous       156   138.34  2.65  0.02  0.03        0.02
# pretty~solid              116   101.73  2.53  0.10  0.00        0.11
# pretty~amazing            350   295.99  2.45  0.08  0.01        0.09
# fairly~obvious            129   112.13  2.39  0.02  0.02        0.02
# slightly~more             214   178.07  2.16  0.02  0.02        0.03
# pretty~tough              125   104.51  2.11  0.07  0.00        0.09
# relatively~young          145   121.45  2.10  0.02  0.02        0.02
# pretty~good              2098 1,627.24  2.09  0.05  0.07        0.06
# fairly~new                236   193.46  2.07  0.01  0.03        0.02
# relatively~easy           307   245.93  1.98  0.01  0.05        0.02
# plain~bad                 157   125.98  1.84  0.01  0.02        0.01
# fairly~similar            118    95.31  1.80  0.01  0.02        0.02
# fairly~easy               288   223.11  1.79  0.01  0.04        0.01
# slightly~better           272   211.03  1.79  0.02  0.03        0.02
# maybe~better              108    87.38  1.78  0.01  0.03        0.01
# pretty~funny              282   203.50  1.50  0.04  0.01        0.05
# pretty~close              604   408.03  1.40  0.03  0.02        0.04
# somewhat~likely           128    95.10  1.40  0.01  0.02        0.01
# pretty~great              274   192.33  1.39  0.03  0.01        0.05
# relatively~simple         261   183.70  1.37  0.01  0.03        0.01
# pretty~tired              158   113.86  1.36  0.04  0.00        0.05
# pretty~excited            419   279.82  1.31  0.03  0.01        0.04
# relatively~close          143   100.48  1.22  0.01  0.02        0.01
# pretty~similar            290   191.60  1.21  0.03  0.01        0.04
# pretty~obvious            221   147.85  1.19  0.03  0.01        0.04
# pretty~basic              118    82.95  1.18  0.03  0.00        0.05
# rather~special            207   134.14  1.07  0.01  0.02        0.01
# pretty~important          136  -478.43 -1.63 -0.01 -0.02        0.00
#
#                          dP2_simple       G2        N     f1     f2  exp_f  \
# key
# otherwise~objectionable        0.03 1,631.17  1761853   6603    384   1.44
# otherwise~unable               0.05 2,436.00  1761853   6603   1248   4.68
# otherwise~unavailable          0.02 1,148.30  1761853   6603    595   2.23
# relatively~inexpensive         0.03   962.26  1761853   5366    575   1.75
# otherwise~inappropriate        0.03 1,312.80  1761853   6603    843   3.16
# definitely~worth               0.18 1,742.33  1761853   1468   5169   4.31
# relatively~minor               0.03 1,005.08  1761853   5366    942   2.87
# plain~weird                    0.05 1,329.78  1761853   5069   2036   5.86
# maybe~more                     0.16 2,129.39  1761853   2581   8296  12.15
# slightly~higher                0.05 1,902.93  1761853   7631   2896  12.54
# plain~silly                    0.03   755.61  1761853   5069   1612   4.64
# plain~stupid                   0.06 1,476.48  1761853   5069   3671  10.56
# pretty~standard                0.01   680.51  1761853  24729    432   6.06
# relatively~unknown             0.02   551.92  1761853   5366   1180   3.59
# slightly~smaller               0.02   650.89  1761853   7631   1140   4.94
# slightly~lower                 0.03   944.70  1761853   7631   1838   7.96
# downright~bizarre              0.02   512.90  1761853   4760   1350   3.65
# pretty~decent                  0.01   570.96  1761853  24729    440   6.18
# definitely~wrong               0.25 1,617.19  1761853   1468  20866  17.39
# slightly~larger                0.03   972.70  1761853   7631   2476  10.72
# fairly~straightforward         0.02   510.41  1761853   5702   1508   4.88
# downright~scary                0.02   497.71  1761853   4760   1797   4.85
# plain~crazy                    0.03   533.77  1761853   5069   2388   6.87
# relatively~cheap               0.02   431.22  1761853   5366   1829   5.57
# relatively~new                 0.11 2,140.10  1761853   5366  13145  40.04
# slightly~less                  0.01   382.07  1761853   7631   1429   6.19
# pretty~cool                    0.03 1,815.56  1761853  24729   5090  71.44
# slightly~different             0.16 3,241.80  1761853   7631  35994 155.90
# relatively~small               0.05   764.61  1761853   5366   9849  30.00
# pretty~awesome                 0.01   709.10  1761853  24729   2218  31.13
# pretty~straightforward         0.01   522.06  1761853  24729   1508  21.17
# plain~wrong                    0.10 1,280.16  1761853   5069  20866  60.03
# downright~dangerous            0.03   410.06  1761853   4760   6537  17.66
# pretty~solid                   0.00   293.73  1761853  24729   1017  14.27
# pretty~amazing                 0.01   743.49  1761853  24729   3848  54.01
# fairly~obvious                 0.02   305.28  1761853   5702   5212  16.87
# slightly~more                  0.03   415.66  1761853   7631   8296  35.93
# pretty~tough                   0.01   251.28  1761853  24729   1460  20.49
# relatively~young               0.03   288.90  1761853   5366   7733  23.55
# pretty~good                    0.08 3,210.64  1761853  24729  33540 470.76
# fairly~new                     0.04   431.36  1761853   5702  13145  42.54
# relatively~easy                0.06   514.34  1761853   5366  20050  61.07
# plain~bad                      0.03   261.87  1761853   5069  10783  31.02
# fairly~similar                 0.02   201.41  1761853   5702   7011  22.69
# fairly~easy                    0.05   423.66  1761853   5702  20050  64.89
# slightly~better                0.04   400.63  1761853   7631  14076  60.97
# maybe~better                   0.04   186.47  1761853   2581  14076  20.62
# pretty~funny                   0.01   323.55  1761853  24729   5593  78.50
# pretty~close                   0.02   562.83  1761853  24729  13962 195.97
# somewhat~likely                0.03   160.36  1761853   4458  13002  32.90
# pretty~great                   0.01   286.69  1761853  24729   5819  81.67
# relatively~simple              0.05   275.57  1761853   5366  25382  77.30
# pretty~tired                   0.01   180.01  1761853  24729   3145  44.14
# pretty~excited                 0.02   375.25  1761853  24729   9916 139.18
# relatively~close               0.03   148.55  1761853   5366  13962  42.52
# pretty~similar                 0.01   250.54  1761853  24729   7011  98.40
# pretty~obvious                 0.01   198.18  1761853  24729   5212  73.15
# pretty~basic                   0.00   123.70  1761853  24729   2497  35.05
# rather~special                 0.02   167.39  1761853   8291  15483  72.86
# pretty~important               0.01  -561.52  1761853  24729  43776 614.43
#
#                                  l1               l2
# key
# otherwise~objectionable   otherwise    objectionable
# otherwise~unable          otherwise           unable
# otherwise~unavailable     otherwise      unavailable
# relatively~inexpensive   relatively      inexpensive
# otherwise~inappropriate   otherwise    inappropriate
# definitely~worth         definitely            worth
# relatively~minor         relatively            minor
# plain~weird                   plain            weird
# maybe~more                    maybe             more
# slightly~higher            slightly           higher
# plain~silly                   plain            silly
# plain~stupid                  plain           stupid
# pretty~standard              pretty         standard
# relatively~unknown       relatively          unknown
# slightly~smaller           slightly          smaller
# slightly~lower             slightly            lower
# downright~bizarre         downright          bizarre
# pretty~decent                pretty           decent
# definitely~wrong         definitely            wrong
# slightly~larger            slightly           larger
# fairly~straightforward       fairly  straightforward
# downright~scary           downright            scary
# plain~crazy                   plain            crazy
# relatively~cheap         relatively            cheap
# relatively~new           relatively              new
# slightly~less              slightly             less
# pretty~cool                  pretty             cool
# slightly~different         slightly        different
# relatively~small         relatively            small
# pretty~awesome               pretty          awesome
# pretty~straightforward       pretty  straightforward
# plain~wrong                   plain            wrong
# downright~dangerous       downright        dangerous
# pretty~solid                 pretty            solid
# pretty~amazing               pretty          amazing
# fairly~obvious               fairly          obvious
# slightly~more              slightly             more
# pretty~tough                 pretty            tough
# relatively~young         relatively            young
# pretty~good                  pretty             good
# fairly~new                   fairly              new
# relatively~easy          relatively             easy
# plain~bad                     plain              bad
# fairly~similar               fairly          similar
# fairly~easy                  fairly             easy
# slightly~better            slightly           better
# maybe~better                  maybe           better
# pretty~funny                 pretty            funny
# pretty~close                 pretty            close
# somewhat~likely            somewhat           likely
# pretty~great                 pretty            great
# relatively~simple        relatively           simple
# pretty~tired                 pretty            tired
# pretty~excited               pretty          excited
# relatively~close         relatively            close
# pretty~similar               pretty          similar
# pretty~obvious               pretty          obvious
# pretty~basic                 pretty            basic
# rather~special               rather          special
# pretty~important             pretty        important

# %% [markdown]
# # %% [markdown]
#
#  Negative Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(neg_prone['Adv'])]
# Out:
#                              f   unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# too~late                 12778 11,597.85  8.09  0.89  0.08        0.97
# too~early                 5158  4,676.18  7.49  0.87  0.03        0.96
# before~available           175    172.93  6.11  0.01  0.60        0.01
# any~better                 416    406.59  5.24  0.03  0.35        0.03
# particularly~noteworthy    100     96.54  4.45  0.21  0.01        0.21
# ...                        ...       ...   ...   ...   ...         ...
# too~interested             114   -716.67 -2.37 -0.08 -0.00        0.01
# too~simple                 327 -1,950.40 -2.55 -0.08 -0.01        0.01
# too~interesting            100 -1,026.50 -2.96 -0.08 -0.01        0.01
# too~important              252 -3,675.80 -3.68 -0.09 -0.03        0.01
# too~different              154 -3,075.56 -3.99 -0.09 -0.02        0.00
#
#                          dP2_simple        G2        N      f1     f2  \
# key
# too~late                       0.08 59,242.42  1761853  158082  13153
# too~early                      0.03 23,279.73  1761853  158082   5370
# before~available               0.61  1,346.37  1761853     288  12636
# any~better                     0.35  2,512.54  1761853    1178  14076
# particularly~noteworthy        0.01    501.81  1761853   13041    468
# ...                             ...       ...      ...     ...    ...
# too~interested                 0.00 -1,043.40  1761853  158082   9258
# too~simple                     0.00 -2,818.41  1761853  158082  25382
# too~interesting                0.00 -1,665.57  1761853  158082  12555
# too~important                  0.00 -6,392.11  1761853  158082  43776
# too~different                  0.00 -5,560.60  1761853  158082  35994
#
#                            exp_f            l1           l2
# key
# too~late                1,180.15           too         late
# too~early                 481.82           too        early
# before~available            2.07        before    available
# any~better                  9.41           any       better
# particularly~noteworthy     3.46  particularly   noteworthy
# ...                          ...           ...          ...
# too~interested            830.67           too   interested
# too~simple              2,277.40           too       simple
# too~interesting         1,126.50           too  interesting
# too~important           3,927.80           too    important
# too~different           3,229.56           too    different
#
# [126 rows x 14 columns]

# %% [markdown]
# # %% [markdown]
#
#  Positive Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(pos_prone['Adj'])]
# Out:
#                             f   unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# otherwise~unable          348    343.32  6.28  0.28  0.05        0.28
# much~larger              1364  1,330.39  6.22  0.54  0.06        0.55
# intimately~familiar       131    129.00  5.63  0.01  0.47        0.01
# eerily~similar            106    104.40  5.52  0.01  0.26        0.02
# physically~unable         106    104.39  5.52  0.08  0.05        0.08
# completely~unrelated      424    410.12  5.38  0.45  0.02        0.46
# strikingly~similar        101     99.30  5.34  0.01  0.23        0.01
# totally~unrelated         200    194.42  4.99  0.21  0.02        0.22
# substantially~similar     115    112.31  4.88  0.02  0.17        0.02
# radically~different       539    520.74  4.72  0.01  0.58        0.01
# altogether~different      843    810.86  4.59  0.02  0.52        0.02
# vastly~different          310    298.56  4.52  0.01  0.53        0.01
# more~akin                 946    768.33  4.45  0.70  0.00        0.86
# remarkably~similar        122    118.04  4.41  0.02  0.12        0.02
# simply~unable             147    141.46  4.33  0.11  0.02        0.12
# completely~different     8352  7,804.10  4.22  0.22  0.30        0.23
# slightly~larger           226    215.28  4.08  0.09  0.03        0.09
# entirely~different       3308  3,097.41  4.00  0.09  0.30        0.09
# drastically~different     186    176.95  4.00  0.01  0.40        0.01
# dramatically~different    150    141.91  3.80  0.00  0.36        0.00
# far~larger                142    134.29  3.73  0.05  0.02        0.06
# too~familiar             7058  5,901.00  3.50  0.46  0.04        0.55
# completely~unaware        190    175.08  3.43  0.18  0.01        0.19
# already~familiar          400    368.49  3.39  0.03  0.09        0.03
# totally~different        2310  2,089.79  3.35  0.06  0.20        0.06
# vaguely~familiar          114    105.87  3.24  0.01  0.10        0.01
# probably~familiar         194    178.70  3.23  0.01  0.09        0.02
# more~likely              8144  6,036.33  3.00  0.47  0.03        0.63
# most~likely              1062    935.52  2.98  0.07  0.06        0.08
# too~brief                 325    269.73  2.97  0.44  0.00        0.53
# remotely~similar          106     96.70  2.91  0.01  0.04        0.02
# very~similar             3437  2,704.77  2.89  0.39  0.02        0.49
# slightly~different       1255  1,099.10  2.88  0.03  0.14        0.03
# less~likely              1188    997.81  2.57  0.08  0.04        0.09
# fundamentally~different   297    252.61  2.40  0.01  0.12        0.01
# wildly~different          146    122.59  2.14  0.00  0.11        0.00
# significantly~different   176    145.36  2.06  0.00  0.10        0.00
# quite~different          3160  2,331.25  1.91  0.07  0.06        0.09
# fairly~similar            118     95.31  1.80  0.01  0.02        0.02
# uniquely~different        100     77.14  1.51  0.00  0.07        0.00
# ever~likely               142    104.90  1.40  0.01  0.02        0.01
# somewhat~likely           128     95.10  1.40  0.01  0.02        0.01
# even~larger               274    188.37  1.38  0.08  0.00        0.11
# quite~similar             466    304.57  1.28  0.04  0.01        0.07
# pretty~similar            290    191.60  1.21  0.03  0.01        0.04
# far~different             312    199.96  1.12  0.01  0.04        0.01
# very~likely               520   -837.94 -1.19 -0.06 -0.01        0.04
# as~likely                 264   -533.87 -1.25 -0.04 -0.01        0.02
# more~familiar             606 -1,484.32 -1.70 -0.12 -0.01        0.05
# too~likely                294   -872.60 -1.71 -0.07 -0.01        0.02
# more~similar              206   -930.51 -2.21 -0.13 -0.00        0.03
# as~familiar               107   -684.30 -2.33 -0.05 -0.01        0.01
# more~different            744 -5,090.74 -2.95 -0.14 -0.02        0.02
# as~different              142 -2,066.77 -3.49 -0.06 -0.02        0.00
# too~different             154 -3,075.56 -3.99 -0.09 -0.02        0.00
#
#                          dP2_simple        G2        N      f1     f2  \
# key
# otherwise~unable               0.05  2,436.00  1761853    6603   1248
# much~larger                    0.06  8,429.52  1761853   23915   2476
# intimately~familiar            0.48    913.70  1761853     273  12895
# eerily~similar                 0.26    712.38  1761853     401   7011
# physically~unable              0.05    693.15  1761853    2269   1248
# completely~unrelated           0.02  2,310.46  1761853   26819    912
# strikingly~similar             0.24    652.69  1761853     428   7011
# totally~unrelated              0.02  1,091.44  1761853   10779    912
# substantially~similar          0.17    661.17  1761853     675   7011
# radically~different            0.60  3,015.43  1761853     894  35994
# altogether~different           0.54  4,436.26  1761853    1573  35994
# vastly~different               0.55  1,655.25  1761853     560  35994
# more~akin                      0.00  2,622.96  1761853  285602   1096
# remarkably~similar             0.12    616.74  1761853     996   7011
# simply~unable                  0.02    700.10  1761853    7826   1248
# completely~different           0.31 34,381.84  1761853   26819  35994
# slightly~larger                0.03    972.70  1761853    7631   2476
# entirely~different             0.32 13,374.36  1761853   10308  35994
# drastically~different          0.42    856.17  1761853     443  35994
# dramatically~different         0.38    652.49  1761853     396  35994
# far~larger                     0.03    569.68  1761853    5484   2476
# too~familiar                   0.04 17,617.34  1761853  158082  12895
# completely~unaware             0.01    651.78  1761853   26819    980
# already~familiar               0.09  1,339.45  1761853    4305  12895
# totally~different              0.21  7,250.39  1761853   10779  35994
# vaguely~familiar               0.10    401.67  1761853    1111  12895
# probably~familiar              0.09    646.38  1761853    2091  12895
# more~likely                    0.03 14,323.98  1761853  285602  13002
# most~likely                    0.06  2,771.04  1761853   17139  13002
# too~brief                      0.00    770.29  1761853  158082    616
# remotely~similar               0.05    328.00  1761853    2336   7011
# very~similar                   0.02  6,645.91  1761853  184009   7011
# slightly~different             0.16  3,241.80  1761853    7631  35994
# less~likely                    0.05  2,477.04  1761853   25772  13002
# fundamentally~different        0.14    656.82  1761853    2173  35994
# wildly~different               0.13    303.61  1761853    1146  35994
# significantly~different        0.12    340.08  1761853    1500  35994
# quite~different                0.08  4,097.08  1761853   40566  35994
# fairly~similar                 0.02    201.41  1761853    5702   7011
# uniquely~different             0.09    146.60  1761853    1119  35994
# ever~likely                    0.03    174.48  1761853    5027  13002
# somewhat~likely                0.03    160.36  1761853    4458  13002
# even~larger                    0.00    276.48  1761853   60933   2476
# quite~similar                  0.01    395.01  1761853   40566   7011
# pretty~similar                 0.01    250.54  1761853   24729   7011
# far~different                  0.06    247.84  1761853    5484  35994
# very~likely                    0.00   -740.78  1761853  184009  13002
# as~likely                      0.00   -509.62  1761853  108116  13002
# more~familiar                  0.00 -1,672.38  1761853  285602  12895
# too~likely                     0.00 -1,002.91  1761853  158082  13002
# more~similar                   0.00 -1,301.18  1761853  285602   7011
# as~familiar                    0.00   -983.04  1761853  108116  12895
# more~different                 0.00 -8,041.56  1761853  285602  35994
# as~different                   0.00 -3,520.78  1761853  108116  35994
# too~different                  0.00 -5,560.60  1761853  158082  35994
#
#                            exp_f             l1         l2
# key
# otherwise~unable            4.68      otherwise     unable
# much~larger                33.61           much     larger
# intimately~familiar         2.00     intimately   familiar
# eerily~similar              1.60         eerily    similar
# physically~unable           1.61     physically     unable
# completely~unrelated       13.88     completely  unrelated
# strikingly~similar          1.70     strikingly    similar
# totally~unrelated           5.58        totally  unrelated
# substantially~similar       2.69  substantially    similar
# radically~different        18.26      radically  different
# altogether~different       32.14     altogether  different
# vastly~different           11.44         vastly  different
# more~akin                 177.67           more       akin
# remarkably~similar          3.96     remarkably    similar
# simply~unable               5.54         simply     unable
# completely~different      547.90     completely  different
# slightly~larger            10.72       slightly     larger
# entirely~different        210.59       entirely  different
# drastically~different       9.05    drastically  different
# dramatically~different      8.09   dramatically  different
# far~larger                  7.71            far     larger
# too~familiar            1,157.00            too   familiar
# completely~unaware         14.92     completely    unaware
# already~familiar           31.51        already   familiar
# totally~different         220.21        totally  different
# vaguely~familiar            8.13        vaguely   familiar
# probably~familiar          15.30       probably   familiar
# more~likely             2,107.67           more     likely
# most~likely               126.48           most     likely
# too~brief                  55.27            too      brief
# remotely~similar            9.30       remotely    similar
# very~similar              732.23           very    similar
# slightly~different        155.90       slightly  different
# less~likely               190.19           less     likely
# fundamentally~different    44.39  fundamentally  different
# wildly~different           23.41         wildly  different
# significantly~different    30.64  significantly  different
# quite~different           828.75          quite  different
# fairly~similar             22.69         fairly    similar
# uniquely~different         22.86       uniquely  different
# ever~likely                37.10           ever     likely
# somewhat~likely            32.90       somewhat     likely
# even~larger                85.63           even     larger
# quite~similar             161.43          quite    similar
# pretty~similar             98.40         pretty    similar
# far~different             112.04            far  different
# very~likely             1,357.94           very     likely
# as~likely                 797.87             as     likely
# more~familiar           2,090.32           more   familiar
# too~likely              1,166.60            too     likely
# more~similar            1,136.51           more    similar
# as~familiar               791.30             as   familiar
# more~different          5,834.74           more  different
# as~different            2,208.77             as  different
# too~different           3,229.56            too  different

# %% [markdown]
# # %% [markdown]
#
#  Negative Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(neg_prone['Adj'])]
# Out:
#                           f   unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# too~late              12778 11,597.85  8.09  0.89  0.08        0.97
# too~early              5158  4,676.18  7.49  0.87  0.03        0.96
# vitally~important       270    262.22  4.98  0.01  0.84        0.01
# truly~alone             190    184.12  4.86  0.23  0.01        0.24
# ever~certain            143    137.59  4.27  0.07  0.03        0.08
# exactly~sure            148    142.28  4.21  0.01  0.14        0.02
# absolutely~certain      154    147.79  4.21  0.08  0.03        0.08
# quite~sure             2984  2,759.65  4.09  0.28  0.07        0.31
# critically~important    209    192.97  3.34  0.00  0.30        0.00
# more~frustrating       2269  1,731.14  3.24  0.52  0.01        0.68
# not~sure               2155  1,834.15  2.90  0.19  0.03        0.22
# too~fancy               543    443.67  2.89  0.40  0.00        0.49
# n't~sure                888    776.35  2.89  0.08  0.04        0.09
# really~alone            198    171.54  2.73  0.22  0.00        0.25
# more~evident           1449  1,047.96  2.60  0.42  0.00        0.59
# more~important        23085 15,988.77  2.47  0.37  0.07        0.53
# entirely~sure           364    306.99  2.38  0.03  0.03        0.04
# more~aggravating        114     85.96  2.27  0.50  0.00        0.66
# equally~important       948    766.27  2.21  0.02  0.11        0.02
# quite~certain           185    141.35  1.69  0.07  0.00        0.10
# really~sure             914    588.43  1.36  0.06  0.01        0.09
# less~certain            106     78.27  1.34  0.04  0.00        0.06
# absolutely~sure         119     87.08  1.31  0.01  0.02        0.01
# most~important         1003    577.15  1.05  0.01  0.03        0.02
# pretty~important        136   -478.43 -1.63 -0.01 -0.02        0.00
# not~important           316 -1,125.47 -1.86 -0.03 -0.02        0.01
# quite~important         135   -872.93 -2.37 -0.02 -0.02        0.00
# more~sure               146 -1,433.53 -3.12 -0.15 -0.01        0.01
# too~important           252 -3,675.80 -3.68 -0.09 -0.03        0.01
#
#                       dP2_simple        G2        N      f1     f2    exp_f  \
# key
# too~late                    0.08 59,242.42  1761853  158082  13153 1,180.15
# too~early                   0.03 23,279.73  1761853  158082   5370   481.82
# vitally~important           0.86  1,748.59  1761853     313  43776     7.78
# truly~alone                 0.01  1,001.94  1761853   13083    792     5.88
# ever~certain                0.03    675.45  1761853    5027   1896     5.41
# exactly~sure                0.14    701.24  1761853    1034   9744     5.72
# absolutely~certain          0.03    708.98  1761853    5772   1896     6.21
# quite~sure                  0.07 11,013.33  1761853   40566   9744   224.35
# critically~important        0.32    754.81  1761853     645  43776    16.03
# more~frustrating            0.01  4,500.17  1761853  285602   3318   537.86
# not~sure                    0.04  4,984.00  1761853   58015   9744   320.85
# too~fancy                   0.00  1,191.54  1761853  158082   1107    99.33
# n't~sure                    0.04  2,225.18  1761853   20187   9744   111.65
# really~alone                0.00    496.09  1761853   58868    792    26.46
# more~evident                0.01  2,283.47  1761853  285602   2474   401.04
# more~important              0.08 31,883.65  1761853  285602  43776 7,096.23
# entirely~sure               0.04    754.87  1761853   10308   9744    57.01
# more~aggravating            0.00    213.72  1761853  285602    173    28.04
# equally~important           0.13  1,698.69  1761853    7314  43776   181.73
# quite~certain               0.00    263.18  1761853   40566   1896    43.65
# really~sure                 0.02    753.78  1761853   58868   9744   325.57
# less~certain                0.00    131.28  1761853   25772   1896    27.73
# absolutely~sure             0.02    141.12  1761853    5772   9744    31.92
# most~important              0.06    592.26  1761853   17139  43776   425.85
# pretty~important            0.01   -561.52  1761853   24729  43776   614.43
# not~important               0.01 -1,344.44  1761853   58015  43776 1,441.47
# quite~important             0.00 -1,240.32  1761853   40566  43776 1,007.93
# more~sure                   0.00 -2,418.50  1761853  285602   9744 1,579.53
# too~important               0.00 -6,392.11  1761853  158082  43776 3,927.80
#
#                               l1           l2
# key
# too~late                     too         late
# too~early                    too        early
# vitally~important        vitally    important
# truly~alone                truly        alone
# ever~certain                ever      certain
# exactly~sure             exactly         sure
# absolutely~certain    absolutely      certain
# quite~sure                 quite         sure
# critically~important  critically    important
# more~frustrating            more  frustrating
# not~sure                     not         sure
# too~fancy                    too        fancy
# n't~sure                     n't         sure
# really~alone              really        alone
# more~evident                more      evident
# more~important              more    important
# entirely~sure           entirely         sure
# more~aggravating            more  aggravating
# equally~important        equally    important
# quite~certain              quite      certain
# really~sure               really         sure
# less~certain                less      certain
# absolutely~sure       absolutely         sure
# most~important              most    important
# pretty~important          pretty    important
# not~important                not    important
# quite~important            quite    important
# more~sure                   more         sure
# too~important                too    important
