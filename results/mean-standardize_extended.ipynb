# %% [markdown]
#   # Exploring Statistical Methods on **PRE-CLEANED** bigram frequencies

# %%
import pandas as pd
import matplotlib.pyplot as plt
from pathlib import Path
# from scipy.stats import zscore
# from scipy.spatial.distance import (
# cosine,
# # jensenshannon as jenshan,
# # minkowski as mkow
# )

import numpy as np
from math import sqrt
from sklearn import cluster, decomposition as decomp
_LSC_DATA_DIR = Path("/share/compling/projects/sanpi/source/LSC/data")

orig_frq = None

# %%
if orig_frq is not None:
    frq_table = orig_frq
else:
    input_csv = Path(
        '/share/compling/projects/sanpi/results/freq_out/all-frq_thresh877.35f.csv')
    frq_table = pd.read_csv(input_csv)

    if 'adv_lemma' in frq_table.columns:
        frq_table = frq_table.set_index('adv_lemma').transpose()
    if frq_table.index.name != 'adj_lemma':
        if 'adj_lemma' in frq_table.columns:
            frq_table = frq_table.set_index('adj_lemma')
        else:
            frq_table.index.name = 'adj_lemma'
    frq_table = frq_table.apply(pd.to_numeric, downcast='unsigned')
    frq_table.columns.name = 'adv_lemma'
    frq_table.columns = frq_table.columns.astype('string')
    if 'SUM' in frq_table.index:
        SUM_row = frq_table.loc['SUM', :]
    if 'SUM' in frq_table.columns:
        SUM_col = frq_table.loc[:, 'SUM']
    frq_table = frq_table.loc[frq_table.index !=
                              'SUM', frq_table.columns != 'SUM']
    print(frq_table.shape[0], 'rows (adj)')
    print(frq_table.shape[1], 'columns (adv)')
    frq_table.index = frq_table.index.astype('string')
    orig_frq = frq_table.copy()
frq_table
# Out:
# 3829 rows (adj)
# 1021 columns (adv)
# adv_lemma        very          more          most          so            \
# adj_lemma
# good                   644398         21021          5880        149256
# many                    21205           373           140       1191059
# important              356900        305891        746782        104663
# much                    42027           102            22        613054
# likely                  35628        498300        191813           847
# ...                       ...           ...           ...           ...
# directional                93           222            52             8
# anti-democratic            24            21            69            10
# panicked                   54           159            31            94
# long-winded                94            70            27            48
# pointy                    150            89             8            46
#
# adv_lemma        not           as            too           really        \
# adj_lemma
# good                   142461        248773         58563        259683
# many                    58394        434207        448976           517
# important               24149        102784         12806         71718
# much                    79899        355270        579790          3063
# likely                  63068         31826          1191           467
# ...                       ...           ...           ...           ...
# directional                36             6            12             3
# anti-democratic            23            16             2             4
# panicked                    8            28            65            16
# long-winded                15            30           117            18
# pointy                     43            35           110            39
#
# adv_lemma        much          pretty        ...  resoundingly  athletically  \
# adj_lemma                                    ...
# good                   286470        241515  ...            12             4
# many                      214            54  ...             0             0
# important                1828          6584  ...             0             1
# much                      289         57797  ...             0             0
# likely                    526          1312  ...             0             0
# ...                       ...           ...  ...           ...           ...
# directional                 2             6  ...             0             0
# anti-democratic             0             3  ...             0             0
# panicked                    3            15  ...             0             0
# long-winded                 1            14  ...             0             0
# pointy                      7             9  ...             0             0
#
# adv_lemma        questionably  inescapably   slyly         second-most   \
# adj_lemma
# good                       10             1             4             0
# many                        1             0             0             0
# important                   3             5             0           112
# much                        0             0             0             0
# likely                      0             0             0            14
# ...                       ...           ...           ...           ...
# directional                 0             0             0             0
# anti-democratic             0             0             0             0
# panicked                    0             0             0             0
# long-winded                 0             0             0             0
# pointy                      0             0             0             0
#
# adv_lemma        bracingly     deservedly    scandalously  urgently
# adj_lemma
# good                        2             5            10             2
# many                        0             0             0             0
# important                   0             0             0           120
# much                        0             0             0             0
# likely                      0             0             0             0
# ...                       ...           ...           ...           ...
# directional                 0             0             0             0
# anti-democratic             0             0             0             0
# panicked                    0             0             0             0
# long-winded                 0             0             0             0
# pointy                      0             0             0             0
#
# [3829 rows x 1021 columns]

# %%
def heatmap(df, columns=None, save_name=None, size=(8, 10)):

    plt.figure(figsize=size, dpi=120, facecolor="white")

    adv_labels = df.index
    if columns:
        df = df.loc[:, columns]
    df = df.astype('float')
    # Displaying dataframe as an heatmap
    # with diverging colourmap as RdYlBu
    plt.imshow(df, cmap="plasma")
    # plt.imshow(df, cmap="gist_rainbow")
    # plt.imshow(df, cmap="jet")
    # plt.imshow(df, cmap="viridis")
    # plt.autoscale(enable=True, axis='both')
    # Displaying a color bar to understand
    # which color represents which range of data
    plt.colorbar()
    # Assigning labels of x-axis
    # according to dataframe
    plt.xticks(range(len(df.columns)), df.columns, rotation=-30)
    # Assigning labels of y-axis
    # according to dataframe
    plt.yticks(range(len(df.index)), adv_labels)
    # Displaying the figure
    plt.show()

def sample_counts(frq_table, label, 
                  rows=pd.Series(dtype='string'), 
                  columns=pd.Series(dtype='string')):

    s = frq_table.iloc[:int(frq_table.shape[0]/4), :int(frq_table.shape[1]/3)]

    rows = rows if any(rows) else s.sample(16).index
    columns = columns if any(columns) else s.T.sample(8).index
    sample_df = s.loc[rows, columns]
    # print(sample_df.describe().T.round(2).to_markdown())
    # fig = plt.figure(figsize=(6, 8), dpi=300)
    fig = plt.figure(dpi=130)
    # ax.barh(s20x10, width=1)
    sample_df.plot(kind='barh',
                   width=0.8,
                   figsize=(8, 10),
                   position=1,
                   title=f'{label} of sample',
                   grid=True,
                   #  colormap="gist_rainbow",
                   #  colormap="brg",
                   #    colormap="nipy_spectral_r",
                   colormap="Set1",
                   ax=plt.gca())
    plt.show()
    fig = plt.figure(dpi=150)
    sample_df.plot(kind='barh',
                   stacked=True,
                   width=0.8,
                   figsize=(8, 10),
                   position=1,
                   title=f'{label} of sample',
                   grid=True,
                   #  colormap="gist_rainbow",
                   #  colormap="brg",
                   #    colormap="nipy_spectral_r",
                   colormap="Set1",
                   ax=plt.gca()
                   )
    plt.show()
    heatmap(sample_df, size=(8, 10))
    # print(sample_df.round().to_markdown(floatfmt=',.0f'))

    return s, sample_df

# %% [markdown]
#   ## Standardization & Normalization
#   Don't want to use `zscore` because it will understate real variation for frequency vectors with large ranges, and exaggerate variation for vectors with small ranges.
#
#   Instead, use *mean-standardization* as recommended in Moisl (2015). I.e. divide each vector by its mean. This will yield vector of floats > 0.
#
#   🤚 there may be an issue if the mean value is ever 0, because the mean standardized values will be undefined (`NaN`)

# %%
def standardize(df):
    if any(df.mean() == 0):
        print('WARNING: data contains vectors with mean of 0')
    token_info = df.mean().to_frame().rename(columns={0: 'token_mean'})
    print(token_info.assign(total=df.sum()).sort_values(
        'token_mean', ascending=False))
    mdf = df.apply(lambda col: col / (col.mean()))
    # z = s.apply(zscore)
    # m.columns = 'ms_' + m.columns
    # z.columns = 'zs_' + z.columns
    # print('standard deviation of mean-standardized columns')
    cvar = mdf.apply(pd.DataFrame.std).round(3)
    # print('coefficient of variation of raw frequency columns (std/mean)')
    # print([round(s[c].std()/s[c].mean(), 3) for c in s.columns])
    # return m, z, cvar
    return mdf, cvar

sample_lemmas = {
    'adv': frq_table.T.sample(10).sort_index().index.to_list(), 
    'adj': frq_table.sample(20).sort_index().index.to_list()
}

# %% [markdown]
#  ### Mean-standardized by **adverb**

# %%
Rm_df, Rvar = standardize(frq_table)
# Out:
#                token_mean    total
# adv_lemma
# very          2573.133194  9852527
# more          2432.117263  9312577
# most          1967.920084  7535166
# so            1489.295377  5702512
# not           1442.752938  5524301
# ...                   ...      ...
# second-most      0.231131      885
# bracingly        0.230870      884
# deservedly       0.230086      881
# scandalously     0.229303      878
# urgently         0.229042      877
#
# [1021 rows x 2 columns]

# %%
Rvar = Rvar.sort_values(ascending=False)
Rvar.plot(kind='hist')
plt.title('Coefficients of Variance for Adverbs')
plt.show()

# %%
heatmap(Rm_df.sample(20).T.sample(10).T)
heatmap(Rm_df.loc[sample_lemmas['adj'], sample_lemmas['adv']] )

# %%
Rvar.nlargest(20)
# Out:
# adv_lemma
# chock         61.852
# scantily      61.501
# crystal       61.324
# nerve         61.041
# brand         60.914
# de            60.864
# proof         60.028
# upwardly      59.446
# squeaky       59.392
# middle        59.243
# hiv           58.776
# golden        58.747
# spotlessly    58.275
# funnily       57.154
# thinly        56.530
# vitally       56.241
# wide          56.194
# terminally    55.928
# closely       54.924
# at            54.750
# dtype: float64

# %%
Rvar.plot()
plt.title('Coefficients of Variance for Adverbs')
plt.xlabel('(adverbs by decreasing variance)')
plt.show()

# %% [markdown]
#  💾 *Save **Adverb** Mean Standardized Frequency Data*

# %%
thresh = int(input_csv.name.split('.')[0].split('_thresh')[1])
limit = min(frq_table.sum())
lim_label = ''
if limit > thresh:
    lim_label = f'_LIMIT{min(frq_table.sum())}'

adv_ms_stem = f"{input_csv.stem}{lim_label}_ADV-mn-std"
print(f'Saving adverb mean standardized frequency data as {adv_ms_stem}.csv')
# Out:
# Saving adverb mean standardized frequency data as all-frq_thresh877.35f_ADV-mn-std.csv

# %%
Rm_df.to_csv(input_csv.with_stem(adv_ms_stem))

# %% [markdown]
#  ### Mean-standardized by **adjective**

# %%
Jm_df, Jvar = standardize(frq_table.T)
Jvar = Jvar.sort_values(ascending=False)
# Out:
#                   token_mean    total
# adj_lemma
# good             2847.058766  2906847
# many             2424.337904  2475249
# important        2166.793340  2212296
# much             1988.283056  2030037
# likely           1034.741430  1056471
# ...                      ...      ...
# directional         0.860921      879
# anti-democratic     0.860921      879
# panicked            0.859941      878
# long-winded         0.858962      877
# pointy              0.858962      877
#
# [3829 rows x 2 columns]

# %%
heatmap(Jm_df.sample(10).T.sample(20), size=(10, 7))
heatmap(Jm_df.T.loc[sample_lemmas['adj'], sample_lemmas['adv']] )

# %%
Jvar.nlargest(10)
# Out:
# adj_lemma
# rigueur           31.953
# away              31.731
# wanted            31.502
# wracking          31.455
# marrow            31.354
# own               31.343
# first             30.318
# intentioned       29.971
# populous          28.702
# inconsiderable    28.459
# dtype: float64

# %%
Jm_df.round(3)
# Out:
# adj_lemma     good             many             important        \
# adv_lemma
# very                  226.338            8.747          164.713
# more                    7.383            0.154          141.172
# most                    2.065            0.058          344.648
# so                     52.425          491.292           48.303
# not                    50.038           24.087           11.145
# ...                       ...              ...              ...
# second-most             0.000            0.000            0.052
# bracingly               0.001            0.000            0.000
# deservedly              0.002            0.000            0.000
# scandalously            0.004            0.000            0.000
# urgently                0.001            0.000            0.055
#
# adj_lemma     much             likely           more             \
# adv_lemma
# very                   21.137           34.432            0.068
# more                    0.051          481.570            1.610
# most                    0.011          185.373            0.089
# so                    308.333            0.819            2.909
# not                    40.185           60.950           18.063
# ...                       ...              ...              ...
# second-most             0.000            0.014            0.000
# bracingly               0.000            0.000            0.000
# deservedly              0.000            0.000            0.000
# scandalously            0.000            0.000            0.000
# urgently                0.000            0.000            0.003
#
# adj_lemma     easy             different        difficult        \
# adv_lemma
# very                  128.425          259.806          227.911
# more                    7.531           13.651          267.664
# most                    1.630            1.524           93.149
# so                     90.545           43.896           32.252
# not                   134.089            5.370           30.985
# ...                       ...              ...              ...
# second-most             0.000            0.000            0.013
# bracingly               0.001            0.015            0.002
# deservedly              0.001            0.000            0.001
# scandalously            0.007            0.002            0.002
# urgently                0.000            0.001            0.000
#
# adj_lemma     available        ...  argumentative    distinguishing   \
# adv_lemma                      ...
# very                    0.490  ...           91.347           33.608
# more                   11.785  ...          137.598           45.198
# most                    1.684  ...           45.095          890.043
# so                      0.596  ...           40.470            1.159
# not                   174.920  ...           72.846            0.000
# ...                       ...  ...              ...              ...
# second-most             0.000  ...            0.000            0.000
# bracingly               0.000  ...            0.000            0.000
# deservedly              0.000  ...            0.000            0.000
# scandalously            0.000  ...            0.000            0.000
# urgently                0.004  ...            1.156            0.000
#
# adj_lemma     famed            non-partisan     contiguous       \
# adv_lemma
# very                   11.602           23.205            4.646
# more                  135.747           17.403          123.124
# most                  756.468           27.845            9.292
# so                     18.564            8.122            6.969
# not                     0.000           20.884          249.733
# ...                       ...              ...              ...
# second-most             0.000            0.000            0.000
# bracingly               0.000            0.000            0.000
# deservedly              0.000            0.000            0.000
# scandalously            0.000            0.000            0.000
# urgently                0.000            0.000            0.000
#
# adj_lemma     directional      anti-democratic  panicked         \
# adv_lemma
# very                  108.024           27.877           62.795
# more                  257.863           24.392          184.896
# most                   60.400           80.147           36.049
# so                      9.292           11.615          109.310
# not                    41.816           26.716            9.303
# ...                       ...              ...              ...
# second-most             0.000            0.000            0.000
# bracingly               0.000            0.000            0.000
# deservedly              0.000            0.000            0.000
# scandalously            0.000            0.000            0.000
# urgently                0.000            0.000            0.000
#
# adj_lemma     long-winded      pointy
# adv_lemma
# very                  109.434          174.629
# more                   81.494          103.613
# most                   31.433            9.314
# so                     55.881           53.553
# not                    17.463           50.060
# ...                       ...              ...
# second-most             0.000            0.000
# bracingly               0.000            0.000
# deservedly              0.000            0.000
# scandalously            0.000            0.000
# urgently                0.000            0.000
#
# [1021 rows x 3829 columns]

# %%
Jvar.plot(kind='hist')
plt.title('Coefficients of Variance for Adjectives')
plt.show()

# %%
Jvar.plot()
plt.title('Coefficients of Variance for Adjectives')
plt.xlabel('(adjectives by decreasing variance)')
plt.show()

# %% [markdown]
#  💾 *Save **Adjective** Mean Standardized Frequency Data*

# %%
adj_ms_stem = f"{input_csv.stem}{lim_label}_ADJ-mn-std"
print(
    f'Saving adjective mean standardized frequency data as {adj_ms_stem}.csv')
# Out:
# Saving adjective mean standardized frequency data as all-frq_thresh877.35f_ADJ-mn-std.csv

# %%
Jm_df.to_csv(input_csv.with_stem(adj_ms_stem))

# %% [markdown]
#  ## Looking at the lemmas showing the most variance
#
#  That is, the adverbs that only show up with particular adjectives and the adjectives that only show up with particular adverbs.

# %%
N = 20
Rvar.nlargest(N)
# Out:
# adv_lemma
# chock         61.852
# scantily      61.501
# crystal       61.324
# nerve         61.041
# brand         60.914
# de            60.864
# proof         60.028
# upwardly      59.446
# squeaky       59.392
# middle        59.243
# hiv           58.776
# golden        58.747
# spotlessly    58.275
# funnily       57.154
# thinly        56.530
# vitally       56.241
# wide          56.194
# terminally    55.928
# closely       54.924
# at            54.750
# dtype: float64

# %%
most_var_R = Rvar.nlargest(N).index
preferred_J = pd.Series(Rm_df[r].loc[Rm_df[r] == Rm_df[r].max(
)].index[0] for r in most_var_R).drop_duplicates().to_list()
# preferred_J
Rm_df.loc[preferred_J, most_var_R].round().apply(
    pd.to_numeric, downcast='unsigned')
# Out:
# adv_lemma  chock       scantily    crystal     nerve       brand       \
# adj_lemma
# full             3827           0           0           0           0
# clad                0        3806           0           0           0
# clear               0           0        3795           0           0
# wracking            0           0           0        3777           0
# new                 0           0           0           0        3769
# rigueur             0           0           0           0           0
# positive            0           0           0           0           0
# mobile              0           0           0           0           0
# clean               0           0          11           0           0
# aged                0           0           0           0           0
# brown               0           0           0           0           0
# enough              0           0           0           0           0
# veiled              0           0           0           0           0
# important           0           0           0           0           0
# open                0           0           0           0           0
# ill                 0           0           0           0           0
# related             0           0           0          12           0
# good                0           0           0           0           0
#
# adv_lemma  de          proof       upwardly    squeaky     middle      \
# adj_lemma
# full                0           0           0           0           0
# clad                0           0           0           0           0
# clear               0           0           0           7           0
# wracking            0           0           0           0           0
# new                 0           0           0           7           0
# rigueur          3766           0           0           0           0
# positive            0        3714           2           0           0
# mobile              0           0        3678           0           0
# clean               0           0           0        3675           0
# aged                0           0           0           0        3665
# brown               0           0           0           0           0
# enough              0          58           0           4           0
# veiled              0           0           0           0           0
# important           0           0           0           0           0
# open                0           0          18           0           0
# ill                 0           0           0           0           0
# related             0           0           0           0           0
# good                0           0           2           0           0
#
# adv_lemma  hiv         golden      spotlessly  funnily     thinly      \
# adj_lemma
# full                0           0           0           0           0
# clad                0           0           0           0          69
# clear               0           8          17           0           0
# wracking            0           0           0           0           0
# new                 0           0           0           0           0
# rigueur             0           0           0           0           0
# positive         3633           0           0           0           2
# mobile              0           0           0           0           0
# clean               0           0        3605           0           0
# aged                0           2           0           0           0
# brown               0        3634           0           0           0
# enough              0           0           0        3536           4
# veiled              0           0           0           0        3497
# important           0           0           0           0           0
# open                0           0           0           0           0
# ill                 0           0           0           0           0
# related             0           0           0           0          11
# good                0           3           2           0           0
#
# adv_lemma  vitally     wide        terminally  closely     at
# adj_lemma
# full                0           0           0           0           1
# clad                0           0           0           0           0
# clear               1           0           0           0           0
# wracking            0           0           0           0           0
# new                 1           0           0           1           1
# rigueur             0           0           0           0           0
# positive            0           0           0           0           0
# mobile              0           0           0           0           0
# clean               0           1           0           0           0
# aged                0           0           0           0           5
# brown               0           0           0           0           0
# enough              0          58           0          38           0
# veiled              0           0           0           0           0
# important        3479           0           0           1           1
# open                0        3471           0           0           0
# ill                 0           0        3461           0           0
# related             3           0           0        3397           0
# good                1           1           0           0        3384

# %% [markdown]
#  *Above table repeated with **raw counts**:*

# %%
frq_table.loc[preferred_J, most_var_R].round().apply(
    pd.to_numeric, downcast='unsigned')
# Out:
# adv_lemma  chock       scantily    crystal     nerve       brand       \
# adj_lemma
# full             2339           0           0           0           0
# clad                0        5365           0           0           0
# clear               0           0        9609           0           0
# wracking            0           0           0         946           0
# new                 0           0           0           0       46484
# rigueur             0           0           0           0           0
# positive            0           0           0           0           4
# mobile              0           0           0           0           0
# clean               0           0          28           0           0
# aged                0           0           0           0           0
# brown               0           0           0           0           0
# enough              0           0           0           0           0
# veiled              0           0           0           0           0
# important           0           0           0           0           0
# open                0           0           0           0           0
# ill                 0           0           0           0           0
# related             0           0           0           3           1
# good                0           0           0           0           2
#
# adv_lemma  de          proof       upwardly    squeaky     middle      \
# adj_lemma
# full                0           0           0           0           0
# clad                0           0           0           0           0
# clear               0           0           0           2           0
# wracking            0           0           0           0           0
# new                 0           0           0           2           0
# rigueur          1499           0           0           0           0
# positive            0        1550           1           0           0
# mobile              0           0        2098           0           0
# clean               0           0           0        1002           0
# aged                0           0           0           0        2206
# brown               0           0           0           0           0
# enough              0          24           0           1           0
# veiled              0           0           0           0           0
# important           0           0           0           0           0
# open                0           0          10           0           0
# ill                 0           0           0           0           0
# related             0           0           0           0           0
# good                0           0           1           0           0
#
# adv_lemma  hiv         golden      spotlessly  funnily     thinly      \
# adj_lemma
# full                0           0           0           0           0
# clad                0           0           0           0          31
# clear               0           5           7           0           0
# wracking            0           0           0           0           0
# new                 0           0           0           0           0
# rigueur             0           0           0           0           0
# positive         1091           0           0           0           1
# mobile              0           0           0           0           0
# clean               0           0        1516           0           0
# aged                0           1           0           0           0
# brown               0        2351           0           0           0
# enough              0           0           0         834           2
# veiled              0           0           0           0        1560
# important           0           0           0           0           0
# open                0           0           0           0           0
# ill                 0           0           0           0           0
# related             0           0           0           0           5
# good                0           2           1           0           0
#
# adv_lemma  vitally     wide        terminally  closely     at
# adj_lemma
# full                1           4           0           0           1
# clad                0           0           0           1           0
# clear               4           1           0           0           0
# wracking            0           0           0           0           0
# new                 4           2           0           5           1
# rigueur             0           0           0           0           0
# positive            2           2           1           1           0
# mobile              0           0           0           0           0
# clean               0           5           1           1           0
# aged                0           2           0           3           4
# brown               0           0           0           0           0
# enough              1         551           0         306           0
# veiled              0           0           0           0           0
# important       17199           2           0           4           1
# open                0       32807           0           0           0
# ill                 2           0       15971           0           0
# related            13           2           0       27148           0
# good                6          11           2           0        2819

# %% [markdown]
#  👀 Note that preference is not necessarily bidirectional ⇎
#
#  For example, the adverb lemmas, *`squeaky`* and *`spotlessly`* are both highly skewed, but they prefer the same adjective, *`clean`*.
#
#  However, as shown below, *`clean`* shows no such preference for these adverbs—*`spotlessly`* is ranked $15^{th}$ and *`squeaky`* $18^{th}$.

# %% [markdown]
#  ### Comparison of Mean Standardized Frequencies

# %%
clean_top18 = Jm_df['clean']
clean_top18 = clean_top18.sort_values(
    ascending=False)[:18].to_frame().reset_index()
clean_top18.index = [1+i for i in range(18)]

clean_top18.set_index('adv_lemma')['clean'].plot(kind='barh')
plt.title('Adverbs seen most often with CLEAN')
plt.xlabel('(adj-mean-standardized frequencies)')
plt.show()

# %% [markdown]
#  ### Comparison of Raw Count Frequencies

# %%
frq_table.T.sort_values('clean', ascending=False)[
    'clean'].iloc[:20].plot(kind='barh')
plt.title('Adverbs seen most often with CLEAN')
plt.xlabel('(raw frequencies)')
plt.show()

# %%
Jvar.nlargest(N)
# Out:
# adj_lemma
# rigueur           31.953
# away              31.731
# wanted            31.502
# wracking          31.455
# marrow            31.354
# own               31.343
# first             30.318
# intentioned       29.971
# populous          28.702
# inconsiderable    28.459
# same              28.028
# distinguishing    27.913
# binding           27.673
# unreleased        27.395
# leeway            27.247
# storied           26.942
# chopped           26.937
# never-ending      26.881
# regarded          26.798
# ardent            26.681
# dtype: float64

# %%
most_var_J = Jvar.nlargest(N).index
preferred_R = pd.Series(Jm_df[j].loc[Jm_df[j] == Jm_df[j].max(
)].index[0] for j in most_var_J).drop_duplicates().to_list()

Jm_df.loc[preferred_R, most_var_J].round(
    0).apply(pd.to_numeric, downcast='unsigned')
# Out:
# adj_lemma   rigueur         away            wanted          wracking        \
# adv_lemma
# de                    1021               0               0               0
# far                      0            1014               0               0
# most                     0               0            1007               1
# nerve                    0               0               0            1005
# bone                     0               0               0               0
# very                     0               0               2               0
# well                     0               1               0               0
# not                      0               0               0               0
# legally                  0               0               0               0
# previously               0               0               0               0
# more                     0               0               5               0
# finely                   0               0               0               0
# seemingly                0               0               0               0
# highly                   0               0               0               0
#
# adj_lemma   marrow          own             first           intentioned     \
# adv_lemma
# de                       0               0               0               0
# far                      0               0               0               0
# most                     0               1               7               1
# nerve                    0               0               0               0
# bone                  1002               0               0               0
# very                    14            1002             969               1
# well                     0               0               0             958
# not                      0               1               1               1
# legally                  0               0               0               0
# previously               0               0               0               0
# more                     1               1               9               2
# finely                   0               0               0               0
# seemingly                0               0               0               0
# highly                   0               0               0               0
#
# adj_lemma   populous        inconsiderable  same            distinguishing  \
# adv_lemma
# de                       0               0               0               0
# far                      0               0               0               0
# most                   915               9               1             890
# nerve                    0               0               0               0
# bone                     0               0               0               0
# very                     4              32             895              34
# well                     0               0               0               1
# not                      0             908              14               0
# legally                  0               0               0               0
# previously               0               1               0               0
# more                    53               1               4              45
# finely                   0               0               0               0
# seemingly                0               0               0               0
# highly                   2               0               0               3
#
# adj_lemma   binding         unreleased      leeway          storied         \
# adv_lemma
# de                       0               0               0               0
# far                      0               3               0               0
# most                     1               1              25             858
# nerve                    0               0               0               0
# bone                     0               0               0               0
# very                     1               0               0              33
# well                     0               0               0               0
# not                      0               0               1               0
# legally                884               0               0               0
# previously               0             874               0               0
# more                    17              15             866              57
# finely                   0               0               0               0
# seemingly                0               0               0               0
# highly                   0               0               0               0
#
# adj_lemma   chopped         never-ending    regarded        ardent
# adv_lemma
# de                       0               0               0               0
# far                      0               0               0               0
# most                     0               0               1             850
# nerve                    0               0               0               0
# bone                     0               0               0               0
# very                     0               0               0              12
# well                     1               0              26               0
# not                      0               3               0               2
# legally                  0               0               0               0
# previously               0               0               0               1
# more                     5               5               0              63
# finely                 855               0               0               0
# seemingly                0             858               0               0
# highly                   0               0             849               0

# %% [markdown]
#  > With Raw Counts:

# %%
frq_table.T.loc[preferred_R, most_var_J]
# Out:
# adj_lemma   rigueur         away            wanted          wracking        \
# adv_lemma
# de                    1499               0               0               0
# far                      0            1283               0               0
# most                     0               0            3354               1
# nerve                    0               0               0             946
# bone                     0               0               0               0
# very                     0               0               6               0
# well                     0               1               0               0
# not                      0               0               0               0
# legally                  0               0               0               0
# previously               0               0               0               0
# more                     0               0              16               0
# finely                   0               0               0               0
# seemingly                0               0               0               0
# highly                   0               0               1               0
#
# adj_lemma   marrow          own             first           intentioned     \
# adv_lemma
# de                       0               0               0               0
# far                      0               0              19               0
# most                     0              52            1065               1
# nerve                    0               0               0               0
# bone                  1147               0               0               0
# very                    16           95849          149883               1
# well                     0               9              71            1830
# not                      0             112             220               2
# legally                  0              14               0               0
# previously               0               3               5               0
# more                     1              90            1457               3
# finely                   0               0               0               0
# seemingly                0               1               5               0
# highly                   0               2               9               0
#
# adj_lemma   populous        inconsiderable  same            distinguishing  \
# adv_lemma
# de                       0               0               1               0
# far                      0               0               2               0
# most                 29390               9              61             768
# nerve                    0               0               0               0
# bone                     0               0               0               0
# very                   137              33           49164              29
# well                     0               0               7               1
# not                     12             928             756               0
# legally                  0               0               1               0
# previously               2               1               3               0
# more                  1693               1             199              39
# finely                   0               0               0               0
# seemingly                0               0              20               0
# highly                  69               0               4               3
#
# adj_lemma   binding         unreleased      leeway          storied         \
# adv_lemma
# de                       0               0               0               0
# far                      0              17               0               0
# most                     2               5              24            1053
# nerve                    0               0               0               0
# bone                     0               0               0               0
# very                     2               1               0              41
# well                     0               1               0               0
# not                      0               2               1               0
# legally               2429               0               0               0
# previously               0            4830               0               0
# more                    47              83             847              70
# finely                   0               0               0               0
# seemingly                0               0               0               0
# highly                   0               0               0               0
#
# adj_lemma   chopped         never-ending    regarded        ardent
# adv_lemma
# de                       0               0               0               0
# far                      0               0               0               0
# most                     0               0               3            7356
# nerve                    0               0               0               0
# bone                     0               0               0               0
# very                     0               1               0             108
# well                     1               0             111               0
# not                      0               6               0              14
# legally                  0               0               0               0
# previously               0               0               1               9
# more                     5              10               1             541
# finely                 914               0               0               1
# seemingly                0            1865               0               1
# highly                   0               0            3561               1

# %% [markdown]
#  Another clear indication of lack of bidirectional preference: ***`most`*** is the strongly preferred adverb for 5 different adjectives:
#  1. *`wanted`*
#  2. *`populous`*
#  3. *`distinguishing`*
#  4. *`storied`*
#  5. *`ardent`*
#
#  Yet, none of these make even the top 20 collocates for *`most`*.
#
#  Keep in mind that the frequency scale here is *mean-standardized*: For example, *`important`* is almost **500 times** more likely to follow *`most`* than the mean adjective co-occurence frequency for *`most`*

# %%
most_top20 = Rm_df['most'].sort_values(
    ascending=False).to_frame().reset_index().iloc[:20]
most_top20.index = [1+i for i in range(len(most_top20))]
most_top20.round(2)
# Out:
#       adj_lemma    most
# 1     important  379.48
# 2       popular  197.10
# 3        recent  154.64
# 4        common  138.38
# 5        likely   97.47
# 6        famous   83.92
# 7     effective   75.63
# 8      powerful   75.56
# 9    successful   57.04
# 10    beautiful   53.06
# 11  significant   44.07
# 12  interesting   42.94
# 13    difficult   38.93
# 14    expensive   37.01
# 15     valuable   33.04
# 16    prominent   32.68
# 17  influential   31.89
# 18     exciting   31.30
# 19    dangerous   30.75
# 20   vulnerable   30.18

# %%
most_top20.set_index('adj_lemma')['most'].plot(kind='barh')
plt.title('Adjectives seen most often following "most"')
plt.xlabel('(mean-standardized frequencies)')
plt.show()
