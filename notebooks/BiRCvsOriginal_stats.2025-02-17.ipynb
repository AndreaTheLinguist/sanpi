# %% [markdown]
# # Compilation of All Counts for <font color=DodgerBlue><u>*Original Corpora*</u></font> & <font color=Brown><u>***BiRC***</u></font>
# ___`BiRC`___ $=\text{``bigram restricted corpus'' or }\texttt{bigram\_subset}$

# %% [markdown]
# ### *imports*

# %%
from pathlib import Path
import pandas as pd
from am_notebooks import *

#! Toggle TESTING
TESTING = False
if TESTING:
    print(
        '🚨⚠️ WARNING!\n  This is a **TEST** run!'
        'Full count data will not be loaded or saved\n'
    )

# // from utils import file_size_round
SUBSET_DATA_DIR = Path('/share/compling/data/sanpi/subsets')
print(
    '==============================\n'
    f'Date: {pd.Timestamp.now().ctime()}\n'
    '=============================='
)
BIGRAMS_PER_CONLLU_CSV = SANPI_HOME.joinpath('info/raw_bigram_counts.csv')
BIRC_INFO_DIR = SANPI_HOME.joinpath('info/BiRC')
confirm_dir(BIRC_INFO_DIR)
BIRC_META_CSV = BIRC_INFO_DIR.joinpath('meta-info-full.csv')
REL_BIRC_TEX_DIR ='ch6/BiRC'
BIRC_TEX_DIR = LATEX_TABLES.joinpath(REL_BIRC_TEX_DIR)
confirm_dir(BIRC_TEX_DIR)
# Out:
# ==============================
# Date: Tue Feb 18 22:56:09 2025
# ==============================

# %% [markdown]
# ## **<font color=grey>Meta Info</font>**

# %% [markdown]
# ### **Define functions** to compile all the disparate meta info...

# %%
def collect_subset_path_index():
    """Collect subset path index information.

    This function gathers information about subset paths, including parent directory,
    name, full path, source path (from symlink), BiRC subcorpus, size, and other
    relevant details. It then processes this information to create a DataFrame with
    additional derived columns, such as 'init_conllu', 'data_key', 'corpus_part',
    'corpus', 'subset_info_dir', and 'path_index_csv'.

    Returns:
        pd.DataFrame: A DataFrame containing the collected subset path index info.
    """
    data = {p.stem:
            {
                'parent': p.parent.name,
                'name': p.name,
                'path': p,
                'source_path': p.readlink(),
                'birc_subcorpus': p.parent.parent.stem,
                'is_link': p.is_symlink(),
                # 'size': file_size_round(p.stat().st_size),
                'size': p.stat().st_size,  # ! no longer forcing into different units
            }
            for p in SUBSET_DATA_DIR.rglob('*.conllu')
            #! to prevent *DEMO* files being included:
            if not p.parent.name.startswith('bigram-DEMO')
            }
    bp_df = pd.DataFrame.from_dict(data, orient='index').convert_dtypes()
    bp_df
    bp_df['init_conllu'] = bp_df.name.str.replace('BIGRAM.', '', regex=False)
    bp_df['data_key'] = bp_df.index.str.replace('BIGRAM.', '', regex=False)

    bp_df['corpus_part'], bp_df['corpus'], bp_df['subset_info_dir'] = zip(
        *bp_df.source_path.apply(
            lambda sp: (sp.parent.parent.stem,
                        sp.parent.parent.parent.stem,
                        sp.parent.joinpath('info')))
    )
    bp_df = bp_df.convert_dtypes()

    set_my_style(bp_df.sample(1).T)

    bp_df['path_index_csv'] = bp_df.subset_info_dir.apply(
        lambda i: max(i.glob('subset-bigram_path-index*csv'),
                      key=lambda file: file.stat().st_ctime))

    try:
        path_info = pd.read_csv(X.path_index_csv,
                                usecols=['STEM', ' INPUT_COUNTS',
                                         ' SUBSET_COUNTS']
                                ).set_index('STEM')
    except ValueError:
        path_info = pd.read_csv(X.path_index_csv,
                                usecols=['STEM', 'INPUT_COUNTS',
                                         'SUBSET_COUNTS']
                                ).set_index('STEM')

    path_info.columns = path_info.columns.str.strip().str.lower()
    path_info.columns

    for stem in path_info.sample(3).T:
        print(f'- {stem}')
        print(f'  - input_counts = {path_info.input_counts[stem]}')
        print(f'  - subset_counts = {path_info.subset_counts[stem]}')

    bp_df.index.name = 'subset_stem'
    return bp_df.reset_index().set_index('data_key')


def collect_meta_info(_bp_df):
    """Collect metadata information from various sources.

    This function groups the input DataFrame by 'path_index_csv', reads data from
    corresponding CSV files, joins the data with the original DataFrame, and
    concatenates the results into a single DataFrame. It also performs some
    string cleaning on the resulting DataFrame's columns.

    Args:
        _bp_df (pd.DataFrame): DataFrame containing file paths and other info.

    Returns:
        pd.DataFrame: A DataFrame containing the combined metadata information.
    """
    subframes = []
    for path_ix, df in _bp_df.groupby('path_index_csv'):
        print(path_ix)
        if 'DEMO' in str(path_ix):
            continue
        try:
            path_info = pd.read_csv(
                path_ix,
                usecols=['STEM', ' INPUT_COUNTS', ' SUBSET_COUNTS']
            ).set_index('STEM')
        except ValueError:
            path_info = pd.read_csv(
                path_ix,
                usecols=['STEM', 'INPUT_COUNTS', 'SUBSET_COUNTS']
            ).set_index('STEM')
        display(set_my_style(df.head(1).T, caption=str(
            path_ix.relative_to('/share/compling/data'))))
        subframes.append(df.join(path_info))

    meta_df = pd.concat(subframes)
    meta_df.iloc[:, -2:] = meta_df.iloc[:, -2:].apply(lambda x: x.str.strip())
    meta_df.columns = meta_df.columns.str.strip().str.lower()
    return meta_df

# %% [markdown]
# ### **Create or read meta info**

# %%
if BIRC_META_CSV.is_file():
    meta_df = pd.read_csv(BIRC_META_CSV, index_col='data_key').convert_dtypes()
    print(f'Meta Info DataFrame loaded from "{BIRC_META_CSV}"')
else:
    bp_df = collect_subset_path_index()
    meta_df = collect_meta_info(bp_df)
    meta_df.to_csv(BIRC_META_CSV)

set_my_style(
    meta_df.head(1).T,
    caption='First Line of Meta DataFrame')
# Out:
# Meta Info DataFrame loaded from "/share/compling/projects/sanpi/info/BiRC/meta-info-full.csv"
# <style type="text/css">
# #T_2fec8 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_2fec8 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2fec8 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2fec8 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_2fec8_row0_col0, #T_2fec8_row1_col0, #T_2fec8_row2_col0, #T_2fec8_row3_col0, #T_2fec8_row4_col0, #T_2fec8_row5_col0, #T_2fec8_row6_col0, #T_2fec8_row7_col0, #T_2fec8_row8_col0, #T_2fec8_row9_col0, #T_2fec8_row10_col0, #T_2fec8_row11_col0, #T_2fec8_row12_col0, #T_2fec8_row13_col0, #T_2fec8_row14_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_2fec8">
#   <caption>First Line of Meta DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_key</th>
#       <th id="T_2fec8_level0_col0" class="col_heading level0 col0" >apw_eng_199411</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fec8_level0_row0" class="row_heading level0 row0" >subset_stem</th>
#       <td id="T_2fec8_row0_col0" class="data row0 col0" >BIGRAM.apw_eng_199411</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row1" class="row_heading level0 row1" >parent</th>
#       <td id="T_2fec8_row1_col0" class="data row1 col0" >bigram-Apw</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row2" class="row_heading level0 row2" >name</th>
#       <td id="T_2fec8_row2_col0" class="data row2 col0" >BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row3" class="row_heading level0 row3" >path</th>
#       <td id="T_2fec8_row3_col0" class="data row3 col0" >/share/compling/data/sanpi/subsets/bigram_news/bigram-Apw/BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row4" class="row_heading level0 row4" >source_path</th>
#       <td id="T_2fec8_row4_col0" class="data row4 col0" >/share/compling/data/news/Apw.conll/subset_bigram/BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row5" class="row_heading level0 row5" >birc_subcorpus</th>
#       <td id="T_2fec8_row5_col0" class="data row5 col0" >bigram_news</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row6" class="row_heading level0 row6" >is_link</th>
#       <td id="T_2fec8_row6_col0" class="data row6 col0" >True</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row7" class="row_heading level0 row7" >size</th>
#       <td id="T_2fec8_row7_col0" class="data row7 col0" >11,162,354</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row8" class="row_heading level0 row8" >init_conllu</th>
#       <td id="T_2fec8_row8_col0" class="data row8 col0" >apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row9" class="row_heading level0 row9" >corpus_part</th>
#       <td id="T_2fec8_row9_col0" class="data row9 col0" >Apw</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row10" class="row_heading level0 row10" >corpus</th>
#       <td id="T_2fec8_row10_col0" class="data row10 col0" >news</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row11" class="row_heading level0 row11" >subset_info_dir</th>
#       <td id="T_2fec8_row11_col0" class="data row11 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row12" class="row_heading level0 row12" >path_index_csv</th>
#       <td id="T_2fec8_row12_col0" class="data row12 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info/subset-bigram_path-index.2023-04-11_0525.csv</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row13" class="row_heading level0 row13" >input_counts</th>
#       <td id="T_2fec8_row13_col0" class="data row13 col0" >/share/compling/data/news/Apw.conll/info/apw_eng_199411.counts.json</td>
#     </tr>
#     <tr>
#       <th id="T_2fec8_level0_row14" class="row_heading level0 row14" >subset_counts</th>
#       <td id="T_2fec8_row14_col0" class="data row14 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info/BIGRAM.apw_eng_199411.counts.json</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## **<font color=violet>Frequency Info</font>**

# %% [markdown]
# ### Total Bigram *hits* per file
#
# Total bigram hits——not *sentences* or *tokens*——are loaded from `BIGRAMS_PER_CONLLU_CSV` (i.e. `info/raw_bigram_counts.csv`).
# It looks like this:
# > ```csv
# > raw_hits_path,total
# > bigram-Apw.rb-bigram/BIGRAM.apw_eng_199411.raw.json,9770
# > bigram-Apw.rb-bigram/BIGRAM.apw_eng_199412.raw.json,15134
# > bigram-Apw.rb-bigram/BIGRAM.apw_eng_199501.raw.json,15909
# > ```
# First column indicates the `.raw.json` collection of `rb-bigram` matches found in the associated `.conllu` file, e.g.: \
#
# - first line: `bigram-Apw.rb-bigram/BIGRAM.apw_eng_199411.raw.json,9770`
#
#   indicates that
#
# - `BIGRAM.apw_eng_199411.conllu` matched the `rb-bigram.pat` pattern specs $9,770$ times
#
# Since this is the `rb-bigram` pattern which was used for *creating* `BIGRAM.apw_eng_199411.conllu`, the original, unrestricted `apw_eng_199411.conllu` file also contains $9,770$ hits.

# %%
def load_bigram_totals():

    bg_totals = pd.read_csv(BIGRAMS_PER_CONLLU_CSV).convert_dtypes().rename(columns={'total':'bigrams'})
    bg_totals['corpus_slice']=bg_totals.raw_hits_path.apply(lambda p: Path(p).name.split('.')[1])
    return bg_totals.set_index('corpus_slice').bigrams

BIRC_HIT_COUNTS = load_bigram_totals()
BIRC_HIT_COUNTS
# Out:
# corpus_slice
# apw_eng_199411      9770
# apw_eng_199412     15134
# apw_eng_199501     15909
# apw_eng_199502     13613
# apw_eng_199503     16157
#                    ...
# pcc_eng_test-02    29949
# pcc_eng_test-03    29787
# pcc_eng_val-01     26376
# pcc_eng_val-02     29839
# pcc_eng_val-03     29050
# Name: bigrams, Length: 3617, dtype: Int64

# %% [markdown]
# ### *Define functions* to retrieve count data

# %%
def load_totals(counts_path):
    """Load total counts from a JSON file.

    This function reads a JSON file containing counts data, extracts the 'total'
    column, drops any missing values (NaN), and returns the result as a dictionary.
    If the provided path is not absolute, it prepends the sanpi data directory.

    Args:
        counts_path (str or Path): Path to the JSON file.

    Returns:
        dict: A dictionary containing the total counts, with keys corresponding to
            the original index of the 'total' column.
    """

    if not Path(counts_path).is_absolute():
        counts_path = f"/share/compling/data/sanpi/{counts_path}"
    counts_df = pd.read_json(counts_path)
    return counts_df.loc[:, 'total'].dropna().to_dict()


def generate_counts(_meta_df, retrieval_key='input'):
    """Generate counts for each data key.

    This generator iterates through the index of the input DataFrame, retrieves the
    counts path based on the retrieval key, and yields the data key along with its
    corresponding counts.

    Args:
        _meta_df (pd.DataFrame): DataFrame containing metadata information.
        retrieval_key (str, optional): Key used to retrieve the counts path.
            Defaults to 'input'.

    Yields:
        tuple: A tuple containing the data key and its corresponding counts.
    """
    for data_key in _meta_df.index:
        counts_path = _meta_df.at[data_key, f'{retrieval_key}_counts']
        yield data_key, load_totals(counts_path)


def retrieve_count_data(_counts_csv_path, _meta_df, test=False):
    seek_birc = "birc" in _counts_csv_path.name.lower()
    _counts_label = "BiRC" if seek_birc else "Original"
    if _counts_csv_path.is_file():
        try:
            _counts_df = pd.read_csv(_counts_csv_path,
                                     index_col='corpus_slice').convert_dtypes()
        except ValueError:
            _counts_df = pd.read_csv(_counts_csv_path).convert_dtypes()

        print(
            f'**{_counts_label} Counts** read from csv',
            f'> Path: {_counts_csv_path.relative_to(SANPI_HOME)}',
            sep='\n')
    else:
        _meta_selection = _meta_df.copy().sample(100) if test else _meta_df.copy()
        _counts_df = pd.DataFrame.from_dict(
            {k: c for k, c in generate_counts(
                _meta_df=_meta_selection,
                retrieval_key='subset' if seek_birc else 'input')},
            orient='index')
        _counts_df.index.name = 'corpus_slice'
        _counts_df = _counts_df.reset_index().convert_dtypes().set_index('corpus_slice')
        print(
            f'**{_counts_label} Counts** saved as csv',
            f'> Path: {_counts_csv_path.relative_to(SANPI_HOME)}',
            sep='\n')
        if test:
            print('TESTING (so, not really)')
        else:
            _counts_df.to_csv(_counts_csv_path)
    return _counts_df.loc[:, ~_counts_df.columns.str.startswith('NR_')]

# %% [markdown]
# ### **Load <font color=DodgerBlue><u>Original</u></font> counts** (if not previously collected)
#
#  (and add *bigrams* column from `BIRC_HIT_COUNTS`)

# %%
orig_counts_df = retrieve_count_data(
    _counts_csv_path=BIRC_INFO_DIR.joinpath('original-count-data.csv'),
    _meta_df=meta_df,
    test=TESTING
).sort_index().assign(bigrams=BIRC_HIT_COUNTS.sort_index())

orig_counts_df.info()
# Out:
# **Original Counts** read from csv
# > Path: info/BiRC/original-count-data.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3617 entries, apw_eng_199411 to pcc_eng_val-03
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   file_MB     3617 non-null   Float64
#  1   sentences   3617 non-null   Int64
#  2   tokens      3617 non-null   Int64
#  3   ADV_tokens  3617 non-null   Int64
#  4   ADV_xpos    3617 non-null   Int64
#  5   ADV_lemmas  3617 non-null   Int64
#  6   ADV_forms   3617 non-null   Int64
#  7   ADJ_tokens  3617 non-null   Int64
#  8   ADJ_xpos    3617 non-null   Int64
#  9   ADJ_lemmas  3617 non-null   Int64
#  10  ADJ_forms   3617 non-null   Int64
#  11  NEG_tokens  3617 non-null   Int64
#  12  NEG_xpos    3617 non-null   Int64
#  13  NEG_lemmas  3617 non-null   Int64
#  14  NEG_forms   3617 non-null   Int64
#  15  bigrams     3617 non-null   Int64
# dtypes: Float64(1), Int64(15)
# memory usage: 536.9+ KB

# %% [markdown]
# ### **...and <font color=Brown><u>BiRC</u></font> counts** (likewise)
#
# (and add *bigrams* column from `BIRC_HIT_COUNTS`)

# %%
birc_counts_df = retrieve_count_data(
    _counts_csv_path=BIRC_INFO_DIR.joinpath('birc-count-data.csv'),
    _meta_df=meta_df,
    test=TESTING
).sort_index().assign(bigrams=BIRC_HIT_COUNTS.sort_index())

birc_counts_df.info()
# if birc_counts_composite_csv.is_file():
#     birc_counts_df = pd.read_csv(birc_counts_composite_csv).convert_dtypes()
#     print(
#         f'**BiRC Counts** read from csv\n> Path: {birc_counts_composite_csv.relative_to(SANPI_HOME)}')
# else:
#     birc_counts_df = pd.DataFrame.from_dict(
#         # {k:c for k,c in generate_counts(meta_df.head(500), 'subset')}, orient='index')
#         {k: c for k, c in generate_counts(meta_df, 'subset')}, orient='index')
#     pd.to_csv(birc_counts_composite_csv)
#     print(
#         f'**BiRC Counts** saved as csv\n> Path: {birc_counts_composite_csv.relative_to(SANPI_HOME)}')
# Out:
# **BiRC Counts** read from csv
# > Path: info/BiRC/birc-count-data.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3617 entries, apw_eng_199411 to pcc_eng_val-03
# Data columns (total 16 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   file_MB     3617 non-null   Float64
#  1   sentences   3617 non-null   Int64
#  2   tokens      3617 non-null   Int64
#  3   ADV_tokens  3617 non-null   Int64
#  4   ADV_xpos    3617 non-null   Int64
#  5   ADV_lemmas  3617 non-null   Int64
#  6   ADV_forms   3617 non-null   Int64
#  7   ADJ_tokens  3617 non-null   Int64
#  8   ADJ_xpos    3617 non-null   Int64
#  9   ADJ_lemmas  3617 non-null   Int64
#  10  ADJ_forms   3617 non-null   Int64
#  11  NEG_tokens  3617 non-null   Int64
#  12  NEG_xpos    3617 non-null   Int64
#  13  NEG_lemmas  3617 non-null   Int64
#  14  NEG_forms   3617 non-null   Int64
#  15  bigrams     3617 non-null   Int64
# dtypes: Float64(1), Int64(15)
# memory usage: 536.9+ KB

# %% [markdown]
# ## *Describe Count Collections*

# %%
save_latex_table(orig_counts_df.describe().T.iloc[:, 1:].assign(Total=orig_counts_df.sum()).filter(['mean', '50%','Total']).convert_dtypes(),
                 caption='Original Corpora: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=7.1,
                 latex_stem='only-counts-descrip-stats-orig')

save_latex_table(birc_counts_df.describe().T.iloc[:, 1:].assign(Total=birc_counts_df.sum()).filter(['mean', '50%','Total']).convert_dtypes(),
                 caption='BiRC: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=7.1,
                 latex_stem='only-counts-descrip-stats-birc')
# Out:
# Caption: Original Corpora: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
# <style type="text/css">
# #T_ef8e6 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_ef8e6 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_ef8e6 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_ef8e6 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_ef8e6_row0_col0, #T_ef8e6_row0_col1, #T_ef8e6_row0_col2, #T_ef8e6_row1_col0, #T_ef8e6_row1_col1, #T_ef8e6_row1_col2, #T_ef8e6_row2_col0, #T_ef8e6_row2_col1, #T_ef8e6_row2_col2, #T_ef8e6_row3_col0, #T_ef8e6_row3_col1, #T_ef8e6_row3_col2, #T_ef8e6_row4_col0, #T_ef8e6_row4_col1, #T_ef8e6_row4_col2, #T_ef8e6_row5_col0, #T_ef8e6_row5_col1, #T_ef8e6_row5_col2, #T_ef8e6_row6_col0, #T_ef8e6_row6_col1, #T_ef8e6_row6_col2, #T_ef8e6_row7_col0, #T_ef8e6_row7_col1, #T_ef8e6_row7_col2, #T_ef8e6_row8_col0, #T_ef8e6_row8_col1, #T_ef8e6_row8_col2, #T_ef8e6_row9_col0, #T_ef8e6_row9_col1, #T_ef8e6_row9_col2, #T_ef8e6_row10_col0, #T_ef8e6_row10_col1, #T_ef8e6_row10_col2, #T_ef8e6_row11_col0, #T_ef8e6_row11_col1, #T_ef8e6_row11_col2, #T_ef8e6_row12_col0, #T_ef8e6_row12_col1, #T_ef8e6_row12_col2, #T_ef8e6_row13_col0, #T_ef8e6_row13_col1, #T_ef8e6_row13_col2, #T_ef8e6_row14_col0, #T_ef8e6_row14_col1, #T_ef8e6_row14_col2, #T_ef8e6_row15_col0, #T_ef8e6_row15_col1, #T_ef8e6_row15_col2 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_ef8e6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ef8e6_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_ef8e6_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_ef8e6_level0_col2" class="col_heading level0 col2" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ef8e6_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_ef8e6_row0_col0" class="data row0 col0" >376.642759</td>
#       <td id="T_ef8e6_row0_col1" class="data row0 col1" >381.310000</td>
#       <td id="T_ef8e6_row0_col2" class="data row0 col2" >1362316.860000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_ef8e6_row1_col0" class="data row1 col0" >264,905.37</td>
#       <td id="T_ef8e6_row1_col1" class="data row1 col1" >252,229.00</td>
#       <td id="T_ef8e6_row1_col2" class="data row1 col2" >958,162,724.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_ef8e6_row2_col0" class="data row2 col0" >7,963,980.62</td>
#       <td id="T_ef8e6_row2_col1" class="data row2 col1" >7,844,694.00</td>
#       <td id="T_ef8e6_row2_col2" class="data row2 col2" >28,805,717,900.00</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_ef8e6_row3_col0" class="data row3 col0" >211630.734310</td>
#       <td id="T_ef8e6_row3_col1" class="data row3 col1" >207234.000000</td>
#       <td id="T_ef8e6_row3_col2" class="data row3 col2" >765468366.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row4" class="row_heading level0 row4" >ADV\_xpos</th>
#       <td id="T_ef8e6_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_ef8e6_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_ef8e6_row4_col2" class="data row4 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row5" class="row_heading level0 row5" >ADV\_lemmas</th>
#       <td id="T_ef8e6_row5_col0" class="data row5 col0" >2373.409732</td>
#       <td id="T_ef8e6_row5_col1" class="data row5 col1" >2380.000000</td>
#       <td id="T_ef8e6_row5_col2" class="data row5 col2" >8584623.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row6" class="row_heading level0 row6" >ADV\_forms</th>
#       <td id="T_ef8e6_row6_col0" class="data row6 col0" >3022.908211</td>
#       <td id="T_ef8e6_row6_col1" class="data row6 col1" >3076.000000</td>
#       <td id="T_ef8e6_row6_col2" class="data row6 col2" >10933859.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row7" class="row_heading level0 row7" >ADJ\_tokens</th>
#       <td id="T_ef8e6_row7_col0" class="data row7 col0" >344358.620957</td>
#       <td id="T_ef8e6_row7_col1" class="data row7 col1" >325172.000000</td>
#       <td id="T_ef8e6_row7_col2" class="data row7 col2" >1245545132.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row8" class="row_heading level0 row8" >ADJ\_xpos</th>
#       <td id="T_ef8e6_row8_col0" class="data row8 col0" >3.000000</td>
#       <td id="T_ef8e6_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_ef8e6_row8_col2" class="data row8 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row9" class="row_heading level0 row9" >ADJ\_lemmas</th>
#       <td id="T_ef8e6_row9_col0" class="data row9 col0" >16051.860658</td>
#       <td id="T_ef8e6_row9_col1" class="data row9 col1" >15164.000000</td>
#       <td id="T_ef8e6_row9_col2" class="data row9 col2" >58059580.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row10" class="row_heading level0 row10" >ADJ\_forms</th>
#       <td id="T_ef8e6_row10_col0" class="data row10 col0" >18132.960188</td>
#       <td id="T_ef8e6_row10_col1" class="data row10 col1" >17393.000000</td>
#       <td id="T_ef8e6_row10_col2" class="data row10 col2" >65586917.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row11" class="row_heading level0 row11" >NEG\_tokens</th>
#       <td id="T_ef8e6_row11_col0" class="data row11 col0" >44051.869229</td>
#       <td id="T_ef8e6_row11_col1" class="data row11 col1" >42393.000000</td>
#       <td id="T_ef8e6_row11_col2" class="data row11 col2" >159335611.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row12" class="row_heading level0 row12" >NEG\_xpos</th>
#       <td id="T_ef8e6_row12_col0" class="data row12 col0" >14.020182</td>
#       <td id="T_ef8e6_row12_col1" class="data row12 col1" >14.000000</td>
#       <td id="T_ef8e6_row12_col2" class="data row12 col2" >50711.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row13" class="row_heading level0 row13" >NEG\_lemmas</th>
#       <td id="T_ef8e6_row13_col0" class="data row13 col0" >14.995576</td>
#       <td id="T_ef8e6_row13_col1" class="data row13 col1" >15.000000</td>
#       <td id="T_ef8e6_row13_col2" class="data row13 col2" >54239.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row14" class="row_heading level0 row14" >NEG\_forms</th>
#       <td id="T_ef8e6_row14_col0" class="data row14 col0" >50.145148</td>
#       <td id="T_ef8e6_row14_col1" class="data row14 col1" >52.000000</td>
#       <td id="T_ef8e6_row14_col2" class="data row14 col2" >181375.000000</td>
#     </tr>
#     <tr>
#       <th id="T_ef8e6_level0_row15" class="row_heading level0 row15" >bigrams</th>
#       <td id="T_ef8e6_row15_col0" class="data row15 col0" >26,399.33</td>
#       <td id="T_ef8e6_row15_col1" class="data row15 col1" >26,167.00</td>
#       <td id="T_ef8e6_row15_col2" class="data row15 col2" >95,486,374.00</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-counts-descrip-stats-orig.2025-02-18.tex
#
# Caption: BiRC: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
# <style type="text/css">
# #T_baea7 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_baea7 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_baea7 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_baea7 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_baea7_row0_col0, #T_baea7_row0_col1, #T_baea7_row0_col2, #T_baea7_row1_col0, #T_baea7_row1_col1, #T_baea7_row1_col2, #T_baea7_row2_col0, #T_baea7_row2_col1, #T_baea7_row2_col2, #T_baea7_row3_col0, #T_baea7_row3_col1, #T_baea7_row3_col2, #T_baea7_row4_col0, #T_baea7_row4_col1, #T_baea7_row4_col2, #T_baea7_row5_col0, #T_baea7_row5_col1, #T_baea7_row5_col2, #T_baea7_row6_col0, #T_baea7_row6_col1, #T_baea7_row6_col2, #T_baea7_row7_col0, #T_baea7_row7_col1, #T_baea7_row7_col2, #T_baea7_row8_col0, #T_baea7_row8_col1, #T_baea7_row8_col2, #T_baea7_row9_col0, #T_baea7_row9_col1, #T_baea7_row9_col2, #T_baea7_row10_col0, #T_baea7_row10_col1, #T_baea7_row10_col2, #T_baea7_row11_col0, #T_baea7_row11_col1, #T_baea7_row11_col2, #T_baea7_row12_col0, #T_baea7_row12_col1, #T_baea7_row12_col2, #T_baea7_row13_col0, #T_baea7_row13_col1, #T_baea7_row13_col2, #T_baea7_row14_col0, #T_baea7_row14_col1, #T_baea7_row14_col2, #T_baea7_row15_col0, #T_baea7_row15_col1, #T_baea7_row15_col2 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_baea7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_baea7_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_baea7_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_baea7_level0_col2" class="col_heading level0 col2" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_baea7_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_baea7_row0_col0" class="data row0 col0" >48.411269</td>
#       <td id="T_baea7_row0_col1" class="data row0 col1" >50.120000</td>
#       <td id="T_baea7_row0_col2" class="data row0 col2" >175103.560000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_baea7_row1_col0" class="data row1 col0" >24,564.02</td>
#       <td id="T_baea7_row1_col1" class="data row1 col1" >24,232.00</td>
#       <td id="T_baea7_row1_col2" class="data row1 col2" >88,848,070.00</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_baea7_row2_col0" class="data row2 col0" >744,482.66</td>
#       <td id="T_baea7_row2_col1" class="data row2 col1" >753,252.00</td>
#       <td id="T_baea7_row2_col2" class="data row2 col2" >2,692,793,781.00</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_baea7_row3_col0" class="data row3 col0" >51777.230301</td>
#       <td id="T_baea7_row3_col1" class="data row3 col1" >51673.000000</td>
#       <td id="T_baea7_row3_col2" class="data row3 col2" >187278242.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row4" class="row_heading level0 row4" >ADV\_xpos</th>
#       <td id="T_baea7_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_baea7_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_baea7_row4_col2" class="data row4 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row5" class="row_heading level0 row5" >ADV\_lemmas</th>
#       <td id="T_baea7_row5_col0" class="data row5 col0" >1345.696434</td>
#       <td id="T_baea7_row5_col1" class="data row5 col1" >1361.000000</td>
#       <td id="T_baea7_row5_col2" class="data row5 col2" >4867384.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row6" class="row_heading level0 row6" >ADV\_forms</th>
#       <td id="T_baea7_row6_col0" class="data row6 col0" >1653.056400</td>
#       <td id="T_baea7_row6_col1" class="data row6 col1" >1692.000000</td>
#       <td id="T_baea7_row6_col2" class="data row6 col2" >5979105.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row7" class="row_heading level0 row7" >ADJ\_tokens</th>
#       <td id="T_baea7_row7_col0" class="data row7 col0" >63886.013547</td>
#       <td id="T_baea7_row7_col1" class="data row7 col1" >62800.000000</td>
#       <td id="T_baea7_row7_col2" class="data row7 col2" >231075711.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row8" class="row_heading level0 row8" >ADJ\_xpos</th>
#       <td id="T_baea7_row8_col0" class="data row8 col0" >3.000000</td>
#       <td id="T_baea7_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_baea7_row8_col2" class="data row8 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row9" class="row_heading level0 row9" >ADJ\_lemmas</th>
#       <td id="T_baea7_row9_col0" class="data row9 col0" >6321.665469</td>
#       <td id="T_baea7_row9_col1" class="data row9 col1" >6205.000000</td>
#       <td id="T_baea7_row9_col2" class="data row9 col2" >22865464.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row10" class="row_heading level0 row10" >ADJ\_forms</th>
#       <td id="T_baea7_row10_col0" class="data row10 col0" >6928.595798</td>
#       <td id="T_baea7_row10_col1" class="data row10 col1" >6867.000000</td>
#       <td id="T_baea7_row10_col2" class="data row10 col2" >25060731.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row11" class="row_heading level0 row11" >NEG\_tokens</th>
#       <td id="T_baea7_row11_col0" class="data row11 col0" >7648.191595</td>
#       <td id="T_baea7_row11_col1" class="data row11 col1" >7775.000000</td>
#       <td id="T_baea7_row11_col2" class="data row11 col2" >27663509.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row12" class="row_heading level0 row12" >NEG\_xpos</th>
#       <td id="T_baea7_row12_col0" class="data row12 col0" >9.828864</td>
#       <td id="T_baea7_row12_col1" class="data row12 col1" >10.000000</td>
#       <td id="T_baea7_row12_col2" class="data row12 col2" >35551.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row13" class="row_heading level0 row13" >NEG\_lemmas</th>
#       <td id="T_baea7_row13_col0" class="data row13 col0" >14.912358</td>
#       <td id="T_baea7_row13_col1" class="data row13 col1" >15.000000</td>
#       <td id="T_baea7_row13_col2" class="data row13 col2" >53938.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row14" class="row_heading level0 row14" >NEG\_forms</th>
#       <td id="T_baea7_row14_col0" class="data row14 col0" >35.844623</td>
#       <td id="T_baea7_row14_col1" class="data row14 col1" >37.000000</td>
#       <td id="T_baea7_row14_col2" class="data row14 col2" >129650.000000</td>
#     </tr>
#     <tr>
#       <th id="T_baea7_level0_row15" class="row_heading level0 row15" >bigrams</th>
#       <td id="T_baea7_row15_col0" class="data row15 col0" >26,399.33</td>
#       <td id="T_baea7_row15_col1" class="data row15 col1" >26,167.00</td>
#       <td id="T_baea7_row15_col2" class="data row15 col2" >95,486,374.00</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-counts-descrip-stats-birc.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/only-counts-descrip-stats-birc.2025-02-18.tex')

# %% [markdown]
# ## Add Rates

# %%
def add_rate_cols(_df):
    return _df.assign(
        tok_per_bigram=(_df.tokens / _df.bigrams),
        
        bigrams_per_mill=(_df.bigrams / _df.tokens)*(10**6),
        ADV_tok_per_mill=(_df.ADV_tokens / _df.tokens)*(10**6),
        ADJ_tok_per_mill=(_df.ADJ_tokens / _df.tokens)*(10**6),
        NEG_tok_per_mill=(_df.NEG_tokens / _df.tokens)*(10**6),
        
        tok_per_ksent=_df.tokens / _df.sentences * 1000,
        bigrams_per_ksent=_df.bigrams / _df.sentences * 1000,
        ADV_tok_per_ksent=_df.ADV_tokens / _df.sentences * 1000,
        ADJ_tok_per_ksent=_df.ADJ_tokens / _df.sentences * 1000,
        NEG_tok_per_ksent=_df.NEG_tokens / _df.sentences * 1000,
        
        ADV_tok_per_bigram=(_df.ADV_tokens / _df.bigrams),
        ADJ_tok_per_bigram=(_df.ADJ_tokens / _df.bigrams),
        
        ADV_tok_per_lemma=_df.ADV_tokens / _df.ADV_lemmas,
        ADJ_tok_per_lemma=_df.ADJ_tokens / _df.ADJ_lemmas,
        NEG_tok_per_lemma=_df.NEG_tokens / _df.NEG_lemmas,
        
        ADV_tok_per_form=_df.ADV_tokens / _df.ADV_forms,
        ADJ_tok_per_form=_df.ADJ_tokens / _df.ADJ_forms,
        NEG_tok_per_form=_df.NEG_tokens / _df.NEG_forms,
        
        ADV_form_per_lemma=_df.ADV_forms / _df.ADV_lemmas,
        ADJ_form_per_lemma=_df.ADJ_forms / _df.ADJ_lemmas,
        NEG_form_per_lemma=_df.NEG_forms / _df.NEG_lemmas,
    )


orig_counts_df = add_rate_cols(orig_counts_df)
birc_counts_df = add_rate_cols(birc_counts_df)
samix = orig_counts_df.sample(4).sort_index().index
nb_display(set_my_style(orig_counts_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for Original Counts'))
nb_display(set_my_style(birc_counts_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for BiRC Counts'))
# Out:
# <style type="text/css">
# #T_e09b8 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e09b8 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e09b8 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e09b8 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e09b8 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e09b8 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e09b8 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e09b8 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e09b8_row0_col0, #T_e09b8_row0_col1, #T_e09b8_row0_col2, #T_e09b8_row0_col3, #T_e09b8_row1_col0, #T_e09b8_row1_col1, #T_e09b8_row1_col2, #T_e09b8_row1_col3, #T_e09b8_row2_col0, #T_e09b8_row2_col1, #T_e09b8_row2_col2, #T_e09b8_row2_col3, #T_e09b8_row3_col0, #T_e09b8_row3_col1, #T_e09b8_row3_col2, #T_e09b8_row3_col3, #T_e09b8_row4_col0, #T_e09b8_row4_col1, #T_e09b8_row4_col2, #T_e09b8_row4_col3, #T_e09b8_row5_col0, #T_e09b8_row5_col1, #T_e09b8_row5_col2, #T_e09b8_row5_col3, #T_e09b8_row6_col0, #T_e09b8_row6_col1, #T_e09b8_row6_col2, #T_e09b8_row6_col3, #T_e09b8_row7_col0, #T_e09b8_row7_col1, #T_e09b8_row7_col2, #T_e09b8_row7_col3, #T_e09b8_row8_col0, #T_e09b8_row8_col1, #T_e09b8_row8_col2, #T_e09b8_row8_col3, #T_e09b8_row9_col0, #T_e09b8_row9_col1, #T_e09b8_row9_col2, #T_e09b8_row9_col3, #T_e09b8_row10_col0, #T_e09b8_row10_col1, #T_e09b8_row10_col2, #T_e09b8_row10_col3, #T_e09b8_row11_col0, #T_e09b8_row11_col1, #T_e09b8_row11_col2, #T_e09b8_row11_col3, #T_e09b8_row12_col0, #T_e09b8_row12_col1, #T_e09b8_row12_col2, #T_e09b8_row12_col3, #T_e09b8_row13_col0, #T_e09b8_row13_col1, #T_e09b8_row13_col2, #T_e09b8_row13_col3, #T_e09b8_row14_col0, #T_e09b8_row14_col1, #T_e09b8_row14_col2, #T_e09b8_row14_col3, #T_e09b8_row15_col0, #T_e09b8_row15_col1, #T_e09b8_row15_col2, #T_e09b8_row15_col3, #T_e09b8_row16_col0, #T_e09b8_row16_col1, #T_e09b8_row16_col2, #T_e09b8_row16_col3, #T_e09b8_row17_col0, #T_e09b8_row17_col1, #T_e09b8_row17_col2, #T_e09b8_row17_col3, #T_e09b8_row18_col0, #T_e09b8_row18_col1, #T_e09b8_row18_col2, #T_e09b8_row18_col3, #T_e09b8_row19_col0, #T_e09b8_row19_col1, #T_e09b8_row19_col2, #T_e09b8_row19_col3, #T_e09b8_row20_col0, #T_e09b8_row20_col1, #T_e09b8_row20_col2, #T_e09b8_row20_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_e09b8">
#   <caption>"Rate" columns for Original Counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_e09b8_level0_col0" class="col_heading level0 col0" >apw_eng_199908</th>
#       <th id="T_e09b8_level0_col1" class="col_heading level0 col1" >pcc_eng_03-017</th>
#       <th id="T_e09b8_level0_col2" class="col_heading level0 col2" >pcc_eng_20-025</th>
#       <th id="T_e09b8_level0_col3" class="col_heading level0 col3" >pcc_eng_21-007</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e09b8_level0_row0" class="row_heading level0 row0" >tok_per_bigram</th>
#       <td id="T_e09b8_row0_col0" class="data row0 col0" >429.34</td>
#       <td id="T_e09b8_row0_col1" class="data row0 col1" >298.72</td>
#       <td id="T_e09b8_row0_col2" class="data row0 col2" >302.50</td>
#       <td id="T_e09b8_row0_col3" class="data row0 col3" >297.72</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row1" class="row_heading level0 row1" >bigrams_per_mill</th>
#       <td id="T_e09b8_row1_col0" class="data row1 col0" >2,329.14</td>
#       <td id="T_e09b8_row1_col1" class="data row1 col1" >3,347.66</td>
#       <td id="T_e09b8_row1_col2" class="data row1 col2" >3,305.76</td>
#       <td id="T_e09b8_row1_col3" class="data row1 col3" >3,358.82</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row2" class="row_heading level0 row2" >ADV_tok_per_mill</th>
#       <td id="T_e09b8_row2_col0" class="data row2 col0" >24,833.16</td>
#       <td id="T_e09b8_row2_col1" class="data row2 col1" >26,483.94</td>
#       <td id="T_e09b8_row2_col2" class="data row2 col2" >26,443.46</td>
#       <td id="T_e09b8_row2_col3" class="data row2 col3" >26,713.15</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row3" class="row_heading level0 row3" >ADJ_tok_per_mill</th>
#       <td id="T_e09b8_row3_col0" class="data row3 col0" >63,589.23</td>
#       <td id="T_e09b8_row3_col1" class="data row3 col1" >41,431.46</td>
#       <td id="T_e09b8_row3_col2" class="data row3 col2" >41,994.34</td>
#       <td id="T_e09b8_row3_col3" class="data row3 col3" >41,595.78</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_e09b8_row4_col0" class="data row4 col0" >5,490.35</td>
#       <td id="T_e09b8_row4_col1" class="data row4 col1" >5,404.38</td>
#       <td id="T_e09b8_row4_col2" class="data row4 col2" >5,363.95</td>
#       <td id="T_e09b8_row4_col3" class="data row4 col3" >5,457.62</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row5" class="row_heading level0 row5" >tok_per_ksent</th>
#       <td id="T_e09b8_row5_col0" class="data row5 col0" >23,607.64</td>
#       <td id="T_e09b8_row5_col1" class="data row5 col1" >31,112.97</td>
#       <td id="T_e09b8_row5_col2" class="data row5 col2" >31,107.91</td>
#       <td id="T_e09b8_row5_col3" class="data row5 col3" >31,151.75</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row6" class="row_heading level0 row6" >bigrams_per_ksent</th>
#       <td id="T_e09b8_row6_col0" class="data row6 col0" >54.99</td>
#       <td id="T_e09b8_row6_col1" class="data row6 col1" >104.16</td>
#       <td id="T_e09b8_row6_col2" class="data row6 col2" >102.84</td>
#       <td id="T_e09b8_row6_col3" class="data row6 col3" >104.63</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row7" class="row_heading level0 row7" >ADV_tok_per_ksent</th>
#       <td id="T_e09b8_row7_col0" class="data row7 col0" >586.25</td>
#       <td id="T_e09b8_row7_col1" class="data row7 col1" >823.99</td>
#       <td id="T_e09b8_row7_col2" class="data row7 col2" >822.60</td>
#       <td id="T_e09b8_row7_col3" class="data row7 col3" >832.16</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row8" class="row_heading level0 row8" >ADJ_tok_per_ksent</th>
#       <td id="T_e09b8_row8_col0" class="data row8 col0" >1,501.19</td>
#       <td id="T_e09b8_row8_col1" class="data row8 col1" >1,289.06</td>
#       <td id="T_e09b8_row8_col2" class="data row8 col2" >1,306.36</td>
#       <td id="T_e09b8_row8_col3" class="data row8 col3" >1,295.78</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row9" class="row_heading level0 row9" >NEG_tok_per_ksent</th>
#       <td id="T_e09b8_row9_col0" class="data row9 col0" >129.61</td>
#       <td id="T_e09b8_row9_col1" class="data row9 col1" >168.15</td>
#       <td id="T_e09b8_row9_col2" class="data row9 col2" >166.86</td>
#       <td id="T_e09b8_row9_col3" class="data row9 col3" >170.01</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row10" class="row_heading level0 row10" >ADV_tok_per_bigram</th>
#       <td id="T_e09b8_row10_col0" class="data row10 col0" >10.66</td>
#       <td id="T_e09b8_row10_col1" class="data row10 col1" >7.91</td>
#       <td id="T_e09b8_row10_col2" class="data row10 col2" >8.00</td>
#       <td id="T_e09b8_row10_col3" class="data row10 col3" >7.95</td>
#     </tr>
#     <tr>
#       <th id="T_e09b8_level0_row11" class="
# <style type="text/css">
# #T_1e0c9 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_1e0c9 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1e0c9 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1e0c9 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_1e0c9 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_1e0c9 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1e0c9 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1e0c9 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_1e0c9_row0_col0, #T_1e0c9_row0_col1, #T_1e0c9_row0_col2, #T_1e0c9_row0_col3, #T_1e0c9_row1_col0, #T_1e0c9_row1_col1, #T_1e0c9_row1_col2, #T_1e0c9_row1_col3, #T_1e0c9_row2_col0, #T_1e0c9_row2_col1, #T_1e0c9_row2_col2, #T_1e0c9_row2_col3, #T_1e0c9_row3_col0, #T_1e0c9_row3_col1, #T_1e0c9_row3_col2, #T_1e0c9_row3_col3, #T_1e0c9_row4_col0, #T_1e0c9_row4_col1, #T_1e0c9_row4_col2, #T_1e0c9_row4_col3, #T_1e0c9_row5_col0, #T_1e0c9_row5_col1, #T_1e0c9_row5_col2, #T_1e0c9_row5_col3, #T_1e0c9_row6_col0, #T_1e0c9_row6_col1, #T_1e0c9_row6_col2, #T_1e0c9_row6_col3, #T_1e0c9_row7_col0, #T_1e0c9_row7_col1, #T_1e0c9_row7_col2, #T_1e0c9_row7_col3, #T_1e0c9_row8_col0, #T_1e0c9_row8_col1, #T_1e0c9_row8_col2, #T_1e0c9_row8_col3, #T_1e0c9_row9_col0, #T_1e0c9_row9_col1, #T_1e0c9_row9_col2, #T_1e0c9_row9_col3, #T_1e0c9_row10_col0, #T_1e0c9_row10_col1, #T_1e0c9_row10_col2, #T_1e0c9_row10_col3, #T_1e0c9_row11_col0, #T_1e0c9_row11_col1, #T_1e0c9_row11_col2, #T_1e0c9_row11_col3, #T_1e0c9_row12_col0, #T_1e0c9_row12_col1, #T_1e0c9_row12_col2, #T_1e0c9_row12_col3, #T_1e0c9_row13_col0, #T_1e0c9_row13_col1, #T_1e0c9_row13_col2, #T_1e0c9_row13_col3, #T_1e0c9_row14_col0, #T_1e0c9_row14_col1, #T_1e0c9_row14_col2, #T_1e0c9_row14_col3, #T_1e0c9_row15_col0, #T_1e0c9_row15_col1, #T_1e0c9_row15_col2, #T_1e0c9_row15_col3, #T_1e0c9_row16_col0, #T_1e0c9_row16_col1, #T_1e0c9_row16_col2, #T_1e0c9_row16_col3, #T_1e0c9_row17_col0, #T_1e0c9_row17_col1, #T_1e0c9_row17_col2, #T_1e0c9_row17_col3, #T_1e0c9_row18_col0, #T_1e0c9_row18_col1, #T_1e0c9_row18_col2, #T_1e0c9_row18_col3, #T_1e0c9_row19_col0, #T_1e0c9_row19_col1, #T_1e0c9_row19_col2, #T_1e0c9_row19_col3, #T_1e0c9_row20_col0, #T_1e0c9_row20_col1, #T_1e0c9_row20_col2, #T_1e0c9_row20_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_1e0c9">
#   <caption>"Rate" columns for BiRC Counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_1e0c9_level0_col0" class="col_heading level0 col0" >apw_eng_199908</th>
#       <th id="T_1e0c9_level0_col1" class="col_heading level0 col1" >pcc_eng_03-017</th>
#       <th id="T_1e0c9_level0_col2" class="col_heading level0 col2" >pcc_eng_20-025</th>
#       <th id="T_1e0c9_level0_col3" class="col_heading level0 col3" >pcc_eng_21-007</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e0c9_level0_row0" class="row_heading level0 row0" >tok_per_bigram</th>
#       <td id="T_1e0c9_row0_col0" class="data row0 col0" >23.20</td>
#       <td id="T_1e0c9_row0_col1" class="data row0 col1" >28.85</td>
#       <td id="T_1e0c9_row0_col2" class="data row0 col2" >28.80</td>
#       <td id="T_1e0c9_row0_col3" class="data row0 col3" >28.69</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row1" class="row_heading level0 row1" >bigrams_per_mill</th>
#       <td id="T_1e0c9_row1_col0" class="data row1 col0" >43,095.10</td>
#       <td id="T_1e0c9_row1_col1" class="data row1 col1" >34,664.39</td>
#       <td id="T_1e0c9_row1_col2" class="data row1 col2" >34,719.06</td>
#       <td id="T_1e0c9_row1_col3" class="data row1 col3" >34,854.12</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row2" class="row_heading level0 row2" >ADV_tok_per_mill</th>
#       <td id="T_1e0c9_row2_col0" class="data row2 col0" >73,676.39</td>
#       <td id="T_1e0c9_row2_col1" class="data row2 col1" >68,134.61</td>
#       <td id="T_1e0c9_row2_col2" class="data row2 col2" >68,268.62</td>
#       <td id="T_1e0c9_row2_col3" class="data row2 col3" >69,519.07</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row3" class="row_heading level0 row3" >ADJ_tok_per_mill</th>
#       <td id="T_1e0c9_row3_col0" class="data row3 col0" >108,298.08</td>
#       <td id="T_1e0c9_row3_col1" class="data row3 col1" >82,962.09</td>
#       <td id="T_1e0c9_row3_col2" class="data row3 col2" >83,120.05</td>
#       <td id="T_1e0c9_row3_col3" class="data row3 col3" >84,636.58</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_1e0c9_row4_col0" class="data row4 col0" >8,614.45</td>
#       <td id="T_1e0c9_row4_col1" class="data row4 col1" >10,227.64</td>
#       <td id="T_1e0c9_row4_col2" class="data row4 col2" >10,177.57</td>
#       <td id="T_1e0c9_row4_col3" class="data row4 col3" >10,447.29</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row5" class="row_heading level0 row5" >tok_per_ksent</th>
#       <td id="T_1e0c9_row5_col0" class="data row5 col0" >23,592.63</td>
#       <td id="T_1e0c9_row5_col1" class="data row5 col1" >31,132.81</td>
#       <td id="T_1e0c9_row5_col2" class="data row5 col2" >31,129.38</td>
#       <td id="T_1e0c9_row5_col3" class="data row5 col3" >31,152.86</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row6" class="row_heading level0 row6" >bigrams_per_ksent</th>
#       <td id="T_1e0c9_row6_col0" class="data row6 col0" >1,016.73</td>
#       <td id="T_1e0c9_row6_col1" class="data row6 col1" >1,079.20</td>
#       <td id="T_1e0c9_row6_col2" class="data row6 col2" >1,080.78</td>
#       <td id="T_1e0c9_row6_col3" class="data row6 col3" >1,085.81</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row7" class="row_heading level0 row7" >ADV_tok_per_ksent</th>
#       <td id="T_1e0c9_row7_col0" class="data row7 col0" >1,738.22</td>
#       <td id="T_1e0c9_row7_col1" class="data row7 col1" >2,121.22</td>
#       <td id="T_1e0c9_row7_col2" class="data row7 col2" >2,125.16</td>
#       <td id="T_1e0c9_row7_col3" class="data row7 col3" >2,165.72</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row8" class="row_heading level0 row8" >ADJ_tok_per_ksent</th>
#       <td id="T_1e0c9_row8_col0" class="data row8 col0" >2,555.04</td>
#       <td id="T_1e0c9_row8_col1" class="data row8 col1" >2,582.84</td>
#       <td id="T_1e0c9_row8_col2" class="data row8 col2" >2,587.48</td>
#       <td id="T_1e0c9_row8_col3" class="data row8 col3" >2,636.67</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row9" class="row_heading level0 row9" >NEG_tok_per_ksent</th>
#       <td id="T_1e0c9_row9_col0" class="data row9 col0" >203.24</td>
#       <td id="T_1e0c9_row9_col1" class="data row9 col1" >318.42</td>
#       <td id="T_1e0c9_row9_col2" class="data row9 col2" >316.82</td>
#       <td id="T_1e0c9_row9_col3" class="data row9 col3" >325.46</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level0_row10" class="row_heading level0 row10" >ADV_tok_per_bigram</th>
#       <td id="T_1e0c9_row10_col0" class="data row10 col0" >1.71</td>
#       <td id="T_1e0c9_row10_col1" class="data row10 col1" >1.97</td>
#       <td id="T_1e0c9_row10_col2" class="data row10 col2" >1.97</td>
#       <td id="T_1e0c9_row10_col3" class="data row10 col3" >1.99</td>
#     </tr>
#     <tr>
#       <th id="T_1e0c9_level

# %% [markdown]
# ### *save latex tables*

# %%
def _stat(cdf):
    stat_df = cdf.describe().T.filter(['mean', '50%','min','max']).assign(
    Total=cdf.sum()
).convert_dtypes()
    stat_df['CV%']=(cdf.std()/cdf.mean()) * 100
    return stat_df

orig_stats = _stat(orig_counts_df)

save_latex_table(orig_stats,
                 caption='Original Corpora Counts & Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='plus-rates-main-stats-orig')
# Out:
# Caption: Original Corpora Counts & Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_5873d th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_5873d th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5873d th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5873d caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_5873d_row0_col0, #T_5873d_row0_col1, #T_5873d_row0_col2, #T_5873d_row0_col3, #T_5873d_row0_col4, #T_5873d_row0_col5, #T_5873d_row1_col0, #T_5873d_row1_col1, #T_5873d_row1_col2, #T_5873d_row1_col3, #T_5873d_row1_col4, #T_5873d_row1_col5, #T_5873d_row2_col0, #T_5873d_row2_col1, #T_5873d_row2_col2, #T_5873d_row2_col3, #T_5873d_row2_col4, #T_5873d_row2_col5, #T_5873d_row3_col0, #T_5873d_row3_col1, #T_5873d_row3_col2, #T_5873d_row3_col3, #T_5873d_row3_col4, #T_5873d_row3_col5, #T_5873d_row4_col0, #T_5873d_row4_col1, #T_5873d_row4_col2, #T_5873d_row4_col3, #T_5873d_row4_col4, #T_5873d_row4_col5, #T_5873d_row5_col0, #T_5873d_row5_col1, #T_5873d_row5_col2, #T_5873d_row5_col3, #T_5873d_row5_col4, #T_5873d_row5_col5, #T_5873d_row6_col0, #T_5873d_row6_col1, #T_5873d_row6_col2, #T_5873d_row6_col3, #T_5873d_row6_col4, #T_5873d_row6_col5, #T_5873d_row7_col0, #T_5873d_row7_col1, #T_5873d_row7_col2, #T_5873d_row7_col3, #T_5873d_row7_col4, #T_5873d_row7_col5, #T_5873d_row8_col0, #T_5873d_row8_col1, #T_5873d_row8_col2, #T_5873d_row8_col3, #T_5873d_row8_col4, #T_5873d_row8_col5, #T_5873d_row9_col0, #T_5873d_row9_col1, #T_5873d_row9_col2, #T_5873d_row9_col3, #T_5873d_row9_col4, #T_5873d_row9_col5, #T_5873d_row10_col0, #T_5873d_row10_col1, #T_5873d_row10_col2, #T_5873d_row10_col3, #T_5873d_row10_col4, #T_5873d_row10_col5, #T_5873d_row11_col0, #T_5873d_row11_col1, #T_5873d_row11_col2, #T_5873d_row11_col3, #T_5873d_row11_col4, #T_5873d_row11_col5, #T_5873d_row12_col0, #T_5873d_row12_col1, #T_5873d_row12_col2, #T_5873d_row12_col3, #T_5873d_row12_col4, #T_5873d_row12_col5, #T_5873d_row13_col0, #T_5873d_row13_col1, #T_5873d_row13_col2, #T_5873d_row13_col3, #T_5873d_row13_col4, #T_5873d_row13_col5, #T_5873d_row14_col0, #T_5873d_row14_col1, #T_5873d_row14_col2, #T_5873d_row14_col3, #T_5873d_row14_col4, #T_5873d_row14_col5, #T_5873d_row15_col0, #T_5873d_row15_col1, #T_5873d_row15_col2, #T_5873d_row15_col3, #T_5873d_row15_col4, #T_5873d_row15_col5, #T_5873d_row16_col0, #T_5873d_row16_col1, #T_5873d_row16_col2, #T_5873d_row16_col3, #T_5873d_row16_col4, #T_5873d_row16_col5, #T_5873d_row17_col0, #T_5873d_row17_col1, #T_5873d_row17_col2, #T_5873d_row17_col3, #T_5873d_row17_col4, #T_5873d_row17_col5, #T_5873d_row18_col0, #T_5873d_row18_col1, #T_5873d_row18_col2, #T_5873d_row18_col3, #T_5873d_row18_col4, #T_5873d_row18_col5, #T_5873d_row19_col0, #T_5873d_row19_col1, #T_5873d_row19_col2, #T_5873d_row19_col3, #T_5873d_row19_col4, #T_5873d_row19_col5, #T_5873d_row20_col0, #T_5873d_row20_col1, #T_5873d_row20_col2, #T_5873d_row20_col3, #T_5873d_row20_col4, #T_5873d_row20_col5, #T_5873d_row21_col0, #T_5873d_row21_col1, #T_5873d_row21_col2, #T_5873d_row21_col3, #T_5873d_row21_col4, #T_5873d_row21_col5, #T_5873d_row22_col0, #T_5873d_row22_col1, #T_5873d_row22_col2, #T_5873d_row22_col3, #T_5873d_row22_col4, #T_5873d_row22_col5, #T_5873d_row23_col0, #T_5873d_row23_col1, #T_5873d_row23_col2, #T_5873d_row23_col3, #T_5873d_row23_col4, #T_5873d_row23_col5, #T_5873d_row24_col0, #T_5873d_row24_col1, #T_5873d_row24_col2, #T_5873d_row24_col3, #T_5873d_row24_col4, #T_5873d_row24_col5, #T_5873d_row25_col0, #T_5873d_row25_col1, #T_5873d_row25_col2, #T_5873d_row25_col3, #T_5873d_row25_col4, #T_5873d_row25_col5, #T_5873d_row26_col0, #T_5873d_row26_col1, #T_5873d_row26_col2, #T_5873d_row26_col3, #T_5873d_row26_col4, #T_5873d_row26_col5, #T_5873d_row27_col0, #T_5873d_row27_col1, #T_5873d_row27_col2, #T_5873d_row27_col3, #T_5873d_row27_col4, #T_5873d_row27_col5, #T_5873d_row28_col0, #T_5873d_row28_col1, #T_5873d_row28_col2, #T_5873d_row28_col3, #T_5873d_row28_col4, #T_5873d_row28_col5, #T_5873d_row29_col0, #T_5873d_row29_col1, #T_5873d_row29_col2, #T_5873d_row29_col3, #T_5873d_row29_col4, #T_5873d_row29_col5, #T_5873d_row30_col0, #T_5873d_row30_col1, #T_5873d_row30_col2, #T_5873d_row30_col3, #T_5873d_row30_col4, #T_5873d_row30_col5, #T_5873d_row31_col0, #T_5873d_row31_col1, #T_5873d_row31_col2, #T_5873d_row31_col3, #T_5873d_row31_col4, #T_5873d_row31_col5, #T_5873d_row32_col0, #T_5873 ...
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_5873d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5873d_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_5873d_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_5873d_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_5873d_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_5873d_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_5873d_level0_col5" class="col_heading level0 col5" >CV\%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5873d_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_5873d_row0_col0" class="data row0 col0" >376.642759</td>
#       <td id="T_5873d_row0_col1" class="data row0 col1" >381.310000</td>
#       <td id="T_5873d_row0_col2" class="data row0 col2" >1.160000</td>
#       <td id="T_5873d_row0_col3" class="data row0 col3" >693.620000</td>
#       <td id="T_5873d_row0_col4" class="data row0 col4" >1362316.860000</td>
#       <td id="T_5873d_row0_col5" class="data row0 col5" >12.764588</td>
#     </tr>
#     <tr>
#       <th id="T_5873d_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_5873d_row1_col0" class="data row1 col0" >264,905.37</td>
#       <td id="T_5873d_row1_col1" class="data row1 col1" >252,229.00</td>
#       <td id="T_5873d_row1_col2" class="data row1 col2" >1,147.00</td>
#       <td id="T_5873d_row1_col3" class="data row1 col3" >820,724.00</td>
#       <td id="T_5873d_row1_col4" class="data row1 col4" >958,162,724.00</td>
#       <td id="T_5873d_row1_col5" class="data row1 col5" >25.48</td>
#     </tr>
#     <tr>
#       <th id="T_5873d_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_5873d_row2_col0" class="data row2 col0" >7,963,980.62</td>
#       <td id="T_5873d_row2_col1" class="data row2 col1" >7,844,694.00</td>
#       <td id="T_5873d_row2_col2" class="data row2 col2" >27,017.00</td>
#       <td id="T_5873d_row2_col3" class="data row2 col3" >19,532,928.00</td>
#       <td id="T_5873d_row2_col4" class="data row2 col4" >28,805,717,900.00</td>
#       <td id="T_5873d_row2_col5" class="data row2 col5" >17.46</td>
#     </tr>
#     <tr>
#       <th id="T_5873d_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_5873d_row3_col0" class="data row3 col0" >211630.734310</
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-main-stats-orig.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-main-stats-orig.2025-02-18.tex')

# %%
birc_stats = _stat(birc_counts_df)

save_latex_table(birc_stats,
                 caption='BiRC Counts & Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='plus-rates-main-stats-birc')
# Out:
# Caption: BiRC Counts & Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_1a325 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_1a325 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1a325 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_1a325 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_1a325_row0_col0, #T_1a325_row0_col1, #T_1a325_row0_col2, #T_1a325_row0_col3, #T_1a325_row0_col4, #T_1a325_row0_col5, #T_1a325_row1_col0, #T_1a325_row1_col1, #T_1a325_row1_col2, #T_1a325_row1_col3, #T_1a325_row1_col4, #T_1a325_row1_col5, #T_1a325_row2_col0, #T_1a325_row2_col1, #T_1a325_row2_col2, #T_1a325_row2_col3, #T_1a325_row2_col4, #T_1a325_row2_col5, #T_1a325_row3_col0, #T_1a325_row3_col1, #T_1a325_row3_col2, #T_1a325_row3_col3, #T_1a325_row3_col4, #T_1a325_row3_col5, #T_1a325_row4_col0, #T_1a325_row4_col1, #T_1a325_row4_col2, #T_1a325_row4_col3, #T_1a325_row4_col4, #T_1a325_row4_col5, #T_1a325_row5_col0, #T_1a325_row5_col1, #T_1a325_row5_col2, #T_1a325_row5_col3, #T_1a325_row5_col4, #T_1a325_row5_col5, #T_1a325_row6_col0, #T_1a325_row6_col1, #T_1a325_row6_col2, #T_1a325_row6_col3, #T_1a325_row6_col4, #T_1a325_row6_col5, #T_1a325_row7_col0, #T_1a325_row7_col1, #T_1a325_row7_col2, #T_1a325_row7_col3, #T_1a325_row7_col4, #T_1a325_row7_col5, #T_1a325_row8_col0, #T_1a325_row8_col1, #T_1a325_row8_col2, #T_1a325_row8_col3, #T_1a325_row8_col4, #T_1a325_row8_col5, #T_1a325_row9_col0, #T_1a325_row9_col1, #T_1a325_row9_col2, #T_1a325_row9_col3, #T_1a325_row9_col4, #T_1a325_row9_col5, #T_1a325_row10_col0, #T_1a325_row10_col1, #T_1a325_row10_col2, #T_1a325_row10_col3, #T_1a325_row10_col4, #T_1a325_row10_col5, #T_1a325_row11_col0, #T_1a325_row11_col1, #T_1a325_row11_col2, #T_1a325_row11_col3, #T_1a325_row11_col4, #T_1a325_row11_col5, #T_1a325_row12_col0, #T_1a325_row12_col1, #T_1a325_row12_col2, #T_1a325_row12_col3, #T_1a325_row12_col4, #T_1a325_row12_col5, #T_1a325_row13_col0, #T_1a325_row13_col1, #T_1a325_row13_col2, #T_1a325_row13_col3, #T_1a325_row13_col4, #T_1a325_row13_col5, #T_1a325_row14_col0, #T_1a325_row14_col1, #T_1a325_row14_col2, #T_1a325_row14_col3, #T_1a325_row14_col4, #T_1a325_row14_col5, #T_1a325_row15_col0, #T_1a325_row15_col1, #T_1a325_row15_col2, #T_1a325_row15_col3, #T_1a325_row15_col4, #T_1a325_row15_col5, #T_1a325_row16_col0, #T_1a325_row16_col1, #T_1a325_row16_col2, #T_1a325_row16_col3, #T_1a325_row16_col4, #T_1a325_row16_col5, #T_1a325_row17_col0, #T_1a325_row17_col1, #T_1a325_row17_col2, #T_1a325_row17_col3, #T_1a325_row17_col4, #T_1a325_row17_col5, #T_1a325_row18_col0, #T_1a325_row18_col1, #T_1a325_row18_col2, #T_1a325_row18_col3, #T_1a325_row18_col4, #T_1a325_row18_col5, #T_1a325_row19_col0, #T_1a325_row19_col1, #T_1a325_row19_col2, #T_1a325_row19_col3, #T_1a325_row19_col4, #T_1a325_row19_col5, #T_1a325_row20_col0, #T_1a325_row20_col1, #T_1a325_row20_col2, #T_1a325_row20_col3, #T_1a325_row20_col4, #T_1a325_row20_col5, #T_1a325_row21_col0, #T_1a325_row21_col1, #T_1a325_row21_col2, #T_1a325_row21_col3, #T_1a325_row21_col4, #T_1a325_row21_col5, #T_1a325_row22_col0, #T_1a325_row22_col1, #T_1a325_row22_col2, #T_1a325_row22_col3, #T_1a325_row22_col4, #T_1a325_row22_col5, #T_1a325_row23_col0, #T_1a325_row23_col1, #T_1a325_row23_col2, #T_1a325_row23_col3, #T_1a325_row23_col4, #T_1a325_row23_col5, #T_1a325_row24_col0, #T_1a325_row24_col1, #T_1a325_row24_col2, #T_1a325_row24_col3, #T_1a325_row24_col4, #T_1a325_row24_col5, #T_1a325_row25_col0, #T_1a325_row25_col1, #T_1a325_row25_col2, #T_1a325_row25_col3, #T_1a325_row25_col4, #T_1a325_row25_col5, #T_1a325_row26_col0, #T_1a325_row26_col1, #T_1a325_row26_col2, #T_1a325_row26_col3, #T_1a325_row26_col4, #T_1a325_row26_col5, #T_1a325_row27_col0, #T_1a325_row27_col1, #T_1a325_row27_col2, #T_1a325_row27_col3, #T_1a325_row27_col4, #T_1a325_row27_col5, #T_1a325_row28_col0, #T_1a325_row28_col1, #T_1a325_row28_col2, #T_1a325_row28_col3, #T_1a325_row28_col4, #T_1a325_row28_col5, #T_1a325_row29_col0, #T_1a325_row29_col1, #T_1a325_row29_col2, #T_1a325_row29_col3, #T_1a325_row29_col4, #T_1a325_row29_col5, #T_1a325_row30_col0, #T_1a325_row30_col1, #T_1a325_row30_col2, #T_1a325_row30_col3, #T_1a325_row30_col4, #T_1a325_row30_col5, #T_1a325_row31_col0, #T_1a325_row31_col1, #T_1a325_row31_col2, #T_1a325_row31_col3, #T_1a325_row31_col4, #T_1a325_row31_col5, #T_1a325_row32_col0, #T_1a32 ...
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_1a325">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1a325_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_1a325_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_1a325_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_1a325_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_1a325_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_1a325_level0_col5" class="col_heading level0 col5" >CV\%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1a325_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_1a325_row0_col0" class="data row0 col0" >48.411269</td>
#       <td id="T_1a325_row0_col1" class="data row0 col1" >50.120000</td>
#       <td id="T_1a325_row0_col2" class="data row0 col2" >0.090000</td>
#       <td id="T_1a325_row0_col3" class="data row0 col3" >76.520000</td>
#       <td id="T_1a325_row0_col4" class="data row0 col4" >175103.560000</td>
#       <td id="T_1a325_row0_col5" class="data row0 col5" >16.168846</td>
#     </tr>
#     <tr>
#       <th id="T_1a325_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_1a325_row1_col0" class="data row1 col0" >24,564.02</td>
#       <td id="T_1a325_row1_col1" class="data row1 col1" >24,232.00</td>
#       <td id="T_1a325_row1_col2" class="data row1 col2" >78.00</td>
#       <td id="T_1a325_row1_col3" class="data row1 col3" >66,997.00</td>
#       <td id="T_1a325_row1_col4" class="data row1 col4" >88,848,070.00</td>
#       <td id="T_1a325_row1_col5" class="data row1 col5" >19.25</td>
#     </tr>
#     <tr>
#       <th id="T_1a325_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_1a325_row2_col0" class="data row2 col0" >744,482.66</td>
#       <td id="T_1a325_row2_col1" class="data row2 col1" >753,252.00</td>
#       <td id="T_1a325_row2_col2" class="data row2 col2" >1,836.00</td>
#       <td id="T_1a325_row2_col3" class="data row2 col3" >1,591,526.00</td>
#       <td id="T_1a325_row2_col4" class="data row2 col4" >2,692,793,781.00</td>
#       <td id="T_1a325_row2_col5" class="data row2 col5" >15.54</td>
#     </tr>
#     <tr>
#       <th id="T_1a325_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_1a325_row3_col0" class="data row3 col0" >51777.230301</td>
#       <td id="T
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-main-stats-birc.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-main-stats-birc.2025-02-18.tex')

# %%
save_latex_table(orig_stats.filter(like='per',axis=0),
                 caption='Original Corpora Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='only-rates-main-stats-orig')
# Out:
# Caption: Original Corpora Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_8bc81 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_8bc81 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_8bc81 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_8bc81 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_8bc81_row0_col0, #T_8bc81_row0_col1, #T_8bc81_row0_col2, #T_8bc81_row0_col3, #T_8bc81_row0_col4, #T_8bc81_row0_col5, #T_8bc81_row1_col0, #T_8bc81_row1_col1, #T_8bc81_row1_col2, #T_8bc81_row1_col3, #T_8bc81_row1_col4, #T_8bc81_row1_col5, #T_8bc81_row2_col0, #T_8bc81_row2_col1, #T_8bc81_row2_col2, #T_8bc81_row2_col3, #T_8bc81_row2_col4, #T_8bc81_row2_col5, #T_8bc81_row3_col0, #T_8bc81_row3_col1, #T_8bc81_row3_col2, #T_8bc81_row3_col3, #T_8bc81_row3_col4, #T_8bc81_row3_col5, #T_8bc81_row4_col0, #T_8bc81_row4_col1, #T_8bc81_row4_col2, #T_8bc81_row4_col3, #T_8bc81_row4_col4, #T_8bc81_row4_col5, #T_8bc81_row5_col0, #T_8bc81_row5_col1, #T_8bc81_row5_col2, #T_8bc81_row5_col3, #T_8bc81_row5_col4, #T_8bc81_row5_col5, #T_8bc81_row6_col0, #T_8bc81_row6_col1, #T_8bc81_row6_col2, #T_8bc81_row6_col3, #T_8bc81_row6_col4, #T_8bc81_row6_col5, #T_8bc81_row7_col0, #T_8bc81_row7_col1, #T_8bc81_row7_col2, #T_8bc81_row7_col3, #T_8bc81_row7_col4, #T_8bc81_row7_col5, #T_8bc81_row8_col0, #T_8bc81_row8_col1, #T_8bc81_row8_col2, #T_8bc81_row8_col3, #T_8bc81_row8_col4, #T_8bc81_row8_col5, #T_8bc81_row9_col0, #T_8bc81_row9_col1, #T_8bc81_row9_col2, #T_8bc81_row9_col3, #T_8bc81_row9_col4, #T_8bc81_row9_col5, #T_8bc81_row10_col0, #T_8bc81_row10_col1, #T_8bc81_row10_col2, #T_8bc81_row10_col3, #T_8bc81_row10_col4, #T_8bc81_row10_col5, #T_8bc81_row11_col0, #T_8bc81_row11_col1, #T_8bc81_row11_col2, #T_8bc81_row11_col3, #T_8bc81_row11_col4, #T_8bc81_row11_col5, #T_8bc81_row12_col0, #T_8bc81_row12_col1, #T_8bc81_row12_col2, #T_8bc81_row12_col3, #T_8bc81_row12_col4, #T_8bc81_row12_col5, #T_8bc81_row13_col0, #T_8bc81_row13_col1, #T_8bc81_row13_col2, #T_8bc81_row13_col3, #T_8bc81_row13_col4, #T_8bc81_row13_col5, #T_8bc81_row14_col0, #T_8bc81_row14_col1, #T_8bc81_row14_col2, #T_8bc81_row14_col3, #T_8bc81_row14_col4, #T_8bc81_row14_col5, #T_8bc81_row15_col0, #T_8bc81_row15_col1, #T_8bc81_row15_col2, #T_8bc81_row15_col3, #T_8bc81_row15_col4, #T_8bc81_row15_col5, #T_8bc81_row16_col0, #T_8bc81_row16_col1, #T_8bc81_row16_col2, #T_8bc81_row16_col3, #T_8bc81_row16_col4, #T_8bc81_row16_col5, #T_8bc81_row17_col0, #T_8bc81_row17_col1, #T_8bc81_row17_col2, #T_8bc81_row17_col3, #T_8bc81_row17_col4, #T_8bc81_row17_col5, #T_8bc81_row18_col0, #T_8bc81_row18_col1, #T_8bc81_row18_col2, #T_8bc81_row18_col3, #T_8bc81_row18_col4, #T_8bc81_row18_col5, #T_8bc81_row19_col0, #T_8bc81_row19_col1, #T_8bc81_row19_col2, #T_8bc81_row19_col3, #T_8bc81_row19_col4, #T_8bc81_row19_col5, #T_8bc81_row20_col0, #T_8bc81_row20_col1, #T_8bc81_row20_col2, #T_8bc81_row20_col3, #T_8bc81_row20_col4, #T_8bc81_row20_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_8bc81">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8bc81_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_8bc81_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_8bc81_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_8bc81_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_8bc81_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_8bc81_level0_col5" class="col_heading level0 col5" >CV\%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8bc81_level0_row0" class="row_heading level0 row0" >tok\_per\_bigram</th>
#       <td id="T_8bc81_row0_col0" class="data row0 col0" >303.960314</td>
#       <td id="T_8bc81_row0_col1" class="data row0 col1" >299.901924</td>
#       <td id="T_8bc81_row0_col2" class="data row0 col2" >25.517736</td>
#       <td id="T_8bc81_row0_col3" class="data row0 col3" >639.502205</td>
#       <td id="T_8bc81_row0_col4" class="data row0 col4" >1099424.456601</td>
#       <td id="T_8bc81_row0_col5" class="data row0 col5" >11.101998</td>
#     </tr>
#     <tr>
#       <th id="T_8bc81_level0_row1" class="row_heading level0 row1" >bigrams\_per\_mill</th>
#       <td id="T_8bc81_row1_col0" class="data row1 col0" >3328.143801</td>
#       <td id="T_8bc81_row1_col1" class="data row1 col1" >3334.423423</td>
#       <td id="T_8bc81_row1_col2" class="data row1 col2" >1563.716266</td>
#       <td id="T_8bc81_row1_col3" class="data row1 col3" >39188.429733</td>
#       <td id="T_8bc81_row1_col4" class="data row1 col4" >12037896.128706</td>
#       <td id="T_8bc81_row1_col5" class="data row1 col5" >19.754245</td>
#     </tr>
#     <tr>
#       <th id="T_8bc81_level0_row2" class="row_heading level0 row2" >ADV\_tok\_per\_mill</th>
#       <td id="T_8bc81_row2_col0" class="data row2 col0" >26718.415610</td>
#       <td id="T_8bc81_row2_col1" class="data row2 col1" >26415.459711</td>
#       <td id="T_8bc81_row2_col2" class="data row2 col2" >16506.162419</td>
#       <td id="T_8bc81_row2_col3" class="data row2 col3" >479278.349333</td>
#       <td id="T_8bc81_row2_col4" class="data row2 col4" >96640509.261629</td>
#       <td id="T_8bc81_row2_col5" class="data row2 col5" >28.867916</td>
#     </tr>
#     <tr>
#       <th id="T_8bc81_level0_row3" class="row_heading level0 row3" >ADJ\_tok\_per\_mill</th>
#       <td id="T_8bc81_row3_col0" class="data row3 col0" >43374.635341</td>
#       <td id="T_8bc81_row3_col1" class="data row3 col1" >41442.631915</td>
#       <td id="T_8bc81_row3_col2" class="data row3 col2" >37574.922799</td>
#       <td id="T_8bc81_row3_col3" class="data row3 col3" >737301.723841</td>
#       <td id="T_8bc81_row3_col4" class="data row3 col4" >156886056.027471</td>
#       <td id="T_8bc81_row3_col5" class="data row3 col5" >29.612538</td>
#     </tr>
#     <tr>
#       <th id="T_8bc81_level0_row4" class="row_heading level0 row4" >NEG\_tok\_per\_mill</th>
#       <td id="T_8bc81_row4_col0" class="data row4 col0" >5551.801189</td>
#       <td id="T_8bc81_row4_col1" class="data row4 col1" >5402.466263</td>
#       <td id="T_8bc81_row4_col2" class="data row4 col2" >3929.536285</td>
#       <td id="T_8bc81_row4_col3" class="data row4 col3" >96553.464313</td>
#       <td id="T_8bc81_row4_col4" class="data row4 col4" >20080864.900171</td>
#       <td id="T_8bc81_row4_col5" class="data row4 col5" >28.995261</td>
#     </tr>
#     <tr>
#       <th id="T_8bc81_level0_row5" class="row_heading level0 row5" >tok\_per\_ksent</th>
#       <td id="T_8bc81_row5_col0" class="data row5 col0" >30375.293006</td>
#       <td id="T_8bc81_row5_col1" class="data row5 col1" >31125.938572</td>
#       <td id="T_8bc81_row5_col2" class="data row5 col2" >1744.826896</td>
#       <td id="T_8bc81_row5_col3" class="data row5 col3" >32176.998737</td>
#       <td id="T_8bc81_row5_col4" class="data row5 col4" >109867434.802504</td>
#       <td id="T_8bc81_row5_col5" class="data row5 col5" >7.563742</td>
#     </tr>
#     <tr>
#       <th id="T_8bc81_level0_row6" class="row_heading level0 row6" >bigrams\_per\_ksent</th>
#       <td id="T_8bc81_row6_col0" class="data row6 col0" >100.919081</td>
#       <td id="T_8bc81_row6_col1" class="data row6 col1" >103.634969</td>
#       <td id="T_8bc81_row6_col2" class="data row6 col2" >36.866788</td>
#       <td id="T_8bc81_row6_col3" class="data row6 col3" >109.912579</td>
#       <td id="T_8bc81_row6_col4" class="data row6 col4" >3650
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-rates-main-stats-orig.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/only-rates-main-stats-orig.2025-02-18.tex')

# %%
save_latex_table(birc_stats.filter(like='per', axis=0),
                 caption='BiRC Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='only-rates-main-stats-birc')
# Out:
# Caption: BiRC Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_e35df th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e35df th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e35df th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e35df caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e35df_row0_col0, #T_e35df_row0_col1, #T_e35df_row0_col2, #T_e35df_row0_col3, #T_e35df_row0_col4, #T_e35df_row0_col5, #T_e35df_row1_col0, #T_e35df_row1_col1, #T_e35df_row1_col2, #T_e35df_row1_col3, #T_e35df_row1_col4, #T_e35df_row1_col5, #T_e35df_row2_col0, #T_e35df_row2_col1, #T_e35df_row2_col2, #T_e35df_row2_col3, #T_e35df_row2_col4, #T_e35df_row2_col5, #T_e35df_row3_col0, #T_e35df_row3_col1, #T_e35df_row3_col2, #T_e35df_row3_col3, #T_e35df_row3_col4, #T_e35df_row3_col5, #T_e35df_row4_col0, #T_e35df_row4_col1, #T_e35df_row4_col2, #T_e35df_row4_col3, #T_e35df_row4_col4, #T_e35df_row4_col5, #T_e35df_row5_col0, #T_e35df_row5_col1, #T_e35df_row5_col2, #T_e35df_row5_col3, #T_e35df_row5_col4, #T_e35df_row5_col5, #T_e35df_row6_col0, #T_e35df_row6_col1, #T_e35df_row6_col2, #T_e35df_row6_col3, #T_e35df_row6_col4, #T_e35df_row6_col5, #T_e35df_row7_col0, #T_e35df_row7_col1, #T_e35df_row7_col2, #T_e35df_row7_col3, #T_e35df_row7_col4, #T_e35df_row7_col5, #T_e35df_row8_col0, #T_e35df_row8_col1, #T_e35df_row8_col2, #T_e35df_row8_col3, #T_e35df_row8_col4, #T_e35df_row8_col5, #T_e35df_row9_col0, #T_e35df_row9_col1, #T_e35df_row9_col2, #T_e35df_row9_col3, #T_e35df_row9_col4, #T_e35df_row9_col5, #T_e35df_row10_col0, #T_e35df_row10_col1, #T_e35df_row10_col2, #T_e35df_row10_col3, #T_e35df_row10_col4, #T_e35df_row10_col5, #T_e35df_row11_col0, #T_e35df_row11_col1, #T_e35df_row11_col2, #T_e35df_row11_col3, #T_e35df_row11_col4, #T_e35df_row11_col5, #T_e35df_row12_col0, #T_e35df_row12_col1, #T_e35df_row12_col2, #T_e35df_row12_col3, #T_e35df_row12_col4, #T_e35df_row12_col5, #T_e35df_row13_col0, #T_e35df_row13_col1, #T_e35df_row13_col2, #T_e35df_row13_col3, #T_e35df_row13_col4, #T_e35df_row13_col5, #T_e35df_row14_col0, #T_e35df_row14_col1, #T_e35df_row14_col2, #T_e35df_row14_col3, #T_e35df_row14_col4, #T_e35df_row14_col5, #T_e35df_row15_col0, #T_e35df_row15_col1, #T_e35df_row15_col2, #T_e35df_row15_col3, #T_e35df_row15_col4, #T_e35df_row15_col5, #T_e35df_row16_col0, #T_e35df_row16_col1, #T_e35df_row16_col2, #T_e35df_row16_col3, #T_e35df_row16_col4, #T_e35df_row16_col5, #T_e35df_row17_col0, #T_e35df_row17_col1, #T_e35df_row17_col2, #T_e35df_row17_col3, #T_e35df_row17_col4, #T_e35df_row17_col5, #T_e35df_row18_col0, #T_e35df_row18_col1, #T_e35df_row18_col2, #T_e35df_row18_col3, #T_e35df_row18_col4, #T_e35df_row18_col5, #T_e35df_row19_col0, #T_e35df_row19_col1, #T_e35df_row19_col2, #T_e35df_row19_col3, #T_e35df_row19_col4, #T_e35df_row19_col5, #T_e35df_row20_col0, #T_e35df_row20_col1, #T_e35df_row20_col2, #T_e35df_row20_col3, #T_e35df_row20_col4, #T_e35df_row20_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_e35df">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e35df_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_e35df_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_e35df_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_e35df_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_e35df_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_e35df_level0_col5" class="col_heading level0 col5" >CV\%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e35df_level0_row0" class="row_heading level0 row0" >tok\_per\_bigram</th>
#       <td id="T_e35df_row0_col0" class="data row0 col0" >28.245656</td>
#       <td id="T_e35df_row0_col1" class="data row0 col1" >28.817545</td>
#       <td id="T_e35df_row0_col2" class="data row0 col2" >22.639803</td>
#       <td id="T_e35df_row0_col3" class="data row0 col3" >29.896107</td>
#       <td id="T_e35df_row0_col4" class="data row0 col4" >102164.536190</td>
#       <td id="T_e35df_row0_col5" class="data row0 col5" >6.212876</td>
#     </tr>
#     <tr>
#       <th id="T_e35df_level0_row1" class="row_heading level0 row1" >bigrams\_per\_mill</th>
#       <td id="T_e35df_row1_col0" class="data row1 col0" >35567.413546</td>
#       <td id="T_e35df_row1_col1" class="data row1 col1" >34701.082847</td>
#       <td id="T_e35df_row1_col2" class="data row1 col2" >33449.171241</td>
#       <td id="T_e35df_row1_col3" class="data row1 col3" >44169.995420</td>
#       <td id="T_e35df_row1_col4" class="data row1 col4" >128647334.797221</td>
#       <td id="T_e35df_row1_col5" class="data row1 col5" >7.413079</td>
#     </tr>
#     <tr>
#       <th id="T_e35df_level0_row2" class="row_heading level0 row2" >ADV\_tok\_per\_mill</th>
#       <td id="T_e35df_row2_col0" class="data row2 col0" >69566.598296</td>
#       <td id="T_e35df_row2_col1" class="data row2 col1" >68617.616136</td>
#       <td id="T_e35df_row2_col2" class="data row2 col2" >65676.414220</td>
#       <td id="T_e35df_row2_col3" class="data row2 col3" >84889.384072</td>
#       <td id="T_e35df_row2_col4" class="data row2 col4" >251622386.035120</td>
#       <td id="T_e35df_row2_col5" class="data row2 col5" >4.875261</td>
#     </tr>
#     <tr>
#       <th id="T_e35df_level0_row3" class="row_heading level0 row3" >ADJ\_tok\_per\_mill</th>
#       <td id="T_e35df_row3_col0" class="data row3 col0" >86166.760500</td>
#       <td id="T_e35df_row3_col1" class="data row3 col1" >83283.729315</td>
#       <td id="T_e35df_row3_col2" class="data row3 col2" >79799.685689</td>
#       <td id="T_e35df_row3_col3" class="data row3 col3" >120159.504580</td>
#       <td id="T_e35df_row3_col4" class="data row3 col4" >311665172.727584</td>
#       <td id="T_e35df_row3_col5" class="data row3 col5" >10.357154</td>
#     </tr>
#     <tr>
#       <th id="T_e35df_level0_row4" class="row_heading level0 row4" >NEG\_tok\_per\_mill</th>
#       <td id="T_e35df_row4_col0" class="data row4 col0" >10238.704921</td>
#       <td id="T_e35df_row4_col1" class="data row4 col1" >10311.474769</td>
#       <td id="T_e35df_row4_col2" class="data row4 col2" >6901.384613</td>
#       <td id="T_e35df_row4_col3" class="data row4 col3" >13071.895425</td>
#       <td id="T_e35df_row4_col4" class="data row4 col4" >37033395.700265</td>
#       <td id="T_e35df_row4_col5" class="data row4 col5" >4.379358</td>
#     </tr>
#     <tr>
#       <th id="T_e35df_level0_row5" class="row_heading level0 row5" >tok\_per\_ksent</th>
#       <td id="T_e35df_row5_col0" class="data row5 col0" >30390.397533</td>
#       <td id="T_e35df_row5_col1" class="data row5 col1" >31139.456758</td>
#       <td id="T_e35df_row5_col2" class="data row5 col2" >23524.093124</td>
#       <td id="T_e35df_row5_col3" class="data row5 col3" >32195.978249</td>
#       <td id="T_e35df_row5_col4" class="data row5 col4" >109922067.875727</td>
#       <td id="T_e35df_row5_col5" class="data row5 col5" >7.452490</td>
#     </tr>
#     <tr>
#       <th id="T_e35df_level0_row6" class="row_heading level0 row6" >bigrams\_per\_ksent</th>
#       <td id="T_e35df_row6_col0" class="data row6 col0" >1074.949182</td>
#       <td id="T_e35df_row6_col1" class="data row6 col1" >1080.000000</td>
#       <td id="T_e35df_row6_col2" class="data row6 col2" >987.179487</td>
#       <td id="T_e35df_row6_col3" class="data row6 col3" >1095.911693</td>
#       <td id="T_e35df_row6_col4" class="data row6 col4" >3
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-rates-main-stats-birc.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/only-rates-main-stats-birc.2025-02-18.tex')

# %% [markdown]
#  ## *Calculate **Reduction*** (<code>BiRC - Full</code>)

# %%
reduction_df = birc_counts_df - orig_counts_df
# iloc[:, 1:] drops the uninformtative `count` column
# save_latex_table(reduction_df.describe().T.iloc[:, 1:].assign(Total=reduction_df.sum()).convert_dtypes(),
#                  caption='Reduction (BiRC -- Full) Counts & Rates: Descriptive Stats', verbose=True,
#                  latex_subdir=REL_BIRC_TEX_DIR,
#                  latex_stem='plus-rates-birc-minus-full-descrip-stats')
# save_latex_table(reduction_df.filter(like='per').describe().T.iloc[:, 1:].assign(Total=reduction_df.sum()).convert_dtypes(),
#                  caption='Reduction (BiRC -- Full) Rates: Descriptive Stats', verbose=True,
#                  latex_subdir=REL_BIRC_TEX_DIR,
#                  latex_stem='only-rates-birc-minus-full-descrip-stats')
# nb_display(set_my_style(reduction_df.describe().T.assign(Total=reduction_df.sum()).convert_dtypes(),
#                         caption='BiRC <i>Reduction</i>: Descriptive Stats', precision=1))
nb_display(set_my_style(reduction_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for <code>BiRC - Full</code> counts'))
# Out:
# <style type="text/css">
# #T_b611d th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_b611d th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_b611d th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_b611d caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_b611d th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_b611d th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_b611d th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_b611d caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_b611d_row0_col0, #T_b611d_row0_col1, #T_b611d_row0_col2, #T_b611d_row0_col3, #T_b611d_row1_col0, #T_b611d_row1_col1, #T_b611d_row1_col2, #T_b611d_row1_col3, #T_b611d_row2_col0, #T_b611d_row2_col1, #T_b611d_row2_col2, #T_b611d_row2_col3, #T_b611d_row3_col0, #T_b611d_row3_col1, #T_b611d_row3_col2, #T_b611d_row3_col3, #T_b611d_row4_col0, #T_b611d_row4_col1, #T_b611d_row4_col2, #T_b611d_row4_col3, #T_b611d_row5_col0, #T_b611d_row5_col1, #T_b611d_row5_col2, #T_b611d_row5_col3, #T_b611d_row6_col0, #T_b611d_row6_col1, #T_b611d_row6_col2, #T_b611d_row6_col3, #T_b611d_row7_col0, #T_b611d_row7_col1, #T_b611d_row7_col2, #T_b611d_row7_col3, #T_b611d_row8_col0, #T_b611d_row8_col1, #T_b611d_row8_col2, #T_b611d_row8_col3, #T_b611d_row9_col0, #T_b611d_row9_col1, #T_b611d_row9_col2, #T_b611d_row9_col3, #T_b611d_row10_col0, #T_b611d_row10_col1, #T_b611d_row10_col2, #T_b611d_row10_col3, #T_b611d_row11_col0, #T_b611d_row11_col1, #T_b611d_row11_col2, #T_b611d_row11_col3, #T_b611d_row12_col0, #T_b611d_row12_col1, #T_b611d_row12_col2, #T_b611d_row12_col3, #T_b611d_row13_col0, #T_b611d_row13_col1, #T_b611d_row13_col2, #T_b611d_row13_col3, #T_b611d_row14_col0, #T_b611d_row14_col1, #T_b611d_row14_col2, #T_b611d_row14_col3, #T_b611d_row15_col0, #T_b611d_row15_col1, #T_b611d_row15_col2, #T_b611d_row15_col3, #T_b611d_row16_col0, #T_b611d_row16_col1, #T_b611d_row16_col2, #T_b611d_row16_col3, #T_b611d_row17_col0, #T_b611d_row17_col1, #T_b611d_row17_col2, #T_b611d_row17_col3, #T_b611d_row18_col0, #T_b611d_row18_col1, #T_b611d_row18_col2, #T_b611d_row18_col3, #T_b611d_row19_col0, #T_b611d_row19_col1, #T_b611d_row19_col2, #T_b611d_row19_col3, #T_b611d_row20_col0, #T_b611d_row20_col1, #T_b611d_row20_col2, #T_b611d_row20_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_b611d">
#   <caption>"Rate" columns for <code>BiRC - Full</code> counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_b611d_level0_col0" class="col_heading level0 col0" >apw_eng_199908</th>
#       <th id="T_b611d_level0_col1" class="col_heading level0 col1" >pcc_eng_03-017</th>
#       <th id="T_b611d_level0_col2" class="col_heading level0 col2" >pcc_eng_20-025</th>
#       <th id="T_b611d_level0_col3" class="col_heading level0 col3" >pcc_eng_21-007</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b611d_level0_row0" class="row_heading level0 row0" >tok_per_bigram</th>
#       <td id="T_b611d_row0_col0" class="data row0 col0" >-406.14</td>
#       <td id="T_b611d_row0_col1" class="data row0 col1" >-269.87</td>
#       <td id="T_b611d_row0_col2" class="data row0 col2" >-273.70</td>
#       <td id="T_b611d_row0_col3" class="data row0 col3" >-269.03</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row1" class="row_heading level0 row1" >bigrams_per_mill</th>
#       <td id="T_b611d_row1_col0" class="data row1 col0" >40,765.96</td>
#       <td id="T_b611d_row1_col1" class="data row1 col1" >31,316.74</td>
#       <td id="T_b611d_row1_col2" class="data row1 col2" >31,413.30</td>
#       <td id="T_b611d_row1_col3" class="data row1 col3" >31,495.30</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row2" class="row_heading level0 row2" >ADV_tok_per_mill</th>
#       <td id="T_b611d_row2_col0" class="data row2 col0" >48,843.23</td>
#       <td id="T_b611d_row2_col1" class="data row2 col1" >41,650.67</td>
#       <td id="T_b611d_row2_col2" class="data row2 col2" >41,825.16</td>
#       <td id="T_b611d_row2_col3" class="data row2 col3" >42,805.93</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row3" class="row_heading level0 row3" >ADJ_tok_per_mill</th>
#       <td id="T_b611d_row3_col0" class="data row3 col0" >44,708.84</td>
#       <td id="T_b611d_row3_col1" class="data row3 col1" >41,530.64</td>
#       <td id="T_b611d_row3_col2" class="data row3 col2" >41,125.70</td>
#       <td id="T_b611d_row3_col3" class="data row3 col3" >43,040.80</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_b611d_row4_col0" class="data row4 col0" >3,124.10</td>
#       <td id="T_b611d_row4_col1" class="data row4 col1" >4,823.26</td>
#       <td id="T_b611d_row4_col2" class="data row4 col2" >4,813.62</td>
#       <td id="T_b611d_row4_col3" class="data row4 col3" >4,989.67</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row5" class="row_heading level0 row5" >tok_per_ksent</th>
#       <td id="T_b611d_row5_col0" class="data row5 col0" >-15.01</td>
#       <td id="T_b611d_row5_col1" class="data row5 col1" >19.84</td>
#       <td id="T_b611d_row5_col2" class="data row5 col2" >21.47</td>
#       <td id="T_b611d_row5_col3" class="data row5 col3" >1.11</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row6" class="row_heading level0 row6" >bigrams_per_ksent</th>
#       <td id="T_b611d_row6_col0" class="data row6 col0" >961.74</td>
#       <td id="T_b611d_row6_col1" class="data row6 col1" >975.04</td>
#       <td id="T_b611d_row6_col2" class="data row6 col2" >977.95</td>
#       <td id="T_b611d_row6_col3" class="data row6 col3" >981.17</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row7" class="row_heading level0 row7" >ADV_tok_per_ksent</th>
#       <td id="T_b611d_row7_col0" class="data row7 col0" >1,151.97</td>
#       <td id="T_b611d_row7_col1" class="data row7 col1" >1,297.23</td>
#       <td id="T_b611d_row7_col2" class="data row7 col2" >1,302.56</td>
#       <td id="T_b611d_row7_col3" class="data row7 col3" >1,333.56</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row8" class="row_heading level0 row8" >ADJ_tok_per_ksent</th>
#       <td id="T_b611d_row8_col0" class="data row8 col0" >1,053.84</td>
#       <td id="T_b611d_row8_col1" class="data row8 col1" >1,293.79</td>
#       <td id="T_b611d_row8_col2" class="data row8 col2" >1,281.12</td>
#       <td id="T_b611d_row8_col3" class="data row8 col3" >1,340.89</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row9" class="row_heading level0 row9" >NEG_tok_per_ksent</th>
#       <td id="T_b611d_row9_col0" class="data row9 col0" >73.62</td>
#       <td id="T_b611d_row9_col1" class="data row9 col1" >150.27</td>
#       <td id="T_b611d_row9_col2" class="data row9 col2" >149.96</td>
#       <td id="T_b611d_row9_col3" class="data row9 col3" >155.45</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_level0_row10" class="row_heading level0 row10" >ADV_tok_per_bigram</th>
#       <td id="T_b611d_row10_col0" class="data row10 col0" >-8.95</td>
#       <td id="T_b611d_row10_col1" class="data row10 col1" >-5.95</td>
#       <td id="T_b611d_row10_col2" class="data row10 col2" >-6.03</td>
#       <td id="T_b611d_row10_col3" class="data row10 col3" >-5.96</td>
#     </tr>
#     <tr>
#       <th id="T_b611d_le

# %%
reduction_stats = _stat(reduction_df)
nb_display(reduction_stats.filter(regex=r'token|sentence|bigram|MB', axis=0))
# Out:
# <style type="text/css">
# #T_c7c7c th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_c7c7c th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_c7c7c th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_c7c7c caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_c7c7c_row0_col0, #T_c7c7c_row0_col1, #T_c7c7c_row0_col2, #T_c7c7c_row0_col3, #T_c7c7c_row0_col4, #T_c7c7c_row0_col5, #T_c7c7c_row1_col0, #T_c7c7c_row1_col1, #T_c7c7c_row1_col2, #T_c7c7c_row1_col3, #T_c7c7c_row1_col4, #T_c7c7c_row1_col5, #T_c7c7c_row2_col0, #T_c7c7c_row2_col1, #T_c7c7c_row2_col2, #T_c7c7c_row2_col3, #T_c7c7c_row2_col4, #T_c7c7c_row2_col5, #T_c7c7c_row3_col0, #T_c7c7c_row3_col1, #T_c7c7c_row3_col2, #T_c7c7c_row3_col3, #T_c7c7c_row3_col4, #T_c7c7c_row3_col5, #T_c7c7c_row4_col0, #T_c7c7c_row4_col1, #T_c7c7c_row4_col2, #T_c7c7c_row4_col3, #T_c7c7c_row4_col4, #T_c7c7c_row4_col5, #T_c7c7c_row5_col0, #T_c7c7c_row5_col1, #T_c7c7c_row5_col2, #T_c7c7c_row5_col3, #T_c7c7c_row5_col4, #T_c7c7c_row5_col5, #T_c7c7c_row6_col0, #T_c7c7c_row6_col1, #T_c7c7c_row6_col2, #T_c7c7c_row6_col3, #T_c7c7c_row6_col4, #T_c7c7c_row6_col5, #T_c7c7c_row7_col0, #T_c7c7c_row7_col1, #T_c7c7c_row7_col2, #T_c7c7c_row7_col3, #T_c7c7c_row7_col4, #T_c7c7c_row7_col5, #T_c7c7c_row8_col0, #T_c7c7c_row8_col1, #T_c7c7c_row8_col2, #T_c7c7c_row8_col3, #T_c7c7c_row8_col4, #T_c7c7c_row8_col5, #T_c7c7c_row9_col0, #T_c7c7c_row9_col1, #T_c7c7c_row9_col2, #T_c7c7c_row9_col3, #T_c7c7c_row9_col4, #T_c7c7c_row9_col5, #T_c7c7c_row10_col0, #T_c7c7c_row10_col1, #T_c7c7c_row10_col2, #T_c7c7c_row10_col3, #T_c7c7c_row10_col4, #T_c7c7c_row10_col5, #T_c7c7c_row11_col0, #T_c7c7c_row11_col1, #T_c7c7c_row11_col2, #T_c7c7c_row11_col3, #T_c7c7c_row11_col4, #T_c7c7c_row11_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_c7c7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c7c7c_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_c7c7c_level0_col1" class="col_heading level0 col1" >50%</th>
#       <th id="T_c7c7c_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_c7c7c_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_c7c7c_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_c7c7c_level0_col5" class="col_heading level0 col5" >CV%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c7c7c_level0_row0" class="row_heading level0 row0" >file_MB</th>
#       <td id="T_c7c7c_row0_col0" class="data row0 col0" >-328.23</td>
#       <td id="T_c7c7c_row0_col1" class="data row0 col1" >-331.15</td>
#       <td id="T_c7c7c_row0_col2" class="data row0 col2" >-617.10</td>
#       <td id="T_c7c7c_row0_col3" class="data row0 col3" >-1.07</td>
#       <td id="T_c7c7c_row0_col4" class="data row0 col4" >-1,187,213.30</td>
#       <td id="T_c7c7c_row0_col5" class="data row0 col5" >-12.80</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_c7c7c_row1_col0" class="data row1 col0" >-240,341.35</td>
#       <td id="T_c7c7c_row1_col1" class="data row1 col1" >-228,003.00</td>
#       <td id="T_c7c7c_row1_col2" class="data row1 col2" >-753,727.00</td>
#       <td id="T_c7c7c_row1_col3" class="data row1 col3" >-1,069.00</td>
#       <td id="T_c7c7c_row1_col4" class="data row1 col4" >-869,314,654.00</td>
#       <td id="T_c7c7c_row1_col5" class="data row1 col5" >-26.53</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_c7c7c_row2_col0" class="data row2 col0" >-7,219,497.96</td>
#       <td id="T_c7c7c_row2_col1" class="data row2 col1" >-7,090,899.00</td>
#       <td id="T_c7c7c_row2_col2" class="data row2 col2" >-17,941,402.00</td>
#       <td id="T_c7c7c_row2_col3" class="data row2 col3" >54,335.00</td>
#       <td id="T_c7c7c_row2_col4" class="data row2 col4" >-26,112,924,119.00</td>
#       <td id="T_c7c7c_row2_col5" class="data row2 col5" >-18.11</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row3" class="row_heading level0 row3" >ADV_tokens</th>
#       <td id="T_c7c7c_row3_col0" class="data row3 col0" >-159,853.50</td>
#       <td id="T_c7c7c_row3_col1" class="data row3 col1" >-155,494.00</td>
#       <td id="T_c7c7c_row3_col2" class="data row3 col2" >-442,051.00</td>
#       <td id="T_c7c7c_row3_col3" class="data row3 col3" >-698.00</td>
#       <td id="T_c7c7c_row3_col4" class="data row3 col4" >-578,190,124.00</td>
#       <td id="T_c7c7c_row3_col5" class="data row3 col5" >-19.52</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row4" class="row_heading level0 row4" >ADJ_tokens</th>
#       <td id="T_c7c7c_row4_col0" class="data row4 col0" >-280,472.61</td>
#       <td id="T_c7c7c_row4_col1" class="data row4 col1" >-262,280.00</td>
#       <td id="T_c7c7c_row4_col2" class="data row4 col2" >-899,305.00</td>
#       <td id="T_c7c7c_row4_col3" class="data row4 col3" >-1,596.00</td>
#       <td id="T_c7c7c_row4_col4" class="data row4 col4" >-1,014,469,421.00</td>
#       <td id="T_c7c7c_row4_col5" class="data row4 col5" >-28.26</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row5" class="row_heading level0 row5" >NEG_tokens</th>
#       <td id="T_c7c7c_row5_col0" class="data row5 col0" >-36,403.68</td>
#       <td id="T_c7c7c_row5_col1" class="data row5 col1" >-34,595.00</td>
#       <td id="T_c7c7c_row5_col2" class="data row5 col2" >-115,331.00</td>
#       <td id="T_c7c7c_row5_col3" class="data row5 col3" >-190.00</td>
#       <td id="T_c7c7c_row5_col4" class="data row5 col4" >-131,672,102.00</td>
#       <td id="T_c7c7c_row5_col5" class="data row5 col5" >-25.63</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_c7c7c_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_c7c7c_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_c7c7c_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_c7c7c_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_c7c7c_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_c7c7c_row6_col5" class="data row6 col5" >&nbsp;</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row7" class="row_heading level0 row7" >tok_per_bigram</th>
#       <td id="T_c7c7c_row7_col0" class="data row7 col0" >-275.71</td>
#       <td id="T_c7c7c_row7_col1" class="data row7 col1" >-271.10</td>
#       <td id="T_c7c7c_row7_col2" class="data row7 col2" >-615.98</td>
#       <td id="T_c7c7c_row7_col3" class="data row7 col3" >3.18</td>
#       <td id="T_c7c7c_row7_col4" class="data row7 col4" >-997,259.92</td>
#       <td id="T_c7c7c_row7_col5" class="data row7 col5" >-12.46</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row8" class="row_heading level0 row8" >bigrams_per_mill</th>
#       <td id="T_c7c7c_row8_col0" class="data row8 col0" >32,239.27</td>
#       <td id="T_c7c7c_row8_col1" class="data row8 col1" >31,366.82</td>
#       <td id="T_c7c7c_row8_col2" class="data row8 col2" >-4,343.04</td>
#       <td id="T_c7c7c_row8_col3" class="data row8 col3" >41,552.13</td>
#       <td id="T_c7c7c_row8_col4" class="data row8 col4" >116,609,438.67</td>
#       <td id="T_c7c7c_row8_col5" class="data row8 col5" >8.55</td>
#     </tr>
#     <tr>
#       <th id="T_c7c7c_level0_row9" class="row_heading level0 row9" >bigrams_per_ksent</th>
#       <td id="T_c7c7c_row9_col0" class="data row9 col0" >974.03</td>
#       <td id="T_c7c7c_row9_col1" class="data row9 col1" >976.23</td>
#       <td id="T_c7c7c_row9_col2" class="data row9 col2" >920.05</td>
#       <td id="T_c7c7c_row9_col3" class="data row9 col3" >1,017.49</td>
#       <td id="T_c7c7c_row9_col4" class="data row9 col4" >3,5

# %%
stats_diff = birc_stats - orig_stats
nb_display(stats_diff.filter(regex=r'token|sentence|bigram|MB', axis=0))
# Out:
# <style type="text/css">
# #T_62134 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_62134 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_62134 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_62134 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_62134_row0_col0, #T_62134_row0_col1, #T_62134_row0_col2, #T_62134_row0_col3, #T_62134_row0_col4, #T_62134_row0_col5, #T_62134_row1_col0, #T_62134_row1_col1, #T_62134_row1_col2, #T_62134_row1_col3, #T_62134_row1_col4, #T_62134_row1_col5, #T_62134_row2_col0, #T_62134_row2_col1, #T_62134_row2_col2, #T_62134_row2_col3, #T_62134_row2_col4, #T_62134_row2_col5, #T_62134_row3_col0, #T_62134_row3_col1, #T_62134_row3_col2, #T_62134_row3_col3, #T_62134_row3_col4, #T_62134_row3_col5, #T_62134_row4_col0, #T_62134_row4_col1, #T_62134_row4_col2, #T_62134_row4_col3, #T_62134_row4_col4, #T_62134_row4_col5, #T_62134_row5_col0, #T_62134_row5_col1, #T_62134_row5_col2, #T_62134_row5_col3, #T_62134_row5_col4, #T_62134_row5_col5, #T_62134_row6_col0, #T_62134_row6_col1, #T_62134_row6_col2, #T_62134_row6_col3, #T_62134_row6_col4, #T_62134_row6_col5, #T_62134_row7_col0, #T_62134_row7_col1, #T_62134_row7_col2, #T_62134_row7_col3, #T_62134_row7_col4, #T_62134_row7_col5, #T_62134_row8_col0, #T_62134_row8_col1, #T_62134_row8_col2, #T_62134_row8_col3, #T_62134_row8_col4, #T_62134_row8_col5, #T_62134_row9_col0, #T_62134_row9_col1, #T_62134_row9_col2, #T_62134_row9_col3, #T_62134_row9_col4, #T_62134_row9_col5, #T_62134_row10_col0, #T_62134_row10_col1, #T_62134_row10_col2, #T_62134_row10_col3, #T_62134_row10_col4, #T_62134_row10_col5, #T_62134_row11_col0, #T_62134_row11_col1, #T_62134_row11_col2, #T_62134_row11_col3, #T_62134_row11_col4, #T_62134_row11_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_62134">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_62134_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_62134_level0_col1" class="col_heading level0 col1" >50%</th>
#       <th id="T_62134_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_62134_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_62134_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_62134_level0_col5" class="col_heading level0 col5" >CV%</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_62134_level0_row0" class="row_heading level0 row0" >file_MB</th>
#       <td id="T_62134_row0_col0" class="data row0 col0" >-328.23</td>
#       <td id="T_62134_row0_col1" class="data row0 col1" >-331.19</td>
#       <td id="T_62134_row0_col2" class="data row0 col2" >-1.07</td>
#       <td id="T_62134_row0_col3" class="data row0 col3" >-617.10</td>
#       <td id="T_62134_row0_col4" class="data row0 col4" >-1,187,213.30</td>
#       <td id="T_62134_row0_col5" class="data row0 col5" >3.40</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_62134_row1_col0" class="data row1 col0" >-240,341.35</td>
#       <td id="T_62134_row1_col1" class="data row1 col1" >-227,997.00</td>
#       <td id="T_62134_row1_col2" class="data row1 col2" >-1,069.00</td>
#       <td id="T_62134_row1_col3" class="data row1 col3" >-753,727.00</td>
#       <td id="T_62134_row1_col4" class="data row1 col4" >-869,314,654.00</td>
#       <td id="T_62134_row1_col5" class="data row1 col5" >-6.24</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_62134_row2_col0" class="data row2 col0" >-7,219,497.96</td>
#       <td id="T_62134_row2_col1" class="data row2 col1" >-7,091,442.00</td>
#       <td id="T_62134_row2_col2" class="data row2 col2" >-25,181.00</td>
#       <td id="T_62134_row2_col3" class="data row2 col3" >-17,941,402.00</td>
#       <td id="T_62134_row2_col4" class="data row2 col4" >-26,112,924,119.00</td>
#       <td id="T_62134_row2_col5" class="data row2 col5" >-1.92</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row3" class="row_heading level0 row3" >ADV_tokens</th>
#       <td id="T_62134_row3_col0" class="data row3 col0" >-159,853.50</td>
#       <td id="T_62134_row3_col1" class="data row3 col1" >-155,561.00</td>
#       <td id="T_62134_row3_col2" class="data row3 col2" >-698.00</td>
#       <td id="T_62134_row3_col3" class="data row3 col3" >-442,051.00</td>
#       <td id="T_62134_row3_col4" class="data row3 col4" >-578,190,124.00</td>
#       <td id="T_62134_row3_col5" class="data row3 col5" >-0.72</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row4" class="row_heading level0 row4" >ADJ_tokens</th>
#       <td id="T_62134_row4_col0" class="data row4 col0" >-280,472.61</td>
#       <td id="T_62134_row4_col1" class="data row4 col1" >-262,372.00</td>
#       <td id="T_62134_row4_col2" class="data row4 col2" >-1,596.00</td>
#       <td id="T_62134_row4_col3" class="data row4 col3" >-899,305.00</td>
#       <td id="T_62134_row4_col4" class="data row4 col4" >-1,014,469,421.00</td>
#       <td id="T_62134_row4_col5" class="data row4 col5" >-5.68</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row5" class="row_heading level0 row5" >NEG_tokens</th>
#       <td id="T_62134_row5_col0" class="data row5 col0" >-36,403.68</td>
#       <td id="T_62134_row5_col1" class="data row5 col1" >-34,618.00</td>
#       <td id="T_62134_row5_col2" class="data row5 col2" >-190.00</td>
#       <td id="T_62134_row5_col3" class="data row5 col3" >-115,331.00</td>
#       <td id="T_62134_row5_col4" class="data row5 col4" >-131,672,102.00</td>
#       <td id="T_62134_row5_col5" class="data row5 col5" >-6.00</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_62134_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_62134_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_62134_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_62134_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_62134_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_62134_row6_col5" class="data row6 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row7" class="row_heading level0 row7" >tok_per_bigram</th>
#       <td id="T_62134_row7_col0" class="data row7 col0" >-275.71</td>
#       <td id="T_62134_row7_col1" class="data row7 col1" >-271.08</td>
#       <td id="T_62134_row7_col2" class="data row7 col2" >-2.88</td>
#       <td id="T_62134_row7_col3" class="data row7 col3" >-609.61</td>
#       <td id="T_62134_row7_col4" class="data row7 col4" >-997,259.92</td>
#       <td id="T_62134_row7_col5" class="data row7 col5" >-4.89</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row8" class="row_heading level0 row8" >bigrams_per_mill</th>
#       <td id="T_62134_row8_col0" class="data row8 col0" >32,239.27</td>
#       <td id="T_62134_row8_col1" class="data row8 col1" >31,366.66</td>
#       <td id="T_62134_row8_col2" class="data row8 col2" >31,885.45</td>
#       <td id="T_62134_row8_col3" class="data row8 col3" >4,981.57</td>
#       <td id="T_62134_row8_col4" class="data row8 col4" >116,609,438.67</td>
#       <td id="T_62134_row8_col5" class="data row8 col5" >-12.34</td>
#     </tr>
#     <tr>
#       <th id="T_62134_level0_row9" class="row_heading level0 row9" >bigrams_per_ksent</th>
#       <td id="T_62134_row9_col0

# %%
stats_rediff = reduction_stats - stats_diff
nb_display(stats_rediff.filter(regex=r'token|sentence|bigram|MB', axis=0))
# Out:
# <style type="text/css">
# #T_3e1a0 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_3e1a0 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_3e1a0 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_3e1a0 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_3e1a0_row0_col0, #T_3e1a0_row0_col1, #T_3e1a0_row0_col2, #T_3e1a0_row0_col3, #T_3e1a0_row0_col4, #T_3e1a0_row0_col5, #T_3e1a0_row1_col0, #T_3e1a0_row1_col1, #T_3e1a0_row1_col2, #T_3e1a0_row1_col3, #T_3e1a0_row1_col4, #T_3e1a0_row1_col5, #T_3e1a0_row2_col0, #T_3e1a0_row2_col1, #T_3e1a0_row2_col2, #T_3e1a0_row2_col3, #T_3e1a0_row2_col4, #T_3e1a0_row2_col5, #T_3e1a0_row3_col0, #T_3e1a0_row3_col1, #T_3e1a0_row3_col2, #T_3e1a0_row3_col3, #T_3e1a0_row3_col4, #T_3e1a0_row3_col5, #T_3e1a0_row4_col0, #T_3e1a0_row4_col1, #T_3e1a0_row4_col2, #T_3e1a0_row4_col3, #T_3e1a0_row4_col4, #T_3e1a0_row4_col5, #T_3e1a0_row5_col0, #T_3e1a0_row5_col1, #T_3e1a0_row5_col2, #T_3e1a0_row5_col3, #T_3e1a0_row5_col4, #T_3e1a0_row5_col5, #T_3e1a0_row6_col0, #T_3e1a0_row6_col1, #T_3e1a0_row6_col2, #T_3e1a0_row6_col3, #T_3e1a0_row6_col4, #T_3e1a0_row6_col5, #T_3e1a0_row7_col0, #T_3e1a0_row7_col1, #T_3e1a0_row7_col2, #T_3e1a0_row7_col3, #T_3e1a0_row7_col4, #T_3e1a0_row7_col5, #T_3e1a0_row8_col0, #T_3e1a0_row8_col1, #T_3e1a0_row8_col2, #T_3e1a0_row8_col3, #T_3e1a0_row8_col4, #T_3e1a0_row8_col5, #T_3e1a0_row9_col0, #T_3e1a0_row9_col1, #T_3e1a0_row9_col2, #T_3e1a0_row9_col3, #T_3e1a0_row9_col4, #T_3e1a0_row9_col5, #T_3e1a0_row10_col0, #T_3e1a0_row10_col1, #T_3e1a0_row10_col2, #T_3e1a0_row10_col3, #T_3e1a0_row10_col4, #T_3e1a0_row10_col5, #T_3e1a0_row11_col0, #T_3e1a0_row11_col1, #T_3e1a0_row11_col2, #T_3e1a0_row11_col3, #T_3e1a0_row11_col4, #T_3e1a0_row11_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_3e1a0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3e1a0_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_3e1a0_level0_col1" class="col_heading level0 col1" >50%</th>
#       <th id="T_3e1a0_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_3e1a0_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_3e1a0_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_3e1a0_level0_col5" class="col_heading level0 col5" >CV%</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e1a0_level0_row0" class="row_heading level0 row0" >file_MB</th>
#       <td id="T_3e1a0_row0_col0" class="data row0 col0" >-0.00</td>
#       <td id="T_3e1a0_row0_col1" class="data row0 col1" >0.04</td>
#       <td id="T_3e1a0_row0_col2" class="data row0 col2" >-616.03</td>
#       <td id="T_3e1a0_row0_col3" class="data row0 col3" >616.03</td>
#       <td id="T_3e1a0_row0_col4" class="data row0 col4" >-0.00</td>
#       <td id="T_3e1a0_row0_col5" class="data row0 col5" >-16.20</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_3e1a0_row1_col0" class="data row1 col0" >0.00</td>
#       <td id="T_3e1a0_row1_col1" class="data row1 col1" >-6.00</td>
#       <td id="T_3e1a0_row1_col2" class="data row1 col2" >-752,658.00</td>
#       <td id="T_3e1a0_row1_col3" class="data row1 col3" >752,658.00</td>
#       <td id="T_3e1a0_row1_col4" class="data row1 col4" >0.00</td>
#       <td id="T_3e1a0_row1_col5" class="data row1 col5" >-20.29</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_3e1a0_row2_col0" class="data row2 col0" >0.00</td>
#       <td id="T_3e1a0_row2_col1" class="data row2 col1" >543.00</td>
#       <td id="T_3e1a0_row2_col2" class="data row2 col2" >-17,916,221.00</td>
#       <td id="T_3e1a0_row2_col3" class="data row2 col3" >17,995,737.00</td>
#       <td id="T_3e1a0_row2_col4" class="data row2 col4" >0.00</td>
#       <td id="T_3e1a0_row2_col5" class="data row2 col5" >-16.20</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row3" class="row_heading level0 row3" >ADV_tokens</th>
#       <td id="T_3e1a0_row3_col0" class="data row3 col0" >0.00</td>
#       <td id="T_3e1a0_row3_col1" class="data row3 col1" >67.00</td>
#       <td id="T_3e1a0_row3_col2" class="data row3 col2" >-441,353.00</td>
#       <td id="T_3e1a0_row3_col3" class="data row3 col3" >441,353.00</td>
#       <td id="T_3e1a0_row3_col4" class="data row3 col4" >0.00</td>
#       <td id="T_3e1a0_row3_col5" class="data row3 col5" >-18.80</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row4" class="row_heading level0 row4" >ADJ_tokens</th>
#       <td id="T_3e1a0_row4_col0" class="data row4 col0" >0.00</td>
#       <td id="T_3e1a0_row4_col1" class="data row4 col1" >92.00</td>
#       <td id="T_3e1a0_row4_col2" class="data row4 col2" >-897,709.00</td>
#       <td id="T_3e1a0_row4_col3" class="data row4 col3" >897,709.00</td>
#       <td id="T_3e1a0_row4_col4" class="data row4 col4" >0.00</td>
#       <td id="T_3e1a0_row4_col5" class="data row4 col5" >-22.58</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row5" class="row_heading level0 row5" >NEG_tokens</th>
#       <td id="T_3e1a0_row5_col0" class="data row5 col0" >0.00</td>
#       <td id="T_3e1a0_row5_col1" class="data row5 col1" >23.00</td>
#       <td id="T_3e1a0_row5_col2" class="data row5 col2" >-115,141.00</td>
#       <td id="T_3e1a0_row5_col3" class="data row5 col3" >115,141.00</td>
#       <td id="T_3e1a0_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_3e1a0_row5_col5" class="data row5 col5" >-19.63</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_3e1a0_row6_col0" class="data row6 col0" >0.00</td>
#       <td id="T_3e1a0_row6_col1" class="data row6 col1" >0.00</td>
#       <td id="T_3e1a0_row6_col2" class="data row6 col2" >0.00</td>
#       <td id="T_3e1a0_row6_col3" class="data row6 col3" >0.00</td>
#       <td id="T_3e1a0_row6_col4" class="data row6 col4" >0.00</td>
#       <td id="T_3e1a0_row6_col5" class="data row6 col5" >&nbsp;</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row7" class="row_heading level0 row7" >tok_per_bigram</th>
#       <td id="T_3e1a0_row7_col0" class="data row7 col0" >0.00</td>
#       <td id="T_3e1a0_row7_col1" class="data row7 col1" >-0.02</td>
#       <td id="T_3e1a0_row7_col2" class="data row7 col2" >-613.10</td>
#       <td id="T_3e1a0_row7_col3" class="data row7 col3" >612.79</td>
#       <td id="T_3e1a0_row7_col4" class="data row7 col4" >0.00</td>
#       <td id="T_3e1a0_row7_col5" class="data row7 col5" >-7.57</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row8" class="row_heading level0 row8" >bigrams_per_mill</th>
#       <td id="T_3e1a0_row8_col0" class="data row8 col0" >-0.00</td>
#       <td id="T_3e1a0_row8_col1" class="data row8 col1" >0.16</td>
#       <td id="T_3e1a0_row8_col2" class="data row8 col2" >-36,228.49</td>
#       <td id="T_3e1a0_row8_col3" class="data row8 col3" >36,570.56</td>
#       <td id="T_3e1a0_row8_col4" class="data row8 col4" >-0.00</td>
#       <td id="T_3e1a0_row8_col5" class="data row8 col5" >20.89</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row9" class="row_heading level0 row9" >bigrams_per_ksent</th>
#       <td id="T_3e1a0_row9_col0" class="data row9 col0" >0.00</td>
#       <td id="T_3e1a0_row9_col1" class="data row9 col1" >-0.14</td>
#       <td id="T_3e1a0_row9_col2" class="data row9 col2" >-30.26</td>
#       <td id="T_3e1a0_row9_col3" class="data row9 col3" >31.49</td>
#       <td id="T_3e1a0_row9_col4" class="data row9 col4" >0.00</td>
#       <td id="T_3e1a0_row9_col5" class="data row9 col5" >10.09</td>
#     </tr>
#     <tr>
#       <th id="T_3e1a0_level0_row10" class="row_heading level0 row

# %%
# %%

def reconfigure_counts(_counts_df, count_kind: str):
    return _counts_df.assign(
        kind=count_kind
    ).reset_index().set_index(['kind', 'corpus_slice']).unstack('kind')


orig_s = reconfigure_counts(orig_counts_df, count_kind='Full')
birc_s = reconfigure_counts(birc_counts_df, 'BiRC')
diff_s = reconfigure_counts(reduction_df, 'diff')
juxta = orig_s.join(birc_s).join(diff_s).convert_dtypes().sort_index(axis=1)

# juxta = orig_counts_df.join(birc_counts_df, rsuffix=':BiRC', lsuffix=':Full').join(reduction_df.add_suffix(':diff')).convert_dtypes()
juxta_desc = juxta.describe().iloc[1:, :]
juxta_desc.loc['TOTAL', :] = juxta.sum()
juxta_desc.index = juxta_desc.index.str.upper()
juxta_desc.loc['CV%', :] = (
    (juxta_desc.T.STD / juxta_desc.T.MEAN).fillna(0) * 100)

# save_path = save_latex_table(juxta_desc.T.convert_dtypes(),
#                  caption='Juxtaposed BiRC: Descriptive Stats', verbose=True,
#                  latex_subdir=REL_BIRC_TEX_DIR,
#                  latex_stem='birc-juxtaposed-descrip-stats-complete')
# if save_path is None: 
#     nb_display(set_my_style(juxta_desc.T.convert_dtypes()))
juxta_desc.stack('kind')
# Out:
#             ADJ_form_per_lemma     ADJ_forms    ADJ_lemmas  \
#       kind
# MEAN  BiRC             1.09741   6928.595798   6321.665469
#       Full            1.135688  18132.960188  16051.860658
#       diff           -0.038278  -11204.36439  -9730.195189
# STD   BiRC             0.02669   1027.290358   1047.608208
#       Full            0.036256   3441.836231   3710.774135
#       diff            0.010314   2636.304786   2852.517447
# MIN   BiRC                 1.0         145.0         145.0
#       Full            1.007716         653.0         648.0
#       diff           -0.092716      -27789.0      -26866.0
# 25%   BiRC            1.102833        6788.0        6135.0
#       Full            1.145225       17249.0       15030.0
#       diff           -0.043723      -10649.0       -9058.0
# 50%   BiRC            1.105679        6867.0        6205.0
#       Full            1.147375       17393.0       15164.0
#       diff           -0.040973      -10531.0       -8951.0
# 75%   BiRC            1.108397        6955.0        6287.0
#       Full            1.149459       17553.0       15316.0
#       diff            -0.03805      -10431.0       -8862.0
# MAX   BiRC            1.134041       12550.0       12298.0
#       Full            1.211316       40339.0       39164.0
#       diff           -0.004292        -508.0        -503.0
# TOTAL BiRC         3969.332419    25060731.0    22865464.0
#       Full         4107.784386    65586917.0    58059580.0
#       diff         -138.451967   -40526186.0   -35194116.0
# CV%   BiRC            2.432083     14.826819     16.571712
#       Full            3.192435     18.981105     23.117408
#       diff          -26.944638    -23.529267    -29.316138
#
#             ADJ_tok_per_bigram  ADJ_tok_per_form  ADJ_tok_per_ksent  \
#       kind
# MEAN  BiRC            2.418362          9.178742        2598.740665
#       Full           13.180262         18.901968        1299.893474
#       diff            -10.7619         -9.723226        1298.847191
# STD   BiRC            0.065775          0.809496          43.692255
#       Full            2.863657          2.194204          52.520707
#       diff            2.824321          1.552152          45.074167
# MIN   BiRC             2.23856          1.468966        2271.795521
#       Full            11.86092          2.770291         952.974036
#       diff          -28.298004        -21.992691         975.717422
# 25%   BiRC            2.389707          9.047001        2580.042182
#       Full           12.333296         18.533421        1281.406511
#       diff          -10.136599         -9.651247        1291.273621
# 50%   BiRC            2.400578          9.140206        2592.926666
#       Full           12.426187         18.682096        1289.702735
#       diff          -10.027732         -9.541231        1302.781769
# 75%   BiRC            2.413314          9.240442        2607.427612
#       Full           12.539208         18.840822        1298.581953
#       diff           -9.935299         -9.429797        1314.372346
# MAX   BiRC            2.845238         15.076557        3075.628588
#       Full           30.859906         34.979225        1648.765967
#       diff           -9.465358         -1.301325        1730.089916
# TOTAL BiRC         8747.215038      33199.511605     9399644.985559
#       Full        47673.006318      68368.418977     4701714.696015
#       diff        -38925.79128     -35168.907372     4697930.289544
# CV%   BiRC            2.719815          8.819244           1.681286
#       Full           21.726862         11.608334           4.040385
#       diff          -26.243705         -15.96334           3.470321
#
#             ADJ_tok_per_lemma  ADJ_tok_per_mill     ADJ_tokens  ADJ_xpos  ...  \
#       kind                                                                ...
# MEAN  BiRC          10.070426        86166.7605   63886.013547       3.0  ...
#       Full          21.445473      43374.635341  344358.620957       3.0  ...
#       diff         -11.375047      42792.125159 -280472.607409       0.0  ...
# STD   BiRC            0.83423        8924.42402   12921.907138       0.0  ...
#       Full           2.180164      12844.330364   89210.573882       0.0  ...
#       diff           1.526052      12211.102686   79264.142497       0.0  ...
# MIN   BiRC           1.468966      79799.685689          213.0       3.0  ...
#       Full           2.791667      37574.922799         1809.0       3.0  ...
#       diff         -23.004653     -654685.66771      -899305.0       0.0  ...
# 25%   BiRC          10.000319      82862.948134        61758.0       3.0  ...
#       Full          21.260058      41162.635743       321416.0       3.0  ...
#       diff         -11.459083      41526.856564      -265507.0       0.0  ...
# 50%   BiRC           10.10971      83283.729315        62800.0       3.0  ...
#       Full          21.435518      41442.631915       325172.0       3.0  ...
#       diff         -11.330744      41888.583624      -262280.0       0.0  ...
# 75%   BiRC           10.21682      83784.047329        63867.0       3.0  ...
#       Full          21.617293      41755.357843       329259.0       3.0  ...
#       diff         -11.194185      42320.838324      -259415.0       0.0  ...
# MAX   BiRC          15.354136      120159.50458       177632.0       3.0  ...
#       Full          36.250845     737301.723841      1076937.0       3.0  ...
#       diff          -1.322701      63876.205028        -1596.0       0.0  ...
# TOTAL BiRC       36424.732372  311665172.727584    231075711.0   10851.0  ...
#       Full       77568.276834  156886056.027471   1245545132.0   10851.0  ...
#       diff      -41143.544463  154779116.700113  -1014469421.0       0.0  ...
# CV%   BiRC           8.283958         10.357154      20.226504       0.0  ...
#       Full          10.166079         29.612538      25.906299       0.0  ...
#       diff          -13.41579         28.535864     -28.260921      <NA>  ...
#
#               NEG_tokens   NEG_xpos       bigrams  bigrams_per_ksent  \
#       kind
# MEAN  BiRC   7648.191595   9.828864  26399.329278        1074.949182
#       Full  44051.869229  14.020182  26399.329278         100.919081
#       diff -36403.677633  -4.191319           0.0         974.030101
# STD   BiRC   1292.408428   1.380076   4871.131447          16.714873
#       Full  10086.446223    2.00618   4871.131447          10.832203
#       diff   9328.879327    1.70466           0.0           8.877768
# MIN   BiRC          24.0        5.0          77.0         987.179487
#       Full         214.0        7.0          77.0          36.866788
#       diff     -115331.0      -11.0           0.0         920.047839
# 25%   BiRC        7608.0        9.0       25764.0        1077.736448
#       Full       41710.0       13.0       25764.0         102.529653
#       diff      -35248.0       -5.0           0.0         974.139289
# 50%   BiRC        7775.0       10.0       26167.0             1080.0
#       Full       42393.0       14.0       26167.0         103.634969
#       diff      -34595.0       -4.0           0.0         976.227374
# 75%   BiRC        7936.0       11.0       26585.0        1081.925676
#       Full       43161.0       15.0       26585.0         104.616698
#       diff      -34060.0       -3.0           0.0         978.027641
# MAX   BiRC       15995.0       15.0       69407.0        1095.911693
#       Full      131326.0       21.0       69407.0         109.912579
#       diff        -190.0        0.0           0.0        1017.493437
# TOTAL BiRC    27663509.0    35551.0    95486374.0     3888091.193028
#       Full   159335611.0    50711.0    95486374.0      365024.317581
#       diff  -131672102.0   -15160.0           0.0     3523066.875447
# CV%   BiRC     16.898222  14.041051     18.451724           1.554945
#       Full      22.89675  14.309229     18.451724          10.733552
#       diff      -25.6262 -40.671203          <NA>           0.911447
#
#             bigrams_per_mill     file_MB      sentences  tok_per_bigram  \
#       kind
# MEAN  BiRC      35567.413546   48.411269   24564.022671       28.245656
#       Full       3328.143801  376.642759  264905.370196      303.960314
#       diff      32239.269745  -328.23149 -240341.347526     -275.714659
# STD   BiRC       2636.640591    7.827544    4727.443967        1.754868
#       Full        657.449687   48.076895   67510.849923       33.745667
#       diff       2756.152844   42.014842   63751.013185        34.36072
# MIN   BiRC      33449.171241        0.09           78.0       22.639803
#       Full       1563.716266        1.16         1147.0       25.517736
#       diff      -4343.035265      -617.1      -753727.0      -615.97697
# 25%   BiRC      34638.081403       49.26        23867.0       28.757182
#       Full       3299.789891      376.87       249191.0      296.843153
#       diff      31304.434978     -335.07      -231181.0     -274.206478
# 50%   BiRC      34701.082847       50.12        24232.0       28.817545
#       Full       3334.423423      381.31       252229.0      299.901924
#       diff       31366.82034     -331.15      -228003.0     -271.100807
# 75%   BiRC      34773.921844       50.93        24603.0       28.869959
#       Full        3368.78243      385.88       255672.0      303.049598
#       diff      31434.886654     -327.31      -225298.0     -268.069976
# MAX   BiRC       44169.99542       76.52        66997.0       29.896107
#       Full      39188.429733      693.62       820724.0      639.502205
#       diff      41552.127098       -1.07        -1069.0        3.180461
# TOTAL BiRC  128647334.797221   175103.56     88848070.0    102164.53619
#       Full   12037896.128706  1362316.86    958162724.0  1099424.456601
#       diff  116609438.668515  -1187213.3   -869314654.0  -997259.920411
# CV%   BiRC          7.413079   16.168846      19.245398        6.212876
#       Full         19.754245   12.764588      25.484893       11.101998
#       diff          8.549055  -12.800369     -26.525196      -12.462421
#
#                tok_per_ksent          tokens
#       kind
# MEAN  BiRC      30390.397533   744482.659939
#       Full      30375.293006  7963980.619298
#       diff         15.104527 -7219497.959359
# STD   BiRC       2264.841388   115699.454022
#       Full       2297.508874  1390308.391637
#       diff        489.738945  1307642.670797
# MIN   BiRC      23524.093124          1836.0
#       Full       1744.826896         27017.0
#       diff       -207.146414     -17941402.0
# 25%   BiRC      31125.878488        741653.0
#       Full      31112.054703       7746686.0
#       diff          3.460209      -7188027.0
# 50%   BiRC      31139.456758        753252.0
#       Full      31125.938572       7844694.0
#       diff         12.636819      -7090899.0
# 75%   BiRC      31152.291269        765219.0
#       Full      31139.395508       7950766.0
#       diff         19.982793      -7001426.0
# MAX   BiRC      32195.978249       1591526.0
#       Full      32176.998737      19532928.0
#       diff      29417.697734         54335.0
# TOTAL BiRC  109922067.875727    2692793781.0
#       Full  109867434.802504   28805717900.0
#       diff      54633.073223  -26112924119.0
# CV%   BiRC           7.45249        15.54092
#       Full          7.563742       17.457456
#       diff       3242.332271      -18.112654
#
# [27 rows x 37 columns]

# %%
orig_stats
# Out:
#                               mean           50%           min            max  \
#
# file_MB                 376.642759        381.31          1.16         693.62
# sentences            264905.370196      252229.0        1147.0       820724.0
# tokens              7963980.619298     7844694.0       27017.0     19532928.0
# ADV_tokens            211630.73431      207234.0         840.0       570729.0
# ADV_xpos                       3.0           3.0           3.0            3.0
# ADV_lemmas             2373.409732        2380.0         185.0         3473.0
# ADV_forms              3022.908211        3076.0         195.0         3808.0
# ADJ_tokens           344358.620957      325172.0        1809.0      1076937.0
# ADJ_xpos                       3.0           3.0           3.0            3.0
# ADJ_lemmas            16051.860658       15164.0         648.0        39164.0
# ADJ_forms             18132.960188       17393.0         653.0        40339.0
# NEG_tokens            44051.869229       42393.0         214.0       131326.0
# NEG_xpos                 14.020182          14.0           7.0           21.0
# NEG_lemmas               14.995576          15.0          11.0           15.0
# NEG_forms                50.145148          52.0          16.0           61.0
# bigrams               26399.329278       26167.0          77.0        69407.0
# tok_per_bigram          303.960314    299.901924     25.517736     639.502205
# bigrams_per_mill       3328.143801   3334.423423   1563.716266   39188.429733
# ADV_tok_per_mill       26718.41561  26415.459711  16506.162419  479278.349333
# ADJ_tok_per_mill      43374.635341  41442.631915  37574.922799  737301.723841
# NEG_tok_per_mill       5551.801189   5402.466263   3929.536285   96553.464313
# tok_per_ksent         30375.293006  31125.938572   1744.826896   32176.998737
# bigrams_per_ksent       100.919081    103.634969     36.866788     109.912579
# ADV_tok_per_ksent       806.727306    821.356413    389.155764      886.41465
# ADJ_tok_per_ksent      1299.893474   1289.702735    952.974036    1648.765967
# NEG_tok_per_ksent       167.069143    167.969656      92.64429     223.678195
# ADV_tok_per_bigram        8.046232       7.92918       7.64009      12.230098
# ADJ_tok_per_bigram       13.180262     12.426187      11.86092      30.859906
# ADV_tok_per_lemma        88.876853       87.1162      4.540541     176.096575
# ADJ_tok_per_lemma        21.445473     21.435518      2.791667      36.250845
# NEG_tok_per_lemma      2937.273175        2826.2     19.454545    8755.066667
# ADV_tok_per_form          70.22003     67.424742      4.307692     160.092286
# ADJ_tok_per_form         18.901968     18.682096      2.770291      34.979225
# NEG_tok_per_form        909.664883    818.788462        13.375    3549.351351
# ADV_form_per_lemma        1.272915      1.291615      1.054054       1.327456
# ADJ_form_per_lemma        1.135688      1.147375      1.007716       1.211316
# NEG_form_per_lemma        3.343584      3.466667      1.454545       4.066667
#
#                                Total        CV%
#
# file_MB                   1362316.86  12.764588
# sentences                958162724.0  25.484893
# tokens                 28805717900.0  17.457456
# ADV_tokens               765468366.0  18.714909
# ADV_xpos                     10851.0        0.0
# ADV_lemmas                 8584623.0   9.654474
# ADV_forms                 10933859.0  10.116005
# ADJ_tokens              1245545132.0  25.906299
# ADJ_xpos                     10851.0        0.0
# ADJ_lemmas                58059580.0  23.117408
# ADJ_forms                 65586917.0  18.981105
# NEG_tokens               159335611.0   22.89675
# NEG_xpos                     50711.0  14.309229
# NEG_lemmas                   54239.0   0.586073
# NEG_forms                   181375.0  12.842644
# bigrams                   95486374.0  18.451724
# tok_per_bigram        1099424.456601  11.101998
# bigrams_per_mill     12037896.128706  19.754245
# ADV_tok_per_mill     96640509.261629  28.867916
# ADJ_tok_per_mill    156886056.027471  29.612538
# NEG_tok_per_mill     20080864.900171  28.995261
# tok_per_ksent       109867434.802504   7.563742
# bigrams_per_ksent      365024.317581  10.733552
# ADV_tok_per_ksent     2917932.665806   7.384976
# ADJ_tok_per_ksent     4701714.696015   4.040385
# NEG_tok_per_ksent       604289.08863   6.053056
# ADV_tok_per_bigram      29103.219651    6.37842
# ADJ_tok_per_bigram      47673.006318  21.726862
# ADV_tok_per_lemma      321467.575759  13.099216
# ADJ_tok_per_lemma       77568.276834  10.166079
# NEG_tok_per_lemma    10624117.073593  22.887581
# ADV_tok_per_form       253985.849321  18.036779
# ADJ_tok_per_form        68368.418977  11.608334
# NEG_tok_per_form      3290257.881089  39.633141
# ADV_form_per_lemma       4604.135303   4.701489
# ADJ_form_per_lemma       4107.784386   3.192435
# NEG_form_per_lemma      12093.745022  12.784605

# %%
juxta = juxta.assign(
    corpus=juxta.index.to_series().str[:3].map(
        {'apw': 'News', 'nyt': 'News', 'pcc': 'Puddin'}).astype('category'))
juxta = juxta.reset_index().set_index(['corpus']+juxta.index.names)
juxta = juxta.sort_index().sort_index(axis=1)

# %%
juxta.filter(like='tokens').sum().unstack(0)
# Out:
#        ADJ_tokens  ADV_tokens  NEG_tokens        tokens
# kind
# BiRC    231075711   187278242    27663509    2692793781
# Full   1245545132   765468366   159335611   28805717900
# diff  -1014469421  -578190124  -131672102  -26112924119

# %%
news_orig = juxta.xs('News').filter(like='Full').droplevel('kind',axis=1)
news_stats = _stat(news_orig)
news_summary = news_stats.T.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams'])
nb_display(news_summary.style.set_caption('News Summary'))
# Out:
# <style type="text/css">
# #T_08514 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_08514 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_08514 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_08514 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_08514_row0_col0, #T_08514_row0_col1, #T_08514_row0_col2, #T_08514_row0_col3, #T_08514_row0_col4, #T_08514_row0_col5, #T_08514_row1_col0, #T_08514_row1_col1, #T_08514_row1_col2, #T_08514_row1_col3, #T_08514_row1_col4, #T_08514_row1_col5, #T_08514_row2_col0, #T_08514_row2_col1, #T_08514_row2_col2, #T_08514_row2_col3, #T_08514_row2_col4, #T_08514_row2_col5, #T_08514_row3_col0, #T_08514_row3_col1, #T_08514_row3_col2, #T_08514_row3_col3, #T_08514_row3_col4, #T_08514_row3_col5, #T_08514_row4_col0, #T_08514_row4_col1, #T_08514_row4_col2, #T_08514_row4_col3, #T_08514_row4_col4, #T_08514_row4_col5, #T_08514_row5_col0, #T_08514_row5_col1, #T_08514_row5_col2, #T_08514_row5_col3, #T_08514_row5_col4, #T_08514_row5_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_08514">
#   <caption>News Summary</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_08514_level0_col0" class="col_heading level0 col0" >file_MB</th>
#       <th id="T_08514_level0_col1" class="col_heading level0 col1" >sentences</th>
#       <th id="T_08514_level0_col2" class="col_heading level0 col2" >tokens</th>
#       <th id="T_08514_level0_col3" class="col_heading level0 col3" >ADV_tokens</th>
#       <th id="T_08514_level0_col4" class="col_heading level0 col4" >ADJ_tokens</th>
#       <th id="T_08514_level0_col5" class="col_heading level0 col5" >bigrams</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_08514_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_08514_row0_col0" class="data row0 col0" >329.63</td>
#       <td id="T_08514_row0_col1" class="data row0 col1" >375,423.08</td>
#       <td id="T_08514_row0_col2" class="data row0 col2" >8,919,504.15</td>
#       <td id="T_08514_row0_col3" class="data row0 col3" >248,527.63</td>
#       <td id="T_08514_row0_col4" class="data row0 col4" >514,518.04</td>
#       <td id="T_08514_row0_col5" class="data row0 col5" >28,213.03</td>
#     </tr>
#     <tr>
#       <th id="T_08514_level0_row1" class="row_heading level0 row1" >50%</th>
#       <td id="T_08514_row1_col0" class="data row1 col0" >322.20</td>
#       <td id="T_08514_row1_col1" class="data row1 col1" >345,973.50</td>
#       <td id="T_08514_row1_col2" class="data row1 col2" >8,227,311.00</td>
#       <td id="T_08514_row1_col3" class="data row1 col3" >246,215.50</td>
#       <td id="T_08514_row1_col4" class="data row1 col4" >507,421.50</td>
#       <td id="T_08514_row1_col5" class="data row1 col5" >26,735.50</td>
#     </tr>
#     <tr>
#       <th id="T_08514_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_08514_row2_col0" class="data row2 col0" >1.16</td>
#       <td id="T_08514_row2_col1" class="data row2 col1" >1,147.00</td>
#       <td id="T_08514_row2_col2" class="data row2 col2" >27,017.00</td>
#       <td id="T_08514_row2_col3" class="data row2 col3" >840.00</td>
#       <td id="T_08514_row2_col4" class="data row2 col4" >1,809.00</td>
#       <td id="T_08514_row2_col5" class="data row2 col5" >77.00</td>
#     </tr>
#     <tr>
#       <th id="T_08514_level0_row3" class="row_heading level0 row3" >max</th>
#       <td id="T_08514_row3_col0" class="data row3 col0" >693.62</td>
#       <td id="T_08514_row3_col1" class="data row3 col1" >820,724.00</td>
#       <td id="T_08514_row3_col2" class="data row3 col2" >19,532,928.00</td>
#       <td id="T_08514_row3_col3" class="data row3 col3" >570,729.00</td>
#       <td id="T_08514_row3_col4" class="data row3 col4" >1,076,937.00</td>
#       <td id="T_08514_row3_col5" class="data row3 col5" >69,407.00</td>
#     </tr>
#     <tr>
#       <th id="T_08514_level0_row4" class="row_heading level0 row4" >Total</th>
#       <td id="T_08514_row4_col0" class="data row4 col0" >121,962.44</td>
#       <td id="T_08514_row4_col1" class="data row4 col1" >138,906,541.00</td>
#       <td id="T_08514_row4_col2" class="data row4 col2" >3,300,216,537.00</td>
#       <td id="T_08514_row4_col3" class="data row4 col3" >91,955,223.00</td>
#       <td id="T_08514_row4_col4" class="data row4 col4" >190,371,676.00</td>
#       <td id="T_08514_row4_col5" class="data row4 col5" >10,438,820.00</td>
#     </tr>
#     <tr>
#       <th id="T_08514_level0_row5" class="row_heading level0 row5" >CV%</th>
#       <td id="T_08514_row5_col0" class="data row5 col0" >42.51</td>
#       <td id="T_08514_row5_col1" class="data row5 col1" >46.73</td>
#       <td id="T_08514_row5_col2" class="data row5 col2" >46.88</td>
#       <td id="T_08514_row5_col3" class="data row5 col3" >47.01</td>
#       <td id="T_08514_row5_col4" class="data row5 col4" >41.36</td>
#       <td id="T_08514_row5_col5" class="data row5 col5" >53.18</td>
#     </tr>
#   </tbody>
# </table>

# %%
apw_orig = news_orig.filter(like='apw', axis=0)
apw_brief = apw_orig.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams'])

apw_stats = pd.concat([apw_brief.describe(),_stat(apw_brief).T, ]).drop_duplicates()
print(apw_stats.to_latex(escape='latex'))
# Out:
#           file_MB      sentences          tokens    ADV_tokens     ADJ_tokens  \
# count       178.0          178.0           178.0         178.0          178.0
# mean   301.714382  343115.561798  8121211.213483  189195.05618  470498.426966
# std    115.137775  150303.679155  3571605.268637  68871.040949  172235.443565
# min          1.16         1147.0         27017.0         840.0         1809.0
# 25%       214.525       234476.5       5533844.5     135132.25       346318.0
# 50%        284.41       305206.5       7204914.0      175909.0       458215.0
# 75%      402.9425      479051.75      11387051.5      256488.5      633997.75
# max        525.86       751043.0      17745454.0      317547.0       775489.0
#
#             bigrams
# count         178.0
# mean   18762.146067
# std     7180.196888
# min            77.0
# 25%         12910.0
# 50%         17008.0
# 75%         25997.5
# max         32508.0

# %%
nyt_orig = news_orig.filter(like='nyt_eng_1', axis=0)
nyt_brief = nyt_orig.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams'])

nyt_stats = pd.concat([nyt_brief.describe(),_stat(nyt_brief).T, ]).drop_duplicates()
print(nyt_stats.to_latex(escape='latex'))
# Out:
# \begin{tabular}{lrrrrrr}
# \toprule
#  & file\_MB & sentences & tokens & ADV\_tokens & ADJ\_tokens & bigrams \\
# \midrule
# count & 65.000000 & 65.000000 & 65.000000 & 65.000000 & 65.000000 & 65.000000 \\
# mean & 490.418462 & 580425.600000 & 13825478.261538 & 408590.246154 & 757593.353846 & 49383.969231 \\
# std & 123.421318 & 153231.098662 & 3651586.751842 & 86518.760808 & 186439.351356 & 10112.051827 \\
# min & 241.240000 & 260787.000000 & 6194247.000000 & 219127.000000 & 386135.000000 & 27368.000000 \\
# 25\% & 427.600000 & 513593.000000 & 12250599.000000 & 369495.000000 & 653601.000000 & 45831.000000 \\
# 50\% & 474.040000 & 569300.000000 & 13582626.000000 & 406979.000000 & 730488.000000 & 49716.000000 \\
# 75\% & 598.020000 & 713551.000000 & 16990496.000000 & 475242.000000 & 916196.000000 & 56292.000000 \\
# max & 693.620000 & 820724.000000 & 19532928.000000 & 570729.000000 & 1076937.000000 & 69407.000000 \\
# Total & 31877.200000 & 37727664.000000 & 898656087.000000 & 26558366.000000 & 49243568.000000 & 3209958.000000 \\
# CV\% & 25.166532 & 26.399783 & 26.412010 & 21.174945 & 24.609423 & 20.476385 \\
# \bottomrule
# \end{tabular}

# %%
pudd_orig = juxta.xs('Puddin').filter(like='Full').droplevel('kind',axis=1)
pudd_stats = _stat(pudd_orig)
pudd_summary = pudd_stats.T.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams'])
nb_display(pudd_summary.style.set_caption('Puddin Summary'))

nb_display((pudd_summary - news_summary).style.set_caption('Summary Discrepancy<br/>(<code>Puddin - News</code>)'))

# %%
save_latex_table(news_orig.describe().T.assign(total=news_orig.sum()).iloc[:,1:].T.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams']),
                 caption='News Summary Statistics (\\num{370} files)',verbose=True,
                 latex_subdir='describe_corpora', latex_stem='news-summary-stats-full', 
                 default_SI='10.0'
                 )
save_latex_table(pudd_orig.describe().T.assign(total=pudd_orig.sum()).iloc[:,1:].T.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams']),
                 caption='Puddin Summary Statistics (\\num{3,247} files)',verbose=True,
                 latex_subdir='describe_corpora', latex_stem='puddin-summary-stats-full', 
                 default_SI='11.0'
                 )
save_latex_table(news_stats.T.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams']),
                 caption='News Summary Statistics (\\num{370} files)',verbose=True,
                 latex_subdir='describe_corpora', latex_stem='news-summary-stats-main', 
                 default_SI='10.0'
                 )
save_latex_table(pudd_stats.T.filter(['file_MB','sentences','tokens','ADV_tokens','ADJ_tokens', 'bigrams']),
                 caption='Puddin Summary Statistics (\\num{3,247} files)',verbose=True,
                 latex_subdir='describe_corpora', latex_stem='puddin-summary-stats-main', 
                 default_SI='11.0'
                 )
# Out:
# Caption: News Summary Statistics (\num{370} files)
# *{1}{l}S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
# <style type="text/css">
# #T_312f0 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_312f0 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_312f0 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_312f0 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_312f0_row0_col0, #T_312f0_row0_col1, #T_312f0_row0_col2, #T_312f0_row0_col3, #T_312f0_row0_col4, #T_312f0_row0_col5, #T_312f0_row1_col0, #T_312f0_row1_col1, #T_312f0_row1_col2, #T_312f0_row1_col3, #T_312f0_row1_col4, #T_312f0_row1_col5, #T_312f0_row2_col0, #T_312f0_row2_col1, #T_312f0_row2_col2, #T_312f0_row2_col3, #T_312f0_row2_col4, #T_312f0_row2_col5, #T_312f0_row3_col0, #T_312f0_row3_col1, #T_312f0_row3_col2, #T_312f0_row3_col3, #T_312f0_row3_col4, #T_312f0_row3_col5, #T_312f0_row4_col0, #T_312f0_row4_col1, #T_312f0_row4_col2, #T_312f0_row4_col3, #T_312f0_row4_col4, #T_312f0_row4_col5, #T_312f0_row5_col0, #T_312f0_row5_col1, #T_312f0_row5_col2, #T_312f0_row5_col3, #T_312f0_row5_col4, #T_312f0_row5_col5, #T_312f0_row6_col0, #T_312f0_row6_col1, #T_312f0_row6_col2, #T_312f0_row6_col3, #T_312f0_row6_col4, #T_312f0_row6_col5, #T_312f0_row7_col0, #T_312f0_row7_col1, #T_312f0_row7_col2, #T_312f0_row7_col3, #T_312f0_row7_col4, #T_312f0_row7_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_312f0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_312f0_level0_col0" class="col_heading level0 col0" >file\_MB</th>
#       <th id="T_312f0_level0_col1" class="col_heading level0 col1" >sentences</th>
#       <th id="T_312f0_level0_col2" class="col_heading level0 col2" >tokens</th>
#       <th id="T_312f0_level0_col3" class="col_heading level0 col3" >ADV\_tokens</th>
#       <th id="T_312f0_level0_col4" class="col_heading level0 col4" >ADJ\_tokens</th>
#       <th id="T_312f0_level0_col5" class="col_heading level0 col5" >bigrams</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_312f0_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_312f0_row0_col0" class="data row0 col0" >329.63</td>
#       <td id="T_312f0_row0_col1" class="data row0 col1" >375,423.08</td>
#       <td id="T_312f0_row0_col2" class="data row0 col2" >8,919,504.15</td>
#       <td id="T_312f0_row0_col3" class="data row0 col3" >248,527.63</td>
#       <td id="T_312f0_row0_col4" class="data row0 col4" >514,518.04</td>
#       <td id="T_312f0_row0_col5" class="data row0 col5" >28,213.03</td>
#     </tr>
#     <tr>
#       <th id="T_312f0_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_312f0_row1_col0" class="data row1 col0" >140.14</td>
#       <td id="T_312f0_row1_col1" class="data row1 col1" >175,417.41</td>
#       <td id="T_312f0_row1_col2" class="data row1 col2" >4,181,676.07</td>
#       <td id="T_312f0_row1_col3" class="data row1 col3" >116,829.05</td>
#       <td id="T_312f0_row1_col4" class="data row1 col4" >212,779.55</td>
#       <td id="T_312f0_row1_col5" class="data row1 col5" >15,003.57</td>
#     </tr>
#     <tr>
#       <th id="T_312f0_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_312f0_row2_col0" class="data row2 col0" >1.16</td>
#       <td id="T_312f0_row2_col1" class="data row2 col1" >1,147.00</td>
#       <td id="T_312f0_row2_col2" class="data row2 col2" >27,017.00</td>
#       <td id="T_312f0_row2_col3" class="data row2 col3" >840.00</td>
#       <td id="T_312f0_row2_col4" class="data row2 col4" >1,809.00</td>
#       <td id="T_312f0_row2_col5" class="data row2 col5" >77.00</td>
#     </tr>
#     <tr>
#       <th id="T_312f0_level0_row3" class="row_heading level0 row3" >25\%</th>
#       <td id="T_312f0_row3_col0" class="data row3 col0" >226.54</td>
#       <td id="T_312f0_row3_col1" class="data row3 col1" >241,787.25</td>
#       <td id="T_312f0_row3_col2" class="data row3 col2" >5,716,480.00</td>
#       <td id="T_312f0_row3_col3" class="data row3 col3" >159,126.00</td>
#       <td id="T_312f0_row3_col4" class="data row3 col4" >361,820.75</td>
#       <td id="T_312f0_row3_col5" class="data row3 col5" >15,906.00</td>
#     </tr>
#     <tr>
#       <th id="T_312f0_level0_row4" class="row_heading level0 row4" >50\%</th>
#       <td id="T_312f0_row4_col0" class="data row4 col0" >322.20</td>
#       <td id="T_312f0_row4_col1" class="data row4 col1" >345,973.50</td>
#       <td id="T_312f0_row4_col2" class="data row4 col2" >8,227,311.00</td>
#       <td id="T_312f0_row4_col3" class="data row4 col3" >246,215.50</td>
#       <td id="T_312f0_row4_col4" class="data row4 col4" >507,421.50</td>
#       <td id="T_312f0_row4_col5" class="data row4 col5" >26,735.50</td>
#     </tr>
#     <tr>
#       <th id="T_312f0_level0_row5" class="row_heading level0 row5" >75\%</th>
#       <td id="T_312f0_row5_col0" class="data row5 col0" >432.06</td>
#       <td id="T_312f0_row5_col1" class="data row5 col1" >503,977.00</td>
#       <td id="T_312f0_row5_col2" class="data row5 col2" >11,997,737.75</td>
#       <td id="T_312f0_row5_col3" class="data row5 col3" >313,945.00</td>
#       <td id="T_312f0_row5_col4" class="data row5 col4" >671,683.75</td>
#       <td id="T_312f0_row5_col5" class="data row5 col5" >38,220.25</td>
#     </tr>
#     <tr>
#       <th id="T_312f0_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_312f0_row6_col0" class="data row6 col0" >693.62</td>
#       <td id="T_312f0_row6_col1" class="data row6 col1" >820,724.00</td>
#       <td id="T_312f0_row6_col2" class="data row6 col2" >19,532,928.00</td>
#       <td id="T_312f0_row6_col3" class="data row6 col3" >570,729.00</td>
#       <td id="T_312f0_row6_col4" class="data row6 col4" >1,076,937.00</td>
#       <td id="T_312f0_row6_col5" class="data row6 col5" >69,407.00</td>
#     </tr>
#     <tr>
#       <th id="T_312f0_level0_row7" class="row_heading level0 row7" >total</th>
#       <td id="T_312f0_row7_col0" class="data row7 col0" >121,962.44</td>
#       <td id="T_312f0_row7_col1" class="data row7 col1" >138,906,541.00</td>
#       <td id="T_312f0_row7_col2" class="data row7 col2" >3,300,216,537.00</td>
#       <td id="T_312f0_row7_col3" class="data row7 col3" >91,955,223.00</td>
#       <td id="T_312f0_row7_col4" class="data row7 col4" >190,371,676.00</td>
#       <td id="T_312f0_row7_col5" class="data row7 col5" >10,438,820.00</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/news-summary-stats-full.2025-02-18.tex
#
# Caption: Puddin Summary Statistics (\num{3,247} files)
# *{1}{l}S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
# <style type="text/css">
# #T_e04d1 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e04d1 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e04d1 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e04d1 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e04d1_row0_col0, #T_e04d1_row0_col1, #T_e04d1_row0_col2, #T_e04d1_row0_col3, #T_e04d1_row0_col4, #T_e04d1_row0_col5, #T_e04d1_row1_col0, #T_e04d1_row1_col1, #T_e04d1_row1_col2, #T_e04d1_row1_col3, #T_e04d1_row1_col4, #T_e04d1_row1_col5, #T_e04d1_row2_col0, #T_e04d1_row2_col1, #T_e04d1_row2_col2, #T_e04d1_row2_col3, #T_e04d1_row2_col4, #T_e04d1_row2_col5, #T_e04d1_row3_col0, #T_e04d1_row3_col1, #T_e04d1_row3_col2, #T_e04d1_row3_col3, #T_e04d1_row3_col4, #T_e04d1_row3_col5, #T_e04d1_row4_col0, #T_e04d1_row4_col1, #T_e04d1_row4_col2, #T_e04d1_row4_col3, #T_e04d1_row4_col4, #T_e04d1_row4_col5, #T_e04d1_row5_col0, #T_e04d1_row5_col1, #T_e04d1_row5_col2, #T_e04d1_row5_col3, #T_e04d1_row5_col4, #T_e04d1_row5_col5, #T_e04d1_row6_col0, #T_e04d1_row6_col1, #T_e04d1_row6_col2, #T_e04d1_row6_col3, #T_e04d1_row6_col4, #T_e04d1_row6_col5, #T_e04d1_row7_col0, #T_e04d1_row7_col1, #T_e04d1_row7_col2, #T_e04d1_row7_col3, #T_e04d1_row7_col4, #T_e04d1_row7_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_e04d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e04d1_level0_col0" class="col_heading level0 col0" >file\_MB</th>
#       <th id="T_e04d1_level0_col1" class="col_heading level0 col1" >sentences</th>
#       <th id="T_e04d1_level0_col2" class="col_heading level0 col2" >tokens</th>
#       <th id="T_e04d1_level0_col3" class="col_heading level0 col3" >ADV\_tokens</th>
#       <th id="T_e04d1_level0_col4" class="col_heading level0 col4" >ADJ\_tokens</th>
#       <th id="T_e04d1_level0_col5" class="col_heading level0 col5" >bigrams</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e04d1_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_e04d1_row0_col0" class="data row0 col0" >382.00</td>
#       <td id="T_e04d1_row0_col1" class="data row0 col1" >252,311.73</td>
#       <td id="T_e04d1_row0_col2" class="data row0 col2" >7,855,097.43</td>
#       <td id="T_e04d1_row0_col3" class="data row0 col3" >207,426.28</td>
#       <td id="T_e04d1_row0_col4" class="data row0 col4" >324,968.73</td>
#       <td id="T_e04d1_row0_col5" class="data row0 col5" >26,192.66</td>
#     </tr>
#     <tr>
#       <th id="T_e04d1_level0_row1" class="row_heading level0 row1" >std</th>
#       <td id="T_e04d1_row1_col0" class="data row1 col0" >7.85</td>
#       <td id="T_e04d1_row1_col1" class="data row1 col1" >5,320.44</td>
#       <td id="T_e04d1_row1_col2" class="data row1 col2" >222,552.20</td>
#       <td id="T_e04d1_row1_col3" class="data row1 col3" >4,798.07</td>
#       <td id="T_e04d1_row1_col4" class="data row1 col4" >6,512.56</td>
#       <td id="T_e04d1_row1_col5" class="data row1 col5" >652.00</td>
#     </tr>
#     <tr>
#       <th id="T_e04d1_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_e04d1_row2_col0" class="data row2 col0" >260.26</td>
#       <td id="T_e04d1_row2_col1" class="data row2 col1" >173,016.00</td>
#       <td id="T_e04d1_row2_col2" class="data row2 col2" >435,945.00</td>
#       <td id="T_e04d1_row2_col3" class="data row2 col3" >138,338.00</td>
#       <td id="T_e04d1_row2_col4" class="data row2 col4" >221,985.00</td>
#       <td id="T_e04d1_row2_col5" class="data row2 col5" >17,084.00</td>
#     </tr>
#     <tr>
#       <th id="T_e04d1_level0_row3" class="row_heading level0 row3" >25\%</th>
#       <td id="T_e04d1_row3_col0" class="data row3 col0" >377.56</td>
#       <td id="T_e04d1_row3_col1" class="data row3 col1" >249,219.00</td>
#       <td id="T_e04d1_row3_col2" class="data row3 col2" >7,755,111.50</td>
#       <td id="T_e04d1_row3_col3" class="data row3 col3" >204,621.50</td>
#       <td id="T_e04d1_row3_col4" class="data row3 col4" >321,259.00</td>
#       <td id="T_e04d1_row3_col5" class="data row3 col5" >25,806.50</td>
#     </tr>
#     <tr>
#       <th id="T_e04d1_level0_row4" class="row_heading level0 row4" >50\%</th>
#       <td id="T_e04d1_row4_col0" class="data row4 col0" >381.50</td>
#       <td id="T_e04d1_row4_col1" class="data row4 col1" >251,996.00</td>
#       <td id="T_e04d1_row4_col2" class="data row4 col2" >7,844,206.00</td>
#       <td id="T_e04d1_row4_col3" class="data row4 col3" >207,094.00</td>
#       <td id="T_e04d1_row4_col4" class="data row4 col4" >324,679.00</td>
#       <td id="T_e04d1_row4_col5" class="data row4 col5" >26,164.00</td>
#     </tr>
#     <tr>
#       <th id="T_e04d1_level0_row5" class="row_heading level0 row5" >75\%</th>
#       <td id="T_e04d1_row5_col0" class="data row5 col0" >385.61</td>
#       <td id="T_e04d1_row5_col1" class="data row5 col1" >254,840.00</td>
#       <td id="T_e04d1_row5_col2" class="data row5 col2" >7,936,449.50</td>
#       <td id="T_e04d1_row5_col3" class="data row5 col3" >209,803.50</td>
#       <td id="T_e04d1_row5_col4" class="data row5 col4" >328,024.50</td>
#       <td id="T_e04d1_row5_col5" class="data row5 col5" >26,539.00</td>
#     </tr>
#     <tr>
#       <th id="T_e04d1_level0_row6" class="row_heading level0 row6" >max</th>
#       <td id="T_e04d1_row6_col0" class="data row6 col0" >437.54</td>
#       <td id="T_e04d1_row6_col1" class="data row6 col1" >290,337.00</td>
#       <td id="T_e04d1_row6_col2" class="data row6 col2" >9,334,512.00</td>
#       <td id="T_e04d1_row6_col3" class="data row6 col3" >238,165.00</td>
#       <td id="T_e04d1_row6_col4" class="data row6 col4" >373,124.00</td>
#       <td id="T_e04d1_row6_col5" class="data row6 col5" >30,002.00</td>
#     </tr>
#     <tr>
#       <th id="T_e04d1_level0_row7" class="row_heading level0 row7" >total</th>
#       <td id="T_e04d1_row7_col0" class="data row7 col0" >1,240,354.42</td>
#       <td id="T_e04d1_row7_col1" class="data row7 col1" >819,256,183.00</td>
#       <td id="T_e04d1_row7_col2" class="data row7 col2" >25,505,501,363.00</td>
#       <td id="T_e04d1_row7_col3" class="data row7 col3" >673,513,143.00</td>
#       <td id="T_e04d1_row7_col4" class="data row7 col4" >1,055,173,456.00</td>
#       <td id="T_e04d1_row7_col5" class="data row7 col5" >85,047,554.00</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/puddin-summary-stats-full.2025-02-18.tex
#
# Caption: News Summary Statistics (\num{370} files)
# *{1}{l}S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
#     S[table-auto-round, table-format=10.0, drop-zero-decimal]
# <style type="text/css">
# #T_ae4ea th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_ae4ea th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_ae4ea th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_ae4ea caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_ae4ea_row0_col0, #T_ae4ea_row0_col1, #T_ae4ea_row0_col2, #T_ae4ea_row0_col3, #T_ae4ea_row0_col4, #T_ae4ea_row0_col5, #T_ae4ea_row1_col0, #T_ae4ea_row1_col1, #T_ae4ea_row1_col2, #T_ae4ea_row1_col3, #T_ae4ea_row1_col4, #T_ae4ea_row1_col5, #T_ae4ea_row2_col0, #T_ae4ea_row2_col1, #T_ae4ea_row2_col2, #T_ae4ea_row2_col3, #T_ae4ea_row2_col4, #T_ae4ea_row2_col5, #T_ae4ea_row3_col0, #T_ae4ea_row3_col1, #T_ae4ea_row3_col2, #T_ae4ea_row3_col3, #T_ae4ea_row3_col4, #T_ae4ea_row3_col5, #T_ae4ea_row4_col0, #T_ae4ea_row4_col1, #T_ae4ea_row4_col2, #T_ae4ea_row4_col3, #T_ae4ea_row4_col4, #T_ae4ea_row4_col5, #T_ae4ea_row5_col0, #T_ae4ea_row5_col1, #T_ae4ea_row5_col2, #T_ae4ea_row5_col3, #T_ae4ea_row5_col4, #T_ae4ea_row5_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_ae4ea">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ae4ea_level0_col0" class="col_heading level0 col0" >file\_MB</th>
#       <th id="T_ae4ea_level0_col1" class="col_heading level0 col1" >sentences</th>
#       <th id="T_ae4ea_level0_col2" class="col_heading level0 col2" >tokens</th>
#       <th id="T_ae4ea_level0_col3" class="col_heading level0 col3" >ADV\_tokens</th>
#       <th id="T_ae4ea_level0_col4" class="col_heading level0 col4" >ADJ\_tokens</th>
#       <th id="T_ae4ea_level0_col5" class="col_heading level0 col5" >bigrams</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae4ea_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_ae4ea_row0_col0" class="data row0 col0" >329.63</td>
#       <td id="T_ae4ea_row0_col1" class="data row0 col1" >375,423.08</td>
#       <td id="T_ae4ea_row0_col2" class="data row0 col2" >8,919,504.15</td>
#       <td id="T_ae4ea_row0_col3" class="data row0 col3" >248,527.63</td>
#       <td id="T_ae4ea_row0_col4" class="data row0 col4" >514,518.04</td>
#       <td id="T_ae4ea_row0_col5" class="data row0 col5" >28,213.03</td>
#     </tr>
#     <tr>
#       <th id="T_ae4ea_level0_row1" class="row_heading level0 row1" >50\%</th>
#       <td id="T_ae4ea_row1_col0" class="data row1 col0" >322.20</td>
#       <td id="T_ae4ea_row1_col1" class="data row1 col1" >345,973.50</td>
#       <td id="T_ae4ea_row1_col2" class="data row1 col2" >8,227,311.00</td>
#       <td id="T_ae4ea_row1_col3" class="data row1 col3" >246,215.50</td>
#       <td id="T_ae4ea_row1_col4" class="data row1 col4" >507,421.50</td>
#       <td id="T_ae4ea_row1_col5" class="data row1 col5" >26,735.50</td>
#     </tr>
#     <tr>
#       <th id="T_ae4ea_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_ae4ea_row2_col0" class="data row2 col0" >1.16</td>
#       <td id="T_ae4ea_row2_col1" class="data row2 col1" >1,147.00</td>
#       <td id="T_ae4ea_row2_col2" class="data row2 col2" >27,017.00</td>
#       <td id="T_ae4ea_row2_col3" class="data row2 col3" >840.00</td>
#       <td id="T_ae4ea_row2_col4" class="data row2 col4" >1,809.00</td>
#       <td id="T_ae4ea_row2_col5" class="data row2 col5" >77.00</td>
#     </tr>
#     <tr>
#       <th id="T_ae4ea_level0_row3" class="row_heading level0 row3" >max</th>
#       <td id="T_ae4ea_row3_col0" class="data row3 col0" >693.62</td>
#       <td id="T_ae4ea_row3_col1" class="data row3 col1" >820,724.00</td>
#       <td id="T_ae4ea_row3_col2" class="data row3 col2" >19,532,928.00</td>
#       <td id="T_ae4ea_row3_col3" class="data row3 col3" >570,729.00</td>
#       <td id="T_ae4ea_row3_col4" class="data row3 col4" >1,076,937.00</td>
#       <td id="T_ae4ea_row3_col5" class="data row3 col5" >69,407.00</td>
#     </tr>
#     <tr>
#       <th id="T_ae4ea_level0_row4" class="row_heading level0 row4" >Total</th>
#       <td id="T_ae4ea_row4_col0" class="data row4 col0" >121,962.44</td>
#       <td id="T_ae4ea_row4_col1" class="data row4 col1" >138,906,541.00</td>
#       <td id="T_ae4ea_row4_col2" class="data row4 col2" >3,300,216,537.00</td>
#       <td id="T_ae4ea_row4_col3" class="data row4 col3" >91,955,223.00</td>
#       <td id="T_ae4ea_row4_col4" class="data row4 col4" >190,371,676.00</td>
#       <td id="T_ae4ea_row4_col5" class="data row4 col5" >10,438,820.00</td>
#     </tr>
#     <tr>
#       <th id="T_ae4ea_level0_row5" class="row_heading level0 row5" >CV\%</th>
#       <td id="T_ae4ea_row5_col0" class="data row5 col0" >42.51</td>
#       <td id="T_ae4ea_row5_col1" class="data row5 col1" >46.73</td>
#       <td id="T_ae4ea_row5_col2" class="data row5 col2" >46.88</td>
#       <td id="T_ae4ea_row5_col3" class="data row5 col3" >47.01</td>
#       <td id="T_ae4ea_row5_col4" class="data row5 col4" >41.36</td>
#       <td id="T_ae4ea_row5_col5" class="data row5 col5" >53.18</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/news-summary-stats-main.2025-02-18.tex
#
# Caption: Puddin Summary Statistics (\num{3,247} files)
# *{1}{l}S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
#     S[table-auto-round, table-format=11.0, drop-zero-decimal]
# <style type="text/css">
# #T_af0fd th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_af0fd th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_af0fd th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_af0fd caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_af0fd_row0_col0, #T_af0fd_row0_col1, #T_af0fd_row0_col2, #T_af0fd_row0_col3, #T_af0fd_row0_col4, #T_af0fd_row0_col5, #T_af0fd_row1_col0, #T_af0fd_row1_col1, #T_af0fd_row1_col2, #T_af0fd_row1_col3, #T_af0fd_row1_col4, #T_af0fd_row1_col5, #T_af0fd_row2_col0, #T_af0fd_row2_col1, #T_af0fd_row2_col2, #T_af0fd_row2_col3, #T_af0fd_row2_col4, #T_af0fd_row2_col5, #T_af0fd_row3_col0, #T_af0fd_row3_col1, #T_af0fd_row3_col2, #T_af0fd_row3_col3, #T_af0fd_row3_col4, #T_af0fd_row3_col5, #T_af0fd_row4_col0, #T_af0fd_row4_col1, #T_af0fd_row4_col2, #T_af0fd_row4_col3, #T_af0fd_row4_col4, #T_af0fd_row4_col5, #T_af0fd_row5_col0, #T_af0fd_row5_col1, #T_af0fd_row5_col2, #T_af0fd_row5_col3, #T_af0fd_row5_col4, #T_af0fd_row5_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_af0fd">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_af0fd_level0_col0" class="col_heading level0 col0" >file\_MB</th>
#       <th id="T_af0fd_level0_col1" class="col_heading level0 col1" >sentences</th>
#       <th id="T_af0fd_level0_col2" class="col_heading level0 col2" >tokens</th>
#       <th id="T_af0fd_level0_col3" class="col_heading level0 col3" >ADV\_tokens</th>
#       <th id="T_af0fd_level0_col4" class="col_heading level0 col4" >ADJ\_tokens</th>
#       <th id="T_af0fd_level0_col5" class="col_heading level0 col5" >bigrams</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_af0fd_level0_row0" class="row_heading level0 row0" >mean</th>
#       <td id="T_af0fd_row0_col0" class="data row0 col0" >382.00</td>
#       <td id="T_af0fd_row0_col1" class="data row0 col1" >252,311.73</td>
#       <td id="T_af0fd_row0_col2" class="data row0 col2" >7,855,097.43</td>
#       <td id="T_af0fd_row0_col3" class="data row0 col3" >207,426.28</td>
#       <td id="T_af0fd_row0_col4" class="data row0 col4" >324,968.73</td>
#       <td id="T_af0fd_row0_col5" class="data row0 col5" >26,192.66</td>
#     </tr>
#     <tr>
#       <th id="T_af0fd_level0_row1" class="row_heading level0 row1" >50\%</th>
#       <td id="T_af0fd_row1_col0" class="data row1 col0" >381.50</td>
#       <td id="T_af0fd_row1_col1" class="data row1 col1" >251,996.00</td>
#       <td id="T_af0fd_row1_col2" class="data row1 col2" >7,844,206.00</td>
#       <td id="T_af0fd_row1_col3" class="data row1 col3" >207,094.00</td>
#       <td id="T_af0fd_row1_col4" class="data row1 col4" >324,679.00</td>
#       <td id="T_af0fd_row1_col5" class="data row1 col5" >26,164.00</td>
#     </tr>
#     <tr>
#       <th id="T_af0fd_level0_row2" class="row_heading level0 row2" >min</th>
#       <td id="T_af0fd_row2_col0" class="data row2 col0" >260.26</td>
#       <td id="T_af0fd_row2_col1" class="data row2 col1" >173,016.00</td>
#       <td id="T_af0fd_row2_col2" class="data row2 col2" >435,945.00</td>
#       <td id="T_af0fd_row2_col3" class="data row2 col3" >138,338.00</td>
#       <td id="T_af0fd_row2_col4" class="data row2 col4" >221,985.00</td>
#       <td id="T_af0fd_row2_col5" class="data row2 col5" >17,084.00</td>
#     </tr>
#     <tr>
#       <th id="T_af0fd_level0_row3" class="row_heading level0 row3" >max</th>
#       <td id="T_af0fd_row3_col0" class="data row3 col0" >437.54</td>
#       <td id="T_af0fd_row3_col1" class="data row3 col1" >290,337.00</td>
#       <td id="T_af0fd_row3_col2" class="data row3 col2" >9,334,512.00</td>
#       <td id="T_af0fd_row3_col3" class="data row3 col3" >238,165.00</td>
#       <td id="T_af0fd_row3_col4" class="data row3 col4" >373,124.00</td>
#       <td id="T_af0fd_row3_col5" class="data row3 col5" >30,002.00</td>
#     </tr>
#     <tr>
#       <th id="T_af0fd_level0_row4" class="row_heading level0 row4" >Total</th>
#       <td id="T_af0fd_row4_col0" class="data row4 col0" >1,240,354.42</td>
#       <td id="T_af0fd_row4_col1" class="data row4 col1" >819,256,183.00</td>
#       <td id="T_af0fd_row4_col2" class="data row4 col2" >25,505,501,363.00</td>
#       <td id="T_af0fd_row4_col3" class="data row4 col3" >673,513,143.00</td>
#       <td id="T_af0fd_row4_col4" class="data row4 col4" >1,055,173,456.00</td>
#       <td id="T_af0fd_row4_col5" class="data row4 col5" >85,047,554.00</td>
#     </tr>
#     <tr>
#       <th id="T_af0fd_level0_row5" class="row_heading level0 row5" >CV\%</th>
#       <td id="T_af0fd_row5_col0" class="data row5 col0" >2.06</td>
#       <td id="T_af0fd_row5_col1" class="data row5 col1" >2.11</td>
#       <td id="T_af0fd_row5_col2" class="data row5 col2" >2.83</td>
#       <td id="T_af0fd_row5_col3" class="data row5 col3" >2.31</td>
#       <td id="T_af0fd_row5_col4" class="data row5 col4" >2.00</td>
#       <td id="T_af0fd_row5_col5" class="data row5 col5" >2.49</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/puddin-summary-stats-main.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/describe_corpora/puddin-summary-stats-main.2025-02-18.tex')

# %%
nb_display(_stat(
    news_orig.filter(['file_MB', 'sentences', 'tokens',
                      'ADV_tokens', 'ADJ_tokens', 'NEG_tokens', 'bigrams'
                      ])
).filter(['Total'])
    .filter(['file_MB', 'sentences', 'tokens',
             'ADV_tokens', 'ADJ_tokens', 'NEG_tokens', 'bigrams',
             'ADV_tok_per_mill', 'ADJ_tok_per_mill', 'bigrams_per_mill',
             'bigrams_per_ksent', 'tokens_per_ksent'])
    .style.set_caption('News'))
# Out:
# <style type="text/css">
# #T_5a289 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_5a289 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5a289 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5a289 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_5a289_row0_col0, #T_5a289_row1_col0, #T_5a289_row2_col0, #T_5a289_row3_col0, #T_5a289_row4_col0, #T_5a289_row5_col0, #T_5a289_row6_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_5a289">
#   <caption>News</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_5a289_level0_col0" class="col_heading level0 col0" >Total</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5a289_level0_row0" class="row_heading level0 row0" >file_MB</th>
#       <td id="T_5a289_row0_col0" class="data row0 col0" >121,962.44</td>
#     </tr>
#     <tr>
#       <th id="T_5a289_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_5a289_row1_col0" class="data row1 col0" >138,906,541.00</td>
#     </tr>
#     <tr>
#       <th id="T_5a289_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_5a289_row2_col0" class="data row2 col0" >3,300,216,537.00</td>
#     </tr>
#     <tr>
#       <th id="T_5a289_level0_row3" class="row_heading level0 row3" >ADV_tokens</th>
#       <td id="T_5a289_row3_col0" class="data row3 col0" >91,955,223.00</td>
#     </tr>
#     <tr>
#       <th id="T_5a289_level0_row4" class="row_heading level0 row4" >ADJ_tokens</th>
#       <td id="T_5a289_row4_col0" class="data row4 col0" >190,371,676.00</td>
#     </tr>
#     <tr>
#       <th id="T_5a289_level0_row5" class="row_heading level0 row5" >NEG_tokens</th>
#       <td id="T_5a289_row5_col0" class="data row5 col0" >21,611,437.00</td>
#     </tr>
#     <tr>
#       <th id="T_5a289_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_5a289_row6_col0" class="data row6 col0" >10,438,820.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
def save_totals_by_corpus(corp_stats, corp_name:str):
    save_latex_table(
    add_rate_cols(
        corp_stats.filter(['Total']).T
    ).filter(['file_MB', 'sentences', 'tokens',
            'ADV_tokens', 'ADJ_tokens', 'NEG_tokens', 'bigrams',
            'ADV_tok_per_mill', 'ADJ_tok_per_mill', 'bigrams_per_mill',
            'bigrams_per_ksent', 'tokens_per_ksent']).T, 
    verbose=True, default_SI=11.0,
    caption = f'{corp_name} Totals', latex_subdir='describe_corpora',
    latex_stem=f"{corp_name.lower().replace(' ','-')}-totals-full")
save_totals_by_corpus(pudd_stats, 'CoCra Puddin')
# Out:
# Caption: CoCra Puddin Totals
# *{1}{l}S[table-auto-round, table-format=11.0, drop-zero-decimal]
# <style type="text/css">
# #T_93c0a th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_93c0a th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_93c0a th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_93c0a caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_93c0a_row0_col0, #T_93c0a_row1_col0, #T_93c0a_row2_col0, #T_93c0a_row3_col0, #T_93c0a_row4_col0, #T_93c0a_row5_col0, #T_93c0a_row6_col0, #T_93c0a_row7_col0, #T_93c0a_row8_col0, #T_93c0a_row9_col0, #T_93c0a_row10_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_93c0a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93c0a_level0_col0" class="col_heading level0 col0" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93c0a_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_93c0a_row0_col0" class="data row0 col0" >1240354.420000</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_93c0a_row1_col0" class="data row1 col0" >819,256,183.00</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_93c0a_row2_col0" class="data row2 col0" >25,505,501,363.00</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_93c0a_row3_col0" class="data row3 col0" >673513143.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row4" class="row_heading level0 row4" >ADJ\_tokens</th>
#       <td id="T_93c0a_row4_col0" class="data row4 col0" >1055173456.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row5" class="row_heading level0 row5" >NEG\_tokens</th>
#       <td id="T_93c0a_row5_col0" class="data row5 col0" >137724174.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_93c0a_row6_col0" class="data row6 col0" >85,047,554.00</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row7" class="row_heading level0 row7" >ADV\_tok\_per\_mill</th>
#       <td id="T_93c0a_row7_col0" class="data row7 col0" >26406.583169</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row8" class="row_heading level0 row8" >ADJ\_tok\_per\_mill</th>
#       <td id="T_93c0a_row8_col0" class="data row8 col0" >41370.425971</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row9" class="row_heading level0 row9" >bigrams\_per\_mill</th>
#       <td id="T_93c0a_row9_col0" class="data row9 col0" >3334.478817</td>
#     </tr>
#     <tr>
#       <th id="T_93c0a_level0_row10" class="row_heading level0 row10" >bigrams\_per\_ksent</th>
#       <td id="T_93c0a_row10_col0" class="data row10 col0" >103.810695</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/cocra-puddin-totals-full.2025-02-18.tex

# %%
save_totals_by_corpus(news_stats, 'News')
# Out:
# Caption: News Totals
# *{1}{l}S[table-auto-round, table-format=11.0, drop-zero-decimal]
# <style type="text/css">
# #T_93cc7 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_93cc7 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_93cc7 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_93cc7 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_93cc7_row0_col0, #T_93cc7_row1_col0, #T_93cc7_row2_col0, #T_93cc7_row3_col0, #T_93cc7_row4_col0, #T_93cc7_row5_col0, #T_93cc7_row6_col0, #T_93cc7_row7_col0, #T_93cc7_row8_col0, #T_93cc7_row9_col0, #T_93cc7_row10_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_93cc7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_93cc7_level0_col0" class="col_heading level0 col0" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_93cc7_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_93cc7_row0_col0" class="data row0 col0" >121962.440000</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_93cc7_row1_col0" class="data row1 col0" >138,906,541.00</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_93cc7_row2_col0" class="data row2 col0" >3,300,216,537.00</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_93cc7_row3_col0" class="data row3 col0" >91955223.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row4" class="row_heading level0 row4" >ADJ\_tokens</th>
#       <td id="T_93cc7_row4_col0" class="data row4 col0" >190371676.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row5" class="row_heading level0 row5" >NEG\_tokens</th>
#       <td id="T_93cc7_row5_col0" class="data row5 col0" >21611437.000000</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_93cc7_row6_col0" class="data row6 col0" >10,438,820.00</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row7" class="row_heading level0 row7" >ADV\_tok\_per\_mill</th>
#       <td id="T_93cc7_row7_col0" class="data row7 col0" >27863.390771</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row8" class="row_heading level0 row8" >ADJ\_tok\_per\_mill</th>
#       <td id="T_93cc7_row8_col0" class="data row8 col0" >57684.601560</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row9" class="row_heading level0 row9" >bigrams\_per\_mill</th>
#       <td id="T_93cc7_row9_col0" class="data row9 col0" >3163.071236</td>
#     </tr>
#     <tr>
#       <th id="T_93cc7_level0_row10" class="row_heading level0 row10" >bigrams\_per\_ksent</th>
#       <td id="T_93cc7_row10_col0" class="data row10 col0" >75.149953</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/news-totals-full.2025-02-18.tex

# %%
save_totals_by_corpus(pudd_stats - news_stats, 'Puddin Minus News')
# Out:
# Caption: Puddin Minus News Totals
# *{1}{l}S[table-auto-round, table-format=11.0, drop-zero-decimal]
# <style type="text/css">
# #T_82956 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_82956 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_82956 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_82956 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_82956_row0_col0, #T_82956_row1_col0, #T_82956_row2_col0, #T_82956_row3_col0, #T_82956_row4_col0, #T_82956_row5_col0, #T_82956_row6_col0, #T_82956_row7_col0, #T_82956_row8_col0, #T_82956_row9_col0, #T_82956_row10_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_82956">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_82956_level0_col0" class="col_heading level0 col0" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82956_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_82956_row0_col0" class="data row0 col0" >1118391.980000</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_82956_row1_col0" class="data row1 col0" >680,349,642.00</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_82956_row2_col0" class="data row2 col0" >22,205,284,826.00</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_82956_row3_col0" class="data row3 col0" >581557920.000000</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row4" class="row_heading level0 row4" >ADJ\_tokens</th>
#       <td id="T_82956_row4_col0" class="data row4 col0" >864801780.000000</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row5" class="row_heading level0 row5" >NEG\_tokens</th>
#       <td id="T_82956_row5_col0" class="data row5 col0" >116112737.000000</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_82956_row6_col0" class="data row6 col0" >74,608,734.00</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row7" class="row_heading level0 row7" >ADV\_tok\_per\_mill</th>
#       <td id="T_82956_row7_col0" class="data row7 col0" >26190.068020</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row8" class="row_heading level0 row8" >ADJ\_tok\_per\_mill</th>
#       <td id="T_82956_row8_col0" class="data row8 col0" >38945.763893</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row9" class="row_heading level0 row9" >bigrams\_per\_mill</th>
#       <td id="T_82956_row9_col0" class="data row9 col0" >3359.953929</td>
#     </tr>
#     <tr>
#       <th id="T_82956_level0_row10" class="row_heading level0 row10" >bigrams\_per\_ksent</th>
#       <td id="T_82956_row10_col0" class="data row10 col0" >109.662340</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/puddin-minus-news-totals-full.2025-02-18.tex

# %%
save_totals_by_corpus(orig_stats, 'Puddin and News Combined')
# Out:
# Caption: Puddin and News Combined Totals
# *{1}{l}S[table-auto-round, table-format=11.0, drop-zero-decimal]
# <style type="text/css">
# #T_e7de6 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e7de6 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e7de6 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e7de6 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e7de6_row0_col0, #T_e7de6_row1_col0, #T_e7de6_row2_col0, #T_e7de6_row3_col0, #T_e7de6_row4_col0, #T_e7de6_row5_col0, #T_e7de6_row6_col0, #T_e7de6_row7_col0, #T_e7de6_row8_col0, #T_e7de6_row9_col0, #T_e7de6_row10_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_e7de6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e7de6_level0_col0" class="col_heading level0 col0" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e7de6_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_e7de6_row0_col0" class="data row0 col0" >1362316.860000</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_e7de6_row1_col0" class="data row1 col0" >958,162,724.00</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_e7de6_row2_col0" class="data row2 col0" >28,805,717,900.00</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_e7de6_row3_col0" class="data row3 col0" >765468366.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row4" class="row_heading level0 row4" >ADJ\_tokens</th>
#       <td id="T_e7de6_row4_col0" class="data row4 col0" >1245545132.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row5" class="row_heading level0 row5" >NEG\_tokens</th>
#       <td id="T_e7de6_row5_col0" class="data row5 col0" >159335611.000000</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row6" class="row_heading level0 row6" >bigrams</th>
#       <td id="T_e7de6_row6_col0" class="data row6 col0" >95,486,374.00</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row7" class="row_heading level0 row7" >ADV\_tok\_per\_mill</th>
#       <td id="T_e7de6_row7_col0" class="data row7 col0" >26573.486856</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row8" class="row_heading level0 row8" >ADJ\_tok\_per\_mill</th>
#       <td id="T_e7de6_row8_col0" class="data row8 col0" >43239.510167</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row9" class="row_heading level0 row9" >bigrams\_per\_mill</th>
#       <td id="T_e7de6_row9_col0" class="data row9 col0" >3314.840975</td>
#     </tr>
#     <tr>
#       <th id="T_e7de6_level0_row10" class="row_heading level0 row10" >bigrams\_per\_ksent</th>
#       <td id="T_e7de6_row10_col0" class="data row10 col0" >99.655697</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/describe_corpora/puddin-and-news-combined-totals-full.2025-02-18.tex

# %%
corpus_tokens_stack = juxta.stack(1).filter(like='tokens')
corpus_tokens_stack.columns.name = 'token_type'
corpus_tokens_stack = corpus_tokens_stack.stack().to_frame('count').reset_index(level=['corpus','kind', 'token_type']).sort_values(['corpus','kind', 'token_type'])
corpus_tokens_stack.value_counts(['corpus', 'kind', 'token_type'])

# %%
corpus_kind_token_totals=(pd.concat(
    [style_crosstab(corpus_tokens_stack,
                    ['corpus', 'kind'], ['token_type'], value_col='count', aggfunc='sum',
                    return_cross_df=True
                    ).sort_index().sort_index(axis=1),
     style_crosstab(corpus_tokens_stack,
                    ['kind'], ['token_type'], value_col='count', aggfunc='sum',
                    return_cross_df=True
                    ).assign(corpus='News+Puddin').reset_index().set_index(['corpus', 'kind']).sort_index()
     ]
).sort_index(axis=1)
)
# save_latex_table(corpus_kind_token_totals.style.format(escape='latex'), 
#                  caption='BiRC Token Count Comparisons by Corpus \& Overall', 
#                  latex_stem='birc-token-counts-by-corpus-kind',
#                  latex_subdir=REL_BIRC_TEX_DIR, verbose=True, default_SI=-11.0, 
#                  neg_color='BrickRed'
#                                         )

# %%
col = 'file_MB'
def build_agg_table(col:str, _juxta):
    _by_corpus = _juxta.stack(1).filter(like=col).unstack(['kind'])
    _overall = (_by_corpus.aggregate(['sum','mean', 'min', 'max'])
                .T.droplevel(0,axis=0).assign(corpus='Overall')
                .reset_index().set_index(['corpus', 'kind']))
    _by_corpus = _by_corpus.groupby('corpus', observed=True).aggregate(
        ['sum','mean', 'min', 'max']).droplevel(0, axis=1).stack('kind')
    return pd.concat((_by_corpus, _overall))

agg_df = build_agg_table('file_MB', juxta)
save_latex_table(agg_df,
                 caption='BiRC File Size (MB) Comparisons by Corpus \& Overall', 
                 latex_stem='birc-file-MB-by-corpus-and-overall',
                 latex_subdir=REL_BIRC_TEX_DIR, verbose=True, default_SI=-7.1, 
                 neg_color='BrickRed'
                 )

# %%
save_latex_table(build_agg_table('sentences', juxta),
                 caption='BiRC Sentence Count Comparisons by Corpus \& Overall', 
                 latex_stem='birc-sent-by-corpus-and-overall',
                 latex_subdir=REL_BIRC_TEX_DIR, verbose=True, default_SI=-9.0, 
                 neg_color='BrickRed'
                 )

# %%
# %%
save_latex_table(
    pd.concat([
        juxta.filter(like='apw', axis=0).sample(1), 
        juxta.filter(like='nyt', axis=0).sample(1),
        # 👆 one sample of apw  and nyt each
        # and then 2 puddin samples
        juxta.filter(like='pcc', axis=0).sample(2)
    ]).drop_duplicates().sort_index().T,
    caption=('Sample of Juxtaposed Counts'),
    verbose=True,
    latex_subdir=REL_BIRC_TEX_DIR,
    latex_stem='birc-juxtaposed-sample-2x2')

# %%
def describe_and_total(_df):
    return _df.describe().T.assign(total=_df.sum()).T


by_corpus_descrip = juxta.groupby(
    'corpus', observed=True).apply(describe_and_total)
by_corpus_descrip.index.names = ['corpus', 'stat']
by_corpus_descrip.columns.names = ['obs', 'kind']

by_corpus_descrip = (
    by_corpus_descrip
    .stack(['obs', 'kind'])
    .unstack(['corpus', 'kind', 'stat'])
    .stack('stat')
    .rename(index={
            'count': '# files',
            '50%': 'median'}))
nb_display(by_corpus_descrip)

# %%
# save_latex_table(
#     by_corpus_descrip.xs('file_MB').style,
#     caption=('BiRC Storare Size (MB) Comparison by Corpus '),
#     verbose=True,
#     latex_subdir=REL_BIRC_TEX_DIR,
#     latex_stem='birc-by-corpus-size-compare-summary'
# )
# save_latex_table(
#     by_corpus_descrip.xs('tokens').style,
#     caption=('BiRC Token Comparison by Corpus '),
#     verbose=True,
#     latex_subdir=REL_BIRC_TEX_DIR,
#     latex_stem='birc-by-corpus-token-compare-summary'
# )

# save_latex_table(
#     by_corpus_descrip.xs('sentences').style,
#     caption=('BiRC Sentence Comparison by Corpus '),
#     verbose=True,
#     latex_subdir=REL_BIRC_TEX_DIR,
#     latex_stem='birc-by-corpus-sentence-compare-summary'
# )
