# %%
import contextlib
from pathlib import Path

import pandas as pd

from source.utils.am_notebooks import catify, embolden, nb_show_table
from source.utils.dataframes import NEG_REGEX, POS_FEW_REGEX
from source.utils.general import HIT_TABLES_DIR

# %%
def show_hit_sample(path, n=1,
                    parts=None,
                    transpose=True,
                    show_following_neg=False,
                    head=None,
                    not_only=False, 
                    positive_few=False) -> pd.DataFrame:
    if not parts:
        parts = ['PccVa', 'Apw']
    path = Path(path)
    if any([p.endswith(('.parq', '.parquet')) for p in path.parts]):

        try:
            _sample = pd.read_parquet(path,
                                    engine='pyarrow', filters=[('part', 'in', parts)])
        except Exception:
            _sample = pd.read_parquet(path)
    elif '.csv' in path.suffixes:
        _sample = catify(pd.read_csv(path, nrows=1500, index_col='hit_id'))
    else:
        _sample = catify(pd.read_pickle(path))
        with contextlib.suppress(AttributeError):
            _sample = _sample.loc[_sample.part.isin(parts), :]
    if not_only: 
        transpose=False
        _sample = _sample.loc[_sample.token_str.str.lower().str.contains('not only'), :].filter(
            ['bigram', 'colloc', 'trigger_lemma', 'trigger_lower', 'neg_lemma', 'adv_form', 'adj_form', 'bigram_lower', 'all_forms_lower', 'hit_text', 'text_window', 'token_str', 'sent_text'])
    if positive_few: 
        _sample = _sample.loc[_sample.token_str.str.lower().str.contains(POS_FEW_REGEX), :]
    if show_following_neg:
        _sample = _sample.loc[_sample.token_str.str.contains(NEG_REGEX), :]
    if head:
        _sample = _sample.loc[(_sample.filter(
            regex=r'[rg]_head').iloc[:, 0]) == head, :]
    _sample = _sample.sample(n)
    for text_col in _sample.filter(['text_window', 'hit_text', 'token_str', 'sent_text']).columns:
        _formatted = '*' + embolden(_sample[text_col], mono=False,
                                    bold_regex=f"({_sample.filter(like='adv_form').iat[0,0]} {_sample.filter(like='adj_form').iat[0,0]})") + '*'
        if 'trigger_lower' in _sample.columns:
            trigger_lower = _sample.trigger_lower.squeeze()
            trigger_regex = r'|'.join(
                [trigger_lower, trigger_lower.capitalize(), trigger_lower.upper()])
            _formatted = _formatted.replace(
                r'\b('+trigger_regex+r')\b', r'`\1`', regex=True)
        _sample[text_col] = _formatted
    if n == 1 and transpose:
        # print(_sample.filter(['all_forms_lower', 'bigram_lower','bigram']).iat[0,0])
        hit_label = f": *{_sample.filter(['all_forms_lower', 'bigram_lower','bigram', 'colloc']).iat[0,0]}*".replace(
            '_', ' ')
    else:
        hit_label = ''
    nb_show_table(
        _sample, transpose=transpose, italics=False,
        title=f'\nSample Hit from `{path.relative_to(HIT_TABLES_DIR)}`{hit_label}\n')
    return _sample

# %%
samples = [show_hit_sample(HIT_TABLES_DIR.joinpath('POSmirror/NEQ-POSmirror_final_sample.24080322.parq'), parts=['Pcc00', 'PccVa', 'Nyt1', 'Apw' ])]
# Out:
# Sample Hit from `POSmirror/NEQ-POSmirror_final_sample.24080322.parq`: *some quite reasonable*
#
# |                           | `pcc_eng_00_001.6058_x0009803_17:1-6-7`                                                                                                                                                                                                                                                                                                                                                                  |
# |:--------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`bigram`**              | quite_reasonable                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`sent_text`**           | *`Some` of these policies are __quite reasonable__, but take a moment to study their features an benefits before you shell out additional cash for them.*                                                                                                                                                                                                                                                |
# | **`adv_form`**            | quite                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adj_form`**            | reasonable                                                                                                                                                                                                                                                                                                                                                                                               |
# | **`hit_text`**            | *`Some` of these policies are __quite reasonable__ , but take a*                                                                                                                                                                                                                                                                                                                                         |
# | **`text_window`**         | *`some` of these policies are __quite reasonable__ , but take a moment to*                                                                                                                                                                                                                                                                                                                               |
# | **`sent_id`**             | pcc_eng_00_001.6058_x0009803_17                                                                                                                                                                                                                                                                                                                                                                          |
# | **`match_id`**            | 1-6-7                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`bigram_id`**           | pcc_eng_00_001.6058_x0009803_17:6-7                                                                                                                                                                                                                                                                                                                                                                      |
# | **`token_str`**           | *`Some` of these policies are __quite reasonable__ , but take a moment to study their features an benefits before you shell out additional cash for them .*                                                                                                                                                                                                                                              |
# | **`lemma_str`**           | some of this policy be quite reasonable , but take a moment to study they feature a benefit before you shell out additional cash for they .                                                                                                                                                                                                                                                              |
# | **`mod_deprel`**          | advmod                                                                                                                                                                                                                                                                                                                                                                                                   |
# | **`mod_head`**            | ADJ                                                                                                                                                                                                                                                                                                                                                                                                      |
# | **`mir_deprel`**          | nsubj                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`mir_head`**            | ADJ                                                                                                                                                                                                                                                                                                                                                                                                      |
# | **`mir_lemma`**           | some                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`adv_lemma`**           | quite                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adj_lemma`**           | reasonable                                                                                                                                                                                                                                                                                                                                                                                               |
# | **`mir_form`**            | Some                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`mir_index`**           | 0                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`adv_index`**           | 5                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`adj_index`**           | 6                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`mir_all_dep_targets`** | [{'index': 3, 'lemma': 'policy', 'form': 'policies', 'xpos': 'NNS', 'deprel': 'nmod'}]                                                                                                                                                                                                                                                                                                                   |
# | **`adv_all_dep_targets`** | []                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`adj_all_dep_targets`** | [{'index': 0, 'lemma': 'some', 'form': 'Some', 'xpos': 'DT', 'deprel': 'nsubj'}, {'index': 4, 'lemma': 'be', 'form': 'are', 'xpos': 'VBP', 'deprel': 'cop'}, {'index': 5, 'lemma': 'quite', 'form': 'quite', 'xpos': 'RB', 'deprel': 'advmod'}, {'index': 9, 'lemma': 'take', 'form': 'take', 'xpos': 'VB', 'deprel': 'conj'}, {'index': 26, 'lemma': '.', 'form': '.', 'xpos': '.', 'deprel': 'punct'}] |
# | **`dep_mod`**             | {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': {'lemma': 'reasonable', 'ix': 6, 'xpos': 'JJ'}, 'target': {'lemma': 'quite', 'ix': 5, 'xpos': 'RB'}}                                                                                                                                                                                                                                   |
# | **`dep_mir`**             | {'node': 'mir', 'contiguous': False, 'relation': 'nsubj', 'head': {'lemma': 'reasonable', 'ix': 6, 'xpos': 'JJ'}, 'target': {'lemma': 'some', 'ix': 0, 'xpos': 'DT'}}                                                                                                                                                                                                                                    |
# | **`mir_form_lower`**      | some                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`adv_form_lower`**      | quite                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adj_form_lower`**      | reasonable                                                                                                                                                                                                                                                                                                                                                                                               |
# | **`utt_len`**             | 27                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`json_source`**         | /share/compling/data/sanpi/1_json_grew-matches/POSmirror/bigram-Pcc00.pos-mirror-R/BIGRAM.pcc_eng_00-001.json                                                                                                                                                                                                                                                                                            |
# | **`bigram_lower`**        | quite_reasonable                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`all_forms_lower`**     | some_quite_reasonable                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`pattern`**             | pos-mirror-R                                                                                                                                                                                                                                                                                                                                                                                             |
# | **`category`**            | POSmirror                                                                                                                                                                                                                                                                                                                                                                                                |
# | **`trigger_lower`**       | some                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`trigger_lemma`**       | some                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`dep_distance`**        | 5                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`window_len`**          | 13                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`quarantine`**          | False                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`id_prefix`**           | pcc_eng_00_00                                                                                                                                                                                                                                                                                                                                                                                            |
# | **`part`**                | Pcc00                                                                                                                                                                                                                                                                                                                                                                                                    |

# %% [markdown]
# Sample Hit from `POSmirror/NEQ-POSmirror_final_sample.24072400.parq`: *something so crucial*
#
# |                       | `pcc_eng_val_3.11224_x52656_18:25-26-27`                                                                                                                                   |
# |:----------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`bigram`**          | so_crucial                                                                                                                                                                 |
# | **`sent_text`**       | Even though I had found it in the "household kitchen faucet" section, it was incredibly ignorant to proceed blindly into purchasing `something` __so crucial__.            |
# | **`adv_form`**        | so                                                                                                                                                                         |
# | **`adj_form`**        | crucial                                                                                                                                                                    |
# | **`hit_text`**        | `something` __so crucial__ .                                                                                                                                               |
# | **`text_window`**     | ignorant to proceed blindly into purchasing `something` __so crucial__ .                                                                                                   |
# | **`sent_id`**         | pcc_eng_val_3.11224_x52656_18                                                                                                                                              |
# | **`match_id`**        | 25-26-27                                                                                                                                                                   |
# | **`bigram_id`**       | pcc_eng_val_3.11224_x52656_18:26-27                                                                                                                                        |
# | **`token_str`**       | Even though I had found it in the " household kitchen faucet " section , it was incredibly ignorant to proceed blindly into purchasing `something` __so crucial__ .        |
# | **`lemma_str`**       | *even though I have find it in the " household kitchen faucet " section , it be incredibly ignorant to proceed blindly into purchase something so crucial .*               |
# | **`mod_deprel`**      | advmod                                                                                                                                                                     |
# | **`mod_head`**        | ADJ                                                                                                                                                                        |
# | **`mir_deprel`**      | amod                                                                                                                                                                       |
# | **`mir_head`**        | MIR                                                                                                                                                                        |
# | **`mir_lemma`**       | something                                                                                                                                                                  |
# | **`adv_lemma`**       | so                                                                                                                                                                         |
# | **`adj_lemma`**       | crucial                                                                                                                                                                    |
# | **`mir_form`**        | something                                                                                                                                                                  |
# | **`mir_index`**       | 24                                                                                                                                                                         |
# | **`adv_index`**       | 25                                                                                                                                                                         |
# | **`adj_index`**       | 26                                                                                                                                                                         |
# | **`dep_mod`**         | *{'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': {'lemma': 'crucial', 'ix': 26, 'xpos': 'JJ'}, 'target': {'lemma': 'so', 'ix': 25, 'xpos': 'RB'}}*       |
# | **`dep_mir`**         | *{'node': 'mir', 'contiguous': False, 'relation': 'amod', 'head': {'lemma': 'something', 'ix': 24, 'xpos': 'NN'}, 'target': {'lemma': 'crucial', 'ix': 26, 'xpos': 'JJ'}}* |
# | **`mir_form_lower`**  | something                                                                                                                                                                  |
# | **`adv_form_lower`**  | so                                                                                                                                                                         |
# | **`adj_form_lower`**  | crucial                                                                                                                                                                    |
# | **`utt_len`**         | 28                                                                                                                                                                         |
# | **`json_source`**     | /share/compling/data/sanpi/1_json_grew-matches/POSmirror/bigram-PccVa.pos-mirror-L/BIGRAM.pcc_eng_val-03.json                                                              |
# | **`bigram_lower`**    | so_crucial                                                                                                                                                                 |
# | **`all_forms_lower`** | something_so_crucial                                                                                                                                                       |
# | **`pattern`**         | pos-mirror-L                                                                                                                                                               |
# | **`category`**        | POSmirror                                                                                                                                                                  |
# | **`trigger_lower`**   | something                                                                                                                                                                  |
# | **`trigger_lemma`**   | something                                                                                                                                                                  |
# | **`dep_distance`**    | 1                                                                                                                                                                          |
# | **`window_len`**      | 10                                                                                                                                                                         |
# | **`quarantine`**      | False                                                                                                                                                                      |
# | **`id_prefix`**       | pcc_eng_val_3                                                                                                                                                              |
# | **`part`**            | PccVa                                                                                                                                                                      |

# %% [markdown]
# Sample Hit from `POSmirror/NEQ-POSmirror_final_sample.24072400.parq`: *sometimes really enough*
#
# |                       | `pcc_eng_val_3.03145_x39665_10:1-5-6`                                                                                                                                     |
# |:----------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`bigram`**          | really_enough                                                                                                                                                             |
# | **`sent_text`**       | *`Sometimes`, it is __really enough__ to not say much about your reasons and let your decision speak for itself.*                                                         |
# | **`adv_form`**        | really                                                                                                                                                                    |
# | **`adj_form`**        | enough                                                                                                                                                                    |
# | **`hit_text`**        | *`Sometimes` , it is __really enough__ to not say much*                                                                                                                   |
# | **`text_window`**     | *`sometimes` , it is __really enough__ to not say much about your*                                                                                                        |
# | **`sent_id`**         | pcc_eng_val_3.03145_x39665_10                                                                                                                                             |
# | **`match_id`**        | 1-5-6                                                                                                                                                                     |
# | **`bigram_id`**       | pcc_eng_val_3.03145_x39665_10:5-6                                                                                                                                         |
# | **`token_str`**       | *`Sometimes` , it is __really enough__ to not say much about your reasons and let your decision speak for itself .*                                                       |
# | **`lemma_str`**       | *sometimes , it be really enough to not say much about you reason and let you decision speak for itself .*                                                                |
# | **`mod_deprel`**      | advmod                                                                                                                                                                    |
# | **`mod_head`**        | ADJ                                                                                                                                                                       |
# | **`mir_deprel`**      | advmod                                                                                                                                                                    |
# | **`mir_head`**        | ADJ                                                                                                                                                                       |
# | **`mir_lemma`**       | sometimes                                                                                                                                                                 |
# | **`adv_lemma`**       | really                                                                                                                                                                    |
# | **`adj_lemma`**       | enough                                                                                                                                                                    |
# | **`mir_form`**        | Sometimes                                                                                                                                                                 |
# | **`mir_index`**       | 0                                                                                                                                                                         |
# | **`adv_index`**       | 4                                                                                                                                                                         |
# | **`adj_index`**       | 5                                                                                                                                                                         |
# | **`dep_mod`**         | *{'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': {'lemma': 'enough', 'ix': 5, 'xpos': 'JJ'}, 'target': {'lemma': 'really', 'ix': 4, 'xpos': 'RB'}}*     |
# | **`dep_mir`**         | *{'node': 'mir', 'contiguous': False, 'relation': 'advmod', 'head': {'lemma': 'enough', 'ix': 5, 'xpos': 'JJ'}, 'target': {'lemma': 'sometimes', 'ix': 0, 'xpos': 'RB'}}* |
# | **`mir_form_lower`**  | sometimes                                                                                                                                                                 |
# | **`adv_form_lower`**  | really                                                                                                                                                                    |
# | **`adj_form_lower`**  | enough                                                                                                                                                                    |
# | **`utt_len`**         | 21                                                                                                                                                                        |
# | **`json_source`**     | /share/compling/data/sanpi/1_json_grew-matches/POSmirror/bigram-PccVa.pos-mirror-R/BIGRAM.pcc_eng_val-03.json                                                             |
# | **`bigram_lower`**    | really_enough                                                                                                                                                             |
# | **`all_forms_lower`** | sometimes_really_enough                                                                                                                                                   |
# | **`pattern`**         | pos-mirror-R                                                                                                                                                              |
# | **`category`**        | POSmirror                                                                                                                                                                 |
# | **`trigger_lower`**   | sometimes                                                                                                                                                                 |
# | **`trigger_lemma`**   | sometimes                                                                                                                                                                 |
# | **`dep_distance`**    | 4                                                                                                                                                                         |
# | **`window_len`**      | 12                                                                                                                                                                        |
# | **`quarantine`**      | False                                                                                                                                                                     |
# | **`id_prefix`**       | pcc_eng_val_3                                                                                                                                                             |
# | **`part`**            | PccVa                                                                                                                                                                     |

# %%
show_hit_sample(HIT_TABLES_DIR.joinpath('NEGmirror/condensed/bigram-PccVa_all-NEGmirror_unique-bigram-id_hits.pkl.gz' ))
# Out:
# Sample Hit from `NEGmirror/condensed/bigram-PccVa_all-NEGmirror_unique-bigram-id_hits.pkl.gz`: *rarely as attractive*
#
# |                           | `pcc_eng_val_2.04602_x23715_22:18-19-20`                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# |:--------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`colloc`**              | as_attractive                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`sent_text`**           | *But second more than anything else, the internet has taught me that famous Hollywood stars are rarely __as attractive__ as they appear in the media.*                                                                                                                                                                                                                                                                                                                                                     |
# | **`neg_form`**            | rarely                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`adv_form`**            | as                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`adj_form`**            | attractive                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | **`hit_text`**            | *rarely __as attractive__ as they appear in*                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | **`text_window`**         | *famous Hollywood stars are rarely __as attractive__ as they appear in*                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`sent_id`**             | pcc_eng_val_2.04602_x23715_22                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`match_id`**            | 18-19-20                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | **`bigram_id`**           | pcc_eng_val_2.04602_x23715_22:19-20                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`token_str`**           | *But second more than anything else , the internet has taught me that famous Hollywood stars are rarely __as attractive__ as they appear in the media .*                                                                                                                                                                                                                                                                                                                                                   |
# | **`lemma_str`**           | but second more than anything else , the internet have teach I that famous Hollywood star be rarely as attractive as they appear in the media .                                                                                                                                                                                                                                                                                                                                                            |
# | **`neg_deprel`**          | advmod                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`neg_head`**            | ADJ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`mod_deprel`**          | advmod                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`mod_head`**            | ADJ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`neg_lemma`**           | rarely                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`adv_lemma`**           | as                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`adj_lemma`**           | attractive                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | **`neg_index`**           | 17                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`adv_index`**           | 18                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`adj_index`**           | 19                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`neg_all_dep_targets`** | []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`adv_all_dep_targets`** | []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`adj_all_dep_targets`** | [{'index': 12, 'lemma': 'that', 'form': 'that', 'xpos': 'IN', 'deprel': 'mark'}, {'index': 15, 'lemma': 'star', 'form': 'stars', 'xpos': 'NNS', 'deprel': 'nsubj'}, {'index': 16, 'lemma': 'be', 'form': 'are', 'xpos': 'VBP', 'deprel': 'cop'}, {'index': 17, 'lemma': 'rarely', 'form': 'rarely', 'xpos': 'RB', 'deprel': 'advmod'}, {'index': 18, 'lemma': 'as', 'form': 'as', 'xpos': 'RB', 'deprel': 'advmod'}, {'index': 22, 'lemma': 'appear', 'form': 'appear', 'xpos': 'VBP', 'deprel': 'advcl'}] |
# | **`dep_neg`**             | {'node': 'neg', 'contiguous': False, 'relation': 'advmod', 'head': {'lemma': 'attractive', 'ix': 19, 'xpos': 'JJ'}, 'target': {'lemma': 'rarely', 'ix': 17, 'xpos': 'RB'}}                                                                                                                                                                                                                                                                                                                                 |
# | **`dep_mod`**             | {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': {'lemma': 'attractive', 'ix': 19, 'xpos': 'JJ'}, 'target': {'lemma': 'as', 'ix': 18, 'xpos': 'RB'}}                                                                                                                                                                                                                                                                                                                                      |
# | **`neg_form_lower`**      | rarely                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                     |
# | **`adv_form_lower`**      | as                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`adj_form_lower`**      | attractive                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | **`utt_len`**             | 27                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                         |
# | **`json_source`**         | /share/compling/data/sanpi/1_json_grew-matches/NEGmirror/bigram-PccVa.neg-mirror-R/BIGRAM.pcc_eng_val-02.json                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`bigram_lower`**        | as_attractive                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`all_forms_lower`**     | rarely_as_attractive                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`pattern`**             | neg-mirror-R                                                                                                                                                                                                                                                                                                                                                                                                                                                                                               |
# | **`category`**            | NEGmirror                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
#                                                colloc  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  as_attractive
#
#                                                                                 sent_text  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  *But second more than anything else, the inter...
#
#                                        neg_form adv_form    adj_form  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20   rarely       as  attractive
#
#                                                                             hit_text  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  *rarely __as attractive__ as they appear in*
#
#                                                                               text_window  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  *famous Hollywood stars are rarely __as attrac...
#
#                                                               sent_id  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  pcc_eng_val_2.04602_x23715_22
#
#                                         match_id  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  18-19-20
#
#                                                                   bigram_id  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  pcc_eng_val_2.04602_x23715_22:19-20
#
#                                         ...  \
# hit_id                                  ...
# pcc_eng_val_2.04602_x23715_22:18-19-20  ...
#
#                                                                                   dep_mod  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  {'node': 'mod', 'contiguous': True, 'relation'...
#
#                                        neg_form_lower adv_form_lower  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20         rarely             as
#
#                                        adj_form_lower utt_len  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20     attractive      27
#
#                                                                               json_source  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  /share/compling/data/sanpi/1_json_grew-matches...
#
#                                          bigram_lower       all_forms_lower  \
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  as_attractive  rarely_as_attractive
#
#                                              pattern   category
# hit_id
# pcc_eng_val_2.04602_x23715_22:18-19-20  neg-mirror-R  NEGmirror
#
# [1 rows x 36 columns]

# %%
show_hit_sample(HIT_TABLES_DIR.joinpath('RBdirect/condensed/Pcc00_all-RBdirect_unique-bigram-id_hits.csv.bz2' ), 
                n=5, not_only=True)
# Out:
# Sample Hit from `RBdirect/condensed/Pcc00_all-RBdirect_unique-bigram-id_hits.csv.bz2`
#
# |                                               | `colloc`         | `neg_lemma`   | `adv_form`   | `adj_form`   | `hit_text`                                                         | `text_window`                                                                   | `token_str`                                                                                                                                                                           | `sent_text`                                                                                                                                                                      |
# |:----------------------------------------------|:-----------------|:--------------|:-------------|:-------------|:-------------------------------------------------------------------|:--------------------------------------------------------------------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **pcc_eng_00_001.5549_x0008939_2:1-6-7**      | extremely_good   | not           | extremely    | good         | *Not only are our distributors __extremely good__ at what they do* | *Not only are our distributors __extremely good__ at what they do*              | *Not only are our distributors __extremely good__ at what they do , but they are also local .*                                                                                        | *Not only are our distributors __extremely good__ at what they do, but they are also local.*                                                                                     |
# | **pcc_eng_00_001.1946_x0003163_12:24-25-26**  | only_unstoppable | not           | only         | unstoppable  | *not only unstoppable , it is gathering*                           | *of the world is not only unstoppable , it is gathering*                        | *Julia Gillard is absolutely right in saying : " The transformation of the Asian region into the economic powerhouse of the world is not only unstoppable , it is gathering pace . "* | *Julia Gillard is absolutely right in saying: "The transformation of the Asian region into the economic powerhouse of the world is not only unstoppable, it is gathering pace."* |
# | **pcc_eng_00_001.0817_x0001331_058:12-13-14** | only_onerous     | not           | only         | onerous      | *not only onerous , but make demands*                              | *, the bills are not only onerous , but make demands*                           | *As far as drug makers are concerned , the bills are not only onerous , but make demands they maintain cannot be met .*                                                               | *As far as drug makers are concerned, the bills are not only onerous, but make demands they maintain cannot be met.*                                                             |
# | **pcc_eng_00_002.1940_x0019263_25:08-09-10**  | only_applicable  | not           | only         | applicable   | *not only applicable to Coca- Cola ,*                              | *, the infographic is not only applicable to Coca- Cola ,*                      | *According to Naik , the infographic is not only applicable to Coca- Cola , but to all caffeinated fizzy drinks .*                                                                    | *According to Naik, the infographic is not only applicable to Coca-Cola, but to all caffeinated fizzy drinks.*                                                                   |
# | **pcc_eng_00_001.5458_x0008792_35:11-13-14**  | budget-_friendly | not           | budget-      | friendly     | *not only budget- friendly -- it's dependable ,*                   | *Stewartstown , Pennsylvania is not only budget- friendly -- it's dependable ,* | *With DISH , high-speed Internet in Stewartstown , Pennsylvania is not only budget- friendly -- it's dependable , too .*                                                              | *With DISH, high-speed Internet in Stewartstown, Pennsylvania is not only budget-friendly--it's dependable, too.*                                                                |
#                                                      colloc neg_lemma  \
# hit_id
# pcc_eng_00_001.5549_x0008939_2:1-6-7         extremely_good       not
# pcc_eng_00_001.1946_x0003163_12:24-25-26   only_unstoppable       not
# pcc_eng_00_001.0817_x0001331_058:12-13-14      only_onerous       not
# pcc_eng_00_002.1940_x0019263_25:08-09-10    only_applicable       not
# pcc_eng_00_001.5458_x0008792_35:11-13-14   budget-_friendly       not
#
#                                             adv_form     adj_form  \
# hit_id
# pcc_eng_00_001.5549_x0008939_2:1-6-7       extremely         good
# pcc_eng_00_001.1946_x0003163_12:24-25-26        only  unstoppable
# pcc_eng_00_001.0817_x0001331_058:12-13-14       only      onerous
# pcc_eng_00_002.1940_x0019263_25:08-09-10        only   applicable
# pcc_eng_00_001.5458_x0008792_35:11-13-14     budget-     friendly
#
#                                                                                     hit_text  \
# hit_id
# pcc_eng_00_001.5549_x0008939_2:1-6-7       *Not only are our distributors __extremely goo...
# pcc_eng_00_001.1946_x0003163_12:24-25-26            *not only unstoppable , it is gathering*
# pcc_eng_00_001.0817_x0001331_058:12-13-14              *not only onerous , but make demands*
# pcc_eng_00_002.1940_x0019263_25:08-09-10               *not only applicable to Coca- Cola ,*
# pcc_eng_00_001.5458_x0008792_35:11-13-14    *not only budget- friendly -- it's dependable ,*
#
#                                                                                  text_window  \
# hit_id
# pcc_eng_00_001.5549_x0008939_2:1-6-7       *Not only are our distributors __extremely goo...
# pcc_eng_00_001.1946_x0003163_12:24-25-26   *of the world is not only unstoppable , it is ...
# pcc_eng_00_001.0817_x0001331_058:12-13-14  *, the bills are not only onerous , but make d...
# pcc_eng_00_002.1940_x0019263_25:08-09-10   *, the infographic is not only applicable to C...
# pcc_eng_00_001.5458_x0008792_35:11-13-14   *Stewartstown , Pennsylvania is not only budge...
#
#                                                                                    token_str  \
# hit_id
# pcc_eng_00_001.5549_x0008939_2:1-6-7       *Not only are our distributors __extremely goo...
# pcc_eng_00_001.1946_x0003163_12:24-25-26   *Julia Gillard is absolutely right in saying :...
# pcc_eng_00_001.0817_x0001331_058:12-13-14  *As far as drug makers are concerned , the bil...
# pcc_eng_00_002.1940_x0019263_25:08-09-10   *According to Naik , the infographic is not on...
# pcc_eng_00_001.5458_x0008792_35:11-13-14   *With DISH , high-speed Internet in Stewartsto...
#
#                                                                                    sent_text
# hit_id
# pcc_eng_00_001.5549_x0008939_2:1-6-7       *Not only are our distributors __extremely goo...
# pcc_eng_00_001.1946_x0003163_12:24-25-26   *Julia Gillard is absolutely right in saying: ...
# pcc_eng_00_001.0817_x0001331_058:12-13-14  *As far as drug makers are concerned, the bill...
# pcc_eng_00_002.1940_x0019263_25:08-09-10   *According to Naik, the infographic is not onl...
# pcc_eng_00_001.5458_x0008792_35:11-13-14   *With DISH, high-speed Internet in Stewartstow...

# %%
samples.append(show_hit_sample(HIT_TABLES_DIR.joinpath('not-RBdirect/NEQ_not-RBdirect_sample.24080200.parq'), show_following_neg=True))
# Out:
# /tmp/ipykernel_792812/1958673019.py:19: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   _sample = _sample.loc[_sample.token_str.str.contains(NEG_REGEX), :]
# Sample Hit from `not-RBdirect/NEQ_not-RBdirect_sample.24080200.parq`: *often sufficient*
#
# |                      | `apw_eng_20020113_0760_15:4-5`                                                                                    |
# |:---------------------|:------------------------------------------------------------------------------------------------------------------|
# | **`adv_form`**       | often                                                                                                             |
# | **`adj_form`**       | sufficient                                                                                                        |
# | **`text_window`**    | *while this is __often sufficient__ , it was not in this*                                                         |
# | **`token_str`**      | *while this is __often sufficient__ , it was not in this game , given the superior placement of Adams ' pieces .* |
# | **`adv_lemma`**      | often                                                                                                             |
# | **`adj_lemma`**      | sufficient                                                                                                        |
# | **`adv_index`**      | 3                                                                                                                 |
# | **`utt_len`**        | 22                                                                                                                |
# | **`adv_form_lower`** | often                                                                                                             |
# | **`adj_form_lower`** | sufficient                                                                                                        |
# | **`bigram_lower`**   | often_sufficient                                                                                                  |
# | **`window_len`**     | 11                                                                                                                |
# | **`chunk`**          | 2                                                                                                                 |
# | **`id_prefix`**      | apw_eng_2002                                                                                                      |
# | **`part`**           | Apw                                                                                                               |

# %% [markdown]
# Sample Hit from `not-RBdirect/NEQ_not-RBdirect_sample.24080200.parq`
#
# |                      | `pcc_eng_val_2.01745_x19038_13:24-25`                                                                                                                         |
# |:---------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`adv_form`**       | pretty                                                                                                                                                        |
# | **`adj_form`**       | rare                                                                                                                                                          |
# | **`text_window`**    | , female- focused surf films are still __pretty rare__ .                                                                                                      |
# | **`token_str`**      | Despite the huge population of women surfers that grace virtually every break on the planet nowadays , female- focused surf films are still __pretty rare__ . |
# | **`adv_lemma`**      | pretty                                                                                                                                                        |
# | **`adj_lemma`**      | rare                                                                                                                                                          |
# | **`adv_index`**      | 23                                                                                                                                                            |
# | **`utt_len`**        | 26                                                                                                                                                            |
# | **`adv_form_lower`** | pretty                                                                                                                                                        |
# | **`adj_form_lower`** | rare                                                                                                                                                          |
# | **`bigram_lower`**   | pretty_rare                                                                                                                                                   |
# | **`window_len`**     | 10                                                                                                                                                            |
# | **`chunk`**          | 1                                                                                                                                                             |
# | **`id_prefix`**      | pcc_eng_val_2                                                                                                                                                 |
# | **`part`**           | PccVa                                                                                                                                                         |
#
# Sample Hit from `not-RBdirect/NEQ_not-RBdirect_sample.24080200.parq`: *often sufficient*
#
# |                      | `apw_eng_20020113_0760_15:4-5`                                                                                    |
# |:---------------------|:------------------------------------------------------------------------------------------------------------------|
# | **`adv_form`**       | often                                                                                                             |
# | **`adj_form`**       | sufficient                                                                                                        |
# | **`text_window`**    | *while this is __often sufficient__ , it was not in this*                                                         |
# | **`token_str`**      | *while this is __often sufficient__ , it was not in this game , given the superior placement of Adams ' pieces .* |
# | **`adv_lemma`**      | often                                                                                                             |
# | **`adj_lemma`**      | sufficient                                                                                                        |
# | **`adv_index`**      | 3                                                                                                                 |
# | **`utt_len`**        | 22                                                                                                                |
# | **`adv_form_lower`** | often                                                                                                             |
# | **`adj_form_lower`** | sufficient                                                                                                        |
# | **`bigram_lower`**   | often_sufficient                                                                                                  |
# | **`window_len`**     | 11                                                                                                                |
# | **`chunk`**          | 2                                                                                                                 |
# | **`id_prefix`**      | apw_eng_2002                                                                                                      |
# | **`part`**           | Apw                                                                                                               |

# %% [markdown]
# Sample Hit from `not-RBdirect/NEQ_not-RBdirect_sample.24080200.parq`: *so many*
#
# |                      | `pcc_eng_val_1.4949_x08088_60:09-10`                                                                                                                                      |
# |:---------------------|:--------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`adv_form`**       | so                                                                                                                                                                        |
# | **`adj_form`**       | many                                                                                                                                                                      |
# | **`text_window`**    | *teammates do tease brissett a bit about __so many__ expectations being placed at his feet*                                                                               |
# | **`token_str`**      | *While teammates do tease Brissett a bit about __so many__ expectations being placed at his feet , Hines said that Brissett does n't seem to feel any sort of pressure .* |
# | **`adv_lemma`**      | so                                                                                                                                                                        |
# | **`adj_lemma`**      | many                                                                                                                                                                      |
# | **`adv_index`**      | 8                                                                                                                                                                         |
# | **`utt_len`**        | 31                                                                                                                                                                        |
# | **`adv_form_lower`** | so                                                                                                                                                                        |
# | **`adj_form_lower`** | many                                                                                                                                                                      |
# | **`bigram_lower`**   | so_many                                                                                                                                                                   |
# | **`window_len`**     | 15                                                                                                                                                                        |
# | **`chunk`**          | 1                                                                                                                                                                         |
# | **`id_prefix`**      | pcc_eng_val_1                                                                                                                                                             |
# | **`part`**           | PccVa                                                                                                                                                                     |

# %%
show_hit_sample(HIT_TABLES_DIR.joinpath('RBdirect/ALL-RBdirect_final.parq'))
# Out:
# Sample Hit from `RBdirect/ALL-RBdirect_final.parq`: *n't especially glamorous*
#
# |                          | `pcc_eng_val_3.02703_x38921_190:7-8-9`                                                                                                                                                                                                                                                                                                   |
# |:-------------------------|:-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`bigram`**             | especially_glamorous                                                                                                                                                                                                                                                                                                                     |
# | **`sent_text`**          | *This is another job that isn't __especially glamorous__, but it's available (and will continue to be for the indeterminate future).*                                                                                                                                                                                                    |
# | **`neg_form`**           | n't                                                                                                                                                                                                                                                                                                                                      |
# | **`adv_form`**           | especially                                                                                                                                                                                                                                                                                                                               |
# | **`adj_form`**           | glamorous                                                                                                                                                                                                                                                                                                                                |
# | **`hit_text`**           | *`n't` __especially glamorous__ , but it 's*                                                                                                                                                                                                                                                                                             |
# | **`text_window`**        | *this is another job that is `n't` __especially glamorous__ , but it 's available (*                                                                                                                                                                                                                                                     |
# | **`sent_id`**            | pcc_eng_val_3.02703_x38921_190                                                                                                                                                                                                                                                                                                           |
# | **`match_id`**           | 7-8-9                                                                                                                                                                                                                                                                                                                                    |
# | **`bigram_id`**          | pcc_eng_val_3.02703_x38921_190:8-9                                                                                                                                                                                                                                                                                                       |
# | **`token_str`**          | *This is another job that is `n't` __especially glamorous__ , but it 's available ( and will continue to be for the indeterminate future ) .*                                                                                                                                                                                            |
# | **`lemma_str`**          | this be another job that be not especially glamorous , but it be available ( and will continue to be for the indeterminate future ) .                                                                                                                                                                                                    |
# | **`neg_deprel`**         | advmod                                                                                                                                                                                                                                                                                                                                   |
# | **`neg_head`**           | ADJ                                                                                                                                                                                                                                                                                                                                      |
# | **`mod_deprel`**         | advmod                                                                                                                                                                                                                                                                                                                                   |
# | **`mod_head`**           | ADJ                                                                                                                                                                                                                                                                                                                                      |
# | **`neg_lemma`**          | not                                                                                                                                                                                                                                                                                                                                      |
# | **`adv_lemma`**          | especially                                                                                                                                                                                                                                                                                                                               |
# | **`adj_lemma`**          | glamorous                                                                                                                                                                                                                                                                                                                                |
# | **`neg_index`**          | 6                                                                                                                                                                                                                                                                                                                                        |
# | **`adv_index`**          | 7                                                                                                                                                                                                                                                                                                                                        |
# | **`adj_index`**          | 8                                                                                                                                                                                                                                                                                                                                        |
# | **`neg_all_dep_target`** | []                                                                                                                                                                                                                                                                                                                                       |
# | **`adv_all_dep_target`** | []                                                                                                                                                                                                                                                                                                                                       |
# | **`adj_all_dep_target`** | [{'index': 4, 'lemma': 'that', 'form': 'that', 'xpos': 'WDT', 'deprel': 'nsubj'}, {'index': 5, 'lemma': 'be', 'form': 'is', 'xpos': 'VBZ', 'deprel': 'cop'}, {'index': 6, 'lemma': 'not', 'form': "n't", 'xpos': 'RB', 'deprel': 'advmod'}, {'index': 7, 'lemma': 'especially', 'form': 'especially', 'xpos': 'RB', 'deprel': 'advmod'}] |
# | **`dep_neg`**            | {'node': 'neg', 'contiguous': False, 'relation': 'advmod', 'head': {'lemma': 'glamorous', 'ix': 8, 'xpos': 'JJ'}, 'target': {'lemma': 'not', 'ix': 6, 'xpos': 'RB'}}                                                                                                                                                                     |
# | **`dep_mod`**            | {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': {'lemma': 'glamorous', 'ix': 8, 'xpos': 'JJ'}, 'target': {'lemma': 'especially', 'ix': 7, 'xpos': 'RB'}}                                                                                                                                                               |
# | **`json_source`**        | /share/compling/data/sanpi/1_json_grew-matches/RBdirect/bigram-PccVa.direct-adj-head/BIGRAM.pcc_eng_val-03.json                                                                                                                                                                                                                          |
# | **`utt_len`**            | 26                                                                                                                                                                                                                                                                                                                                       |
# | **`pattern`**            | direct-adj-head                                                                                                                                                                                                                                                                                                                          |
# | **`category`**           | RBdirect                                                                                                                                                                                                                                                                                                                                 |
# | **`adv_form_lower`**     | especially                                                                                                                                                                                                                                                                                                                               |
# | **`adj_form_lower`**     | glamorous                                                                                                                                                                                                                                                                                                                                |
# | **`bigram_lower`**       | especially_glamorous                                                                                                                                                                                                                                                                                                                     |
# | **`neg_form_lower`**     | n't                                                                                                                                                                                                                                                                                                                                      |
# | **`trigger_lower`**      | n't                                                                                                                                                                                                                                                                                                                                      |
# | **`trigger_lemma`**      | not                                                                                                                                                                                                                                                                                                                                      |
# | **`all_forms_lower`**    | n't_especially_glamorous                                                                                                                                                                                                                                                                                                                 |
# | **`dep_distance`**       | 1                                                                                                                                                                                                                                                                                                                                        |
# | **`window_len`**         | 15                                                                                                                                                                                                                                                                                                                                       |
# | **`quarantine`**         | False                                                                                                                                                                                                                                                                                                                                    |
# | **`id_prefix`**          | pcc_eng_val_3                                                                                                                                                                                                                                                                                                                            |
# | **`part`**               | PccVa                                                                                                                                                                                                                                                                                                                                    |
#                                                     bigram  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  especially_glamorous
#
#                                                                               sent_text  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  *This is another job that isn't __especially g...
#
#                                      neg_form    adv_form   adj_form  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9      n't  especially  glamorous
#
#                                                                           hit_text  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  *`n't` __especially glamorous__ , but it 's*
#
#                                                                             text_window  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  *this is another job that is `n't` __especiall...
#
#                                                              sent_id match_id  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  pcc_eng_val_3.02703_x38921_190    7-8-9
#
#                                                                bigram_id  ...  \
# hit_id                                                                    ...
# pcc_eng_val_3.02703_x38921_190:7-8-9  pcc_eng_val_3.02703_x38921_190:8-9  ...
#
#                                               bigram_lower neg_form_lower  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  especially_glamorous            n't
#
#                                      trigger_lower trigger_lemma  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9           n't           not
#
#                                                all_forms_lower dep_distance  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  n't_especially_glamorous            1
#
#                                      window_len quarantine      id_prefix  \
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9         15      False  pcc_eng_val_3
#
#                                        part
# hit_id
# pcc_eng_val_3.02703_x38921_190:7-8-9  PccVa
#
# [1 rows x 43 columns]

# %%
show_hit_sample(HIT_TABLES_DIR.joinpath('NEGmirror/ALL-NEGmirror_final.parq'))
# Out:
# Sample Hit from `NEGmirror/ALL-NEGmirror_final.parq`: *never quite comfortable*
#
# |                           | `pcc_eng_val_3.04925_x42562_13:08-09-10`                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# |:--------------------------|:---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`bigram`**              | quite_comfortable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`sent_text`**           | *For whatever reason, little Ted was `never` __quite comfortable__ about being born.*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`neg_form`**            | never                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adv_form`**            | quite                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adj_form`**            | comfortable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`hit_text`**            | *`never` __quite comfortable__ about being born .*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`text_window`**         | *whatever reason , little ted was `never` __quite comfortable__ about being born .*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | **`sent_id`**             | pcc_eng_val_3.04925_x42562_13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | **`match_id`**            | 08-09-10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | **`bigram_id`**           | pcc_eng_val_3.04925_x42562_13:09-10                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | **`token_str`**           | *For whatever reason , little Ted was `never` __quite comfortable__ about being born .*                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | **`lemma_str`**           | for whatever reason , little Ted be never quite comfortable about be bear .                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`neg_deprel`**          | advmod                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | **`neg_head`**            | ADJ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | **`mod_deprel`**          | advmod                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                   |
# | **`mod_head`**            | ADJ                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      |
# | **`neg_lemma`**           | never                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adv_lemma`**           | quite                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adj_lemma`**           | comfortable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`neg_index`**           | 7                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`adv_index`**           | 8                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`adj_index`**           | 9                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`neg_all_dep_targets`** | []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`adv_all_dep_targets`** | []                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`adj_all_dep_targets`** | [{'index': 2, 'lemma': 'reason', 'form': 'reason', 'xpos': 'NN', 'deprel': 'obl'}, {'index': 3, 'lemma': ',', 'form': ',', 'xpos': ',', 'deprel': 'punct'}, {'index': 5, 'lemma': 'Ted', 'form': 'Ted', 'xpos': 'NNP', 'deprel': 'nsubj'}, {'index': 6, 'lemma': 'be', 'form': 'was', 'xpos': 'VBD', 'deprel': 'cop'}, {'index': 7, 'lemma': 'never', 'form': 'never', 'xpos': 'RB', 'deprel': 'advmod'}, {'index': 8, 'lemma': 'quite', 'form': 'quite', 'xpos': 'RB', 'deprel': 'advmod'}, {'index': 12, 'lemma': 'bear', 'form': 'born', 'xpos': 'VBN', 'deprel': 'advcl'}, {'index': 13, 'lemma': '.', 'form': '.', 'xpos': '.', 'deprel': 'punct'}] |
# | **`dep_neg`**             | {'node': 'neg', 'contiguous': False, 'relation': 'advmod', 'head': {'lemma': 'comfortable', 'ix': 9, 'xpos': 'JJ'}, 'target': {'lemma': 'never', 'ix': 7, 'xpos': 'RB'}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                 |
# | **`dep_mod`**             | {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': {'lemma': 'comfortable', 'ix': 9, 'xpos': 'JJ'}, 'target': {'lemma': 'quite', 'ix': 8, 'xpos': 'RB'}}                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | **`neg_form_lower`**      | never                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adv_form_lower`**      | quite                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`adj_form_lower`**      | comfortable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              |
# | **`utt_len`**             | 14                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`json_source`**         | /share/compling/data/sanpi/1_json_grew-matches/NEGmirror/bigram-PccVa.neg-mirror-R/BIGRAM.pcc_eng_val-03.json                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | **`bigram_lower`**        | quite_comfortable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`all_forms_lower`**     | never_quite_comfortable                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                  |
# | **`pattern`**             | neg-mirror-R                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                             |
# | **`category`**            | NEGmirror                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                |
# | **`trigger_lower`**       | never                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`trigger_lemma`**       | never                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`dep_distance`**        | 1                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                        |
# | **`window_len`**          | 13                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       |
# | **`quarantine`**          | False                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# | **`id_prefix`**           | pcc_eng_val_3                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                            |
# | **`part`**                | PccVa                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
#                                                    bigram  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  quite_comfortable
#
#                                                                                 sent_text  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  *For whatever reason, little Ted was `never` _...
#
#                                        neg_form adv_form     adj_form  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10    never    quite  comfortable
#
#                                                                                  hit_text  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  *`never` __quite comfortable__ about being bor...
#
#                                                                               text_window  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  *whatever reason , little ted was `never` __qu...
#
#                                                               sent_id  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  pcc_eng_val_3.04925_x42562_13
#
#                                         match_id  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  08-09-10
#
#                                                                   bigram_id  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  pcc_eng_val_3.04925_x42562_13:09-10
#
#                                         ...          all_forms_lower  \
# hit_id                                  ...
# pcc_eng_val_3.04925_x42562_13:08-09-10  ...  never_quite_comfortable
#
#                                              pattern   category trigger_lower  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10  neg-mirror-R  NEGmirror         never
#
#                                        trigger_lemma dep_distance window_len  \
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10         never            1         13
#
#                                        quarantine      id_prefix   part
# hit_id
# pcc_eng_val_3.04925_x42562_13:08-09-10      False  pcc_eng_val_3  PccVa
#
# [1 rows x 43 columns]

# %%
show_hit_sample(HIT_TABLES_DIR.joinpath('POSmirror/ALL-POSmirror_final.parq'), head='MIR').T
# Out:
# Sample Hit from `POSmirror/ALL-POSmirror_final.parq`: *something fairly bad*
#
# |                           | `pcc_eng_val_1.9883_x16019_07:10-11-12`                                                                                                                               |
# |:--------------------------|:----------------------------------------------------------------------------------------------------------------------------------------------------------------------|
# | **`bigram`**              | fairly_bad                                                                                                                                                            |
# | **`sent_text`**           | *It seemed clear to me that Santi had done `something` __fairly bad__ to his knee.*                                                                                   |
# | **`adv_form`**            | fairly                                                                                                                                                                |
# | **`adj_form`**            | bad                                                                                                                                                                   |
# | **`hit_text`**            | *`something` __fairly bad__ to his knee .*                                                                                                                            |
# | **`text_window`**         | *to me that santi had done `something` __fairly bad__ to his knee .*                                                                                                  |
# | **`sent_id`**             | pcc_eng_val_1.9883_x16019_07                                                                                                                                          |
# | **`match_id`**            | 10-11-12                                                                                                                                                              |
# | **`bigram_id`**           | pcc_eng_val_1.9883_x16019_07:11-12                                                                                                                                    |
# | **`token_str`**           | *It seemed clear to me that Santi had done `something` __fairly bad__ to his knee .*                                                                                  |
# | **`lemma_str`**           | it seem clear to I that Santi have do something fairly bad to he knee .                                                                                               |
# | **`mod_deprel`**          | advmod                                                                                                                                                                |
# | **`mod_head`**            | ADJ                                                                                                                                                                   |
# | **`mir_deprel`**          | amod                                                                                                                                                                  |
# | **`mir_head`**            | MIR                                                                                                                                                                   |
# | **`mir_lemma`**           | something                                                                                                                                                             |
# | **`adv_lemma`**           | fairly                                                                                                                                                                |
# | **`adj_lemma`**           | bad                                                                                                                                                                   |
# | **`mir_form`**            | something                                                                                                                                                             |
# | **`mir_index`**           | 9                                                                                                                                                                     |
# | **`adv_index`**           | 10                                                                                                                                                                    |
# | **`adj_index`**           | 11                                                                                                                                                                    |
# | **`mir_all_dep_targets`** | [{'index': 11, 'lemma': 'bad', 'form': 'bad', 'xpos': 'JJ', 'deprel': 'amod'}]                                                                                        |
# | **`adv_all_dep_targets`** | []                                                                                                                                                                    |
# | **`adj_all_dep_targets`** | [{'index': 10, 'lemma': 'fairly', 'form': 'fairly', 'xpos': 'RB', 'deprel': 'advmod'}, {'index': 14, 'lemma': 'knee', 'form': 'knee', 'xpos': 'NN', 'deprel': 'obl'}] |
# | **`dep_mod`**             | {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': {'lemma': 'bad', 'ix': 11, 'xpos': 'JJ'}, 'target': {'lemma': 'fairly', 'ix': 10, 'xpos': 'RB'}}    |
# | **`dep_mir`**             | {'node': 'mir', 'contiguous': False, 'relation': 'amod', 'head': {'lemma': 'something', 'ix': 9, 'xpos': 'NN'}, 'target': {'lemma': 'bad', 'ix': 11, 'xpos': 'JJ'}}   |
# | **`mir_form_lower`**      | something                                                                                                                                                             |
# | **`adv_form_lower`**      | fairly                                                                                                                                                                |
# | **`adj_form_lower`**      | bad                                                                                                                                                                   |
# | **`utt_len`**             | 16                                                                                                                                                                    |
# | **`json_source`**         | /share/compling/data/sanpi/1_json_grew-matches/POSmirror/bigram-PccVa.pos-mirror-L/BIGRAM.pcc_eng_val-01.json                                                         |
# | **`bigram_lower`**        | fairly_bad                                                                                                                                                            |
# | **`all_forms_lower`**     | something_fairly_bad                                                                                                                                                  |
# | **`pattern`**             | pos-mirror-L                                                                                                                                                          |
# | **`category`**            | POSmirror                                                                                                                                                             |
# | **`trigger_lower`**       | something                                                                                                                                                             |
# | **`trigger_lemma`**       | something                                                                                                                                                             |
# | **`dep_distance`**        | 1                                                                                                                                                                     |
# | **`window_len`**          | 13                                                                                                                                                                    |
# | **`quarantine`**          | False                                                                                                                                                                 |
# | **`id_prefix`**           | pcc_eng_val_1                                                                                                                                                         |
# | **`part`**                | PccVa                                                                                                                                                                 |
# hit_id                           pcc_eng_val_1.9883_x16019_07:10-11-12
# bigram                                                      fairly_bad
# sent_text            *It seemed clear to me that Santi had done `so...
# adv_form                                                        fairly
# adj_form                                                           bad
# hit_text                    *`something` __fairly bad__ to his knee .*
# text_window          *to me that santi had done `something` __fairl...
# sent_id                                   pcc_eng_val_1.9883_x16019_07
# match_id                                                      10-11-12
# bigram_id                           pcc_eng_val_1.9883_x16019_07:11-12
# token_str            *It seemed clear to me that Santi had done `so...
# lemma_str            it seem clear to I that Santi have do somethin...
# mod_deprel                                                      advmod
# mod_head                                                           ADJ
# mir_deprel                                                        amod
# mir_head                                                           MIR
# mir_lemma                                                    something
# adv_lemma                                                       fairly
# adj_lemma                                                          bad
# mir_form                                                     something
# mir_index                                                            9
# adv_index                                                           10
# adj_index                                                           11
# mir_all_dep_targets  [{'index': 11, 'lemma': 'bad', 'form': 'bad', ...
# adv_all_dep_targets                                                 []
# adj_all_dep_targets  [{'index': 10, 'lemma': 'fairly', 'form': 'fai...
# dep_mod              {'node': 'mod', 'contiguous': True, 'relation'...
# dep_mir              {'node': 'mir', 'contiguous': False, 'relation...
# mir_form_lower                                               something
# adv_form_lower                                                  fairly
# adj_form_lower                                                     bad
# utt_len                                                             16
# json_source          /share/compling/data/sanpi/1_json_grew-matches...
# bigram_lower                                                fairly_bad
# all_forms_lower                                   something_fairly_bad
# pattern                                                   pos-mirror-L
# category                                                     POSmirror
# trigger_lower                                                something
# trigger_lemma                                                something
# dep_distance                                                         1
# window_len                                                          13
# quarantine                                                       False
# id_prefix                                                pcc_eng_val_1
# part                                                             PccVa

# %%
show_hit_sample(HIT_TABLES_DIR.joinpath('RBXadj/cleaned/clean_PccVa_rb-bigram_hits.parq'), parts=['PccVa'])
# Out:
# Sample Hit from `RBXadj/cleaned/clean_PccVa_rb-bigram_hits.parq`: *so harmful*
#
# |                      | `pcc_eng_val_1.6689_x10841_17:13-14`                                                                                   |
# |:---------------------|:-----------------------------------------------------------------------------------------------------------------------|
# | **`adv_form`**       | so                                                                                                                     |
# | **`adj_form`**       | harmful                                                                                                                |
# | **`text_window`**    | *properties of plastics , which make them __so harmful__ when they end up in the*                                      |
# | **`token_str`**      | *But it is these useful properties of plastics , which make them __so harmful__ when they end up in the environment .* |
# | **`adv_lemma`**      | so                                                                                                                     |
# | **`adj_lemma`**      | harmful                                                                                                                |
# | **`adv_index`**      | 12                                                                                                                     |
# | **`utt_len`**        | 22                                                                                                                     |
# | **`adv_form_lower`** | so                                                                                                                     |
# | **`adj_form_lower`** | harmful                                                                                                                |
# | **`bigram_lower`**   | so_harmful                                                                                                             |
# | **`window_len`**     | 15                                                                                                                     |
# | **`id_prefix`**      | pcc_eng_val_1                                                                                                          |
#                                    adv_form adj_form  \
# hit_id
# pcc_eng_val_1.6689_x10841_17:13-14       so  harmful
#
#                                                                           text_window  \
# hit_id
# pcc_eng_val_1.6689_x10841_17:13-14  *properties of plastics , which make them __so...
#
#                                                                             token_str  \
# hit_id
# pcc_eng_val_1.6689_x10841_17:13-14  *But it is these useful properties of plastics...
#
#                                    adv_lemma adj_lemma  adv_index  utt_len  \
# hit_id
# pcc_eng_val_1.6689_x10841_17:13-14        so   harmful         12       22
#
#                                    adv_form_lower adj_form_lower bigram_lower  \
# hit_id
# pcc_eng_val_1.6689_x10841_17:13-14             so        harmful   so_harmful
#
#                                     window_len      id_prefix
# hit_id
# pcc_eng_val_1.6689_x10841_17:13-14          15  pcc_eng_val_1

# %% [markdown]
# Sample Hit from `RBXadj/cleaned/clean_PccVa_rb-bigram_hits.parq`: *so harmful*
#
# |                      | `pcc_eng_val_1.6689_x10841_17:13-14`                                                                                   |
# |:---------------------|:-----------------------------------------------------------------------------------------------------------------------|
# | **`adv_form`**       | so                                                                                                                     |
# | **`adj_form`**       | harmful                                                                                                                |
# | **`text_window`**    | *properties of plastics , which make them __so harmful__ when they end up in the*                                      |
# | **`token_str`**      | *But it is these useful properties of plastics , which make them __so harmful__ when they end up in the environment .* |
# | **`adv_lemma`**      | so                                                                                                                     |
# | **`adj_lemma`**      | harmful                                                                                                                |
# | **`adv_index`**      | 12                                                                                                                     |
# | **`utt_len`**        | 22                                                                                                                     |
# | **`adv_form_lower`** | so                                                                                                                     |
# | **`adj_form_lower`** | harmful                                                                                                                |
# | **`bigram_lower`**   | so_harmful                                                                                                             |
# | **`window_len`**     | 15                                                                                                                     |
# | **`id_prefix`**      | pcc_eng_val_1                                                                                                          |

# %%
show_hit_sample(HIT_TABLES_DIR.joinpath('RBdirect/cleaned/clean_Pcc25_RBdirect_hits.csv.bz2'), n=5, 
                not_only=True)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_792812/3892247395.py in ?()
# ----> 1 show_hit_sample(HIT_TABLES_DIR.joinpath('RBdirect/ALL-RBdirect_final.parq'), n=5,
#       2                 parq_filter_list=[('neg_lemma', '==', 'not'), ('adv_form_lower', '==', 'only')])
#
# /tmp/ipykernel_792812/2577827604.py in ?(path, n, parts, transpose, show_following_neg, head, parq_filter_list)
#      35                                     bold_regex=f"({_sample.filter(like='adv_form').iat[0,0]} {_sample.filter(like='adj_form').iat[0,0]})") + '*'
#      36         if 'trigger_lower' in _sample.columns:
#      37             trigger_lower = _sample.trigger_lower.squeeze()
#      38             trigger_regex = r'|'.join(
# ---> 39                 [trigger_lower, trigger_lower.capitalize(), trigger_lower.upper()])
#      40             _formatted = _formatted.replace(
#      41                 r'\b('+trigger_regex+r')\b', r'`\1`', regex=True)
#      42         _sample[text_col] = _formatted
#
# ~/.conda/envs/dev-sanpi/lib/python3.11/site-packages/pandas/core/generic.py in ?(self, name)
#    6200             and name not in self._accessors
#    6201             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'capitalize'
