# %%
# Install `transformers` from master
# ! 👇 apparently this isn't really python code. It only works on jupyter kernal
# %pip install transformers
# %pip list | grep -E 'transformers|tokenizers'
# transformers version at notebook update --- 4.32.1 #//2.11.0
# tokenizers version at notebook update ---  0.13.3 #//0.8.0rc1

import csv
from pathlib import Path
from pprint import pprint

import pandas as pd
import torch
from transformers import (AutoModel, AutoModelForMaskedLM, AutoTokenizer,
                          pipeline)
from utils.LexicalCategories import ADJ_BY_SCALE as ADJ_SETS
from utils.LexicalCategories import ADV_OF_INTEREST as ADV_SETS

pd.set_option('display.max_colwidth', 70)
pd.set_option("display.precision", 5)
MASK_POS = 'adv'
MODEL = 'distilbert-base-uncased'
UNMASK = pipeline('fill-mask', model=MODEL, tokenizer=MODEL, framework='pt')
HITS_PATH = Path(
    '/share/compling/projects/sanpi/demo/data/2_hit_tables/RBXadj/bigram_X2puddin_all-RB-JJs_hits.csv')
FRQ_FILTER = Path(
    '/share/compling/projects/sanpi/demo/data/4_post-processed/RBxpos/hit-index_thr0-001p.1f.txt')
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (4.32.1)
# Requirement already satisfied: regex!=2019.12.17 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (2023.8.8)
# Requirement already satisfied: numpy>=1.17 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (1.22.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (0.13.3)
# Requirement already satisfied: filelock in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (3.12.3)
# Requirement already satisfied: tqdm>=4.27 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (4.66.1)
# Requirement already satisfied: safetensors>=0.3.1 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (0.3.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.15.1 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (0.16.4)
# Requirement already satisfied: packaging>=20.0 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (21.3)
# Requirement already satisfied: requests in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from transformers) (6.0.1)
# Requirement already satisfied: fsspec in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (2023.9.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.15.1->transformers) (4.7.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from packaging>=20.0->transformers) (3.0.9)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from requests->transformers) (2.0.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from requests->transformers) (3.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from requests->transformers) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages (from requests->transformers) (3.4)
# Note: you may need to restart the kernel to use updated packages.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# tokenizers               0.13.3
# transformers             4.32.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
#  ## Load sample hit table as data

# %%
def _load_hits(dpath=HITS_PATH):

    if '.csv' in dpath.suffixes:
        data = pd.read_csv(dpath)
        data = data.set_index('hit_id').convert_dtypes()

    elif dpath.endswith('pkl.gz'):
        data = pd.read_pickle(dpath)

    print('data loaded')
    pprint(data.columns)
    print(data.sample(3))

    return data

data = _load_hits()
# Out:
# data loaded
# Index(['colloc', 'sent_text', 'adv_form', 'adj_form', 'hit_text',
#        'text_window', 'sent_id', 'match_id', 'colloc_id', 'token_str',
#        'lemma_str', 'context_prev_id', 'context_prev_sent', 'context_next_id',
#        'context_next_sent', 'adv_lemma', 'adj_lemma', 'adv_index', 'adj_index',
#        'dep_mod', 'json_source', 'utt_len', 'category'],
#       dtype='object')
#                                                colloc  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29   very_eventful
# pcc_eng_29_109.3185_x1745367_07:09-10  most_important
# pcc_eng_29_108.4211_x1736061_05:4-5       very_public
#
#                                                                                                    sent_text  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29  Set in a sleepy cul-de-sac somewhere in beachside suburbia, Swingi...
# pcc_eng_29_109.3185_x1745367_07:09-10  DEA agents should also focus on "the most important cases in their...
# pcc_eng_29_108.4211_x1736061_05:4-5    Aside from that very public spat with Kim Cattrall, Sarah Jessica ...
#
#                                       adv_form   adj_form        hit_text  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29     very   eventful   very eventful
# pcc_eng_29_109.3185_x1745367_07:09-10     most  important  most important
# pcc_eng_29_108.4211_x1736061_05:4-5       very     public     very public
#
#                                                                      text_window  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29       , hot and very eventful summer a 200
# pcc_eng_29_109.3185_x1745367_07:09-10     on " the most important cases in their
# pcc_eng_29_108.4211_x1736061_05:4-5    Aside from that very public spat with Kim
#
#                                                                sent_id  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29  pcc_eng_29_108.2028_x1732482_04
# pcc_eng_29_109.3185_x1745367_07:09-10  pcc_eng_29_109.3185_x1745367_07
# pcc_eng_29_108.4211_x1736061_05:4-5    pcc_eng_29_108.4211_x1736061_05
#
#                                       match_id  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29    28-29
# pcc_eng_29_109.3185_x1745367_07:09-10    09-10
# pcc_eng_29_108.4211_x1736061_05:4-5        4-5
#
#                                                                    colloc_id  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29  pcc_eng_29_108.2028_x1732482_04:28-29
# pcc_eng_29_109.3185_x1745367_07:09-10  pcc_eng_29_109.3185_x1745367_07:09-10
# pcc_eng_29_108.4211_x1736061_05:4-5      pcc_eng_29_108.4211_x1736061_05:4-5
#
#                                                                                                    token_str  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29  Set in a sleepy cul-de-sac somewhere in beachside suburbia , Swing...
# pcc_eng_29_109.3185_x1745367_07:09-10  DEA agents should also focus on " the most important cases in thei...
# pcc_eng_29_108.4211_x1736061_05:4-5    Aside from that very public spat with Kim Cattrall , Sarah Jessica...
#
#                                        ...                  context_next_id  \
# hit_id                                 ...
# pcc_eng_29_108.2028_x1732482_04:28-29  ...  pcc_eng_29_108.2028_x1732482_05
# pcc_eng_29_109.3185_x1745367_07:09-10  ...  pcc_eng_29_109.3185_x1745367_08
# pcc_eng_29_108.4211_x1736061_05:4-5    ...  pcc_eng_29_108.4211_x1736061_06
#
#                                       context_next_sent adv_lemma  adj_lemma  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29              <NA>      very   eventful
# pcc_eng_29_109.3185_x1745367_07:09-10              <NA>      most  important
# pcc_eng_29_108.4211_x1736061_05:4-5                <NA>      very     public
#
#                                       adv_index adj_index  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29        27        28
# pcc_eng_29_109.3185_x1745367_07:09-10         8         9
# pcc_eng_29_108.4211_x1736061_05:4-5           3         4
#
#                                                                                                      dep_mod  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29  {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': ...
# pcc_eng_29_109.3185_x1745367_07:09-10  {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': ...
# pcc_eng_29_108.4211_x1736061_05:4-5    {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': ...
#
#                                                                                                  json_source  \
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29  /share/compling/projects/sanpi/demo/data/1_json_grew-matches/RBXad...
# pcc_eng_29_109.3185_x1745367_07:09-10  /share/compling/projects/sanpi/demo/data/1_json_grew-matches/RBXad...
# pcc_eng_29_108.4211_x1736061_05:4-5    /share/compling/projects/sanpi/demo/data/1_json_grew-matches/RBXad...
#
#                                        utt_len category
# hit_id
# pcc_eng_29_108.2028_x1732482_04:28-29       41   RBXadj
# pcc_eng_29_109.3185_x1745367_07:09-10       53   RBXadj
# pcc_eng_29_108.4211_x1736061_05:4-5         57   RBXadj
#
# [3 rows x 23 columns]

# %% [markdown]
#  Apply filters to loaded data, based on frequency as well as manual criteria

# %%
def _filter_hits(hits_data):
    # trim data
    filter_hi = pd.read_csv(FRQ_FILTER).squeeze()
    df = hits_data.loc[filter_hi,
                       ['adv_form', 'adj_form', 'adv_lemma', 'adj_lemma',
                        'adv_index', 'adj_index', 'token_str', 'text_window']]
    df = df.assign(
        prev_prev_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[max(-1,df.adv_index[ix] - 2)]),
        prev_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[max(-1,df.adv_index[ix] - 1)]),
        next_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[min(len(df.token_str[ix].split())-1, df.adj_index[ix] + 1)]),
        next_next_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[min(len(df.token_str[ix].split())-1, df.adj_index[ix] + 2)])
        )
    df.loc[df.prev_word == df.prev_prev_word, 'prev_prev_word'] = ''
    df.loc[df.prev_word == df.adv_form, 'prev_word'] = ''
    df.loc[df.next_word == df.next_next_word, 'next_next_word'] = ''
    df.loc[df.next_word == df.adj_form, 'next_word'] = ''
    manual_criteria = (
        # limit to `token_str` values with no more than 14 spaces ≈ max 15 words
        (df.token_str.str.count(' ') <= 14)
        # NOTE: 'many', 'much' & 'enough' have abnormal syntactic patterns
        & (~df.adv_lemma.str.lower().isin(('enough', 'how', 'much', 'most')))
        & (~df.adj_lemma.str.lower().isin(('many', 'more', 'much')))
        # have issues filling position following "much" and "more"--they don't wind up being adverbs but comparative adjectives
        & (~df.prev_word.isin(['more', 'much', 'as']))
        & (~df.next_word.str.lower().isin(['as']))
    )
    df = df.loc[manual_criteria, :]

    return df

data = _filter_hits(data)

# %%
data.sample(5).reset_index(drop=True).loc[:, data.columns.str.endswith(('word', 'form', 'str', 'window'))].set_index('text_window')
# Out:
#                                                        adv_form    adj_form  \
# text_window
# Very amazed with the standard                              Very      amazed
# I 'm also curious to see how                               also     curious
# thing that is definitely better about Portland is    definitely      better
# pain is a surprisingly mysterious thing .          surprisingly  mysterious
# Being so Normal was released on                              so      Normal
#
#                                                                                                                token_str  \
# text_window
# Very amazed with the standard                      Very amazed with the standard of his provider and his professional...
# I 'm also curious to see how                             I 'm also curious to see how players take to the leaderboards .
# thing that is definitely better about Portland is  Austin -- the one thing that is definitely better about Portland i...
# pain is a surprisingly mysterious thing .                              Chronic pain is a surprisingly mysterious thing .
# Being so Normal was released on                    Being so Normal was released on September 18th via Kingfisher Bluez .
#
#                                                   prev_prev_word prev_word  \
# text_window
# Very amazed with the standard                                            .
# I 'm also curious to see how                                   I        'm
# thing that is definitely better about Portland is           that        is
# pain is a surprisingly mysterious thing .                     is         a
# Being so Normal was released on                                .     Being
#
#                                                   next_word next_next_word
# text_window
# Very amazed with the standard                          with            the
# I 'm also curious to see how                             to            see
# thing that is definitely better about Portland is     about       Portland
# pain is a surprisingly mysterious thing .             thing              .
# Being so Normal was released on                         was       released

# %% [markdown]
#  ## Mask tokens
#  In this version, the data is not pre-masked.
#  It consists of sentence strings and target information, including the index of token nodes in the `token_str` values.
#  Should be able to use the `adv_index` and/or `adj_index` to create the corresponding masked version of `token_str`
#
#  _Note: for some reason, the initial filter series, `filter_hi`, gets reshaped as the index of `data`, so it cannot be used in place of `data.index.to_series()`_

# %%
def pre_mask(df, mask_pos='adv'):
    # df.info()
    mask_ix = df.loc[:, f'{mask_pos}_index']
    # print(mask_ix)
    # #! end index is not included in the returned value! [:mask_ix[h]-1] cuts out the word preceding the adv as well

    return df.index.to_series().apply(
        lambda h: ' '.join(df.token_str[h].split()[:mask_ix[h]]))


def post_mask(df, mask_pos='adv'):
    mask_ix = df.loc[:, f'{mask_pos}_index']

    return mask_ix.index.to_series().apply(
        lambda h: ' '.join(df.token_str[h].split()[mask_ix[h]+1:]))


def mask(df: pd.DataFrame, pos='adv'):
    # sourcery skip: use-fstring-for-concatenation
    pre_col = pre_mask(df, pos)
    post_col = post_mask(df, pos)
    return df.assign(masked=pre_col + ' [MASK] ' + post_col)


data = mask(data, MASK_POS)

# %%
data.sample(9).rename(columns={'adv_form':'original token'}).set_index('original token')[['masked']]
# Out:
#                                                                                masked
# original token
# very                                         It 's [MASK] clear about their mission .
# that               But I can I admit I have n't always been [MASK] welcoming to him .
# more                  White - winged Crossbills were the [MASK] abundant of the two .
# economically          Digital thermometers are [MASK] cheaper than the other forms of
# not             You might feel like you have plenty of choice , but simply [MASK] ...
# rather          Slicing and dicing into small pieces - yes , that did sound [MASK]...
# super                                  They are [MASK] soft and extremely absorbent .
# not             For publishers , the news may be dispiriting , but it 's [MASK] su...
# too                                                            Life is [MASK] short !

# %% [markdown]
#  ## *Unmask* Tokens
#  Data is loaded and now _masked_ sentences are a column in the dataframe.
#  Can use `UNMASK` pipeline to get probabilities of tokens at masked position.
#
#  ## For just 1 input
#
#  Select sample sentence and run pipeline

# %%
selected_data = data.loc[:, ['adv_form', 'adj_form', 'text_window', 'masked', 'prev_word', 'next_word']]
sent_row = selected_data.sample(1)
sent = sent_row.masked.squeeze()
sent_row.transpose()
# Out:
# hit_id           pcc_eng_29_109.3186_x1745368_049:5-6
# adv_form                                         very
# adj_form                                    ambiguous
# text_window        it 's a very ambiguous paragraph .
# masked       And it 's a [MASK] ambiguous paragraph .
# prev_word                                           a
# next_word                                   paragraph

# %% [markdown]
#  get top 10 predictions for masked position

# %%
results = UNMASK(sent, top_k=10)
rdf = pd.DataFrame(results).sort_values('score', ascending=False)
rdf.set_index('token_str')
# Out:
#                score  token                                     sequence
# token_str
# very         0.12981   2200         and it's a very ambiguous paragraph.
# rather       0.10789   2738       and it's a rather ambiguous paragraph.
# highly       0.06455   3811       and it's a highly ambiguous paragraph.
# pretty       0.04952   3492       and it's a pretty ambiguous paragraph.
# somewhat     0.04842   5399     and it's a somewhat ambiguous paragraph.
# fairly       0.04229   7199       and it's a fairly ambiguous paragraph.
# perfectly    0.03731   6669    and it's a perfectly ambiguous paragraph.
# politically  0.03101  10317  and it's a politically ambiguous paragraph.
# slightly     0.02751   3621     and it's a slightly ambiguous paragraph.
# morally      0.02369  28980      and it's a morally ambiguous paragraph.

# %% [markdown]
#  load lexical categories and compare

# %%
def add_lexcats(results:pd.DataFrame, 
                lex_dict:dict,
                original_forms:pd.Series) -> pd.DataFrame:

    cat_start_index = len(results.columns)
    for lex_type, lex_set in lex_dict.items():
        results.loc[:, lex_type] = results.token_str.isin(lex_set)
    return (results
            .assign(lexcat_defined=rdf.iloc[:, cat_start_index:].apply(any, axis=1),
                    match_masked_POS=results.token_str.isin(original_forms))
            )


if MASK_POS == 'adj':
    lexcat_dict = ADJ_SETS
elif MASK_POS == 'adv':
    # for adv_type, adv_set in ADV_SETS.items():
    #     rdf.loc[:, adv_type] = rdf.token_str.isin(adv_set)
    # rdf = rdf.assign(match_masked_POS=rdf.token_str.isin(data.adv_form))
    lexcat_dict = ADV_SETS

rdf = add_lexcats(rdf, lexcat_dict, data[f'{MASK_POS}_form'])
rdf = rdf.set_index('token_str')
print(f'## input:\n   > {sent}')
# Out:
# ## input:
#    > And it 's a [MASK] ambiguous paragraph .

# %%
rdf.loc[:, ['score']].join(rdf.iloc[:, 3:])
# Out:
#                score  sufficient  min_threshold  max_threshold  moderate  \
# token_str
# very         0.12981       False          False          False     False
# rather       0.10789       False          False          False     False
# highly       0.06455       False          False          False     False
# pretty       0.04952       False          False          False     False
# somewhat     0.04842       False          False          False     False
# fairly       0.04229       False          False          False     False
# perfectly    0.03731       False          False           True     False
# politically  0.03101       False          False          False     False
# slightly     0.02751       False           True          False      True
# morally      0.02369       False          False          False     False
#
#              precise  compare  weak_intense  meas_intense  mod_intense  ...  \
# token_str                                                               ...
# very           False    False          True         False        False  ...
# rather         False    False         False         False        False  ...
# highly         False    False         False          True        False  ...
# pretty         False    False         False         False        False  ...
# somewhat       False    False         False         False        False  ...
# fairly         False    False         False         False        False  ...
# perfectly      False    False         False         False        False  ...
# politically    False    False         False         False        False  ...
# slightly       False    False         False         False        False  ...
# morally        False    False         False         False        False  ...
#
#              max_intense  EDM_Morzycki  Mmod_SoltWilson  negative  positive  \
# token_str
# very               False         False            False     False     False
# rather             False         False             True     False     False
# highly             False         False            False     False     False
# pretty             False         False             True     False     False
# somewhat           False         False             True     False     False
# fairly             False         False             True     False     False
# perfectly           True         False            False     False     False
# politically        False         False            False     False     False
# slightly           False         False            False     False     False
# morally            False         False            False     False     False
#
#                NPS  PS_rescuer    PPS  lexcat_defined  match_masked_POS
# token_str
# very         False       False  False            True              True
# rather       False       False   True            True              True
# highly       False       False  False            True              True
# pretty       False       False   True            True              True
# somewhat     False       False   True            True              True
# fairly       False       False   True            True              True
# perfectly    False       False  False            True              True
# politically  False       False  False           False              True
# slightly     False       False  False            True              True
# morally      False       False  False           False              True
#
# [10 rows x 31 columns]

# %% [markdown]
#  ## Across multiple inputs
#
#  Apply across all masked sentences and collect results

# %%
pprint([{'hit_id': i,
         f'original_{MASK_POS}': selected_data.loc[i, f'{MASK_POS}_form'],
         'text_window': selected_data.text_window[i],
         'masked_str': selected_data.masked[i],
         'scores': UNMASK(selected_data.masked[i], top_k=3)}
        for i in selected_data.sample(3).index])
# Out:
# [{'hit_id': 'pcc_eng_29_108.5107_x1737524_64:12-13',
#   'masked_str': 'Men are very safe with us , let them be ever [MASK] rich .',
#   'original_adv': 'so',
#   'scores': [{'score': 0.478022038936615,
#               'sequence': 'men are very safe with us, let them be ever so '
#                           'rich.',
#               'token': 2061,
#               'token_str': 'so'},
#              {'score': 0.14283417165279388,
#               'sequence': 'men are very safe with us, let them be ever too '
#                           'rich.',
#               'token': 2205,
#               'token_str': 'too'},
#              {'score': 0.08018776029348373,
#               'sequence': 'men are very safe with us, let them be ever more '
#                           'rich.',
#               'token': 2062,
#               'token_str': 'more'}],
#   'text_window': 'them be ever so rich .'},
#  {'hit_id': 'pcc_eng_29_109.0735_x1741513_02:3-4',
#   'masked_str': "Pope ' [MASK] afraid of schism ' within Catholic Church under "
#                 'pressure from US clergy',
#   'original_adv': 'not',
#   'scores': [{'score': 0.6379310488700867,
#               'sequence': "pope's afraid of schism'within catholic church "
#                           'under pressure from us clergy',
#               'token': 1055,
#               'token_str': 's'},
#              {'score': 0.029908649623394012,
#               'sequence': "pope'not afraid of schism'within catholic church "
#                           'under pressure from us clergy',
#               'token': 2025,
#               'token_str': 'not'},
#              {'score': 0.012588290497660637,
#               'sequence': "pope'tis afraid of schism'within catholic church "
#                           'under pressure from us clergy',
#               'token': 22320,
#               'token_str': 'tis'}],
#   'text_window': "Pope ' not afraid of schism '"},
#  {'hit_id': 'pcc_eng_29_108.6592_x1739914_14:5-6',
#   'masked_str': 'The Welsh outfit are [MASK] unbeaten in League',
#   'original_adv': 'currently',
#   'scores': [{'score': 0.6759222149848938,
#               'sequence': 'the welsh outfit are currently unbeaten in league',
#               'token': 2747,
#               'token_str': 'currently'},
#              {'score': 0.243729829788208,
#               'sequence': 'the welsh outfit are still unbeaten in league',
#               'token': 2145,
#               'token_str': 'still'},
#              {'score': 0.02490020915865898,
#               'sequence': 'the welsh outfit are now unbeaten in league',
#               'token': 2085,
#               'token_str': 'now'}],
#   'text_window': 'Welsh outfit are currently unbeaten in League'}]

# %%
selected_data = selected_data.sample(300) # HACK: #! temporary. REMOVE


def get_scores(masked, top_k=10):
    return {word_fill['token_str']: word_fill['score'] for word_fill in UNMASK(masked, top_k=top_k)}


def sum_lexcats(scores: dict, lex_dict: dict):
    results = pd.Series(scores).to_frame('score')
    # results.index.name = 'filler_str'
    # results = results.reset_index()
    lexcat_sums = pd.Series(dtype='float')
    for lex_type, lex_set in lex_dict.items():
        # return results.loc[results.index.isin(lex_set), 'score'].sum()
        lexcat_sums.loc[f'{lex_type}_total'] = results.loc[results.index.isin(
            lex_set), 'score'].sum().round(5)
    return lexcat_sums

# %%
score_df = selected_data.assign(scores=selected_data.masked.apply(get_scores, top_k=30))
score_df = score_df.join(score_df.scores.apply(sum_lexcats, lex_dict=ADV_SETS))
score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, pcc_eng_29_108.5498_x1738154_20:11-12 to pcc_eng_29_109.1591_x1742842_37:09-10
# Data columns (total 35 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   adv_form                 300 non-null    string
#  1   adj_form                 300 non-null    string
#  2   text_window              300 non-null    string
#  3   masked                   300 non-null    object
#  4   prev_word                300 non-null    object
#  5   next_word                300 non-null    object
#  6   scores                   300 non-null    object
#  7   sufficient_total         300 non-null    float64
#  8   min_threshold_total      300 non-null    float64
#  9   max_threshold_total      300 non-null    float64
#  10  moderate_total           300 non-null    float64
#  11  precise_total            300 non-null    float64
#  12  compare_total            300 non-null    float64
#  13  weak_intense_total       300 non-null    float64
#  14  meas_intense_total       300 non-null    float64
#  15  mod_intense_total        300 non-null    float64
#  16  good_intense_total       300 non-null    float64
#  17  epistemic_total          300 non-null    float64
#  18  serious_intense_total    300 non-null    float64
#  19  observable_total         300 non-null    float64
#  20  fear_intense_total       300 non-null    float64
#  21  taboo_intense_total      300 non-null    float64
#  22  absurd_intense_total     300 non-null    float64
#  23  crazy_intense_total      300 non-null    float64
#  24  disbelief_intense_total  300 non-null    float64
#  25  unease_intense_total     300 non-null    float64
#  26  excess_intense_total     300 non-null    float64
#  27  max_intense_total        300 non-null    float64
#  28  EDM_Morzycki_total       300 non-null    float64
#  29  Mmod_SoltWilson_total    300 non-null    float64
#  30  negative_total           300 non-null    float64
#  31  positive_total           300 non-null    float64
#  32  NPS_total                300 non-null    float64
#  33  PS_rescuer_total         300 non-null    float64
#  34  PPS_total                300 non-null    float64
# dtypes: float64(28), object(4), string(3)
# memory usage: 92.5+ KB

# %%
stats = score_df.describe().round(4).T.sort_values('mean', ascending=False)
stats
# Out:
#                          count    mean     std  min     25%     50%     75%  \
# weak_intense_total       300.0  0.1072  0.1435  0.0  0.0051  0.0531  0.1542
# sufficient_total         300.0  0.0723  0.1780  0.0  0.0000  0.0031  0.0473
# compare_total            300.0  0.0528  0.1588  0.0  0.0000  0.0037  0.0239
# PPS_total                300.0  0.0522  0.1050  0.0  0.0000  0.0142  0.0516
# Mmod_SoltWilson_total    300.0  0.0500  0.1051  0.0  0.0000  0.0113  0.0437
# PS_rescuer_total         300.0  0.0490  0.1387  0.0  0.0000  0.0067  0.0249
# mod_intense_total        300.0  0.0424  0.0884  0.0  0.0000  0.0088  0.0421
# negative_total           300.0  0.0254  0.0858  0.0  0.0000  0.0000  0.0133
# max_intense_total        300.0  0.0196  0.0577  0.0  0.0000  0.0000  0.0153
# meas_intense_total       300.0  0.0185  0.0594  0.0  0.0000  0.0000  0.0138
# positive_total           300.0  0.0155  0.0350  0.0  0.0000  0.0000  0.0158
# max_threshold_total      300.0  0.0127  0.0477  0.0  0.0000  0.0000  0.0081
# epistemic_total          300.0  0.0099  0.0232  0.0  0.0000  0.0000  0.0114
# EDM_Morzycki_total       300.0  0.0098  0.0341  0.0  0.0000  0.0000  0.0070
# moderate_total           300.0  0.0087  0.0294  0.0  0.0000  0.0000  0.0052
# disbelief_intense_total  300.0  0.0068  0.0170  0.0  0.0000  0.0000  0.0065
# fear_intense_total       300.0  0.0060  0.0195  0.0  0.0000  0.0000  0.0016
# min_threshold_total      300.0  0.0032  0.0151  0.0  0.0000  0.0000  0.0000
# excess_intense_total     300.0  0.0030  0.0115  0.0  0.0000  0.0000  0.0000
# taboo_intense_total      300.0  0.0027  0.0186  0.0  0.0000  0.0000  0.0000
# NPS_total                300.0  0.0016  0.0085  0.0  0.0000  0.0000  0.0000
# observable_total         300.0  0.0013  0.0051  0.0  0.0000  0.0000  0.0000
# good_intense_total       300.0  0.0010  0.0064  0.0  0.0000  0.0000  0.0000
# precise_total            300.0  0.0009  0.0071  0.0  0.0000  0.0000  0.0000
# absurd_intense_total     300.0  0.0006  0.0033  0.0  0.0000  0.0000  0.0000
# serious_intense_total    300.0  0.0005  0.0025  0.0  0.0000  0.0000  0.0000
# crazy_intense_total      300.0  0.0002  0.0015  0.0  0.0000  0.0000  0.0000
# unease_intense_total     300.0  0.0000  0.0000  0.0  0.0000  0.0000  0.0000
#
#                             max
# weak_intense_total       0.9829
# sufficient_total         0.9852
# compare_total            0.9922
# PPS_total                0.9005
# Mmod_SoltWilson_total    0.9005
# PS_rescuer_total         0.9786
# mod_intense_total        0.7837
# negative_total           0.8354
# max_intense_total        0.5966
# meas_intense_total       0.6993
# positive_total           0.2761
# max_threshold_total      0.5937
# epistemic_total          0.2644
# EDM_Morzycki_total       0.4585
# moderate_total           0.2646
# disbelief_intense_total  0.1872
# fear_intense_total       0.1616
# min_threshold_total      0.1311
# excess_intense_total     0.1222
# taboo_intense_total      0.2757
# NPS_total                0.1106
# observable_total         0.0392
# good_intense_total       0.0888
# precise_total            0.1004
# absurd_intense_total     0.0395
# serious_intense_total    0.0270
# crazy_intense_total      0.0189
# unease_intense_total     0.0000

# %%
adv_sets = pd.Series(dtype='string')
for adv_cat in stats.index:
    adv_cat = adv_cat.replace('_total', '')
    adv_sets[adv_cat] = ', '.join(ADV_SETS[adv_cat])
adv_sets = adv_sets.to_frame('members')
adv_sets.index.name = 'adv category'
pd.set_option('display.max_colwidth', 100)
adv_sets
# Out:
#                                                                                                                members
# adv category
# weak_intense                                                                                       quite, very, really
# sufficient                                                                                             enough, too, so
# compare                                                                     comparatively, less, as, most, more, least
# PPS                                                            kinda, pretty, sorta, utterly, somewhat, rather, fairly
# Mmod_SoltWilson                                                         kinda, pretty, sorta, somewhat, rather, fairly
# PS_rescuer                                                                                     too, only, enough, even
# mod_intense                                                     entirely, notably, particularly, extremely, especially
# negative                                                                  never, rarely, scarcely, not, barely, hardly
# max_intense                                                         perfectly, totally, maximally, completely, utterly
# meas_intense                                         strongly, super, deeply, hugely, widely, greatly, highly, largely
# positive                                       often, some, always, typically, usually, commonly, normally, frequently
# max_threshold                                                                             perfectly, fully, completely
# epistemic          honestly, positively, certainly, certifiably, definitely, genuinely, veritably, surely, verifiab...
# EDM_Morzycki       straight-up, positively, simply, outright, balls-out, just, full-on, absolutely, out-and-out, do...
# moderate           tolerably, modestly, supposedly, dubiously, weakly, reasonably, acceptably, underwhelmingly, par...
# disbelief_intense                         inutterably, unbelievably, incredibly, impossibly, unfathomably, unspeakably
# fear_intense       dreadfully, creepily, alarmingly, terribly, eerily, frightfully, horribly, scarily, spookily, da...
# min_threshold                                                                                      slightly, partially
# excess_intense                            overwhelmingly, intolerably, overly, unacceptably, inordinately, excessively
# taboo_intense      morbidly, insatiably, violently, miserably, voraciously, fatally, fucking, maddeningly, disgusti...
# NPS                                                                                                 ever, exactly, yet
# observable                                                                       obviously, clearly, openly, blatantly
# good_intense       gloriously, impressively, sensationally, marvelously, heartily, fabulously, wonderfully, delicio...
# precise                                                                                             precisely, exactly
# absurd_intense          freakily, peculiarly, weirdly, bizarrely, strangely, ridiculously, absurdly, oddly, freakishly
# serious_intense                                                            seriously, sincerely, earnestly, hopelessly
# crazy_intense                                                                          crazy, crazily, insanely, madly
# unease_intense                                                  disconcertingly, worryingly, disturbingly, troublingly

# %%
score_df.sample(15)
# Out:
#                                            adv_form     adj_form  \
# hit_id
# pcc_eng_29_108.2595_x1733448_13:3-4             not    necessary
# pcc_eng_29_108.3249_x1734511_51:11-12           not        green
# pcc_eng_29_109.5621_x1749274_36:10-11          more    pertinent
# pcc_eng_29_109.3318_x1745597_08:7-8             too       simple
# pcc_eng_29_109.2591_x1744427_01:3-4             not         Fair
# pcc_eng_29_108.1997_x1732436_04:3-4            Just   delightful
# pcc_eng_29_109.6613_x1750903_10:1-2            Also         good
# pcc_eng_29_109.3677_x1746172_17:1-2            Very        amiss
# pcc_eng_29_109.0705_x1741471_024:3-4      perfectly        valid
# pcc_eng_29_109.4172_x1746961_03:2-3    ridiculously  over-priced
# pcc_eng_29_109.6365_x1750493_53:3-4             n't         rich
# pcc_eng_29_109.3911_x1746538_126:7-8           very       likely
# pcc_eng_29_109.2216_x1743854_28:12-13          very      excited
# pcc_eng_29_109.4543_x1747577_3:12-13             as          big
# pcc_eng_29_109.4336_x1747248_11:7-8          highly    sensitive
#
#                                                                            text_window  \
# hit_id
# pcc_eng_29_108.2595_x1733448_13:3-4               This is not necessary when using the
# pcc_eng_29_108.3249_x1734511_51:11-12                    battery is orange not green .
# pcc_eng_29_109.5621_x1749274_36:10-11  debate and elicits more pertinent information .
# pcc_eng_29_109.3318_x1745597_08:7-8                         be putting it too simple .
# pcc_eng_29_109.2591_x1744427_01:3-4                                Its Just not Fair !
# pcc_eng_29_108.1997_x1732436_04:3-4                           Edit : Just delightful .
# pcc_eng_29_109.6613_x1750903_10:1-2                       Also good for flanking sunny
# pcc_eng_29_109.3677_x1746172_17:1-2                                       Very amiss .
# pcc_eng_29_109.0705_x1741471_024:3-4                This is perfectly valid JSON , per
# pcc_eng_29_109.4172_x1746961_03:2-3      From ridiculously over-priced watches to high
# pcc_eng_29_109.6365_x1750493_53:3-4                  Fisher was n't rich or anything .
# pcc_eng_29_109.3911_x1746538_126:7-8                      think they are very likely .
# pcc_eng_29_109.2216_x1743854_28:12-13            that everyone 's very excited about .
# pcc_eng_29_109.4543_x1747577_3:12-13                       binaries got twice as big .
# pcc_eng_29_109.4336_x1747248_11:7-8    and careers for highly sensitive persons ( HSPs
#
#                                                                                                                                 masked  \
# hit_id
# pcc_eng_29_108.2595_x1733448_13:3-4                                        This is [MASK] necessary when using the dynamic framework .
# pcc_eng_29_108.3249_x1734511_51:11-12                                  The sunshine on the plug in to battery is orange [MASK] green .
# pcc_eng_29_109.5621_x1749274_36:10-11  Some observers believe this format stimulates debate and elicits [MASK] pertinent information .
# pcc_eng_29_109.3318_x1745597_08:7-8                                                       But that would be putting it [MASK] simple .
# pcc_eng_29_109.2591_x1744427_01:3-4                                                                             Its Just [MASK] Fair !
# pcc_eng_29_108.1997_x1732436_04:3-4                                                                         Edit : [MASK] delightful .
# pcc_eng_29_109.6613_x1750903_10:1-2                                                [MASK] good for flanking sunny doorways or arbors .
# pcc_eng_29_109.3677_x1746172_17:1-2                                                                                     [MASK] amiss .
# pcc_eng_29_109.0705_x1741471_024:3-4                                                   This is [MASK] valid JSON , per the JSON spec :
# pcc_eng_29_109.4172_x1746961_03:2-3                                     From [MASK] over-priced watches to high class four wheeled ...
# pcc_eng_29_109.6365_x1750493_53:3-4                                                               Fisher was [MASK] rich or anything .
# pcc_eng_29_109.3911_x1746538_126:7-8                                                           Well , I think they are [MASK] likely .
# pcc_eng_29_109.2216_x1743854_28:12-13                    " It 's a different type of situation that everyone 's [MASK] excited about .
# pcc_eng_29_109.4543_x1747577_3:12-13                      When Apple moved to universal binaries , the binaries got twice [MASK] big .
# pcc_eng_29_109.4336_x1747248_11:7-8                                  The best jobs and careers for [MASK] sensitive persons ( HSPs ) .
#
#                                       prev_word    next_word  \
# hit_id
# pcc_eng_29_108.2595_x1733448_13:3-4          is         when
# pcc_eng_29_108.3249_x1734511_51:11-12    orange            .
# pcc_eng_29_109.5621_x1749274_36:10-11   elicits  information
# pcc_eng_29_109.3318_x1745597_08:7-8          it            .
# pcc_eng_29_109.2591_x1744427_01:3-4        Just            !
# pcc_eng_29_108.1997_x1732436_04:3-4           :            .
# pcc_eng_29_109.6613_x1750903_10:1-2           .          for
# pcc_eng_29_109.3677_x1746172_17:1-2           .            .
# pcc_eng_29_109.0705_x1741471_024:3-4         is         JSON
# pcc_eng_29_109.4172_x1746961_03:2-3        From      watches
# pcc_eng_29_109.6365_x1750493_53:3-4         was           or
# pcc_eng_29_109.3911_x1746538_126:7-8        are            .
# pcc_eng_29_109.2216_x1743854_28:12-13        's        about
# pcc_eng_29_109.4543_x1747577_3:12-13      twice            .
# pcc_eng_29_109.4336_x1747248_11:7-8         for      persons
#
#                                                                                                                                     scores  \
# hit_id
# pcc_eng_29_108.2595_x1733448_13:3-4    {'usually': 0.11686263233423233, 'not': 0.09931281954050064, 'therefore': 0.07445567101240158, '...
# pcc_eng_29_108.3249_x1734511_51:11-12  {'or': 0.3573743999004364, 'and': 0.1321895718574524, '-': 0.1184810921549797, '/': 0.1012193858...
# pcc_eng_29_109.5621_x1749274_36:10-11  {'more': 0.26272404193878174, 'much': 0.04430467635393143, 'increasingly': 0.026463249698281288,...
# pcc_eng_29_109.3318_x1745597_08:7-8    {'too': 0.2638441026210785, 'so': 0.13080938160419464, 'as': 0.09529045224189758, 'pretty': 0.06...
# pcc_eng_29_109.2591_x1744427_01:3-4    {'not': 0.07358408719301224, 'too': 0.0585193894803524, 'a': 0.04666743054986, 'plain': 0.044469...
# pcc_eng_29_108.1997_x1732436_04:3-4    {'roger': 0.00421407213434577, 'jonathan': 0.0041914028115570545, '#': 0.0035584899596869946, 't...
# pcc_eng_29_109.6613_x1750903_10:1-2    {'especially': 0.11291126906871796, 'particularly': 0.06442534178495407, 'not': 0.05678001046180...
# pcc_eng_29_109.3677_x1746172_17:1-2    {'bitter': 0.04257819801568985, 'never': 0.03674129769206047, 'no': 0.029797472059726715, 'not':...
# pcc_eng_29_109.0705_x1741471_024:3-4   {'a': 0.6661784052848816, 'the': 0.1116970106959343, 'another': 0.0297965370118618, 'one': 0.010...
# pcc_eng_29_109.4172_x1746961_03:2-3    {'inexpensive': 0.1144171804189682, 'cheap': 0.10992474108934402, 'luxury': 0.08209829032421112,...
