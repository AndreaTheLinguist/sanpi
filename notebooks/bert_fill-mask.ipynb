# %%
# Install `transformers` from master
# ! 👇 apparently this isn't really python code. It only works on jupyter kernal
# %pip install transformers
# %pip list | grep -E 'transformers|tokenizers'
# transformers version at notebook update --- 4.32.1 #//2.11.0
# tokenizers version at notebook update ---  0.13.3 #//0.8.0rc1

import csv
from pathlib import Path
from pprint import pprint

import pandas as pd
import torch
from transformers import (AutoModel, AutoModelForMaskedLM, AutoTokenizer,
                          pipeline)
from utils.LexicalCategories import ADJ_BY_SCALE as ADJ_SETS
from utils.LexicalCategories import ADV_OF_INTEREST as ADV_SETS

pd.set_option('display.max_colwidth', 70)
pd.set_option("display.precision", 5)
MASK_POS = 'adv'
MODEL = 'distilbert-base-uncased'
UNMASK = pipeline('fill-mask', model=MODEL, tokenizer=MODEL, framework='pt')
HITS_PATH = Path(
    '/share/compling/data/sanpi/4_post-processed/RBXadj/bigrams_frq-thr0-01p.25f.pkl.gz')
FRQ_FILTER = Path(
    '/share/compling/projects/sanpi/demo/data/4_post-processed/RBxpos/hit-index_thr0-001p.1f.txt')
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-2-fd265fb0f3bc> in <module>
#      21 MASK_POS = 'adv'
#      22 MODEL = 'distilbert-base-uncased'
# ---> 23 UNMASK = pipeline('fill-mask', model=MODEL, tokenizer=MODEL, framework='pt')
#      24 HITS_PATH = Path(
#      25     '/share/compling/data/sanpi/4_post-processed/RBXadj/bigrams_frq-thr0-01p.25f.pkl.gz')
#
# ~/.local/lib/python3.8/site-packages/transformers/pipelines/__init__.py in pipeline(task, model, config, tokenizer, feature_extractor, image_processor, framework, revision, use_fast, token, device, device_map, torch_dtype, trust_remote_code, model_kwargs, pipeline_class, **kwargs)
#     805     if isinstance(model, str) or framework is None:
#     806         model_classes = {"tf": targeted_task["tf"], "pt": targeted_task["pt"]}
# --> 807         framework, model = infer_framework_load_model(
#     808             model,
#     809             model_classes=model_classes,
#
# ~/.local/lib/python3.8/site-packages/transformers/pipelines/base.py in infer_framework_load_model(model, config, model_classes, task, framework, **model_kwargs)
#     265
#     266             try:
# --> 267                 model = model_class.from_pretrained(model, **kwargs)
#     268                 if hasattr(model, "eval"):
#     269                     model = model.eval()
#
# ~/.local/lib/python3.8/site-packages/transformers/models/auto/auto_factory.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     514         elif type(config) in cls._model_mapping.keys():
#     515             model_class = _get_model_class(config, cls._model_mapping)
# --> 516             return model_class.from_pretrained(
#     517                 pretrained_model_name_or_path, *model_args, config=config, **hub_kwargs, **kwargs
#     518             )
#
# ~/.local/lib/python3.8/site-packages/transformers/modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, config, cache_dir, ignore_mismatched_sizes, force_download, local_files_only, token, revision, use_safetensors, *model_args, **kwargs)
#    2803             if not is_sharded and state_dict is None:
#    2804                 # Time to load the checkpoint
# -> 2805                 state_dict = load_state_dict(resolved_archive_file)
#    2806
#    2807             # set dtype to instantiate the model under:
#
# ~/.local/lib/python3.8/site-packages/transformers/modeling_utils.py in load_state_dict(checkpoint_file)
#     467                 f"Conversion from a {metadata['format']} safetensors archive to PyTorch is not implemented yet."
#     468             )
# --> 469         return safe_load_file(checkpoint_file)
#     470     try:
#     471         if (
#
# ~/.local/lib/python3.8/site-packages/safetensors/torch.py in load_file(filename, device)
#     308     with safe_open(filename, framework="pt", device=device) as f:
#     309         for k in f.keys():
# --> 310             result[k] = f.get_tensor(k)
#     311     return result
#     312
#
# RuntimeError: shape '[768]' is invalid for input of size 96

# %% [markdown]
#  ## Load sample hit table as data

# %%
def _load_hits(dpath=HITS_PATH):

    if '.csv' in dpath.suffixes:
        data = pd.read_csv(dpath)
        data = data.set_index('hit_id').convert_dtypes()

    elif dpath.endswith('pkl.gz'):
        data = pd.read_pickle(dpath)

    print('data loaded')
    pprint(data.columns)
    

    return data

all_data = _load_hits()
all_data.sample(3)
# Out:
# data loaded
# Index(['colloc', 'sent_text', 'adv_form', 'adj_form', 'hit_text',
#        'text_window', 'sent_id', 'match_id', 'colloc_id', 'token_str',
#        'lemma_str', 'context_prev_id', 'context_prev_sent', 'context_next_id',
#        'context_next_sent', 'adv_lemma', 'adj_lemma', 'adv_index', 'adj_index',
#        'dep_mod', 'json_source', 'utt_len', 'category'],
#       dtype='object')
#                                                   colloc  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  particularly_hard
# pcc_eng_29_109.0555_x1741207_081:7-8          very_tight
# pcc_eng_29_108.6294_x1739422_07:6-7         more_glaring
#
#                                                                                                    sent_text  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  In a blog post Wednesday, she wrote about a particularly hard nigh...
# pcc_eng_29_109.0555_x1741207_081:7-8   Puhakka also had Gunderson in a very tight looking anaconda choke ...
# pcc_eng_29_108.6294_x1739422_07:6-7                                         Here is one of the more glaring:
#
#                                            adv_form adj_form  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  particularly     hard
# pcc_eng_29_109.0555_x1741207_081:7-8           very    tight
# pcc_eng_29_108.6294_x1739422_07:6-7            more  glaring
#
#                                                 hit_text  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  particularly hard
# pcc_eng_29_109.0555_x1741207_081:7-8          very tight
# pcc_eng_29_108.6294_x1739422_07:6-7         more glaring
#
#                                                                                  text_window  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  wrote about a particularly hard night she experienced
# pcc_eng_29_109.0555_x1741207_081:7-8        Gunderson in a very tight looking anaconda choke
# pcc_eng_29_108.6294_x1739422_07:6-7                                one of the more glaring :
#
#                                                                 sent_id  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12   pcc_eng_29_109.4743_x1747869_06
# pcc_eng_29_109.0555_x1741207_081:7-8   pcc_eng_29_109.0555_x1741207_081
# pcc_eng_29_108.6294_x1739422_07:6-7     pcc_eng_29_108.6294_x1739422_07
#
#                                       match_id  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12    11-12
# pcc_eng_29_109.0555_x1741207_081:7-8       7-8
# pcc_eng_29_108.6294_x1739422_07:6-7        6-7
#
#                                                                    colloc_id  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  pcc_eng_29_109.4743_x1747869_06:11-12
# pcc_eng_29_109.0555_x1741207_081:7-8    pcc_eng_29_109.0555_x1741207_081:7-8
# pcc_eng_29_108.6294_x1739422_07:6-7      pcc_eng_29_108.6294_x1739422_07:6-7
#
#                                                                                                    token_str  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  In a blog post Wednesday , she wrote about a particularly hard nig...
# pcc_eng_29_109.0555_x1741207_081:7-8   Puhakka also had Gunderson in a very tight looking anaconda choke ...
# pcc_eng_29_108.6294_x1739422_07:6-7                                        Here is one of the more glaring :
#
#                                        ...                   context_next_id  \
# hit_id                                 ...
# pcc_eng_29_109.4743_x1747869_06:11-12  ...   pcc_eng_29_109.4743_x1747869_07
# pcc_eng_29_109.0555_x1741207_081:7-8   ...  pcc_eng_29_109.0555_x1741207_082
# pcc_eng_29_108.6294_x1739422_07:6-7    ...   pcc_eng_29_108.6294_x1739422_08
#
#                                       context_next_sent     adv_lemma  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12              <NA>  particularly
# pcc_eng_29_109.0555_x1741207_081:7-8               <NA>          very
# pcc_eng_29_108.6294_x1739422_07:6-7                <NA>          more
#
#                                       adj_lemma adv_index adj_index  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12      hard        10        11
# pcc_eng_29_109.0555_x1741207_081:7-8      tight         6         7
# pcc_eng_29_108.6294_x1739422_07:6-7     glaring         5         6
#
#                                                                                                      dep_mod  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': ...
# pcc_eng_29_109.0555_x1741207_081:7-8   {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': ...
# pcc_eng_29_108.6294_x1739422_07:6-7    {'node': 'mod', 'contiguous': True, 'relation': 'advmod', 'head': ...
#
#                                                                                                  json_source  \
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12  /share/compling/projects/sanpi/demo/data/1_json_grew-matches/RBXad...
# pcc_eng_29_109.0555_x1741207_081:7-8   /share/compling/projects/sanpi/demo/data/1_json_grew-matches/RBXad...
# pcc_eng_29_108.6294_x1739422_07:6-7    /share/compling/projects/sanpi/demo/data/1_json_grew-matches/RBXad...
#
#                                        utt_len category
# hit_id
# pcc_eng_29_109.4743_x1747869_06:11-12       24   RBXadj
# pcc_eng_29_109.0555_x1741207_081:7-8        22   RBXadj
# pcc_eng_29_108.6294_x1739422_07:6-7          8   RBXadj
#
# [3 rows x 23 columns]

# %% [markdown]
#  Apply filters to loaded data, based on frequency as well as manual criteria

# %%
def _filter_hits(hits_data):
    # trim data
    filter_hi = pd.read_csv(FRQ_FILTER).squeeze()
    df = hits_data.loc[filter_hi,
                       ['adv_form', 'adj_form', 'adv_lemma', 'adj_lemma',
                        'adv_index', 'adj_index', 'token_str', 'text_window']]
    df = df.assign(
        prev_prev_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[max(-1,df.adv_index[ix] - 2)]),
        prev_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[max(-1,df.adv_index[ix] - 1)]),
        next_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[min(len(df.token_str[ix].split())-1, df.adj_index[ix] + 1)]),
        next_next_word=df.index.to_series().apply(
            lambda ix: df.token_str[ix].split()[min(len(df.token_str[ix].split())-1, df.adj_index[ix] + 2)])
        )
    df.loc[df.prev_word == df.prev_prev_word, 'prev_prev_word'] = ''
    df.loc[df.prev_word == df.adv_form, 'prev_word'] = ''
    df.loc[df.next_word == df.next_next_word, 'next_next_word'] = ''
    df.loc[df.next_word == df.adj_form, 'next_word'] = ''
    manual_criteria = (
        # limit to `token_str` values with no more than 14 spaces ≈ max 15 words
        (df.token_str.str.count(' ') <= 14)
        # NOTE: 'many', 'much' & 'enough' have abnormal syntactic patterns
        & (~df.adv_lemma.str.lower().isin(('enough', 'how', 'much', 'most')))
        & (~df.adj_lemma.str.lower().isin(('many', 'more', 'much', 'enough')))
        # have issues filling position following "much" and "more"--they don't wind up being adverbs but comparative adjectives
        & (~df.prev_word.str.lower().isin(['more', 'much', 'as']))
        & (~df.next_word.str.lower().isin(['as']))
    )
    df = df.loc[manual_criteria, :]

    return df

data = _filter_hits(all_data)
data.sample(1).T
# Out:
# hit_id                                 pcc_eng_29_108.2074_x1732562_074:11-12
# adv_form                                                            extremely
# adj_form                                                              pleased
# adv_lemma                                                           extremely
# adj_lemma                                                             pleased
# adv_index                                                                  10
# adj_index                                                                  11
# token_str       Hi Alan , it looks really lovely and I 'm extremely pleased .
# text_window                                      and I 'm extremely pleased .
# prev_prev_word                                                              I
# prev_word                                                                  'm
# next_word                                                                   .
# next_next_word

# %%
print('Adjective lemmas remaining, in order of frequency:')
print(data.value_counts('adj_lemma').to_frame('tokens remaining').to_markdown(floatfmt=',.0f'))
# Out:
# Adjective lemmas remaining, in order of frequency:
# | adj_lemma        |   tokens remaining |
# |:-----------------|-------------------:|
# | good             |                260 |
# | important        |                118 |
# | easy             |                109 |
# | available        |                105 |
# | different        |                103 |
# | bad              |                 70 |
# | sure             |                 64 |
# | happy            |                 62 |
# | difficult        |                 57 |
# | true             |                 47 |
# | simple           |                 45 |
# | big              |                 45 |
# | cool             |                 45 |
# | high             |                 44 |
# | great            |                 41 |
# | excited          |                 40 |
# | nice             |                 38 |
# | hard             |                 38 |
# | interesting      |                 38 |
# | popular          |                 37 |
# | clear            |                 36 |
# | close            |                 35 |
# | possible         |                 33 |
# | right            |                 33 |
# | worth            |                 32 |
# | interested       |                 30 |
# | special          |                 30 |
# | fun              |                 29 |
# | new              |                 28 |
# | expensive        |                 27 |
# | low              |                 27 |
# | alone            |                 26 |
# | few              |                 26 |
# | proud            |                 25 |
# | small            |                 25 |
# | large            |                 24 |
# | amazing          |                 24 |
# | dangerous        |                 23 |
# | effective        |                 23 |
# | late             |                 22 |
# | little           |                 22 |
# | free             |                 21 |
# | pleased          |                 21 |
# | beautiful        |                 21 |
# | open             |                 21 |
# | ready            |                 21 |
# | helpful          |                 21 |
# | comfortable      |                 20 |
# | strong           |                 20 |
# | powerful         |                 20 |
# | wrong            |                 20 |
# | impressed        |                 20 |
# | likely           |                 20 |
# | impressive       |                 19 |
# | serious          |                 19 |
# | necessary        |                 19 |
# | complex          |                 18 |
# | common           |                 18 |
# | young            |                 18 |
# | funny            |                 18 |
# | short            |                 18 |
# | responsible      |                 18 |
# | long             |                 18 |
# | hot              |                 18 |
# | awesome          |                 18 |
# | busy             |                 18 |
# | cheap            |                 17 |
# | cute             |                 17 |
# | glad             |                 17 |
# | complicated      |                 16 |
# | positive         |                 16 |
# | useful           |                 16 |
# | sweet            |                 15 |
# | exciting         |                 15 |
# | unique           |                 15 |
# | soft             |                 15 |
# | obvious          |                 15 |
# | perfect          |                 14 |
# | surprising       |                 14 |
# | successful       |                 14 |
# | surprised        |                 13 |
# | satisfied        |                 13 |
# | fine             |                 13 |
# | active           |                 13 |
# | sensitive        |                 13 |
# | similar          |                 13 |
# | disappointed     |                 13 |
# | conservative     |                 13 |
# | safe             |                 13 |
# | rare             |                 12 |
# | friendly         |                 12 |
# | tough            |                 12 |
# | real             |                 12 |
# | delicious        |                 12 |
# | afraid           |                 12 |
# | able             |                 12 |
# | impossible       |                 12 |
# | wonderful        |                 12 |
# | aware            |                 12 |
# | worried          |                 11 |
# | professional     |                 11 |
# | sad              |                 11 |
# | lucky            |                 11 |
# | normal           |                 11 |
# | stupid           |                 11 |
# | cold             |                 11 |
# | productive       |                 11 |
# | enjoyable        |                 11 |
# | rich             |                 10 |
# | challenging      |                 10 |
# | detailed         |                 10 |
# | qualified        |                 10 |
# | early            |                 10 |
# | fast             |                 10 |
# | unusual          |                 10 |
# | affordable       |                 10 |
# | stressful        |                 10 |
# | visible          |                 10 |
# | tired            |                 10 |
# | specific         |                 10 |
# | realistic        |                  9 |
# | quiet            |                  9 |
# | confident        |                  9 |
# | poor             |                  9 |
# | personal         |                  9 |
# | dead             |                  9 |
# | slow             |                  9 |
# | light            |                  9 |
# | intense          |                  9 |
# | accurate         |                  9 |
# | hungry           |                  9 |
# | valid            |                  9 |
# | grateful         |                  9 |
# | frustrating      |                  9 |
# | fair             |                  9 |
# | familiar         |                  9 |
# | related          |                  9 |
# | aggressive       |                  9 |
# | significant      |                  9 |
# | sorry            |                  8 |
# | less             |                  8 |
# | nervous          |                  8 |
# | strange          |                  8 |
# | curious          |                  8 |
# | dry              |                  8 |
# | old              |                  8 |
# | accessible       |                  8 |
# | correct          |                  8 |
# | human            |                  8 |
# | bitter           |                  8 |
# | consistent       |                  8 |
# | essential        |                  8 |
# | careful          |                  8 |
# | first            |                  8 |
# | competitive      |                  8 |
# | scared           |                  8 |
# | talented         |                  7 |
# | concerned        |                  7 |
# | customizable     |                  7 |
# | upset            |                  7 |
# | dark             |                  7 |
# | loud             |                  7 |
# | kind             |                  7 |
# | compact          |                  7 |
# | solid            |                  7 |
# | dull             |                  7 |
# | acceptable       |                  7 |
# | versatile        |                  7 |
# | entertaining     |                  7 |
# | gorgeous         |                  7 |
# | willing          |                  7 |
# | appealing        |                  7 |
# | least            |                  7 |
# | attractive       |                  7 |
# | clean            |                  7 |
# | secure           |                  7 |
# | magical          |                  6 |
# | sufficient       |                  6 |
# | overwhelming     |                  6 |
# | optimistic       |                  6 |
# | crazy            |                  6 |
# | critical         |                  6 |
# | noticeable       |                  6 |
# | basic            |                  6 |
# | welcome          |                  6 |
# | weak             |                  6 |
# | stable           |                  6 |
# | pleasant         |                  6 |
# | straightforward  |                  6 |
# | keen             |                  6 |
# | shocked          |                  6 |
# | intrigue         |                  6 |
# | volatile         |                  6 |
# | guilty           |                  6 |
# | relevant         |                  6 |
# | responsive       |                  6 |
# | valuable         |                  6 |
# | honest           |                  6 |
# | rewarding        |                  6 |
# | painful          |                  6 |
# | heavy            |                  6 |
# | present          |                  6 |
# | appropriate      |                  6 |
# | awful            |                  6 |
# | bizarre          |                  6 |
# | compatible       |                  6 |
# | tasty            |                  6 |
# | angry            |                  6 |
# | bright           |                  6 |
# | dramatic         |                  5 |
# | tight            |                  5 |
# | alive            |                  5 |
# | complete         |                  5 |
# | spectacular      |                  5 |
# | authentic        |                  5 |
# | involved         |                  5 |
# | reliable         |                  5 |
# | inclined         |                  5 |
# | smart            |                  5 |
# | false            |                  5 |
# | sharp            |                  5 |
# | disappointing    |                  5 |
# | vulnerable       |                  5 |
# | predictable      |                  5 |
# | lonely           |                  5 |
# | scary            |                  5 |
# | standard         |                  5 |
# | deep             |                  5 |
# | white            |                  5 |
# | accountable      |                  5 |
# | fresh            |                  5 |
# | illegal          |                  5 |
# | viable           |                  5 |
# | applicable       |                  5 |
# | permanent        |                  5 |
# | unnecessary      |                  5 |
# | flexible         |                  5 |
# | sick             |                  5 |
# | own              |                  5 |
# | fortunate        |                  5 |
# | full             |                  5 |
# | empty            |                  5 |
# | annoying         |                  5 |
# | confused         |                  5 |
# | creative         |                  5 |
# | clever           |                  5 |
# | violent          |                  5 |
# | ok               |                  5 |
# | silly            |                  5 |
# | apparent         |                  4 |
# | prevalent        |                  4 |
# | glamorous        |                  4 |
# | warm             |                  4 |
# | smooth           |                  4 |
# | pleasing         |                  4 |
# | shocking         |                  4 |
# | inspiring        |                  4 |
# | superior         |                  4 |
# | emotional        |                  4 |
# | humble           |                  4 |
# | hardy            |                  4 |
# | remarkable       |                  4 |
# | durable          |                  4 |
# | certain          |                  4 |
# | handy            |                  4 |
# | last             |                  4 |
# | inaccurate       |                  4 |
# | inconvenient     |                  4 |
# | incredible       |                  4 |
# | green            |                  4 |
# | compelling       |                  4 |
# | disturbing       |                  4 |
# | fascinating      |                  4 |
# | dependent        |                  4 |
# | addictive        |                  4 |
# | meaningful       |                  4 |
# | gentle           |                  4 |
# | welcoming        |                  4 |
# | miserable        |                  4 |
# | damaging         |                  4 |
# | mysterious       |                  4 |
# | frightening      |                  4 |
# | negative         |                  4 |
# | skeptical        |                  4 |
# | surreal          |                  4 |
# | thin             |                  4 |
# | okay             |                  4 |
# | wide             |                  4 |
# | ordinary         |                  4 |
# | breathtaking     |                  4 |
# | terrible         |                  4 |
# | flat             |                  4 |
# | controversial    |                  4 |
# | plain            |                  4 |
# | strict           |                  4 |
# | memorable        |                  4 |
# | subtle           |                  4 |
# | boring           |                  4 |
# | delighted        |                  4 |
# | legal            |                  4 |
# | fundamental      |                  4 |
# | depressed        |                  4 |
# | temporary        |                  4 |
# | uncomfortable    |                  4 |
# | excellent        |                  4 |
# | limited          |                  4 |
# | shallow          |                  4 |
# | healthy          |                  4 |
# | satisfying       |                  4 |
# | ugly             |                  4 |
# | typical          |                  4 |
# | mad              |                  4 |
# | wet              |                  3 |
# | generous         |                  3 |
# | feminine         |                  3 |
# | harsh            |                  3 |
# | general          |                  3 |
# | global           |                  3 |
# | formal           |                  3 |
# | weird            |                  3 |
# | fragile          |                  3 |
# | vital            |                  3 |
# | frequent         |                  3 |
# | ridiculous       |                  3 |
# | windy            |                  3 |
# | unknown          |                  3 |
# | horrible         |                  3 |
# | live             |                  3 |
# | reasonable       |                  3 |
# | minimal          |                  3 |
# | modern           |                  3 |
# | transparent      |                  3 |
# | sexy             |                  3 |
# | threatening      |                  3 |
# | numerous         |                  3 |
# | obsessed         |                  3 |
# | thick            |                  3 |
# | original         |                  3 |
# | outstanding      |                  3 |
# | uncharted        |                  1 |
# | advantaged       |                  1 |
# | uncommon         |                  1 |
# | suspenseful      |                  1 |
# | universal        |                  1 |
# | suspect          |                  1 |
# | addicted         |                  1 |
# | unstoppable      |                  1 |
# | authoritarian    |                  1 |
# | straight         |                  1 |
# | stoked           |                  1 |
# | stilted          |                  1 |
# | sticky           |                  1 |
# | stellar          |                  1 |
# | untouched        |                  1 |
# | untrue           |                  1 |
# | acoustic         |                  1 |
# | static           |                  1 |
# | troubling        |                  1 |
# | acidic           |                  1 |
# | upsetting        |                  1 |
# | urban            |                  1 |
# | awake            |                  1 |
# | sporadic         |                  1 |
# | baffling         |                  1 |
# | usable           |                  1 |
# | specious         |                  1 |
# | accommodating    |                  1 |
# | bankrupt         |                  1 |
# | utopian          |                  1 |
# | sound            |                  1 |
# | soulful          |                  1 |
# | attuned          |                  1 |
# | stretchable      |                  1 |
# | attentive        |                  1 |
# | unprecedented    |                  1 |
# | unlawful         |                  1 |
# | apologetic       |                  1 |
# | apt              |                  1 |
# | adaptive         |                  1 |
# | unnerving        |                  1 |
# | unnoticed        |                  1 |
# | sure-handed      |                  1 |
# | armed            |                  1 |
# | unpleasant       |                  1 |
# | unpopular        |                  1 |
# | superb           |                  1 |
# | such             |                  1 |
# | stringent        |                  1 |
# | ashamed          |                  1 |
# | asleep           |                  1 |
# | unpredictable    |                  1 |
# | subdued          |                  1 |
# | stylish          |                  1 |
# | astonish         |                  1 |
# | adaptable        |                  1 |
# | unreliable       |                  1 |
# | unsatisfied      |                  1 |
# | unscathed        |                  1 |
# | unstable         |                  1 |
# | far-fetched      |                  1 |
# | conducive        |                  1 |
# | rigorous         |                  1 |
# | infallible       |                  1 |
# | informal         |                  1 |
# | divine           |                  1 |
# | innocent         |                  1 |
# | diverse          |                  1 |
# | insecure         |                  1 |
# | insidious        |                  1 |
# | insightful       |                  1 |
# | divergent        |                  1 |
# | inspirational    |                  1 |
# | distressed       |                  1 |
# | institutional    |                  1 |
# | insurmountable   |                  1 |
# | intact           |                  1 |
# | intellectual     |                  1 |
# | intelligent      |                  1 |
# | infinite         |                  1 |
# | inevitable       |                  1 |
# | dishonest        |                  1 |
# | individual       |                  1 |
# | implausible      |                  1 |
# | dumb             |                  1 |
# | inaccessible     |                  1 |
# | downloadable     |                  1 |
# | inadequate       |                  1 |
# | inappropriate    |                  1 |
# | incapable        |                  1 |
# | doubtful         |                  1 |
# | inclusive        |                  1 |
# | incompetent      |                  1 |
# | incomplete       |                  1 |
# | inconceivable    |                  1 |
# | double           |                  1 |
# | incorrect        |                  1 |
# | divisive         |                  1 |
# | distinctive      |                  1 |
# | internal         |                  1 |
# | imperfect        |                  1 |
# | determined       |                  1 |
# | destructive      |                  1 |
# | legible          |                  1 |
# | lethargic        |                  1 |
# | life-threatening |                  1 |
# | desert           |                  1 |
# | depressing       |                  1 |
# | democratic       |                  1 |
# | liquid           |                  1 |
# | literal          |                  1 |
# | literate         |                  1 |
# | demand           |                  1 |
# | cordial          |                  1 |
# | onerous          |                  1 |
# | omnipresent      |                  1 |
# | credible         |                  1 |
# | nutritious       |                  1 |
# | noteworthy       |                  1 |
# | cryptic          |                  1 |
# | notorious        |                  1 |
# | nuanced          |                  1 |
# | numb             |                  1 |
# | crunchy          |                  1 |
# | objectionable    |                  1 |
# | criminal         |                  1 |
# | oblivious        |                  1 |
# | observational    |                  1 |
# | crumbly          |                  1 |
# | obsolete         |                  1 |
# | offensive        |                  1 |
# | crucial          |                  1 |
# | zero             |                  1 |

# %%
print('Adverb lemmas remaining, in order of frequency:')
# print(data.value_counts('adv_lemma').to_frame('tokens remaining').to_markdown(floatfmt=',.0f'))
data.value_counts('adv_lemma').to_frame('tokens remaining')
# Out:
# Adverb lemmas remaining, in order of frequency:
# | adv_lemma          |   tokens remaining |
# |:-------------------|-------------------:|
# | very               |                936 |
# | not                |                584 |
# | more               |                532 |
# | so                 |                423 |
# | really             |                242 |
# | too                |                231 |
# | pretty             |                153 |
# | quite              |                108 |
# | also               |                101 |
# | extremely          |                 95 |
# | always             |                 78 |
# | just               |                 67 |
# | less               |                 66 |
# | even               |                 65 |
# | as                 |                 63 |
# | completely         |                 60 |
# | still              |                 57 |
# | all                |                 54 |
# | highly             |                 54 |
# | super              |                 52 |
# | totally            |                 45 |
# | truly              |                 45 |
# | now                |                 41 |
# | incredibly         |                 39 |
# | only               |                 38 |
# | absolutely         |                 37 |
# | rather             |                 35 |
# | relatively         |                 33 |
# | particularly       |                 29 |
# | that               |                 27 |
# | slightly           |                 26 |
# | somewhat           |                 25 |
# | often              |                 25 |
# | fairly             |                 24 |
# | simply             |                 23 |
# | equally            |                 21 |
# | fully              |                 21 |
# | entirely           |                 20 |
# | currently          |                 20 |
# | almost             |                 19 |
# | actually           |                 19 |
# | far                |                 18 |
# | definitely         |                 18 |
# | especially         |                 17 |
# | already            |                 17 |
# | perfectly          |                 15 |
# | never              |                 15 |
# | both               |                 15 |
# | well               |                 15 |
# | deeply             |                 15 |
# | largely            |                 14 |
# | generally          |                 12 |
# | seemingly          |                 12 |
# | usually            |                 12 |
# | long               |                 12 |
# | ever               |                 12 |
# | increasingly       |                 12 |
# | surprisingly       |                 11 |
# | mostly             |                 11 |
# | amazingly          |                 11 |
# | real               |                 10 |
# | any                |                 10 |
# | overly             |                 10 |
# | no                 |                  9 |
# | probably           |                  9 |
# | hugely             |                  9 |
# | potentially        |                  9 |
# | easily             |                  9 |
# | exactly            |                  8 |
# | certainly          |                  8 |
# | immediately        |                  8 |
# | non                |                  7 |
# | noticeably         |                  7 |
# | kinda              |                  7 |
# | exceptionally      |                  7 |
# | damn               |                  7 |
# | sometimes          |                  7 |
# | barely             |                  7 |
# | similarly          |                  6 |
# | technically        |                  6 |
# | seriously          |                  6 |
# | politically        |                  6 |
# | plain              |                  6 |
# | strictly           |                  6 |
# | socially           |                  6 |
# | physically         |                  6 |
# | mentally           |                  5 |
# | terribly           |                  5 |
# | vastly             |                  5 |
# | nearly             |                  5 |
# | inherently         |                  2 |
# | yet                |                  2 |
# | notoriously        |                  2 |
# | near               |                  2 |
# | intentionally      |                  1 |
# | darn               |                  1 |
# | closely            |                  1 |
# | collectively       |                  1 |
# | comically          |                  1 |
# | nevertheless       |                  1 |
# | comparatively      |                  1 |
# | then               |                  1 |
# | openly             |                  1 |
# | criminally         |                  1 |
# | over               |                  1 |
# | dangerously        |                  1 |
# | surely             |                  1 |
# | cautiously         |                  1 |
# | supposedly         |                  1 |
# | nauseatingly       |                  1 |
# | suitably           |                  1 |
# | sufficiently       |                  1 |
# | stunningly         |                  1 |
# | structurally       |                  1 |
# | strikingly         |                  1 |
# | mutually           |                  1 |
# | demonstrably       |                  1 |
# | strangely          |                  1 |
# | chronically        |                  1 |
# | ultimately         |                  1 |
# | startlingly        |                  1 |
# | unabashedly        |                  1 |
# | abnormally         |                  1 |
# | adorably           |                  1 |
# | occasionally       |                  1 |
# | wide               |                  1 |
# | wickedly           |                  1 |
# | alarmingly         |                  1 |
# | appropriately      |                  1 |
# | vitally            |                  1 |
# | architecturally    |                  1 |
# | offensively        |                  1 |
# | notably            |                  1 |
# | back               |                  1 |
# | backwards          |                  1 |
# | normally           |                  1 |
# | nicely             |                  1 |
# | unquestionably     |                  1 |
# | blazingly          |                  1 |
# | blissfully         |                  1 |
# | brilliantly        |                  1 |
# | unfortunately      |                  1 |
# | unexpectedly       |                  1 |
# | uncomfortably      |                  1 |
# | online             |                  1 |
# | devastatingly      |                  1 |
# | Way                |                  1 |
# | invariably         |                  1 |
# | lightly            |                  1 |
# | fiscally           |                  1 |
# | forever            |                  1 |
# | frequently         |                  1 |
# | readily            |                  1 |
# | peculiarly         |                  1 |
# | rarely             |                  1 |
# | radically          |                  1 |
# | globally           |                  1 |
# | quickly            |                  1 |
# | greatly            |                  1 |
# | literally          |                  1 |
# | prohibitively      |                  1 |
# | disproportionately |                  1 |
# | legally            |                  1 |
# | hence              |                  1 |
# | pervasively        |                  1 |
# | hopelessly         |                  1 |
# | philosophically    |                  1 |
# | ideologically      |                  1 |
# | impossibly         |                  1 |
# | indeed             |                  1 |
# | infinitely         |                  1 |
# | keenly             |                  1 |
# | insanely           |                  1 |
# | medically          |                  1 |
# | finely             |                  1 |
# | mighty             |                  1 |
# | respectfully       |                  1 |
# | specifically       |                  1 |
# | distinctly         |                  1 |
# | double             |                  1 |
# | somehow            |                  1 |
# | doubly             |                  1 |
# | eerily             |                  1 |
# | effectively        |                  1 |
# | embarrassingly     |                  1 |
# | essentially        |                  1 |
# | eternally          |                  1 |
# | moderately         |                  1 |
# | exclusively        |                  1 |
# | minimally          |                  1 |
# | severely           |                  1 |
# | exponentially      |                  1 |
# | exquisitely        |                  1 |
# | extraordinarily    |                  1 |
# | fascinatingly      |                  1 |
# | fast               |                  1 |
# | sadly              |                  1 |
# | roughly            |                  1 |
# | right              |                  1 |
# | fatally            |                  1 |
# | obscenely          |                  1 |

# %%
data.sample(5).reset_index(drop=True).loc[:, data.columns.str.endswith(('word', 'form', 'str', 'window'))].set_index('text_window')
# Out:
#                                                    adv_form     adj_form  \
# text_window
# Hardly ideal circumstances .                         Hardly        ideal
# therapy session is totally normal .                 totally       normal
# " It is not traditional for the students                not  traditional
# proverbial demons is less clear-cut .                  less    clear-cut
# called the allegations politically motivated .  politically    motivated
#
#                                                                                                            token_str  \
# text_window
# Hardly ideal circumstances .                                                            Hardly ideal circumstances .
# therapy session is totally normal .             Feeling nervous about your first therapy session is totally normal .
# " It is not traditional for the students              " It is not traditional for the students to leave the area . "
# proverbial demons is less clear-cut .                         But how we fight proverbial demons is less clear-cut .
# called the allegations politically motivated .                 Kobach called the allegations politically motivated .
#
#                                                prev_prev_word    prev_word  \
# text_window
# Hardly ideal circumstances .                                             .
# therapy session is totally normal .                   session           is
# " It is not traditional for the students                   It           is
# proverbial demons is less clear-cut .                  demons           is
# called the allegations politically motivated .            the  allegations
#
#                                                     next_word next_next_word
# text_window
# Hardly ideal circumstances .                    circumstances              .
# therapy session is totally normal .                         .
# " It is not traditional for the students                  for            the
# proverbial demons is less clear-cut .                       .
# called the allegations politically motivated .              .

# %% [markdown]
#  ## Mask tokens
#  In this version, the data is not pre-masked.
#  It consists of sentence strings and target information, including the index of token nodes in the `token_str` values.
#  Should be able to use the `adv_index` and/or `adj_index` to create the corresponding masked version of `token_str`
#
#  _Note: for some reason, the initial filter series, `filter_hi`, gets reshaped as the index of `data`, so it cannot be used in place of `data.index.to_series()`_

# %%
def pre_mask(df, mask_pos='adv'):
    # df.info()
    mask_ix = df.loc[:, f'{mask_pos}_index']
    # print(mask_ix)
    # #! end index is not included in the returned value! [:mask_ix[h]-1] cuts out the word preceding the adv as well

    return df.index.to_series().apply(
        lambda h: ' '.join(df.token_str[h].split()[:mask_ix[h]]))


def post_mask(df, mask_pos='adv'):
    mask_ix = df.loc[:, f'{mask_pos}_index']

    return mask_ix.index.to_series().apply(
        lambda h: ' '.join(df.token_str[h].split()[mask_ix[h]+1:]))


def mask(df: pd.DataFrame, pos='adv'):
    # sourcery skip: use-fstring-for-concatenation
    pre_col = pre_mask(df, pos)
    post_col = post_mask(df, pos)
    return df.assign(masked=pre_col + ' [MASK] ' + post_col)


data = mask(data, MASK_POS)

# %%
data.sample(9).rename(columns={'adv_form':'original token'}).set_index('original token')[['masked']]
# Out:
#                                                                             masked
# original token
# more                It could have been deeply improved with [MASK] suspenseful sex
# so                                               I was [MASK] glad it was n't me .
# pretty                              But Boyd also flung a few [MASK] deep passes .
# Really                                              [MASK] childish name-calling .
# more            Is there anything [MASK] intimidating than moving to a new place ?
# very                      It was a [MASK] brief speech -- and not a pleasant one .
# more                   They want to make lives of the poor even [MASK] miserable .
# absolutely                                                     It 's [MASK] FREE !
# So                                                                   [MASK] cute !

# %% [markdown]
#  ## *Unmask* Tokens
#  Data is loaded and now _masked_ sentences are a column in the dataframe.
#  Can use `UNMASK` pipeline to get probabilities of tokens at masked position.
#
#  ## For just 1 input
#
#  Select sample sentence and run pipeline

# %%
selected_data = data.loc[:, ['adv_form', 'adj_form', 'text_window', 'masked', 'prev_word', 'next_word']]
cat = 'absurd_intense'
try:
    sent_row = selected_data.loc[data.adv_lemma.isin(ADV_SETS[cat]), :].sample(1)
except ValueError: 
    sent_row = selected_data.sample(1)

sent = sent_row.masked.squeeze()
sent_row.transpose()
# Out:
# hit_id                      pcc_eng_29_108.4740_x1736939_04:6-7
# adv_form                                                  oddly
# adj_form                                               specific
# text_window               four is an oddly specific number , no
# masked       Seventy - four is an [MASK] specific number , no ?
# prev_word                                                    an
# next_word                                                number

# %% [markdown]
#  get top 10 predictions for masked position

# %%
K1=50
results = UNMASK(sent, top_k=K1)
rdf = pd.DataFrame(results).sort_values('score', ascending=False)
rdf.set_index('token_str')
# Out:
#                    score  token  \
# token_str
# extremely        0.09949   5186
# unusually        0.09207  12890
# exceptionally    0.04772  17077
# infinitely       0.02706  25773
# alphabet         0.02445  12440
# arbitrary        0.01863  15275
# apparently       0.01784   4593
# actual           0.01173   5025
# overly           0.01111  15241
# ultra            0.00899  11087
# oddly            0.00874  15056
# unspecified      0.00840  25851
# appropriately    0.00838  23263
# incredibly       0.00824  11757
# ibm              0.00785   9980
# odd              0.00776   5976
# indefinite       0.00775  25617
# otherwise        0.00757   4728
# officially       0.00724   3985
# authorized       0.00695   9362
# unidentified     0.00653  20293
# entirely         0.00625   4498
# internationally  0.00613   7587
# approximate      0.00604  15796
# exact            0.00592   6635
# unusual          0.00557   5866
# equally          0.00533   8053
# appropriate      0.00528   6413
# english          0.00506   2394
# especially       0.00486   2926
# acceptable       0.00470  11701
# old              0.00456   2214
# fbi              0.00452   8495
# obviously        0.00429   5525
# internally       0.00404  16058
# unknown          0.00396   4242
# ordinary         0.00395   6623
# intentionally    0.00390  15734
# insurance        0.00368   5427
# official         0.00364   2880
# industry         0.00363   3068
# earth            0.00361   3011
# enigma           0.00356  26757
# assumed          0.00346   5071
# amazingly        0.00344  29350
# absolute         0.00340   7619
# absolutely       0.00335   7078
# interesting      0.00328   5875
# unnamed          0.00320  13294
# egyptian         0.00309   6811
#
#                                                                   sequence
# token_str
# extremely              seventy - four is an extremely specific number, no?
# unusually              seventy - four is an unusually specific number, no?
# exceptionally      seventy - four is an exceptionally specific number, no?
# infinitely            seventy - four is an infinitely specific number, no?
# alphabet                seventy - four is an alphabet specific number, no?
# arbitrary              seventy - four is an arbitrary specific number, no?
# apparently            seventy - four is an apparently specific number, no?
# actual                    seventy - four is an actual specific number, no?
# overly                    seventy - four is an overly specific number, no?
# ultra                      seventy - four is an ultra specific number, no?
# oddly                      seventy - four is an oddly specific number, no?
# unspecified          seventy - four is an unspecified specific number, no?
# appropriately      seventy - four is an appropriately specific number, no?
# incredibly            seventy - four is an incredibly specific number, no?
# ibm                          seventy - four is an ibm specific number, no?
# odd                          seventy - four is an odd specific number, no?
# indefinite            seventy - four is an indefinite specific number, no?
# otherwise              seventy - four is an otherwise specific number, no?
# officially            seventy - four is an officially specific number, no?
# authorized            seventy - four is an authorized specific number, no?
# unidentified        seventy - four is an unidentified specific number, no?
# entirely                seventy - four is an entirely specific number, no?
# internationally  seventy - four is an internationally specific number, no?
# approximate          seventy - four is an approximate specific number, no?
# exact                      seventy - four is an exact specific number, no?
# unusual                  seventy - four is an unusual specific number, no?
# equally                  seventy - four is an equally specific number, no?
# appropriate          seventy - four is an appropriate specific number, no?
# english                  seventy - four is an english specific number, no?
# especially            seventy - four is an especially specific number, no?
# acceptable            seventy - four is an acceptable specific number, no?
# old                          seventy - four is an old specific number, no?
# fbi                          seventy - four is an fbi specific number, no?
# obviously              seventy - four is an obviously specific number, no?
# internally            seventy - four is an internally specific number, no?
# unknown                  seventy - four is an unknown specific number, no?
# ordinary                seventy - four is an ordinary specific number, no?
# intentionally      seventy - four is an intentionally specific number, no?
# insurance              seventy - four is an insurance specific number, no?
# official                seventy - four is an official specific number, no?
# industry                seventy - four is an industry specific number, no?
# earth                      seventy - four is an earth specific number, no?
# enigma                    seventy - four is an enigma specific number, no?
# assumed                  seventy - four is an assumed specific number, no?
# amazingly              seventy - four is an amazingly specific number, no?
# absolute                seventy - four is an absolute specific number, no?
# absolutely            seventy - four is an absolutely specific number, no?
# interesting          seventy - four is an interesting specific number, no?
# unnamed                  seventy - four is an unnamed specific number, no?
# egyptian                seventy - four is an egyptian specific number, no?

# %% [markdown]
#  load lexical categories and compare

# %%
def add_lexcats(results: pd.DataFrame,
                lex_dict: dict,
                original_forms: pd.Series) -> pd.DataFrame:
    if results.index.name == 'token_str':
        results = results.reset_index()
    cat_start_index = len(results.columns)
    for lex_type, lex_set in lex_dict.items():
        results.loc[:, lex_type] = results.token_str.isin(lex_set)
    results = results.assign(any_defined_cat=rdf.iloc[:, cat_start_index:].apply(any, axis=1),
                             # match_masked_POS=results.token_str.isin(original_forms)
                             )
    return results.replace({True: 1, False: 0})


if MASK_POS == 'adj':
    lexcat_dict = ADJ_SETS
elif MASK_POS == 'adv':
    # for adv_type, adv_set in ADV_SETS.items():
    #     rdf.loc[:, adv_type] = rdf.token_str.isin(adv_set)
    # rdf = rdf.assign(match_masked_POS=rdf.token_str.isin(data.adv_form))
    lexcat_dict = ADV_SETS

rdf = add_lexcats(rdf, lexcat_dict, data[f'{MASK_POS}_form'])
if rdf.index.name != 'token_str':
    rdf = rdf.set_index('token_str')
print(f'## input:\n   > {sent}')
# Out:
# ## input:
#    > Seventy - four is an [MASK] specific number , no ?

# %%
rdf.loc[:, ['score']].join(rdf.iloc[:, 3:]).head(4)
# Out:
#                  score  sufficient  min_threshold  max_threshold  moderate  \
# token_str
# extremely      0.09949           0              0              0         0
# unusually      0.09207           0              0              0         0
# exceptionally  0.04772           0              0              0         0
# infinitely     0.02706           0              0              0         0
#
#                precise_intense  compare  weak_intense  meas_intense  \
# token_str
# extremely                    0        0             0             0
# unusually                    0        0             0             0
# exceptionally                0        0             0             0
# infinitely                   0        0             0             0
#
#                mod_intense  ...  excess_intense  max_intense  EDM_Morzycki  \
# token_str                   ...
# extremely                1  ...               0            0             0
# unusually                0  ...               0            0             0
# exceptionally            0  ...               0            0             0
# infinitely               0  ...               0            0             0
#
#                Mmod_SoltWilson  negative  positive  NPS  PS_rescuer  PPS  \
# token_str
# extremely                    0         0         0    0           0    0
# unusually                    0         0         0    0           0    0
# exceptionally                0         0         0    0           0    0
# infinitely                   0         0         0    0           0    0
#
#                any_defined_cat
# token_str
# extremely                    1
# unusually                    1
# exceptionally                1
# infinitely                   1
#
# [4 rows x 37 columns]

# %%
lex_counts = rdf.iloc[:,3:].sum().sort_values(ascending=False).astype('uint8').to_frame('count')
lex_counts = lex_counts.assign(found=pd.Series({col: rdf.loc[rdf[col].apply(bool), col].index.to_list() for col in rdf.columns[3:]}))
lex_counts = lex_counts.assign(composite_score=lex_counts.found.apply(lambda words: rdf.loc[words, 'score'].sum()).round(3), 
                  found=lex_counts.found.apply(lambda x:', '.join(x)))
lex_counts.sort_values('composite_score', ascending=False)
# Out:
#                      count  \
# any_defined_cat         14
# expectation_intense      3
# mod_intense              3
# time                     1
# reporting                1
# excess_intense           1
# absurd_intense           1
# observable               2
# max_intense              1
# good_intense             1
# EDM_Morzycki             1
# meas_intense             0
# serious_intense          0
# epistemic                0
# physical_intense         0
# bad_intense              0
# max_threshold            0
# weak_intense             0
# compare                  0
# precise_intense          0
# moderate                 0
# min_threshold            0
# fear_intense             0
# PPS                      0
# curse_intense            0
# taboo_intense            0
# sufficient               0
# crazy_intense            0
# PS_rescuer               0
# NPS                      0
# unease_intense           0
# positive                 0
# negative                 0
# Mmod_SoltWilson          0
# round-up_intense         0
# consume_intense          0
#
#                                                                                      found  \
# any_defined_cat      extremely, unusually, exceptionally, infinitely, apparently, overl...
# expectation_intense                                   unusually, exceptionally, incredibly
# mod_intense                                                extremely, entirely, especially
# time                                                                            infinitely
# reporting                                                                       apparently
# excess_intense                                                                      overly
# absurd_intense                                                                       oddly
# observable                                                        obviously, intentionally
# max_intense                                                                       entirely
# good_intense                                                                     amazingly
# EDM_Morzycki                                                                    absolutely
# meas_intense
# serious_intense
# epistemic
# physical_intense
# bad_intense
# max_threshold
# weak_intense
# compare
# precise_intense
# moderate
# min_threshold
# fear_intense
# PPS
# curse_intense
# taboo_intense
# sufficient
# crazy_intense
# PS_rescuer
# NPS
# unease_intense
# positive
# negative
# Mmod_SoltWilson
# round-up_intense
# consume_intense
#
#                      composite_score
# any_defined_cat                0.338
# expectation_intense            0.148
# mod_intense                    0.111
# time                           0.027
# reporting                      0.018
# excess_intense                 0.011
# absurd_intense                 0.009
# observable                     0.008
# max_intense                    0.006
# good_intense                   0.003
# EDM_Morzycki                   0.003
# meas_intense                   0.000
# serious_intense                0.000
# epistemic                      0.000
# physical_intense               0.000
# bad_intense                    0.000
# max_threshold                  0.000
# weak_intense                   0.000
# compare                        0.000
# precise_intense                0.000
# moderate                       0.000
# min_threshold                  0.000
# fear_intense                   0.000
# PPS                            0.000
# curse_intense                  0.000
# taboo_intense                  0.000
# sufficient                     0.000
# crazy_intense                  0.000
# PS_rescuer                     0.000
# NPS                            0.000
# unease_intense                 0.000
# positive                       0.000
# negative                       0.000
# Mmod_SoltWilson                0.000
# round-up_intense               0.000
# consume_intense                0.000

# %% [markdown]
#  ## Across multiple inputs
#
#  Apply across all masked sentences and collect results

# %%
pprint([{'hit_id': i,
         f'original_{MASK_POS}': selected_data.loc[i, f'{MASK_POS}_form'],
         'text_window': selected_data.text_window[i],
         'masked_str': selected_data.masked[i],
         'scores': UNMASK(selected_data.masked[i], top_k=3)}
        for i in selected_data.sample(3).index])
# Out:
# [{'hit_id': 'pcc_eng_29_108.0099_x1729367_17:1-2',
#   'masked_str': ' [MASK] afraid of contact .',
#   'original_adv': 'Not',
#   'scores': [{'score': 0.14227072894573212,
#               'sequence': 'not afraid of contact.',
#               'token': 2025,
#               'token_str': 'not'},
#              {'score': 0.09962216764688492,
#               'sequence': 'too afraid of contact.',
#               'token': 2205,
#               'token_str': 'too'},
#              {'score': 0.038818925619125366,
#               'sequence': 'never afraid of contact.',
#               'token': 2196,
#               'token_str': 'never'}],
#   'text_window': 'Not afraid of contact .'},
#  {'hit_id': 'pcc_eng_29_109.0330_x1740841_18:3-4',
#   'masked_str': 'Is this [MASK] true ?',
#   'original_adv': 'all',
#   'scores': [{'score': 0.20503869652748108,
#               'sequence': 'is this all true?',
#               'token': 2035,
#               'token_str': 'all'},
#              {'score': 0.1602722853422165,
#               'sequence': 'is this really true?',
#               'token': 2428,
#               'token_str': 'really'},
#              {'score': 0.06772445887327194,
#               'sequence': 'is this truly true?',
#               'token': 5621,
#               'token_str': 'truly'}],
#   'text_window': 'Is this all true ?'},
#  {'hit_id': 'pcc_eng_29_108.2191_x1732749_09:5-6',
#   'masked_str': 'Important questions , but [MASK] straightforward compared to '
#                 'this one :',
#   'original_adv': 'pretty',
#   'scores': [{'score': 0.26263076066970825,
#               'sequence': 'important questions, but less straightforward '
#                           'compared to this one :',
#               'token': 2625,
#               'token_str': 'less'},
#              {'score': 0.20573823153972626,
#               'sequence': 'important questions, but more straightforward '
#                           'compared to this one :',
#               'token': 2062,
#               'token_str': 'more'},
#              {'score': 0.08281431347131729,
#               'sequence': 'important questions, but relatively straightforward '
#                           'compared to this one :',
#               'token': 4659,
#               'token_str': 'relatively'}],
#   'text_window': 'questions , but pretty straightforward compared to this'}]

# %%
selected_data = selected_data.sample(300) # HACK: #! temporary. REMOVE


def get_scores(masked, top_k=10):
    return {word_fill['token_str']: word_fill['score'] for word_fill in UNMASK(masked, top_k=top_k)}


def sum_lexcats(scores: dict, lex_dict: dict):
    results = pd.Series(scores).to_frame('score')
    # results.index.name = 'filler_str'
    # results = results.reset_index()
    lexcat_sums = pd.Series(dtype='float')
    for lex_type, lex_set in lex_dict.items():
        # return results.loc[results.index.isin(lex_set), 'score'].sum()
        lexcat_sums.loc[f'{lex_type}_total'] = results.loc[results.index.isin(
            lex_set), 'score'].sum().round(5)
    return lexcat_sums

# %%
score_df = selected_data.assign(scores=selected_data.masked.apply(get_scores, top_k=50))

# %%
cat_score_df = score_df.join(score_df.scores.apply(sum_lexcats, lex_dict=ADV_SETS)).convert_dtypes()
is_float = cat_score_df.dtypes=='Float64'
cat_score_df.loc[:, is_float] = cat_score_df.loc[:, is_float].apply(pd.to_numeric, downcast='float')
# cat_score_df
cat_score_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 300 entries, pcc_eng_29_108.4104_x1735877_12:09-10 to pcc_eng_29_109.2648_x1744516_34:5-6
# Data columns (total 42 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   adv_form                   300 non-null    string
#  1   adj_form                   300 non-null    string
#  2   text_window                300 non-null    string
#  3   masked                     300 non-null    string
#  4   prev_word                  300 non-null    string
#  5   next_word                  300 non-null    string
#  6   scores                     300 non-null    object
#  7   sufficient_total           300 non-null    Float32
#  8   min_threshold_total        300 non-null    Float32
#  9   max_threshold_total        300 non-null    Float32
#  10  moderate_total             300 non-null    Float32
#  11  precise_intense_total      300 non-null    Float32
#  12  compare_total              300 non-null    Float32
#  13  weak_intense_total         300 non-null    Float32
#  14  meas_intense_total         300 non-null    Float32
#  15  mod_intense_total          300 non-null    Float32
#  16  good_intense_total         300 non-null    Float32
#  17  bad_intense_total          300 non-null    Float32
#  18  physical_intense_total     300 non-null    Float32
#  19  epistemic_total            300 non-null    Float32
#  20  reporting_total            300 non-null    Float32
#  21  serious_intense_total      300 non-null    Float32
#  22  time_total                 300 non-null    Float32
#  23  observable_total           300 non-null    Float32
#  24  fear_intense_total         300 non-null    Float32
#  25  consume_intense_total      300 non-null    Int64
#  26  curse_intense_total        300 non-null    Float32
#  27  taboo_intense_total        300 non-null    Float32
#  28  round-up_intense_total     300 non-null    Float32
#  29  absurd_intense_total       300 non-null    Float32
#  30  crazy_intense_total        300 non-null    Float32
#  31  expectation_intense_total  300 non-null    Float32
#  32  unease_intense_total       300 non-null    Int64
#  33  excess_intense_total       300 non-null    Float32
#  34  max_intense_total          300 non-null    Float32
#  35  EDM_Morzycki_total         300 non-null    Float32
#  36  Mmod_SoltWilson_total      300 non-null    Float32
#  37  negative_total             300 non-null    Float32
#  38  positive_total             300 non-null    Float32
#  39  NPS_total                  300 non-null    Float32
#  40  PS_rescuer_total           300 non-null    Float32
#  41  PPS_total                  300 non-null    Float32
# dtypes: Float32(33), Int64(2), object(1), string(6)
# memory usage: 80.5+ KB

# %%
stats = cat_score_df.describe().round(3).T.sort_values('mean', ascending=False)
stats
# Out:
#                            count   mean    std  min    25%    50%    75%  \
# weak_intense_total         300.0  0.106  0.133  0.0  0.009  0.050  0.166
# compare_total              300.0  0.072  0.201  0.0  0.000  0.003  0.022
# sufficient_total           300.0  0.070  0.174  0.0  0.000  0.004  0.043
# PS_rescuer_total           300.0  0.051  0.155  0.0  0.000  0.004  0.021
# PPS_total                  300.0  0.051  0.094  0.0  0.001  0.013  0.055
# Mmod_SoltWilson_total      300.0  0.049  0.094  0.0  0.000  0.011  0.045
# negative_total             300.0  0.036  0.118  0.0  0.000  0.003  0.021
# mod_intense_total          300.0  0.034  0.062  0.0  0.001  0.011  0.041
# time_total                 300.0  0.028  0.074  0.0  0.000  0.006  0.027
# max_intense_total          300.0  0.022  0.045  0.0  0.000  0.003  0.020
# positive_total             300.0  0.022  0.054  0.0  0.000  0.004  0.019
# meas_intense_total         300.0  0.020  0.046  0.0  0.000  0.002  0.014
# expectation_intense_total  300.0  0.016  0.033  0.0  0.000  0.002  0.017
# max_threshold_total        300.0  0.014  0.033  0.0  0.000  0.001  0.009
# EDM_Morzycki_total         300.0  0.013  0.037  0.0  0.000  0.001  0.011
# epistemic_total            300.0  0.013  0.036  0.0  0.000  0.002  0.013
# observable_total           300.0  0.011  0.051  0.0  0.000  0.000  0.005
# reporting_total            300.0  0.010  0.064  0.0  0.000  0.000  0.003
# moderate_total             300.0  0.008  0.028  0.0  0.000  0.000  0.005
# fear_intense_total         300.0  0.005  0.016  0.0  0.000  0.000  0.003
# serious_intense_total      300.0  0.005  0.028  0.0  0.000  0.000  0.002
# curse_intense_total        300.0  0.004  0.016  0.0  0.000  0.000  0.000
# round-up_intense_total     300.0  0.004  0.016  0.0  0.000  0.000  0.000
# min_threshold_total        300.0  0.004  0.023  0.0  0.000  0.000  0.000
# excess_intense_total       300.0  0.004  0.020  0.0  0.000  0.000  0.001
# physical_intense_total     300.0  0.003  0.019  0.0  0.000  0.000  0.000
# NPS_total                  300.0  0.003  0.013  0.0  0.000  0.000  0.000
# precise_intense_total      300.0  0.002  0.011  0.0  0.000  0.000  0.000
# crazy_intense_total        300.0  0.001  0.004  0.0  0.000  0.000  0.000
# absurd_intense_total       300.0  0.001  0.006  0.0  0.000  0.000  0.000
# good_intense_total         300.0  0.001  0.005  0.0  0.000  0.000  0.000
# unease_intense_total       300.0  0.000  0.000  0.0  0.000  0.000  0.000
# consume_intense_total      300.0  0.000  0.000  0.0  0.000  0.000  0.000
# bad_intense_total          300.0  0.000  0.001  0.0  0.000  0.000  0.000
# taboo_intense_total        300.0  0.000  0.003  0.0  0.000  0.000  0.000
#
#                              max
# weak_intense_total         0.657
# compare_total              0.992
# sufficient_total           0.995
# PS_rescuer_total           0.992
# PPS_total                  0.647
# Mmod_SoltWilson_total      0.645
# negative_total             0.987
# mod_intense_total          0.549
# time_total                 0.856
# max_intense_total          0.310
# positive_total             0.446
# meas_intense_total         0.327
# expectation_intense_total  0.213
# max_threshold_total        0.238
# EDM_Morzycki_total         0.385
# epistemic_total            0.412
# observable_total           0.705
# reporting_total            0.893
# moderate_total             0.347
# fear_intense_total         0.167
# serious_intense_total      0.364
# curse_intense_total        0.180
# round-up_intense_total     0.154
# min_threshold_total        0.347
# excess_intense_total       0.258
# physical_intense_total     0.265
# NPS_total                  0.132
# precise_intense_total      0.127
# crazy_intense_total        0.046
# absurd_intense_total       0.064
# good_intense_total         0.068
# unease_intense_total       0.000
# consume_intense_total      0.000
# bad_intense_total          0.006
# taboo_intense_total        0.037

# %%
adv_sets = pd.Series(dtype='string')
for adv_cat in stats.index:
    adv_cat = adv_cat.replace('_total', '')
    adv_sets[adv_cat] = ', '.join(ADV_SETS[adv_cat])
adv_df = adv_sets.to_frame(f'{MASK_POS} list')
adv_df.index.name = 'category'
pd.set_option('display.max_colwidth', 120)

# %%
adv_category = pd.Series({k: ', '.join(v) for k,v in ADV_SETS.items()}).sort_index()
adv_cat_df = adv_category.to_frame('words')
adv_cat_df.index.name='adv_category'

# %%
# adv_cat_df = adv_cat_df.assign(cat_type = adv_category.replace(adv_category.str.endswith(('intense', 'Morzycki')), 'intensifier'))
# adv_cat_df.cat_type.where(cond=adv_cat_df.cat_type == 'non-intensifier', other='intensifier', inplace=True)
# adv_cat_df
intense = adv_category.index.to_series().str.endswith(('intense','Morzycki','x_threshold'))
adv_cat_df.loc[:, '+intense'] = intense
adv_cat_df
# Out:
#                                                                                                                                        words  \
# adv_category
# EDM_Morzycki               simply, flat-out, outright, absolutely, downright, full-on, just, positively, balls-out, straight-up, out-and-out
# Mmod_SoltWilson                                                                               fairly, kinda, somewhat, rather, sorta, pretty
# NPS                                                                                                                       ever, exactly, yet
# PPS                                                                                  fairly, kinda, somewhat, utterly, rather, sorta, pretty
# PS_rescuer                                                                                                           only, enough, even, too
# absurd_intense                     strangely, bizarrely, ridiculously, peculiarly, weirdly, freakily, absurdly, freakishly, curiously, oddly
# bad_intense                                                                                  unfortunately, dismally, disappointingly, badly
# compare                                                                                           more, most, less, comparatively, least, as
# consume_intense                                                                                            insatiably, greedily, voraciously
# crazy_intense                                                                                        crazy, crazily, insanely, madly, wildly
# curse_intense                                                                                              fucking, bloody, freaking, damned
# epistemic            honestly, doubtless, incontravertably, certainly, definitely, certifiably, verifiably, undoubtedly, genuinely, verit...
# excess_intense                                                  overly, inordinately, intolerably, overwhelmingly, unacceptably, excessively
# expectation_intense  surprisingly, inutterably, incredibly, impossibly, remarkably, unfathomably, exceptionally, unspeakably, unexpectedl...
# fear_intense         competitively, eerily, awfully, horribly, spookily, dreadfully, dangerously, suspiciously, creepily, alarmingly, fie...
# good_intense         heartily, impressively, gloriously, awesomely, amazingly, divinely, deliciously, fabulously, extraordinarily, marvel...
# max_intense                                                                  totally, completely, maximally, thoroughly, perfectly, entirely
# max_threshold                                                                                                   completely, fully, perfectly
# meas_intense         grossly, increasingly, largely, strongly, monumentally, greatly, widely, tremendously, steeply, highly, hugely, imme...
# min_threshold                                                                                                            slightly, partially
# mod_intense                                                                  entirely, extremely, particularly, super, intensely, especially
# moderate             weakly, passing, moderately, partially, satisfactorily, adequately, dubiously, slightly, marginally, tolerably, pass...
# negative                                                                                    scarcely, hardly, not, barely, never, rarely, no
# observable           distinctly, blatantly, intentionally, audibly, uniquely, notably, visibly, obviously, flagrantly, deliberately, clea...
# physical_intense                                                                   viscerally, excruciatingly, painfully, sorely, physically
# positive                                                             normally, frequently, typically, commonly, usually, some, often, always
# precise_intense                                                                                                           precisely, exactly
# reporting            theoretically, ostensibly, hypothetically, seemingly, tentatively, apparently, perceived, potentially, reportedly, e...
# round-up_intense                                                                              practically, basically, essentially, virtually
# serious_intense      depressingly, seriously, hopelessly, desperately, rigidly, earnestly, sincerely, profoundly, severely, sadly, strict...
# sufficient                                                                                                                   too, enough, so
# taboo_intense         morbidly, brutally, disgustingly, grotesquely, violently, maddeningly, sickeningly, belligerantly, terminally, fatally
# time                 now, forever, recently, already, eventually, previously, still, soon, infinitely, yet, instantly, eternally, formerl...
# unease_intense                                                            alarmingly, worryingly, disturbingly, troublingly, disconcertingly
# weak_intense                                                                                                       real, quite, very, really
#
#                      +intense
# adv_category
# EDM_Morzycki             True
# Mmod_SoltWilson         False
# NPS                     False
# PPS                     False
# PS_rescuer              False
# absurd_intense           True
# bad_intense              True
# compare                 False
# consume_intense          True
# crazy_intense            True
# curse_intense            True
# epistemic               False
# excess_intense           True
# expectation_intense      True
# fear_intense             True
# good_intense             True
# max_intense              True
# max_threshold            True
# meas_intense             True
# min_threshold           False
# mod_intense              True
# moderate                False
# negative                False
# observable              False
# physical_intense         True
# positive                False
# precise_intense          True
# reporting               False
# round-up_intense         True
# serious_intense          True
# sufficient              False
# taboo_intense            True
# time                    False
# unease_intense           True
# weak_intense             True

# %%
adv_cat_df = adv_cat_df.assign(
    req_scale=adv_cat_df.index.str.endswith(
        ('compare', 'moderate', 'sufficient', 'Mmod_SoltWilson', 'threshold', 'intense'))
)
adv_cat_df
# Out:
#                                                                                                                                        words  \
# adv_category
# EDM_Morzycki               simply, flat-out, outright, absolutely, downright, full-on, just, positively, balls-out, straight-up, out-and-out
# Mmod_SoltWilson                                                                               fairly, kinda, somewhat, rather, sorta, pretty
# NPS                                                                                                                       ever, exactly, yet
# PPS                                                                                  fairly, kinda, somewhat, utterly, rather, sorta, pretty
# PS_rescuer                                                                                                           only, enough, even, too
# absurd_intense                     strangely, bizarrely, ridiculously, peculiarly, weirdly, freakily, absurdly, freakishly, curiously, oddly
# bad_intense                                                                                  unfortunately, dismally, disappointingly, badly
# compare                                                                                           more, most, less, comparatively, least, as
# consume_intense                                                                                            insatiably, greedily, voraciously
# crazy_intense                                                                                        crazy, crazily, insanely, madly, wildly
# curse_intense                                                                                              fucking, bloody, freaking, damned
# epistemic            honestly, doubtless, incontravertably, certainly, definitely, certifiably, verifiably, undoubtedly, genuinely, verit...
# excess_intense                                                  overly, inordinately, intolerably, overwhelmingly, unacceptably, excessively
# expectation_intense  surprisingly, inutterably, incredibly, impossibly, remarkably, unfathomably, exceptionally, unspeakably, unexpectedl...
# fear_intense         competitively, eerily, awfully, horribly, spookily, dreadfully, dangerously, suspiciously, creepily, alarmingly, fie...
# good_intense         heartily, impressively, gloriously, awesomely, amazingly, divinely, deliciously, fabulously, extraordinarily, marvel...
# max_intense                                                                  totally, completely, maximally, thoroughly, perfectly, entirely
# max_threshold                                                                                                   completely, fully, perfectly
# meas_intense         grossly, increasingly, largely, strongly, monumentally, greatly, widely, tremendously, steeply, highly, hugely, imme...
# min_threshold                                                                                                            slightly, partially
# mod_intense                                                                  entirely, extremely, particularly, super, intensely, especially
# moderate             weakly, passing, moderately, partially, satisfactorily, adequately, dubiously, slightly, marginally, tolerably, pass...
# negative                                                                                    scarcely, hardly, not, barely, never, rarely, no
# observable           distinctly, blatantly, intentionally, audibly, uniquely, notably, visibly, obviously, flagrantly, deliberately, clea...
# physical_intense                                                                   viscerally, excruciatingly, painfully, sorely, physically
# positive                                                             normally, frequently, typically, commonly, usually, some, often, always
# precise_intense                                                                                                           precisely, exactly
# reporting            theoretically, ostensibly, hypothetically, seemingly, tentatively, apparently, perceived, potentially, reportedly, e...
# round-up_intense                                                                              practically, basically, essentially, virtually
# serious_intense      depressingly, seriously, hopelessly, desperately, rigidly, earnestly, sincerely, profoundly, severely, sadly, strict...
# sufficient                                                                                                                   too, enough, so
# taboo_intense         morbidly, brutally, disgustingly, grotesquely, violently, maddeningly, sickeningly, belligerantly, terminally, fatally
# time                 now, forever, recently, already, eventually, previously, still, soon, infinitely, yet, instantly, eternally, formerl...
# unease_intense                                                            alarmingly, worryingly, disturbingly, troublingly, disconcertingly
# weak_intense                                                                                                       real, quite, very, really
#
#                      +intense  req_scale
# adv_category
# EDM_Morzycki             True      False
# Mmod_SoltWilson         False       True
# NPS                     False      False
# PPS                     False      False
# PS_rescuer              False      False
# absurd_intense           True       True
# bad_intense              True       True
# compare                 False       True
# consume_intense          True       True
# crazy_intense            True       True
# curse_intense            True       True
# epistemic               False      False
# excess_intense           True       True
# expectation_intense      True       True
# fear_intense             True       True
# good_intense             True       True
# max_intense              True       True
# max_threshold            True       True
# meas_intense             True       True
# min_threshold           False       True
# mod_intense              True       True
# moderate                False       True
# negative                False      False
# observable              False      False
# physical_intense         True       True
# positive                False      False
# precise_intense          True       True
# reporting               False      False
# round-up_intense         True       True
# serious_intense          True       True
# sufficient              False       True
# taboo_intense            True       True
# time                    False      False
# unease_intense           True       True
# weak_intense             True       True

# %%
adv_cat_table = adv_cat_df[['+intense', 'req_scale', 'words']].to_markdown()

Path('/home/arh234/projects/sanpi/info/adv-cat_table-23-09-08.md').write_text(f'# Adverb Categories\n\n{adv_cat_table}')
# Out:
# 9492

# %%
cat_score_df.sample(2)
# Out:
#                                      adv_form   adj_form  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6    pretty      young
# pcc_eng_29_109.2648_x1744516_34:5-6  remotely  realistic
#
#                                                              text_window  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6             , that 's pretty young .
# pcc_eng_29_109.2648_x1744516_34:5-6  It 's not remotely realistic , " he
#
#                                                                          masked  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6               Yeah , that 's [MASK] young .
# pcc_eng_29_109.2648_x1744516_34:5-6  " It 's not [MASK] realistic , " he said .
#
#                                     prev_word next_word  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6        's         .
# pcc_eng_29_109.2648_x1744516_34:5-6       not         ,
#
#                                                                                                                                                       scores  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6  {'pretty': 0.5080512166023254, 'too': 0.10320878773927689, 'really': 0.04407912865281105, 'very': 0.0402987524867057...
# pcc_eng_29_109.2648_x1744516_34:5-6  {'very': 0.15076076984405518, 'exactly': 0.12407334893941879, 'too': 0.10400662571191788, 'quite': 0.078553706407547...
#
#                                      sufficient_total  min_threshold_total  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6           0.14177                  0.0
# pcc_eng_29_109.2648_x1744516_34:5-6           0.13753                  0.0
#
#                                      max_threshold_total  ...  \
# hit_id                                                    ...
# pcc_eng_29_109.5996_x1749878_65:5-6                  0.0  ...
# pcc_eng_29_109.2648_x1744516_34:5-6              0.03587  ...
#
#                                      unease_intense_total  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6                     0
# pcc_eng_29_109.2648_x1744516_34:5-6                     0
#
#                                      excess_intense_total  max_intense_total  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6                   0.0            0.00201
# pcc_eng_29_109.2648_x1744516_34:5-6               0.02998            0.12642
#
#                                      EDM_Morzycki_total  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6             0.00119
# pcc_eng_29_109.2648_x1744516_34:5-6              0.0092
#
#                                      Mmod_SoltWilson_total  negative_total  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6                0.54555          0.0028
# pcc_eng_29_109.2648_x1744516_34:5-6                0.00601             0.0
#
#                                      positive_total  NPS_total  \
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6         0.00144        0.0
# pcc_eng_29_109.2648_x1744516_34:5-6         0.01852    0.13192
#
#                                      PS_rescuer_total  PPS_total
# hit_id
# pcc_eng_29_109.5996_x1749878_65:5-6           0.10321    0.54555
# pcc_eng_29_109.2648_x1744516_34:5-6           0.12115    0.00601
#
# [2 rows x 42 columns]

# %%
scores_by_adv = pd.DataFrame.from_records((cat_score_df.scores), index=cat_score_df.index)
scores_by_adv.loc['total', :] = scores_by_adv.sum()
scores_by_adv.T.sort_values('total', ascending=False)
# Out:
# hit_id       pcc_eng_29_108.4104_x1735877_12:09-10  \
# very                                       0.10623
# more                                           NaN
# too                                        0.00166
# not                                        0.00275
# pretty                                     0.00208
# ...                                            ...
# adult                                          NaN
# explicit                                       NaN
# using                                          NaN
# unlawful                                       NaN
# provocative                                    NaN
#
# hit_id       pcc_eng_29_108.0914_x1730699_44:3-4  \
# very                                     0.20558
# more                                     0.00304
# too                                      0.01035
# not                                          NaN
# pretty                                   0.00324
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_109.0678_x1741426_17:12-13  \
# very                                       0.00725
# more                                           NaN
# too                                        0.00311
# not                                        0.01318
# pretty                                         NaN
# ...                                            ...
# adult                                          NaN
# explicit                                       NaN
# using                                          NaN
# unlawful                                       NaN
# provocative                                    NaN
#
# hit_id       pcc_eng_29_108.2083_x1732574_17:8-9  \
# very                                     0.08908
# more                                     0.00562
# too                                      0.03895
# not                                      0.01919
# pretty                                       NaN
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_108.3720_x1735266_51:3-4  \
# very                                         NaN
# more                                         NaN
# too                                          NaN
# not                                          NaN
# pretty                                       NaN
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_109.5996_x1749878_59:6-7  \
# very                                     0.33679
# more                                         NaN
# too                                      0.15853
# not                                      0.00150
# pretty                                   0.15799
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_108.4794_x1737020_15:10-11  \
# very                                       0.00579
# more                                       0.00610
# too                                            NaN
# not                                        0.52274
# pretty                                         NaN
# ...                                            ...
# adult                                          NaN
# explicit                                       NaN
# using                                          NaN
# unlawful                                       NaN
# provocative                                    NaN
#
# hit_id       pcc_eng_29_109.3668_x1746155_83:13-14  \
# very                                       0.36425
# more                                       0.01741
# too                                        0.01174
# not                                        0.01153
# pretty                                     0.00759
# ...                                            ...
# adult                                          NaN
# explicit                                       NaN
# using                                          NaN
# unlawful                                       NaN
# provocative                                    NaN
#
# hit_id       pcc_eng_29_109.5831_x1749611_15:11-12  \
# very                                       0.01833
# more                                       0.00511
# too                                        0.00363
# not                                            NaN
# pretty                                     0.27420
# ...                                            ...
# adult                                          NaN
# explicit                                       NaN
# using                                          NaN
# unlawful                                       NaN
# provocative                                    NaN
#
# hit_id       pcc_eng_29_108.2695_x1733607_17:4-5  ...  \
# very                                     0.19588  ...
# more                                     0.01899  ...
# too                                      0.04746  ...
# not                                          NaN  ...
# pretty                                   0.03983  ...
# ...                                          ...  ...
# adult                                        NaN  ...
# explicit                                     NaN  ...
# using                                        NaN  ...
# unlawful                                     NaN  ...
# provocative                                  NaN  ...
#
# hit_id       pcc_eng_29_109.4947_x1748195_21:3-4  \
# very                                     0.05275
# more                                         NaN
# too                                      0.05965
# not                                          NaN
# pretty                                   0.20273
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_109.3836_x1746418_082:3-4  \
# very                                      0.00460
# more                                          NaN
# too                                       0.14533
# not                                       0.01685
# pretty                                    0.03095
# ...                                           ...
# adult                                         NaN
# explicit                                      NaN
# using                                         NaN
# unlawful                                      NaN
# provocative                                   NaN
#
# hit_id       pcc_eng_29_108.1860_x1732220_26:4-5  \
# very                                     0.01478
# more                                         NaN
# too                                      0.09557
# not                                      0.16666
# pretty                                   0.05195
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_108.4585_x1736672_46:6-7  \
# very                                     0.00188
# more                                         NaN
# too                                      0.00194
# not                                      0.00504
# pretty                                       NaN
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_109.3412_x1745737_41:6-7  \
# very                                     0.02826
# more                                     0.37632
# too                                      0.04206
# not                                          NaN
# pretty                                       NaN
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_108.2616_x1733488_16:7-8  \
# very                                     0.00152
# more                                     0.00164
# too                                          NaN
# not                                          NaN
# pretty                                       NaN
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_108.2413_x1733128_03:1-2  \
# very                                     0.12387
# more                                     0.00825
# too                                          NaN
# not                                      0.01058
# pretty                                   0.03435
# ...                                          ...
# adult                                        NaN
# explicit                                     NaN
# using                                        NaN
# unlawful                                     NaN
# provocative                                  NaN
#
# hit_id       pcc_eng_29_108.5679_x1738439_176:8-9  \
# very                                      0.01665
# more                                      0.03024
# too                                           NaN
# not                                           NaN
# pretty                                    0.01334
# ...                                           ...
# adult                                         NaN
# explicit                                      NaN
# using                                         NaN
# unlawful                                      NaN
# provocative                                   NaN
#
# hit_id       pcc_eng_29_109.2648_x1744516_34:5-6        total
# very                                     0.15076  1.84971e+01
# more                                     0.00382  1.29377e+01
# too                                      0.10401  1.27260e+01
# not                                          NaN  9.41714e+00
# pretty                                   0.00601  8.32201e+00
# ...                                          ...          ...
# adult                                        NaN  3.31247e-06
# explicit                                     NaN  3.29792e-06
# using                                        NaN  3.27568e-06
# unlawful                                     NaN  3.10245e-06
# provocative                                  NaN  3.05670e-06
#
# [1945 rows x 301 columns]

# %%
# scores_by_adv=scores_by_adv.join(data.loc[:, ['adj_form', 'adj_lemma', 'adv_form', 'adv_lemma']])
