# %% [markdown]
# # Sanity Check

# %% [markdown]
# That was only testing 'every' contexts though, as the "unknowns". Let's do a sanity check: how much do distributions which we *know* are negative diverge from the rest of the negative data?
#
# ### `no` vs. all other negative cases

# %% [markdown]
# ---
#
# ---

# %%
import pandas as pd
from scipy.stats import entropy
import numpy as np
import matplotlib_inline as mplot
import itertools

# %%
# copied from `getFrequencies.py` and then modified slightly
def basic_freq_table(data: pd.DataFrame, label: str, mode: str = 'colloc'):
    if mode == 'colloc':
        crosstab_rows = data.colloc
    elif mode == 'adv':
        crosstab_rows = data.adv  # _word
    elif mode == 'adj':
        crosstab_rows = data.adj  # _word

    # get frequency table
    by_context = pd.crosstab(
        crosstab_rows, data.context).apply(pd.to_numeric, downcast="unsigned")
    with_sum = by_context.assign(COMBINED=by_context.sum(axis=1))
    sum2 = with_sum.sum()
    sum2.name = 'SUM'
    with_sum = with_sum.append(sum2)
    with_sum = (with_sum
                .sort_values('COMBINED', ascending=False)
                .sort_values(by='SUM', axis=1, ascending=False))
    # print('>>>', name, mode, 'frequencies')
    # print(with_sum.head(11))
    new_label = f'{label[0:3].upper()}_COMBINED'
    
    with_sum.columns = with_sum.columns.str.replace('COMBINED', new_label)
    
    return with_sum

# %%
# load nonoverlapping hits dataframe
compiled = pd.read_pickle("compiled_hits.pkl.gz")
hits = compiled.loc[:, ['colloc', 'context', 'context_word',
                        'context_type', 'context_group', 'adv', 'adj', 'polarity']]

# %%
pos_hits = hits[hits.polarity == 'positive']
neg_hits = hits[hits.polarity == 'negative']

# %%
other_neg_hits, no_hits = [x for _, x in neg_hits.groupby(neg_hits.context_word.isin(['no','nobody','no-one']))]

other_neg_hits.context.unique().to_list()
# Out:
# ['never_VP-adv',
#  'not_VP-adv',
#  'without-being_PP',
#  'neither_subj-det',
#  'neither_subj-NP',
#  'nothing_subj-NP',
#  'not-one_subj-det',
#  'not-one_subj-NP',
#  'not-a-single_subj-det',
#  'none_subj-NP',
#  'few_subj',
#  'few_det-of-subj']

# %%
no_hits.context.unique().to_list()
# Out:
# ['no_subj-det', 'nobody_subj-NP', 'no-one_subj-NP']

# %% [markdown]
# colloc-by-context frequency tables could be calculated from pre-divided groups, or all together, and then select from the count columns based on context.
#
# First, from all the hits together:

# %%
all_counts = basic_freq_table(hits, label='all')
all_counts.head(11)
# Out:
# context                ALL_COMBINED  be-ADV-ADJ_positive  not_VP-adv  \
# colloc
# SUM                          641085               374956      238598
# immediately_clear             15805                   21       15769
# immediately_available         14363                   59       11632
# as_good                        6492                 2245        3858
# very_good                      4913                 2101        2665
# so_sure                        4123                  122        3940
# too_late                       3871                 2158        1173
# as_bad                         3525                  455        2921
# too_early                      3285                 2688         347
# so_bad                         2638                  685        1901
# very_important                 2512                 2313         143
#
# context                never_VP-adv  no_subj-det  everyone_subj  none_subj-NP  \
# colloc
# SUM                            7302         4818           2881          1902
# immediately_clear                 0           14              0             1
# immediately_available             1         2191              0            27
# as_good                         233           24              8            21
# very_good                        86            4              2            17
# so_sure                           7            0             43             1
# too_late                        537            0              2             0
# as_bad                           90            8              1            14
# too_early                       250            0              0             0
# so_bad                           35            6              0             1
# very_important                    4            1              0             2
#
# context                no-one_subj-NP  few_det-of-subj  everybody_subj  \
# colloc
# SUM                              1817             1785            1605
# immediately_clear                   0                0               0
# immediately_available             314               65               0
# as_good                            16               11               8
# very_good                           0                6               7
# so_sure                             5                0               1
# too_late                            1                0               0
# as_bad                              4                1               0
# too_early                           0                0               0
# so_bad                              2                2               0
# very_important                      0                8               0
#
# context                nothing_subj-NP  every_det-of-subj  nobody_subj-NP  \
# colloc
# SUM                               1492               1226             689
# immediately_clear                    0                  0               0
# immediately_available                0                  0              49
# as_good                             26                 16               9
# very_good                            0                  6               6
# so_sure                              1                  1               1
# too_late                             0                  0               0
# as_bad                              23                  0               1
# too_early                            0                  0               0
# so_bad                               5                  0               0
# very_important                       1                 40               0
#
# context                few_subj  without-being_PP  neither_subj-NP  \
# colloc
# SUM                         681               589              379
# immediately_clear             0                 0                0
# immediately_available         1                 0               11
# as_good                       5                 0               10
# very_good                     3                 1                7
# so_sure                       0                 0                1
# too_late                      0                 0                0
# as_bad                        0                 0                6
# too_early                     0                 0                0
# so_bad                        0                 0                0
# very_important                0                 0                0
#
# context                neither_subj-det  not-one_subj-NP  \
# colloc
# SUM                                 323               33
# immediately_clear                     0                0
# immediately_available                13                0
# as_good                               2                0
# very_good                             2                0
# so_sure                               0                0
# too_late                              0                0
# as_bad                                0                1
# too_early                             0                0
# so_bad                                1                0
# very_important                        0                0
#
# context                not-a-single_subj-det  not-one_subj-det
# colloc
# SUM                                        5                 4
# immediately_clear                          0                 0
# immediately_available                      0                 0
# as_good                                    0                 0
# very_good                                  0                 0
# so_sure                                    0                 0
# too_late                                   0                 0
# as_bad                                     0                 0
# too_early                                  0                 0
# so_bad                                     0                 0
# very_important                             0                 0

# %%
pos_counts = basic_freq_table(pos_hits, label='positive')
pos_counts
# Out:
# context                   be-ADV-ADJ_positive  POS_COMBINED
# colloc
# SUM                                    374956        374956
# too_early                                2688          2688
# very_important                           2313          2313
# as_good                                  2245          2245
# too_late                                 2158          2158
# ...                                       ...           ...
# irresponsibly_vague                         1             1
# irreversibly_busted                         1             1
# irreversibly_committed                      1             1
# irreversibly_constricted                    1             1
# now_legion                                  1             1
#
# [80651 rows x 2 columns]

# %%
neg_main_counts = basic_freq_table(other_neg_hits, label='negative')
neg_main_counts
# Out:
# context                NEG_COMBINED  not_VP-adv  never_VP-adv  none_subj-NP  \
# colloc
# SUM                          253093      238598          7302          1902
# immediately_clear             15770       15769             0             1
# immediately_available         11750       11632             1            27
# as_good                        4166        3858           233            21
# so_sure                        3950        3940             7             1
# ...                             ...         ...           ...           ...
# just_justifiable                  1           1             0             0
# just_jobless                      1           1             0             0
# just_jiggy                        1           1             0             0
# just_jewish                       1           1             0             0
# normal_soccer                     1           1             0             0
#
# context                few_det-of-subj  nothing_subj-NP  few_subj  \
# colloc
# SUM                               1785             1492       681
# immediately_clear                    0                0         0
# immediately_available               65                0         1
# as_good                             11               26         5
# so_sure                              0                1         0
# ...                                ...              ...       ...
# just_justifiable                     0                0         0
# just_jobless                         0                0         0
# just_jiggy                           0                0         0
# just_jewish                          0                0         0
# normal_soccer                        0                0         0
#
# context                without-being_PP  neither_subj-NP  neither_subj-det  \
# colloc
# SUM                                 589              379               323
# immediately_clear                     0                0                 0
# immediately_available                 0               11                13
# as_good                               0               10                 2
# so_sure                               0                1                 0
# ...                                 ...              ...               ...
# just_justifiable                      0                0                 0
# just_jobless                          0                0                 0
# just_jiggy                            0                0                 0
# just_jewish                           0                0                 0
# normal_soccer                         0                0                 0
#
# context                not-one_subj-NP  not-a-single_subj-det  \
# colloc
# SUM                                 33                      5
# immediately_clear                    0                      0
# immediately_available                0                      0
# as_good                              0                      0
# so_sure                              0                      0
# ...                                ...                    ...
# just_justifiable                     0                      0
# just_jobless                         0                      0
# just_jiggy                           0                      0
# just_jewish                          0                      0
# normal_soccer                        0                      0
#
# context                not-one_subj-det
# colloc
# SUM                                   4
# immediately_clear                     0
# immediately_available                 0
# as_good                               0
# so_sure                               0
# ...                                 ...
# just_justifiable                      0
# just_jobless                          0
# just_jiggy                            0
# just_jewish                           0
# normal_soccer                         0
#
# [34119 rows x 13 columns]

# %%
no_counts = basic_freq_table(no_hits, label='no')
no_counts
# Out:
# context                NO_COMBINED  no_subj-det  no-one_subj-NP  \
# colloc
# SUM                           7324         4818            1817
# immediately_available         2554         2191             314
# quite_sure                     500            0             382
# too_small                      193          193               0
# really_sure                    121            0              84
# ...                            ...          ...             ...
# flat-out_awful                   1            0               1
# fiscally_conservative            1            0               1
# firmly_ingrained                 1            1               0
# financially_viable               1            1               0
# peculiarly_fond                  1            1               0
#
# context                nobody_subj-NP
# colloc
# SUM                               689
# immediately_available              49
# quite_sure                        118
# too_small                           0
# really_sure                        37
# ...                               ...
# flat-out_awful                      0
# fiscally_conservative               0
# firmly_ingrained                    0
# financially_viable                  0
# peculiarly_fond                     0
#
# [1955 rows x 4 columns]

# %%
san_chk = pos_counts.join(neg_main_counts).join(no_counts)
san_chk = san_chk.loc[:,san_chk.columns.str.contains('COMBINED')].fillna(0)
san_chk = san_chk.assign(TOTAL=san_chk.sum(axis=1)).convert_dtypes()
san_chk.sort_values('NO_COMBINED', ascending=False)
# Out:
#                        POS_COMBINED  NEG_COMBINED  NO_COMBINED   TOTAL
# colloc
# SUM                          374956        253093         7324  635373
# immediately_available            59         11750         2554   14363
# quite_sure                       93          1569          500    2162
# too_small                      1024            85          193    1302
# really_sure                       7           735          121     863
# ...                             ...           ...          ...     ...
# real_woozy                        1             0            0       1
# usually_unwelcome                 1             0            0       1
# usually_pivotal                   1             0            0       1
# usually_unwilling                 1             0            0       1
# now_legion                        1             0            0       1
#
# [80651 rows x 4 columns]

# %% [markdown]
# An overly simplified sanity check perhaps, but how do the subset `COMBINED` columns compare to the superset column `TOTAL`?

# %%
san_chk = san_chk.add(1)

# %%
def column_divergence(df, col):
    div_df = pd.DataFrame()
    for c1, c2 in itertools.permutations(col, 2): 
        l1 = df[c1].to_list()

        l2 = df[c2].to_list()
        kldiv = round(entropy(l1, l2),3)
        print(c1, 'KLdiv from', c2, '=', kldiv)
        
        div_df.loc[c1+'_KLdiv','from_'+c2] = kldiv

    return div_df.fillna(0).convert_dtypes()

# %%
col = san_chk.columns.to_list()
div_table = column_divergence(san_chk, col)
print('---\nKL Divergence between *all* columns')
div_table
# Out:
# POS_COMBINED KLdiv from NEG_COMBINED = 0.573
# POS_COMBINED KLdiv from NO_COMBINED = 1.155
# POS_COMBINED KLdiv from TOTAL = 0.106
# NEG_COMBINED KLdiv from POS_COMBINED = 0.801
# NEG_COMBINED KLdiv from NO_COMBINED = 1.478
# NEG_COMBINED KLdiv from TOTAL = 0.146
# NO_COMBINED KLdiv from POS_COMBINED = 1.038
# NO_COMBINED KLdiv from NEG_COMBINED = 1.171
# NO_COMBINED KLdiv from TOTAL = 1.159
# TOTAL KLdiv from POS_COMBINED = 0.242
# TOTAL KLdiv from NEG_COMBINED = 0.232
# TOTAL KLdiv from NO_COMBINED = 1.32
# ---
# KL Divergence between *all* columns
#                     from_NEG_COMBINED  from_NO_COMBINED  from_TOTAL  \
# POS_COMBINED_KLdiv              0.573             1.155       0.106
# NEG_COMBINED_KLdiv                0.0             1.478       0.146
# NO_COMBINED_KLdiv               1.171               0.0       1.159
# TOTAL_KLdiv                     0.232              1.32         0.0
#
#                     from_POS_COMBINED
# POS_COMBINED_KLdiv                0.0
# NEG_COMBINED_KLdiv              0.801
# NO_COMBINED_KLdiv               1.038
# TOTAL_KLdiv                     0.242

# %% [markdown]
# We see that total doesn't diverge from itself (as should be the the case), but this also shows that the larger the subset is, the less it diverges from the superset. This also makes sense: the bigger the contribution, the better the final distribution will represent that contribution.
#
# But how do the subdistributions compare to each other?

# %%
col = san_chk.columns.to_list()
col.pop(-1)
div_table = column_divergence(san_chk, col)
print('---\nKL Divergence between data subgroup columns')
div_table
# Out:
# POS_COMBINED KLdiv from NEG_COMBINED = 0.573
# POS_COMBINED KLdiv from NO_COMBINED = 1.155
# NEG_COMBINED KLdiv from POS_COMBINED = 0.801
# NEG_COMBINED KLdiv from NO_COMBINED = 1.478
# NO_COMBINED KLdiv from POS_COMBINED = 1.038
# NO_COMBINED KLdiv from NEG_COMBINED = 1.171
# ---
# KL Divergence between data subgroup columns
#                     from_NEG_COMBINED  from_NO_COMBINED  from_POS_COMBINED
# POS_COMBINED_KLdiv              0.573             1.155                0.0
# NEG_COMBINED_KLdiv                0.0             1.478              0.801
# NO_COMBINED_KLdiv               1.171               0.0              1.038
