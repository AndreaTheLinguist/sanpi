# %% [markdown]
# # %% [markdown]
#
#  # Compilation of All Counts for <font color=DodgerBlue><u>*Original Corpora*</u></font> & <font color=Brown><u>***BiRC***</u></font>
#  ___`BiRC`___ $=\text{``bigram restricted corpus'' or }\texttt{bigram\_subset}$

# %% [markdown]
# # %% [markdown]
#
#  ### *imports*

# %%
from pathlib import Path
import pandas as pd
from am_notebooks import *

#! Toggle TESTING
TESTING = False
if TESTING:
    print(
        '🚨⚠️ WARNING!\n  This is a **TEST** run!'
        'Full count data will not be loaded or saved\n'
    )

# // from utils import file_size_round
SUBSET_DATA_DIR = Path('/share/compling/data/sanpi/subsets')
print(
    '==============================\n'
    f'Date: {pd.Timestamp.now().ctime()}\n'
    '=============================='
)

BIRC_INFO_DIR = SANPI_HOME.joinpath('info/BiRC')
confirm_dir(BIRC_INFO_DIR)
BIRC_META_CSV = BIRC_INFO_DIR.joinpath('meta-info-full.csv')
REL_BIRC_TEX_DIR ='ch6/BiRC'
BIRC_TEX_DIR = LATEX_TABLES.joinpath(REL_BIRC_TEX_DIR)
confirm_dir(BIRC_TEX_DIR)
# Out:
# ==============================
# Date: Mon Feb 17 00:48:14 2025
# ==============================

# %% [markdown]
# # %% [markdown]
#
#  ## **Define functions** to compile all the disparate meta info...

# %%
def collect_subset_path_index():
    """Collect subset path index information.

    This function gathers information about subset paths, including parent directory,
    name, full path, source path (from symlink), BiRC subcorpus, size, and other
    relevant details. It then processes this information to create a DataFrame with
    additional derived columns, such as 'init_conllu', 'data_key', 'corpus_part',
    'corpus', 'subset_info_dir', and 'path_index_csv'.

    Returns:
        pd.DataFrame: A DataFrame containing the collected subset path index info.
    """
    data = {p.stem:
            {
                'parent': p.parent.name,
                'name': p.name,
                'path': p,
                'source_path': p.readlink(),
                'birc_subcorpus': p.parent.parent.stem,
                'is_link': p.is_symlink(),
                # 'size': file_size_round(p.stat().st_size),
                'size': p.stat().st_size,  # ! no longer forcing into different units
            }
            for p in SUBSET_DATA_DIR.rglob('*.conllu')
            #! to prevent *DEMO* files being included:
            if not p.parent.name.startswith('bigram-DEMO')
            }
    bp_df = pd.DataFrame.from_dict(data, orient='index').convert_dtypes()
    bp_df
    bp_df['init_conllu'] = bp_df.name.str.replace('BIGRAM.', '', regex=False)
    bp_df['data_key'] = bp_df.index.str.replace('BIGRAM.', '', regex=False)

    bp_df['corpus_part'], bp_df['corpus'], bp_df['subset_info_dir'] = zip(
        *bp_df.source_path.apply(
            lambda sp: (sp.parent.parent.stem,
                        sp.parent.parent.parent.stem,
                        sp.parent.joinpath('info')))
    )
    bp_df = bp_df.convert_dtypes()

    set_my_style(bp_df.sample(1).T)

    bp_df['path_index_csv'] = bp_df.subset_info_dir.apply(
        lambda i: max(i.glob('subset-bigram_path-index*csv'),
                      key=lambda file: file.stat().st_ctime))

    try:
        path_info = pd.read_csv(X.path_index_csv,
                                usecols=['STEM', ' INPUT_COUNTS',
                                         ' SUBSET_COUNTS']
                                ).set_index('STEM')
    except ValueError:
        path_info = pd.read_csv(X.path_index_csv,
                                usecols=['STEM', 'INPUT_COUNTS',
                                         'SUBSET_COUNTS']
                                ).set_index('STEM')

    path_info.columns = path_info.columns.str.strip().str.lower()
    path_info.columns

    for stem in path_info.sample(3).T:
        print(f'- {stem}')
        print(f'  - input_counts = {path_info.input_counts[stem]}')
        print(f'  - subset_counts = {path_info.subset_counts[stem]}')

    bp_df.index.name = 'subset_stem'
    return bp_df.reset_index().set_index('data_key')


def collect_meta_info(_bp_df):
    """Collect metadata information from various sources.

    This function groups the input DataFrame by 'path_index_csv', reads data from
    corresponding CSV files, joins the data with the original DataFrame, and
    concatenates the results into a single DataFrame. It also performs some
    string cleaning on the resulting DataFrame's columns.

    Args:
        _bp_df (pd.DataFrame): DataFrame containing file paths and other info.

    Returns:
        pd.DataFrame: A DataFrame containing the combined metadata information.
    """
    subframes = []
    for path_ix, df in _bp_df.groupby('path_index_csv'):
        print(path_ix)
        if 'DEMO' in str(path_ix):
            continue
        try:
            path_info = pd.read_csv(
                path_ix,
                usecols=['STEM', ' INPUT_COUNTS', ' SUBSET_COUNTS']
            ).set_index('STEM')
        except ValueError:
            path_info = pd.read_csv(
                path_ix,
                usecols=['STEM', 'INPUT_COUNTS', 'SUBSET_COUNTS']
            ).set_index('STEM')
        display(set_my_style(df.head(1).T, caption=str(
            path_ix.relative_to('/share/compling/data'))))
        subframes.append(df.join(path_info))

    meta_df = pd.concat(subframes)
    meta_df.iloc[:, -2:] = meta_df.iloc[:, -2:].apply(lambda x: x.str.strip())
    meta_df.columns = meta_df.columns.str.strip().str.lower()
    return meta_df

# %% [markdown]
# #  %% [markdown]
#
#  ## **Create or read meta info**

# %%
if BIRC_META_CSV.is_file():
    meta_df = pd.read_csv(BIRC_META_CSV, index_col='data_key').convert_dtypes()
    print(f'Meta Info DataFrame loaded from "{BIRC_META_CSV}"')
else:
    bp_df = collect_subset_path_index()
    meta_df = collect_meta_info(bp_df)
    meta_df.to_csv(BIRC_META_CSV)

set_my_style(
    meta_df.head(1).T,
    caption='First Line of Meta DataFrame')
# Out:
# Meta Info DataFrame loaded from "/share/compling/projects/sanpi/info/BiRC/meta-info-full.csv"
# <style type="text/css">
# #T_051fc th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_051fc th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_051fc th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_051fc caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_051fc_row0_col0, #T_051fc_row1_col0, #T_051fc_row2_col0, #T_051fc_row3_col0, #T_051fc_row4_col0, #T_051fc_row5_col0, #T_051fc_row6_col0, #T_051fc_row7_col0, #T_051fc_row8_col0, #T_051fc_row9_col0, #T_051fc_row10_col0, #T_051fc_row11_col0, #T_051fc_row12_col0, #T_051fc_row13_col0, #T_051fc_row14_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_051fc">
#   <caption>First Line of Meta DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_key</th>
#       <th id="T_051fc_level0_col0" class="col_heading level0 col0" >apw_eng_199411</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_051fc_level0_row0" class="row_heading level0 row0" >subset_stem</th>
#       <td id="T_051fc_row0_col0" class="data row0 col0" >BIGRAM.apw_eng_199411</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row1" class="row_heading level0 row1" >parent</th>
#       <td id="T_051fc_row1_col0" class="data row1 col0" >bigram-Apw</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row2" class="row_heading level0 row2" >name</th>
#       <td id="T_051fc_row2_col0" class="data row2 col0" >BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row3" class="row_heading level0 row3" >path</th>
#       <td id="T_051fc_row3_col0" class="data row3 col0" >/share/compling/data/sanpi/subsets/bigram_news/bigram-Apw/BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row4" class="row_heading level0 row4" >source_path</th>
#       <td id="T_051fc_row4_col0" class="data row4 col0" >/share/compling/data/news/Apw.conll/subset_bigram/BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row5" class="row_heading level0 row5" >birc_subcorpus</th>
#       <td id="T_051fc_row5_col0" class="data row5 col0" >bigram_news</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row6" class="row_heading level0 row6" >is_link</th>
#       <td id="T_051fc_row6_col0" class="data row6 col0" >True</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row7" class="row_heading level0 row7" >size</th>
#       <td id="T_051fc_row7_col0" class="data row7 col0" >11,162,354</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row8" class="row_heading level0 row8" >init_conllu</th>
#       <td id="T_051fc_row8_col0" class="data row8 col0" >apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row9" class="row_heading level0 row9" >corpus_part</th>
#       <td id="T_051fc_row9_col0" class="data row9 col0" >Apw</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row10" class="row_heading level0 row10" >corpus</th>
#       <td id="T_051fc_row10_col0" class="data row10 col0" >news</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row11" class="row_heading level0 row11" >subset_info_dir</th>
#       <td id="T_051fc_row11_col0" class="data row11 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row12" class="row_heading level0 row12" >path_index_csv</th>
#       <td id="T_051fc_row12_col0" class="data row12 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info/subset-bigram_path-index.2023-04-11_0525.csv</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row13" class="row_heading level0 row13" >input_counts</th>
#       <td id="T_051fc_row13_col0" class="data row13 col0" >/share/compling/data/news/Apw.conll/info/apw_eng_199411.counts.json</td>
#     </tr>
#     <tr>
#       <th id="T_051fc_level0_row14" class="row_heading level0 row14" >subset_counts</th>
#       <td id="T_051fc_row14_col0" class="data row14 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info/BIGRAM.apw_eng_199411.counts.json</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # %% [markdown]
#
#  ## *Define functions* to retrieve count data

# %%
def load_totals(counts_path):
    """Load total counts from a JSON file.

    This function reads a JSON file containing counts data, extracts the 'total'
    column, drops any missing values (NaN), and returns the result as a dictionary.
    If the provided path is not absolute, it prepends the sanpi data directory.

    Args:
        counts_path (str or Path): Path to the JSON file.

    Returns:
        dict: A dictionary containing the total counts, with keys corresponding to
            the original index of the 'total' column.
    """

    if not Path(counts_path).is_absolute():
        counts_path = f"/share/compling/data/sanpi/{counts_path}"
    counts_df = pd.read_json(counts_path)
    return counts_df.loc[:, 'total'].dropna().to_dict()


def generate_counts(_meta_df, retrieval_key='input'):
    """Generate counts for each data key.

    This generator iterates through the index of the input DataFrame, retrieves the
    counts path based on the retrieval key, and yields the data key along with its
    corresponding counts.

    Args:
        _meta_df (pd.DataFrame): DataFrame containing metadata information.
        retrieval_key (str, optional): Key used to retrieve the counts path.
            Defaults to 'input'.

    Yields:
        tuple: A tuple containing the data key and its corresponding counts.
    """
    for data_key in _meta_df.index:
        counts_path = _meta_df.at[data_key, f'{retrieval_key}_counts']
        yield data_key, load_totals(counts_path)


def retrieve_count_data(_counts_csv_path, _meta_df, test=False):
    seek_birc = "birc" in _counts_csv_path.name.lower()
    _counts_label = "BiRC" if seek_birc else "Original"
    if _counts_csv_path.is_file():
        try:
            _counts_df = pd.read_csv(_counts_csv_path,
                                     index_col='corpus_slice').convert_dtypes()
        except ValueError:
            _counts_df = pd.read_csv(_counts_csv_path).convert_dtypes()

        print(
            f'**{_counts_label} Counts** read from csv',
            f'> Path: {_counts_csv_path.relative_to(SANPI_HOME)}',
            sep='\n')
    else:
        _meta_selection = _meta_df.copy().sample(100) if test else _meta_df.copy()
        _counts_df = pd.DataFrame.from_dict(
            {k: c for k, c in generate_counts(
                _meta_df=_meta_selection,
                retrieval_key='subset' if seek_birc else 'input')},
            orient='index')
        _counts_df.index.name = 'corpus_slice'
        _counts_df = _counts_df.reset_index().convert_dtypes().set_index('corpus_slice')
        print(
            f'**{_counts_label} Counts** saved as csv',
            f'> Path: {_counts_csv_path.relative_to(SANPI_HOME)}',
            sep='\n')
        if test:
            print('TESTING (so, not really)')
        else:
            _counts_df.to_csv(_counts_csv_path)
    return _counts_df.loc[:, ~_counts_df.columns.str.startswith('NR_')]

# %% [markdown]
# # %% [markdown]
#
#  ## **Load <font color=DodgerBlue><u>Original</u></font> counts** (if not previously collected)

# %%
orig_counts_df = retrieve_count_data(
    _counts_csv_path=BIRC_INFO_DIR.joinpath('original-count-data.csv'),
    _meta_df=meta_df,
    test=TESTING
)

orig_counts_df.info()
# Out:
# **Original Counts** read from csv
# > Path: info/BiRC/original-count-data.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3617 entries, apw_eng_199411 to pcc_eng_val-03
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   file_MB     3617 non-null   Float64
#  1   sentences   3617 non-null   Int64
#  2   tokens      3617 non-null   Int64
#  3   ADV_tokens  3617 non-null   Int64
#  4   ADV_xpos    3617 non-null   Int64
#  5   ADV_lemmas  3617 non-null   Int64
#  6   ADV_forms   3617 non-null   Int64
#  7   ADJ_tokens  3617 non-null   Int64
#  8   ADJ_xpos    3617 non-null   Int64
#  9   ADJ_lemmas  3617 non-null   Int64
#  10  ADJ_forms   3617 non-null   Int64
#  11  NEG_tokens  3617 non-null   Int64
#  12  NEG_xpos    3617 non-null   Int64
#  13  NEG_lemmas  3617 non-null   Int64
#  14  NEG_forms   3617 non-null   Int64
# dtypes: Float64(1), Int64(14)
# memory usage: 505.1+ KB

# %% [markdown]
# # %% [markdown]
#
#  ## **...and <font color=Brown><u>BiRC</u></font> counts** (likewise)

# %%
birc_counts_df = retrieve_count_data(
    _counts_csv_path=BIRC_INFO_DIR.joinpath('birc-count-data.csv'),
    _meta_df=meta_df,
    test=TESTING
)

birc_counts_df.info()
# if birc_counts_composite_csv.is_file():
#     birc_counts_df = pd.read_csv(birc_counts_composite_csv).convert_dtypes()
#     print(
#         f'**BiRC Counts** read from csv\n> Path: {birc_counts_composite_csv.relative_to(SANPI_HOME)}')
# else:
#     birc_counts_df = pd.DataFrame.from_dict(
#         # {k:c for k,c in generate_counts(meta_df.head(500), 'subset')}, orient='index')
#         {k: c for k, c in generate_counts(meta_df, 'subset')}, orient='index')
#     pd.to_csv(birc_counts_composite_csv)
#     print(
#         f'**BiRC Counts** saved as csv\n> Path: {birc_counts_composite_csv.relative_to(SANPI_HOME)}')
# Out:
# **BiRC Counts** read from csv
# > Path: info/BiRC/birc-count-data.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3617 entries, apw_eng_199411 to pcc_eng_val-03
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   file_MB     3617 non-null   Float64
#  1   sentences   3617 non-null   Int64
#  2   tokens      3617 non-null   Int64
#  3   ADV_tokens  3617 non-null   Int64
#  4   ADV_xpos    3617 non-null   Int64
#  5   ADV_lemmas  3617 non-null   Int64
#  6   ADV_forms   3617 non-null   Int64
#  7   ADJ_tokens  3617 non-null   Int64
#  8   ADJ_xpos    3617 non-null   Int64
#  9   ADJ_lemmas  3617 non-null   Int64
#  10  ADJ_forms   3617 non-null   Int64
#  11  NEG_tokens  3617 non-null   Int64
#  12  NEG_xpos    3617 non-null   Int64
#  13  NEG_lemmas  3617 non-null   Int64
#  14  NEG_forms   3617 non-null   Int64
# dtypes: Float64(1), Int64(14)
# memory usage: 505.1+ KB

# %% [markdown]
# # %% [markdown]
#
#  ## *Describe Count Collections*

# %%
save_latex_table(orig_counts_df.describe().T.iloc[:, 1:].assign(Total=orig_counts_df.sum()).convert_dtypes(),
                 caption='Original Corpora: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='init-descrip-stats-orig')

save_latex_table(birc_counts_df.describe().T.iloc[:, 1:].assign(Total=birc_counts_df.sum()).convert_dtypes(),
                 caption='BiRC: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='init-descrip-stats-birc')
# Out:
# Caption: Original Corpora: Descriptive Stats
# <style type="text/css">
# #T_38587 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_38587 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_38587 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_38587 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_38587_row0_col0, #T_38587_row0_col1, #T_38587_row0_col2, #T_38587_row0_col3, #T_38587_row0_col4, #T_38587_row0_col5, #T_38587_row0_col6, #T_38587_row0_col7, #T_38587_row1_col0, #T_38587_row1_col1, #T_38587_row1_col2, #T_38587_row1_col3, #T_38587_row1_col4, #T_38587_row1_col5, #T_38587_row1_col6, #T_38587_row1_col7, #T_38587_row2_col0, #T_38587_row2_col1, #T_38587_row2_col2, #T_38587_row2_col3, #T_38587_row2_col4, #T_38587_row2_col5, #T_38587_row2_col6, #T_38587_row2_col7, #T_38587_row3_col0, #T_38587_row3_col1, #T_38587_row3_col2, #T_38587_row3_col3, #T_38587_row3_col4, #T_38587_row3_col5, #T_38587_row3_col6, #T_38587_row3_col7, #T_38587_row4_col0, #T_38587_row4_col1, #T_38587_row4_col2, #T_38587_row4_col3, #T_38587_row4_col4, #T_38587_row4_col5, #T_38587_row4_col6, #T_38587_row4_col7, #T_38587_row5_col0, #T_38587_row5_col1, #T_38587_row5_col2, #T_38587_row5_col3, #T_38587_row5_col4, #T_38587_row5_col5, #T_38587_row5_col6, #T_38587_row5_col7, #T_38587_row6_col0, #T_38587_row6_col1, #T_38587_row6_col2, #T_38587_row6_col3, #T_38587_row6_col4, #T_38587_row6_col5, #T_38587_row6_col6, #T_38587_row6_col7, #T_38587_row7_col0, #T_38587_row7_col1, #T_38587_row7_col2, #T_38587_row7_col3, #T_38587_row7_col4, #T_38587_row7_col5, #T_38587_row7_col6, #T_38587_row7_col7, #T_38587_row8_col0, #T_38587_row8_col1, #T_38587_row8_col2, #T_38587_row8_col3, #T_38587_row8_col4, #T_38587_row8_col5, #T_38587_row8_col6, #T_38587_row8_col7, #T_38587_row9_col0, #T_38587_row9_col1, #T_38587_row9_col2, #T_38587_row9_col3, #T_38587_row9_col4, #T_38587_row9_col5, #T_38587_row9_col6, #T_38587_row9_col7, #T_38587_row10_col0, #T_38587_row10_col1, #T_38587_row10_col2, #T_38587_row10_col3, #T_38587_row10_col4, #T_38587_row10_col5, #T_38587_row10_col6, #T_38587_row10_col7, #T_38587_row11_col0, #T_38587_row11_col1, #T_38587_row11_col2, #T_38587_row11_col3, #T_38587_row11_col4, #T_38587_row11_col5, #T_38587_row11_col6, #T_38587_row11_col7, #T_38587_row12_col0, #T_38587_row12_col1, #T_38587_row12_col2, #T_38587_row12_col3, #T_38587_row12_col4, #T_38587_row12_col5, #T_38587_row12_col6, #T_38587_row12_col7, #T_38587_row13_col0, #T_38587_row13_col1, #T_38587_row13_col2, #T_38587_row13_col3, #T_38587_row13_col4, #T_38587_row13_col5, #T_38587_row13_col6, #T_38587_row13_col7, #T_38587_row14_col0, #T_38587_row14_col1, #T_38587_row14_col2, #T_38587_row14_col3, #T_38587_row14_col4, #T_38587_row14_col5, #T_38587_row14_col6, #T_38587_row14_col7 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_38587">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_38587_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_38587_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_38587_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_38587_level0_col3" class="col_heading level0 col3" >25\%</th>
#       <th id="T_38587_level0_col4" class="col_heading level0 col4" >50\%</th>
#       <th id="T_38587_level0_col5" class="col_heading level0 col5" >75\%</th>
#       <th id="T_38587_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_38587_level0_col7" class="col_heading level0 col7" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_38587_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_38587_row0_col0" class="data row0 col0" >376.642759</td>
#       <td id="T_38587_row0_col1" class="data row0 col1" >48.076895</td>
#       <td id="T_38587_row0_col2" class="data row0 col2" >1.160000</td>
#       <td id="T_38587_row0_col3" class="data row0 col3" >376.870000</td>
#       <td id="T_38587_row0_col4" class="data row0 col4" >381.310000</td>
#       <td id="T_38587_row0_col5" class="data row0 col5" >385.880000</td>
#       <td id="T_38587_row0_col6" class="data row0 col6" >693.620000</td>
#       <td id="T_38587_row0_col7" class="data row0 col7" >1362316.860000</td>
#     </tr>
#     <tr>
#       <th id="T_38587_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_38587_row1_col0" class="data row1 col0" >264,905.37</td>
#       <td id="T_38587_row1_col1" class="data row1 col1" >67,510.85</td>
#       <td id="T_38587_row1_col2" class="data row1 col2" >1,147.00</td>
#       <td id="T_38587_row1_col3" class="data row1 col3" >249,191.00</td>
#       <td id="T_38587_row1_col4" class="data row1 col4" >252,229.00</td>
#       <td id="T_38587_row1_col5" class="data row1 col5" >255,672.00</td>
#       <td id="T_38587_row1_col6" class="data row1 col6" >820,724.00</td>
#       <td id="T_38587_row1_col7" class="data row1 col7" >958,162,724.00</td>
#     </tr>
#     <tr>
#       <th id="T_38587_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T
>10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_6b3ff_level0_row5" class="row_heading level0 row5" >ADV\_lemmas</th>
#       <td id="T_6b3ff_row5_col0" class="data row5 col0" >1345.696434</td>
#       <td id="T_6b3ff_row5_col1" class="data row5 col1" >150.913612</td>
#       <td id="T_6b3ff_row5_col2" class="data
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/init-descrip-stats-birc.2025-02-17.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/init-descrip-stats-birc.2025-02-17.tex')

# %%
# %%

def add_rate_cols(_df):
    return _df.assign(
        tok_per_sent=_df.tokens / _df.sentences,
        ADV_tok_per_sent=_df.ADV_tokens / _df.sentences,
        ADJ_tok_per_sent=_df.ADJ_tokens / _df.sentences,
        NEG_tok_per_sent=_df.NEG_tokens / _df.sentences,
        NEG_tok_per_mill=(_df.NEG_tokens / _df.tokens)*(10**6),
        ADV_tok_per_mill=(_df.ADV_tokens / _df.tokens)*(10**6),
        ADJ_tok_per_mill=(_df.ADJ_tokens / _df.tokens)*(10**6),
        ADV_form_per_lemma=_df.ADV_forms / _df.ADV_lemmas,
        # ADV_lemma_per_form= _df.ADV_lemmas / _df.ADV_forms,
        ADV_tok_per_lemma=_df.ADV_tokens / _df.ADV_lemmas,
        ADV_tok_per_form=_df.ADV_tokens / _df.ADV_forms,
        ADJ_form_per_lemma=_df.ADJ_forms / _df.ADJ_lemmas,
        # ADJ_lemma_per_form= _df.ADJ_lemmas / _df.ADJ_forms,
        ADJ_tok_per_lemma=_df.ADJ_tokens / _df.ADJ_lemmas,
        ADJ_tok_per_form=_df.ADJ_tokens / _df.ADJ_forms,
        # NEG_lemma_per_form= _df.NEG_lemmas / _df.NEG_forms,
        NEG_form_per_lemma=_df.NEG_forms / _df.NEG_lemmas,
    )


orig_counts_df = add_rate_cols(orig_counts_df)
birc_counts_df = add_rate_cols(birc_counts_df)
samix = orig_counts_df.sample(4).sort_index().index
nb_display(set_my_style(orig_counts_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for Original Counts'))
nb_display(set_my_style(birc_counts_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for BiRC Counts'))
# Out:
# <style type="text/css">
# #T_5ff52 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_5ff52 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5ff52 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5ff52 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_5ff52 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_5ff52 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5ff52 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_5ff52 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_5ff52_row0_col0, #T_5ff52_row0_col1, #T_5ff52_row0_col2, #T_5ff52_row0_col3, #T_5ff52_row1_col0, #T_5ff52_row1_col1, #T_5ff52_row1_col2, #T_5ff52_row1_col3, #T_5ff52_row2_col0, #T_5ff52_row2_col1, #T_5ff52_row2_col2, #T_5ff52_row2_col3, #T_5ff52_row3_col0, #T_5ff52_row3_col1, #T_5ff52_row3_col2, #T_5ff52_row3_col3, #T_5ff52_row4_col0, #T_5ff52_row4_col1, #T_5ff52_row4_col2, #T_5ff52_row4_col3, #T_5ff52_row5_col0, #T_5ff52_row5_col1, #T_5ff52_row5_col2, #T_5ff52_row5_col3, #T_5ff52_row6_col0, #T_5ff52_row6_col1, #T_5ff52_row6_col2, #T_5ff52_row6_col3, #T_5ff52_row7_col0, #T_5ff52_row7_col1, #T_5ff52_row7_col2, #T_5ff52_row7_col3, #T_5ff52_row8_col0, #T_5ff52_row8_col1, #T_5ff52_row8_col2, #T_5ff52_row8_col3, #T_5ff52_row9_col0, #T_5ff52_row9_col1, #T_5ff52_row9_col2, #T_5ff52_row9_col3, #T_5ff52_row10_col0, #T_5ff52_row10_col1, #T_5ff52_row10_col2, #T_5ff52_row10_col3, #T_5ff52_row11_col0, #T_5ff52_row11_col1, #T_5ff52_row11_col2, #T_5ff52_row11_col3, #T_5ff52_row12_col0, #T_5ff52_row12_col1, #T_5ff52_row12_col2, #T_5ff52_row12_col3, #T_5ff52_row13_col0, #T_5ff52_row13_col1, #T_5ff52_row13_col2, #T_5ff52_row13_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_5ff52">
#   <caption>"Rate" columns for Original Counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_5ff52_level0_col0" class="col_heading level0 col0" >apw_eng_200808</th>
#       <th id="T_5ff52_level0_col1" class="col_heading level0 col1" >pcc_eng_07-019</th>
#       <th id="T_5ff52_level0_col2" class="col_heading level0 col2" >pcc_eng_20-020</th>
#       <th id="T_5ff52_level0_col3" class="col_heading level0 col3" >pcc_eng_23-094</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ff52_level0_row0" class="row_heading level0 row0" >tok_per_sent</th>
#       <td id="T_5ff52_row0_col0" class="data row0 col0" >23.73</td>
#       <td id="T_5ff52_row0_col1" class="data row0 col1" >31.12</td>
#       <td id="T_5ff52_row0_col2" class="data row0 col2" >31.15</td>
#       <td id="T_5ff52_row0_col3" class="data row0 col3" >31.11</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row1" class="row_heading level0 row1" >ADV_tok_per_sent</th>
#       <td id="T_5ff52_row1_col0" class="data row1 col0" >0.60</td>
#       <td id="T_5ff52_row1_col1" class="data row1 col1" >0.82</td>
#       <td id="T_5ff52_row1_col2" class="data row1 col2" >0.81</td>
#       <td id="T_5ff52_row1_col3" class="data row1 col3" >0.80</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row2" class="row_heading level0 row2" >ADJ_tok_per_sent</th>
#       <td id="T_5ff52_row2_col0" class="data row2 col0" >1.36</td>
#       <td id="T_5ff52_row2_col1" class="data row2 col1" >1.29</td>
#       <td id="T_5ff52_row2_col2" class="data row2 col2" >1.28</td>
#       <td id="T_5ff52_row2_col3" class="data row2 col3" >1.28</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row3" class="row_heading level0 row3" >NEG_tok_per_sent</th>
#       <td id="T_5ff52_row3_col0" class="data row3 col0" >0.14</td>
#       <td id="T_5ff52_row3_col1" class="data row3 col1" >0.17</td>
#       <td id="T_5ff52_row3_col2" class="data row3 col2" >0.17</td>
#       <td id="T_5ff52_row3_col3" class="data row3 col3" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_5ff52_row4_col0" class="data row4 col0" >5,715.24</td>
#       <td id="T_5ff52_row4_col1" class="data row4 col1" >5,425.61</td>
#       <td id="T_5ff52_row4_col2" class="data row4 col2" >5,323.12</td>
#       <td id="T_5ff52_row4_col3" class="data row4 col3" >5,246.17</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row5" class="row_heading level0 row5" >ADV_tok_per_mill</th>
#       <td id="T_5ff52_row5_col0" class="data row5 col0" >25,319.36</td>
#       <td id="T_5ff52_row5_col1" class="data row5 col1" >26,479.48</td>
#       <td id="T_5ff52_row5_col2" class="data row5 col2" >25,975.99</td>
#       <td id="T_5ff52_row5_col3" class="data row5 col3" >25,830.36</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row6" class="row_heading level0 row6" >ADJ_tok_per_mill</th>
#       <td id="T_5ff52_row6_col0" class="data row6 col0" >57,441.80</td>
#       <td id="T_5ff52_row6_col1" class="data row6 col1" >41,434.51</td>
#       <td id="T_5ff52_row6_col2" class="data row6 col2" >40,947.24</td>
#       <td id="T_5ff52_row6_col3" class="data row6 col3" >41,186.52</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row7" class="row_heading level0 row7" >ADV_form_per_lemma</th>
#       <td id="T_5ff52_row7_col0" class="data row7 col0" >1.10</td>
#       <td id="T_5ff52_row7_col1" class="data row7 col1" >1.29</td>
#       <td id="T_5ff52_row7_col2" class="data row7 col2" >1.30</td>
#       <td id="T_5ff52_row7_col3" class="data row7 col3" >1.30</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row8" class="row_heading level0 row8" >ADV_tok_per_lemma</th>
#       <td id="T_5ff52_row8_col0" class="data row8 col0" >139.44</td>
#       <td id="T_5ff52_row8_col1" class="data row8 col1" >86.89</td>
#       <td id="T_5ff52_row8_col2" class="data row8 col2" >87.78</td>
#       <td id="T_5ff52_row8_col3" class="data row8 col3" >87.24</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row9" class="row_heading level0 row9" >ADV_tok_per_form</th>
#       <td id="T_5ff52_row9_col0" class="data row9 col0" >126.69</td>
#       <td id="T_5ff52_row9_col1" class="data row9 col1" >67.12</td>
#       <td id="T_5ff52_row9_col2" class="data row9 col2" >67.44</td>
#       <td id="T_5ff52_row9_col3" class="data row9 col3" >67.04</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row10" class="row_heading level0 row10" >ADJ_form_per_lemma</th>
#       <td id="T_5ff52_row10_col0" class="data row10 col0" >1.03</td>
#       <td id="T_5ff52_row10_col1" class="data row10 col1" >1.15</td>
#       <td id="T_5ff52_row10_col2" class="data row10 col2" >1.15</td>
#       <td id="T_5ff52_row10_col3" class="data row10 col3" >1.15</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row11" class="row_heading level0 row11" >ADJ_tok_per_lemma</th>
#       <td id="T_5ff52_row11_col0" class="data row11 col0" >30.70</td>
#       <td id="T_5ff52_row11_col1" class="data row11 col1" >21.42</td>
#       <td id="T_5ff52_row11_col2" class="data row11 col2" >21.45</td>
#       <td id="T_5ff52_row11_col3" class="data row11 col3" >21.33</td>
#     </tr>
#     <tr>
#       <th id="T_5ff52_level0_row12" class="row_heading level0 row12" >ADJ_tok_per_form</th>
#       <td id="T_5ff52_row12_col0" class="data row12 col0" >29.79</td>
#       <td id="T_5ff52_row12_col1" class="data row12 col1" >18.61</td>
#       <td id="T_5ff52_row12_col2" class="data row12 col2" >18.63</td>
#       <
# <style type="text/css">
# #T_7aae7 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_7aae7 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7aae7 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7aae7 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_7aae7 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_7aae7 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7aae7 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7aae7 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_7aae7_row0_col0, #T_7aae7_row0_col1, #T_7aae7_row0_col2, #T_7aae7_row0_col3, #T_7aae7_row1_col0, #T_7aae7_row1_col1, #T_7aae7_row1_col2, #T_7aae7_row1_col3, #T_7aae7_row2_col0, #T_7aae7_row2_col1, #T_7aae7_row2_col2, #T_7aae7_row2_col3, #T_7aae7_row3_col0, #T_7aae7_row3_col1, #T_7aae7_row3_col2, #T_7aae7_row3_col3, #T_7aae7_row4_col0, #T_7aae7_row4_col1, #T_7aae7_row4_col2, #T_7aae7_row4_col3, #T_7aae7_row5_col0, #T_7aae7_row5_col1, #T_7aae7_row5_col2, #T_7aae7_row5_col3, #T_7aae7_row6_col0, #T_7aae7_row6_col1, #T_7aae7_row6_col2, #T_7aae7_row6_col3, #T_7aae7_row7_col0, #T_7aae7_row7_col1, #T_7aae7_row7_col2, #T_7aae7_row7_col3, #T_7aae7_row8_col0, #T_7aae7_row8_col1, #T_7aae7_row8_col2, #T_7aae7_row8_col3, #T_7aae7_row9_col0, #T_7aae7_row9_col1, #T_7aae7_row9_col2, #T_7aae7_row9_col3, #T_7aae7_row10_col0, #T_7aae7_row10_col1, #T_7aae7_row10_col2, #T_7aae7_row10_col3, #T_7aae7_row11_col0, #T_7aae7_row11_col1, #T_7aae7_row11_col2, #T_7aae7_row11_col3, #T_7aae7_row12_col0, #T_7aae7_row12_col1, #T_7aae7_row12_col2, #T_7aae7_row12_col3, #T_7aae7_row13_col0, #T_7aae7_row13_col1, #T_7aae7_row13_col2, #T_7aae7_row13_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_7aae7">
#   <caption>"Rate" columns for BiRC Counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_7aae7_level0_col0" class="col_heading level0 col0" >apw_eng_200808</th>
#       <th id="T_7aae7_level0_col1" class="col_heading level0 col1" >pcc_eng_07-019</th>
#       <th id="T_7aae7_level0_col2" class="col_heading level0 col2" >pcc_eng_20-020</th>
#       <th id="T_7aae7_level0_col3" class="col_heading level0 col3" >pcc_eng_23-094</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7aae7_level0_row0" class="row_heading level0 row0" >tok_per_sent</th>
#       <td id="T_7aae7_row0_col0" class="data row0 col0" >23.64</td>
#       <td id="T_7aae7_row0_col1" class="data row0 col1" >31.14</td>
#       <td id="T_7aae7_row0_col2" class="data row0 col2" >31.13</td>
#       <td id="T_7aae7_row0_col3" class="data row0 col3" >31.13</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row1" class="row_heading level0 row1" >ADV_tok_per_sent</th>
#       <td id="T_7aae7_row1_col0" class="data row1 col0" >1.80</td>
#       <td id="T_7aae7_row1_col1" class="data row1 col1" >2.14</td>
#       <td id="T_7aae7_row1_col2" class="data row1 col2" >2.15</td>
#       <td id="T_7aae7_row1_col3" class="data row1 col3" >2.12</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row2" class="row_heading level0 row2" >ADJ_tok_per_sent</th>
#       <td id="T_7aae7_row2_col0" class="data row2 col0" >2.59</td>
#       <td id="T_7aae7_row2_col1" class="data row2 col1" >2.59</td>
#       <td id="T_7aae7_row2_col2" class="data row2 col2" >2.62</td>
#       <td id="T_7aae7_row2_col3" class="data row2 col3" >2.58</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row3" class="row_heading level0 row3" >NEG_tok_per_sent</th>
#       <td id="T_7aae7_row3_col0" class="data row3 col0" >0.21</td>
#       <td id="T_7aae7_row3_col1" class="data row3 col1" >0.32</td>
#       <td id="T_7aae7_row3_col2" class="data row3 col2" >0.32</td>
#       <td id="T_7aae7_row3_col3" class="data row3 col3" >0.31</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_7aae7_row4_col0" class="data row4 col0" >9,026.42</td>
#       <td id="T_7aae7_row4_col1" class="data row4 col1" >10,389.59</td>
#       <td id="T_7aae7_row4_col2" class="data row4 col2" >10,416.47</td>
#       <td id="T_7aae7_row4_col3" class="data row4 col3" >10,038.99</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row5" class="row_heading level0 row5" >ADV_tok_per_mill</th>
#       <td id="T_7aae7_row5_col0" class="data row5 col0" >76,281.28</td>
#       <td id="T_7aae7_row5_col1" class="data row5 col1" >68,704.96</td>
#       <td id="T_7aae7_row5_col2" class="data row5 col2" >69,034.44</td>
#       <td id="T_7aae7_row5_col3" class="data row5 col3" >67,957.20</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row6" class="row_heading level0 row6" >ADJ_tok_per_mill</th>
#       <td id="T_7aae7_row6_col0" class="data row6 col0" >109,338.03</td>
#       <td id="T_7aae7_row6_col1" class="data row6 col1" >83,200.09</td>
#       <td id="T_7aae7_row6_col2" class="data row6 col2" >84,216.69</td>
#       <td id="T_7aae7_row6_col3" class="data row6 col3" >82,974.70</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row7" class="row_heading level0 row7" >ADV_form_per_lemma</th>
#       <td id="T_7aae7_row7_col0" class="data row7 col0" >1.08</td>
#       <td id="T_7aae7_row7_col1" class="data row7 col1" >1.25</td>
#       <td id="T_7aae7_row7_col2" class="data row7 col2" >1.26</td>
#       <td id="T_7aae7_row7_col3" class="data row7 col3" >1.26</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row8" class="row_heading level0 row8" >ADV_tok_per_lemma</th>
#       <td id="T_7aae7_row8_col0" class="data row8 col0" >48.93</td>
#       <td id="T_7aae7_row8_col1" class="data row8 col1" >37.32</td>
#       <td id="T_7aae7_row8_col2" class="data row8 col2" >38.04</td>
#       <td id="T_7aae7_row8_col3" class="data row8 col3" >38.32</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row9" class="row_heading level0 row9" >ADV_tok_per_form</th>
#       <td id="T_7aae7_row9_col0" class="data row9 col0" >45.38</td>
#       <td id="T_7aae7_row9_col1" class="data row9 col1" >29.95</td>
#       <td id="T_7aae7_row9_col2" class="data row9 col2" >30.29</td>
#       <td id="T_7aae7_row9_col3" class="data row9 col3" >30.50</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row10" class="row_heading level0 row10" >ADJ_form_per_lemma</th>
#       <td id="T_7aae7_row10_col0" class="data row10 col0" >1.02</td>
#       <td id="T_7aae7_row10_col1" class="data row10 col1" >1.10</td>
#       <td id="T_7aae7_row10_col2" class="data row10 col2" >1.11</td>
#       <td id="T_7aae7_row10_col3" class="data row10 col3" >1.11</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row11" class="row_heading level0 row11" >ADJ_tok_per_lemma</th>
#       <td id="T_7aae7_row11_col0" class="data row11 col0" >11.72</td>
#       <td id="T_7aae7_row11_col1" class="data row11 col1" >10.03</td>
#       <td id="T_7aae7_row11_col2" class="data row11 col2" >10.19</td>
#       <td id="T_7aae7_row11_col3" class="data row11 col3" >10.04</td>
#     </tr>
#     <tr>
#       <th id="T_7aae7_level0_row12" class="row_heading level0 row12" >ADJ_tok_per_form</th>
#       <td id="T_7aae7_row12_col0" class="data row12 col0" >11.52</td>
#       <td id="T_7aae7_row12_col1" class="data row12 col1" >9.11</td>
#       <td id="T_7aae7_row12_col2" class="data row12 col2" >9.16</td>
#       <td i

# %%
# %%

save_latex_table(orig_counts_df.describe().T.iloc[:, 1:].assign(Total=orig_counts_df.sum()).convert_dtypes(),
                 caption='Original Corpora Counts & Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='plus-rates-descrip-stats-orig')

save_latex_table(birc_counts_df.describe().T.iloc[:, 1:].assign(Total=birc_counts_df.sum()).convert_dtypes(),
                 caption='BiRC Counts & Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='plus-rates-descrip-stats-birc')

save_latex_table(orig_counts_df.filter(like='per').describe().T.iloc[:, 1:].assign(Total=orig_counts_df.sum()).convert_dtypes(),
                 caption='Original Corpora Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='only-rates-descrip-stats-orig')

save_latex_table(birc_counts_df.filter(like='per').describe().T.iloc[:, 1:].assign(Total=birc_counts_df.sum()).convert_dtypes(),
                 caption='BiRC Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='only-rates-descrip-stats-birc')
# Out:
# Caption: Original Corpora Counts & Rates: Descriptive Stats
# <style type="text/css">
# #T_2a771 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_2a771 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2a771 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2a771 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_2a771_row0_col0, #T_2a771_row0_col1, #T_2a771_row0_col2, #T_2a771_row0_col3, #T_2a771_row0_col4, #T_2a771_row0_col5, #T_2a771_row0_col6, #T_2a771_row0_col7, #T_2a771_row1_col0, #T_2a771_row1_col1, #T_2a771_row1_col2, #T_2a771_row1_col3, #T_2a771_row1_col4, #T_2a771_row1_col5, #T_2a771_row1_col6, #T_2a771_row1_col7, #T_2a771_row2_col0, #T_2a771_row2_col1, #T_2a771_row2_col2, #T_2a771_row2_col3, #T_2a771_row2_col4, #T_2a771_row2_col5, #T_2a771_row2_col6, #T_2a771_row2_col7, #T_2a771_row3_col0, #T_2a771_row3_col1, #T_2a771_row3_col2, #T_2a771_row3_col3, #T_2a771_row3_col4, #T_2a771_row3_col5, #T_2a771_row3_col6, #T_2a771_row3_col7, #T_2a771_row4_col0, #T_2a771_row4_col1, #T_2a771_row4_col2, #T_2a771_row4_col3, #T_2a771_row4_col4, #T_2a771_row4_col5, #T_2a771_row4_col6, #T_2a771_row4_col7, #T_2a771_row5_col0, #T_2a771_row5_col1, #T_2a771_row5_col2, #T_2a771_row5_col3, #T_2a771_row5_col4, #T_2a771_row5_col5, #T_2a771_row5_col6, #T_2a771_row5_col7, #T_2a771_row6_col0, #T_2a771_row6_col1, #T_2a771_row6_col2, #T_2a771_row6_col3, #T_2a771_row6_col4, #T_2a771_row6_col5, #T_2a771_row6_col6, #T_2a771_row6_col7, #T_2a771_row7_col0, #T_2a771_row7_col1, #T_2a771_row7_col2, #T_2a771_row7_col3, #T_2a771_row7_col4, #T_2a771_row7_col5, #T_2a771_row7_col6, #T_2a771_row7_col7, #T_2a771_row8_col0, #T_2a771_row8_col1, #T_2a771_row8_col2, #T_2a771_row8_col3, #T_2a771_row8_col4, #T_2a771_row8_col5, #T_2a771_row8_col6, #T_2a771_row8_col7, #
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_2a771">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2a771_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_2a771_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_2a771_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_2a771_level0_col3" class="col_heading level0 col3" >25\%</th>
#       <th id="T_2a771_level0_col4" class="col_heading level0 col4" >50\%</th>
#       <th id="T_2a771_level0_col5" class="col_heading level0 col5" >75\%</th>
#       <th id="T_2a771_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_2a771_level0_col7" class="col_heading level0 col7" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2a771_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_2a771_row0_col0" class="data row0 col0" >376.642759</td>
#       <td id="T_2a771_row0_col1" class="data row0 col1" >48.076895</td>
#       <td id="T_2a771_row0_col2" class="data row0 col2" >1.160000</td>
#       <td id="T_2a771_row0_col3" class="data row0 col3" >376.870000</td>
#       <td id="T_2a771_row0_col4" class="data row0 col4" >381.310000</td>
#       <td id="T_2a771_row0_col5" class="data row0 col5" >385.880000</td>
#       <td id="T_2a771_row0_col6" class="data row0 col6" >693.620000</td>
#       <td id="T_2a771_row0_col7" class="data row0 col7" >1362316.860000</td>
#     </tr>
#     <tr>
#       <th id="T_2a771_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_2a771_row1_col0" class="data row1 col0" >264,905.37</td>
#       <td id="T_2a771_row1_col1" class="data row1 col1" >67,510.85</td>
#       <td id="T_2a771_row1_col2" class="data row1 col2" >1,147.00</td>
#       <td id="T_2a771_row1_col3" class="data row1 col3" >249,191.00</td>
#       <td id="T_2a771_row1_col4" class="data row1 col4" >252,229.00</td>
#       <td id="T_2a771_row1_col5" class="data row1 col5" >255,672.00</td>
#       <td id="T_2a771_row1_col6" class="data row1 col6" >820,724.00</td>
#       <td id="T_2a771_row1_col7" class="data row1 col7" >958,162,724.00</
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-descrip-stats-orig.2025-02-17.tex
#
# Caption: BiRC Counts & Rates: Descriptive Stats
# <style type="text/css">
# #T_8931e th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_8931e th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_8931e th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_8931e caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_8931e_row0_col0, #T_8931e_row0_col1, #T_8931e_row0_col2, #T_8931e_row0_col3, #T_8931e_row0_col4, #T_8931e_row0_col5, #T_8931e_row0_col6, #T_8931e_row0_col7, #T_8931e_row1_col0, #T_8931e_row1_col1, #T_8931e_row1_col2, #T_8931e_row1_col3, #T_8931e_row1_col4, #T_8931e_row1_col5, #T_8931e_row1_col6, #T_8931e_row1_col7, #T_8931e_row2_col0, #T_8931e_row2_col1, #T_8931e_row2_col2, #T_8931e_row2_col3, #T_8931e_row2_col4, #T_8931e_row2_col5, #T_8931e_row2_col6, #T_8931e_row2_col7, #T_8931e_row3_col0, #T_8931e_row3_col1, #T_8931e_row3_col2, #T_8931e_row3_col3, #T_8931e_row3_col4, #T_8931e_row3_col5, #T_8931e_row3_col6, #T_8931e_row3_col7, #T_8931e_row4_col0, #T_8931e_row4_col1, #T_8931e_row4_col2, #T_8931e_row4_col3, #T_8931e_row4_col4, #T_8931e_row4_col5, #T_8931e_row4_col6, #T_8931e_row4_col7, #T_8931e_row5_col0, #T_8931e_row5_col1, #T_8931e_row5_col2, #T_8931e_row5_col3, #T_8931e_row5_col4, #T_8931e_row5_col5, #T_8931e
row20_col3, #T_8931e_row20_col4, #T_8931e_row20_col5, #T_8931e_row20_col6, #T_8931e_row20_col7, #T_8931e_row21_col0, #T_8931e_row21_col1, #T_8931e_row21_col2, #T_8931e_row21_col3, #T_8931e_row21_col4, #T_8931e_row21_col5, #T_8931e_row21_col6, #T_8931e_row21_col7, #T_8931e_row22_col0, #T_8931e_row22_col1, #T_8931e_row22_col2, #T_8931e_row22_col3, #T_8931e_row22_col4, #T_8931e_row22_col5, #T_8931e_row22_col6, #T_8931e_row22_col7, #T_8931e_row23_col0, #T_8931e_row23_col1, #T_8931e_row23_col2, #T_8931e_row23_col3, #T_8931e_row23_col4, #T_8931e_row23_col5, #T_8931e_row23_col6, #T_8931e_row23_col7, #T_8931e_row24_col0, #T_8931e_row24_col1, #T_893 ...
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_8931e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8931e_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_8931e_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_8931e_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_8931e_level0_col3" class="col_heading level0 col3" >25\%</th>
#       <th id="T_8931e_level0_col4" class="col_heading level0 col4" >50\%</th>
#       <th id="T_8931e_level0_col5" class="col_heading level0 col5" >75\%</th>
#       <th id="T_8931e_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_8931e_level0_col7" class="col_heading level0 col7" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8931e_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_8931e_row0_col0" class="data row0 col0" >48.411269</td>
#       <td id="T_8931e_row0_col1" class="data row0 col1" >7.827544</td>
#       <td id="T_8931e_row0_col2" class="data row0 col2" >0.090000</td>
#       <td id="T_8931e_row0_col3" class="data row0 col3" >49.260000</td>
#       <td id="T_8931e_row0_col4" class="data row0 col4" >50.120000</td>
#       <td id="T_8931e_row0_col5" class="data row0 col5" >50.930000</td>
#       <td id="T_8931e_row0_col6" class="data row0 col6" >76.520000</td>
#       <td id="T_8931e_row0_col7" class="data row0 col7" >175103.560000</td>
#     </tr>
#     <tr>
#       <th id="T_8931e_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_8931e_row1_col0" class="data row1 col0" >24,564.02</td>
#       <td id="T_8931e_row1_col1" class="data row1 col1" >4,727.44</td>
#       <td id="T_8931e_row1_col2" class="data row1 col2" >78.00</td>
#       <td id="T_8931e_row1_col3" class="data row1 col3" >23,867.00</td>
#       <td id="T_8931e_row1_col4" class="data row1 col4" >24,232.00</td>
#       <td id="T_8931e_row1_col5" class="data row1 col5" >24,603.00</td>
#       <td id="T_8931e_row1_col6" class="data row1 col6" >66,997.00</td>
#       <td id="T_8931e_row1_col7" class="data row1 col7" >88,848,070.00</td>
#     </tr>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-descrip-stats-birc.2025-02-17.tex
#
# Caption: Original Corpora Rates: Descriptive Stats
# <style type="text/css">
# #T_70953 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_70953 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_70953 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_70953 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_70953_row0_col0, #T_70953_row0_col1, #T_70953_row0_col2, #T_70953_row0_col3, #T_70953_row0_col4, #T_70953_row0_col5, #T_70953_row0_col6, #T_70953_row0_col7, #T_70953_row1_col0, #T_70953_row1_col1, #T_70953_row1_col2, #T_70953_row1_col3, #T_70953_row1_col4, #T_70953_row1_col5, #T_70953_row1_col6, #T_70953_row1_col7, #T_70953_row2_col0, #T_70953_row2_col1, #T_70953_row2_col2, #T_70953_row2_col3, #T_70953_row2_col4, #T_70953_row2_col5, #T_70953_row2_col6, #T_70953_row2_col7, #T_70953_row3_col0, #T_70953_row3_col1, #T_70953_row3_col2, #T_70953_row3_col3, #T_70953_row3_col4, #T_70953_row3_col5, #T_70953_row3_col6, #T_70953_row3_col7, #T_70953_row4_col0, #T_70953_row4_col1, #T_70953_row4_col2, #T_70953_row4_col3, #T_70953_row4_col4, #T_70953_row4_col5, #T_70953_row4_col6, #T_70953_row4_col7, #T_70953_row5_col0, #T_70953_row5_col1, #T_70953_row5_col2, #T_70953_row5_col3, #T_70953_row5_col4, #T_70953_row5_col5, #T_70953_row5_col6, #T_70953_row5_col7, #T_70953_row6_col0, #T_70953_row6_col1, #T_70953_row6_col2, #T_70953_row6_col3, #T_70953_row6_col4, #T_70953_row6_col5, #T_70953_row6_col6, #T_70953_row6_col7, #T_70953_row7_col0, #T_70953_row7_col1, #T_70953_row7_col2, #T_70953_row7_col3, #T_70953_row7_col4, #T_70953_row7_col5, #T_70953_row7_col6, #T_70953_row7_col7, #T_70953_row8_col0, #T_70953_row8_col1, #T_70953_row8_col2, #T_70953_row8_col3, #T_70953_row8_col4, #T_70953_row8_col5, #T_70953_row8_col6, #T_70953_row8_col7, #T_70953_row9_col0, #T_70953_row9_col1, #T_70953_row9_col2, #T_70953_row9_col3, #T_70953_row9_col4, #T_70953_row9_col5, #T_70953_row9_col6, #T_70953_row9_col7, #T_70953_row10_col0, #T_70953_row10_col1, #T_70953_row10_col2, #T_70953_row10_col3, #T_70953_row10_col4, #T_70953_row10_col5, #T_70953_row10_col6, #T_70953_row10_col7, #T_70953_row11_col0, #T_70953_row11_col1, #T_70953_row11_col2, #T_70953_row11_col3, #T_70953_row11_col4, #T_70953_row11_col5, #T_70953_row11_col6, #T_70953_row11_col7, #T_70953_row12_col0, #T_70953_row12_col1, #T_70953_row12_col2, #T_70953_row12_col3, #T_70953_row12_col4, #T_70953_row12_col5, #T_70953_row12_col6, #T_70953_row12_col7, #T_70953_row13_col0, #T_70953_row13_col1, #T_70953_row13_col2, #T_70953_row13_col3, #T_70953_row13_col4, #T_70953_row13_col5, #T_70953_row13_col6, #T_70953_row13_col7 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_70953">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70953_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_70953_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_70953_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_70953_level0_col3" class="col_heading level0 col3" >25\%</th>
#       <th id="T_70953_level0_col4" class="col_heading level0 col4" >50\%</th>
#       <th id="T_70953_level0_col5" class="col_heading level0 col5" >75\%</th>
#       <th id="T_70953_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_70953_level0_col7" class="col_heading level0 col7" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70953_level0_row0" class="row_heading level0 row0" >tok\_per\_sent</th>
#       <td id="T_70953_row0_col0" class="data row0 col0" >30.375293</td>
#       <td id="T_70953_row0_col1" class="data row0 col1" >2.297509</td>
#       <td id="T_70953_row0_col2" class="data row0 col2" >1.744827</td>
#       <td id="T_70953_row0_col3" class="data row0 col3" >31.112055</td>
#       <td id="T_70953_row0_col4" class="data row0 col4" >31.125939</td>
#       <td id="T_70953_row0_col5" class="data row0 col5" >31.139396</td>
#       <td id="T_70953_row0_col6" class="data row0 col6" >32.176999</td>
#       <td id="T_70953_row0_col7" class="data row0 col7" >109867.434803</td>
#       <td id="T_f1a54_row3_col1" class="data row3 col1" >0.030635</td>
#       <td id="T_f1a54_row3_col2" class="data row3 col2" >0.163388</td>
#       <td id="T_f1a54_row3_col3" class="data row3 col3" >0.316392</td>
#       <td id="T_f1a54_row3_col4" class="data row3 col4" >0.320608</td>
#       <td id="T_f1a54_row3_col5" class="data row3 col5" >0.324286</td>
#       <td id="T_f1a54_row3_col6" class="data row3 col6" >0.363451</td>
#       <td id="T_f1a54_row3_col7" class="data row3 col7" >1127.459420</td>
#     </tr>
#     <tr>
#       <th id="T_f1a54_level0_row4" class="row_heading level0 row4" >NEG\_tok\_per\_mill</th>
#       <td id="T_f1a54_row4_col0" class="data row4 col0" >10238.704921</td>
#       <td id="T_f1a54_row4_col1" class="data row4 col1" >448.389591</td>
#       <td id="T_f1a54_row4_col2" class="data row4 col2" >6901.384613</td>
#       <td id="T_f1a54_row4_col3" class="data row4 col3" >10184.950732</td>
#       <td id="T_f1a54_row4_col4" class="data row4 col4" >10311.474769</td>
#       <td id="T_f1a54_row4_col5" class="data row4 col5" >10426.156677</td>
#       <td id="T_f1a54_row4_col6" class="data row4 col6" >13071.895425</td>
#       <td id="T_f1a54_row4_col7" class="data row4 col7" >37033395.700265</td>
#     </tr>
#     <tr>
#       <th id="T_f1a54_level0_row5" class="row_heading level0 row5" >ADV\_tok\_per\_mill</th>
#       <td id="T_f1a54_row5_col0" class="data row5 col0" >69566.598296</td>
#       <td id="T_f1a54_row5_col1" class="data row5 col1" >3391.553055</td>
#       <td id="T_f1a54_row5_col2" class="data row5 col2" >65676.414220</td>
#       <td id="T_f1a54_row5_col3" class="data row5 col3" >68286.559501</td>
#       <td id="T_f1a54_row5_col4
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-rates-descrip-stats-birc.2025-02-17.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/only-rates-descrip-stats-birc.2025-02-17.tex')

# %% [markdown]
# # %% [markdown]
#
#  ## *Calculate **Reduction*** (<code>BiRC - Full</code>)

# %%
reduction_df = birc_counts_df - orig_counts_df
# iloc[:, 1:] drops the uninformtative `count` column
save_latex_table(reduction_df.describe().T.iloc[:, 1:].assign(Total=reduction_df.sum()).convert_dtypes(),
                 caption='Reduction (BiRC -- Full) Counts & Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='plus-rates-birc-minus-full-descrip-stats')
save_latex_table(reduction_df.filter(like='per').describe().T.iloc[:, 1:].assign(Total=reduction_df.sum()).convert_dtypes(),
                 caption='Reduction (BiRC -- Full) Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='only-rates-birc-minus-full-descrip-stats')
# nb_display(set_my_style(reduction_df.describe().T.assign(Total=reduction_df.sum()).convert_dtypes(),
#                         caption='BiRC <i>Reduction</i>: Descriptive Stats', precision=1))
nb_display(set_my_style(reduction_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for <code>BiRC - Full</code> counts'))
# Out:
# Caption: Reduction (BiRC -- Full) Counts & Rates: Descriptive Stats
# <style type="text/css">
# #T_fb9c5 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_fb9c5 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_fb9c5 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_fb9c5 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T
level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_fb9c5_row0_col0" class="data row0 col0" >-328.231490</td>
#       <td id="T_fb9c5_row0_col1" class="data row0 col1" >42.014842</td>
#       <td id="T_fb9c5_row0_col2" class="data row0 col2" >-617.100000</td>
#       <td id="T_fb9c5_row0_col3" class="data row0 col3" >-335.070000</td>
#       <td id="T_fb9c5_row0_col4" class="data row0 col4" >-331.150000</td>
#       <td id="T_fb9c5_row0_col5" class="data row0 col5" >-327.310000</td>
#       <td id="T_fb9c5_row0_col6" class="data row0 col6" >-1.070000</td>
#       <td id="T_fb9c5_row0_col7" class="data row0 col7" >-1187213.300000</td>
#     </tr>
#     <tr>
#       <th id="T_fb9c5_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_fb9c5_row1_col0" class="data row1 col0" >-240,341.35</td>
#       <td id="T_fb9c5_row1_col1" class="data row1 col1" >63,751.01</td>
#       <td id="T_fb9c5_row1_col2" class="data row1 col2" >-753,727.00</td>
#       <td id="T_fb9c5_row1_col3" class="data row1 col3" >-231,181.00</td>
#       <td id="T_fb9c5_row1_col4" class="data row1 col4" >-228,003.00</td>
#       <td id="T_fb9c5_row1_col5" class="data row1 col5" >-225,298.00</td>
#       <td id="T_fb9c5_row1_col6" class="data row1 col6" >-1,069.00</td>
#       <td id="T_fb9c5_row1_col7" class="data row1 col7" >-86
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-birc-minus-full-descrip-stats.2025-02-17.tex
#
# Caption: Reduction (BiRC -- Full) Rates: Descriptive Stats
# <style type="text/css">
# #T_e129c th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e129c th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e129c th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e129c caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e129c_row0_col0, #T_e129c_row0_col1, #T_e129c_row0_col2, #T_e129c_row0_col3, #T_e129c_row0_col4, #T_e129c_row0_col5, #T_e129c_row0_col6, #T_e129c_row0_col7, #T_e129c_row1_col0, #T_e129c_row1_col1, #T_e129c_row1_col2, #T_e129c_row1_col3, #T_e129c_row1_col4, #T_e129c_row1_col5, #T_e129c_row1_col6, #T_e129c_row1_col7, #T_e129c_row2_col0, #T_e129c_row2_col1, #T_e129c_row2_col2, #T_e129c_row2_col3, #T_e129c_row2_col4, #T_e129c_row2_col5, #T_e129c_row2_col6, #T_e129c_row2_col7, #T_e129c_row3_col0, #T_e129c_row3_col1, #T_e129c_row3_col2, #T_e129c_row3_col3, #T_e129c_row3_col4, #T_e129c_row3_col5, #T_e129c_row3_col6, #T_e129c_row3_col7, #T_e129c_row4_col0, #T_e129c_row4_col1, #T_e129c_row4_col2, #T_e129c_row4_col3, #T_e129c_row4_col4, #T_e129c_row4_col5, #T_e129c_row4_col6, #T_e129c_row4_col7, #T_e129c_row5_col0, #T_e129c_row5_col1, #T_e129c_row5_col2, #T_e129c_row5_col3, #T_e129c_row5_col4, #T_e129c_row5_col5, #T_e129c_row5_col6, #T_e129c_row5_col7, #T_e129c_row6_col0, #T_e129c_row6_col1, #T_e129c_row6_col2, #T_e129c_row6_col3, #T_e129c_row6_col4, #T_e129c_row6_col5, #T_e129c_row6_col6, #T_e129c_row6_col7, #T_e129c_row7_col0, #T_e129c_row7_col1, #T_e129c_row7_col2, #T_e129c_row7_col3, #T_e129c_row7_col4, #T_e129c_row7_col5, #T_e129c_row7_col6, #T_e129c_row7_col7, #T_e129c_row8_col0, #T_e129c_row8_col1, #T_e129c_row8_col2, #T_e129c_row8_col3, #T_e129c_row8_col4, #T_e129c_row8_col5, #T_e129c_row8_col6, #T_e129c_row8_col7, #T_e129c_row9_col0, #T_e129c_row9_col1, #T_e129c_row9_col2, #T_e129c_row9_col3, #T_e129c_row9_col4, #T_e129c_row9_col5, #T_e129c_row9_col6, #T_e129c_row9_col7, #T_e129c_row10_col0, #T_e129c_row10_col1, #T_e129c_row10_col2, #T_e129c_row10_col3, #T_e129c_row10_col4, #T_e129c_row10_col5, #T_e129c_row10_col6, #T_e129c_row10_col7, #T_e129c_row11_col0, #T_e129c_row11_col1, #T_e129c_row11_col2, #T_e129c_row11_col3, #T_e129c_row11_col4, #T_e129c_row11_col5, #T_e129c_row11_col6, #T_e129c_row11_col7, #T_e129c_row12_col0, #T_e129c_row12_col1, #T_e129c_row12_col2, #T_e129c_row12_col3, #T_e129c_row12_col4, #T_e129c_row12_col5, #T_e129c_row12_col6, #T_e129c_row12_col7, #T_e129c_row13_col0, #T_e129c_row13_col1, #T_e129c_row13_col2, #T_e129c_row13_col3, #T_e129c_row13_col4, #T_e129c_row13_col5, #T_e129c_row13_col6, #T_e129c_row13_col7 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_e129c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e129c_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_e129c_level0_col1" class="col_heading level0 col1" >std</th>
#       <th id="T_e129c_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_e129c_level0_col3" class="col_heading level0 col3" >25\%</th>
#       <th id="T_e129c_level0_col4" class="col_heading level0 col4" >50\%</th>
#       <th id="T_e129c_level0_col5" class="col_heading level0 col5" >75\%</th>
#       <th id="T_e129c_level0_col6" class="col_heading level0 col6" >max</th>
#       <th id="T_e129c_level0_col7" class="col_heading level0 col7" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e129c_level0_row0" class="row_heading level0 row0" >tok\_per\_sent</th>
#       <td id="T_e129c_row0_col0" class="data row0 col0" >0.015105</td>
#       <td id="T_e129c_row0_col1" class="data row0 col1" >0.489739</td>
#       <td id="T_e129c_row0_col2" class="data row0 col2" >-0.207146</td>
#       <td id="T_e129c_row0_col3" class="data row0 col3" >0.003460</td>
#       <td id="T_e129c_row0_col4" class="data row0 col4" >0.012637</td>
#       <td id="T_e129c_row0_col5" class="data row0 col5" >0.019983</td>
#       <td id="T_e129c_row0_col6" class="data row0 col6" >29.417698</td>
#       <td id="T_e129c_row0_col7" class="data row0 col7" >54.633073</td>
#     </tr>
#     <tr>
#       <th id="T_e129c_level0_row1" class="row_heading level0 row1" >ADV\_tok\_per\_sent</th>
#       <td id="T_e129c_row1_col0" class="data row1 col0" >1.300675</td>
#       <td id="T_e129c_row1_col1" class="data row1 col1" >0.044423</td>
#       <td id="T_e129c_row1_col2" class="data row1 col2" >1.064536</td>
#       <td id="T_e129c_row1_col3" class="data row1 col3" >1.301333</td>
#       <td id="T_e129c_row1_col4" class="data row1 col4" >1.311478</td>
#       <td id="T_e129c_row1_col5" class="data row1 col5" >1.319974</td>
#       <td id="T_e129c_row1_col6" class="data row1 col6" >1.387743</td>
#       <td id="T_e129c_row1_col7" class="data row1 col7" >4704.540347</td>
#     </tr>
#     <tr>
#       <th id="T_e129c_level0_row2" class="row_heading level0 row2" >ADJ\_tok\_per\_sent</th>
#       <td id="T_e129c_row2_col0" class="data row2 col0" >1.298847</td>
#       <td id="T_e129c_row2_col1" class="data row2 col1" >0.045074</td>
#       <td id="T_e129c_row2_col2" class="data row2 col2" >0.975717</td>
#       <td id="T_e129c_row2_col3" class="data row2 col3" >1.291274</td>
#       <td id="T_e129c_row2_col4" class="data row2 col4" >1.302782</td>
#       <td id="T_e129c_row2_col5" class="data row2 col5" >1.314372</td>
#       <td id="T_e129c_row2_col6" class="data row2 col6" >1.730090</td>
#       <td id="T_e129c_row2_col7" class="data row2 col7" >4697.930290</td>
#     </tr>
#     <tr>
#       <th id="T_e129c_level0_row3" class="row_heading level0 row3" >NEG\_tok\_per\_sent</th>
#       <td id="T_e129c_row3_col0" class="data row3 col0" >0.144642</td>
#       <td id="T_e129c_row3_col1" class="data row3 col1" >0.026795</td>
#       <td id="T_e129c_row3_col2" class="data row3 col2" >0.031708</td>
#       <td id="T_e129c_row3_col3" class="data row3 col3" >0.149225</td>
#       <td id="T_e129c_row3_col4" class="data row3 col4" >0.152656</td>
#       <td id="T_e129c_row3_col5" class="data row3 col5" >0.155844</td>
#       <td id="T_e129c_row3_col6" class="data row3 col6" >0.188230</td>
#       <td id="T_e129c_row3_col7" class="data row3 col7" >523.170331</td>
#     </tr>
#     <tr>
#       <th id="T_e129c_level0_row4" class="row_heading level0 row4" >NEG\_tok\_per\_mill</th>
#       <td id="T_e129c_row4_col0" class="data row4 col0" >4686.903732</td>
#       <td id="T_e129c_row4_col1" class="data row4 col1" >1654.886587</td>
#       <td id="T_e129c_row4_col2" class="data row4 col2" >-86285.862127</td>
#       <td id="T_e129c_row4_col3" class="data row4 col3" >4784.877305</td>
#       <td id="T_e129c_row4_col4" class="data row4 col4" >4898.730270</td>
#       <td id="T_e129c_row4_col5" class="data row4 col5" >5000.881611</td>
#       <td id="T_e129c_row4_col6" class="data row4 col6" >6033.782075</td>
#       <td id="T_e129c_row4_col7" class="data row4 col7" >16952530.800093</td>
#     </tr>
#     <tr>
#       <th id="T_e129c_level0_row5" class="row_heading level0 row5" >ADV\_tok\_per\_mill</th>
#       <td id="T_e129c_row5_col0" class="data row5 col0" >42848.182686</td>
#       <td id="T_e129c_row5_col1" class="data row5 col1" >7973.780074</td>
#       <td id="T_e129c_row5_col2" class="data row5 col2" >-410894.976566</td>
#       <td id="T_e129c_row5_col3" class="data row5 col3" >41916.697892</td>
#       <td id="T_e129c_row5_col4" class="
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-rates-birc-minus-full-descrip-stats.2025-02-17.tex
# <style type="text/css">
# #T_2983b th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_2983b th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2983b th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2983b caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_2983b th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_2983b th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2983b th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2983b caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_2983b_row0_col0, #T_2983b_row0_col1, #T_2983b_row0_col2, #T_2983b_row0_col3, #T_2983b_row1_col0, #T_2983b_row1_col1, #T_2983b_row1_col2, #T_2983b_row1_col3, #T_2983b_row2_col0, #T_2983b_row2_col1, #T_2983b_row2_col2, #T_2983b_row2_col3, #T_2983b_row3_col0, #T_2983b_row3_col1, #T_2983b_row3_col2, #T_2983b_row3_col3, #T_2983b_row4_col0, #T_2983b_row4_col1, #T_2983b_row4_col2, #T_2983b_row4_col3, #T_2983b_row5_col0, #T_2983b_row5_col1, #T_2983b_row5_col2, #T_2983b_row5_col3, #T_2983b_row6_col0, #T_2983b_row6_col1, #T_2983b_row6_col2, #T_2983b_row6_col3, #T_2983b_row7_col0, #T_2983b_row7_col1, #T_2983b_row7_col2, #T_2983b_row7_col3, #T_2983b_row8_col0, #T_2983b_row8_col1, #T_2983b_row8_col2, #T_2983b_row8_col3, #T_2983b_row9_col0, #T_2983b_row9_col1, #T_2983b_row9_col2, #T_2983b_row9_col3, #T_2983b_row10_col0, #T_2983b_row10_col1, #T_2983b_row10_col2, #T_2983b_row10_col3, #T_2983b_row11_col0, #T_2983b_row11_col1, #T_2983b_row11_col2, #T_2983b_row11_col3, #T_2983b_row12_col0, #T_2983b_row12_col1, #T_2983b_row12_col2, #T_2983b_row12_col3, #T_2983b_row13_col0, #T_2983b_row13_col1, #T_2983b_row13_col2, #T_2983b_row13_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_2983b">
#   <caption>"Rate" columns for <code>BiRC - Full</code> counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_2983b_level0_col0" class="col_heading level0 col0" >apw_eng_200808</th>
#       <th id="T_2983b_level0_col1" class="col_heading level0 col1" >pcc_eng_07-019</th>
#       <th id="T_2983b_level0_col2" class="col_heading level0 col2" >pcc_eng_20-020</th>
#       <th id="T_2983b_level0_col3" class="col_heading level0 col3" >pcc_eng_23-094</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2983b_level0_row0" class="row_heading level0 row0" >tok_per_sent</th>
#       <td id="T_2983b_row0_col0" class="data row0 col0" >-0.09</td>
#       <td id="T_2983b_row0_col1" class="data row0 col1" >0.02</td>
#       <td id="T_2983b_row0_col2" class="data row0 col2" >-0.02</td>
#       <td id="T_2983b_row0_col3" class="data row0 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row1" class="row_heading level0 row1" >ADV_tok_per_sent</th>
#       <td id="T_2983b_row1_col0" class="data row1 col0" >1.20</td>
#       <td id="T_2983b_row1_col1" class="data row1 col1" >1.32</td>
#       <td id="T_2983b_row1_col2" class="data row1 col2" >1.34</td>
#       <td id="T_2983b_row1_col3" class="data row1 col3" >1.31</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row2" class="row_heading level0 row2" >ADJ_tok_per_sent</th>
#       <td id="T_2983b_row2_col0" class="data row2 col0" >1.22</td>
#       <td id="T_2983b_row2_col1" class="data row2 col1" >1.30</td>
#       <td id="T_2983b_row2_col2" class="data row2 col2" >1.35</td>
#       <td id="T_2983b_row2_col3" class="data row2 col3" >1.30</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row3" class="row_heading level0 row3" >NEG_tok_per_sent</th>
#       <td id="T_2983b_row3_col0" class="data row3 col0" >0.08</td>
#       <td id="T_2983b_row3_col1" class="data row3 col1" >0.15</td>
#       <td id="T_2983b_row3_col2" class="data row3 col2" >0.16</td>
#       <td id="T_2983b_row3_col3" class="data row3 col3" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_2983b_row4_col0" class="data row4 col0" >3,311.18</td>
#       <td id="T_2983b_row4_col1" class="data row4 col1" >4,963.98</td>
#       <td id="T_2983b_row4_col2" class="data row4 col2" >5,093.35</td>
#       <td id="T_2983b_row4_col3" class="data row4 col3" >4,792.82</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row5" class="row_heading level0 row5" >ADV_tok_per_mill</th>
#       <td id="T_2983b_row5_col0" class="data row5 col0" >50,961.92</td>
#       <td id="T_2983b_row5_col1" class="data row5 col1" >42,225.48</td>
#       <td id="T_2983b_row5_col2" class="data row5 col2" >43,058.45</td>
#       <td id="T_2983b_row5_col3" class="data row5 col3" >42,126.84</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row6" class="row_heading level0 row6" >ADJ_tok_per_mill</th>
#       <td id="T_2983b_row6_col0" class="data row6 col0" >51,896.24</td>
#       <td id="T_2983b_row6_col1" class="data row6 col1" >41,765.58</td>
#       <td id="T_2983b_row6_col2" class="data row6 col2" >43,269.45</td>
#       <td id="T_2983b_row6_col3" class="data row6 col3" >41,788.18</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row7" class="row_heading level0 row7" >ADV_form_per_lemma</th>
#       <td id="T_2983b_row7_col0" class="data row7 col0" >-0.02</td>
#       <td id="T_2983b_row7_col1" class="data row7 col1" >-0.05</td>
#       <td id="T_2983b_row7_col2" class="data row7 col2" >-0.05</td>
#       <td id="T_2983b_row7_col3" class="data row7 col3" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row8" class="row_heading level0 row8" >ADV_tok_per_lemma</th>
#       <td id="T_2983b_row8_col0" class="data row8 col0" >-90.51</td>
#       <td id="T_2983b_row8_col1" class="data row8 col1" >-49.57</td>
#       <td id="T_2983b_row8_col2" class="data row8 col2" >-49.74</td>
#       <td id="T_2983b_row8_col3" class="data row8 col3" >-48.92</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row9" class="row_heading level0 row9" >ADV_tok_per_form</th>
#       <td id="T_2983b_row9_col0" class="data row9 col0" >-81.31</td>
#       <td id="T_2983b_row9_col1" class="data row9 col1" >-37.17</td>
#       <td id="T_2983b_row9_col2" class="data row9 col2" >-37.15</td>
#       <td id="T_2983b_row9_col3" class="data row9 col3" >-36.54</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row10" class="row_heading level0 row10" >ADJ_form_per_lemma</th>
#       <td id="T_2983b_row10_col0" class="data row10 col0" >-0.01</td>
#       <td id="T_2983b_row10_col1" class="data row10 col1" >-0.05</td>
#       <td id="T_2983b_row10_col2" class="data row10 col2" >-0.04</td>
#       <td id="T_2983b_row10_col3" class="data row10 col3" >-0.04</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row11" class="row_heading level0 row11" >ADJ_tok_per_lemma</th>
#       <td id="T_2983b_row11_col0" class="data row11 col0" >-18.98</td>
#       <td id="T_2983b_row11_col1" class="data row11 col1" >-11.39</td>
#       <td id="T_2983b_row11_col2" class="data row11 col2" >-11.26</td>
#       <td id="T_2983b_row11_col3" class="data row11 col3" >-11.29</td>
#     </tr>
#     <tr>
#       <th id="T_2983b_level0_row12" class="row_heading level0 row12" >ADJ_tok_per_form</th>
#       <td id="T_2983b_row12_col0" class="data row12 col0" >-18.28</td>
#       <td id="T_2983b_row12_col1" class="data row12 col1" >-9.50</td>
#       <td id="T_2983b_row12_col2" class="dat

# %%
# %%

def reconfigure_counts(_counts_df, count_kind: str):
    return _counts_df.assign(
        kind=count_kind
    ).reset_index().set_index(['kind', 'corpus_slice']).unstack('kind')


orig_s = reconfigure_counts(orig_counts_df, count_kind='Full')
birc_s = reconfigure_counts(birc_counts_df, 'BiRC')
diff_s = reconfigure_counts(reduction_df, 'diff')
juxta = orig_s.join(birc_s).join(diff_s).convert_dtypes().sort_index(axis=1)

# juxta = orig_counts_df.join(birc_counts_df, rsuffix=':BiRC', lsuffix=':Full').join(reduction_df.add_suffix(':diff')).convert_dtypes()
juxta_desc = juxta.describe().iloc[1:, :]
juxta_desc.loc['TOTAL', :] = juxta.sum()
juxta_desc.index = juxta_desc.index.str.upper()
juxta_desc.loc['CV%', :] = (
    (juxta_desc.T.STD / juxta_desc.T.MEAN).fillna(0) * 100)
save_latex_table(juxta_desc.T.convert_dtypes(),
                 caption='Juxtaposed BiRC: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='birc-juxtaposed-descrip-stats-complete')

juxta = pd.concat([juxta, juxta_desc])
# juxtaT = juxta.T.assign(TOTAL=juxta.sum(), MEAN=juxta.mean(), MEDIAN=juxta.median(),
#                         MAX=juxta.max(), MIN=juxta.min(),
#                         STD=juxta.std())
# juxta = juxtaT.sort_index().T.sort_index()
juxta = juxta.sort_index().sort_index(axis=1)
# Out:
# Caption: Juxtaposed BiRC: Descriptive Stats
# <style type="text/css">
# #T_435b8 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_435b8 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_435b8 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_435b8 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_435b8_row0_col0, #T_435b8_row0_col1, #T_435b8_row0_col2, #T_435b8_row0_col3, #T_435b8_row0_col4, #T_435b8_row0_col5, #T_435b8_row0_col6, #T_435b8_row0_col7, #T_435b8_row0_col8, #T_435b8_row1_col0, #T_435b8_row1_col1, #T_435b8_row1_col2, #T_435b8_row1_col3, #T_435b8_row1_col4, #T_435b8_row1_col5, #T_435b8_row1_col6, #T_435b8_row1_col7, #T_435b8_row1_col8, #T_435b8_row2_col0, #T_435b8_row2_col1, #T_435b8_row2_col2, #T_435b8_row2_col3, #T_435b8_row2_col4, #T_435b8_row2_col5, #T_435b8_row2_col6, #T_435b8_row2_col7, #T_435b8_row2_col8, #T_435b8_row3_col0, #T_435b8_row3_col1, #T_435b8_row3_col2, #T_435b8_row3_col3, #T_435b8_row3_col4, #T_435b8_row3_col5, #T_435b8_row3_col6, #T_435b8_row3_col7, #T_435b8_row3_col8, #T_435b8_row4_col0, #T_435b8_row4_col1, #T_435b8_row4_col2, #T_435b8_row4_col3, #T_435b8_row4_col4, #T_435b8_row4_col5, #T_435b8_row4_col6, #T_435b8_row4_col7, #T_435b8_row4_col8, #T_435b8_row5_col0, #T_435b8_row5_col1, #T_435b8_row5_col2, #T_435b8_row5_col3, #T_435b8_row5_col4, #T_435b8_row5_col5, #T_435b8_row5_col6, #T_435b8_row5_col7, #T_435b8_row5_col8, #T_435b8_row6_col0, #T_435b8_row6_col1, #T_435b8_row6_col2, #T_435b8_row6_col3, #T_435b8_row6_col4, #T_435b8_row6_col5, #T_435b8_row6_col6, #T_435b8_row6_col7, #T_435b8_row6_col8, #T_435b8_row7_col0, #T_435b8_row7_col1, #T_435b8_row7_col2, #T_435b8_row7_col3, #T_435b8_row7_col4, #T_435b8_row7_col5, #T_435b8_row7_col6, #T_435b8_row7_col7, #T_435b8_row7_col8, #T_435b8_row8_col0, #T_435b8_row8_col1, #T_435b8_row8_col2, #T_435b8_row8_col3, #T_435b8_row8_col4, #T_435b8_row8_col5, #T_435b8_row8_col6, #T_435b8_row8_col7, #T_435b8_row8_col8, #T_435b8_row9_col0, #T_435b8_row9_col1, #T_435b8_row9_col2, #T_435b8_row9_col3, #T_435b8_row9_col4, #T_435b8_row9_col5, #T_435b8_row9_col6, #T_435b8_row9_col7, #T_435b8_row9_col8, #T_435b8_row10_col0, #T_435b8_row10_col1, #T_435b8_row10_col2, #T_435b8_row10_col3, #T_435b8_row10_col4, #T_435b8_row10_col5, #T_435b8_row10_col6, #T_435b8_row10_col7, #T_435b8_row10_col8, #T_435b8_row11_col0, #T_435b8_row11_col1, #T_435b8_row11_col2, #T_435b8_row11_col3, #T_435b8_row11_col4, #T_435b8_row11_col5, #T_435b8_row11_col6, #T_435b8_row11_col7, #T_435b8_row11_col8, #T_435b8_row12_col0, #T_435b8_row12_col1, #T_435b8_row12_col2, #T_435b8_row12_col3, #T_435b8_row12_col4, #T_435b8_row12_col5, #T_435b8_row12_col6, #T_435b8_row12_col7, #T_435b8_row12_col8, #T_435b8_row13_col0, #T_435b8_row13_col1, #T_435b8_row13_col2, #T_435b8_row13_col3, #T_435b8_row13_col4, #T_435b8_row13_col5, #T_435b8_row13_col6, #T_435b8_row13_col7, #T_435b8_row13_col8, #T_435b8_row14_col0, #T_435b8_row14_col1, #T_435b8_row14_col2, #T_435b8_row14_col3, #T_435b8_row14_col4, #T_435b8_row14_col5, #T_435b8_row14_col6, #T_435b8_row14_col7, #T_435b8_row14_col8, #T_435b8_row15_col0, #T_435b8_row15_col1, #T_435b8_row15_col2, #T_435b8_row15_col3, #T_435b8_row15_col4, #T_435b8_row15_col5, #T_435b8_row15_col6, #T_435b8_row15_col7, #T_435b8_row15_col8, #T_435b8_row16_col0, #T_435b8_row16_col1, #T_435b8_row16_col2, #T_435b8_row16_col3, #T_435b8_row16_col4, #T_435b8_row16_col5, #T_435b8_row16_col6, #T_435b8_row16_col7, #T_435b8_row16_col8, #T_435b8_row17_col0, #T_435b8_row17_col1, #T_435b8_row17_col2, #T_435b8_row17_col3, #T_435b8_row17_col4, #T_435b8_row17_col5, #T_435b8_row17_col6, #T_435b8_row17_col7, #T_435b8_row17_col8, #T_435b8_row18_col0, #T_435b8_row18_col1, #T_435b8_row18_col2, #T_435b8_row18_col3, #T_435b8_row18_col4, #T_435b8_row18_col5, #T_435b8_row18_col6, #T_435b8_row18_col7, #T_435b8_row18_col8, #T_435b8_row19_col0, #T_435b8_row19_col1, #T_435b8_row19_col2, #T_435b8_row19_col3, #T_435b8_row19_col4, #T_435b8_row19_col5, #T_435b8_row19_col6, #T_435b8_row19_col7, #T_435b8_row19_col8, #T_435b8_row20_col0, #T_435b8_row20_col1, #T_435b8_row20_col2, #T_435b8_row20_col3, #T_435b8_row20_col4, #T_435b8_row20_col5, #T_435b8_row20_col6, #T_435b8_row20_col7, #T_435b8_row20_col8, #T_435b8_row21_col0, #T_435b8_row21_col1, #T_435b8_row21_col2, #T_435b8_row21_col3, #T_435b8_row21_col4, #T_435b8_row21_c ...
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/birc-juxtaposed-descrip-stats-complete.2025-02-17.tex

# %%
# %%

save_latex_table(
    pd.concat([
        juxta.filter(like='apw', axis=0).sample(1), 
        juxta.filter(like='nyt', axis=0).sample(1),
        # 👆 to ensure at least one sample of apw  and news are included
        juxta.iloc[9:, :].sample(15)
    ]).drop_duplicates().sort_index().T,
    caption=('Sample of Juxtaposed Counts'),
    verbose=True,
    latex_subdir=REL_BIRC_TEX_DIR,
    latex_stem='birc-juxtaposed-sample')
# Out:
# Caption: Sample of Juxtaposed Counts
# <style type="text/css">
# #T_299c2 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_299c2 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_299c2 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_299c2 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_299c2_row0_col0, #T_299c2_row0_col1, #T_299c2_row0_col2, #T_299c2_row0_col3, #T_299c2_row0_col4, #T_299c2_row0_col5, #T_299c2_row0_col6, #T_299c2_row0_col7, #T_299c2_row0_col8, #T_299c2_row0_col9, #T_299c2_row0_col10, #T_299c2_row0_col11, #T_299c2_row0_col12, #T_299c2_row0_col13, #T_299c2_row0_col14, #T_299c2_row0_col15, #T_299c2_row0_col16, #T_299c2_row1_col0, #T_299c2_row1_col1, #T_299c2_row1_col2, #T_299c2_row1_col3, #T_299c2_row1_col4, #T_299c2_row1_col5, #T_299c2_row1_col6, #T_299c2_row1_col7, #T_299c2_row1_col8, #T_299c2_row1_col9, #T_299c2_row1_col10, #T_299c2_row1_col11, #T_299c2_row1_col12, #T_299c2_row1_col13, #T_299c2_row1_col14, #T_299c2_row1_col15, #T_299c2_row1_col16, #T_299c2_row2_col0, #T_299c2_row2_col1, #T_299c2_row2_col2, #T_299c2_row2_col3, #T_299c2_row2_col4, #T_299c2_row2_col5, #T_299c2_row2_col6, #T_299c2_row2_col7, #T_299c2_row2_col8, #T_299c2_row2_col9, #T_299c2_row2_col10, #T_299c2_row2_col11, #T_299c2_row2_col12, #T_299c2_row2_col13, #T_299c2_row2_col14, #T_299c2_row2_col15, #T_299c2_row2_col16, #T_299c2_row3_col0, #T_299c2_row3_col1, #T_299c2_row3_col2, #T_299c2_row3_col3, #T_299c2_row3_col4, #T_299c2_row3_col5, #T_299c2_row3_col6, #T_299c2_row3_col7, #T_299c2_row3_col8, #T_299c2_row3_col9, #T_299c2_row3_col10, #T_299c2_row3_col11, #T_299c2_row3_col12, #T_299c2_row3_col13, #T_299c2_row3_col14, #T_299c2_row3_col15, #T_299c2_row3_col16, #T_299c2_row4_col0, #T_299c2_row4_col1, #T_299c2_row4_col2, #T_299c2_row4_col3, #T_299c2_row4_col4, #T_299c2_row4_col5, #T_299c2_row4_col6, #T_299c2_row4_col7, #T_299c2_row4_col8, #T_299c2_row4_col9, #T_299c2_row4_col10, #T_299c2_row4_col11, #T_299c2_row4_col12, #T_299c2_row4_col13, #T_299c2_row4_col14, #T_299c2_row4_col15, #T_299c2_row4_col16, #T_299c2_row5_col0, #T_299c2_row5_col1, #T_299c2_row5_col2, #T_299c2_row5_col3, #T_299c2_row5_col4, #T_299c2_row5_col5, #T_299c2_row5_col6, #T_299c2_row5_col7, #T_299c2_row5_col8, #T_299c2_row5_col9, #T_299c2_row5_col10, #T_299c2_row5_col11, #T_299c2_row5_col12, #T_299c2_row5_col13, #T_299c2_row5_col14, #T_299c2_row5_col15, #T_299c2_row5_col16, #T_299c2_row6_col0, #T_299c2_row6_col1, #T_299c2_row6_col2, #T_299c2_row6_col3, #T_299c2_row6_col4, #T_299c2_row6_col5, #T_299c2_row6_col6, #T_299c2_row6_col7, #T_299c2_row6_col8, #T_299c2_row6_col9, #T_299c2_row6_col10, #T_299c2_row6_col11, #T_299c2_row6_col12, #T_299c2_row6_col13, #T_299c2_row6_col14, #T_299c2_row6_col15, #T_299c2_row6_col16, #T_299c2_row7_col0, #T_299c2_row7_col1, #T_299c2_row7_col2, #T_299c2_row7_col3, #T_299c2_row7_col4, #T_299c2_row7_col5, #T_299c2_row7_col6, #T_299c2_row7_col7, #T_299c2_row7_col8, #T_299c2_row7_col9, #T_299c2_row7_col10, #T_299c2_row7_col11, #T_299c2_row7_col12, #T_299c2_row7_col13, #T_299c2_row7_col14, #T_299c2_row7_col15, #T_299c2_row7_col16, #T_299c2_row8_col0, #T_299c2_row8_col1, #T_299c2_row8_col2, #T_299c2_row8_col3, #T_299c2_row8_col4, #T_299c2_row8_col5, #T_299c2_row8_col6, #T_299c2_row8_col7, #T_299c2_row8_col8, #T_299c2_row8_col9, #T_299c2_row8_col10, #T_299c2_row8_col11, #T_299c2_row8_col12, #T_299c2_row8_col13, #T_299c2_row8_col14, #T_299c2_row8_col15, #T_299c2_row8_col16, #T_299c2_row9_col0, #T_299c2_row9_col1, #T_299c2_row9_col2, #T_299c2_row9_col3, #T_299c2_row9_col4, #T_299c2_row9_col5, #T_299c2_row9_col6, #T_299c2_row9_col7, #T_299c2_row9_col8, #T_299c2_row9_col9, #T_299c2_row9_col10, #T_299c2_row9_col11, #T_299c2_row9_col12, #T_299c2_row9_col13, #T_299c2_row9_col14, #T_299c2_row9_col15, #T_299c2_row9_col16, #T_299c2_row10_col0, #T_299c2_row10_col1, #T_299c2_row10_col2, #T_299c2_row10_col3, #T_299c2_row10_col4, #T_299c2_row10_col5, #T_299c2_row10_col6, #T_299c2_row10_col7, #T_299c2_row10_col8, #T_299c2_row10_col9, #T_299c2_row10_col10, #T_299c2_row10_col11, #T_299c2_row10_col12, #T_299c2_row10_col13, #T_299c2_row10_col14, #T_299c2_row10_col15, #T_299c2_row10_col16, #T_299c2_row11_col0, #T_299c2_row11_col1, #T_299c2_row11_col2, #T_299c2_row11_col3, #T_299c2_row11_col4, #T_299c2_row11_col5, #T_299c2_row11_col6, #T_299c2_row11_col7 ...
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/birc-juxtaposed-sample.2025-02-17.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/birc-juxtaposed-sample.2025-02-17.tex')
