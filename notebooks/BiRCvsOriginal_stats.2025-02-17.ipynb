# %% [markdown]
# # Compilation of All Counts for <font color=DodgerBlue><u>*Original Corpora*</u></font> & <font color=Brown><u>***BiRC***</u></font>
# ___`BiRC`___ $=\text{``bigram restricted corpus'' or }\texttt{bigram\_subset}$

# %% [markdown]
# ### *imports*

# %%
from pathlib import Path
import pandas as pd
from am_notebooks import *

#! Toggle TESTING
TESTING = False
if TESTING:
    print(
        '🚨⚠️ WARNING!\n  This is a **TEST** run!'
        'Full count data will not be loaded or saved\n'
    )

# // from utils import file_size_round
SUBSET_DATA_DIR = Path('/share/compling/data/sanpi/subsets')
print(
    '==============================\n'
    f'Date: {pd.Timestamp.now().ctime()}\n'
    '=============================='
)

BIRC_INFO_DIR = SANPI_HOME.joinpath('info/BiRC')
confirm_dir(BIRC_INFO_DIR)
BIRC_META_CSV = BIRC_INFO_DIR.joinpath('meta-info-full.csv')
REL_BIRC_TEX_DIR ='ch6/BiRC'
BIRC_TEX_DIR = LATEX_TABLES.joinpath(REL_BIRC_TEX_DIR)
confirm_dir(BIRC_TEX_DIR)
# Out:
# ==============================
# Date: Tue Feb 18 00:19:32 2025
# ==============================

# %% [markdown]
#  ## **Define functions** to compile all the disparate meta info...

# %%
def collect_subset_path_index():
    """Collect subset path index information.

    This function gathers information about subset paths, including parent directory,
    name, full path, source path (from symlink), BiRC subcorpus, size, and other
    relevant details. It then processes this information to create a DataFrame with
    additional derived columns, such as 'init_conllu', 'data_key', 'corpus_part',
    'corpus', 'subset_info_dir', and 'path_index_csv'.

    Returns:
        pd.DataFrame: A DataFrame containing the collected subset path index info.
    """
    data = {p.stem:
            {
                'parent': p.parent.name,
                'name': p.name,
                'path': p,
                'source_path': p.readlink(),
                'birc_subcorpus': p.parent.parent.stem,
                'is_link': p.is_symlink(),
                # 'size': file_size_round(p.stat().st_size),
                'size': p.stat().st_size,  # ! no longer forcing into different units
            }
            for p in SUBSET_DATA_DIR.rglob('*.conllu')
            #! to prevent *DEMO* files being included:
            if not p.parent.name.startswith('bigram-DEMO')
            }
    bp_df = pd.DataFrame.from_dict(data, orient='index').convert_dtypes()
    bp_df
    bp_df['init_conllu'] = bp_df.name.str.replace('BIGRAM.', '', regex=False)
    bp_df['data_key'] = bp_df.index.str.replace('BIGRAM.', '', regex=False)

    bp_df['corpus_part'], bp_df['corpus'], bp_df['subset_info_dir'] = zip(
        *bp_df.source_path.apply(
            lambda sp: (sp.parent.parent.stem,
                        sp.parent.parent.parent.stem,
                        sp.parent.joinpath('info')))
    )
    bp_df = bp_df.convert_dtypes()

    set_my_style(bp_df.sample(1).T)

    bp_df['path_index_csv'] = bp_df.subset_info_dir.apply(
        lambda i: max(i.glob('subset-bigram_path-index*csv'),
                      key=lambda file: file.stat().st_ctime))

    try:
        path_info = pd.read_csv(X.path_index_csv,
                                usecols=['STEM', ' INPUT_COUNTS',
                                         ' SUBSET_COUNTS']
                                ).set_index('STEM')
    except ValueError:
        path_info = pd.read_csv(X.path_index_csv,
                                usecols=['STEM', 'INPUT_COUNTS',
                                         'SUBSET_COUNTS']
                                ).set_index('STEM')

    path_info.columns = path_info.columns.str.strip().str.lower()
    path_info.columns

    for stem in path_info.sample(3).T:
        print(f'- {stem}')
        print(f'  - input_counts = {path_info.input_counts[stem]}')
        print(f'  - subset_counts = {path_info.subset_counts[stem]}')

    bp_df.index.name = 'subset_stem'
    return bp_df.reset_index().set_index('data_key')


def collect_meta_info(_bp_df):
    """Collect metadata information from various sources.

    This function groups the input DataFrame by 'path_index_csv', reads data from
    corresponding CSV files, joins the data with the original DataFrame, and
    concatenates the results into a single DataFrame. It also performs some
    string cleaning on the resulting DataFrame's columns.

    Args:
        _bp_df (pd.DataFrame): DataFrame containing file paths and other info.

    Returns:
        pd.DataFrame: A DataFrame containing the combined metadata information.
    """
    subframes = []
    for path_ix, df in _bp_df.groupby('path_index_csv'):
        print(path_ix)
        if 'DEMO' in str(path_ix):
            continue
        try:
            path_info = pd.read_csv(
                path_ix,
                usecols=['STEM', ' INPUT_COUNTS', ' SUBSET_COUNTS']
            ).set_index('STEM')
        except ValueError:
            path_info = pd.read_csv(
                path_ix,
                usecols=['STEM', 'INPUT_COUNTS', 'SUBSET_COUNTS']
            ).set_index('STEM')
        display(set_my_style(df.head(1).T, caption=str(
            path_ix.relative_to('/share/compling/data'))))
        subframes.append(df.join(path_info))

    meta_df = pd.concat(subframes)
    meta_df.iloc[:, -2:] = meta_df.iloc[:, -2:].apply(lambda x: x.str.strip())
    meta_df.columns = meta_df.columns.str.strip().str.lower()
    return meta_df

# %% [markdown]
#  ## **Create or read meta info**

# %%
if BIRC_META_CSV.is_file():
    meta_df = pd.read_csv(BIRC_META_CSV, index_col='data_key').convert_dtypes()
    print(f'Meta Info DataFrame loaded from "{BIRC_META_CSV}"')
else:
    bp_df = collect_subset_path_index()
    meta_df = collect_meta_info(bp_df)
    meta_df.to_csv(BIRC_META_CSV)

set_my_style(
    meta_df.head(1).T,
    caption='First Line of Meta DataFrame')
# Out:
# Meta Info DataFrame loaded from "/share/compling/projects/sanpi/info/BiRC/meta-info-full.csv"
# <style type="text/css">
# #T_e4103 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e4103 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e4103 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e4103 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e4103_row0_col0, #T_e4103_row1_col0, #T_e4103_row2_col0, #T_e4103_row3_col0, #T_e4103_row4_col0, #T_e4103_row5_col0, #T_e4103_row6_col0, #T_e4103_row7_col0, #T_e4103_row8_col0, #T_e4103_row9_col0, #T_e4103_row10_col0, #T_e4103_row11_col0, #T_e4103_row12_col0, #T_e4103_row13_col0, #T_e4103_row14_col0 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_e4103">
#   <caption>First Line of Meta DataFrame</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >data_key</th>
#       <th id="T_e4103_level0_col0" class="col_heading level0 col0" >apw_eng_199411</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e4103_level0_row0" class="row_heading level0 row0" >subset_stem</th>
#       <td id="T_e4103_row0_col0" class="data row0 col0" >BIGRAM.apw_eng_199411</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row1" class="row_heading level0 row1" >parent</th>
#       <td id="T_e4103_row1_col0" class="data row1 col0" >bigram-Apw</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row2" class="row_heading level0 row2" >name</th>
#       <td id="T_e4103_row2_col0" class="data row2 col0" >BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row3" class="row_heading level0 row3" >path</th>
#       <td id="T_e4103_row3_col0" class="data row3 col0" >/share/compling/data/sanpi/subsets/bigram_news/bigram-Apw/BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row4" class="row_heading level0 row4" >source_path</th>
#       <td id="T_e4103_row4_col0" class="data row4 col0" >/share/compling/data/news/Apw.conll/subset_bigram/BIGRAM.apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row5" class="row_heading level0 row5" >birc_subcorpus</th>
#       <td id="T_e4103_row5_col0" class="data row5 col0" >bigram_news</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row6" class="row_heading level0 row6" >is_link</th>
#       <td id="T_e4103_row6_col0" class="data row6 col0" >True</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row7" class="row_heading level0 row7" >size</th>
#       <td id="T_e4103_row7_col0" class="data row7 col0" >11,162,354</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row8" class="row_heading level0 row8" >init_conllu</th>
#       <td id="T_e4103_row8_col0" class="data row8 col0" >apw_eng_199411.conllu</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row9" class="row_heading level0 row9" >corpus_part</th>
#       <td id="T_e4103_row9_col0" class="data row9 col0" >Apw</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row10" class="row_heading level0 row10" >corpus</th>
#       <td id="T_e4103_row10_col0" class="data row10 col0" >news</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row11" class="row_heading level0 row11" >subset_info_dir</th>
#       <td id="T_e4103_row11_col0" class="data row11 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row12" class="row_heading level0 row12" >path_index_csv</th>
#       <td id="T_e4103_row12_col0" class="data row12 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info/subset-bigram_path-index.2023-04-11_0525.csv</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row13" class="row_heading level0 row13" >input_counts</th>
#       <td id="T_e4103_row13_col0" class="data row13 col0" >/share/compling/data/news/Apw.conll/info/apw_eng_199411.counts.json</td>
#     </tr>
#     <tr>
#       <th id="T_e4103_level0_row14" class="row_heading level0 row14" >subset_counts</th>
#       <td id="T_e4103_row14_col0" class="data row14 col0" >/share/compling/data/news/Apw.conll/subset_bigram/info/BIGRAM.apw_eng_199411.counts.json</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
#  ## *Define functions* to retrieve count data

# %%
def load_totals(counts_path):
    """Load total counts from a JSON file.

    This function reads a JSON file containing counts data, extracts the 'total'
    column, drops any missing values (NaN), and returns the result as a dictionary.
    If the provided path is not absolute, it prepends the sanpi data directory.

    Args:
        counts_path (str or Path): Path to the JSON file.

    Returns:
        dict: A dictionary containing the total counts, with keys corresponding to
            the original index of the 'total' column.
    """

    if not Path(counts_path).is_absolute():
        counts_path = f"/share/compling/data/sanpi/{counts_path}"
    counts_df = pd.read_json(counts_path)
    return counts_df.loc[:, 'total'].dropna().to_dict()


def generate_counts(_meta_df, retrieval_key='input'):
    """Generate counts for each data key.

    This generator iterates through the index of the input DataFrame, retrieves the
    counts path based on the retrieval key, and yields the data key along with its
    corresponding counts.

    Args:
        _meta_df (pd.DataFrame): DataFrame containing metadata information.
        retrieval_key (str, optional): Key used to retrieve the counts path.
            Defaults to 'input'.

    Yields:
        tuple: A tuple containing the data key and its corresponding counts.
    """
    for data_key in _meta_df.index:
        counts_path = _meta_df.at[data_key, f'{retrieval_key}_counts']
        yield data_key, load_totals(counts_path)


def retrieve_count_data(_counts_csv_path, _meta_df, test=False):
    seek_birc = "birc" in _counts_csv_path.name.lower()
    _counts_label = "BiRC" if seek_birc else "Original"
    if _counts_csv_path.is_file():
        try:
            _counts_df = pd.read_csv(_counts_csv_path,
                                     index_col='corpus_slice').convert_dtypes()
        except ValueError:
            _counts_df = pd.read_csv(_counts_csv_path).convert_dtypes()

        print(
            f'**{_counts_label} Counts** read from csv',
            f'> Path: {_counts_csv_path.relative_to(SANPI_HOME)}',
            sep='\n')
    else:
        _meta_selection = _meta_df.copy().sample(100) if test else _meta_df.copy()
        _counts_df = pd.DataFrame.from_dict(
            {k: c for k, c in generate_counts(
                _meta_df=_meta_selection,
                retrieval_key='subset' if seek_birc else 'input')},
            orient='index')
        _counts_df.index.name = 'corpus_slice'
        _counts_df = _counts_df.reset_index().convert_dtypes().set_index('corpus_slice')
        print(
            f'**{_counts_label} Counts** saved as csv',
            f'> Path: {_counts_csv_path.relative_to(SANPI_HOME)}',
            sep='\n')
        if test:
            print('TESTING (so, not really)')
        else:
            _counts_df.to_csv(_counts_csv_path)
    return _counts_df.loc[:, ~_counts_df.columns.str.startswith('NR_')]

# %% [markdown]
#  ## **Load <font color=DodgerBlue><u>Original</u></font> counts** (if not previously collected)

# %%
orig_counts_df = retrieve_count_data(
    _counts_csv_path=BIRC_INFO_DIR.joinpath('original-count-data.csv'),
    _meta_df=meta_df,
    test=TESTING
)

orig_counts_df.info()
# Out:
# **Original Counts** read from csv
# > Path: info/BiRC/original-count-data.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3617 entries, apw_eng_199411 to pcc_eng_val-03
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   file_MB     3617 non-null   Float64
#  1   sentences   3617 non-null   Int64
#  2   tokens      3617 non-null   Int64
#  3   ADV_tokens  3617 non-null   Int64
#  4   ADV_xpos    3617 non-null   Int64
#  5   ADV_lemmas  3617 non-null   Int64
#  6   ADV_forms   3617 non-null   Int64
#  7   ADJ_tokens  3617 non-null   Int64
#  8   ADJ_xpos    3617 non-null   Int64
#  9   ADJ_lemmas  3617 non-null   Int64
#  10  ADJ_forms   3617 non-null   Int64
#  11  NEG_tokens  3617 non-null   Int64
#  12  NEG_xpos    3617 non-null   Int64
#  13  NEG_lemmas  3617 non-null   Int64
#  14  NEG_forms   3617 non-null   Int64
# dtypes: Float64(1), Int64(14)
# memory usage: 505.1+ KB

# %% [markdown]
#  ## **...and <font color=Brown><u>BiRC</u></font> counts** (likewise)

# %%
birc_counts_df = retrieve_count_data(
    _counts_csv_path=BIRC_INFO_DIR.joinpath('birc-count-data.csv'),
    _meta_df=meta_df,
    test=TESTING
)

birc_counts_df.info()
# if birc_counts_composite_csv.is_file():
#     birc_counts_df = pd.read_csv(birc_counts_composite_csv).convert_dtypes()
#     print(
#         f'**BiRC Counts** read from csv\n> Path: {birc_counts_composite_csv.relative_to(SANPI_HOME)}')
# else:
#     birc_counts_df = pd.DataFrame.from_dict(
#         # {k:c for k,c in generate_counts(meta_df.head(500), 'subset')}, orient='index')
#         {k: c for k, c in generate_counts(meta_df, 'subset')}, orient='index')
#     pd.to_csv(birc_counts_composite_csv)
#     print(
#         f'**BiRC Counts** saved as csv\n> Path: {birc_counts_composite_csv.relative_to(SANPI_HOME)}')
# Out:
# **BiRC Counts** read from csv
# > Path: info/BiRC/birc-count-data.csv
# <class 'pandas.core.frame.DataFrame'>
# Index: 3617 entries, apw_eng_199411 to pcc_eng_val-03
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   file_MB     3617 non-null   Float64
#  1   sentences   3617 non-null   Int64
#  2   tokens      3617 non-null   Int64
#  3   ADV_tokens  3617 non-null   Int64
#  4   ADV_xpos    3617 non-null   Int64
#  5   ADV_lemmas  3617 non-null   Int64
#  6   ADV_forms   3617 non-null   Int64
#  7   ADJ_tokens  3617 non-null   Int64
#  8   ADJ_xpos    3617 non-null   Int64
#  9   ADJ_lemmas  3617 non-null   Int64
#  10  ADJ_forms   3617 non-null   Int64
#  11  NEG_tokens  3617 non-null   Int64
#  12  NEG_xpos    3617 non-null   Int64
#  13  NEG_lemmas  3617 non-null   Int64
#  14  NEG_forms   3617 non-null   Int64
# dtypes: Float64(1), Int64(14)
# memory usage: 505.1+ KB

# %% [markdown]
#  ## *Describe Count Collections*

# %%
save_latex_table(orig_counts_df.describe().T.iloc[:, 1:].assign(Total=orig_counts_df.sum()).filter(['mean', '50%','Total']).convert_dtypes(),
                 caption='Original Corpora: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=7.1,
                 latex_stem='only-counts-descrip-stats-orig')

save_latex_table(birc_counts_df.describe().T.iloc[:, 1:].assign(Total=birc_counts_df.sum()).filter(['mean', '50%','Total']).convert_dtypes(),
                 caption='BiRC: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=7.1,
                 latex_stem='only-counts-descrip-stats-birc')
# Out:
# Caption: Original Corpora: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
# <style type="text/css">
# #T_61247 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_61247 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_61247 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_61247 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_61247_row0_col0, #T_61247_row0_col1, #T_61247_row0_col2, #T_61247_row1_col0, #T_61247_row1_col1, #T_61247_row1_col2, #T_61247_row2_col0, #T_61247_row2_col1, #T_61247_row2_col2, #T_61247_row3_col0, #T_61247_row3_col1, #T_61247_row3_col2, #T_61247_row4_col0, #T_61247_row4_col1, #T_61247_row4_col2, #T_61247_row5_col0, #T_61247_row5_col1, #T_61247_row5_col2, #T_61247_row6_col0, #T_61247_row6_col1, #T_61247_row6_col2, #T_61247_row7_col0, #T_61247_row7_col1, #T_61247_row7_col2, #T_61247_row8_col0, #T_61247_row8_col1, #T_61247_row8_col2, #T_61247_row9_col0, #T_61247_row9_col1, #T_61247_row9_col2, #T_61247_row10_col0, #T_61247_row10_col1, #T_61247_row10_col2, #T_61247_row11_col0, #T_61247_row11_col1, #T_61247_row11_col2, #T_61247_row12_col0, #T_61247_row12_col1, #T_61247_row12_col2, #T_61247_row13_col0, #T_61247_row13_col1, #T_61247_row13_col2, #T_61247_row14_col0, #T_61247_row14_col1, #T_61247_row14_col2 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_61247">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_61247_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_61247_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_61247_level0_col2" class="col_heading level0 col2" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_61247_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_61247_row0_col0" class="data row0 col0" >376.642759</td>
#       <td id="T_61247_row0_col1" class="data row0 col1" >381.310000</td>
#       <td id="T_61247_row0_col2" class="data row0 col2" >1362316.860000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_61247_row1_col0" class="data row1 col0" >264,905.37</td>
#       <td id="T_61247_row1_col1" class="data row1 col1" >252,229.00</td>
#       <td id="T_61247_row1_col2" class="data row1 col2" >958,162,724.00</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_61247_row2_col0" class="data row2 col0" >7,963,980.62</td>
#       <td id="T_61247_row2_col1" class="data row2 col1" >7,844,694.00</td>
#       <td id="T_61247_row2_col2" class="data row2 col2" >28,805,717,900.00</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_61247_row3_col0" class="data row3 col0" >211630.734310</td>
#       <td id="T_61247_row3_col1" class="data row3 col1" >207234.000000</td>
#       <td id="T_61247_row3_col2" class="data row3 col2" >765468366.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row4" class="row_heading level0 row4" >ADV\_xpos</th>
#       <td id="T_61247_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_61247_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_61247_row4_col2" class="data row4 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row5" class="row_heading level0 row5" >ADV\_lemmas</th>
#       <td id="T_61247_row5_col0" class="data row5 col0" >2373.409732</td>
#       <td id="T_61247_row5_col1" class="data row5 col1" >2380.000000</td>
#       <td id="T_61247_row5_col2" class="data row5 col2" >8584623.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row6" class="row_heading level0 row6" >ADV\_forms</th>
#       <td id="T_61247_row6_col0" class="data row6 col0" >3022.908211</td>
#       <td id="T_61247_row6_col1" class="data row6 col1" >3076.000000</td>
#       <td id="T_61247_row6_col2" class="data row6 col2" >10933859.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row7" class="row_heading level0 row7" >ADJ\_tokens</th>
#       <td id="T_61247_row7_col0" class="data row7 col0" >344358.620957</td>
#       <td id="T_61247_row7_col1" class="data row7 col1" >325172.000000</td>
#       <td id="T_61247_row7_col2" class="data row7 col2" >1245545132.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row8" class="row_heading level0 row8" >ADJ\_xpos</th>
#       <td id="T_61247_row8_col0" class="data row8 col0" >3.000000</td>
#       <td id="T_61247_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_61247_row8_col2" class="data row8 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row9" class="row_heading level0 row9" >ADJ\_lemmas</th>
#       <td id="T_61247_row9_col0" class="data row9 col0" >16051.860658</td>
#       <td id="T_61247_row9_col1" class="data row9 col1" >15164.000000</td>
#       <td id="T_61247_row9_col2" class="data row9 col2" >58059580.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row10" class="row_heading level0 row10" >ADJ\_forms</th>
#       <td id="T_61247_row10_col0" class="data row10 col0" >18132.960188</td>
#       <td id="T_61247_row10_col1" class="data row10 col1" >17393.000000</td>
#       <td id="T_61247_row10_col2" class="data row10 col2" >65586917.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row11" class="row_heading level0 row11" >NEG\_tokens</th>
#       <td id="T_61247_row11_col0" class="data row11 col0" >44051.869229</td>
#       <td id="T_61247_row11_col1" class="data row11 col1" >42393.000000</td>
#       <td id="T_61247_row11_col2" class="data row11 col2" >159335611.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row12" class="row_heading level0 row12" >NEG\_xpos</th>
#       <td id="T_61247_row12_col0" class="data row12 col0" >14.020182</td>
#       <td id="T_61247_row12_col1" class="data row12 col1" >14.000000</td>
#       <td id="T_61247_row12_col2" class="data row12 col2" >50711.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row13" class="row_heading level0 row13" >NEG\_lemmas</th>
#       <td id="T_61247_row13_col0" class="data row13 col0" >14.995576</td>
#       <td id="T_61247_row13_col1" class="data row13 col1" >15.000000</td>
#       <td id="T_61247_row13_col2" class="data row13 col2" >54239.000000</td>
#     </tr>
#     <tr>
#       <th id="T_61247_level0_row14" class="row_heading level0 row14" >NEG\_forms</th>
#       <td id="T_61247_row14_col0" class="data row14 col0" >50.145148</td>
#       <td id="T_61247_row14_col1" class="data row14 col1" >52.000000</td>
#       <td id="T_61247_row14_col2" class="data row14 col2" >181375.000000</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-counts-descrip-stats-orig.2025-02-18.tex
#
# Caption: BiRC: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
#     S[table-auto-round, table-format=7.1, drop-zero-decimal]
# <style type="text/css">
# #T_12377 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_12377 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_12377 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_12377 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_12377_row0_col0, #T_12377_row0_col1, #T_12377_row0_col2, #T_12377_row1_col0, #T_12377_row1_col1, #T_12377_row1_col2, #T_12377_row2_col0, #T_12377_row2_col1, #T_12377_row2_col2, #T_12377_row3_col0, #T_12377_row3_col1, #T_12377_row3_col2, #T_12377_row4_col0, #T_12377_row4_col1, #T_12377_row4_col2, #T_12377_row5_col0, #T_12377_row5_col1, #T_12377_row5_col2, #T_12377_row6_col0, #T_12377_row6_col1, #T_12377_row6_col2, #T_12377_row7_col0, #T_12377_row7_col1, #T_12377_row7_col2, #T_12377_row8_col0, #T_12377_row8_col1, #T_12377_row8_col2, #T_12377_row9_col0, #T_12377_row9_col1, #T_12377_row9_col2, #T_12377_row10_col0, #T_12377_row10_col1, #T_12377_row10_col2, #T_12377_row11_col0, #T_12377_row11_col1, #T_12377_row11_col2, #T_12377_row12_col0, #T_12377_row12_col1, #T_12377_row12_col2, #T_12377_row13_col0, #T_12377_row13_col1, #T_12377_row13_col2, #T_12377_row14_col0, #T_12377_row14_col1, #T_12377_row14_col2 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_12377">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_12377_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_12377_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_12377_level0_col2" class="col_heading level0 col2" >Total</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_12377_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_12377_row0_col0" class="data row0 col0" >48.411269</td>
#       <td id="T_12377_row0_col1" class="data row0 col1" >50.120000</td>
#       <td id="T_12377_row0_col2" class="data row0 col2" >175103.560000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_12377_row1_col0" class="data row1 col0" >24,564.02</td>
#       <td id="T_12377_row1_col1" class="data row1 col1" >24,232.00</td>
#       <td id="T_12377_row1_col2" class="data row1 col2" >88,848,070.00</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_12377_row2_col0" class="data row2 col0" >744,482.66</td>
#       <td id="T_12377_row2_col1" class="data row2 col1" >753,252.00</td>
#       <td id="T_12377_row2_col2" class="data row2 col2" >2,692,793,781.00</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_12377_row3_col0" class="data row3 col0" >51777.230301</td>
#       <td id="T_12377_row3_col1" class="data row3 col1" >51673.000000</td>
#       <td id="T_12377_row3_col2" class="data row3 col2" >187278242.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row4" class="row_heading level0 row4" >ADV\_xpos</th>
#       <td id="T_12377_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_12377_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_12377_row4_col2" class="data row4 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row5" class="row_heading level0 row5" >ADV\_lemmas</th>
#       <td id="T_12377_row5_col0" class="data row5 col0" >1345.696434</td>
#       <td id="T_12377_row5_col1" class="data row5 col1" >1361.000000</td>
#       <td id="T_12377_row5_col2" class="data row5 col2" >4867384.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row6" class="row_heading level0 row6" >ADV\_forms</th>
#       <td id="T_12377_row6_col0" class="data row6 col0" >1653.056400</td>
#       <td id="T_12377_row6_col1" class="data row6 col1" >1692.000000</td>
#       <td id="T_12377_row6_col2" class="data row6 col2" >5979105.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row7" class="row_heading level0 row7" >ADJ\_tokens</th>
#       <td id="T_12377_row7_col0" class="data row7 col0" >63886.013547</td>
#       <td id="T_12377_row7_col1" class="data row7 col1" >62800.000000</td>
#       <td id="T_12377_row7_col2" class="data row7 col2" >231075711.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row8" class="row_heading level0 row8" >ADJ\_xpos</th>
#       <td id="T_12377_row8_col0" class="data row8 col0" >3.000000</td>
#       <td id="T_12377_row8_col1" class="data row8 col1" >3.000000</td>
#       <td id="T_12377_row8_col2" class="data row8 col2" >10851.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row9" class="row_heading level0 row9" >ADJ\_lemmas</th>
#       <td id="T_12377_row9_col0" class="data row9 col0" >6321.665469</td>
#       <td id="T_12377_row9_col1" class="data row9 col1" >6205.000000</td>
#       <td id="T_12377_row9_col2" class="data row9 col2" >22865464.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row10" class="row_heading level0 row10" >ADJ\_forms</th>
#       <td id="T_12377_row10_col0" class="data row10 col0" >6928.595798</td>
#       <td id="T_12377_row10_col1" class="data row10 col1" >6867.000000</td>
#       <td id="T_12377_row10_col2" class="data row10 col2" >25060731.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row11" class="row_heading level0 row11" >NEG\_tokens</th>
#       <td id="T_12377_row11_col0" class="data row11 col0" >7648.191595</td>
#       <td id="T_12377_row11_col1" class="data row11 col1" >7775.000000</td>
#       <td id="T_12377_row11_col2" class="data row11 col2" >27663509.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row12" class="row_heading level0 row12" >NEG\_xpos</th>
#       <td id="T_12377_row12_col0" class="data row12 col0" >9.828864</td>
#       <td id="T_12377_row12_col1" class="data row12 col1" >10.000000</td>
#       <td id="T_12377_row12_col2" class="data row12 col2" >35551.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row13" class="row_heading level0 row13" >NEG\_lemmas</th>
#       <td id="T_12377_row13_col0" class="data row13 col0" >14.912358</td>
#       <td id="T_12377_row13_col1" class="data row13 col1" >15.000000</td>
#       <td id="T_12377_row13_col2" class="data row13 col2" >53938.000000</td>
#     </tr>
#     <tr>
#       <th id="T_12377_level0_row14" class="row_heading level0 row14" >NEG\_forms</th>
#       <td id="T_12377_row14_col0" class="data row14 col0" >35.844623</td>
#       <td id="T_12377_row14_col1" class="data row14 col1" >37.000000</td>
#       <td id="T_12377_row14_col2" class="data row14 col2" >129650.000000</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-counts-descrip-stats-birc.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/only-counts-descrip-stats-birc.2025-02-18.tex')

# %%
def add_rate_cols(_df):
    return _df.assign(
        tok_per_sent=_df.tokens / _df.sentences,
        ADV_tok_per_sent=_df.ADV_tokens / _df.sentences,
        ADJ_tok_per_sent=_df.ADJ_tokens / _df.sentences,
        NEG_tok_per_sent=_df.NEG_tokens / _df.sentences,
        NEG_tok_per_mill=(_df.NEG_tokens / _df.tokens)*(10**6),
        ADV_tok_per_mill=(_df.ADV_tokens / _df.tokens)*(10**6),
        ADJ_tok_per_mill=(_df.ADJ_tokens / _df.tokens)*(10**6),
        ADV_form_per_lemma=_df.ADV_forms / _df.ADV_lemmas,
        # ADV_lemma_per_form= _df.ADV_lemmas / _df.ADV_forms,
        ADV_tok_per_lemma=_df.ADV_tokens / _df.ADV_lemmas,
        ADV_tok_per_form=_df.ADV_tokens / _df.ADV_forms,
        ADJ_form_per_lemma=_df.ADJ_forms / _df.ADJ_lemmas,
        # ADJ_lemma_per_form= _df.ADJ_lemmas / _df.ADJ_forms,
        ADJ_tok_per_lemma=_df.ADJ_tokens / _df.ADJ_lemmas,
        ADJ_tok_per_form=_df.ADJ_tokens / _df.ADJ_forms,
        # NEG_lemma_per_form= _df.NEG_lemmas / _df.NEG_forms,
        NEG_form_per_lemma=_df.NEG_forms / _df.NEG_lemmas,
        NEG_tok_per_lemma=_df.NEG_tokens / _df.NEG_lemmas,
    )


orig_counts_df = add_rate_cols(orig_counts_df)
birc_counts_df = add_rate_cols(birc_counts_df)
samix = orig_counts_df.sample(4).sort_index().index
nb_display(set_my_style(orig_counts_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for Original Counts'))
nb_display(set_my_style(birc_counts_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for BiRC Counts'))
# Out:
# <style type="text/css">
# #T_2413d th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_2413d th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2413d th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2413d caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_2413d th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_2413d th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2413d th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_2413d caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_2413d_row0_col0, #T_2413d_row0_col1, #T_2413d_row0_col2, #T_2413d_row0_col3, #T_2413d_row1_col0, #T_2413d_row1_col1, #T_2413d_row1_col2, #T_2413d_row1_col3, #T_2413d_row2_col0, #T_2413d_row2_col1, #T_2413d_row2_col2, #T_2413d_row2_col3, #T_2413d_row3_col0, #T_2413d_row3_col1, #T_2413d_row3_col2, #T_2413d_row3_col3, #T_2413d_row4_col0, #T_2413d_row4_col1, #T_2413d_row4_col2, #T_2413d_row4_col3, #T_2413d_row5_col0, #T_2413d_row5_col1, #T_2413d_row5_col2, #T_2413d_row5_col3, #T_2413d_row6_col0, #T_2413d_row6_col1, #T_2413d_row6_col2, #T_2413d_row6_col3, #T_2413d_row7_col0, #T_2413d_row7_col1, #T_2413d_row7_col2, #T_2413d_row7_col3, #T_2413d_row8_col0, #T_2413d_row8_col1, #T_2413d_row8_col2, #T_2413d_row8_col3, #T_2413d_row9_col0, #T_2413d_row9_col1, #T_2413d_row9_col2, #T_2413d_row9_col3, #T_2413d_row10_col0, #T_2413d_row10_col1, #T_2413d_row10_col2, #T_2413d_row10_col3, #T_2413d_row11_col0, #T_2413d_row11_col1, #T_2413d_row11_col2, #T_2413d_row11_col3, #T_2413d_row12_col0, #T_2413d_row12_col1, #T_2413d_row12_col2, #T_2413d_row12_col3, #T_2413d_row13_col0, #T_2413d_row13_col1, #T_2413d_row13_col2, #T_2413d_row13_col3, #T_2413d_row14_col0, #T_2413d_row14_col1, #T_2413d_row14_col2, #T_2413d_row14_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_2413d">
#   <caption>"Rate" columns for Original Counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_2413d_level0_col0" class="col_heading level0 col0" >apw_eng_200703</th>
#       <th id="T_2413d_level0_col1" class="col_heading level0 col1" >pcc_eng_00-041</th>
#       <th id="T_2413d_level0_col2" class="col_heading level0 col2" >pcc_eng_04-100</th>
#       <th id="T_2413d_level0_col3" class="col_heading level0 col3" >pcc_eng_14-056</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2413d_level0_row0" class="row_heading level0 row0" >tok_per_sent</th>
#       <td id="T_2413d_row0_col0" class="data row0 col0" >23.78</td>
#       <td id="T_2413d_row0_col1" class="data row0 col1" >31.11</td>
#       <td id="T_2413d_row0_col2" class="data row0 col2" >31.12</td>
#       <td id="T_2413d_row0_col3" class="data row0 col3" >31.13</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row1" class="row_heading level0 row1" >ADV_tok_per_sent</th>
#       <td id="T_2413d_row1_col0" class="data row1 col0" >0.53</td>
#       <td id="T_2413d_row1_col1" class="data row1 col1" >0.83</td>
#       <td id="T_2413d_row1_col2" class="data row1 col2" >0.81</td>
#       <td id="T_2413d_row1_col3" class="data row1 col3" >0.82</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row2" class="row_heading level0 row2" >ADJ_tok_per_sent</th>
#       <td id="T_2413d_row2_col0" class="data row2 col0" >1.38</td>
#       <td id="T_2413d_row2_col1" class="data row2 col1" >1.29</td>
#       <td id="T_2413d_row2_col2" class="data row2 col2" >1.28</td>
#       <td id="T_2413d_row2_col3" class="data row2 col3" >1.28</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row3" class="row_heading level0 row3" >NEG_tok_per_sent</th>
#       <td id="T_2413d_row3_col0" class="data row3 col0" >0.13</td>
#       <td id="T_2413d_row3_col1" class="data row3 col1" >0.17</td>
#       <td id="T_2413d_row3_col2" class="data row3 col2" >0.16</td>
#       <td id="T_2413d_row3_col3" class="data row3 col3" >0.17</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_2413d_row4_col0" class="data row4 col0" >5,266.44</td>
#       <td id="T_2413d_row4_col1" class="data row4 col1" >5,400.16</td>
#       <td id="T_2413d_row4_col2" class="data row4 col2" >5,287.51</td>
#       <td id="T_2413d_row4_col3" class="data row4 col3" >5,321.69</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row5" class="row_heading level0 row5" >ADV_tok_per_mill</th>
#       <td id="T_2413d_row5_col0" class="data row5 col0" >22,403.64</td>
#       <td id="T_2413d_row5_col1" class="data row5 col1" >26,583.96</td>
#       <td id="T_2413d_row5_col2" class="data row5 col2" >26,037.86</td>
#       <td id="T_2413d_row5_col3" class="data row5 col3" >26,302.53</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row6" class="row_heading level0 row6" >ADJ_tok_per_mill</th>
#       <td id="T_2413d_row6_col0" class="data row6 col0" >57,915.99</td>
#       <td id="T_2413d_row6_col1" class="data row6 col1" >41,436.97</td>
#       <td id="T_2413d_row6_col2" class="data row6 col2" >41,018.66</td>
#       <td id="T_2413d_row6_col3" class="data row6 col3" >41,187.93</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row7" class="row_heading level0 row7" >ADV_form_per_lemma</th>
#       <td id="T_2413d_row7_col0" class="data row7 col0" >1.11</td>
#       <td id="T_2413d_row7_col1" class="data row7 col1" >1.28</td>
#       <td id="T_2413d_row7_col2" class="data row7 col2" >1.30</td>
#       <td id="T_2413d_row7_col3" class="data row7 col3" >1.29</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row8" class="row_heading level0 row8" >ADV_tok_per_lemma</th>
#       <td id="T_2413d_row8_col0" class="data row8 col0" >152.02</td>
#       <td id="T_2413d_row8_col1" class="data row8 col1" >86.53</td>
#       <td id="T_2413d_row8_col2" class="data row8 col2" >85.95</td>
#       <td id="T_2413d_row8_col3" class="data row8 col3" >89.44</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row9" class="row_heading level0 row9" >ADV_tok_per_form</th>
#       <td id="T_2413d_row9_col0" class="data row9 col0" >136.85</td>
#       <td id="T_2413d_row9_col1" class="data row9 col1" >67.54</td>
#       <td id="T_2413d_row9_col2" class="data row9 col2" >66.32</td>
#       <td id="T_2413d_row9_col3" class="data row9 col3" >69.16</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row10" class="row_heading level0 row10" >ADJ_form_per_lemma</th>
#       <td id="T_2413d_row10_col0" class="data row10 col0" >1.03</td>
#       <td id="T_2413d_row10_col1" class="data row10 col1" >1.15</td>
#       <td id="T_2413d_row10_col2" class="data row10 col2" >1.15</td>
#       <td id="T_2413d_row10_col3" class="data row10 col3" >1.15</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row11" class="row_heading level0 row11" >ADJ_tok_per_lemma</th>
#       <td id="T_2413d_row11_col0" class="data row11 col0" >33.95</td>
#       <td id="T_2413d_row11_col1" class="data row11 col1" >21.40</td>
#       <td id="T_2413d_row11_col2" class="data row11 col2" >21.35</td>
#       <td id="T_2413d_row11_col3" class="data row11 col3" >21.71</td>
#     </tr>
#     <tr>
#       <th id="T_2413d_level0_row12" class="row_heading level0 row12" >ADJ_tok_per_form</th>
#       <td id="T_2413d_row12_col0" class="data row12 col0" >32.91</td>
#       <td id="T_2413d_row12_col1" class="data row12 col1" >18.6
# <style type="text/css">
# #T_7c8cf th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_7c8cf th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7c8cf th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7c8cf caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_7c8cf th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_7c8cf th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7c8cf th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_7c8cf caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_7c8cf_row0_col0, #T_7c8cf_row0_col1, #T_7c8cf_row0_col2, #T_7c8cf_row0_col3, #T_7c8cf_row1_col0, #T_7c8cf_row1_col1, #T_7c8cf_row1_col2, #T_7c8cf_row1_col3, #T_7c8cf_row2_col0, #T_7c8cf_row2_col1, #T_7c8cf_row2_col2, #T_7c8cf_row2_col3, #T_7c8cf_row3_col0, #T_7c8cf_row3_col1, #T_7c8cf_row3_col2, #T_7c8cf_row3_col3, #T_7c8cf_row4_col0, #T_7c8cf_row4_col1, #T_7c8cf_row4_col2, #T_7c8cf_row4_col3, #T_7c8cf_row5_col0, #T_7c8cf_row5_col1, #T_7c8cf_row5_col2, #T_7c8cf_row5_col3, #T_7c8cf_row6_col0, #T_7c8cf_row6_col1, #T_7c8cf_row6_col2, #T_7c8cf_row6_col3, #T_7c8cf_row7_col0, #T_7c8cf_row7_col1, #T_7c8cf_row7_col2, #T_7c8cf_row7_col3, #T_7c8cf_row8_col0, #T_7c8cf_row8_col1, #T_7c8cf_row8_col2, #T_7c8cf_row8_col3, #T_7c8cf_row9_col0, #T_7c8cf_row9_col1, #T_7c8cf_row9_col2, #T_7c8cf_row9_col3, #T_7c8cf_row10_col0, #T_7c8cf_row10_col1, #T_7c8cf_row10_col2, #T_7c8cf_row10_col3, #T_7c8cf_row11_col0, #T_7c8cf_row11_col1, #T_7c8cf_row11_col2, #T_7c8cf_row11_col3, #T_7c8cf_row12_col0, #T_7c8cf_row12_col1, #T_7c8cf_row12_col2, #T_7c8cf_row12_col3, #T_7c8cf_row13_col0, #T_7c8cf_row13_col1, #T_7c8cf_row13_col2, #T_7c8cf_row13_col3, #T_7c8cf_row14_col0, #T_7c8cf_row14_col1, #T_7c8cf_row14_col2, #T_7c8cf_row14_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_7c8cf">
#   <caption>"Rate" columns for BiRC Counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_7c8cf_level0_col0" class="col_heading level0 col0" >apw_eng_200703</th>
#       <th id="T_7c8cf_level0_col1" class="col_heading level0 col1" >pcc_eng_00-041</th>
#       <th id="T_7c8cf_level0_col2" class="col_heading level0 col2" >pcc_eng_04-100</th>
#       <th id="T_7c8cf_level0_col3" class="col_heading level0 col3" >pcc_eng_14-056</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7c8cf_level0_row0" class="row_heading level0 row0" >tok_per_sent</th>
#       <td id="T_7c8cf_row0_col0" class="data row0 col0" >23.60</td>
#       <td id="T_7c8cf_row0_col1" class="data row0 col1" >31.14</td>
#       <td id="T_7c8cf_row0_col2" class="data row0 col2" >31.13</td>
#       <td id="T_7c8cf_row0_col3" class="data row0 col3" >31.14</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row1" class="row_heading level0 row1" >ADV_tok_per_sent</th>
#       <td id="T_7c8cf_row1_col0" class="data row1 col0" >1.76</td>
#       <td id="T_7c8cf_row1_col1" class="data row1 col1" >2.14</td>
#       <td id="T_7c8cf_row1_col2" class="data row1 col2" >2.11</td>
#       <td id="T_7c8cf_row1_col3" class="data row1 col3" >2.16</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row2" class="row_heading level0 row2" >ADJ_tok_per_sent</th>
#       <td id="T_7c8cf_row2_col0" class="data row2 col0" >2.70</td>
#       <td id="T_7c8cf_row2_col1" class="data row2 col1" >2.59</td>
#       <td id="T_7c8cf_row2_col2" class="data row2 col2" >2.59</td>
#       <td id="T_7c8cf_row2_col3" class="data row2 col3" >2.60</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row3" class="row_heading level0 row3" >NEG_tok_per_sent</th>
#       <td id="T_7c8cf_row3_col0" class="data row3 col0" >0.21</td>
#       <td id="T_7c8cf_row3_col1" class="data row3 col1" >0.32</td>
#       <td id="T_7c8cf_row3_col2" class="data row3 col2" >0.31</td>
#       <td id="T_7c8cf_row3_col3" class="data row3 col3" >0.32</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_7c8cf_row4_col0" class="data row4 col0" >8,840.34</td>
#       <td id="T_7c8cf_row4_col1" class="data row4 col1" >10,168.94</td>
#       <td id="T_7c8cf_row4_col2" class="data row4 col2" >10,118.83</td>
#       <td id="T_7c8cf_row4_col3" class="data row4 col3" >10,287.75</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row5" class="row_heading level0 row5" >ADV_tok_per_mill</th>
#       <td id="T_7c8cf_row5_col0" class="data row5 col0" >74,735.43</td>
#       <td id="T_7c8cf_row5_col1" class="data row5 col1" >68,590.78</td>
#       <td id="T_7c8cf_row5_col2" class="data row5 col2" >67,883.27</td>
#       <td id="T_7c8cf_row5_col3" class="data row5 col3" >69,244.24</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row6" class="row_heading level0 row6" >ADJ_tok_per_mill</th>
#       <td id="T_7c8cf_row6_col0" class="data row6 col0" >114,217.96</td>
#       <td id="T_7c8cf_row6_col1" class="data row6 col1" >83,296.03</td>
#       <td id="T_7c8cf_row6_col2" class="data row6 col2" >83,255.13</td>
#       <td id="T_7c8cf_row6_col3" class="data row6 col3" >83,528.52</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row7" class="row_heading level0 row7" >ADV_form_per_lemma</th>
#       <td id="T_7c8cf_row7_col0" class="data row7 col0" >1.10</td>
#       <td id="T_7c8cf_row7_col1" class="data row7 col1" >1.23</td>
#       <td id="T_7c8cf_row7_col2" class="data row7 col2" >1.24</td>
#       <td id="T_7c8cf_row7_col3" class="data row7 col3" >1.25</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row8" class="row_heading level0 row8" >ADV_tok_per_lemma</th>
#       <td id="T_7c8cf_row8_col0" class="data row8 col0" >55.07</td>
#       <td id="T_7c8cf_row8_col1" class="data row8 col1" >37.37</td>
#       <td id="T_7c8cf_row8_col2" class="data row8 col2" >37.93</td>
#       <td id="T_7c8cf_row8_col3" class="data row8 col3" >39.34</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row9" class="row_heading level0 row9" >ADV_tok_per_form</th>
#       <td id="T_7c8cf_row9_col0" class="data row9 col0" >50.24</td>
#       <td id="T_7c8cf_row9_col1" class="data row9 col1" >30.48</td>
#       <td id="T_7c8cf_row9_col2" class="data row9 col2" >30.49</td>
#       <td id="T_7c8cf_row9_col3" class="data row9 col3" >31.59</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row10" class="row_heading level0 row10" >ADJ_form_per_lemma</th>
#       <td id="T_7c8cf_row10_col0" class="data row10 col0" >1.02</td>
#       <td id="T_7c8cf_row10_col1" class="data row10 col1" >1.11</td>
#       <td id="T_7c8cf_row10_col2" class="data row10 col2" >1.11</td>
#       <td id="T_7c8cf_row10_col3" class="data row10 col3" >1.11</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row11" class="row_heading level0 row11" >ADJ_tok_per_lemma</th>
#       <td id="T_7c8cf_row11_col0" class="data row11 col0" >12.92</td>
#       <td id="T_7c8cf_row11_col1" class="data row11 col1" >10.11</td>
#       <td id="T_7c8cf_row11_col2" class="data row11 col2" >10.23</td>
#       <td id="T_7c8cf_row11_col3" class="data row11 col3" >10.24</td>
#     </tr>
#     <tr>
#       <th id="T_7c8cf_level0_row12" class="row_heading level0 row12" >ADJ_tok_per_form</th>
#       <td id="T_7c8cf_row12_col0" class="data row12 col0" >12.66</td>
#       <td id="T_7c8cf_row12_col1" class="data row12 col1" >9.11</

# %%
# %%

save_latex_table(orig_counts_df.describe().T.filter(['mean', '50%','min','max']).assign(
    Total=orig_counts_df.sum(), 
    CVx100=(orig_counts_df.std()/orig_counts_df.mean()) * 100
).convert_dtypes(),
                 caption='Original Corpora Counts & Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='plus-rates-main-stats-orig')

save_latex_table(birc_counts_df.describe().T.filter(['mean', '50%','min','max']).assign(
    Total=birc_counts_df.sum(), 
    CVx100=(birc_counts_df.std()/birc_counts_df.mean()) * 100
).convert_dtypes(),
                 caption='BiRC Counts & Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='plus-rates-main-stats-birc')

save_latex_table(orig_counts_df.filter(like='per').describe().T.filter(['mean', '50%','min','max']).assign(
    Total=orig_counts_df.sum(), 
    CVx100=(orig_counts_df.std()/orig_counts_df.mean()) * 100
).convert_dtypes(),
                 caption='Original Corpora Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='only-rates-main-stats-orig')

save_latex_table(birc_counts_df.filter(like='per').describe().T.filter(['mean', '50%','min','max']).assign(
    Total=birc_counts_df.sum(), 
    CVx100=(birc_counts_df.std()/birc_counts_df.mean()) * 100
).convert_dtypes(),
                 caption='BiRC Rates: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR, default_SI=10.1,
                 latex_stem='only-rates-main-stats-birc')
# Out:
# Caption: Original Corpora Counts & Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_4268b th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_4268b th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_4268b th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_4268b caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_4268b_row0_col0, #T_4268b_row0_col1, #T_4268b_row0_col2, #T_4268b_row0_col3, #T_4268b_row0_col4, #T_4268b_row0_col5, #T_4268b_row1_col0, #T_4268b_row1_col1, #T_4268b_row1_col2, #T_4268b_row1_col3, #T_4268b_row1_col4, #T_4268b_row1_col5, #T_4268b_row2_col0, #T_4268b_row2_col1, #T_4268b_row2_col2, #T_4268b_row2_col3, #T_4268b_row2_col4, #T_4268b_row2_col5, #T_4268b_row3_col0, #T_4268b_row3_col1, #T_4268b_row3_col2, #T_4268b_row3_col3, #T_4268b_row3_col4, #T_4268b_row3_col5, #T_4268b_row4_col0, #T_4268b_row4_col1, #T_4268b_row4_col2, #T_4268b_row4_col3, #T_4268b_row4_col4, #T_4268b_row4_col5, #T_4268b_row5_col0, #T_4268b_row5_col1, #T_4268b_row5_col2, #T_4268b_row5_col3, #T_4268b_row5_col4, #T_4268b_row5_col5, #T_4268b_row6_col0, #T_4268b_row6_col1, #T_4268b_row6_col2, #T_4268b_row6_col3, #T_4268b_row6_col4, #T_4268b_row6_col5, #T_4268b_row7_col0, #T_4268b_row7_col1, #T_4268b_row7_col2, #T_4268b_row7_col3, #T_4268b_row7_col4, #T_4268b_row7_col5, #T_4268b_row8_col0, #T_4268b_row8_col1, #T_4268b_row8_col2, #T_4268b_row8_col3, #T_4268b_row8_col4, #T_4268b_row8_col5, #T_4268b_row9_col0, #T_4268b_row9_col1, #T_4268b_row9_col2, #T_4268b_row9_col3, #T_4268b_row9_col4, #T_4268b_row9_col5, #T_4268b_row10_col0, #T_4268b_row10_col1, #T_4268b_row10_col2, #T_4268b_row10_col3, #T_4268b_row10_col4, #T_4268b_row10_col5, #T_4268b_row11_col0, #T_4268b_row11_col1, #T_4268b_row11_col2, #T_4268b_row11_col3, #T_4268b_row11_col4, #T_4268b_row11_col5, #T_4268b_row12_col0, #T_4268b_row12_col1, #T_4268b_row12_col2, #T_4268b_row12_col3, #T_4268b_row12_col4, #T_4268b_row12_col5, #T_4268b_row13_col0, #T_4268b_row13_col1, #T_4268b_row13_col2, #T_4268b_row13_col3, #T_4268b_row13_col4, #T_4268b_row13_col5, #T_4268b_row14_col0, #T_4268b_row14_col1, #T_4268b_row14_col2, #T_4268b_row14_col3, #T_4268b_row14_col4, #T_4268b_row14_col5, #T_4268b_row15_col0, #T_4268b_row15_col1, #T_4268b_row15_col2, #T_4268b_row15_col3, #T_4268b_row15_col4, #T_4268b_row15_col5, #T_4268b_row16_col0, #T_4268b_row16_col1, #T_4268b_row16_col2, #T_4268b_row16_col3, #T_4268b_row16_col4, #T_4268b_row16_col5, #T_4268b_row17_col0, #T_4268b_row17_col1, #T_4268b_row17_col2, #T_4268b_row17_col3, #T_4268b_row17_col4, #T_4268b_row17_col5, #T_4268b_row18_col0, #T_4268b_row18_col1, #T_4268b_row18_col2, #T_4268b_row18_col3, #T_4268b_row18_col4, #T_4268b_row18_col5, #T_4268b_row19_col0, #T_4268b_row19_col1, #T_4268b_row19_col2, #T_4268b_row19_col3, #T_4268b_row19_col4, #T_4268b_row19_col5, #T_4268b_row20_col0, #T_4268b_row20_col1, #T_4268b_row20_col2, #T_4268b_row20_col3, #T_4268b_row20_col4, #T_4268b_row20_col5, #T_4268b_row21_col0, #T_4268b_row21_col1, #T_4268b_row21_col2, #T_4268b_row21_col3, #T_4268b_row21_col4, #T_4268b_row21_col5, #T_4268b_row22_col0, #T_4268b_row22_col1, #T_4268b_row22_col2, #T_4268b_row22_col3, #T_4268b_row22_col4, #T_4268b_row22_col5, #T_4268b_row23_col0, #T_4268b_row23_col1, #T_4268b_row23_col2, #T_4268b_row23_col3, #T_4268b_row23_col4, #T_4268b_row23_col5, #T_4268b_row24_col0, #T_4268b_row24_col1, #T_4268b_row24_col2, #T_4268b_row24_col3, #T_4268b_row24_col4, #T_4268b_row24_col5, #T_4268b_row25_col0, #T_4268b_row25_col1, #T_4268b_row25_col2, #T_4268b_row25_col3, #T_4268b_row25_col4, #T_4268b_row25_col5, #T_4268b_row26_col0, #T_4268b_row26_col1, #T_4268b_row26_col2, #T_4268b_row26_col3, #T_4268b_row26_col4, #T_4268b_row26_col5, #T_4268b_row27_col0, #T_4268b_row27_col1, #T_4268b_row27_col2, #T_4268b_row27_col3, #T_4268b_row27_col4, #T_4268b_row27_col5, #T_4268b_row28_col0, #T_4268b_row28_col1, #T_4268b_row28_col2, #T_4268b_row28_col3, #T_4268b_row28_col4, #T_4268b_row28_col5, #T_4268b_row29_col0, #T_4268b_row29_col1, #T_4268b_row29_col2, #T_4268b_row29_col3, #T_4268b_row29_col4, #T_4268b_row29_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_4268b">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4268b_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_4268b_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_4268b_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_4268b_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_4268b_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_4268b_level0_col5" class="col_heading level0 col5" >CVx100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4268b_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_4268b_row0_col0" class="data row0 col0" >376.642759</td>
#       <td id="T_4268b_row0_col1" class="data row0 col1" >381.310000</td>
#       <td id="T_4268b_row0_col2" class="data row0 col2" >1.160000</td>
#       <td id="T_4268b_row0_col3" class="data row0 col3" >693.620000</td>
#       <td id="T_4268b_row0_col4" class="data row0 col4" >1362316.860000</td>
#       <td id="T_4268b_row0_col5" class="data row0 col5" >12.764588</td>
#     </tr>
#     <tr>
#       <th id="T_4268b_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_4268b_row1_col0" class="data row1 col0" >264,905.37</td>
#       <td id="T_4268b_row1_col1" class="data row1 col1" >252,229.00</td>
#       <td id="T_4268b_row1_col2" class="data row1 col2" >1,147.00</td>
#       <td id="T_4268b_row1_col3" class="data row1 col3" >820,724.00</td>
#       <td id="T_4268b_row1_col4" class="data row1 col4" >958,162,724.00</td>
#       <td id="T_4268b_row1_col5" class="data row1 col5" >25.48</td>
#     </tr>
#     <tr>
#       <th id="T_4268b_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_4268b_row2_col0" class="data row2 col0" >7,963,980.62</td>
#       <td id="T_4268b_row2_col1" class="data row2 col1" >7,844,694.00</td>
#       <td id="T_4268b_row2_col2" class="data row2 col2" >27,017.00</td>
#       <td id="T_4268b_row2_col3" class="data row2 col3" >19,532,928.00</td>
#       <td id="T_4268b_row2_col4" class="data row2 col4" >28,805,717,900.00</td>
#       <td id="T_4268b_row2_col5" class="data row2 col5" >17.46</td>
#     </tr>
#     <tr>
#       <th id="T_4268b_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_4268b_row3_col0" class="data row3 col0" >211630.734310</td>
#       <td id="T_4268b_row3_col1" class="data row3 col1" >207234.000000</td>
#       <td id="T_4268b_row3_col2" class="data row3 col2" >840.000000</td>
#       <td id="T_4268b_row3_col3" class="data row3 col3" >570729.000000</td>
#       <td id="T_4268b_row3_col4" class="data row3 col4" >765468366.000000</td>
#       <td id="T_4268b_row3_col5" class="data row3 col5" >18.714909</td>
#     </tr>
#     <tr>
#       <th id="T_4268b_level0_row4" class="row_heading level0 row4" >ADV\_xpos</th>
#       <td id="T_4268b_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_4268b_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_4268b_row4_col2" class="data row4 col2" >3.000000</td>
#       <td id="T_4268b_row4_col3" class="data row4 col3" >3.000000</td>
#       <td id="T_4268b_row4_col4" class="data row4 col4" >10851.000000</td>
#       <td id="T_4268b_row4_col5" class=
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-main-stats-orig.2025-02-18.tex
#
# Caption: BiRC Counts & Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_f414f th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_f414f th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_f414f th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_f414f caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_f414f_row0_col0, #T_f414f_row0_col1, #T_f414f_row0_col2, #T_f414f_row0_col3, #T_f414f_row0_col4, #T_f414f_row0_col5, #T_f414f_row1_col0, #T_f414f_row1_col1, #T_f414f_row1_col2, #T_f414f_row1_col3, #T_f414f_row1_col4, #T_f414f_row1_col5, #T_f414f_row2_col0, #T_f414f_row2_col1, #T_f414f_row2_col2, #T_f414f_row2_col3, #T_f414f_row2_col4, #T_f414f_row2_col5, #T_f414f_row3_col0, #T_f414f_row3_col1, #T_f414f_row3_col2, #T_f414f_row3_col3, #T_f414f_row3_col4, #T_f414f_row3_col5, #T_f414f_row4_col0, #T_f414f_row4_col1, #T_f414f_row4_col2, #T_f414f_row4_col3, #T_f414f_row4_col4, #T_f414f_row4_col5, #T_f414f_row5_col0, #T_f414f_row5_col1, #T_f414f_row5_col2, #T_f414f_row5_col3, #T_f414f_row5_col4, #T_f414f_row5_col5, #T_f414f_row6_col0, #T_f414f_row6_col1, #T_f414f_row6_col2, #T_f414f_row6_col3, #T_f414f_row6_col4, #T_f414f_row6_col5, #T_f414f_row7_col0, #T_f414f_row7_col1, #T_f414f_row7_col2, #T_f414f_row7_col3, #T_f414f_row7_col4, #T_f414f_row7_col5, #T_f414f_row8_col0, #T_f414f_row8_col1, #T_f414f_row8_col2, #T_f414f_row8_col3, #T_f414f_row8_col4, #T_f414f_row8_col5, #T_f414f_row9_col0, #T_f414f_row9_col1, #T_f414f_row9_col2, #T_f414f_row9_col3, #T_f414f_row9_col4, #T_f414f_row9_col5, #T_f414f_row10_col0, #T_f414f_row10_col1, #T_f414f_row10_col2, #T_f414f_row10_col3, #T_f414f_row10_col4, #T_f414f_row10_col5, #T_f414f_row11_col0, #T_f414f_row11_col1, #T_f414f_row11_col2, #T_f414f_row11_col3, #T_f414f_row11_col4, #T_f414f_row11_col5, #T_f414f_row12_col0, #T_f414f_row12_col1, #T_f414f_row12_col2, #T_f414f_row12_col3, #T_f414f_row12_col4, #T_f414f_row12_col5, #T_f414f_row13_col0, #T_f414f_row13_col1, #T_f414f_row13_col2, #T_f414f_row13_col3, #T_f414f_row13_col4, #T_f414f_row13_col5, #T_f414f_row14_col0, #T_f414f_row14_col1, #T_f414f_row14_col2, #T_f414f_row14_col3, #T_f414f_row14_col4, #T_f414f_row14_col5, #T_f414f_row15_col0, #T_f414f_row15_col1, #T_f414f_row15_col2, #T_f414f_row15_col3, #T_f414f_row15_col4, #T_f414f_row15_col5, #T_f414f_row16_col0, #T_f414f_row16_col1, #T_f414f_row16_col2, #T_f414f_row16_col3, #T_f414f_row16_col4, #T_f414f_row16_col5, #T_f414f_row17_col0, #T_f414f_row17_col1, #T_f414f_row17_col2, #T_f414f_row17_col3, #T_f414f_row17_col4, #T_f414f_row17_col5, #T_f414f_row18_col0, #T_f414f_row18_col1, #T_f414f_row18_col2, #T_f414f_row18_col3, #T_f414f_row18_col4, #T_f414f_row18_col5, #T_f414f_row19_col0, #T_f414f_row19_col1, #T_f414f_row19_col2, #T_f414f_row19_col3, #T_f414f_row19_col4, #T_f414f_row19_col5, #T_f414f_row20_col0, #T_f414f_row20_col1, #T_f414f_row20_col2, #T_f414f_row20_col3, #T_f414f_row20_col4, #T_f414f_row20_col5, #T_f414f_row21_col0, #T_f414f_row21_col1, #T_f414f_row21_col2, #T_f414f_row21_col3, #T_f414f_row21_col4, #T_f414f_row21_col5, #T_f414f_row22_col0, #T_f414f_row22_col1, #T_f414f_row22_col2, #T_f414f_row22_col3, #T_f414f_row22_col4, #T_f414f_row22_col5, #T_f414f_row23_col0, #T_f414f_row23_col1, #T_f414f_row23_col2, #T_f414f_row23_col3, #T_f414f_row23_col4, #T_f414f_row23_col5, #T_f414f_row24_col0, #T_f414f_row24_col1, #T_f414f_row24_col2, #T_f414f_row24_col3, #T_f414f_row24_col4, #T_f414f_row24_col5, #T_f414f_row25_col0, #T_f414f_row25_col1, #T_f414f_row25_col2, #T_f414f_row25_col3, #T_f414f_row25_col4, #T_f414f_row25_col5, #T_f414f_row26_col0, #T_f414f_row26_col1, #T_f414f_row26_col2, #T_f414f_row26_col3, #T_f414f_row26_col4, #T_f414f_row26_col5, #T_f414f_row27_col0, #T_f414f_row27_col1, #T_f414f_row27_col2, #T_f414f_row27_col3, #T_f414f_row27_col4, #T_f414f_row27_col5, #T_f414f_row28_col0, #T_f414f_row28_col1, #T_f414f_row28_col2, #T_f414f_row28_col3, #T_f414f_row28_col4, #T_f414f_row28_col5, #T_f414f_row29_col0, #T_f414f_row29_col1, #T_f414f_row29_col2, #T_f414f_row29_col3, #T_f414f_row29_col4, #T_f414f_row29_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_f414f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f414f_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_f414f_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_f414f_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_f414f_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_f414f_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_f414f_level0_col5" class="col_heading level0 col5" >CVx100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f414f_level0_row0" class="row_heading level0 row0" >file\_MB</th>
#       <td id="T_f414f_row0_col0" class="data row0 col0" >48.411269</td>
#       <td id="T_f414f_row0_col1" class="data row0 col1" >50.120000</td>
#       <td id="T_f414f_row0_col2" class="data row0 col2" >0.090000</td>
#       <td id="T_f414f_row0_col3" class="data row0 col3" >76.520000</td>
#       <td id="T_f414f_row0_col4" class="data row0 col4" >175103.560000</td>
#       <td id="T_f414f_row0_col5" class="data row0 col5" >16.168846</td>
#     </tr>
#     <tr>
#       <th id="T_f414f_level0_row1" class="row_heading level0 row1" >sentences</th>
#       <td id="T_f414f_row1_col0" class="data row1 col0" >24,564.02</td>
#       <td id="T_f414f_row1_col1" class="data row1 col1" >24,232.00</td>
#       <td id="T_f414f_row1_col2" class="data row1 col2" >78.00</td>
#       <td id="T_f414f_row1_col3" class="data row1 col3" >66,997.00</td>
#       <td id="T_f414f_row1_col4" class="data row1 col4" >88,848,070.00</td>
#       <td id="T_f414f_row1_col5" class="data row1 col5" >19.25</td>
#     </tr>
#     <tr>
#       <th id="T_f414f_level0_row2" class="row_heading level0 row2" >tokens</th>
#       <td id="T_f414f_row2_col0" class="data row2 col0" >744,482.66</td>
#       <td id="T_f414f_row2_col1" class="data row2 col1" >753,252.00</td>
#       <td id="T_f414f_row2_col2" class="data row2 col2" >1,836.00</td>
#       <td id="T_f414f_row2_col3" class="data row2 col3" >1,591,526.00</td>
#       <td id="T_f414f_row2_col4" class="data row2 col4" >2,692,793,781.00</td>
#       <td id="T_f414f_row2_col5" class="data row2 col5" >15.54</td>
#     </tr>
#     <tr>
#       <th id="T_f414f_level0_row3" class="row_heading level0 row3" >ADV\_tokens</th>
#       <td id="T_f414f_row3_col0" class="data row3 col0" >51777.230301</td>
#       <td id="T_f414f_row3_col1" class="data row3 col1" >51673.000000</td>
#       <td id="T_f414f_row3_col2" class="data row3 col2" >142.000000</td>
#       <td id="T_f414f_row3_col3" class="data row3 col3" >128678.000000</td>
#       <td id="T_f414f_row3_col4" class="data row3 col4" >187278242.000000</td>
#       <td id="T_f414f_row3_col5" class="data row3 col5" >17.999014</td>
#     </tr>
#     <tr>
#       <th id="T_f414f_level0_row4" class="row_heading level0 row4" >ADV\_xpos</th>
#       <td id="T_f414f_row4_col0" class="data row4 col0" >3.000000</td>
#       <td id="T_f414f_row4_col1" class="data row4 col1" >3.000000</td>
#       <td id="T_f414f_row4_col2" class="data row4 col2" >3.000000</td>
#       <td id="T_f414f_row4_col3" class="data row4 col3" >3.000000</td>
#       <td id="T_f414f_row4_col4" class="data row4 col4" >10851.000000</td>
#       <td id="T_f414f_row4_col5" class="data row4 col5" >0.
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/plus-rates-main-stats-birc.2025-02-18.tex
#
# Caption: Original Corpora Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_27098 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_27098 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_27098 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_27098 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_27098_row0_col0, #T_27098_row0_col1, #T_27098_row0_col2, #T_27098_row0_col3, #T_27098_row0_col4, #T_27098_row0_col5, #T_27098_row1_col0, #T_27098_row1_col1, #T_27098_row1_col2, #T_27098_row1_col3, #T_27098_row1_col4, #T_27098_row1_col5, #T_27098_row2_col0, #T_27098_row2_col1, #T_27098_row2_col2, #T_27098_row2_col3, #T_27098_row2_col4, #T_27098_row2_col5, #T_27098_row3_col0, #T_27098_row3_col1, #T_27098_row3_col2, #T_27098_row3_col3, #T_27098_row3_col4, #T_27098_row3_col5, #T_27098_row4_col0, #T_27098_row4_col1, #T_27098_row4_col2, #T_27098_row4_col3, #T_27098_row4_col4, #T_27098_row4_col5, #T_27098_row5_col0, #T_27098_row5_col1, #T_27098_row5_col2, #T_27098_row5_col3, #T_27098_row5_col4, #T_27098_row5_col5, #T_27098_row6_col0, #T_27098_row6_col1, #T_27098_row6_col2, #T_27098_row6_col3, #T_27098_row6_col4, #T_27098_row6_col5, #T_27098_row7_col0, #T_27098_row7_col1, #T_27098_row7_col2, #T_27098_row7_col3, #T_27098_row7_col4, #T_27098_row7_col5, #T_27098_row8_col0, #T_27098_row8_col1, #T_27098_row8_col2, #T_27098_row8_col3, #T_27098_row8_col4, #T_27098_row8_col5, #T_27098_row9_col0, #T_27098_row9_col1, #T_27098_row9_col2, #T_27098_row9_col3, #T_27098_row9_col4, #T_27098_row9_col5, #T_27098_row10_col0, #T_27098_row10_col1, #T_27098_row10_col2, #T_27098_row10_col3, #T_27098_row10_col4, #T_27098_row10_col5, #T_27098_row11_col0, #T_27098_row11_col1, #T_27098_row11_col2, #T_27098_row11_col3, #T_27098_row11_col4, #T_27098_row11_col5, #T_27098_row12_col0, #T_27098_row12_col1, #T_27098_row12_col2, #T_27098_row12_col3, #T_27098_row12_col4, #T_27098_row12_col5, #T_27098_row13_col0, #T_27098_row13_col1, #T_27098_row13_col2, #T_27098_row13_col3, #T_27098_row13_col4, #T_27098_row13_col5, #T_27098_row14_col0, #T_27098_row14_col1, #T_27098_row14_col2, #T_27098_row14_col3, #T_27098_row14_col4, #T_27098_row14_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_27098">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_27098_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_27098_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_27098_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_27098_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_27098_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_27098_level0_col5" class="col_heading level0 col5" >CVx100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_27098_level0_row0" class="row_heading level0 row0" >tok\_per\_sent</th>
#       <td id="T_27098_row0_col0" class="data row0 col0" >30.375293</td>
#       <td id="T_27098_row0_col1" class="data row0 col1" >31.125939</td>
#       <td id="T_27098_row0_col2" class="data row0 col2" >1.744827</td>
#       <td id="T_27098_row0_col3" class="data row0 col3" >32.176999</td>
#       <td id="T_27098_row0_col4" class="data row0 col4" >109867.434803</td>
#       <td id="T_27098_row0_col5" class="data row0 col5" >7.563742</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row1" class="row_heading level0 row1" >ADV\_tok\_per\_sent</th>
#       <td id="T_27098_row1_col0" class="data row1 col0" >0.806727</td>
#       <td id="T_27098_row1_col1" class="data row1 col1" >0.821356</td>
#       <td id="T_27098_row1_col2" class="data row1 col2" >0.389156</td>
#       <td id="T_27098_row1_col3" class="data row1 col3" >0.886415</td>
#       <td id="T_27098_row1_col4" class="data row1 col4" >2917.932666</td>
#       <td id="T_27098_row1_col5" class="data row1 col5" >7.384976</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row2" class="row_heading level0 row2" >ADJ\_tok\_per\_sent</th>
#       <td id="T_27098_row2_col0" class="data row2 col0" >1.299893</td>
#       <td id="T_27098_row2_col1" class="data row2 col1" >1.289703</td>
#       <td id="T_27098_row2_col2" class="data row2 col2" >0.952974</td>
#       <td id="T_27098_row2_col3" class="data row2 col3" >1.648766</td>
#       <td id="T_27098_row2_col4" class="data row2 col4" >4701.714696</td>
#       <td id="T_27098_row2_col5" class="data row2 col5" >4.040385</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row3" class="row_heading level0 row3" >NEG\_tok\_per\_sent</th>
#       <td id="T_27098_row3_col0" class="data row3 col0" >0.167069</td>
#       <td id="T_27098_row3_col1" class="data row3 col1" >0.167970</td>
#       <td id="T_27098_row3_col2" class="data row3 col2" >0.092644</td>
#       <td id="T_27098_row3_col3" class="data row3 col3" >0.223678</td>
#       <td id="T_27098_row3_col4" class="data row3 col4" >604.289089</td>
#       <td id="T_27098_row3_col5" class="data row3 col5" >6.053056</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row4" class="row_heading level0 row4" >NEG\_tok\_per\_mill</th>
#       <td id="T_27098_row4_col0" class="data row4 col0" >5551.801189</td>
#       <td id="T_27098_row4_col1" class="data row4 col1" >5402.466263</td>
#       <td id="T_27098_row4_col2" class="data row4 col2" >3929.536285</td>
#       <td id="T_27098_row4_col3" class="data row4 col3" >96553.464313</td>
#       <td id="T_27098_row4_col4" class="data row4 col4" >20080864.900171</td>
#       <td id="T_27098_row4_col5" class="data row4 col5" >28.995261</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row5" class="row_heading level0 row5" >ADV\_tok\_per\_mill</th>
#       <td id="T_27098_row5_col0" class="data row5 col0" >26718.415610</td>
#       <td id="T_27098_row5_col1" class="data row5 col1" >26415.459711</td>
#       <td id="T_27098_row5_col2" class="data row5 col2" >16506.162419</td>
#       <td id="T_27098_row5_col3" class="data row5 col3" >479278.349333</td>
#       <td id="T_27098_row5_col4" class="data row5 col4" >96640509.261629</td>
#       <td id="T_27098_row5_col5" class="data row5 col5" >28.867916</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row6" class="row_heading level0 row6" >ADJ\_tok\_per\_mill</th>
#       <td id="T_27098_row6_col0" class="data row6 col0" >43374.635341</td>
#       <td id="T_27098_row6_col1" class="data row6 col1" >41442.631915</td>
#       <td id="T_27098_row6_col2" class="data row6 col2" >37574.922799</td>
#       <td id="T_27098_row6_col3" class="data row6 col3" >737301.723841</td>
#       <td id="T_27098_row6_col4" class="data row6 col4" >156886056.027471</td>
#       <td id="T_27098_row6_col5" class="data row6 col5" >29.612538</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row7" class="row_heading level0 row7" >ADV\_form\_per\_lemma</th>
#       <td id="T_27098_row7_col0" class="data row7 col0" >1.272915</td>
#       <td id="T_27098_row7_col1" class="data row7 col1" >1.291615</td>
#       <td id="T_27098_row7_col2" class="data row7 col2" >1.054054</td>
#       <td id="T_27098_row7_col3" class="data row7 col3" >1.327456</td>
#       <td id="T_27098_row7_col4" class="data row7 col4" >4604.135303</td>
#       <td id="T_27098_row7_col5" class="data row7 col5" >4.701489</td>
#     </tr>
#     <tr>
#       <th id="T_27098_level0_row8" class="row_heading level0 row8" >ADV\_tok\_per\_lemma</th>
#       <td id="T_27098_row8_col0" class="data row8 col0" >88.876
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-rates-main-stats-orig.2025-02-18.tex
#
# Caption: BiRC Rates: Descriptive Stats
# *{1}{l}S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
#     S[table-auto-round, table-format=10.1, drop-zero-decimal]
# <style type="text/css">
# #T_e92f7 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_e92f7 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e92f7 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_e92f7 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_e92f7_row0_col0, #T_e92f7_row0_col1, #T_e92f7_row0_col2, #T_e92f7_row0_col3, #T_e92f7_row0_col4, #T_e92f7_row0_col5, #T_e92f7_row1_col0, #T_e92f7_row1_col1, #T_e92f7_row1_col2, #T_e92f7_row1_col3, #T_e92f7_row1_col4, #T_e92f7_row1_col5, #T_e92f7_row2_col0, #T_e92f7_row2_col1, #T_e92f7_row2_col2, #T_e92f7_row2_col3, #T_e92f7_row2_col4, #T_e92f7_row2_col5, #T_e92f7_row3_col0, #T_e92f7_row3_col1, #T_e92f7_row3_col2, #T_e92f7_row3_col3, #T_e92f7_row3_col4, #T_e92f7_row3_col5, #T_e92f7_row4_col0, #T_e92f7_row4_col1, #T_e92f7_row4_col2, #T_e92f7_row4_col3, #T_e92f7_row4_col4, #T_e92f7_row4_col5, #T_e92f7_row5_col0, #T_e92f7_row5_col1, #T_e92f7_row5_col2, #T_e92f7_row5_col3, #T_e92f7_row5_col4, #T_e92f7_row5_col5, #T_e92f7_row6_col0, #T_e92f7_row6_col1, #T_e92f7_row6_col2, #T_e92f7_row6_col3, #T_e92f7_row6_col4, #T_e92f7_row6_col5, #T_e92f7_row7_col0, #T_e92f7_row7_col1, #T_e92f7_row7_col2, #T_e92f7_row7_col3, #T_e92f7_row7_col4, #T_e92f7_row7_col5, #T_e92f7_row8_col0, #T_e92f7_row8_col1, #T_e92f7_row8_col2, #T_e92f7_row8_col3, #T_e92f7_row8_col4, #T_e92f7_row8_col5, #T_e92f7_row9_col0, #T_e92f7_row9_col1, #T_e92f7_row9_col2, #T_e92f7_row9_col3, #T_e92f7_row9_col4, #T_e92f7_row9_col5, #T_e92f7_row10_col0, #T_e92f7_row10_col1, #T_e92f7_row10_col2, #T_e92f7_row10_col3, #T_e92f7_row10_col4, #T_e92f7_row10_col5, #T_e92f7_row11_col0, #T_e92f7_row11_col1, #T_e92f7_row11_col2, #T_e92f7_row11_col3, #T_e92f7_row11_col4, #T_e92f7_row11_col5, #T_e92f7_row12_col0, #T_e92f7_row12_col1, #T_e92f7_row12_col2, #T_e92f7_row12_col3, #T_e92f7_row12_col4, #T_e92f7_row12_col5, #T_e92f7_row13_col0, #T_e92f7_row13_col1, #T_e92f7_row13_col2, #T_e92f7_row13_col3, #T_e92f7_row13_col4, #T_e92f7_row13_col5, #T_e92f7_row14_col0, #T_e92f7_row14_col1, #T_e92f7_row14_col2, #T_e92f7_row14_col3, #T_e92f7_row14_col4, #T_e92f7_row14_col5 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_e92f7">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e92f7_level0_col0" class="col_heading level0 col0" >mean</th>
#       <th id="T_e92f7_level0_col1" class="col_heading level0 col1" >50\%</th>
#       <th id="T_e92f7_level0_col2" class="col_heading level0 col2" >min</th>
#       <th id="T_e92f7_level0_col3" class="col_heading level0 col3" >max</th>
#       <th id="T_e92f7_level0_col4" class="col_heading level0 col4" >Total</th>
#       <th id="T_e92f7_level0_col5" class="col_heading level0 col5" >CVx100</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" ></th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e92f7_level0_row0" class="row_heading level0 row0" >tok\_per\_sent</th>
#       <td id="T_e92f7_row0_col0" class="data row0 col0" >30.390398</td>
#       <td id="T_e92f7_row0_col1" class="data row0 col1" >31.139457</td>
#       <td id="T_e92f7_row0_col2" class="data row0 col2" >23.524093</td>
#       <td id="T_e92f7_row0_col3" class="data row0 col3" >32.195978</td>
#       <td id="T_e92f7_row0_col4" class="data row0 col4" >109922.067876</td>
#       <td id="T_e92f7_row0_col5" class="data row0 col5" >7.452490</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row1" class="row_heading level0 row1" >ADV\_tok\_per\_sent</th>
#       <td id="T_e92f7_row1_col0" class="data row1 col0" >2.107402</td>
#       <td id="T_e92f7_row1_col1" class="data row1 col1" >2.133300</td>
#       <td id="T_e92f7_row1_col2" class="data row1 col2" >1.581904</td>
#       <td id="T_e92f7_row1_col3" class="data row1 col3" >2.228142</td>
#       <td id="T_e92f7_row1_col4" class="data row1 col4" >7622.473013</td>
#       <td id="T_e92f7_row1_col5" class="data row1 col5" >4.424594</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row2" class="row_heading level0 row2" >ADJ\_tok\_per\_sent</th>
#       <td id="T_e92f7_row2_col0" class="data row2 col0" >2.598741</td>
#       <td id="T_e92f7_row2_col1" class="data row2 col1" >2.592927</td>
#       <td id="T_e92f7_row2_col2" class="data row2 col2" >2.271796</td>
#       <td id="T_e92f7_row2_col3" class="data row2 col3" >3.075629</td>
#       <td id="T_e92f7_row2_col4" class="data row2 col4" >9399.644986</td>
#       <td id="T_e92f7_row2_col5" class="data row2 col5" >1.681286</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row3" class="row_heading level0 row3" >NEG\_tok\_per\_sent</th>
#       <td id="T_e92f7_row3_col0" class="data row3 col0" >0.311711</td>
#       <td id="T_e92f7_row3_col1" class="data row3 col1" >0.320608</td>
#       <td id="T_e92f7_row3_col2" class="data row3 col2" >0.163388</td>
#       <td id="T_e92f7_row3_col3" class="data row3 col3" >0.363451</td>
#       <td id="T_e92f7_row3_col4" class="data row3 col4" >1127.459420</td>
#       <td id="T_e92f7_row3_col5" class="data row3 col5" >9.827857</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row4" class="row_heading level0 row4" >NEG\_tok\_per\_mill</th>
#       <td id="T_e92f7_row4_col0" class="data row4 col0" >10238.704921</td>
#       <td id="T_e92f7_row4_col1" class="data row4 col1" >10311.474769</td>
#       <td id="T_e92f7_row4_col2" class="data row4 col2" >6901.384613</td>
#       <td id="T_e92f7_row4_col3" class="data row4 col3" >13071.895425</td>
#       <td id="T_e92f7_row4_col4" class="data row4 col4" >37033395.700265</td>
#       <td id="T_e92f7_row4_col5" class="data row4 col5" >4.379358</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row5" class="row_heading level0 row5" >ADV\_tok\_per\_mill</th>
#       <td id="T_e92f7_row5_col0" class="data row5 col0" >69566.598296</td>
#       <td id="T_e92f7_row5_col1" class="data row5 col1" >68617.616136</td>
#       <td id="T_e92f7_row5_col2" class="data row5 col2" >65676.414220</td>
#       <td id="T_e92f7_row5_col3" class="data row5 col3" >84889.384072</td>
#       <td id="T_e92f7_row5_col4" class="data row5 col4" >251622386.035120</td>
#       <td id="T_e92f7_row5_col5" class="data row5 col5" >4.875261</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row6" class="row_heading level0 row6" >ADJ\_tok\_per\_mill</th>
#       <td id="T_e92f7_row6_col0" class="data row6 col0" >86166.760500</td>
#       <td id="T_e92f7_row6_col1" class="data row6 col1" >83283.729315</td>
#       <td id="T_e92f7_row6_col2" class="data row6 col2" >79799.685689</td>
#       <td id="T_e92f7_row6_col3" class="data row6 col3" >120159.504580</td>
#       <td id="T_e92f7_row6_col4" class="data row6 col4" >311665172.727584</td>
#       <td id="T_e92f7_row6_col5" class="data row6 col5" >10.357154</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row7" class="row_heading level0 row7" >ADV\_form\_per\_lemma</th>
#       <td id="T_e92f7_row7_col0" class="data row7 col0" >1.226534</td>
#       <td id="T_e92f7_row7_col1" class="data row7 col1" >1.242447</td>
#       <td id="T_e92f7_row7_col2" class="data row7 col2" >1.034682</td>
#       <td id="T_e92f7_row7_col3" class="data row7 col3" >1.297749</td>
#       <td id="T_e92f7_row7_col4" class="data row7 col4" >4436.374840</td>
#       <td id="T_e92f7_row7_col5" class="data row7 col5" >4.268204</td>
#     </tr>
#     <tr>
#       <th id="T_e92f7_level0_row8" class="row_heading level0 row8" >ADV\_tok\_per\_lemma</th>
#       <td id="T_e92f7_row8_col0" class="data row8 col0" >38.2
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/only-rates-main-stats-birc.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/only-rates-main-stats-birc.2025-02-18.tex')

# %% [markdown]
#  ## *Calculate **Reduction*** (<code>BiRC - Full</code>)

# %%
reduction_df = birc_counts_df - orig_counts_df
# iloc[:, 1:] drops the uninformtative `count` column
# save_latex_table(reduction_df.describe().T.iloc[:, 1:].assign(Total=reduction_df.sum()).convert_dtypes(),
#                  caption='Reduction (BiRC -- Full) Counts & Rates: Descriptive Stats', verbose=True,
#                  latex_subdir=REL_BIRC_TEX_DIR,
#                  latex_stem='plus-rates-birc-minus-full-descrip-stats')
# save_latex_table(reduction_df.filter(like='per').describe().T.iloc[:, 1:].assign(Total=reduction_df.sum()).convert_dtypes(),
#                  caption='Reduction (BiRC -- Full) Rates: Descriptive Stats', verbose=True,
#                  latex_subdir=REL_BIRC_TEX_DIR,
#                  latex_stem='only-rates-birc-minus-full-descrip-stats')
# nb_display(set_my_style(reduction_df.describe().T.assign(Total=reduction_df.sum()).convert_dtypes(),
#                         caption='BiRC <i>Reduction</i>: Descriptive Stats', precision=1))
nb_display(set_my_style(reduction_df.filter(
    like='per').loc[samix, :].T, caption='"Rate" columns for <code>BiRC - Full</code> counts'))
# Out:
# <style type="text/css">
# #T_76e89 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_76e89 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_76e89 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_76e89 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_76e89 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_76e89 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_76e89 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_76e89 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_76e89_row0_col0, #T_76e89_row0_col1, #T_76e89_row0_col2, #T_76e89_row0_col3, #T_76e89_row1_col0, #T_76e89_row1_col1, #T_76e89_row1_col2, #T_76e89_row1_col3, #T_76e89_row2_col0, #T_76e89_row2_col1, #T_76e89_row2_col2, #T_76e89_row2_col3, #T_76e89_row3_col0, #T_76e89_row3_col1, #T_76e89_row3_col2, #T_76e89_row3_col3, #T_76e89_row4_col0, #T_76e89_row4_col1, #T_76e89_row4_col2, #T_76e89_row4_col3, #T_76e89_row5_col0, #T_76e89_row5_col1, #T_76e89_row5_col2, #T_76e89_row5_col3, #T_76e89_row6_col0, #T_76e89_row6_col1, #T_76e89_row6_col2, #T_76e89_row6_col3, #T_76e89_row7_col0, #T_76e89_row7_col1, #T_76e89_row7_col2, #T_76e89_row7_col3, #T_76e89_row8_col0, #T_76e89_row8_col1, #T_76e89_row8_col2, #T_76e89_row8_col3, #T_76e89_row9_col0, #T_76e89_row9_col1, #T_76e89_row9_col2, #T_76e89_row9_col3, #T_76e89_row10_col0, #T_76e89_row10_col1, #T_76e89_row10_col2, #T_76e89_row10_col3, #T_76e89_row11_col0, #T_76e89_row11_col1, #T_76e89_row11_col2, #T_76e89_row11_col3, #T_76e89_row12_col0, #T_76e89_row12_col1, #T_76e89_row12_col2, #T_76e89_row12_col3, #T_76e89_row13_col0, #T_76e89_row13_col1, #T_76e89_row13_col2, #T_76e89_row13_col3, #T_76e89_row14_col0, #T_76e89_row14_col1, #T_76e89_row14_col2, #T_76e89_row14_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_76e89">
#   <caption>"Rate" columns for <code>BiRC - Full</code> counts</caption>
#   <thead>
#     <tr>
#       <th class="index_name level0" >corpus_slice</th>
#       <th id="T_76e89_level0_col0" class="col_heading level0 col0" >apw_eng_200703</th>
#       <th id="T_76e89_level0_col1" class="col_heading level0 col1" >pcc_eng_00-041</th>
#       <th id="T_76e89_level0_col2" class="col_heading level0 col2" >pcc_eng_04-100</th>
#       <th id="T_76e89_level0_col3" class="col_heading level0 col3" >pcc_eng_14-056</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_76e89_level0_row0" class="row_heading level0 row0" >tok_per_sent</th>
#       <td id="T_76e89_row0_col0" class="data row0 col0" >-0.18</td>
#       <td id="T_76e89_row0_col1" class="data row0 col1" >0.03</td>
#       <td id="T_76e89_row0_col2" class="data row0 col2" >0.00</td>
#       <td id="T_76e89_row0_col3" class="data row0 col3" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row1" class="row_heading level0 row1" >ADV_tok_per_sent</th>
#       <td id="T_76e89_row1_col0" class="data row1 col0" >1.23</td>
#       <td id="T_76e89_row1_col1" class="data row1 col1" >1.31</td>
#       <td id="T_76e89_row1_col2" class="data row1 col2" >1.30</td>
#       <td id="T_76e89_row1_col3" class="data row1 col3" >1.34</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row2" class="row_heading level0 row2" >ADJ_tok_per_sent</th>
#       <td id="T_76e89_row2_col0" class="data row2 col0" >1.32</td>
#       <td id="T_76e89_row2_col1" class="data row2 col1" >1.30</td>
#       <td id="T_76e89_row2_col2" class="data row2 col2" >1.31</td>
#       <td id="T_76e89_row2_col3" class="data row2 col3" >1.32</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row3" class="row_heading level0 row3" >NEG_tok_per_sent</th>
#       <td id="T_76e89_row3_col0" class="data row3 col0" >0.08</td>
#       <td id="T_76e89_row3_col1" class="data row3 col1" >0.15</td>
#       <td id="T_76e89_row3_col2" class="data row3 col2" >0.15</td>
#       <td id="T_76e89_row3_col3" class="data row3 col3" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row4" class="row_heading level0 row4" >NEG_tok_per_mill</th>
#       <td id="T_76e89_row4_col0" class="data row4 col0" >3,573.89</td>
#       <td id="T_76e89_row4_col1" class="data row4 col1" >4,768.78</td>
#       <td id="T_76e89_row4_col2" class="data row4 col2" >4,831.32</td>
#       <td id="T_76e89_row4_col3" class="data row4 col3" >4,966.05</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row5" class="row_heading level0 row5" >ADV_tok_per_mill</th>
#       <td id="T_76e89_row5_col0" class="data row5 col0" >52,331.79</td>
#       <td id="T_76e89_row5_col1" class="data row5 col1" >42,006.82</td>
#       <td id="T_76e89_row5_col2" class="data row5 col2" >41,845.41</td>
#       <td id="T_76e89_row5_col3" class="data row5 col3" >42,941.71</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row6" class="row_heading level0 row6" >ADJ_tok_per_mill</th>
#       <td id="T_76e89_row6_col0" class="data row6 col0" >56,301.97</td>
#       <td id="T_76e89_row6_col1" class="data row6 col1" >41,859.05</td>
#       <td id="T_76e89_row6_col2" class="data row6 col2" >42,236.47</td>
#       <td id="T_76e89_row6_col3" class="data row6 col3" >42,340.58</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row7" class="row_heading level0 row7" >ADV_form_per_lemma</th>
#       <td id="T_76e89_row7_col0" class="data row7 col0" >-0.01</td>
#       <td id="T_76e89_row7_col1" class="data row7 col1" >-0.05</td>
#       <td id="T_76e89_row7_col2" class="data row7 col2" >-0.05</td>
#       <td id="T_76e89_row7_col3" class="data row7 col3" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row8" class="row_heading level0 row8" >ADV_tok_per_lemma</th>
#       <td id="T_76e89_row8_col0" class="data row8 col0" >-96.95</td>
#       <td id="T_76e89_row8_col1" class="data row8 col1" >-49.16</td>
#       <td id="T_76e89_row8_col2" class="data row8 col2" >-48.02</td>
#       <td id="T_76e89_row8_col3" class="data row8 col3" >-50.10</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row9" class="row_heading level0 row9" >ADV_tok_per_form</th>
#       <td id="T_76e89_row9_col0" class="data row9 col0" >-86.61</td>
#       <td id="T_76e89_row9_col1" class="data row9 col1" >-37.07</td>
#       <td id="T_76e89_row9_col2" class="data row9 col2" >-35.83</td>
#       <td id="T_76e89_row9_col3" class="data row9 col3" >-37.57</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row10" class="row_heading level0 row10" >ADJ_form_per_lemma</th>
#       <td id="T_76e89_row10_col0" class="data row10 col0" >-0.01</td>
#       <td id="T_76e89_row10_col1" class="data row10 col1" >-0.04</td>
#       <td id="T_76e89_row10_col2" class="data row10 col2" >-0.04</td>
#       <td id="T_76e89_row10_col3" class="data row10 col3" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row11" class="row_heading level0 row11" >ADJ_tok_per_lemma</th>
#       <td id="T_76e89_row11_col0" class="data row11 col0" >-21.03</td>
#       <td id="T_76e89_row11_col1" class="data row11 col1" >-11.29</td>
#       <td id="T_76e89_row11_col2" class="data row11 col2" >-11.11</td>
#       <td id="T_76e89_row11_col3" class="data row11 col3" >-11.47</td>
#     </tr>
#     <tr>
#       <th id="T_76e89_level0_row12" class="row_heading level0 row12" >ADJ_tok_per_form</th>
#       <td id="T_76e89_row12_col0" class="data row12 col0" >-20.25</td>
#       <td id="T_76e89_row12_col

# %%
# %%

def reconfigure_counts(_counts_df, count_kind: str):
    return _counts_df.assign(
        kind=count_kind
    ).reset_index().set_index(['kind', 'corpus_slice']).unstack('kind')


orig_s = reconfigure_counts(orig_counts_df, count_kind='Full')
birc_s = reconfigure_counts(birc_counts_df, 'BiRC')
diff_s = reconfigure_counts(reduction_df, 'diff')
juxta = orig_s.join(birc_s).join(diff_s).convert_dtypes().sort_index(axis=1)

# juxta = orig_counts_df.join(birc_counts_df, rsuffix=':BiRC', lsuffix=':Full').join(reduction_df.add_suffix(':diff')).convert_dtypes()
juxta_desc = juxta.describe().iloc[1:, :]
juxta_desc.loc['TOTAL', :] = juxta.sum()
juxta_desc.index = juxta_desc.index.str.upper()
juxta_desc.loc['CV%', :] = (
    (juxta_desc.T.STD / juxta_desc.T.MEAN).fillna(0) * 100)

save_path = save_latex_table(juxta_desc.T.convert_dtypes(),
                 caption='Juxtaposed BiRC: Descriptive Stats', verbose=True,
                 latex_subdir=REL_BIRC_TEX_DIR,
                 latex_stem='birc-juxtaposed-descrip-stats-complete')
# if save_path is None: 
#     nb_display(set_my_style(juxta_desc.T.convert_dtypes()))
# Out:
# ! Error: Table has more than 50 rows---too long. Reconsider what you want to include.
#   NO TABLE SAVED.
# <style type="text/css">
# #T_637d3 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_637d3 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_637d3 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_637d3 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_637d3_row0_col0, #T_637d3_row0_col1, #T_637d3_row0_col2, #T_637d3_row0_col3, #T_637d3_row0_col4, #T_637d3_row0_col5, #T_637d3_row0_col6, #T_637d3_row0_col7, #T_637d3_row0_col8, #T_637d3_row1_col0, #T_637d3_row1_col1, #T_637d3_row1_col2, #T_637d3_row1_col3, #T_637d3_row1_col4, #T_637d3_row1_col5, #T_637d3_row1_col6, #T_637d3_row1_col7, #T_637d3_row1_col8, #T_637d3_row2_col0, #T_637d3_row2_col1, #T_637d3_row2_col2, #T_637d3_row2_col3, #T_637d3_row2_col4, #T_637d3_row2_col5, #T_637d3_row2_col6, #T_637d3_row2_col7, #T_637d3_row2_col8, #T_637d3_row3_col0, #T_637d3_row3_col1, #T_637d3_row3_col2, #T_637d3_row3_col3, #T_637d3_row3_col4, #T_637d3_row3_col5, #T_637d3_row3_col6, #T_637d3_row3_col7, #T_637d3_row3_col8, #T_637d3_row4_col0, #T_637d3_row4_col1, #T_637d3_row4_col2, #T_637d3_row4_col3, #T_637d3_row4_col4, #T_637d3_row4_col5, #T_637d3_row4_col6, #T_637d3_row4_col7, #T_637d3_row4_col8, #T_637d3_row5_col0, #T_637d3_row5_col1, #T_637d3_row5_col2, #T_637d3_row5_col3, #T_637d3_row5_col4, #T_637d3_row5_col5, #T_637d3_row5_col6, #T_637d3_row5_col7, #T_637d3_row5_col8, #T_637d3_row6_col0, #T_637d3_row6_col1, #T_637d3_row6_col2, #T_637d3_row6_col3, #T_637d3_row6_col4, #T_637d3_row6_col5, #T_637d3_row6_col6, #T_637d3_row6_col7, #T_637d3_row6_col8, #T_637d3_row7_col0, #T_637d3_row7_col1, #T_637d3_row7_col2, #T_637d3_row7_col3, #T_637d3_row7_col4, #T_637d3_row7_col5, #T_637d3_row7_col6, #T_637d3_row7_col7, #T_637d3_row7_col8, #T_637d3_row8_col0, #T_637d3_row8_col1, #T_637d3_row8_col2, #T_637d3_row8_col3, #T_637d3_row8_col4, #T_637d3_row8_col5, #T_637d3_row8_col6, #T_637d3_row8_col7, #T_637d3_row8_col8, #T_637d3_row9_col0, #T_637d3_row9_col1, #T_637d3_row9_col2, #T_637d3_row9_col3, #T_637d3_row9_col4, #T_637d3_row9_col5, #T_637d3_row9_col6, #T_637d3_row9_col7, #T_637d3_row9_col8, #T_637d3_row10_col0, #T_637d3_row10_col1, #T_637d3_row10_col2, #T_637d3_row10_col3, #T_637d3_row10_col4, #T_637d3_row10_col5, #T_637d3_row10_col6, #T_637d3_row10_col7, #T_637d3_row10_col8, #T_637d3_row11_col0, #T_637d3_row11_col1, #T_637d3_row11_col2, #T_637d3_row11_col3, #T_637d3_row11_col4, #T_637d3_row11_col5, #T_637d3_row11_col6, #T_637d3_row11_col7, #T_637d3_row11_col8, #T_637d3_row12_col0, #T_637d3_row12_col1, #T_637d3_row12_col2, #T_637d3_row12_col3, #T_637d3_row12_col4, #T_637d3_row12_col5, #T_637d3_row12_col6, #T_637d3_row12_col7, #T_637d3_row12_col8, #T_637d3_row13_col0, #T_637d3_row13_col1, #T_637d3_row13_col2, #T_637d3_row13_col3, #T_637d3_row13_col4, #T_637d3_row13_col5, #T_637d3_row13_col6, #T_637d3_row13_col7, #T_637d3_row13_col8, #T_637d3_row14_col0, #T_637d3_row14_col1, #T_637d3_row14_col2, #T_637d3_row14_col3, #T_637d3_row14_col4, #T_637d3_row14_col5, #T_637d3_row14_col6, #T_637d3_row14_col7, #T_637d3_row14_col8, #T_637d3_row15_col0, #T_637d3_row15_col1, #T_637d3_row15_col2, #T_637d3_row15_col3, #T_637d3_row15_col4, #T_637d3_row15_col5, #T_637d3_row15_col6, #T_637d3_row15_col7, #T_637d3_row15_col8, #T_637d3_row16_col0, #T_637d3_row16_col1, #T_637d3_row16_col2, #T_637d3_row16_col3, #T_637d3_row16_col4, #T_637d3_row16_col5, #T_637d3_row16_col6, #T_637d3_row16_col7, #T_637d3_row16_col8, #T_637d3_row17_col0, #T_637d3_row17_col1, #T_637d3_row17_col2, #T_637d3_row17_col3, #T_637d3_row17_col4, #T_637d3_row17_col5, #T_637d3_row17_col6, #T_637d3_row17_col7, #T_637d3_row17_col8, #T_637d3_row18_col0, #T_637d3_row18_col1, #T_637d3_row18_col2, #T_637d3_row18_col3, #T_637d3_row18_col4, #T_637d3_row18_col5, #T_637d3_row18_col6, #T_637d3_row18_col7, #T_637d3_row18_col8, #T_637d3_row19_col0, #T_637d3_row19_col1, #T_637d3_row19_col2, #T_637d3_row19_col3, #T_637d3_row19_col4, #T_637d3_row19_col5, #T_637d3_row19_col6, #T_637d3_row19_col7, #T_637d3_row19_col8, #T_637d3_row20_col0, #T_637d3_row20_col1, #T_637d3_row20_col2, #T_637d3_row20_col3, #T_637d3_row20_col4, #T_637d3_row20_col5, #T_637d3_row20_col6, #T_637d3_row20_col7, #T_637d3_row20_col8, #T_637d3_row21_col0, #T_637d3_row21_col1, #T_637d3_row21_col2, #T_637d3_row21_col3, #T_637d3_row21_col4, #T_637d3_row21_c ...

# %%
juxta = juxta.assign(
    corpus=juxta.index.to_series().str[:3].map(
        {'apw': 'News', 'nyt': 'News', 'pcc': 'Puddin'}).astype('category'))
juxta = juxta.reset_index().set_index(['corpus']+juxta.index.names)
juxta = juxta.sort_index().sort_index(axis=1)

# %%
juxta.filter(like='tokens').sum().unstack(0)
# Out:
#        ADJ_tokens  ADV_tokens  NEG_tokens        tokens
# kind
# BiRC    231075711   187278242    27663509    2692793781
# Full   1245545132   765468366   159335611   28805717900
# diff  -1014469421  -578190124  -131672102  -26112924119

# %%
corpus_tokens_stack = juxta.stack(1).filter(like='tokens')
corpus_tokens_stack.columns.name = 'token_type'
corpus_tokens_stack = corpus_tokens_stack.stack().to_frame('count').reset_index(level=['corpus','kind', 'token_type']).sort_values(['corpus','kind', 'token_type'])
corpus_tokens_stack.value_counts(['corpus', 'kind', 'token_type'])
# Out:
# corpus  kind  token_type
# Puddin  Full  ADJ_tokens    3247
#               ADV_tokens    3247
#               NEG_tokens    3247
#               tokens        3247
#         BiRC  ADJ_tokens    3247
#               ADV_tokens    3247
#               NEG_tokens    3247
#               tokens        3247
#         diff  ADJ_tokens    3247
#               ADV_tokens    3247
#               NEG_tokens    3247
#               tokens        3247
# News    BiRC  tokens         370
#               NEG_tokens     370
#               ADV_tokens     370
#               ADJ_tokens     370
#         Full  tokens         370
#               NEG_tokens     370
#               ADV_tokens     370
#               ADJ_tokens     370
#         diff  ADJ_tokens     370
#               ADV_tokens     370
#               NEG_tokens     370
#               tokens         370
# Name: count, dtype: int64

# %%
corpus_kind_token_totals=(pd.concat(
    [style_crosstab(corpus_tokens_stack,
                    ['corpus', 'kind'], ['token_type'], value_col='count', aggfunc='sum',
                    return_cross_df=True
                    ).sort_index().sort_index(axis=1),
     style_crosstab(corpus_tokens_stack,
                    ['kind'], ['token_type'], value_col='count', aggfunc='sum',
                    return_cross_df=True
                    ).assign(corpus='News+Puddin').reset_index().set_index(['corpus', 'kind']).sort_index()
     ]
).sort_index(axis=1)
)
save_latex_table(corpus_kind_token_totals, 
                 caption='BiRC Token Count Comparisons by Corpus \& Overall', 
                 latex_stem='birc-token-counts-by-corpus-kind',
                 latex_subdir=REL_BIRC_TEX_DIR, verbose=True, default_SI=-11.1, 
                 neg_color='BrickRed'
                                        )
# Out:
# Caption: BiRC Token Count Comparisons by Corpus \& Overall
# *{2}{l}S[table-auto-round, table-format=-11.1, drop-zero-decimal, negative-color={BrickRed}]
#     S[table-auto-round, table-format=-11.1, drop-zero-decimal, negative-color={BrickRed}]
#     S[table-auto-round, table-format=-11.1, drop-zero-decimal, negative-color={BrickRed}]
#     S[table-auto-round, table-format=-11.1, drop-zero-decimal, negative-color={BrickRed}]
# <style type="text/css">
# #T_06e52 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_06e52 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_06e52 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_06e52 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_06e52_row0_col0, #T_06e52_row0_col1, #T_06e52_row0_col2, #T_06e52_row0_col3, #T_06e52_row1_col0, #T_06e52_row1_col1, #T_06e52_row1_col2, #T_06e52_row1_col3, #T_06e52_row2_col0, #T_06e52_row2_col1, #T_06e52_row2_col2, #T_06e52_row2_col3, #T_06e52_row3_col0, #T_06e52_row3_col1, #T_06e52_row3_col2, #T_06e52_row3_col3, #T_06e52_row4_col0, #T_06e52_row4_col1, #T_06e52_row4_col2, #T_06e52_row4_col3, #T_06e52_row5_col0, #T_06e52_row5_col1, #T_06e52_row5_col2, #T_06e52_row5_col3, #T_06e52_row6_col0, #T_06e52_row6_col1, #T_06e52_row6_col2, #T_06e52_row6_col3, #T_06e52_row7_col0, #T_06e52_row7_col1, #T_06e52_row7_col2, #T_06e52_row7_col3, #T_06e52_row8_col0, #T_06e52_row8_col1, #T_06e52_row8_col2, #T_06e52_row8_col3 {
#   text-align: right;
#   font-family: iosevka aile;
#   font-size: 8.5pt;
# }
# </style>
# <table id="T_06e52">
#   <thead>
#     <tr>
#       <th class="blank" >&nbsp;</th>
#       <th class="index_name level0" >token_type</th>
#       <th id="T_06e52_level0_col0" class="col_heading level0 col0" >ADJ\_tokens</th>
#       <th id="T_06e52_level0_col1" class="col_heading level0 col1" >ADV\_tokens</th>
#       <th id="T_06e52_level0_col2" class="col_heading level0 col2" >NEG\_tokens</th>
#       <th id="T_06e52_level0_col3" class="col_heading level0 col3" >tokens</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Corpus</th>
#       <th class="index_name level1" >Kind</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_06e52_level0_row0" class="row_heading level0 row0" rowspan="3">News</th>
#       <th id="T_06e52_level1_row0" class="row_heading level1 row0" >BiRC</th>
#       <td id="T_06e52_row0_col0" class="data row0 col0" >27,043,166</td>
#       <td id="T_06e52_row0_col1" class="data row0 col1" >19,147,268</td>
#       <td id="T_06e52_row0_col2" class="data row0 col2" >2,351,756</td>
#       <td id="T_06e52_row0_col3" class="data row0 col3" >240,357,823</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level1_row1" class="row_heading level1 row1" >Full</th>
#       <td id="T_06e52_row1_col0" class="data row1 col0" >190,371,676</td>
#       <td id="T_06e52_row1_col1" class="data row1 col1" >91,955,223</td>
#       <td id="T_06e52_row1_col2" class="data row1 col2" >21,611,437</td>
#       <td id="T_06e52_row1_col3" class="data row1 col3" >3,300,216,537</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level1_row2" class="row_heading level1 row2" >diff</th>
#       <td id="T_06e52_row2_col0" class="data row2 col0" >-163,328,510</td>
#       <td id="T_06e52_row2_col1" class="data row2 col1" >-72,807,955</td>
#       <td id="T_06e52_row2_col2" class="data row2 col2" >-19,259,681</td>
#       <td id="T_06e52_row2_col3" class="data row2 col3" >-3,059,858,714</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level0_row3" class="row_heading level0 row3" rowspan="3">Puddin</th>
#       <th id="T_06e52_level1_row3" class="row_heading level1 row3" >BiRC</th>
#       <td id="T_06e52_row3_col0" class="data row3 col0" >204,032,545</td>
#       <td id="T_06e52_row3_col1" class="data row3 col1" >168,130,974</td>
#       <td id="T_06e52_row3_col2" class="data row3 col2" >25,311,753</td>
#       <td id="T_06e52_row3_col3" class="data row3 col3" >2,452,435,958</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level1_row4" class="row_heading level1 row4" >Full</th>
#       <td id="T_06e52_row4_col0" class="data row4 col0" >1,055,173,456</td>
#       <td id="T_06e52_row4_col1" class="data row4 col1" >673,513,143</td>
#       <td id="T_06e52_row4_col2" class="data row4 col2" >137,724,174</td>
#       <td id="T_06e52_row4_col3" class="data row4 col3" >25,505,501,363</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level1_row5" class="row_heading level1 row5" >diff</th>
#       <td id="T_06e52_row5_col0" class="data row5 col0" >-851,140,911</td>
#       <td id="T_06e52_row5_col1" class="data row5 col1" >-505,382,169</td>
#       <td id="T_06e52_row5_col2" class="data row5 col2" >-112,412,421</td>
#       <td id="T_06e52_row5_col3" class="data row5 col3" >-23,053,065,405</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level0_row6" class="row_heading level0 row6" rowspan="3">News+Puddin</th>
#       <th id="T_06e52_level1_row6" class="row_heading level1 row6" >BiRC</th>
#       <td id="T_06e52_row6_col0" class="data row6 col0" >231,075,711</td>
#       <td id="T_06e52_row6_col1" class="data row6 col1" >187,278,242</td>
#       <td id="T_06e52_row6_col2" class="data row6 col2" >27,663,509</td>
#       <td id="T_06e52_row6_col3" class="data row6 col3" >2,692,793,781</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level1_row7" class="row_heading level1 row7" >Full</th>
#       <td id="T_06e52_row7_col0" class="data row7 col0" >1,245,545,132</td>
#       <td id="T_06e52_row7_col1" class="data row7 col1" >765,468,366</td>
#       <td id="T_06e52_row7_col2" class="data row7 col2" >159,335,611</td>
#       <td id="T_06e52_row7_col3" class="data row7 col3" >28,805,717,900</td>
#     </tr>
#     <tr>
#       <th id="T_06e52_level1_row8" class="row_heading level1 row8" >diff</th>
#       <td id="T_06e52_row8_col0" class="data row8 col0" >-1,014,469,421</td>
#       <td id="T_06e52_row8_col1" class="data row8 col1" >-578,190,124</td>
#       <td id="T_06e52_row8_col2" class="data row8 col2" >-131,672,102</td>
#       <td id="T_06e52_row8_col3" class="data row8 col3" >-26,112,924,119</td>
#     </tr>
#   </tbody>
# </table>
# Stylized latex table saved as:
#   OverleafDissertex/assets/tables/ch6/BiRC/birc-token-counts-by-corpus-kind.2025-02-18.tex
# PosixPath('/share/compling/projects/arh234/OverleafDissertex/assets/tables/ch6/BiRC/birc-token-counts-by-corpus-kind.2025-02-18.tex')

# %%
# %%

save_latex_table(
    pd.concat([
        juxta.filter(like='apw', axis=0).sample(1), 
        juxta.filter(like='nyt', axis=0).sample(1),
        # 👆 one sample of apw  and nyt each
        # and then 2 puddin samples
        juxta.filter(like='pcc', axis=0).sample(2)
    ]).drop_duplicates().sort_index().T,
    caption=('Sample of Juxtaposed Counts'),
    verbose=True,
    latex_subdir=REL_BIRC_TEX_DIR,
    latex_stem='birc-juxtaposed-sample-2x2')

# %%
def describe_and_total(_df):
    return _df.describe().T.assign(total=_df.sum()).T


by_corpus_descrip = juxta.groupby(
    'corpus', observed=True).apply(describe_and_total)
by_corpus_descrip.index.names = ['corpus', 'stat']
by_corpus_descrip.columns.names = ['obs', 'kind']

by_corpus_descrip = (
    by_corpus_descrip
    .stack(['obs', 'kind'])
    .unstack(['corpus', 'kind', 'stat'])
    .stack('stat')
    .rename(index={
            'count': '# files',
            '50%': 'median'}))
nb_display(by_corpus_descrip)
# Out:
# <style type="text/css">
# #T_53853 th.index_name {
#   font-family: iosevka aile;
#   font-size: 8pt;
#   font-style: italic;
#   color: darkgrey;
# }
# #T_53853 th.col_heading {
#   font-family: iosevka fixed;
#   font-size: 10pt;
#   text-align: center;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_53853 th.row_heading {
#   font-weight: 500;
#   text-align: right;
#   font-family: iosevka aile;
#   font-style: italic;
#   font-size: 9pt;
#   border-bottom: 1px dotted darkgrey;
#   border-right: 1px dotted darkgrey;
# }
# #T_53853 caption {
#   caption-side: top;
#   text-align: center;
#   font-size: 1.2em;
#   font-family: serif;
# }
# #T_53853_row0_col0, #T_53853_row0_col1, #T_53853_row0_col2, #T_53853_row0_col3, #T_53853_row0_col4, #T_53853_row0_col5, #T_53853_row1_col0, #T_53853_row1_col1, #T_53853_row1_col2, #T_53853_row1_col3, #T_53853_row1_col4, #T_53853_row1_col5, #T_53853_row2_col0, #T_53853_row2_col1, #T_53853_row2_col2, #T_53853_row2_col3, #T_53853_row2_col4, #T_53853_row2_col5, #T_53853_row3_col0, #T_53853_row3_col1, #T_53853_row3_col2, #T_53853_row3_col3, #T_53853_row3_col4, #T_53853_row3_col5, #T_53853_row4_col0, #T_53853_row4_col1, #T_53853_row4_col2, #T_53853_row4_col3, #T_53853_row4_col4, #T_53853_row4_col5, #T_53853_row5_col0, #T_53853_row5_col1, #T_53853_row5_col2, #T_53853_row5_col3, #T_53853_row5_col4, #T_53853_row5_col5, #T_53853_row6_col0, #T_53853_row6_col1, #T_53853_row6_col2, #T_53853_row6_col3, #T_53853_row6_col4, #T_53853_row6_col5, #T_53853_row7_col0, #T_53853_row7_col1, #T_53853_row7_col2, #T_53853_row7_col3, #T_53853_row7_col4, #T_53853_row7_col5, #T_53853_row8_col0, #T_53853_row8_col1, #T_53853_row8_col2, #T_53853_row8_col3, #T_53853_row8_col4, #T_53853_row8_col5, #T_53853_row9_col0, #T_53853_row9_col1, #T_53853_row9_col2, #T_53853_row9_col3, #T_53853_row9_col4, #T_53853_row9_col5, #T_53853_row10_col0, #T_53853_row10_col1, #T_53853_row10_col2, #T_53853_row10_col3, #T_53853_row10_col4, #T_53853_row10_col5, #T_53853_row11_col0, #T_53853_row11_col1, #T_53853_row11_col2, #T_53853_row11_col3, #T_53853_row11_col4, #T_53853_row11_col5, #T_53853_row12_col0, #T_53853_row12_col1, #T_53853_row12_col2, #T_53853_row12_col3, #T_53853_row12_col4, #T_53853_row12_col5, #T_53853_row13_col0, #T_53853_row13_col1, #T_53853_row13_col2, #T_53853_row13_col3, #T_53853_row13_col4, #T_53853_row13_col5, #T_53853_row14_col0, #T_53853_row14_col1, #T_53853_row14_col2, #T_53853_row14_col3, #T_53853_row14_col4, #T_53853_row14_col5, #T_53853_row15_col0, #T_53853_row15_col1, #T_53853_row15_col2, #T_53853_row15_col3, #T_53853_row15_col4, #T_53853_row15_col5, #T_53853_row16_col0, #T_53853_row16_col1, #T_53853_row16_col2, #T_53853_row16_col3, #T_53853_row16_col4, #T_53853_row16_col5, #T_53853_row17_col0, #T_53853_row17_col1, #T_53853_row17_col2, #T_53853_row17_col3, #T_53853_row17_col4, #T_53853_row17_col5, #T_53853_row18_col0, #T_53853_row18_col1, #T_53853_row18_col2, #T_53853_row18_col3, #T_53853_row18_col4, #T_53853_row18_col5, #T_53853_row19_col0, #T_53853_row19_col1, #T_53853_row19_col2, #T_53853_row19_col3, #T_53853_row19_col4, #T_53853_row19_col5, #T_53853_row20_col0, #T_53853_row20_col1, #T_53853_row20_col2, #T_53853_row20_col3, #T_53853_row20_col4, #T_53853_row20_col5, #T_53853_row21_col0, #T_53853_row21_col1, #T_53853_row21_col2, #T_53853_row21_col3, #T_53853_row21_col4, #T_53853_row21_col5, #T_53853_row22_col0, #T_53853_row22_col1, #T_53853_row22_col2, #T_53853_row22_col3, #T_53853_row22_col4, #T_53853_row22_col5, #T_53853_row23_col0, #T_53853_row23_col1, #T_53853_row23_col2, #T_53853_row23_col3, #T_53853_row23_col4, #T_53853_row23_col5, #T_53853_row24_col0, #T_53853_row24_col1, #T_53853_row24_col2, #T_53853_row24_col3, #T_53853_row24_col4, #T_53853_row24_col5, #T_53853_row25_col0, #T_53853_row25_col1, #T_53853_row25_col2, #T_53853_row25_col3, #T_53853_row25_col4, #T_53853_row25_col5, #T_53853_row26_col0, #T_53853_row26_col1, #T_53853_row26_col2, #T_53853_row26_col3, #T_53853_row26_col4, #T_53853_row26_col5, #T_53853_row27_col0, #T_53853_row27_col1, #T_53853_row27_col2, #T_53853_row27_col3, #T_53853_row27_col4, #T_53853_row27_col5, #T_53853_row28_col0, #T_53853_row28_col1, #T_53853_row28_col2, #T_53853_row28_col3, #T_53853_row28_col4, #T_53853_row28_col5, #T_53853_row29_col0, #T_53853_row29_col1, #T_53853_row29_col2, #T_53853_row29_col3, #T_53853_row29_col4, #T_53853_row29_col5, #T_53853_row30_col0, #T_53853_row30_col1, #T_53853_row30_col2, #T_53853_row30_col3, #T_53853_row30_col4, #T_53853_row30_col5, #T_53853_row31_col0, #T_53853_row31_col1, #T_53853_row31_col2, #T_53853_row31_col3, #T_53853_row31_col4, #T_53853_row31_col5, #T_53853_row32_col0, #T_5385 ...

# %%
# save_latex_table(
#     by_corpus_descrip.xs('file_MB').style,
#     caption=('BiRC Storare Size (MB) Comparison by Corpus '),
#     verbose=True,
#     latex_subdir=REL_BIRC_TEX_DIR,
#     latex_stem='birc-by-corpus-size-compare-summary'
# )
# save_latex_table(
#     by_corpus_descrip.xs('tokens').style,
#     caption=('BiRC Token Comparison by Corpus '),
#     verbose=True,
#     latex_subdir=REL_BIRC_TEX_DIR,
#     latex_stem='birc-by-corpus-token-compare-summary'
# )

# save_latex_table(
#     by_corpus_descrip.xs('sentences').style,
#     caption=('BiRC Sentence Comparison by Corpus '),
#     verbose=True,
#     latex_subdir=REL_BIRC_TEX_DIR,
#     latex_stem='birc-by-corpus-sentence-compare-summary'
# )
