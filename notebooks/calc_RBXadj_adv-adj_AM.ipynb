# %%
import pandas as pd

from source.utils import FREQ_DIR, RESULT_DIR, UCS_DIR, confirm_dir
from source.utils.associate import (BINARY_ASSOC_ARGS, add_extra_am,
                                    associate_ucs, confirm_basic_ucs)
from source.utils.associate import convert_ucs_to_csv as ucs2csv
from source.utils.associate import get_associations_csv as init_am, AM_DF_DIR
from source.utils.associate import manipulate_ucs, seek_readable_ucs, adjust_assoc_columns
pd.set_option('display.float_format', '{:,.2f}'.format)
# Out:
# /home/arh234/anaconda3/envs/dev-sanpi/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.3
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"

# %% [markdown]
# set parameters

# %%
UNIT = 'Adj'
# PAT_DIR = 'POSmirror'
# PAT_DIR = 'NEGmirror'
# PAT_DIR = 'ANYmirror'
# PAT_DIR = 'RBdirect'
PAT_DIR = 'RBXadj'
# FRQ_FLOOR = 3
# FRQ_FLOOR = 10
# FRQ_FLOOR = 20
# FRQ_FLOOR = 50
FRQ_FLOOR = 100  # BUG 100 will be used regardless, so set it to this to at least keep the naming accurate
ADVADJ_TSV = FREQ_DIR.joinpath(
    f'{PAT_DIR}/ucs_format/Adv{UNIT}_frq-thrMIN-7.35f.tsv')
FOCUS = ['f', 'unexpected_f',
         'conservative_log_ratio',
         'am_p1_given2', 'am_p2_given1',
         'am_p1_given2_simple', 'am_p2_given1_simple',
         'am_log_likelihood',
         #  'mutual_information', 'am_odds_ratio_disc', 't_score',
         'N', 'f1', 'f2', 'E11',
         'l1', 'l2']

# %%
def invert_set_dict(d: dict):
    return {v: k for k in d for v in d[k]}

# %% [markdown]
# 1. Run `seek_readable_ucs()` to generate consistent output path

# %%
readable = seek_readable_ucs(min_freq=FRQ_FLOOR,
                             ucs_subdir='adv_adj',
                             contained_counts_path=ADVADJ_TSV)
print(readable.relative_to(RESULT_DIR))
# Out:
#     > seeking `adv_adj/RBXadj/readable/AdvAdj_frq-thrMIN-7.35f_min100x*` frequency data and initial associations...
# ucs/adv_adj/RBXadj/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv

# %% [markdown]
# Snippet of starting frequency data (`ADVADJ_TSV`)

# %%
! head -5 {ADVADJ_TSV} | column -t
# Out:
# 1191864  so    many
# 748533   most  important
# 614652   so    much
# 583184   too   much
# 507499   very  good

# %% [markdown]
#  2. Run `confirm_basic_ucs()` (if needed)

# %%
if not readable.is_file():
    basic_ucs_path = readable.parent.parent.joinpath(
        readable.name.replace('.rsort-view_am-only.txt', '.ds.gz'))
    print(
        f'Creating initial UCS table: `{basic_ucs_path.relative_to(RESULT_DIR)}')

    basic_ucs_path = confirm_basic_ucs(
        basic_ucs_path,
        freq_floor=FRQ_FLOOR,
        contained_counts_path=ADVADJ_TSV)

# %% [markdown]
# Excerpt of initial UCS table

# %%
init_readable = UCS_DIR.joinpath(
    f'adv_adj/{PAT_DIR}/readable'
).joinpath(f'{ADVADJ_TSV.name.replace(".tsv","")}_min{FRQ_FLOOR}x.init.txt')
! head -7 {init_readable}
# Out:
#                   l1  l2                       f       f2        f1         N
# --------------------  -----------------  -------  -------  --------  --------
#                 very  many                 21237  2212989  10051689  86330753
#                 more  many                   373  2212989   9607398  86330753
#                 most  many                   140  2212989   7734049  86330753
#                   so  many               1191874  2212989   5819223  86330753
#                  not  many                 58442  2212989   4511534  86330753

# %% [markdown]
#  3. Run `associate_ucs()` (if needed)

# %%
if not readable.is_file():
    associate_ucs(basic_ucs_path)

transform_ucs_log = f'/share/compling/projects/sanpi/logs/associate/ucs//ucs-{PAT_DIR}_Adv{UNIT}_frq-thrMIN-7-35f_min{FRQ_FLOOR}x*.log'
! head -15 `ls -t1 {transform_ucs_log} | head -1`
! echo '...'
! tail -2 `ls -t1 {transform_ucs_log} | head -1`
# Out:
# # Manipulating AdvAdj_frq-thrMIN-7-35f_min100x ucs table
# path to this script: /share/compling/projects/sanpi/script/transform_ucs.sh
# Wed May  8 19:36:58 EDT 2024
# (TMP: /share/compling/projects/sanpi/results/ucs/adv_adj/RBXadj/tmp/tmp_RBXadj-20240508-193658.AdvAdj_frq-thrMIN-7-35f_min100x)
# ## Initial Contingency Info
#
# DATA SET FILE:  /share/compling/projects/sanpi/results/ucs/adv_adj/RBXadj/AdvAdj_frq-thrMIN-7.35f_min100x.ds.gz
#
# # Frequency signatures computed by the ucs-make-tables tool for relational cooccurrences.
# # Sample size:  N = 86330753 tokens,  V = 1940305 pair types.
# # A frequency threshold of f >= 100 was applied, leaving V = 55282 pair types.
#
# ##:: size = 55282
# ##:: threshold = 100
#
# ...
# Loading data set /share/compling/projects/sanpi/results/ucs/adv_adj/RBXadj/AdvAdj_frq-thrMIN-7.35f_min100x.rsort.gz ... 55282 rows
# Script finished at Wed May  8 19:37:30 EDT 2024

# %% [markdown]
#  4. Run `ucs_to_csv()` to convert `ucs/[PAT_DIR]/readable/*.txt` to format that `pandas` can parse as a dataframe

# %%
! head -15 {readable} | tail -5 | column -t -s,
csv_path = ucs2csv(readable)
print(f'CSV: `{csv_path.relative_to(RESULT_DIR)}`')
# Out:
# fast       bowler        223  2.1621913e-02  4.0895153e+03  5.6438806403  0.97797792533  0.02723824671  0.97807017544  0.02723830463  8187    228  86330753
# medically  induced       207  5.1598577e-02  3.3995261e+03  5.1945370450  0.97617410199  0.00985145549  0.97641509434  0.00985151342  21012   212  86330753
# nerve      wracking      561  3.7696880e-03  1.4336513e+04  8.8419681624  0.97395828700  0.99292018023  0.97395833333  0.99292035398  565     576  86330753
# only       half-joking   209  1.1667425e+00  2.1160061e+03  3.6591035362  0.95775935445  0.00045016902  0.96313364055  0.00045026219  464174  217  86330753
# fully      multi-coated  145  4.2635221e-01  1.6518884e+03  3.8981875937  0.95744305077  0.00059478501  0.96026490066  0.00059485471  243757  151  86330753
# UCS table text converted & saved as /share/compling/projects/sanpi/results/ucs/adv_adj/RBXadj/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv
# CSV: `ucs/adv_adj/RBXadj/readable/AdvAdj_frq-thrMIN-7.35f_min100x.rsort-view_am-only.csv`

# %%
adx_amdf = pd.read_csv(csv_path).convert_dtypes()
adx_amdf
# Out:
#                l1          l2     f        E11  am_log_likelihood  \
# 0             hip      flexor   104       0.00           2,491.45
# 1      thoroughly  cum-dumped   175       0.09           2,671.08
# 2           super       duper   721       2.66           8,064.58
# 3             far        away  1284       6.71          13,424.89
# 4            fait    accompli   264       0.00           7,157.93
# ...           ...         ...   ...        ...                ...
# 55277        very  impossible   129  23,964.33         -49,382.63
# 55278        very      easier   129  27,673.63         -57,254.24
# 55279        very      higher   158  31,582.26         -65,236.97
# 55280        very       worse   103  24,935.84         -51,729.40
# 55281        very   available   403 100,862.05        -210,254.79
#
#        am_odds_ratio_disc  am_p1_given2  am_p2_given1  am_p1_given2_simple  \
# 0                    7.56          1.00          0.17                 1.00
# 1                    5.86          1.00          0.00                 1.00
# 2                    5.11          0.99          0.00                 1.00
# 3                    4.52          0.99          0.00                 0.99
# 4                    9.16          0.99          0.99                 0.99
# ...                   ...           ...           ...                  ...
# 55277               -2.32         -0.12         -0.00                 0.00
# 55278               -2.38         -0.12         -0.00                 0.00
# 55279               -2.35         -0.12         -0.00                 0.00
# 55280               -2.44         -0.12         -0.00                 0.00
# 55281               -2.46         -0.12         -0.01                 0.00
#
#        am_p2_given1_simple        f1      f2         N
# 0                     0.17       595     104  86330753
# 1                     0.00     41945     175  86330753
# 2                     0.00    318597     722  86330753
# 3                     0.00    448431    1291  86330753
# 4                     0.99       267     268  86330753
# ...                    ...       ...     ...       ...
# 55277                 0.00  10051689  205822  86330753
# 55278                 0.00  10051689  237680  86330753
# 55279                 0.00  10051689  271250  86330753
# 55280                 0.00  10051689  214166  86330753
# 55281                 0.00  10051689  866272  86330753
#
# [55282 rows x 13 columns]

# %%
adx_amdf['key'] = (adx_amdf.l1 + '~' +
                   adx_amdf.l2).astype('string')
adx_amdf = adx_amdf.set_index('key')
adx_amdf
# Out:
#                                l1          l2     f        E11  \
# key
# hip~flexor                    hip      flexor   104       0.00
# thoroughly~cum-dumped  thoroughly  cum-dumped   175       0.09
# super~duper                 super       duper   721       2.66
# far~away                      far        away  1284       6.71
# fait~accompli                fait    accompli   264       0.00
# ...                           ...         ...   ...        ...
# very~impossible              very  impossible   129  23,964.33
# very~easier                  very      easier   129  27,673.63
# very~higher                  very      higher   158  31,582.26
# very~worse                   very       worse   103  24,935.84
# very~available               very   available   403 100,862.05
#
#                        am_log_likelihood  am_odds_ratio_disc  am_p1_given2  \
# key
# hip~flexor                      2,491.45                7.56          1.00
# thoroughly~cum-dumped           2,671.08                5.86          1.00
# super~duper                     8,064.58                5.11          0.99
# far~away                       13,424.89                4.52          0.99
# fait~accompli                   7,157.93                9.16          0.99
# ...                                  ...                 ...           ...
# very~impossible               -49,382.63               -2.32         -0.12
# very~easier                   -57,254.24               -2.38         -0.12
# very~higher                   -65,236.97               -2.35         -0.12
# very~worse                    -51,729.40               -2.44         -0.12
# very~available               -210,254.79               -2.46         -0.12
#
#                        am_p2_given1  am_p1_given2_simple  am_p2_given1_simple  \
# key
# hip~flexor                     0.17                 1.00                 0.17
# thoroughly~cum-dumped          0.00                 1.00                 0.00
# super~duper                    0.00                 1.00                 0.00
# far~away                       0.00                 0.99                 0.00
# fait~accompli                  0.99                 0.99                 0.99
# ...                             ...                  ...                  ...
# very~impossible               -0.00                 0.00                 0.00
# very~easier                   -0.00                 0.00                 0.00
# very~higher                   -0.00                 0.00                 0.00
# very~worse                    -0.00                 0.00                 0.00
# very~available                -0.01                 0.00                 0.00
#
#                              f1      f2         N
# key
# hip~flexor                  595     104  86330753
# thoroughly~cum-dumped     41945     175  86330753
# super~duper              318597     722  86330753
# far~away                 448431    1291  86330753
# fait~accompli               267     268  86330753
# ...                         ...     ...       ...
# very~impossible        10051689  205822  86330753
# very~easier            10051689  237680  86330753
# very~higher            10051689  271250  86330753
# very~worse             10051689  214166  86330753
# very~available         10051689  866272  86330753
#
# [55282 rows x 13 columns]

# %% [markdown]
# 6. Save to `./results/assoc_df/`

# %%
df_csv_path = AM_DF_DIR.joinpath(
    str(csv_path.relative_to(UCS_DIR))
    .replace('/readable', '')
    .replace('.rsort-view_am-only', ''))

if not df_csv_path.is_file():
    confirm_dir(df_csv_path.parent)
    adx_amdf.to_csv(df_csv_path)

df_pkl_path = df_csv_path.with_suffix('.pkl.gz')
if not df_pkl_path.is_file():
    adx_amdf.to_pickle(df_csv_path.with_suffix('.pkl.gz'))

# %% [markdown]
# 7. Add additional AM via `add_extra_am()`
#
#    Define dictionary containing relevant vocab sizes
#
#    !!! Warning This is a `#HACK`: \
#        Rather than developing a command/code to retrieve the vocab sizes programmatically,
#        I simply copied the values given in the log output of `transform_usc.sh`
#        for each `PAT_DIR`+`UNIT` combination

# %%
VOCABS = {
    # // 'ANYmirror': {'Adj': 83422},
    'NEGmirror': {'Adj': 40004},
    'POSmirror': {'Adj': 178159},
    'RBdirect':  {'Adj': 61860},
    'RBXadj':  {'Adj': 1940305}
}  # ! #HACK
VOCAB = VOCABS[PAT_DIR][UNIT]

print(pd.DataFrame(VOCABS).convert_dtypes().to_markdown(intfmt=','))
VOCAB = None
ex_adx_amdf = add_extra_am(df=adx_amdf,
                           verbose=True,
                           vocab=VOCAB,
                           metrics=['t_score', 'mutual_information']
                           ).convert_dtypes()
# Out:
# |     |   NEGmirror |   POSmirror |   RBdirect |    RBXadj |
# |:----|------------:|------------:|-----------:|----------:|
# | Adj |      40,004 |     178,159 |     61,860 | 1,940,305 |
#
# Preview of Extended Measures (rounded)
#
# | key                   |   t_score |   mutual_information |   deltaP_min |   deltaP_max |   deltaP_max_abs |   deltaP_product |   unexpected_f |   unexpected_ratio |
# |:----------------------|----------:|---------------------:|-------------:|-------------:|-----------------:|-----------------:|---------------:|-------------------:|
# | hip~flexor            |     10.20 |                 5.16 |         0.17 |         1.00 |             1.00 |             0.17 |         104.00 |               1.00 |
# | thoroughly~cum-dumped |     13.22 |                 3.31 |         0.00 |         1.00 |             1.00 |             0.00 |         174.91 |               1.00 |
# | super~duper           |     26.75 |                 2.43 |         0.00 |         0.99 |             0.99 |             0.00 |         718.34 |               1.00 |
# | far~away              |     35.65 |                 2.28 |         0.00 |         0.99 |             0.99 |             0.00 |       1,277.29 |               0.99 |
# | fait~accompli         |     16.25 |                 5.50 |         0.99 |         0.99 |             0.99 |             0.97 |         264.00 |               1.00 |
# | smack~dab             |     13.56 |                 5.65 |         0.97 |         0.98 |             0.98 |             0.96 |         184.00 |               1.00 |
# | massively~multiplayer |     13.00 |                 3.64 |         0.01 |         0.98 |             0.98 |             0.01 |         168.96 |               1.00 |
# | bone~marrow           |     33.87 |                 4.78 |         0.82 |         0.98 |             0.98 |             0.81 |       1,146.98 |               1.00 |
# | best~buy              |     14.10 |                 3.18 |         0.00 |         0.98 |             0.98 |             0.00 |         198.87 |               1.00 |
# | fast~bowler           |     14.93 |                 4.01 |         0.03 |         0.98 |             0.98 |             0.03 |         222.98 |               1.00 |

# %% [markdown]
# Save extended AM tables to `extra/` subdirectory if not already saved

# %%
df_extra_csv = df_csv_path.parent / 'extra' / \
    df_csv_path.name.replace('.csv', '_extra.csv')
print(df_extra_csv)
if not df_extra_csv.is_file():
    confirm_dir(df_extra_csv.parent)
    ex_adx_amdf.to_csv(df_extra_csv)

df_extra_pkl = df_extra_csv.with_suffix('.pkl.gz')
if not df_extra_pkl.is_file():
    ex_adx_amdf.to_pickle(df_extra_pkl)
# Out:
# /share/compling/projects/sanpi/results/assoc_df/adv_adj/RBXadj/extra/AdvAdj_frq-thrMIN-7.35f_min100x_extra.csv

# %%
ex_adx_full = ex_adx_amdf.copy()
ex_adx_abbr = adjust_assoc_columns(
    ex_adx_amdf[[c for c in ['polarity', 'quant'] + FOCUS if c in ex_adx_amdf.columns]]).sort_values('LRC', ascending=False)
cols = ex_adx_abbr.columns

# %% [markdown]
#  Define lexical items with given lean shown in binary environment evaluation

# %%
pos_prone = {
    'Adj': [
        'unrelated',
        'unable',
        'akin',
        'larger',
        'different',
        'familiar',
        'similar',
        'likely',
        'brief',
        'unaware'
    ],
    'Adv': [
        'slightly',
        'definitely',
        'utterly',
        # LRC top
        'pretty',
        'rather',
        'plain',
        'fairly',
        'somewhat',
        'otherwise',
        'downright',
        'relatively',
        # G2 top
        # 'very',
        # 'even',
        # 'just',
        # dP1 top (and odds ratio disc)
        'plain',
        'maybe'
    ],
    'Bigr': [
        # G2 top
        'completely_different',
        'too_familiar',
        'even_better',
        # dP1 top
        'quite_different',
        'too_real',
        'well_aware',
        # LRC top
        'too_common',
        'entirely_different'
    ]}
neg_prone = {
    'Bigr': [
        # LRC top
        'quite_sure',
        'really_sure',
        'too_early',
        'too_pleased',
        'too_fancy',
        # dP1 top
        'entirely_sure',
        'ever_easy',
        'ever_perfect',
        'particularly_surprising',
        'particularly_new',
        # G2 top
        'too_late',
        'more_important',
        'so_easy',
        'as_good',
        'too_old'
    ],
    'Adv': [
        'yet',
        # LRC top
        'ever',
        'any',
        'longer',
        'necessarily',
        'that',
        # dP1 top
        'before',
        'wise',  # ? How is this used as an adverb?
        'earthly',
        'remotely',
        'exactly',
        # G2 top
        'particularly',
        'too',
        # 'inherently'
    ],
    'Adj': [
        # LRC top
        'early',
        'late',
        'fancy',
        'alone',
        'sure',
        # dP1 top
        'shabby',
        'demoralizing',
        'alone',
        'aggravating',
        'groundbreaking',
        'eventful',
        # G2 top
        'important',
        'frustrating',
        'evident',
        'certain'
    ]
}


def sort_prone_by_f2(prone_list, amdf):
    return amdf.copy().loc[amdf.l2.isin(prone_list), ['f2', 'l2']].drop_duplicates().reset_index(drop=True).set_index('l2').round(1).sort_values(['f2'], ascending=False).index.to_list()


pos_prone[UNIT] = sort_prone_by_f2(pos_prone[UNIT], ex_adx_abbr)
neg_prone[UNIT] = sort_prone_by_f2(neg_prone[UNIT], ex_adx_abbr)
pos_prone[UNIT]
# Out:
# ['likely',
#  'different',
#  'similar',
#  'familiar',
#  'larger',
#  'unable',
#  'unaware',
#  'brief',
#  'unrelated',
#  'akin']

# %% [markdown]
# Strongest associations for each polarity by metric

# %%
def show_metric_top(amdf: pd.DataFrame,
                    metric: str,
                    k=5,
                    cols=[None]):
    if not any(cols):
        cols = amdf.columns
    return (amdf.nlargest(k, metric)
            .loc[:, [metric] + cols[cols != metric].to_list()]
            .reset_index(drop=True).set_index(['l1', 'l2'])
            )

# %% [markdown]
# Top consevative log ratio $LRC$ values

# %%
exdf = show_metric_top(ex_adx_abbr, "LRC", k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                   LRC     f  unexp_f  dP1  dP2  dP1_simple  dP2_simple  \
# l1    l2
# fait  accompli  20.78   264   264.00 0.99 0.99        0.99        0.99
# smack dab       20.62   184   184.00 0.98 0.97        0.98        0.97
# nerve wracking  20.61   561   561.00 0.97 0.99        0.97        0.99
# slam  dunk      20.56   158   158.00 0.94 0.86        0.94        0.86
# ex    officio   20.20   281   281.00 0.95 0.74        0.95        0.74
# bone  marrow    20.13  1147 1,146.98 0.98 0.82        0.98        0.82
# bona  fide      20.09   454   454.00 0.93 0.99        0.93        0.99
# anal  retentive 17.50   233   233.00 0.52 0.68        0.52        0.68
#
#                        G2         N    f1    f2  exp_f
# l1    l2
# fait  accompli   7,157.93  86330753   267   268   0.00
# smack dab        5,096.69  86330753   189   187   0.00
# nerve wracking  14,336.51  86330753   565   576   0.00
# slam  dunk       4,264.99  86330753   184   168   0.00
# ex    officio    7,109.10  86330753   382   295   0.00
# bone  marrow    26,533.24  86330753  1396  1168   0.02
# bona  fide      11,663.44  86330753   458   486   0.00
# anal  retentive  5,389.98  86330753   342   450   0.00

# %% [markdown]
# Top $\Delta P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                         dP1     f  unexp_f   LRC  dP2  dP1_simple  dP2_simple  \
# l1         l2
# hip        flexor      1.00   104   104.00 16.69 0.17        1.00        0.17
# thoroughly cum-dumped  1.00   175   174.91 11.31 0.00        1.00        0.00
# super      duper       0.99   721   718.34 10.44 0.00        1.00        0.00
# far        away        0.99  1284 1,277.29 12.40 0.00        0.99        0.00
# fait       accompli    0.99   264   264.00 20.78 0.99        0.99        0.99
# smack      dab         0.98   184   184.00 20.62 0.97        0.98        0.97
# massively  multiplayer 0.98   169   168.96 13.79 0.01        0.98        0.01
# bone       marrow      0.98  1147 1,146.98 20.13 0.82        0.98        0.82
#
#                               G2         N      f1    f2  exp_f
# l1         l2
# hip        flexor       2,491.45  86330753     595   104   0.00
# thoroughly cum-dumped   2,671.08  86330753   41945   175   0.09
# super      duper        8,064.58  86330753  318597   722   2.66
# far        away        13,424.89  86330753  448431  1291   6.71
# fait       accompli     7,157.93  86330753     267   268   0.00
# smack      dab          5,096.69  86330753     189   187   0.00
# massively  multiplayer  2,812.58  86330753   19291   172   0.04
# bone       marrow      26,533.24  86330753    1396  1168   0.02

# %% [markdown]
# Top conditional probability $P(\texttt{adv}|\texttt{adj})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP1_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                          dP1_simple     f  unexp_f   LRC  dP1  dP2  \
# l1         l2
# hip        flexor              1.00   104   104.00 16.69 1.00 0.17
# thoroughly cum-dumped          1.00   175   174.91 11.31 1.00 0.00
# not        human-vetted        1.00   195   184.81  4.64 0.95 0.00
# more       infodownload        1.00   162   143.97  3.19 0.89 0.00
#            moderen             1.00   133   118.20  2.90 0.89 0.00
# super      duper               1.00   721   718.34 10.44 0.99 0.00
# far        away                0.99  1284 1,277.29 12.40 0.99 0.00
# most       wanted              0.99  3371 3,064.97  8.50 0.90 0.00
#
#                          dP2_simple        G2         N       f1    f2  exp_f
# l1         l2
# hip        flexor              0.17  2,491.45  86330753      595   104   0.00
# thoroughly cum-dumped          0.00  2,671.08  86330753    41945   175   0.09
# not        human-vetted        0.00  1,151.11  86330753  4511534   195  10.19
# more       infodownload        0.00    711.39  86330753  9607398   162  18.03
#            moderen             0.00    584.05  86330753  9607398   133  14.80
# super      duper               0.00  8,064.58  86330753   318597   722   2.66
# far        away                0.00 13,424.89  86330753   448431  1291   6.71
# most       wanted              0.00 15,796.15  86330753  7734049  3416 306.03

# %% [markdown]
# Top $\Delta P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                              dP2     f  unexp_f   LRC  dP1  dP1_simple  \
# l1             l2
# non-personally identifiable 1.00   177   176.95 11.70 0.01        0.01
# chock          full         1.00  1288 1,286.41  9.66 0.01        0.01
# nerve          wracking     0.99   561   561.00 20.61 0.97        0.97
# awe            inspiring    0.99   140   139.94 11.10 0.00        0.00
# scantily       clad         0.99  5367 5,366.52 15.07 0.71        0.71
# sizey          deep         0.99   130   129.87  9.95 0.00        0.00
# bona           fide         0.99   454   454.00 20.09 0.93        0.93
# fait           accompli     0.99   264   264.00 20.78 0.99        0.99
#
#                              dP2_simple         G2         N    f1      f2  \
# l1             l2
# non-personally identifiable        1.00   2,881.18  86330753   177   25293
# chock          full                1.00  17,267.03  86330753  1288  106587
# nerve          wracking            0.99  14,336.51  86330753   565     576
# awe            inspiring           0.99   2,156.04  86330753   141   37532
# scantily       clad                0.99 104,950.63  86330753  5413    7606
# sizey          deep                0.99   1,794.29  86330753   131   83134
# bona           fide                0.99  11,663.44  86330753   458     486
# fait           accompli            0.99   7,157.93  86330753   267     268
#
#                              exp_f
# l1             l2
# non-personally identifiable   0.05
# chock          full           1.59
# nerve          wracking       0.00
# awe            inspiring      0.06
# scantily       clad           0.48
# sizey          deep           0.13
# bona           fide           0.00
# fait           accompli       0.00

# %% [markdown]
# Top conditional probability $P(\texttt{adj}|\texttt{adv})$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'dP2_simple', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                              dP2_simple     f  unexp_f   LRC  dP1  dP2  \
# l1             l2
# non-personally identifiable        1.00   177   176.95 11.70 0.01 1.00
# chock          full                1.00  1288 1,286.41  9.66 0.01 1.00
# nerve          wracking            0.99   561   561.00 20.61 0.97 0.99
# awe            inspiring           0.99   140   139.94 11.10 0.00 0.99
# sizey          deep                0.99   130   129.87  9.95 0.00 0.99
# scantily       clad                0.99  5367 5,366.52 15.07 0.71 0.99
# bona           fide                0.99   454   454.00 20.09 0.93 0.99
# fait           accompli            0.99   264   264.00 20.78 0.99 0.99
#
#                              dP1_simple         G2         N    f1      f2  \
# l1             l2
# non-personally identifiable        0.01   2,881.18  86330753   177   25293
# chock          full                0.01  17,267.03  86330753  1288  106587
# nerve          wracking            0.97  14,336.51  86330753   565     576
# awe            inspiring           0.00   2,156.04  86330753   141   37532
# sizey          deep                0.00   1,794.29  86330753   131   83134
# scantily       clad                0.71 104,950.63  86330753  5413    7606
# bona           fide                0.93  11,663.44  86330753   458     486
# fait           accompli            0.99   7,157.93  86330753   267     268
#
#                              exp_f
# l1             l2
# non-personally identifiable   0.05
# chock          full           1.59
# nerve          wracking       0.00
# awe            inspiring      0.06
# sizey          deep           0.13
# scantily       clad           0.48
# bona           fide           0.00
# fait           accompli       0.00

# %% [markdown]
# Top log-likelihood $G^2$ values

# %%
exdf = show_metric_top(ex_adx_abbr, 'G2', k=8)
# pos_prone, neg_prone = update_prone(exdf, pos_prone, neg_prone)
exdf
# Out:
#                          G2        f      unexp_f  LRC  dP1  dP2  dP1_simple  \
# l1   l2
# so   many      3,735,386.50  1191874 1,042,704.95 4.00 0.48 0.19        0.54
# not  sure      1,680,246.00   467213   423,055.38 4.47 0.51 0.10        0.55
# too  much      1,636,073.60   583185   508,918.75 3.47 0.29 0.15        0.33
# much more      1,434,754.70   355655   331,551.00 4.44 0.33 0.17        0.34
#      better    1,282,245.60   295224   277,866.87 4.77 0.38 0.14        0.40
# so   much      1,232,042.70   614676   494,778.07 2.86 0.28 0.09        0.35
# most recent    1,114,531.30   313185   277,177.86 5.14 0.69 0.04        0.78
#      important 1,106,213.50   748533   551,162.29 2.38 0.26 0.08        0.34
#
#                 dP2_simple         N       f1       f2      exp_f
# l1   l2
# so   many             0.20  86330753  5819223  2212989 149,169.05
# not  sure             0.10  86330753  4511534   844981  44,157.62
# too  much             0.16  86330753  3604498  1778739  74,266.25
# much more             0.18  86330753  2015845  1032280  24,104.00
#      better           0.15  86330753  2015845   743338  17,357.13
# so   much             0.11  86330753  5819223  1778739 119,897.93
# most recent           0.04  86330753  7734049   401927  36,007.14
#      important        0.10  86330753  7734049  2203136 197,370.71

# %%
sig_adx_abbr = ex_adx_abbr.loc[ex_adx_abbr.LRC.abs() > 1, :]
sig_adx_abbr
# Out:
#                   f     unexp_f    LRC   dP1   dP2  dP1_simple  dP2_simple  \
# key
# fait~accompli   264      264.00  20.78  0.99  0.99        0.99        0.99
# smack~dab       184      184.00  20.62  0.98  0.97        0.98        0.97
# nerve~wracking  561      561.00  20.61  0.97  0.99        0.97        0.99
# slam~dunk       158      158.00  20.56  0.94  0.86        0.94        0.86
# ex~officio      281      281.00  20.20  0.95  0.74        0.95        0.74
# ...             ...         ...    ...   ...   ...         ...         ...
# very~available  403 -100,459.05  -7.79 -0.12 -0.01        0.00        0.00
# more~enough     115  -50,385.44  -8.28 -0.11 -0.01        0.00        0.00
# more~many       373 -245,901.54  -9.17 -0.11 -0.03        0.00        0.00
# most~many       140 -198,113.40 -10.00 -0.09 -0.03        0.00        0.00
# more~much       102 -197,846.62 -10.39 -0.11 -0.02        0.00        0.00
#
#                         G2         N        f1       f2      exp_f     l1  \
# key
# fait~accompli     7,157.93  86330753       267      268       0.00   fait
# smack~dab         5,096.69  86330753       189      187       0.00  smack
# nerve~wracking   14,336.51  86330753       565      576       0.00  nerve
# slam~dunk         4,264.99  86330753       184      168       0.00   slam
# ex~officio        7,109.10  86330753       382      295       0.00     ex
# ...                    ...       ...       ...      ...        ...    ...
# very~available -210,254.79  86330753  10051689   866272 100,862.05   very
# more~enough    -105,717.87  86330753   9607398   453790  50,500.44   more
# more~many      -523,711.57  86330753   9607398  2212989 246,274.54   more
# most~many      -418,743.50  86330753   7734049  2212989 198,253.40   most
# more~much      -422,590.29  86330753   9607398  1778739 197,948.62   more
#
#                        l2
# key
# fait~accompli    accompli
# smack~dab             dab
# nerve~wracking   wracking
# slam~dunk            dunk
# ex~officio        officio
# ...                   ...
# very~available  available
# more~enough        enough
# more~many            many
# most~many            many
# more~much            much
#
# [29278 rows x 14 columns]

# %% [markdown]
# Positive Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(pos_prone['Adv'])]
# Out:
#                               f    unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# otherwise~product-specific  105     104.84 10.14  0.81  0.00        0.81
# slightly~ajar               638     634.19  8.94  0.77  0.00        0.78
# otherwise~law-abiding       500     498.30  8.45  0.36  0.00        0.36
# slightly~stoopid            180     178.60  7.47  0.59  0.00        0.60
# slightly~off-center         316     313.21  7.31  0.52  0.00        0.52
# ...                         ...        ...   ...   ...   ...         ...
# pretty~ready                152  -4,447.26 -4.37 -0.02 -0.00        0.00
# relatively~different        133  -6,473.91 -5.03 -0.01 -0.01        0.00
# rather~many                 173 -10,148.44 -5.36 -0.00 -0.03        0.00
# relatively~important        281 -15,716.90 -5.42 -0.01 -0.03        0.00
# slightly~important          106 -10,106.91 -5.90 -0.00 -0.03        0.00
#
#                             dP2_simple         G2         N       f1       f2  \
# key
# otherwise~product-specific        0.00   1,278.72  86330753   106856      130
# slightly~ajar                     0.00   5,985.76  86330753   400197      822
# otherwise~law-abiding             0.00   4,898.19  86330753   106856     1373
# slightly~stoopid                  0.00   1,528.40  86330753   400197      302
# slightly~off-center               0.00   2,566.21  86330753   400197      602
# ...                                ...        ...       ...      ...      ...
# pretty~ready                      0.00  -7,953.56  86330753  1652360   240297
# relatively~different              0.00 -12,023.06  86330753   626884   909864
# rather~many                       0.00 -19,190.39  86330753   402649  2212989
# relatively~important              0.00 -29,678.85  86330753   626884  2203136
# slightly~important                0.00 -19,552.84  86330753   400197  2203136
#
#                                exp_f          l1                l2
# key
# otherwise~product-specific      0.16   otherwise  product-specific
# slightly~ajar                   3.81    slightly              ajar
# otherwise~law-abiding           1.70   otherwise       law-abiding
# slightly~stoopid                1.40    slightly           stoopid
# slightly~off-center             2.79    slightly        off-center
# ...                              ...         ...               ...
# pretty~ready                4,599.26      pretty             ready
# relatively~different        6,606.91  relatively         different
# rather~many                10,321.44      rather              many
# relatively~important       15,997.90  relatively         important
# slightly~important         10,212.91    slightly         important
#
# [2362 rows x 14 columns]

# %% [markdown]
#  Negative Prone Adverbs with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l1.isin(neg_prone['Adv'])]
# Out:
#                          f    unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# yet~unborn             463     462.25 10.52  0.73  0.00        0.73
# remotely~exploitable   154     153.70  8.61  0.13  0.01        0.13
# exactly~alike         3040   3,030.54  8.56  0.23  0.05        0.23
# yet~unnamed            771     768.38  8.49  0.35  0.01        0.35
# ever~olympic           229     228.24  8.42  0.43  0.00        0.43
# ...                    ...        ...   ...   ...   ...         ...
# too~likely            1196 -42,592.94 -5.05 -0.04 -0.01        0.00
# too~necessary          127  -7,697.19 -5.37 -0.04 -0.00        0.00
# too~responsible        124  -8,672.69 -5.57 -0.04 -0.00        0.00
# too~possible           234 -14,974.86 -5.62 -0.04 -0.00        0.00
# too~available          277 -35,891.75 -6.66 -0.04 -0.01        0.00
#
#                       dP2_simple         G2         N       f1       f2  \
# key
# yet~unborn                  0.00   5,505.48  86330753   101707      635
# remotely~exploitable        0.01   1,639.61  86330753    22194     1158
# exactly~alike               0.05  29,939.31  86330753    61599    13261
# yet~unnamed                 0.01   7,535.14  86330753   101707     2227
# ever~olympic                0.00   2,273.22  86330753   124592      529
# ...                          ...        ...       ...      ...      ...
# too~likely                  0.00 -78,883.59  86330753  3604498  1048782
# too~necessary               0.00 -14,690.20  86330753  3604498   187396
# too~responsible             0.00 -16,677.58  86330753  3604498   210688
# too~possible                0.00 -28,694.70  86330753  3604498   364265
# too~available               0.00 -70,989.98  86330753  3604498   866272
#
#                          exp_f        l1           l2
# key
# yet~unborn                0.75       yet       unborn
# remotely~exploitable      0.30  remotely  exploitable
# exactly~alike             9.46   exactly        alike
# yet~unnamed               2.62       yet      unnamed
# ever~olympic              0.76      ever      olympic
# ...                        ...       ...          ...
# too~likely           43,788.94       too       likely
# too~necessary         7,824.19       too    necessary
# too~responsible       8,796.69       too  responsible
# too~possible         15,208.86       too     possible
# too~available        36,168.75       too    available
#
# [1298 rows x 14 columns]

# %% [markdown]
#  Positive Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(pos_prone['Adj'])]
# Out:
#                         f    unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# blissfully~unaware   3112   3,109.50 10.34  0.11  0.40        0.11
# blithely~unaware      255     254.72  9.46  0.01  0.29        0.01
# mercifully~brief      290     289.43  8.62  0.01  0.15        0.01
# confusingly~similar   700     697.18  7.80  0.00  0.63        0.00
# intimately~familiar  3832   3,811.43  7.48  0.02  0.45        0.02
# ...                   ...        ...   ...   ...   ...         ...
# less~different        198 -13,511.54 -5.63 -0.02 -0.01        0.00
# most~different       1364 -80,147.31 -5.84 -0.09 -0.01        0.00
# so~larger             122 -10,118.07 -5.85 -0.07 -0.00        0.00
# much~likely           259 -24,230.33 -6.15 -0.02 -0.01        0.00
# so~likely             847 -69,847.35 -6.24 -0.07 -0.01        0.00
#
#                      dP2_simple          G2         N       f1       f2  \
# key
# blissfully~unaware         0.40   39,949.36  86330753     7768    27809
# blithely~unaware           0.29    3,048.13  86330753      874    27809
# mercifully~brief           0.15    3,084.05  86330753     1927    25571
# confusingly~similar        0.64    6,914.49  86330753     1100   221410
# intimately~familiar        0.46   34,594.29  86330753     8385   211750
# ...                         ...         ...       ...      ...      ...
# less~different             0.00  -25,691.21  86330753  1300804   909864
# most~different             0.00 -157,571.34  86330753  7734049   909864
# so~larger                  0.00  -19,880.09  86330753  5819223   151916
# much~likely                0.00  -46,973.59  86330753  2015845  1048782
# so~likely                  0.00 -137,979.63  86330753  5819223  1048782
#
#                         exp_f           l1         l2
# key
# blissfully~unaware       2.50   blissfully    unaware
# blithely~unaware         0.28     blithely    unaware
# mercifully~brief         0.57   mercifully      brief
# confusingly~similar      2.82  confusingly    similar
# intimately~familiar     20.57   intimately   familiar
# ...                       ...          ...        ...
# less~different      13,709.54         less  different
# most~different      81,511.31         most  different
# so~larger           10,240.07           so     larger
# much~likely         24,489.33         much     likely
# so~likely           70,694.35           so     likely
#
# [431 rows x 14 columns]

# %% [markdown]
#  Negative Prone Adjectives with significant LRC

# %%
sig_adx_abbr.loc[sig_adx_abbr.l2.isin(neg_prone['Adj'])]
# Out:
#                          f    unexp_f   LRC   dP1   dP2  dP1_simple  \
# key
# too~late            136383 129,584.07  6.84  0.80  0.04        0.84
# fashionably~late       384     380.38  6.41  0.00  0.20        0.00
# amply~evident          102     101.18  6.28  0.00  0.09        0.00
# plainly~evident        367     362.07  5.86  0.01  0.05        0.01
# too~shabby            5903   5,568.65  5.83  0.70  0.00        0.74
# ...                    ...        ...   ...   ...   ...         ...
# totally~important      122  -9,135.96 -5.61 -0.00 -0.03        0.00
# extremely~sure         111  -9,599.34 -5.79 -0.01 -0.01        0.00
# slightly~important     106 -10,106.91 -5.90 -0.00 -0.03        0.00
# most~late              157 -14,431.23 -6.10 -0.09 -0.00        0.00
# most~sure              315 -75,383.68 -7.64 -0.09 -0.01        0.00
#
#                     dP2_simple          G2         N       f1       f2  \
# key
# too~late                  0.04  728,970.71  86330753  3604498   162840
# fashionably~late          0.20    2,903.39  86330753     1919   162840
# amply~evident             0.09      789.89  86330753     1168    60888
# plainly~evident           0.05    2,460.79  86330753     6989    60888
# too~shabby                0.00   28,458.74  86330753  3604498     8008
# ...                        ...         ...       ...      ...      ...
# totally~important         0.00  -17,488.68  86330753   362777  2203136
# extremely~sure            0.00  -18,410.50  86330753   992094   844981
# slightly~important        0.00  -19,552.84  86330753   400197  2203136
# most~late                 0.00  -28,830.40  86330753  7734049   162840
# most~sure                 0.00 -155,283.28  86330753  7734049   844981
#
#                        exp_f           l1         l2
# key
# too~late            6,798.93          too       late
# fashionably~late        3.62  fashionably       late
# amply~evident           0.82        amply    evident
# plainly~evident         4.93      plainly    evident
# too~shabby            334.35          too     shabby
# ...                      ...          ...        ...
# totally~important   9,257.96      totally  important
# extremely~sure      9,710.34    extremely       sure
# slightly~important 10,212.91     slightly  important
# most~late          14,588.23         most       late
# most~sure          75,698.68         most       sure
#
# [312 rows x 14 columns]
